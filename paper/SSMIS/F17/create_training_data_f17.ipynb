# %%
'''
Creates training data for F17 channel predictor
'''


import numpy as np
import xarray as xr
import glob
from tqdm import tqdm
from util_funcs.L1C import scantime2datetime
from util_funcs import data2xarray, array_funcs
import geography

import sensor_info
import local_functions

satellite = sensor_info.satellite
sensor = sensor_info.sensor

datapath = f'/edata1/archive/GPM/1C_{satellite}_V7/'

# %%
'''
Satellite: F13

Get data and quality check for training.

nscans: generally around 3220
npixs: 90

    
Tb array will be set up as follows:
    Tbs =  [m x n], where m is the number of samples and n is the
           number of channels (features)
    1-2:   19V and H
    3:     22V
    4-5:   37V and H
    6-9:   92V and H (high-frequency channels are double sampled)
    10-11: 150H
    12-13: 183+-1 H
    14-15: 183+-3 H
    16-17: 183+-7 H
'''

#Set up a random seed for reproducibility
np.random.seed(12)

#Get a random list of files
file_list = glob.glob(f'{datapath}*/*/1C.{satellite}.{sensor}.*.HDF5'); file_list.sort()

#Everything looks good before about 04/2016:
good_files = [ifile for ifile in file_list if int(ifile.split('/')[5]) <= 1604]

flist = np.random.choice(good_files, size=200)

raise

#Loop through files and get good quality data.
for i, ifile in enumerate(tqdm(flist, desc="Processing Files")):

    #print(f'{i+1} of {len(flist)}, {ifile}')

    data = local_functions.read_ssmis_l1c(ifile)

    lat = data['lat']
    lon = data['lon']
    scantime = data['scantime']
    Tbs = data['Tbs']
    qual = data['qual']

    #Get only good quality data and reshape:
    goodqual = np.all(qual == 0, axis=2)
    all_bad = np.all(goodqual == False)
    if all_bad:
        print('all were bad.')
        continue
    lat = lat[goodqual]
    lon = lon[goodqual]
    scantime = scantime[np.where(goodqual)[0]]
    Tbs = Tbs[goodqual]

    #Check for NaNs (shouldn't be any if all good, but I've seen some)
    nonans = local_functions.find_nan_rows(Tbs, return_good=True)
    Tbs = Tbs[nonans]
    lat = lat[nonans]
    lon = lon[nonans]
    scantime = scantime[nonans]
    

    #Attach GPROF surface map data to each pixel
    sfctype = local_functions.attach_gpm_sfctype(lat, lon, scantime, sensor=sensor)

    npixs = lat.size

    #Output as NetCDF
    dset = data2xarray(data_vars = [lat, lon, scantime, sfctype, Tbs],
                       var_names = ['latitude', 'longitude', 'scantime', 'sfctype', 'Tbs'],
                       dims = [npixs, sensor_info.nfeatures],
                       dim_names = ['pixels', 'channels'])


    if i == 0:
        training_dataset = dset
    else:
        training_dataset = xr.concat((training_dataset, dset), dim='pixels')

training_dataset.to_netcdf(f'training_data/{satellite}_training_data.nc', engine='netcdf4')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 34
#      30 good_files = [ifile for ifile in file_list if int(ifile.split('/')[5]) <= 1604]
#      32 flist = np.random.choice(good_files, size=200)
# ---> 34 raise
#      36 #Loop through files and get good quality data.
#      37 for i, ifile in enumerate(tqdm(flist, desc="Processing Files")):
#      38
#      39     #print(f'{i+1} of {len(flist)}, {ifile}')
#
# RuntimeError: No active exception to reraise

# %%
with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    sfctype = f.sfctype.values

for i in range(19):
    print(f'Number of pixels with surface type {i}: {np.sum(sfctype == i)}')

print(f'Total number of ocean pixels: {np.sum(sfctype == 1)}')
print(f'Total number of nonocean pixels: {np.sum(sfctype > 1)}')
# Out:
# Number of pixels with surface type 0: 0
# Number of pixels with surface type 1: 28123167
# Number of pixels with surface type 2: 6121504
# Number of pixels with surface type 3: 1823154
# Number of pixels with surface type 4: 1096168
# Number of pixels with surface type 5: 959364
# Number of pixels with surface type 6: 496573
# Number of pixels with surface type 7: 890662
# Number of pixels with surface type 8: 242927
# Number of pixels with surface type 9: 313284
# Number of pixels with surface type 10: 1572325
# Number of pixels with surface type 11: 5467484
# Number of pixels with surface type 12: 817676
# Number of pixels with surface type 13: 1262277
# Number of pixels with surface type 14: 1407041
# Number of pixels with surface type 15: 944236
# Number of pixels with surface type 16: 283542
# Number of pixels with surface type 17: 2053833
# Number of pixels with surface type 18: 1119462
# Total number of ocean pixels: 28123167
# Total number of nonocean pixels: 26871512

# %%
flist
# Out:
# array(['/edata1/archive/GPM/1C_F17_V7/0905/090503/1C.F17.SSMIS.XCAL2021-V.20090503-S025528-E043723.012863.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0811/081109/1C.F17.SSMIS.XCAL2021-V.20081109-S194618-E212813.010401.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0908/090825/1C.F17.SSMIS.XCAL2021-V.20090825-S225013-E003209.014485.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081207/1C.F17.SSMIS.XCAL2021-V.20081207-S084311-E102507.010790.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0804/080408/1C.F17.SSMIS.XCAL2021-V.20080408-S023555-E041751.007354.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0910/091023/1C.F17.SSMIS.XCAL2021-V.20091023-S202830-E221025.015317.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081208/1C.F17.SSMIS.XCAL2021-V.20081208-S032435-E050631.010801.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0902/090205/1C.F17.SSMIS.XCAL2021-V.20090205-S212635-E230830.011645.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091118/1C.F17.SSMIS.XCAL2021-V.20091118-S232606-E010801.015686.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091121/1C.F17.SSMIS.XCAL2021-V.20091121-S210549-E224744.015727.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0903/090322/1C.F17.SSMIS.XCAL2021-V.20090322-S032215-E050411.012270.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0806/080607/1C.F17.SSMIS.XCAL2021-V.20080607-S065009-E083205.008204.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0811/081106/1C.F17.SSMIS.XCAL2021-V.20081106-S083056-E101252.010352.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0901/090109/1C.F17.SSMIS.XCAL2021-V.20090109-S050554-E064750.011254.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0910/091026/1C.F17.SSMIS.XCAL2021-V.20091026-S162618-E180813.015357.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081229/1C.F17.SSMIS.XCAL2021-V.20081229-S173759-E191955.011106.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0902/090202/1C.F17.SSMIS.XCAL2021-V.20090202-S014131-E032327.011591.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0909/090907/1C.F17.SSMIS.XCAL2021-V.20090907-S095233-E113429.014661.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0905/090503/1C.F17.SSMIS.XCAL2021-V.20090503-S080118-E094313.012866.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0804/080403/1C.F17.SSMIS.XCAL2021-V.20080403-S033941-E052137.007284.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0806/080609/1C.F17.SSMIS.XCAL2021-V.20080609-S094833-E113029.008234.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0809/080925/1C.F17.SSMIS.XCAL2021-V.20080925-S085649-E103845.009759.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091130/1C.F17.SSMIS.XCAL2021-V.20091130-S191048-E205244.015853.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0905/090504/1C.F17.SSMIS.XCAL2021-V.20090504-S093028-E111223.012881.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0902/090201/1C.F17.SSMIS.XCAL2021-V.20090201-S171148-E185343.011586.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0902/090225/1C.F17.SSMIS.XCAL2021-V.20090225-S152918-E171113.011924.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0908/090816/1C.F17.SSMIS.XCAL2021-V.20090816-S161525-E175721.014354.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0902/090210/1C.F17.SSMIS.XCAL2021-V.20090210-S133458-E151654.011711.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0805/080528/1C.F17.SSMIS.XCAL2021-V.20080528-S035150-E053346.008061.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0902/090221/1C.F17.SSMIS.XCAL2021-V.20090221-S212612-E230808.011871.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0809/080904/1C.F17.SSMIS.XCAL2021-V.20080904-S031252-E045448.009459.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0908/090810/1C.F17.SSMIS.XCAL2021-V.20090810-S155005-E173200.014269.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0805/080512/1C.F17.SSMIS.XCAL2021-V.20080512-S021003-E035159.007834.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081216/1C.F17.SSMIS.XCAL2021-V.20081216-S133607-E151803.010920.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0807/080703/1C.F17.SSMIS.XCAL2021-V.20080703-S214158-E232354.008580.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0905/090524/1C.F17.SSMIS.XCAL2021-V.20090524-S033303-E051459.013160.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0807/080710/1C.F17.SSMIS.XCAL2021-V.20080710-S183046-E201241.008677.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0805/080524/1C.F17.SSMIS.XCAL2021-V.20080524-S113038-E131234.008009.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0908/090823/1C.F17.SSMIS.XCAL2021-V.20090823-S061618-E075814.014447.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0908/090826/1C.F17.SSMIS.XCAL2021-V.20090826-S053800-E071955.014489.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0806/080626/1C.F17.SSMIS.XCAL2021-V.20080626-S042949-E061145.008471.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0912/091208/1C.F17.SSMIS.XCAL2021-V.20091208-S104047-E122243.015961.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080825/1C.F17.SSMIS.XCAL2021-V.20080825-S185556-E203752.009327.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081205/1C.F17.SSMIS.XCAL2021-V.20081205-S173826-E192022.010767.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0803/080331/1C.F17.SSMIS.XCAL2021-V.20080331-S193528-E211724.007251.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0903/090321/1C.F17.SSMIS.XCAL2021-V.20090321-S033502-E051657.012256.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091123/1C.F17.SSMIS.XCAL2021-V.20091123-S084639-E102834.015748.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0811/081105/1C.F17.SSMIS.XCAL2021-V.20081105-S221916-E000112.010346.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0810/081009/1C.F17.SSMIS.XCAL2021-V.20081009-S175156-E193352.009962.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0907/090711/1C.F17.SSMIS.XCAL2021-V.20090711-S083735-E101931.013841.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0910/091016/1C.F17.SSMIS.XCAL2021-V.20091016-S013433-E031629.015207.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0906/090608/1C.F17.SSMIS.XCAL2021-V.20090608-S103309-E121504.013376.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091121/1C.F17.SSMIS.XCAL2021-V.20091121-S192352-E210548.015726.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0803/080323/1C.F17.SSMIS.XCAL2021-V.20080323-S124746-E142942.007134.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081202/1C.F17.SSMIS.XCAL2021-V.20081202-S080503-E094659.010719.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0902/090207/1C.F17.SSMIS.XCAL2021-V.20090207-S040135-E054331.011663.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0809/080914/1C.F17.SSMIS.XCAL2021-V.20080914-S111704-E125900.009605.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0809/080909/1C.F17.SSMIS.XCAL2021-V.20080909-S154442-E172638.009537.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080818/1C.F17.SSMIS.XCAL2021-V.20080818-S202510-E220706.009229.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091102/1C.F17.SSMIS.XCAL2021-V.20091102-S012119-E030315.015447.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0905/090513/1C.F17.SSMIS.XCAL2021-V.20090513-S073530-E091725.013007.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0803/080330/1C.F17.SSMIS.XCAL2021-V.20080330-S180616-E194812.007236.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081219/1C.F17.SSMIS.XCAL2021-V.20081219-S075200-E093356.010959.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0807/080723/1C.F17.SSMIS.XCAL2021-V.20080723-S140303-E154459.008858.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0809/080924/1C.F17.SSMIS.XCAL2021-V.20080924-S210312-E224507.009752.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0804/080424/1C.F17.SSMIS.XCAL2021-V.20080424-S005347-E023543.007579.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0809/080921/1C.F17.SSMIS.XCAL2021-V.20080921-S145340-E163535.009706.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0804/080422/1C.F17.SSMIS.XCAL2021-V.20080422-S200042-E214238.007562.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0901/090110/1C.F17.SSMIS.XCAL2021-V.20090110-S114056-E132251.011272.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0810/081008/1C.F17.SSMIS.XCAL2021-V.20081008-S125851-E144047.009945.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0907/090707/1C.F17.SSMIS.XCAL2021-V.20090707-S175823-E194019.013790.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0906/090615/1C.F17.SSMIS.XCAL2021-V.20090615-S122738-E140934.013476.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0806/080607/1C.F17.SSMIS.XCAL2021-V.20080607-S202544-E220739.008212.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0803/080329/1C.F17.SSMIS.XCAL2021-V.20080329-S214255-E232451.007224.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0805/080530/1C.F17.SSMIS.XCAL2021-V.20080530-S202548-E220744.008099.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0805/080529/1C.F17.SSMIS.XCAL2021-V.20080529-S135046-E153242.008081.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080815/1C.F17.SSMIS.XCAL2021-V.20080815-S105145-E123340.009181.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0912/091226/1C.F17.SSMIS.XCAL2021-V.20091226-S152027-E170222.016218.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091121/1C.F17.SSMIS.XCAL2021-V.20091121-S091212-E105408.015720.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081208/1C.F17.SSMIS.XCAL2021-V.20081208-S234756-E012952.010813.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0805/080517/1C.F17.SSMIS.XCAL2021-V.20080517-S162348-E180544.007913.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0904/090422/1C.F17.SSMIS.XCAL2021-V.20090422-S185132-E203328.012717.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080824/1C.F17.SSMIS.XCAL2021-V.20080824-S154447-E172643.009311.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0906/090608/1C.F17.SSMIS.XCAL2021-V.20090608-S085112-E103308.013375.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0811/081130/1C.F17.SSMIS.XCAL2021-V.20081130-S032444-E050640.010688.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0810/081023/1C.F17.SSMIS.XCAL2021-V.20081023-S011750-E025946.010150.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0811/081123/1C.F17.SSMIS.XCAL2021-V.20081123-S215331-E233526.010600.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0809/080911/1C.F17.SSMIS.XCAL2021-V.20080911-S000141-E014337.009556.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0811/081109/1C.F17.SSMIS.XCAL2021-V.20081109-S111634-E125830.010396.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0905/090513/1C.F17.SSMIS.XCAL2021-V.20090513-S091726-E105922.013008.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080806/1C.F17.SSMIS.XCAL2021-V.20080806-S005252-E023448.009048.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0910/091031/1C.F17.SSMIS.XCAL2021-V.20091031-S221012-E235208.015431.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0806/080603/1C.F17.SSMIS.XCAL2021-V.20080603-S175251-E193446.008154.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080804/1C.F17.SSMIS.XCAL2021-V.20080804-S113003-E131159.009026.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081228/1C.F17.SSMIS.XCAL2021-V.20081228-S193242-E211437.011093.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0904/090415/1C.F17.SSMIS.XCAL2021-V.20090415-S151508-E165703.012616.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0902/090218/1C.F17.SSMIS.XCAL2021-V.20090218-S101053-E115249.011822.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0806/080605/1C.F17.SSMIS.XCAL2021-V.20080605-S071539-E085735.008176.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0810/081001/1C.F17.SSMIS.XCAL2021-V.20081001-S142806-E161002.009847.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0805/080505/1C.F17.SSMIS.XCAL2021-V.20080505-S135100-E153256.007742.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0909/090901/1C.F17.SSMIS.XCAL2021-V.20090901-S023927-E042122.014572.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0901/090123/1C.F17.SSMIS.XCAL2021-V.20090123-S020713-E034909.011450.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0905/090526/1C.F17.SSMIS.XCAL2021-V.20090526-S182501-E200656.013197.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0912/091217/1C.F17.SSMIS.XCAL2021-V.20091217-S171529-E185725.016092.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0906/090629/1C.F17.SSMIS.XCAL2021-V.20090629-S092852-E111048.013672.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0809/080904/1C.F17.SSMIS.XCAL2021-V.20080904-S201220-E215416.009469.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0907/090710/1C.F17.SSMIS.XCAL2021-V.20090710-S121414-E135610.013829.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0910/091030/1C.F17.SSMIS.XCAL2021-V.20091030-S204102-E222258.015416.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081214/1C.F17.SSMIS.XCAL2021-V.20081214-S190728-E204924.010895.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0912/091211/1C.F17.SSMIS.XCAL2021-V.20091211-S031440-E045636.015999.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081213/1C.F17.SSMIS.XCAL2021-V.20081213-S105031-E123226.010876.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0905/090513/1C.F17.SSMIS.XCAL2021-V.20090513-S073530-E091725.013007.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0901/090109/1C.F17.SSMIS.XCAL2021-V.20090109-S234718-E012914.011265.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080827/1C.F17.SSMIS.XCAL2021-V.20080827-S045452-E063647.009347.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0805/080524/1C.F17.SSMIS.XCAL2021-V.20080524-S131235-E145431.008010.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0807/080716/1C.F17.SSMIS.XCAL2021-V.20080716-S153218-E171414.008760.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0806/080613/1C.F17.SSMIS.XCAL2021-V.20080613-S154519-E172715.008294.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081213/1C.F17.SSMIS.XCAL2021-V.20081213-S141424-E155620.010878.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0907/090727/1C.F17.SSMIS.XCAL2021-V.20090727-S000727-E014923.014062.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0903/090323/1C.F17.SSMIS.XCAL2021-V.20090323-S164503-E182658.012292.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0809/080924/1C.F17.SSMIS.XCAL2021-V.20080924-S155721-E173917.009749.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080822/1C.F17.SSMIS.XCAL2021-V.20080822-S211607-E225803.009286.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0907/090702/1C.F17.SSMIS.XCAL2021-V.20090702-S204410-E222606.013721.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0906/090612/1C.F17.SSMIS.XCAL2021-V.20090612-S025417-E043613.013428.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0905/090529/1C.F17.SSMIS.XCAL2021-V.20090529-S142248-E160444.013237.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091114/1C.F17.SSMIS.XCAL2021-V.20091114-S191122-E205317.015627.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0806/080611/1C.F17.SSMIS.XCAL2021-V.20080611-S023515-E041711.008258.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091121/1C.F17.SSMIS.XCAL2021-V.20091121-S073015-E091211.015719.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0811/081129/1C.F17.SSMIS.XCAL2021-V.20081129-S051926-E070122.010675.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0901/090106/1C.F17.SSMIS.XCAL2021-V.20090106-S141355-E155551.011217.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0804/080415/1C.F17.SSMIS.XCAL2021-V.20080415-S010638-E024834.007452.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0912/091215/1C.F17.SSMIS.XCAL2021-V.20091215-S141709-E155905.016062.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0809/080901/1C.F17.SSMIS.XCAL2021-V.20080901-S085657-E103853.009420.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081203/1C.F17.SSMIS.XCAL2021-V.20081203-S061021-E075216.010732.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0804/080421/1C.F17.SSMIS.XCAL2021-V.20080421-S201328-E215523.007548.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080816/1C.F17.SSMIS.XCAL2021-V.20080816-S190843-E205039.009200.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0901/090125/1C.F17.SSMIS.XCAL2021-V.20090125-S220502-E234658.011490.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0810/081017/1C.F17.SSMIS.XCAL2021-V.20081017-S041618-E055814.010067.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0907/090714/1C.F17.SSMIS.XCAL2021-V.20090714-S011130-E025326.013879.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080827/1C.F17.SSMIS.XCAL2021-V.20080827-S215420-E233615.009357.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0910/091031/1C.F17.SSMIS.XCAL2021-V.20091031-S134029-E152225.015426.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0904/090404/1C.F17.SSMIS.XCAL2021-V.20090404-S090555-E104751.012457.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0908/090813/1C.F17.SSMIS.XCAL2021-V.20090813-S114753-E132949.014309.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0912/091223/1C.F17.SSMIS.XCAL2021-V.20091223-S210437-E224633.016179.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0902/090225/1C.F17.SSMIS.XCAL2021-V.20090225-S203508-E221703.011927.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0901/090109/1C.F17.SSMIS.XCAL2021-V.20090109-S050554-E064750.011254.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080821/1C.F17.SSMIS.XCAL2021-V.20080821-S162302-E180458.009269.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0908/090824/1C.F17.SSMIS.XCAL2021-V.20090824-S060332-E074528.014461.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081218/1C.F17.SSMIS.XCAL2021-V.20081218-S094642-E112838.010946.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091126/1C.F17.SSMIS.XCAL2021-V.20091126-S232549-E010745.015799.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0905/090523/1C.F17.SSMIS.XCAL2021-V.20090523-S121533-E135728.013151.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0803/080327/1C.F17.SSMIS.XCAL2021-V.20080327-S133842-E152037.007191.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081211/1C.F17.SSMIS.XCAL2021-V.20081211-S061012-E075208.010845.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081211/1C.F17.SSMIS.XCAL2021-V.20081211-S125759-E143955.010849.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0909/090915/1C.F17.SSMIS.XCAL2021-V.20090915-S012238-E030433.014769.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0804/080421/1C.F17.SSMIS.XCAL2021-V.20080421-S063753-E081949.007540.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080823/1C.F17.SSMIS.XCAL2021-V.20080823-S173929-E192125.009298.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0905/090516/1C.F17.SSMIS.XCAL2021-V.20090516-S203244-E221440.013057.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091105/1C.F17.SSMIS.XCAL2021-V.20091105-S192423-E210619.015500.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081224/1C.F17.SSMIS.XCAL2021-V.20081224-S101204-E115400.011031.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0909/090925/1C.F17.SSMIS.XCAL2021-V.20090925-S175620-E193816.014920.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0811/081128/1C.F17.SSMIS.XCAL2021-V.20081128-S204942-E223138.010670.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091129/1C.F17.SSMIS.XCAL2021-V.20091129-S123548-E141744.015835.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0910/091001/1C.F17.SSMIS.XCAL2021-V.20091001-S062803-E080959.014998.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0907/090726/1C.F17.SSMIS.XCAL2021-V.20090726-S034406-E052602.014050.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0811/081116/1C.F17.SSMIS.XCAL2021-V.20081116-S163503-E181658.010498.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0912/091211/1C.F17.SSMIS.XCAL2021-V.20091211-S114424-E132619.016004.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0902/090218/1C.F17.SSMIS.XCAL2021-V.20090218-S014110-E032305.011817.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0807/080713/1C.F17.SSMIS.XCAL2021-V.20080713-S023459-E041655.008710.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081220/1C.F17.SSMIS.XCAL2021-V.20081220-S175054-E193250.010979.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0807/080706/1C.F17.SSMIS.XCAL2021-V.20080706-S022218-E040414.008611.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0910/091002/1C.F17.SSMIS.XCAL2021-V.20091002-S130304-E144500.015016.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0910/091022/1C.F17.SSMIS.XCAL2021-V.20091022-S121132-E135328.015298.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091118/1C.F17.SSMIS.XCAL2021-V.20091118-S044442-E062638.015675.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0908/090806/1C.F17.SSMIS.XCAL2021-V.20090806-S095323-E113518.014209.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0903/090329/1C.F17.SSMIS.XCAL2021-V.20090329-S171021-E185217.012377.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0907/090705/1C.F17.SSMIS.XCAL2021-V.20090705-S214749-E232945.013764.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081211/1C.F17.SSMIS.XCAL2021-V.20081211-S162152-E180348.010851.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0807/080707/1C.F17.SSMIS.XCAL2021-V.20080707-S172704-E190900.008634.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0909/090907/1C.F17.SSMIS.XCAL2021-V.20090907-S030447-E044642.014657.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0805/080525/1C.F17.SSMIS.XCAL2021-V.20080525-S093556-E111752.008022.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0910/091014/1C.F17.SSMIS.XCAL2021-V.20091014-S204129-E222325.015190.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0909/090922/1C.F17.SSMIS.XCAL2021-V.20090922-S100455-E114651.014873.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081227/1C.F17.SSMIS.XCAL2021-V.20081227-S162134-E180330.011077.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0804/080420/1C.F17.SSMIS.XCAL2021-V.20080420-S115629-E133825.007529.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0909/090929/1C.F17.SSMIS.XCAL2021-V.20090929-S014745-E032941.014967.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0804/080414/1C.F17.SSMIS.XCAL2021-V.20080414-S232441-E010637.007451.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0910/091014/1C.F17.SSMIS.XCAL2021-V.20091014-S121146-E135342.015185.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0909/090929/1C.F17.SSMIS.XCAL2021-V.20090929-S152319-E170515.014975.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0805/080511/1C.F17.SSMIS.XCAL2021-V.20080511-S141626-E155821.007827.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0808/080826/1C.F17.SSMIS.XCAL2021-V.20080826-S115524-E133719.009337.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0911/091111/1C.F17.SSMIS.XCAL2021-V.20091111-S111958-E130154.015580.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0806/080606/1C.F17.SSMIS.XCAL2021-V.20080606-S171435-E185631.008196.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0807/080725/1C.F17.SSMIS.XCAL2021-V.20080725-S234914-E013110.008892.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0902/090211/1C.F17.SSMIS.XCAL2021-V.20090211-S081622-E095818.011722.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0803/080323/1C.F17.SSMIS.XCAL2021-V.20080323-S041802-E055958.007129.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0906/090629/1C.F17.SSMIS.XCAL2021-V.20090629-S125246-E143441.013674.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0812/081202/1C.F17.SSMIS.XCAL2021-V.20081202-S232234-E010429.010728.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0912/091228/1C.F17.SSMIS.XCAL2021-V.20091228-S232436-E010632.016251.V07A.HDF5',
#        '/edata1/archive/GPM/1C_F17_V7/0910/091025/1C.F17.SSMIS.XCAL2021-V.20091025-S113314-E131509.015340.V07A.HDF5'],
#       dtype='<U107')
