# %% [markdown]
# # Channel Prediction Model for Quality Control
#
# This notebook contains the code and outlines the development of the
# SSMI Channel Prediction Neural Network for QC purposes of SSMIS L1C
# data. The simple Feed-Forward Neural Networks (FFNNs) are trained on
# good quality SSMIS brightness temperature observation vectors and are
# trained to predict one channel from all the others as predictors.
#
# The end product is a tree of FFNNs, discretized by surface (ocean or
# land), and by channel, since these are fully distinct problems.

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import glob
import torch
from torch import nn
import cartopy.crs as ccrs
from util_funcs.L1C import scantime2datetime
from util_funcs import data2xarray, array_funcs
import geography
from tqdm import tqdm

from dataset_class import dataset
from model_class import channel_predictor
import local_functions
import sensor_info


#General parameters:

satellite = sensor_info.satellite
sensor = sensor_info.sensor

nchans = sensor_info.nchannels
batch_size = 1000
input_size = nchans - 1
hidden_size = 256
output_size = 1

# %%
'''
Function Definitions:
'''

chan_desc = sensor_info.channel_descriptions


def extract_channel(Tb_array, chan):

    '''
    Use in preparing training data.

    Assumes Tb array is [m x n] where m (rows) are samples
    and n (columns) is the number of channels.

    Passing in the channel description splits the data so
    that the specified channel is its own vector y and the
    rest are kept as predictors x.

    Inputs:
        Tb_array    |  ndarray of Tbs
        chan        |  string of channel name
    Outputs:
        x           |  matrix of predictors (other channels)
        y           |  vector of predictands (the missing channel)
        
    '''
    
    chan_desc = np.array(sensor_info.channel_descriptions)


    chan_indx = np.where(chan == chan_desc)[0]

    if np.size(chan_indx) == 0:
        raise ValueError(f'Channel description must be in list {chan_desc}.')

    y = Tb_array[:,chan_indx]
    x = Tb_array[:,np.delete(np.arange(0,len(chan_desc)),chan_indx)]

    return x, y


def train_model(model, nepochs, dataloader, learning_rate=0.001, quiet=False, stage=None, validation_dataloader=None):

    nbatches = len(dataloader)
    
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=nepochs)
    device = None

    if stage:
        print(f'Training stage: {stage}')

    loss_arr    = np.zeros([nbatches,nepochs], dtype='f')
    valloss_arr = np.zeros([nbatches,nepochs], dtype='f')
    
    for epoch in range(nepochs):
        for i, (profs, obs) in enumerate(dataloader):
            if device:
                profs, obs = profs.to(device), obs.to(device)

            if validation_dataloader and i%1000==0:
                valprofs, valobs = next(enumerate(validation_dataloader))[1]
                val_pred = model(valprofs)
                valloss  = criterion(val_pred, valobs)
                print(f'Validation Loss = {valloss.item():.3f}')

            #Forward pass:
            obs_pred = model(profs)
            loss     = criterion(obs_pred, obs)


            #Backward pass:
            optimizer.zero_grad()
            loss.backward()

            #Update neurons:
            optimizer.step()

            loss_arr[i,epoch] = loss.item()
            valloss_arr[i,epoch] = valloss.item()
            
            if not quiet:
                if i%1000 == 0:
                    print(f'Epoch={epoch+1}, batch = {i} of {nbatches}, loss={loss.item():.3f}, LR={scheduler.get_last_lr()[0]}')
        
        scheduler.step()




    return loss_arr, valloss_arr

# %%
'''

SSMI CHANNEL PREDICTION MODEL:
    1: Ocean

'''

sfc = [1]

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = np.isin(sfctype, sfc)
    sfcindcs = np.where(correct_sfc)[0]

    Tbs = f.Tbs.values[sfcindcs]

#---Don't shuffle data before splitting
#np.random.seed(40)
#Tbs = array_funcs.shuffle_data(Tbs, axis=0)

if Tbs.shape[0] > 5.0e+06:
    Tbs = Tbs[:5_000_000,:]


print(Tbs.shape)

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train = array_funcs.shuffle_data(Tbs_train, axis=0)
# Out:
# (5000000, 17)

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    print(channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_ocean.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_ocean.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 19V
# Training stage: 1
# Validation Loss = 47562.449
# Epoch=1, batch = 0 of 4000, loss=41392.844, LR=0.001
# Validation Loss = 1.411
# Epoch=1, batch = 100 of 4000, loss=13.608, LR=0.001
# Validation Loss = 0.733
# Epoch=1, batch = 200 of 4000, loss=9.586, LR=0.001
# Validation Loss = 0.212
# Epoch=1, batch = 300 of 4000, loss=4.972, LR=0.001
# Validation Loss = 0.358
# Epoch=1, batch = 400 of 4000, loss=4.157, LR=0.001
# Validation Loss = 0.598
# Epoch=1, batch = 500 of 4000, loss=2.615, LR=0.001
# Validation Loss = 0.240
# Epoch=1, batch = 600 of 4000, loss=2.298, LR=0.001
# Validation Loss = 0.011
# Epoch=1, batch = 700 of 4000, loss=1.723, LR=0.001
# Validation Loss = 0.056
# Epoch=1, batch = 800 of 4000, loss=2.049, LR=0.001
# Validation Loss = 0.049
# Epoch=1, batch = 900 of 4000, loss=1.712, LR=0.001
# Validation Loss = 0.682
# Epoch=1, batch = 1000 of 4000, loss=1.505, LR=0.001
# Validation Loss = 1.254
# Epoch=1, batch = 1100 of 4000, loss=1.897, LR=0.001
# Validation Loss = 1.294
# Epoch=1, batch = 1200 of 4000, loss=1.764, LR=0.001
# Validation Loss = 0.202
# Epoch=1, batch = 1300 of 4000, loss=1.564, LR=0.001
# Validation Loss = 0.428
# Epoch=1, batch = 1400 of 4000, loss=1.334, LR=0.001
# Validation Loss = 0.537
# Epoch=1, batch = 1500 of 4000, loss=1.604, LR=0.001
# Validation Loss = 0.218
# Epoch=1, batch = 1600 of 4000, loss=1.278, LR=0.001
# Validation Loss = 0.156
# Epoch=1, batch = 1700 of 4000, loss=0.845, LR=0.001
# Validation Loss = 0.185
# Epoch=1, batch = 1800 of 4000, loss=0.993, LR=0.001
# Validation Loss = 0.001
# Epoch=1, batch = 1900 of 4000, loss=0.943, LR=0.001
# Validation Loss = 1.042
# Epoch=1, batch = 2000 of 4000, loss=1.324, LR=0.001
# Validation Loss = 0.027
# Epoch=1, batch = 2100 of 4000, loss=0.817, LR=0.001
# Validation Loss = 0.078
# Epoch=1, batch = 2200 of 4000, loss=1.075, LR=0.001
# Validation Loss = 0.288
# Epoch=1, batch = 2300 of 4000, loss=0.869, LR=0.001
# Validation Loss = 0.000
# Epoch=1, batch = 2400 of 4000, loss=0.964, LR=0.001
# Validation Loss = 0.167
# Epoch=1, batch = 2500 of 4000, loss=1.297, LR=0.001
# Validation Loss = 1.230
# Epoch=1, batch = 2600 of 4000, loss=1.763, LR=0.001
# Validation Loss = 0.757
# Epoch=1, batch = 2700 of 4000, loss=1.293, LR=0.001
# Validation Loss = 1.344
# Epoch=1, batch = 2800 of 4000, loss=1.474, LR=0.001
# Validation Loss = 0.077
# Epoch=1, batch = 2900 of 4000, loss=1.101, LR=0.001
# Validation Loss = 1.455
# Epoch=1, batch = 3000 of 4000, loss=1.796, LR=0.001
# Validation Loss = 0.014
# Epoch=1, batch = 3100 of 4000, loss=0.877, LR=0.001
# Validation Loss = 1.016
# Epoch=1, batch = 3200 of 4000, loss=2.110, LR=0.001
# Validation Loss = 2.250
# Epoch=1, batch = 3300 of 4000, loss=2.146, LR=0.001
# Validation Loss = 0.363
# Epoch=1, batch = 3400 of 4000, loss=0.982, LR=0.001
# Validation Loss = 0.114
# Epoch=1, batch = 3500 of 4000, loss=0.726, LR=0.001
# Validation Loss = 2.946
# Epoch=1, batch = 3600 of 4000, loss=3.395, LR=0.001
# Validation Loss = 0.227
# Epoch=1, batch = 3700 of 4000, loss=0.767, LR=0.001
# Validation Loss = 0.668
# Epoch=1, batch = 3800 of 4000, loss=1.164, LR=0.001
# Validation Loss = 0.441
# Epoch=1, batch = 3900 of 4000, loss=1.533, LR=0.001
# Validation Loss = 1.633
# Epoch=2, batch = 0 of 4000, loss=2.781, LR=0.0009045084971874737
# Validation Loss = 0.132
# Epoch=2, batch = 100 of 4000, loss=0.897, LR=0.0009045084971874737
# Validation Loss = 3.530
# Epoch=2, batch = 200 of 4000, loss=3.075, LR=0.0009045084971874737
# Validation Loss = 2.572
# Epoch=2, batch = 300 of 4000, loss=3.502, LR=0.0009045084971874737
# Validation Loss = 2.800
# Epoch=2, batch = 400 of 4000, loss=2.446, LR=0.0009045084971874737
# Validation Loss = 0.294
# Epoch=2, batch = 500 of 4000, loss=0.843, LR=0.0009045084971874737
# Validation Loss = 1.873
# Epoch=2, batch = 600 of 4000, loss=1.972, LR=0.0009045084971874737
# Validation Loss = 0.484
# Epoch=2, batch = 700 of 4000, loss=0.901, LR=0.0009045084971874737
# Validation Loss = 0.374
# Epoch=2, batch = 800 of 4000, loss=0.928, LR=0.0009045084971874737
# Validation Loss = 2.007
# Epoch=2, batch = 900 of 4000, loss=2.062, LR=0.0009045084971874737
# Validation Loss = 0.094
# Epoch=2, batch = 1000 of 4000, loss=0.753, LR=0.0009045084971874737
# Validation Loss = 2.032
# Epoch=2, batch = 1100 of 4000, loss=2.073, LR=0.0009045084971874737
# Validation Loss = 0.605
# Epoch=2, batch = 1200 of 4000, loss=1.078, LR=0.0009045084971874737
# Validation Loss = 1.720
# Epoch=2, batch = 1300 of 4000, loss=2.682, LR=0.0009045084971874737
# Validation Loss = 0.371
# Epoch=2, batch = 1400 of 4000, loss=1.246, LR=0.0009045084971874737
# Validation Loss = 0.035
# Epoch=2, batch = 1500 of 4000, loss=0.737, LR=0.0009045084971874737
# Validation Loss = 0.518
# Epoch=2, batch = 1600 of 4000, loss=1.417, LR=0.0009045084971874737
# Validation Loss = 2.665
# Epoch=2, batch = 1700 of 4000, loss=3.641, LR=0.0009045084971874737
# Validation Loss = 0.003
# Epoch=2, batch = 1800 of 4000, loss=0.752, LR=0.0009045084971874737
# Validation Loss = 1.986
# Epoch=2, batch = 1900 of 4000, loss=2.153, LR=0.0009045084971874737
# Validation Loss = 0.211
# Epoch=2, batch = 2000 of 4000, loss=0.965, LR=0.0009045084971874737
# Validation Loss = 0.660
# Epoch=2, batch = 2100 of 4000, loss=1.254, LR=0.0009045084971874737
# Validation Loss = 0.630
# Epoch=2, batch = 2200 of 4000, loss=0.980, LR=0.0009045084971874737
# Validation Loss = 0.059
# Epoch=2, batch = 2300 of 4000, loss=0.693, LR=0.0009045084971874737
# Validation Loss = 1.946
# Epoch=2, batch = 2400 of 4000, loss=1.786, LR=0.0009045084971874737
# Validation Loss = 1.677
# Epoch=2, batch = 2500 of 4000, loss=1.606, LR=0.0009045084971874737
# Validation Loss = 1.235
# Epoch=2, batch = 2600 of 4000, loss=1.932, LR=0.0009045084971874737
# Validation Loss = 0.535
# Epoch=2, batch = 2700 of 4000, loss=0.968, LR=0.0009045084971874737
# Validation Loss = 0.005
# Epoch=2, batch = 2800 of 4000, loss=0.771, LR=0.0009045084971874737
# Validation Loss = 1.076
# Epoch=2, batch = 2900 of 4000, loss=1.460, LR=0.0009045084971874737
# Validation Loss = 1.718
# Epoch=2, batch = 3000 of 4000, loss=2.235, LR=0.0009045084971874737
# Validation Loss = 0.069
# Epoch=2, batch = 3100 of 4000, loss=0.827, LR=0.0009045084971874737
# Validation Loss = 0.163
# Epoch=2, batch = 3200 of 4000, loss=0.911, LR=0.0009045084971874737
# Validation Loss = 0.183
# Epoch=2, batch = 3300 of 4000, loss=1.112, LR=0.0009045084971874737
# Validation Loss = 1.183
# Epoch=2, batch = 3400 of 4000, loss=1.656, LR=0.0009045084971874737
# Validation Loss = 2.454
# Epoch=2, batch = 3500 of 4000, loss=2.363, LR=0.0009045084971874737
# Validation Loss = 1.218
# Epoch=2, batch = 3600 of 4000, loss=1.905, LR=0.0009045084971874737
# Validation Loss = 0.161
# Epoch=2, batch = 3700 of 4000, loss=0.710, LR=0.0009045084971874737
# Validation Loss = 1.622
# Epoch=2, batch = 3800 of 4000, loss=1.628, LR=0.0009045084971874737
# Validation Loss = 0.027
# Epoch=2, batch = 3900 of 4000, loss=0.852, LR=0.0009045084971874737
# Validation Loss = 2.062
# Epoch=3, batch = 0 of 4000, loss=2.130, LR=0.0006545084971874737
# Validation Loss = 0.003
# Epoch=3, batch = 100 of 4000, loss=0.755, LR=0.0006545084971874737
# Validation Loss = 0.030
# Epoch=3, batch = 200 of 4000, loss=0.643, LR=0.0006545084971874737
# Validation Loss = 0.003
# Epoch=3, batch = 300 of 4000, loss=0.637, LR=0.0006545084971874737
# Validation Loss = 0.099
# Epoch=3, batch = 400 of 4000, loss=0.835, LR=0.0006545084971874737
# Validation Loss = 0.375
# Epoch=3, batch = 500 of 4000, loss=1.184, LR=0.0006545084971874737
# Validation Loss = 0.045
# Epoch=3, batch = 600 of 4000, loss=0.746, LR=0.0006545084971874737
# Validation Loss = 0.003
# Epoch=3, batch = 700 of 4000, loss=0.656, LR=0.0006545084971874737
# Validation Loss = 0.012
# Epoch=3, batch = 800 of 4000, loss=0.699, LR=0.0006545084971874737
# Validation Loss = 1.095
# Epoch=3, batch = 900 of 4000, loss=1.930, LR=0.0006545084971874737
# Validation Loss = 0.237
# Epoch=3, batch = 1000 of 4000, loss=0.777, LR=0.0006545084971874737
# Validation Loss = 1.316
# Epoch=3, batch = 1100 of 4000, loss=1.636, LR=0.0006545084971874737
# Validation Loss = 0.403
# Epoch=3, batch = 1200 of 4000, loss=0.941, LR=0.0006545084971874737
# Validation Loss = 0.087
# Epoch=3, batch = 1300 of 4000, loss=0.829, LR=0.0006545084971874737
# Validation Loss = 0.075
# Epoch=3, batch = 1400 of 4000, loss=0.756, LR=0.0006545084971874737
# Validation Loss = 0.256
# Epoch=3, batch = 1500 of 4000, loss=0.964, LR=0.0006545084971874737
# Validation Loss = 0.592
# Epoch=3, batch = 1600 of 4000, loss=1.081, LR=0.0006545084971874737
# Validation Loss = 0.018
# Epoch=3, batch = 1700 of 4000, loss=0.644, LR=0.0006545084971874737
# Validation Loss = 4.521
# Epoch=3, batch = 1800 of 4000, loss=4.508, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=3, batch = 1900 of 4000, loss=0.784, LR=0.0006545084971874737
# Validation Loss = 1.335
# Epoch=3, batch = 2000 of 4000, loss=1.592, LR=0.0006545084971874737
# Validation Loss = 0.020
# Epoch=3, batch = 2100 of 4000, loss=0.649, LR=0.0006545084971874737
# Validation Loss = 0.240
# Epoch=3, batch = 2200 of 4000, loss=0.854, LR=0.0006545084971874737
# Validation Loss = 1.557
# Epoch=3, batch = 2300 of 4000, loss=2.274, LR=0.0006545084971874737
# Validation Loss = 0.421
# Epoch=3, batch = 2400 of 4000, loss=0.845, LR=0.0006545084971874737
# Validation Loss = 0.216
# Epoch=3, batch = 2500 of 4000, loss=0.773, LR=0.0006545084971874737
# Validation Loss = 0.005
# Epoch=3, batch = 2600 of 4000, loss=0.656, LR=0.0006545084971874737
# Validation Loss = 0.454
# Epoch=3, batch = 2700 of 4000, loss=0.901, LR=0.0006545084971874737
# Validation Loss = 0.010
# Epoch=3, batch = 2800 of 4000, loss=0.694, LR=0.0006545084971874737
# Validation Loss = 0.552
# Epoch=3, batch = 2900 of 4000, loss=1.012, LR=0.0006545084971874737
# Validation Loss = 0.962
# Epoch=3, batch = 3000 of 4000, loss=1.656, LR=0.0006545084971874737
# Validation Loss = 0.122
# Epoch=3, batch = 3100 of 4000, loss=0.745, LR=0.0006545084971874737
# Validation Loss = 0.425
# Epoch=3, batch = 3200 of 4000, loss=0.796, LR=0.0006545084971874737
# Validation Loss = 0.952
# Epoch=3, batch = 3300 of 4000, loss=1.444, LR=0.0006545084971874737
# Validation Loss = 0.738
# Epoch=3, batch = 3400 of 4000, loss=1.218, LR=0.0006545084971874737
# Validation Loss = 0.183
# Epoch=3, batch = 3500 of 4000, loss=0.879, LR=0.0006545084971874737
# Validation Loss = 0.520
# Epoch=3, batch = 3600 of 4000, loss=0.852, LR=0.0006545084971874737
# Validation Loss = 0.819
# Epoch=3, batch = 3700 of 4000, loss=1.463, LR=0.0006545084971874737
# Validation Loss = 0.293
# Epoch=3, batch = 3800 of 4000, loss=0.829, LR=0.0006545084971874737
# Validation Loss = 1.927
# Epoch=3, batch = 3900 of 4000, loss=2.564, LR=0.0006545084971874737
# Validation Loss = 0.075
# Epoch=4, batch = 0 of 4000, loss=0.720, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=4, batch = 100 of 4000, loss=0.699, LR=0.00034549150281252633
# Validation Loss = 0.012
# Epoch=4, batch = 200 of 4000, loss=0.562, LR=0.00034549150281252633
# Validation Loss = 0.002
# Epoch=4, batch = 300 of 4000, loss=0.573, LR=0.00034549150281252633
# Validation Loss = 0.089
# Epoch=4, batch = 400 of 4000, loss=0.568, LR=0.00034549150281252633
# Validation Loss = 0.012
# Epoch=4, batch = 500 of 4000, loss=0.578, LR=0.00034549150281252633
# Validation Loss = 0.008
# Epoch=4, batch = 600 of 4000, loss=0.547, LR=0.00034549150281252633
# Validation Loss = 0.066
# Epoch=4, batch = 700 of 4000, loss=0.548, LR=0.00034549150281252633
# Validation Loss = 0.215
# Epoch=4, batch = 800 of 4000, loss=0.722, LR=0.00034549150281252633
# Validation Loss = 0.028
# Epoch=4, batch = 900 of 4000, loss=0.579, LR=0.00034549150281252633
# Validation Loss = 0.297
# Epoch=4, batch = 1000 of 4000, loss=0.682, LR=0.00034549150281252633
# Validation Loss = 0.034
# Epoch=4, batch = 1100 of 4000, loss=0.582, LR=0.00034549150281252633
# Validation Loss = 0.124
# Epoch=4, batch = 1200 of 4000, loss=0.729, LR=0.00034549150281252633
# Validation Loss = 0.733
# Epoch=4, batch = 1300 of 4000, loss=1.100, LR=0.00034549150281252633
# Validation Loss = 0.105
# Epoch=4, batch = 1400 of 4000, loss=0.755, LR=0.00034549150281252633
# Validation Loss = 0.086
# Epoch=4, batch = 1500 of 4000, loss=0.703, LR=0.00034549150281252633
# Validation Loss = 0.631
# Epoch=4, batch = 1600 of 4000, loss=0.944, LR=0.00034549150281252633
# Validation Loss = 0.234
# Epoch=4, batch = 1700 of 4000, loss=0.741, LR=0.00034549150281252633
# Validation Loss = 0.020
# Epoch=4, batch = 1800 of 4000, loss=0.541, LR=0.00034549150281252633
# Validation Loss = 0.102
# Epoch=4, batch = 1900 of 4000, loss=0.671, LR=0.00034549150281252633
# Validation Loss = 0.008
# Epoch=4, batch = 2000 of 4000, loss=0.569, LR=0.00034549150281252633
# Validation Loss = 0.011
# Epoch=4, batch = 2100 of 4000, loss=0.564, LR=0.00034549150281252633
# Validation Loss = 0.007
# Epoch=4, batch = 2200 of 4000, loss=0.615, LR=0.00034549150281252633
# Validation Loss = 0.109
# Epoch=4, batch = 2300 of 4000, loss=0.663, LR=0.00034549150281252633
# Validation Loss = 0.290
# Epoch=4, batch = 2400 of 4000, loss=0.675, LR=0.00034549150281252633
# Validation Loss = 0.182
# Epoch=4, batch = 2500 of 4000, loss=0.771, LR=0.00034549150281252633
# Validation Loss = 0.484
# Epoch=4, batch = 2600 of 4000, loss=0.946, LR=0.00034549150281252633
# Validation Loss = 0.042
# Epoch=4, batch = 2700 of 4000, loss=0.499, LR=0.00034549150281252633
# Validation Loss = 0.046
# Epoch=4, batch = 2800 of 4000, loss=0.578, LR=0.00034549150281252633
# Validation Loss = 0.032
# Epoch=4, batch = 2900 of 4000, loss=0.534, LR=0.00034549150281252633
# Validation Loss = 0.000
# Epoch=4, batch = 3000 of 4000, loss=0.515, LR=0.00034549150281252633
# Validation Loss = 0.503
# Epoch=4, batch = 3100 of 4000, loss=0.809, LR=0.00034549150281252633
# Validation Loss = 0.322
# Epoch=4, batch = 3200 of 4000, loss=0.854, LR=0.00034549150281252633
# Validation Loss = 0.004
# Epoch=4, batch = 3300 of 4000, loss=0.486, LR=0.00034549150281252633
# Validation Loss = 0.193
# Epoch=4, batch = 3400 of 4000, loss=0.581, LR=0.00034549150281252633
# Validation Loss = 0.077
# Epoch=4, batch = 3500 of 4000, loss=0.638, LR=0.00034549150281252633
# Validation Loss = 0.419
# Epoch=4, batch = 3600 of 4000, loss=0.794, LR=0.00034549150281252633
# Validation Loss = 0.199
# Epoch=4, batch = 3700 of 4000, loss=0.774, LR=0.00034549150281252633
# Validation Loss = 0.049
# Epoch=4, batch = 3800 of 4000, loss=0.508, LR=0.00034549150281252633
# Validation Loss = 0.174
# Epoch=4, batch = 3900 of 4000, loss=0.780, LR=0.00034549150281252633
# Validation Loss = 0.082
# Epoch=5, batch = 0 of 4000, loss=0.572, LR=9.549150281252633e-05
# Validation Loss = 0.018
# Epoch=5, batch = 100 of 4000, loss=0.541, LR=9.549150281252633e-05
# Validation Loss = 0.000
# Epoch=5, batch = 200 of 4000, loss=0.504, LR=9.549150281252633e-05
# Validation Loss = 0.017
# Epoch=5, batch = 300 of 4000, loss=0.550, LR=9.549150281252633e-05
# Validation Loss = 0.000
# Epoch=5, batch = 400 of 4000, loss=0.568, LR=9.549150281252633e-05
# Validation Loss = 0.003
# Epoch=5, batch = 500 of 4000, loss=0.464, LR=9.549150281252633e-05
# Validation Loss = 0.021
# Epoch=5, batch = 600 of 4000, loss=0.496, LR=9.549150281252633e-05
# Validation Loss = 0.009
# Epoch=5, batch = 700 of 4000, loss=0.525, LR=9.549150281252633e-05
# Validation Loss = 0.021
# Epoch=5, batch = 800 of 4000, loss=0.487, LR=9.549150281252633e-05
# Validation Loss = 0.001
# Epoch=5, batch = 900 of 4000, loss=0.503, LR=9.549150281252633e-05
# Validation Loss = 0.001
# Epoch=5, batch = 1000 of 4000, loss=0.502, LR=9.549150281252633e-05
# Validation Loss = 0.056
# Epoch=5, batch = 1100 of 4000, loss=0.510, LR=9.549150281252633e-05
# Validation Loss = 0.001
# Epoch=5, batch = 1200 of 4000, loss=0.537, LR=9.549150281252633e-05
# Validation Loss = 0.018
# Epoch=5, batch = 1300 of 4000, loss=0.541, LR=9.549150281252633e-05
# Validation Loss = 0.052
# Epoch=5, batch = 1400 of 4000, loss=0.557, LR=9.549150281252633e-05
# Validation Loss = 0.009
# Epoch=5, batch = 1500 of 4000, loss=0.513, LR=9.549150281252633e-05
# Validation Loss = 0.001
# Epoch=5, batch = 1600 of 4000, loss=0.483, LR=9.549150281252633e-05
# Validation Loss = 0.037
# Epoch=5, batch = 1700 of 4000, loss=0.505, LR=9.549150281252633e-05
# Validation Loss = 0.024
# Epoch=5, batch = 1800 of 4000, loss=0.513, LR=9.549150281252633e-05
# Validation Loss = 0.000
# Epoch=5, batch = 1900 of 4000, loss=0.523, LR=9.549150281252633e-05
# Validation Loss = 0.006
# Epoch=5, batch = 2000 of 4000, loss=0.491, LR=9.549150281252633e-05
# Validation Loss = 0.002
# Epoch=5, batch = 2100 of 4000, loss=0.490, LR=9.549150281252633e-05
# Validation Loss = 0.037
# Epoch=5, batch = 2200 of 4000, loss=0.505, LR=9.549150281252633e-05
# Validation Loss = 0.018
# Epoch=5, batch = 2300 of 4000, loss=0.515, LR=9.549150281252633e-05
# Validation Loss = 0.014
# Epoch=5, batch = 2400 of 4000, loss=0.455, LR=9.549150281252633e-05
# Validation Loss = 0.008
# Epoch=5, batch = 2500 of 4000, loss=0.451, LR=9.549150281252633e-05
# Validation Loss = 0.035
# Epoch=5, batch = 2600 of 4000, loss=0.480, LR=9.549150281252633e-05
# Validation Loss = 0.055
# Epoch=5, batch = 2700 of 4000, loss=0.498, LR=9.549150281252633e-05
# Validation Loss = 0.033
# Epoch=5, batch = 2800 of 4000, loss=0.474, LR=9.549150281252633e-05
# Validation Loss = 0.147
# Epoch=5, batch = 2900 of 4000, loss=0.533, LR=9.549150281252633e-05
# Validation Loss = 0.188
# Epoch=5, batch = 3000 of 4000, loss=0.596, LR=9.549150281252633e-05
# Validation Loss = 0.137
# Epoch=5, batch = 3100 of 4000, loss=0.519, LR=9.549150281252633e-05
# Validation Loss = 0.008
# Epoch=5, batch = 3200 of 4000, loss=0.515, LR=9.549150281252633e-05
# Validation Loss = 0.004
# Epoch=5, batch = 3300 of 4000, loss=0.489, LR=9.549150281252633e-05
# Validation Loss = 0.003
# Epoch=5, batch = 3400 of 4000, loss=0.501, LR=9.549150281252633e-05
# Validation Loss = 0.053
# Epoch=5, batch = 3500 of 4000, loss=0.520, LR=9.549150281252633e-05
# Validation Loss = 0.004
# Epoch=5, batch = 3600 of 4000, loss=0.525, LR=9.549150281252633e-05
# Validation Loss = 0.000
# Epoch=5, batch = 3700 of 4000, loss=0.474, LR=9.549150281252633e-05
# Validation Loss = 0.031
# Epoch=5, batch = 3800 of 4000, loss=0.557, LR=9.549150281252633e-05
# Validation Loss = 0.016
# Epoch=5, batch = 3900 of 4000, loss=0.485, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.077
# Epoch=1, batch = 0 of 4000, loss=0.708, LR=0.001
# Validation Loss = 0.023
# Epoch=1, batch = 100 of 4000, loss=1.137, LR=0.001
# Validation Loss = 0.071
# Epoch=1, batch = 200 of 4000, loss=0.846, LR=0.001
# Validation Loss = 0.040
# Epoch=1, batch = 300 of 4000, loss=0.770, LR=0.001
# Validation Loss = 0.018
# Epoch=1, batch = 400 of 4000, loss=0.720, LR=0.001
# Validation Loss = 0.073
# Epoch=1, batch = 500 of 4000, loss=0.810, LR=0.001
# Validation Loss = 0.001
# Epoch=1, batch = 600 of 4000, loss=0.606, LR=0.001
# Validation Loss = 0.000
# Epoch=1, batch = 700 of 4000, loss=0.612, LR=0.001
# Validation Loss = 0.025
# Epoch=1, batch = 800 of 4000, loss=0.538, LR=0.001
# Validation Loss = 0.003
# Epoch=1, batch = 900 of 4000, loss=0.583, LR=0.001
# Validation Loss = 0.007
# Epoch=1, batch = 1000 of 4000, loss=0.556, LR=0.001
# Validation Loss = 0.010
# Epoch=1, batch = 1100 of 4000, loss=0.602, LR=0.001
# Validation Loss = 0.011
# Epoch=1, batch = 1200 of 4000, loss=0.570, LR=0.001
# Validation Loss = 0.006
# Epoch=1, batch = 1300 of 4000, loss=0.543, LR=0.001
# Validation Loss = 0.019
# Epoch=1, batch = 1400 of 4000, loss=0.534, LR=0.001
# Validation Loss = 1.226
# Epoch=1, batch = 1500 of 4000, loss=1.682, LR=0.001
# Validation Loss = 0.059
# Epoch=1, batch = 1600 of 4000, loss=0.660, LR=0.001
# Validation Loss = 4.775
# Epoch=1, batch = 1700 of 4000, loss=4.539, LR=0.001
# Validation Loss = 0.484
# Epoch=1, batch = 1800 of 4000, loss=0.944, LR=0.001
# Validation Loss = 1.125
# Epoch=1, batch = 1900 of 4000, loss=1.494, LR=0.001
# Validation Loss = 2.057
# Epoch=1, batch = 2000 of 4000, loss=2.547, LR=0.001
# Validation Loss = 0.037
# Epoch=1, batch = 2100 of 4000, loss=0.540, LR=0.001
# Validation Loss = 4.185
# Epoch=1, batch = 2200 of 4000, loss=4.086, LR=0.001
# Validation Loss = 4.008
# Epoch=1, batch = 2300 of 4000, loss=4.311, LR=0.001
# Validation Loss = 0.030
# Epoch=1, batch = 2400 of 4000, loss=0.636, LR=0.001
# Validation Loss = 0.592
# Epoch=1, batch = 2500 of 4000, loss=1.126, LR=0.001
# Validation Loss = 1.408
# Epoch=1, batch = 2600 of 4000, loss=1.723, LR=0.001
# Validation Loss = 0.342
# Epoch=1, batch = 2700 of 4000, loss=0.926, LR=0.001
# Validation Loss = 0.130
# Epoch=1, batch = 2800 of 4000, loss=0.586, LR=0.001
# Validation Loss = 0.134
# Epoch=1, batch = 2900 of 4000, loss=0.687, LR=0.001
# Validation Loss = 3.726
# Epoch=1, batch = 3000 of 4000, loss=3.473, LR=0.001
# Validation Loss = 1.202
# Epoch=1, batch = 3100 of 4000, loss=1.378, LR=0.001
# Validation Loss = 0.185
# Epoch=1, batch = 3200 of 4000, loss=0.618, LR=0.001
# Validation Loss = 0.495
# Epoch=1, batch = 3300 of 4000, loss=1.065, LR=0.001
# Validation Loss = 0.127
# Epoch=1, batch = 3400 of 4000, loss=0.674, LR=0.001
# Validation Loss = 2.004
# Epoch=1, batch = 3500 of 4000, loss=2.116, LR=0.001
# Validation Loss = 0.037
# Epoch=1, batch = 3600 of 4000, loss=0.543, LR=0.001
# Validation Loss = 0.065
# Epoch=1, batch = 3700 of 4000, loss=0.584, LR=0.001
# Validation Loss = 0.004
# Epoch=1, batch = 3800 of 4000, loss=0.553, LR=0.001
# Validation Loss = 0.445
# Epoch=1, batch = 3900 of 4000, loss=1.093, LR=0.001
# Validation Loss = 0.366
# Epoch=2, batch = 0 of 4000, loss=0.784, LR=0.0009755282581475768
# Validation Loss = 0.067
# Epoch=2, batch = 100 of 4000, loss=0.607, LR=0.0009755282581475768
# Validation Loss = 0.532
# Epoch=2, batch = 200 of 4000, loss=1.112, LR=0.0009755282581475768
# Validation Loss = 8.204
# Epoch=2, batch = 300 of 4000, loss=7.784, LR=0.0009755282581475768
# Validation Loss = 1.040
# Epoch=2, batch = 400 of 4000, loss=1.131, LR=0.0009755282581475768
# Validation Loss = 0.017
# Epoch=2, batch = 500 of 4000, loss=0.544, LR=0.0009755282581475768
# Validation Loss = 2.294
# Epoch=2, batch = 600 of 4000, loss=2.387, LR=0.0009755282581475768
# Validation Loss = 0.088
# Epoch=2, batch = 700 of 4000, loss=0.621, LR=0.0009755282581475768
# Validation Loss = 0.621
# Epoch=2, batch = 800 of 4000, loss=1.283, LR=0.0009755282581475768
# Validation Loss = 0.306
# Epoch=2, batch = 900 of 4000, loss=0.903, LR=0.0009755282581475768
# Validation Loss = 0.258
# Epoch=2, batch = 1000 of 4000, loss=0.802, LR=0.0009755282581475768
# Validation Loss = 0.013
# Epoch=2, batch = 1100 of 4000, loss=0.573, LR=0.0009755282581475768
# Validation Loss = 1.490
# Epoch=2, batch = 1200 of 4000, loss=1.718, LR=0.0009755282581475768
# Validation Loss = 0.012
# Epoch=2, batch = 1300 of 4000, loss=0.638, LR=0.0009755282581475768
# Validation Loss = 0.678
# Epoch=2, batch = 1400 of 4000, loss=0.979, LR=0.0009755282581475768
# Validation Loss = 0.012
# Epoch=2, batch = 1500 of 4000, loss=0.518, LR=0.0009755282581475768
# Validation Loss = 0.655
# Epoch=2, batch = 1600 of 4000, loss=1.062, LR=0.0009755282581475768
# Validation Loss = 0.590
# Epoch=2, batch = 1700 of 4000, loss=1.044, LR=0.0009755282581475768
# Validation Loss = 0.496
# Epoch=2, batch = 1800 of 4000, loss=0.834, LR=0.0009755282581475768
# Validation Loss = 0.001
# Epoch=2, batch = 1900 of 4000, loss=0.540, LR=0.0009755282581475768
# Validation Loss = 0.229
# Epoch=2, batch = 2000 of 4000, loss=0.709, LR=0.0009755282581475768
# Validation Loss = 1.936
# Epoch=2, batch = 2100 of 4000, loss=1.910, LR=0.0009755282581475768
# Validation Loss = 0.322
# Epoch=2, batch = 2200 of 4000, loss=0.883, LR=0.0009755282581475768
# Validation Loss = 0.006
# Epoch=2, batch = 2300 of 4000, loss=0.582, LR=0.0009755282581475768
# Validation Loss = 1.913
# Epoch=2, batch = 2400 of 4000, loss=1.983, LR=0.0009755282581475768
# Validation Loss = 2.552
# Epoch=2, batch = 2500 of 4000, loss=2.886, LR=0.0009755282581475768
# Validation Loss = 1.870
# Epoch=2, batch = 2600 of 4000, loss=2.451, LR=0.0009755282581475768
# Validation Loss = 0.193
# Epoch=2, batch = 2700 of 4000, loss=0.807, LR=0.0009755282581475768
# Validation Loss = 1.195
# Epoch=2, batch = 2800 of 4000, loss=1.834, LR=0.0009755282581475768
# Validation Loss = 0.493
# Epoch=2, batch = 2900 of 4000, loss=0.928, LR=0.0009755282581475768
# Validation Loss = 0.040
# Epoch=2, batch = 3000 of 4000, loss=0.606, LR=0.0009755282581475768
# Validation Loss = 0.414
# Epoch=2, batch = 3100 of 4000, loss=0.963, LR=0.0009755282581475768
# Validation Loss = 2.188
# Epoch=2, batch = 3200 of 4000, loss=2.387, LR=0.0009755282581475768
# Validation Loss = 2.425
# Epoch=2, batch = 3300 of 4000, loss=2.782, LR=0.0009755282581475768
# Validation Loss = 0.085
# Epoch=2, batch = 3400 of 4000, loss=0.565, LR=0.0009755282581475768
# Validation Loss = 0.141
# Epoch=2, batch = 3500 of 4000, loss=0.707, LR=0.0009755282581475768
# Validation Loss = 0.172
# Epoch=2, batch = 3600 of 4000, loss=0.797, LR=0.0009755282581475768
# Validation Loss = 0.534
# Epoch=2, batch = 3700 of 4000, loss=0.929, LR=0.0009755282581475768
# Validation Loss = 0.769
# Epoch=2, batch = 3800 of 4000, loss=1.456, LR=0.0009755282581475768
# Validation Loss = 1.145
# Epoch=2, batch = 3900 of 4000, loss=1.741, LR=0.0009755282581475768
# Validation Loss = 0.860
# Epoch=3, batch = 0 of 4000, loss=1.535, LR=0.0009045084971874736
# Validation Loss = 0.320
# Epoch=3, batch = 100 of 4000, loss=0.970, LR=0.0009045084971874736
# Validation Loss = 1.134
# Epoch=3, batch = 200 of 4000, loss=1.550, LR=0.0009045084971874736
# Validation Loss = 0.094
# Epoch=3, batch = 300 of 4000, loss=0.717, LR=0.0009045084971874736
# Validation Loss = 0.084
# Epoch=3, batch = 400 of 4000, loss=0.534, LR=0.0009045084971874736
# Validation Loss = 0.355
# Epoch=3, batch = 500 of 4000, loss=0.635, LR=0.0009045084971874736
# Validation Loss = 1.895
# Epoch=3, batch = 600 of 4000, loss=2.559, LR=0.0009045084971874736
# Validation Loss = 3.208
# Epoch=3, batch = 700 of 4000, loss=2.889, LR=0.0009045084971874736
# Validation Loss = 0.247
# Epoch=3, batch = 800 of 4000, loss=0.864, LR=0.0009045084971874736
# Validation Loss = 4.075
# Epoch=3, batch = 900 of 4000, loss=4.060, LR=0.0009045084971874736
# Validation Loss = 0.086
# Epoch=3, batch = 1000 of 4000, loss=0.668, LR=0.0009045084971874736
# Validation Loss = 0.535
# Epoch=3, batch = 1100 of 4000, loss=0.892, LR=0.0009045084971874736
# Validation Loss = 0.296
# Epoch=3, batch = 1200 of 4000, loss=0.736, LR=0.0009045084971874736
# Validation Loss = 0.093
# Epoch=3, batch = 1300 of 4000, loss=0.598, LR=0.0009045084971874736
# Validation Loss = 0.286
# Epoch=3, batch = 1400 of 4000, loss=0.897, LR=0.0009045084971874736
# Validation Loss = 0.491
# Epoch=3, batch = 1500 of 4000, loss=0.775, LR=0.0009045084971874736
# Validation Loss = 0.008
# Epoch=3, batch = 1600 of 4000, loss=0.555, LR=0.0009045084971874736
# Validation Loss = 0.065
# Epoch=3, batch = 1700 of 4000, loss=0.603, LR=0.0009045084971874736
# Validation Loss = 0.872
# Epoch=3, batch = 1800 of 4000, loss=1.446, LR=0.0009045084971874736
# Validation Loss = 0.001
# Epoch=3, batch = 1900 of 4000, loss=0.555, LR=0.0009045084971874736
# Validation Loss = 0.036
# Epoch=3, batch = 2000 of 4000, loss=0.450, LR=0.0009045084971874736
# Validation Loss = 0.364
# Epoch=3, batch = 2100 of 4000, loss=0.977, LR=0.0009045084971874736
# Validation Loss = 0.608
# Epoch=3, batch = 2200 of 4000, loss=1.107, LR=0.0009045084971874736
# Validation Loss = 0.042
# Epoch=3, batch = 2300 of 4000, loss=0.551, LR=0.0009045084971874736
# Validation Loss = 0.752
# Epoch=3, batch = 2400 of 4000, loss=0.953, LR=0.0009045084971874736
# Validation Loss = 0.075
# Epoch=3, batch = 2500 of 4000, loss=0.667, LR=0.0009045084971874736
# Validation Loss = 0.989
# Epoch=3, batch = 2600 of 4000, loss=1.671, LR=0.0009045084971874736
# Validation Loss = 1.035
# Epoch=3, batch = 2700 of 4000, loss=1.263, LR=0.0009045084971874736
# Validation Loss = 0.127
# Epoch=3, batch = 2800 of 4000, loss=0.752, LR=0.0009045084971874736
# Validation Loss = 1.278
# Epoch=3, batch = 2900 of 4000, loss=1.356, LR=0.0009045084971874736
# Validation Loss = 1.056
# Epoch=3, batch = 3000 of 4000, loss=1.269, LR=0.0009045084971874736
# Validation Loss = 0.026
# Epoch=3, batch = 3100 of 4000, loss=0.495, LR=0.0009045084971874736
# Validation Loss = 0.246
# Epoch=3, batch = 3200 of 4000, loss=0.885, LR=0.0009045084971874736
# Validation Loss = 0.148
# Epoch=3, batch = 3300 of 4000, loss=0.685, LR=0.0009045084971874736
# Validation Loss = 0.003
# Epoch=3, batch = 3400 of 4000, loss=0.522, LR=0.0009045084971874736
# Validation Loss = 0.346
# Epoch=3, batch = 3500 of 4000, loss=1.011, LR=0.0009045084971874736
# Validation Loss = 0.163
# Epoch=3, batch = 3600 of 4000, loss=0.773, LR=0.0009045084971874736
# Validation Loss = 0.209
# Epoch=3, batch = 3700 of 4000, loss=0.647, LR=0.0009045084971874736
# Validation Loss = 0.543
# Epoch=3, batch = 3800 of 4000, loss=1.134, LR=0.0009045084971874736
# Validation Loss = 0.423
# Epoch=3, batch = 3900 of 4000, loss=0.974, LR=0.0009045084971874736
# Validation Loss = 0.686
# Epoch=4, batch = 0 of 4000, loss=1.520, LR=0.0007938926261462366
# Validation Loss = 0.039
# Epoch=4, batch = 100 of 4000, loss=0.537, LR=0.0007938926261462366
# Validation Loss = 0.159
# Epoch=4, batch = 200 of 4000, loss=0.546, LR=0.0007938926261462366
# Validation Loss = 0.348
# Epoch=4, batch = 300 of 4000, loss=0.840, LR=0.0007938926261462366
# Validation Loss = 0.013
# Epoch=4, batch = 400 of 4000, loss=0.477, LR=0.0007938926261462366
# Validation Loss = 0.092
# Epoch=4, batch = 500 of 4000, loss=0.666, LR=0.0007938926261462366
# Validation Loss = 0.007
# Epoch=4, batch = 600 of 4000, loss=0.517, LR=0.0007938926261462366
# Validation Loss = 0.004
# Epoch=4, batch = 700 of 4000, loss=0.492, LR=0.0007938926261462366
# Validation Loss = 0.285
# Epoch=4, batch = 800 of 4000, loss=0.727, LR=0.0007938926261462366
# Validation Loss = 0.306
# Epoch=4, batch = 900 of 4000, loss=0.669, LR=0.0007938926261462366
# Validation Loss = 0.133
# Epoch=4, batch = 1000 of 4000, loss=0.593, LR=0.0007938926261462366
# Validation Loss = 0.015
# Epoch=4, batch = 1100 of 4000, loss=0.510, LR=0.0007938926261462366
# Validation Loss = 0.345
# Epoch=4, batch = 1200 of 4000, loss=0.694, LR=0.0007938926261462366
# Validation Loss = 0.325
# Epoch=4, batch = 1300 of 4000, loss=0.951, LR=0.0007938926261462366
# Validation Loss = 0.887
# Epoch=4, batch = 1400 of 4000, loss=1.451, LR=0.0007938926261462366
# Validation Loss = 0.148
# Epoch=4, batch = 1500 of 4000, loss=0.785, LR=0.0007938926261462366
# Validation Loss = 0.147
# Epoch=4, batch = 1600 of 4000, loss=0.763, LR=0.0007938926261462366
# Validation Loss = 0.867
# Epoch=4, batch = 1700 of 4000, loss=1.552, LR=0.0007938926261462366
# Validation Loss = 0.246
# Epoch=4, batch = 1800 of 4000, loss=0.665, LR=0.0007938926261462366
# Validation Loss = 0.098
# Epoch=4, batch = 1900 of 4000, loss=0.702, LR=0.0007938926261462366
# Validation Loss = 0.006
# Epoch=4, batch = 2000 of 4000, loss=0.489, LR=0.0007938926261462366
# Validation Loss = 0.794
# Epoch=4, batch = 2100 of 4000, loss=1.430, LR=0.0007938926261462366
# Validation Loss = 0.088
# Epoch=4, batch = 2200 of 4000, loss=0.524, LR=0.0007938926261462366
# Validation Loss = 0.930
# Epoch=4, batch = 2300 of 4000, loss=1.407, LR=0.0007938926261462366
# Validation Loss = 0.001
# Epoch=4, batch = 2400 of 4000, loss=0.529, LR=0.0007938926261462366
# Validation Loss = 4.270
# Epoch=4, batch = 2500 of 4000, loss=4.093, LR=0.0007938926261462366
# Validation Loss = 0.912
# Epoch=4, batch = 2600 of 4000, loss=1.438, LR=0.0007938926261462366
# Validation Loss = 0.578
# Epoch=4, batch = 2700 of 4000, loss=1.045, LR=0.0007938926261462366
# Validation Loss = 0.104
# Epoch=4, batch = 2800 of 4000, loss=0.647, LR=0.0007938926261462366
# Validation Loss = 0.050
# Epoch=4, batch = 2900 of 4000, loss=0.519, LR=0.0007938926261462366
# Validation Loss = 0.007
# Epoch=4, batch = 3000 of 4000, loss=0.502, LR=0.0007938926261462366
# Validation Loss = 1.490
# Epoch=4, batch = 3100 of 4000, loss=1.609, LR=0.0007938926261462366
# Validation Loss = 0.302
# Epoch=4, batch = 3200 of 4000, loss=0.942, LR=0.0007938926261462366
# Validation Loss = 0.060
# Epoch=4, batch = 3300 of 4000, loss=0.698, LR=0.0007938926261462366
# Validation Loss = 0.000
# Epoch=4, batch = 3400 of 4000, loss=0.516, LR=0.0007938926261462366
# Validation Loss = 0.123
# Epoch=4, batch = 3500 of 4000, loss=0.515, LR=0.0007938926261462366
# Validation Loss = 0.003
# Epoch=4, batch = 3600 of 4000, loss=0.500, LR=0.0007938926261462366
# Validation Loss = 1.501
# Epoch=4, batch = 3700 of 4000, loss=2.171, LR=0.0007938926261462366
# Validation Loss = 0.073
# Epoch=4, batch = 3800 of 4000, loss=0.662, LR=0.0007938926261462366
# Validation Loss = 0.013
# Epoch=4, batch = 3900 of 4000, loss=0.524, LR=0.0007938926261462366
# Validation Loss = 0.083
# Epoch=5, batch = 0 of 4000, loss=0.522, LR=0.0006545084971874737
# Validation Loss = 0.010
# Epoch=5, batch = 100 of 4000, loss=0.513, LR=0.0006545084971874737
# Validation Loss = 0.002
# Epoch=5, batch = 200 of 4000, loss=0.457, LR=0.0006545084971874737
# Validation Loss = 0.065
# Epoch=5, batch = 300 of 4000, loss=0.545, LR=0.0006545084971874737
# Validation Loss = 0.074
# Epoch=5, batch = 400 of 4000, loss=0.584, LR=0.0006545084971874737
# Validation Loss = 0.541
# Epoch=5, batch = 500 of 4000, loss=0.788, LR=0.0006545084971874737
# Validation Loss = 0.177
# Epoch=5, batch = 600 of 4000, loss=0.680, LR=0.0006545084971874737
# Validation Loss = 0.034
# Epoch=5, batch = 700 of 4000, loss=0.533, LR=0.0006545084971874737
# Validation Loss = 0.669
# Epoch=5, batch = 800 of 4000, loss=0.927, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=5, batch = 900 of 4000, loss=0.516, LR=0.0006545084971874737
# Validation Loss = 0.934
# Epoch=5, batch = 1000 of 4000, loss=1.442, LR=0.0006545084971874737
# Validation Loss = 0.327
# Epoch=5, batch = 1100 of 4000, loss=0.770, LR=0.0006545084971874737
# Validation Loss = 0.016
# Epoch=5, batch = 1200 of 4000, loss=0.484, LR=0.0006545084971874737
# Validation Loss = 0.274
# Epoch=5, batch = 1300 of 4000, loss=0.621, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=5, batch = 1400 of 4000, loss=0.504, LR=0.0006545084971874737
# Validation Loss = 0.732
# Epoch=5, batch = 1500 of 4000, loss=1.182, LR=0.0006545084971874737
# Validation Loss = 0.509
# Epoch=5, batch = 1600 of 4000, loss=0.887, LR=0.0006545084971874737
# Validation Loss = 0.040
# Epoch=5, batch = 1700 of 4000, loss=0.539, LR=0.0006545084971874737
# Validation Loss = 0.103
# Epoch=5, batch = 1800 of 4000, loss=0.562, LR=0.0006545084971874737
# Validation Loss = 0.094
# Epoch=5, batch = 1900 of 4000, loss=0.593, LR=0.0006545084971874737
# Validation Loss = 0.095
# Epoch=5, batch = 2000 of 4000, loss=0.521, LR=0.0006545084971874737
# Validation Loss = 0.017
# Epoch=5, batch = 2100 of 4000, loss=0.581, LR=0.0006545084971874737
# Validation Loss = 0.173
# Epoch=5, batch = 2200 of 4000, loss=0.610, LR=0.0006545084971874737
# Validation Loss = 0.010
# Epoch=5, batch = 2300 of 4000, loss=0.477, LR=0.0006545084971874737
# Validation Loss = 0.154
# Epoch=5, batch = 2400 of 4000, loss=0.670, LR=0.0006545084971874737
# Validation Loss = 0.909
# Epoch=5, batch = 2500 of 4000, loss=1.389, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=5, batch = 2600 of 4000, loss=0.499, LR=0.0006545084971874737
# Validation Loss = 0.377
# Epoch=5, batch = 2700 of 4000, loss=0.960, LR=0.0006545084971874737
# Validation Loss = 0.423
# Epoch=5, batch = 2800 of 4000, loss=0.946, LR=0.0006545084971874737
# Validation Loss = 0.508
# Epoch=5, batch = 2900 of 4000, loss=0.756, LR=0.0006545084971874737
# Validation Loss = 0.003
# Epoch=5, batch = 3000 of 4000, loss=0.497, LR=0.0006545084971874737
# Validation Loss = 0.065
# Epoch=5, batch = 3100 of 4000, loss=0.553, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=5, batch = 3200 of 4000, loss=0.490, LR=0.0006545084971874737
# Validation Loss = 0.005
# Epoch=5, batch = 3300 of 4000, loss=0.461, LR=0.0006545084971874737
# Validation Loss = 0.014
# Epoch=5, batch = 3400 of 4000, loss=0.593, LR=0.0006545084971874737
# Validation Loss = 0.080
# Epoch=5, batch = 3500 of 4000, loss=0.561, LR=0.0006545084971874737
# Validation Loss = 1.177
# Epoch=5, batch = 3600 of 4000, loss=1.682, LR=0.0006545084971874737
# Validation Loss = 0.104
# Epoch=5, batch = 3700 of 4000, loss=0.630, LR=0.0006545084971874737
# Validation Loss = 0.425
# Epoch=5, batch = 3800 of 4000, loss=0.729, LR=0.0006545084971874737
# Validation Loss = 0.631
# Epoch=5, batch = 3900 of 4000, loss=1.092, LR=0.0006545084971874737
# Validation Loss = 0.012
# Epoch=6, batch = 0 of 4000, loss=0.543, LR=0.0005
# Validation Loss = 0.002
# Epoch=6, batch = 100 of 4000, loss=0.500, LR=0.0005
# Validation Loss = 0.013
# Epoch=6, batch = 200 of 4000, loss=0.496, LR=0.0005
# Validation Loss = 0.134
# Epoch=6, batch = 300 of 4000, loss=0.548, LR=0.0005
# Validation Loss = 0.053
# Epoch=6, batch = 400 of 4000, loss=0.485, LR=0.0005
# Validation Loss = 0.000
# Epoch=6, batch = 500 of 4000, loss=0.549, LR=0.0005
# Validation Loss = 0.042
# Epoch=6, batch = 600 of 4000, loss=0.603, LR=0.0005
# Validation Loss = 0.101
# Epoch=6, batch = 700 of 4000, loss=0.541, LR=0.0005
# Validation Loss = 0.041
# Epoch=6, batch = 800 of 4000, loss=0.524, LR=0.0005
# Validation Loss = 0.087
# Epoch=6, batch = 900 of 4000, loss=0.649, LR=0.0005
# Validation Loss = 0.000
# Epoch=6, batch = 1000 of 4000, loss=0.472, LR=0.0005
# Validation Loss = 0.186
# Epoch=6, batch = 1100 of 4000, loss=0.656, LR=0.0005
# Validation Loss = 0.010
# Epoch=6, batch = 1200 of 4000, loss=0.455, LR=0.0005
# Validation Loss = 0.169
# Epoch=6, batch = 1300 of 4000, loss=0.709, LR=0.0005
# Validation Loss = 0.891
# Epoch=6, batch = 1400 of 4000, loss=1.267, LR=0.0005
# Validation Loss = 0.090
# Epoch=6, batch = 1500 of 4000, loss=0.486, LR=0.0005
# Validation Loss = 0.281
# Epoch=6, batch = 1600 of 4000, loss=0.693, LR=0.0005
# Validation Loss = 0.006
# Epoch=6, batch = 1700 of 4000, loss=0.475, LR=0.0005
# Validation Loss = 0.142
# Epoch=6, batch = 1800 of 4000, loss=0.560, LR=0.0005
# Validation Loss = 0.003
# Epoch=6, batch = 1900 of 4000, loss=0.453, LR=0.0005
# Validation Loss = 0.076
# Epoch=6, batch = 2000 of 4000, loss=0.586, LR=0.0005
# Validation Loss = 0.493
# Epoch=6, batch = 2100 of 4000, loss=0.965, LR=0.0005
# Validation Loss = 0.254
# Epoch=6, batch = 2200 of 4000, loss=0.628, LR=0.0005
# Validation Loss = 0.000
# Epoch=6, batch = 2300 of 4000, loss=0.461, LR=0.0005
# Validation Loss = 0.017
# Epoch=6, batch = 2400 of 4000, loss=0.485, LR=0.0005
# Validation Loss = 0.533
# Epoch=6, batch = 2500 of 4000, loss=0.945, LR=0.0005
# Validation Loss = 0.041
# Epoch=6, batch = 2600 of 4000, loss=0.492, LR=0.0005
# Validation Loss = 0.003
# Epoch=6, batch = 2700 of 4000, loss=0.457, LR=0.0005
# Validation Loss = 0.012
# Epoch=6, batch = 2800 of 4000, loss=0.497, LR=0.0005
# Validation Loss = 0.046
# Epoch=6, batch = 2900 of 4000, loss=0.494, LR=0.0005
# Validation Loss = 0.127
# Epoch=6, batch = 3000 of 4000, loss=0.558, LR=0.0005
# Validation Loss = 0.113
# Epoch=6, batch = 3100 of 4000, loss=0.566, LR=0.0005
# Validation Loss = 0.002
# Epoch=6, batch = 3200 of 4000, loss=0.489, LR=0.0005
# Validation Loss = 0.019
# Epoch=6, batch = 3300 of 4000, loss=0.458, LR=0.0005
# Validation Loss = 0.045
# Epoch=6, batch = 3400 of 4000, loss=0.454, LR=0.0005
# Validation Loss = 0.047
# Epoch=6, batch = 3500 of 4000, loss=0.566, LR=0.0005
# Validation Loss = 0.058
# Epoch=6, batch = 3600 of 4000, loss=0.576, LR=0.0005
# Validation Loss = 0.025
# Epoch=6, batch = 3700 of 4000, loss=0.504, LR=0.0005
# Validation Loss = 0.046
# Epoch=6, batch = 3800 of 4000, loss=0.513, LR=0.0005
# Validation Loss = 0.026
# Epoch=6, batch = 3900 of 4000, loss=0.530, LR=0.0005
# Validation Loss = 0.245
# Epoch=7, batch = 0 of 4000, loss=0.787, LR=0.00034549150281252633
# Validation Loss = 0.000
# Epoch=7, batch = 100 of 4000, loss=0.494, LR=0.00034549150281252633
# Validation Loss = 0.012
# Epoch=7, batch = 200 of 4000, loss=0.453, LR=0.00034549150281252633
# Validation Loss = 0.030
# Epoch=7, batch = 300 of 4000, loss=0.454, LR=0.00034549150281252633
# Validation Loss = 0.121
# Epoch=7, batch = 400 of 4000, loss=0.551, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=7, batch = 500 of 4000, loss=0.468, LR=0.00034549150281252633
# Validation Loss = 0.000
# Epoch=7, batch = 600 of 4000, loss=0.426, LR=0.00034549150281252633
# Validation Loss = 0.016
# Epoch=7, batch = 700 of 4000, loss=0.474, LR=0.00034549150281252633
# Validation Loss = 0.129
# Epoch=7, batch = 800 of 4000, loss=0.547, LR=0.00034549150281252633
# Validation Loss = 0.420
# Epoch=7, batch = 900 of 4000, loss=0.734, LR=0.00034549150281252633
# Validation Loss = 0.006
# Epoch=7, batch = 1000 of 4000, loss=0.461, LR=0.00034549150281252633
# Validation Loss = 0.029
# Epoch=7, batch = 1100 of 4000, loss=0.434, LR=0.00034549150281252633
# Validation Loss = 0.000
# Epoch=7, batch = 1200 of 4000, loss=0.480, LR=0.00034549150281252633
# Validation Loss = 0.085
# Epoch=7, batch = 1300 of 4000, loss=0.577, LR=0.00034549150281252633
# Validation Loss = 0.184
# Epoch=7, batch = 1400 of 4000, loss=0.563, LR=0.00034549150281252633
# Validation Loss = 0.002
# Epoch=7, batch = 1500 of 4000, loss=0.467, LR=0.00034549150281252633
# Validation Loss = 0.025
# Epoch=7, batch = 1600 of 4000, loss=0.456, LR=0.00034549150281252633
# Validation Loss = 0.007
# Epoch=7, batch = 1700 of 4000, loss=0.418, LR=0.00034549150281252633
# Validation Loss = 0.151
# Epoch=7, batch = 1800 of 4000, loss=0.498, LR=0.00034549150281252633
# Validation Loss = 0.044
# Epoch=7, batch = 1900 of 4000, loss=0.478, LR=0.00034549150281252633
# Validation Loss = 0.059
# Epoch=7, batch = 2000 of 4000, loss=0.579, LR=0.00034549150281252633
# Validation Loss = 0.321
# Epoch=7, batch = 2100 of 4000, loss=0.629, LR=0.00034549150281252633
# Validation Loss = 0.036
# Epoch=7, batch = 2200 of 4000, loss=0.433, LR=0.00034549150281252633
# Validation Loss = 0.201
# Epoch=7, batch = 2300 of 4000, loss=0.552, LR=0.00034549150281252633
# Validation Loss = 0.017
# Epoch=7, batch = 2400 of 4000, loss=0.452, LR=0.00034549150281252633
# Validation Loss = 0.153
# Epoch=7, batch = 2500 of 4000, loss=0.552, LR=0.00034549150281252633
# Validation Loss = 0.020
# Epoch=7, batch = 2600 of 4000, loss=0.468, LR=0.00034549150281252633
# Validation Loss = 0.019
# Epoch=7, batch = 2700 of 4000, loss=0.451, LR=0.00034549150281252633
# Validation Loss = 0.041
# Epoch=7, batch = 2800 of 4000, loss=0.514, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=7, batch = 2900 of 4000, loss=0.415, LR=0.00034549150281252633
# Validation Loss = 0.075
# Epoch=7, batch = 3000 of 4000, loss=0.669, LR=0.00034549150281252633
# Validation Loss = 0.019
# Epoch=7, batch = 3100 of 4000, loss=0.497, LR=0.00034549150281252633
# Validation Loss = 0.058
# Epoch=7, batch = 3200 of 4000, loss=0.516, LR=0.00034549150281252633
# Validation Loss = 0.230
# Epoch=7, batch = 3300 of 4000, loss=0.528, LR=0.00034549150281252633
# Validation Loss = 0.006
# Epoch=7, batch = 3400 of 4000, loss=0.442, LR=0.00034549150281252633
# Validation Loss = 1.695
# Epoch=7, batch = 3500 of 4000, loss=1.725, LR=0.00034549150281252633
# Validation Loss = 0.009
# Epoch=7, batch = 3600 of 4000, loss=0.483, LR=0.00034549150281252633
# Validation Loss = 0.066
# Epoch=7, batch = 3700 of 4000, loss=0.454, LR=0.00034549150281252633
# Validation Loss = 0.089
# Epoch=7, batch = 3800 of 4000, loss=0.540, LR=0.00034549150281252633
# Validation Loss = 0.045
# Epoch=7, batch = 3900 of 4000, loss=0.429, LR=0.00034549150281252633
# Validation Loss = 0.047
# Epoch=8, batch = 0 of 4000, loss=0.500, LR=0.0002061073738537635
# Validation Loss = 0.004
# Epoch=8, batch = 100 of 4000, loss=0.459, LR=0.0002061073738537635
# Validation Loss = 0.009
# Epoch=8, batch = 200 of 4000, loss=0.481, LR=0.0002061073738537635
# Validation Loss = 0.006
# Epoch=8, batch = 300 of 4000, loss=0.463, LR=0.0002061073738537635
# Validation Loss = 0.088
# Epoch=8, batch = 400 of 4000, loss=0.482, LR=0.0002061073738537635
# Validation Loss = 0.015
# Epoch=8, batch = 500 of 4000, loss=0.450, LR=0.0002061073738537635
# Validation Loss = 0.000
# Epoch=8, batch = 600 of 4000, loss=0.477, LR=0.0002061073738537635
# Validation Loss = 0.036
# Epoch=8, batch = 700 of 4000, loss=0.422, LR=0.0002061073738537635
# Validation Loss = 0.014
# Epoch=8, batch = 800 of 4000, loss=0.435, LR=0.0002061073738537635
# Validation Loss = 0.000
# Epoch=8, batch = 900 of 4000, loss=0.433, LR=0.0002061073738537635
# Validation Loss = 0.028
# Epoch=8, batch = 1000 of 4000, loss=0.422, LR=0.0002061073738537635
# Validation Loss = 0.019
# Epoch=8, batch = 1100 of 4000, loss=0.546, LR=0.0002061073738537635
# Validation Loss = 0.006
# Epoch=8, batch = 1200 of 4000, loss=0.438, LR=0.0002061073738537635
# Validation Loss = 0.000
# Epoch=8, batch = 1300 of 4000, loss=0.480, LR=0.0002061073738537635
# Validation Loss = 0.004
# Epoch=8, batch = 1400 of 4000, loss=0.415, LR=0.0002061073738537635
# Validation Loss = 0.018
# Epoch=8, batch = 1500 of 4000, loss=0.410, LR=0.0002061073738537635
# Validation Loss = 0.000
# Epoch=8, batch = 1600 of 4000, loss=0.401, LR=0.0002061073738537635
# Validation Loss = 0.023
# Epoch=8, batch = 1700 of 4000, loss=0.554, LR=0.0002061073738537635
# Validation Loss = 0.106
# Epoch=8, batch = 1800 of 4000, loss=0.488, LR=0.0002061073738537635
# Validation Loss = 0.003
# Epoch=8, batch = 1900 of 4000, loss=0.444, LR=0.0002061073738537635
# Validation Loss = 0.025
# Epoch=8, batch = 2000 of 4000, loss=0.468, LR=0.0002061073738537635
# Validation Loss = 0.024
# Epoch=8, batch = 2100 of 4000, loss=0.437, LR=0.0002061073738537635
# Validation Loss = 0.000
# Epoch=8, batch = 2200 of 4000, loss=0.447, LR=0.0002061073738537635
# Validation Loss = 0.011
# Epoch=8, batch = 2300 of 4000, loss=0.465, LR=0.0002061073738537635
# Validation Loss = 0.000
# Epoch=8, batch = 2400 of 4000, loss=0.529, LR=0.0002061073738537635
# Validation Loss = 0.065
# Epoch=8, batch = 2500 of 4000, loss=0.495, LR=0.0002061073738537635
# Validation Loss = 0.009
# Epoch=8, batch = 2600 of 4000, loss=0.398, LR=0.0002061073738537635
# Validation Loss = 0.053
# Epoch=8, batch = 2700 of 4000, loss=0.442, LR=0.0002061073738537635
# Validation Loss = 0.006
# Epoch=8, batch = 2800 of 4000, loss=0.484, LR=0.0002061073738537635
# Validation Loss = 0.100
# Epoch=8, batch = 2900 of 4000, loss=0.434, LR=0.0002061073738537635
# Validation Loss = 0.264
# Epoch=8, batch = 3000 of 4000, loss=0.551, LR=0.0002061073738537635
# Validation Loss = 0.077
# Epoch=8, batch = 3100 of 4000, loss=0.456, LR=0.0002061073738537635
# Validation Loss = 0.032
# Epoch=8, batch = 3200 of 4000, loss=0.512, LR=0.0002061073738537635
# Validation Loss = 0.000
# Epoch=8, batch = 3300 of 4000, loss=0.453, LR=0.0002061073738537635
# Validation Loss = 0.178
# Epoch=8, batch = 3400 of 4000, loss=0.494, LR=0.0002061073738537635
# Validation Loss = 0.001
# Epoch=8, batch = 3500 of 4000, loss=0.423, LR=0.0002061073738537635
# Validation Loss = 0.018
# Epoch=8, batch = 3600 of 4000, loss=0.407, LR=0.0002061073738537635
# Validation Loss = 0.047
# Epoch=8, batch = 3700 of 4000, loss=0.413, LR=0.0002061073738537635
# Validation Loss = 0.000
# Epoch=8, batch = 3800 of 4000, loss=0.416, LR=0.0002061073738537635
# Validation Loss = 0.043
# Epoch=8, batch = 3900 of 4000, loss=0.457, LR=0.0002061073738537635
# Validation Loss = 0.002
# Epoch=9, batch = 0 of 4000, loss=0.478, LR=9.549150281252634e-05
# Validation Loss = 0.015
# Epoch=9, batch = 100 of 4000, loss=0.398, LR=9.549150281252634e-05
# Validation Loss = 0.062
# Epoch=9, batch = 200 of 4000, loss=0.440, LR=9.549150281252634e-05
# Validation Loss = 0.009
# Epoch=9, batch = 300 of 4000, loss=0.427, LR=9.549150281252634e-05
# Validation Loss = 0.022
# Epoch=9, batch = 400 of 4000, loss=0.445, LR=9.549150281252634e-05
# Validation Loss = 0.096
# Epoch=9, batch = 500 of 4000, loss=0.443, LR=9.549150281252634e-05
# Validation Loss = 0.062
# Epoch=9, batch = 600 of 4000, loss=0.445, LR=9.549150281252634e-05
# Validation Loss = 0.156
# Epoch=9, batch = 700 of 4000, loss=0.501, LR=9.549150281252634e-05
# Validation Loss = 0.033
# Epoch=9, batch = 800 of 4000, loss=0.480, LR=9.549150281252634e-05
# Validation Loss = 0.078
# Epoch=9, batch = 900 of 4000, loss=0.448, LR=9.549150281252634e-05
# Validation Loss = 0.007
# Epoch=9, batch = 1000 of 4000, loss=0.402, LR=9.549150281252634e-05
# Validation Loss = 0.004
# Epoch=9, batch = 1100 of 4000, loss=0.449, LR=9.549150281252634e-05
# Validation Loss = 0.035
# Epoch=9, batch = 1200 of 4000, loss=0.396, LR=9.549150281252634e-05
# Validation Loss = 0.054
# Epoch=9, batch = 1300 of 4000, loss=0.453, LR=9.549150281252634e-05
# Validation Loss = 0.005
# Epoch=9, batch = 1400 of 4000, loss=0.480, LR=9.549150281252634e-05
# Validation Loss = 0.022
# Epoch=9, batch = 1500 of 4000, loss=0.384, LR=9.549150281252634e-05
# Validation Loss = 0.126
# Epoch=9, batch = 1600 of 4000, loss=0.452, LR=9.549150281252634e-05
# Validation Loss = 0.004
# Epoch=9, batch = 1700 of 4000, loss=0.411, LR=9.549150281252634e-05
# Validation Loss = 0.051
# Epoch=9, batch = 1800 of 4000, loss=0.413, LR=9.549150281252634e-05
# Validation Loss = 0.095
# Epoch=9, batch = 1900 of 4000, loss=0.415, LR=9.549150281252634e-05
# Validation Loss = 0.022
# Epoch=9, batch = 2000 of 4000, loss=0.537, LR=9.549150281252634e-05
# Validation Loss = 0.047
# Epoch=9, batch = 2100 of 4000, loss=0.383, LR=9.549150281252634e-05
# Validation Loss = 0.003
# ...
# Validation Loss = 1.333
# Epoch=20, batch = 3400 of 4000, loss=4.175, LR=6.15582970243117e-06
# Validation Loss = 1.211
# Epoch=20, batch = 3500 of 4000, loss=4.000, LR=6.15582970243117e-06
# Validation Loss = 1.257
# Epoch=20, batch = 3600 of 4000, loss=3.897, LR=6.15582970243117e-06
# Validation Loss = 1.071
# Epoch=20, batch = 3700 of 4000, loss=4.193, LR=6.15582970243117e-06
# Validation Loss = 1.187
# Epoch=20, batch = 3800 of 4000, loss=4.188, LR=6.15582970243117e-06
# Validation Loss = 1.648
# Epoch=20, batch = 3900 of 4000, loss=4.214, LR=6.15582970243117e-06
# Finished training model for channel 150Hb.
# 183+-1Ha
# Training stage: 1
# Validation Loss = 65047.383
# Epoch=1, batch = 0 of 4000, loss=60129.055, LR=0.001
# Validation Loss = 45.316
# Epoch=1, batch = 100 of 4000, loss=106.369, LR=0.001
# Validation Loss = 0.736
# Epoch=1, batch = 200 of 4000, loss=15.464, LR=0.001
# Validation Loss = 5.565
# Epoch=1, batch = 300 of 4000, loss=12.942, LR=0.001
# Validation Loss = 4.243
# Epoch=1, batch = 400 of 4000, loss=11.046, LR=0.001
# Validation Loss = 5.414
# Epoch=1, batch = 500 of 4000, loss=10.072, LR=0.001
# Validation Loss = 6.651
# Epoch=1, batch = 600 of 4000, loss=10.682, LR=0.001
# Validation Loss = 6.130
# Epoch=1, batch = 700 of 4000, loss=10.265, LR=0.001
# Validation Loss = 5.303
# Epoch=1, batch = 800 of 4000, loss=9.367, LR=0.001
# Validation Loss = 4.109
# Epoch=1, batch = 900 of 4000, loss=9.484, LR=0.001
# Validation Loss = 4.736
# Epoch=1, batch = 1000 of 4000, loss=9.242, LR=0.001
# Validation Loss = 5.694
# Epoch=1, batch = 1100 of 4000, loss=8.176, LR=0.001
# Validation Loss = 2.949
# Epoch=1, batch = 1200 of 4000, loss=7.932, LR=0.001
# Validation Loss = 6.838
# Epoch=1, batch = 1300 of 4000, loss=8.394, LR=0.001
# Validation Loss = 2.063
# Epoch=1, batch = 1400 of 4000, loss=7.869, LR=0.001
# Validation Loss = 3.755
# Epoch=1, batch = 1500 of 4000, loss=7.611, LR=0.001
# Validation Loss = 3.790
# Epoch=1, batch = 1600 of 4000, loss=7.763, LR=0.001
# Validation Loss = 2.092
# Epoch=1, batch = 1700 of 4000, loss=7.283, LR=0.001
# Validation Loss = 2.743
# Epoch=1, batch = 1800 of 4000, loss=6.971, LR=0.001
# Validation Loss = 1.158
# Epoch=1, batch = 1900 of 4000, loss=6.867, LR=0.001
# Validation Loss = 2.196
# Epoch=1, batch = 2000 of 4000, loss=6.688, LR=0.001
# Validation Loss = 0.433
# Epoch=1, batch = 2100 of 4000, loss=6.797, LR=0.001
# Validation Loss = 1.758
# Epoch=1, batch = 2200 of 4000, loss=6.279, LR=0.001
# Validation Loss = 0.304
# Epoch=1, batch = 2300 of 4000, loss=6.576, LR=0.001
# Validation Loss = 2.565
# Epoch=1, batch = 2400 of 4000, loss=5.954, LR=0.001
# Validation Loss = 1.226
# Epoch=1, batch = 2500 of 4000, loss=5.865, LR=0.001
# Validation Loss = 0.637
# Epoch=1, batch = 2600 of 4000, loss=5.755, LR=0.001
# Validation Loss = 0.897
# Epoch=1, batch = 2700 of 4000, loss=6.068, LR=0.001
# Validation Loss = 0.154
# Epoch=1, batch = 2800 of 4000, loss=6.113, LR=0.001
# Validation Loss = 0.163
# Epoch=1, batch = 2900 of 4000, loss=5.905, LR=0.001
# Validation Loss = 3.057
# Epoch=1, batch = 3000 of 4000, loss=6.048, LR=0.001
# Validation Loss = 1.080
# Epoch=1, batch = 3100 of 4000, loss=5.912, LR=0.001
# Validation Loss = 2.176
# Epoch=1, batch = 3200 of 4000, loss=6.144, LR=0.001
# Validation Loss = 12.888
# Epoch=1, batch = 3300 of 4000, loss=11.986, LR=0.001
# Validation Loss = 2.423
# Epoch=1, batch = 3400 of 4000, loss=9.830, LR=0.001
# Validation Loss = 5.648
# Epoch=1, batch = 3500 of 4000, loss=8.080, LR=0.001
# Validation Loss = 0.002
# Epoch=1, batch = 3600 of 4000, loss=6.203, LR=0.001
# Validation Loss = 3.617
# Epoch=1, batch = 3700 of 4000, loss=6.622, LR=0.001
# Validation Loss = 0.211
# Epoch=1, batch = 3800 of 4000, loss=7.041, LR=0.001
# Validation Loss = 0.702
# Epoch=1, batch = 3900 of 4000, loss=8.032, LR=0.001
# Validation Loss = 65.482
# Epoch=2, batch = 0 of 4000, loss=53.562, LR=0.0009045084971874737
# Validation Loss = 1.632
# Epoch=2, batch = 100 of 4000, loss=5.656, LR=0.0009045084971874737
# Validation Loss = 0.025
# Epoch=2, batch = 200 of 4000, loss=5.416, LR=0.0009045084971874737
# Validation Loss = 2.141
# Epoch=2, batch = 300 of 4000, loss=5.684, LR=0.0009045084971874737
# Validation Loss = 0.118
# Epoch=2, batch = 400 of 4000, loss=6.919, LR=0.0009045084971874737
# Validation Loss = 1.174
# Epoch=2, batch = 500 of 4000, loss=5.321, LR=0.0009045084971874737
# Validation Loss = 0.330
# Epoch=2, batch = 600 of 4000, loss=5.804, LR=0.0009045084971874737
# Validation Loss = 1.331
# Epoch=2, batch = 700 of 4000, loss=8.605, LR=0.0009045084971874737
# Validation Loss = 1.885
# Epoch=2, batch = 800 of 4000, loss=5.471, LR=0.0009045084971874737
# Validation Loss = 1.832
# Epoch=2, batch = 900 of 4000, loss=5.420, LR=0.0009045084971874737
# Validation Loss = 3.319
# Epoch=2, batch = 1000 of 4000, loss=6.304, LR=0.0009045084971874737
# Validation Loss = 3.371
# Epoch=2, batch = 1100 of 4000, loss=6.130, LR=0.0009045084971874737
# Validation Loss = 0.246
# Epoch=2, batch = 1200 of 4000, loss=5.906, LR=0.0009045084971874737
# Validation Loss = 0.422
# Epoch=2, batch = 1300 of 4000, loss=6.378, LR=0.0009045084971874737
# Validation Loss = 2.254
# Epoch=2, batch = 1400 of 4000, loss=5.617, LR=0.0009045084971874737
# Validation Loss = 2.392
# Epoch=2, batch = 1500 of 4000, loss=9.950, LR=0.0009045084971874737
# Validation Loss = 0.243
# Epoch=2, batch = 1600 of 4000, loss=6.012, LR=0.0009045084971874737
# Validation Loss = 5.049
# Epoch=2, batch = 1700 of 4000, loss=12.437, LR=0.0009045084971874737
# Validation Loss = 0.096
# Epoch=2, batch = 1800 of 4000, loss=6.744, LR=0.0009045084971874737
# Validation Loss = 0.022
# Epoch=2, batch = 1900 of 4000, loss=6.133, LR=0.0009045084971874737
# Validation Loss = 3.034
# Epoch=2, batch = 2000 of 4000, loss=6.814, LR=0.0009045084971874737
# Validation Loss = 0.150
# Epoch=2, batch = 2100 of 4000, loss=6.338, LR=0.0009045084971874737
# Validation Loss = 0.492
# Epoch=2, batch = 2200 of 4000, loss=5.231, LR=0.0009045084971874737
# Validation Loss = 0.657
# Epoch=2, batch = 2300 of 4000, loss=5.290, LR=0.0009045084971874737
# Validation Loss = 10.363
# Epoch=2, batch = 2400 of 4000, loss=10.841, LR=0.0009045084971874737
# Validation Loss = 0.565
# Epoch=2, batch = 2500 of 4000, loss=5.328, LR=0.0009045084971874737
# Validation Loss = 0.139
# Epoch=2, batch = 2600 of 4000, loss=6.442, LR=0.0009045084971874737
# Validation Loss = 0.239
# Epoch=2, batch = 2700 of 4000, loss=5.274, LR=0.0009045084971874737
# Validation Loss = 0.631
# Epoch=2, batch = 2800 of 4000, loss=5.064, LR=0.0009045084971874737
# Validation Loss = 8.863
# Epoch=2, batch = 2900 of 4000, loss=9.837, LR=0.0009045084971874737
# Validation Loss = 4.231
# Epoch=2, batch = 3000 of 4000, loss=7.334, LR=0.0009045084971874737
# Validation Loss = 0.003
# Epoch=2, batch = 3100 of 4000, loss=5.505, LR=0.0009045084971874737
# Validation Loss = 0.023
# Epoch=2, batch = 3200 of 4000, loss=6.751, LR=0.0009045084971874737
# Validation Loss = 0.179
# Epoch=2, batch = 3300 of 4000, loss=6.838, LR=0.0009045084971874737
# Validation Loss = 0.172
# Epoch=2, batch = 3400 of 4000, loss=5.071, LR=0.0009045084971874737
# Validation Loss = 3.205
# Epoch=2, batch = 3500 of 4000, loss=6.604, LR=0.0009045084971874737
# Validation Loss = 0.167
# Epoch=2, batch = 3600 of 4000, loss=5.371, LR=0.0009045084971874737
# Validation Loss = 0.019
# Epoch=2, batch = 3700 of 4000, loss=5.978, LR=0.0009045084971874737
# Validation Loss = 1.030
# Epoch=2, batch = 3800 of 4000, loss=5.466, LR=0.0009045084971874737
# Validation Loss = 0.125
# Epoch=2, batch = 3900 of 4000, loss=5.576, LR=0.0009045084971874737
# Validation Loss = 0.734
# Epoch=3, batch = 0 of 4000, loss=7.400, LR=0.0006545084971874737
# Validation Loss = 1.010
# Epoch=3, batch = 100 of 4000, loss=5.715, LR=0.0006545084971874737
# Validation Loss = 0.226
# Epoch=3, batch = 200 of 4000, loss=5.034, LR=0.0006545084971874737
# Validation Loss = 1.646
# Epoch=3, batch = 300 of 4000, loss=5.958, LR=0.0006545084971874737
# Validation Loss = 0.341
# Epoch=3, batch = 400 of 4000, loss=4.899, LR=0.0006545084971874737
# Validation Loss = 0.422
# Epoch=3, batch = 500 of 4000, loss=5.157, LR=0.0006545084971874737
# Validation Loss = 0.152
# Epoch=3, batch = 600 of 4000, loss=6.435, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=3, batch = 700 of 4000, loss=5.681, LR=0.0006545084971874737
# Validation Loss = 5.829
# Epoch=3, batch = 800 of 4000, loss=8.989, LR=0.0006545084971874737
# Validation Loss = 0.319
# Epoch=3, batch = 900 of 4000, loss=5.553, LR=0.0006545084971874737
# Validation Loss = 1.593
# Epoch=3, batch = 1000 of 4000, loss=6.364, LR=0.0006545084971874737
# Validation Loss = 0.267
# Epoch=3, batch = 1100 of 4000, loss=5.886, LR=0.0006545084971874737
# Validation Loss = 0.288
# Epoch=3, batch = 1200 of 4000, loss=5.237, LR=0.0006545084971874737
# Validation Loss = 0.277
# Epoch=3, batch = 1300 of 4000, loss=6.084, LR=0.0006545084971874737
# Validation Loss = 0.290
# Epoch=3, batch = 1400 of 4000, loss=6.174, LR=0.0006545084971874737
# Validation Loss = 0.004
# Epoch=3, batch = 1500 of 4000, loss=5.748, LR=0.0006545084971874737
# Validation Loss = 0.087
# Epoch=3, batch = 1600 of 4000, loss=5.227, LR=0.0006545084971874737
# Validation Loss = 0.014
# Epoch=3, batch = 1700 of 4000, loss=5.775, LR=0.0006545084971874737
# Validation Loss = 3.687
# Epoch=3, batch = 1800 of 4000, loss=7.641, LR=0.0006545084971874737
# Validation Loss = 0.001
# Epoch=3, batch = 1900 of 4000, loss=5.510, LR=0.0006545084971874737
# Validation Loss = 0.085
# Epoch=3, batch = 2000 of 4000, loss=5.333, LR=0.0006545084971874737
# Validation Loss = 2.125
# Epoch=3, batch = 2100 of 4000, loss=6.468, LR=0.0006545084971874737
# Validation Loss = 0.622
# Epoch=3, batch = 2200 of 4000, loss=6.010, LR=0.0006545084971874737
# Validation Loss = 0.199
# Epoch=3, batch = 2300 of 4000, loss=5.560, LR=0.0006545084971874737
# Validation Loss = 0.042
# Epoch=3, batch = 2400 of 4000, loss=5.546, LR=0.0006545084971874737
# Validation Loss = 0.011
# Epoch=3, batch = 2500 of 4000, loss=5.367, LR=0.0006545084971874737
# Validation Loss = 0.226
# Epoch=3, batch = 2600 of 4000, loss=5.172, LR=0.0006545084971874737
# Validation Loss = 1.034
# Epoch=3, batch = 2700 of 4000, loss=5.116, LR=0.0006545084971874737
# Validation Loss = 5.048
# Epoch=3, batch = 2800 of 4000, loss=8.595, LR=0.0006545084971874737
# Validation Loss = 1.201
# Epoch=3, batch = 2900 of 4000, loss=5.273, LR=0.0006545084971874737
# Validation Loss = 0.045
# Epoch=3, batch = 3000 of 4000, loss=6.110, LR=0.0006545084971874737
# Validation Loss = 1.079
# Epoch=3, batch = 3100 of 4000, loss=5.710, LR=0.0006545084971874737
# Validation Loss = 0.396
# Epoch=3, batch = 3200 of 4000, loss=6.263, LR=0.0006545084971874737
# Validation Loss = 0.845
# Epoch=3, batch = 3300 of 4000, loss=6.475, LR=0.0006545084971874737
# Validation Loss = 0.077
# Epoch=3, batch = 3400 of 4000, loss=5.408, LR=0.0006545084971874737
# Validation Loss = 0.470
# Epoch=3, batch = 3500 of 4000, loss=6.212, LR=0.0006545084971874737
# Validation Loss = 1.175
# Epoch=3, batch = 3600 of 4000, loss=5.186, LR=0.0006545084971874737
# Validation Loss = 4.071
# Epoch=3, batch = 3700 of 4000, loss=7.921, LR=0.0006545084971874737
# Validation Loss = 0.787
# Epoch=3, batch = 3800 of 4000, loss=6.727, LR=0.0006545084971874737
# Validation Loss = 1.521
# Epoch=3, batch = 3900 of 4000, loss=5.795, LR=0.0006545084971874737
# Validation Loss = 0.001
# Epoch=4, batch = 0 of 4000, loss=5.667, LR=0.00034549150281252633
# Validation Loss = 0.003
# Epoch=4, batch = 100 of 4000, loss=5.421, LR=0.00034549150281252633
# Validation Loss = 0.199
# Epoch=4, batch = 200 of 4000, loss=5.205, LR=0.00034549150281252633
# Validation Loss = 0.002
# Epoch=4, batch = 300 of 4000, loss=5.132, LR=0.00034549150281252633
# Validation Loss = 0.204
# Epoch=4, batch = 400 of 4000, loss=5.195, LR=0.00034549150281252633
# Validation Loss = 0.092
# Epoch=4, batch = 500 of 4000, loss=5.343, LR=0.00034549150281252633
# Validation Loss = 0.064
# Epoch=4, batch = 600 of 4000, loss=5.704, LR=0.00034549150281252633
# Validation Loss = 0.070
# Epoch=4, batch = 700 of 4000, loss=5.410, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=4, batch = 800 of 4000, loss=5.465, LR=0.00034549150281252633
# Validation Loss = 0.354
# Epoch=4, batch = 900 of 4000, loss=5.555, LR=0.00034549150281252633
# Validation Loss = 0.033
# Epoch=4, batch = 1000 of 4000, loss=5.485, LR=0.00034549150281252633
# Validation Loss = 0.611
# Epoch=4, batch = 1100 of 4000, loss=5.720, LR=0.00034549150281252633
# Validation Loss = 0.615
# Epoch=4, batch = 1200 of 4000, loss=4.928, LR=0.00034549150281252633
# Validation Loss = 0.554
# Epoch=4, batch = 1300 of 4000, loss=5.358, LR=0.00034549150281252633
# Validation Loss = 0.262
# Epoch=4, batch = 1400 of 4000, loss=5.623, LR=0.00034549150281252633
# Validation Loss = 0.000
# Epoch=4, batch = 1500 of 4000, loss=5.445, LR=0.00034549150281252633
# Validation Loss = 0.198
# Epoch=4, batch = 1600 of 4000, loss=4.765, LR=0.00034549150281252633
# Validation Loss = 0.246
# Epoch=4, batch = 1700 of 4000, loss=5.737, LR=0.00034549150281252633
# Validation Loss = 0.140
# Epoch=4, batch = 1800 of 4000, loss=5.359, LR=0.00034549150281252633
# Validation Loss = 0.545
# Epoch=4, batch = 1900 of 4000, loss=5.348, LR=0.00034549150281252633
# Validation Loss = 0.033
# Epoch=4, batch = 2000 of 4000, loss=5.161, LR=0.00034549150281252633
# Validation Loss = 2.610
# Epoch=4, batch = 2100 of 4000, loss=7.026, LR=0.00034549150281252633
# Validation Loss = 0.011
# Epoch=4, batch = 2200 of 4000, loss=5.608, LR=0.00034549150281252633
# Validation Loss = 0.002
# Epoch=4, batch = 2300 of 4000, loss=5.445, LR=0.00034549150281252633
# Validation Loss = 0.192
# Epoch=4, batch = 2400 of 4000, loss=5.379, LR=0.00034549150281252633
# Validation Loss = 0.185
# Epoch=4, batch = 2500 of 4000, loss=6.176, LR=0.00034549150281252633
# Validation Loss = 0.290
# Epoch=4, batch = 2600 of 4000, loss=5.389, LR=0.00034549150281252633
# Validation Loss = 0.065
# Epoch=4, batch = 2700 of 4000, loss=5.596, LR=0.00034549150281252633
# Validation Loss = 0.339
# Epoch=4, batch = 2800 of 4000, loss=5.897, LR=0.00034549150281252633
# Validation Loss = 0.327
# Epoch=4, batch = 2900 of 4000, loss=5.129, LR=0.00034549150281252633
# Validation Loss = 0.430
# Epoch=4, batch = 3000 of 4000, loss=6.345, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=4, batch = 3100 of 4000, loss=5.445, LR=0.00034549150281252633
# Validation Loss = 0.116
# Epoch=4, batch = 3200 of 4000, loss=5.271, LR=0.00034549150281252633
# Validation Loss = 0.206
# Epoch=4, batch = 3300 of 4000, loss=4.962, LR=0.00034549150281252633
# Validation Loss = 0.230
# Epoch=4, batch = 3400 of 4000, loss=5.507, LR=0.00034549150281252633
# Validation Loss = 0.517
# Epoch=4, batch = 3500 of 4000, loss=5.289, LR=0.00034549150281252633
# Validation Loss = 2.256
# Epoch=4, batch = 3600 of 4000, loss=6.640, LR=0.00034549150281252633
# Validation Loss = 1.387
# Epoch=4, batch = 3700 of 4000, loss=7.901, LR=0.00034549150281252633
# Validation Loss = 0.148
# Epoch=4, batch = 3800 of 4000, loss=6.009, LR=0.00034549150281252633
# Validation Loss = 0.111
# Epoch=4, batch = 3900 of 4000, loss=5.725, LR=0.00034549150281252633
# Validation Loss = 0.206
# Epoch=5, batch = 0 of 4000, loss=4.978, LR=9.549150281252633e-05
# Validation Loss = 0.003
# Epoch=5, batch = 100 of 4000, loss=5.546, LR=9.549150281252633e-05
# Validation Loss = 0.166
# Epoch=5, batch = 200 of 4000, loss=4.636, LR=9.549150281252633e-05
# Validation Loss = 0.195
# Epoch=5, batch = 300 of 4000, loss=5.022, LR=9.549150281252633e-05
# Validation Loss = 0.144
# Epoch=5, batch = 400 of 4000, loss=5.275, LR=9.549150281252633e-05
# Validation Loss = 0.241
# Epoch=5, batch = 500 of 4000, loss=4.920, LR=9.549150281252633e-05
# Validation Loss = 0.021
# Epoch=5, batch = 600 of 4000, loss=5.065, LR=9.549150281252633e-05
# Validation Loss = 0.319
# Epoch=5, batch = 700 of 4000, loss=5.280, LR=9.549150281252633e-05
# Validation Loss = 0.310
# Epoch=5, batch = 800 of 4000, loss=4.935, LR=9.549150281252633e-05
# Validation Loss = 0.049
# Epoch=5, batch = 900 of 4000, loss=5.458, LR=9.549150281252633e-05
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
#General parameters:
input_size = nchans - 1 + 1 #Remaining channels + surface type

# %%
'''

SSMI CHANNEL PREDICTION MODEL:
    2: Non-Ocean Surfaces

'''

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = sfctype > 1

    Tbs = f.Tbs.values[correct_sfc,:]
    sfctype = sfctype[correct_sfc]

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

sfctype_train = sfctype[train_indcs].astype(np.float32)
sfctype_test  = sfctype[test_indcs].astype(np.float32)
sfctype_val   = sfctype[val_indcs].astype(np.float32)

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train, shuffled_indcs = array_funcs.shuffle_data(Tbs_train, axis=0, return_indcs=True)
sfctype_train = sfctype_train[shuffled_indcs]

# %%
sfctype_train, sfctype_test, sfctype_val
# Out:
# (array([18.,  2., 11., ...,  5., 17., 10.],
#        shape=(21497209,), dtype=float32),
#  array([11., 11., 11., ..., 17.,  3., 17.], shape=(2687151,), dtype=float32),
#  array([ 4., 12., 12., ..., 11., 11., 11.], shape=(2687152,), dtype=float32))

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    print(channel)

    if ichan < 5: continue

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)

    x_train = np.concatenate((x_train, sfctype_train[:,None]), axis=1)
    x_test  = np.concatenate((x_test,  sfctype_test[:,None]), axis=1)
    x_val   = np.concatenate((x_val,   sfctype_val[:,None]), axis=1)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_nonocean.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_nonocean.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 19V
# 19H
# 22V
# 37V
# 37H
# 92Va
# Training stage: 1
# Validation Loss = 91607.656
# Epoch=1, batch = 0 of 21497, loss=67802.125, LR=0.001
# Validation Loss = 0.107
# Epoch=1, batch = 1000 of 21497, loss=4.320, LR=0.001
# Validation Loss = 0.031
# Epoch=1, batch = 2000 of 21497, loss=3.973, LR=0.001
# Validation Loss = 0.111
# Epoch=1, batch = 3000 of 21497, loss=4.967, LR=0.001
# Validation Loss = 1.760
# Epoch=1, batch = 4000 of 21497, loss=7.239, LR=0.001
# Validation Loss = 0.461
# Epoch=1, batch = 5000 of 21497, loss=3.940, LR=0.001
# Validation Loss = 3.778
# Epoch=1, batch = 6000 of 21497, loss=4.577, LR=0.001
# Validation Loss = 4.884
# Epoch=1, batch = 7000 of 21497, loss=6.537, LR=0.001
# Validation Loss = 1.956
# Epoch=1, batch = 8000 of 21497, loss=4.011, LR=0.001
# Validation Loss = 0.527
# Epoch=1, batch = 9000 of 21497, loss=3.744, LR=0.001
# Validation Loss = 5.706
# Epoch=1, batch = 10000 of 21497, loss=6.344, LR=0.001
# Validation Loss = 0.000
# Epoch=1, batch = 11000 of 21497, loss=3.706, LR=0.001
# Validation Loss = 0.071
# Epoch=1, batch = 12000 of 21497, loss=4.086, LR=0.001
# Validation Loss = 0.363
# Epoch=1, batch = 13000 of 21497, loss=4.103, LR=0.001
# Validation Loss = 0.907
# Epoch=1, batch = 14000 of 21497, loss=2.491, LR=0.001
# Validation Loss = 2.919
# Epoch=1, batch = 15000 of 21497, loss=5.093, LR=0.001
# Validation Loss = 7.768
# Epoch=1, batch = 16000 of 21497, loss=12.465, LR=0.001
# Validation Loss = 4.811
# Epoch=1, batch = 17000 of 21497, loss=5.302, LR=0.001
# Validation Loss = 2.861
# Epoch=1, batch = 18000 of 21497, loss=4.504, LR=0.001
# Validation Loss = 0.002
# Epoch=1, batch = 19000 of 21497, loss=3.325, LR=0.001
# Validation Loss = 0.928
# Epoch=1, batch = 20000 of 21497, loss=4.352, LR=0.001
# Validation Loss = 0.030
# Epoch=1, batch = 21000 of 21497, loss=2.937, LR=0.001
# Validation Loss = 0.718
# Epoch=2, batch = 0 of 21497, loss=3.043, LR=0.0009045084971874737
# Validation Loss = 2.291
# Epoch=2, batch = 1000 of 21497, loss=4.135, LR=0.0009045084971874737
# Validation Loss = 0.000
# Epoch=2, batch = 2000 of 21497, loss=3.167, LR=0.0009045084971874737
# Validation Loss = 0.228
# Epoch=2, batch = 3000 of 21497, loss=3.270, LR=0.0009045084971874737
# Validation Loss = 1.894
# Epoch=2, batch = 4000 of 21497, loss=3.618, LR=0.0009045084971874737
# Validation Loss = 0.044
# Epoch=2, batch = 5000 of 21497, loss=3.488, LR=0.0009045084971874737
# Validation Loss = 0.001
# Epoch=2, batch = 6000 of 21497, loss=3.180, LR=0.0009045084971874737
# Validation Loss = 0.078
# Epoch=2, batch = 7000 of 21497, loss=3.324, LR=0.0009045084971874737
# Validation Loss = 0.590
# Epoch=2, batch = 8000 of 21497, loss=4.807, LR=0.0009045084971874737
# Validation Loss = 0.275
# Epoch=2, batch = 9000 of 21497, loss=3.716, LR=0.0009045084971874737
# Validation Loss = 2.011
# Epoch=2, batch = 10000 of 21497, loss=3.592, LR=0.0009045084971874737
# Validation Loss = 3.126
# Epoch=2, batch = 11000 of 21497, loss=5.702, LR=0.0009045084971874737
# Validation Loss = 0.732
# Epoch=2, batch = 12000 of 21497, loss=3.195, LR=0.0009045084971874737
# Validation Loss = 0.400
# Epoch=2, batch = 13000 of 21497, loss=2.866, LR=0.0009045084971874737
# Validation Loss = 3.040
# Epoch=2, batch = 14000 of 21497, loss=4.032, LR=0.0009045084971874737
# Validation Loss = 5.815
# Epoch=2, batch = 15000 of 21497, loss=4.591, LR=0.0009045084971874737
# Validation Loss = 2.640
# Epoch=2, batch = 16000 of 21497, loss=5.098, LR=0.0009045084971874737
# Validation Loss = 0.384
# Epoch=2, batch = 17000 of 21497, loss=4.176, LR=0.0009045084971874737
# Validation Loss = 1.951
# Epoch=2, batch = 18000 of 21497, loss=5.359, LR=0.0009045084971874737
# Validation Loss = 1.242
# Epoch=2, batch = 19000 of 21497, loss=3.102, LR=0.0009045084971874737
# Validation Loss = 3.225
# Epoch=2, batch = 20000 of 21497, loss=4.489, LR=0.0009045084971874737
# Validation Loss = 1.807
# Epoch=2, batch = 21000 of 21497, loss=3.288, LR=0.0009045084971874737
# Validation Loss = 0.068
# Epoch=3, batch = 0 of 21497, loss=2.911, LR=0.0006545084971874737
# Validation Loss = 0.155
# Epoch=3, batch = 1000 of 21497, loss=2.570, LR=0.0006545084971874737
# Validation Loss = 0.219
# Epoch=3, batch = 2000 of 21497, loss=2.663, LR=0.0006545084971874737
# Validation Loss = 2.045
# Epoch=3, batch = 3000 of 21497, loss=3.814, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=3, batch = 4000 of 21497, loss=3.081, LR=0.0006545084971874737
# Validation Loss = 0.111
# Epoch=3, batch = 5000 of 21497, loss=2.335, LR=0.0006545084971874737
# Validation Loss = 0.116
# Epoch=3, batch = 6000 of 21497, loss=2.499, LR=0.0006545084971874737
# Validation Loss = 0.048
# Epoch=3, batch = 7000 of 21497, loss=3.225, LR=0.0006545084971874737
# Validation Loss = 0.059
# Epoch=3, batch = 8000 of 21497, loss=2.952, LR=0.0006545084971874737
# Validation Loss = 0.291
# Epoch=3, batch = 9000 of 21497, loss=3.208, LR=0.0006545084971874737
# Validation Loss = 0.361
# Epoch=3, batch = 10000 of 21497, loss=2.628, LR=0.0006545084971874737
# Validation Loss = 0.632
# Epoch=3, batch = 11000 of 21497, loss=2.866, LR=0.0006545084971874737
# Validation Loss = 0.200
# Epoch=3, batch = 12000 of 21497, loss=2.639, LR=0.0006545084971874737
# Validation Loss = 0.040
# Epoch=3, batch = 13000 of 21497, loss=2.344, LR=0.0006545084971874737
# Validation Loss = 0.068
# Epoch=3, batch = 14000 of 21497, loss=3.244, LR=0.0006545084971874737
# Validation Loss = 0.357
# Epoch=3, batch = 15000 of 21497, loss=3.740, LR=0.0006545084971874737
# Validation Loss = 0.022
# Epoch=3, batch = 16000 of 21497, loss=2.617, LR=0.0006545084971874737
# Validation Loss = 1.815
# Epoch=3, batch = 17000 of 21497, loss=2.731, LR=0.0006545084971874737
# Validation Loss = 0.297
# Epoch=3, batch = 18000 of 21497, loss=2.489, LR=0.0006545084971874737
# Validation Loss = 0.158
# Epoch=3, batch = 19000 of 21497, loss=2.773, LR=0.0006545084971874737
# Validation Loss = 0.021
# Epoch=3, batch = 20000 of 21497, loss=2.291, LR=0.0006545084971874737
# Validation Loss = 1.093
# Epoch=3, batch = 21000 of 21497, loss=2.998, LR=0.0006545084971874737
# Validation Loss = 0.878
# Epoch=4, batch = 0 of 21497, loss=2.500, LR=0.00034549150281252633
# Validation Loss = 0.049
# Epoch=4, batch = 1000 of 21497, loss=2.513, LR=0.00034549150281252633
# Validation Loss = 0.222
# Epoch=4, batch = 2000 of 21497, loss=2.413, LR=0.00034549150281252633
# Validation Loss = 0.415
# Epoch=4, batch = 3000 of 21497, loss=2.704, LR=0.00034549150281252633
# Validation Loss = 0.025
# Epoch=4, batch = 4000 of 21497, loss=3.006, LR=0.00034549150281252633
# Validation Loss = 0.478
# Epoch=4, batch = 5000 of 21497, loss=2.545, LR=0.00034549150281252633
# Validation Loss = 0.003
# Epoch=4, batch = 6000 of 21497, loss=2.819, LR=0.00034549150281252633
# Validation Loss = 0.126
# Epoch=4, batch = 7000 of 21497, loss=3.211, LR=0.00034549150281252633
# Validation Loss = 0.337
# Epoch=4, batch = 8000 of 21497, loss=2.471, LR=0.00034549150281252633
# Validation Loss = 0.000
# Epoch=4, batch = 9000 of 21497, loss=2.627, LR=0.00034549150281252633
# Validation Loss = 0.015
# Epoch=4, batch = 10000 of 21497, loss=3.020, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=4, batch = 11000 of 21497, loss=2.885, LR=0.00034549150281252633
# Validation Loss = 0.057
# Epoch=4, batch = 12000 of 21497, loss=2.292, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=4, batch = 13000 of 21497, loss=3.135, LR=0.00034549150281252633
# Validation Loss = 0.009
# Epoch=4, batch = 14000 of 21497, loss=2.204, LR=0.00034549150281252633
# Validation Loss = 0.929
# Epoch=4, batch = 15000 of 21497, loss=2.922, LR=0.00034549150281252633
# Validation Loss = 1.689
# Epoch=4, batch = 16000 of 21497, loss=2.889, LR=0.00034549150281252633
# Validation Loss = 0.002
# Epoch=4, batch = 17000 of 21497, loss=2.566, LR=0.00034549150281252633
# Validation Loss = 0.017
# Epoch=4, batch = 18000 of 21497, loss=2.298, LR=0.00034549150281252633
# Validation Loss = 0.152
# Epoch=4, batch = 19000 of 21497, loss=2.656, LR=0.00034549150281252633
# Validation Loss = 0.024
# Epoch=4, batch = 20000 of 21497, loss=2.537, LR=0.00034549150281252633
# Validation Loss = 0.681
# Epoch=4, batch = 21000 of 21497, loss=2.739, LR=0.00034549150281252633
# Validation Loss = 0.230
# Epoch=5, batch = 0 of 21497, loss=2.464, LR=9.549150281252633e-05
# Validation Loss = 0.212
# Epoch=5, batch = 1000 of 21497, loss=2.286, LR=9.549150281252633e-05
# Validation Loss = 0.161
# Epoch=5, batch = 2000 of 21497, loss=2.501, LR=9.549150281252633e-05
# Validation Loss = 0.091
# Epoch=5, batch = 3000 of 21497, loss=2.312, LR=9.549150281252633e-05
# Validation Loss = 0.131
# Epoch=5, batch = 4000 of 21497, loss=2.688, LR=9.549150281252633e-05
# Validation Loss = 0.016
# Epoch=5, batch = 5000 of 21497, loss=2.599, LR=9.549150281252633e-05
# Validation Loss = 0.046
# Epoch=5, batch = 6000 of 21497, loss=1.968, LR=9.549150281252633e-05
# Validation Loss = 0.003
# Epoch=5, batch = 7000 of 21497, loss=2.262, LR=9.549150281252633e-05
# Validation Loss = 0.106
# Epoch=5, batch = 8000 of 21497, loss=2.462, LR=9.549150281252633e-05
# Validation Loss = 0.270
# Epoch=5, batch = 9000 of 21497, loss=2.480, LR=9.549150281252633e-05
# Validation Loss = 0.144
# Epoch=5, batch = 10000 of 21497, loss=2.451, LR=9.549150281252633e-05
# Validation Loss = 0.185
# Epoch=5, batch = 11000 of 21497, loss=2.731, LR=9.549150281252633e-05
# Validation Loss = 0.019
# Epoch=5, batch = 12000 of 21497, loss=2.415, LR=9.549150281252633e-05
# Validation Loss = 0.409
# Epoch=5, batch = 13000 of 21497, loss=2.507, LR=9.549150281252633e-05
# Validation Loss = 0.001
# Epoch=5, batch = 14000 of 21497, loss=2.452, LR=9.549150281252633e-05
# Validation Loss = 0.040
# Epoch=5, batch = 15000 of 21497, loss=3.232, LR=9.549150281252633e-05
# Validation Loss = 0.001
# Epoch=5, batch = 16000 of 21497, loss=2.402, LR=9.549150281252633e-05
# Validation Loss = 0.011
# Epoch=5, batch = 17000 of 21497, loss=2.727, LR=9.549150281252633e-05
# Validation Loss = 0.031
# Epoch=5, batch = 18000 of 21497, loss=3.542, LR=9.549150281252633e-05
# Validation Loss = 0.030
# Epoch=5, batch = 19000 of 21497, loss=2.139, LR=9.549150281252633e-05
# Validation Loss = 0.083
# Epoch=5, batch = 20000 of 21497, loss=2.302, LR=9.549150281252633e-05
# Validation Loss = 0.250
# Epoch=5, batch = 21000 of 21497, loss=2.633, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.053
# Epoch=1, batch = 0 of 21497, loss=2.317, LR=0.001
# Validation Loss = 0.036
# Epoch=1, batch = 1000 of 21497, loss=3.270, LR=0.001
# Validation Loss = 1.523
# Epoch=1, batch = 2000 of 21497, loss=3.607, LR=0.001
# Validation Loss = 0.616
# Epoch=1, batch = 3000 of 21497, loss=3.537, LR=0.001
# Validation Loss = 0.212
# Epoch=1, batch = 4000 of 21497, loss=2.688, LR=0.001
# Validation Loss = 0.603
# Epoch=1, batch = 5000 of 21497, loss=2.801, LR=0.001
# Validation Loss = 0.031
# Epoch=1, batch = 6000 of 21497, loss=2.889, LR=0.001
# Validation Loss = 0.040
# Epoch=1, batch = 7000 of 21497, loss=3.497, LR=0.001
# Validation Loss = 0.011
# Epoch=1, batch = 8000 of 21497, loss=3.028, LR=0.001
# Validation Loss = 0.012
# Epoch=1, batch = 9000 of 21497, loss=2.907, LR=0.001
# Validation Loss = 0.719
# Epoch=1, batch = 10000 of 21497, loss=4.697, LR=0.001
# Validation Loss = 0.023
# Epoch=1, batch = 11000 of 21497, loss=2.444, LR=0.001
# Validation Loss = 1.303
# Epoch=1, batch = 12000 of 21497, loss=2.884, LR=0.001
# Validation Loss = 0.093
# Epoch=1, batch = 13000 of 21497, loss=2.578, LR=0.001
# Validation Loss = 0.322
# Epoch=1, batch = 14000 of 21497, loss=2.982, LR=0.001
# Validation Loss = 0.758
# Epoch=1, batch = 15000 of 21497, loss=3.482, LR=0.001
# Validation Loss = 0.835
# Epoch=1, batch = 16000 of 21497, loss=2.486, LR=0.001
# Validation Loss = 1.756
# Epoch=1, batch = 17000 of 21497, loss=3.458, LR=0.001
# Validation Loss = 0.020
# Epoch=1, batch = 18000 of 21497, loss=2.863, LR=0.001
# Validation Loss = 0.168
# Epoch=1, batch = 19000 of 21497, loss=2.948, LR=0.001
# Validation Loss = 0.750
# Epoch=1, batch = 20000 of 21497, loss=2.722, LR=0.001
# Validation Loss = 0.000
# Epoch=1, batch = 21000 of 21497, loss=2.648, LR=0.001
# Validation Loss = 0.164
# Epoch=2, batch = 0 of 21497, loss=2.334, LR=0.0009755282581475768
# Validation Loss = 0.080
# Epoch=2, batch = 1000 of 21497, loss=2.546, LR=0.0009755282581475768
# Validation Loss = 0.549
# Epoch=2, batch = 2000 of 21497, loss=3.896, LR=0.0009755282581475768
# Validation Loss = 1.764
# Epoch=2, batch = 3000 of 21497, loss=3.239, LR=0.0009755282581475768
# Validation Loss = 0.277
# Epoch=2, batch = 4000 of 21497, loss=3.294, LR=0.0009755282581475768
# Validation Loss = 1.916
# Epoch=2, batch = 5000 of 21497, loss=3.939, LR=0.0009755282581475768
# Validation Loss = 2.847
# Epoch=2, batch = 6000 of 21497, loss=3.750, LR=0.0009755282581475768
# Validation Loss = 0.147
# Epoch=2, batch = 7000 of 21497, loss=2.528, LR=0.0009755282581475768
# Validation Loss = 0.648
# Epoch=2, batch = 8000 of 21497, loss=2.955, LR=0.0009755282581475768
# Validation Loss = 0.773
# Epoch=2, batch = 9000 of 21497, loss=2.308, LR=0.0009755282581475768
# Validation Loss = 0.123
# Epoch=2, batch = 10000 of 21497, loss=3.265, LR=0.0009755282581475768
# Validation Loss = 1.432
# Epoch=2, batch = 11000 of 21497, loss=2.762, LR=0.0009755282581475768
# Validation Loss = 0.803
# Epoch=2, batch = 12000 of 21497, loss=3.340, LR=0.0009755282581475768
# Validation Loss = 0.597
# Epoch=2, batch = 13000 of 21497, loss=3.598, LR=0.0009755282581475768
# Validation Loss = 0.817
# Epoch=2, batch = 14000 of 21497, loss=2.957, LR=0.0009755282581475768
# Validation Loss = 0.428
# Epoch=2, batch = 15000 of 21497, loss=2.933, LR=0.0009755282581475768
# Validation Loss = 1.312
# Epoch=2, batch = 16000 of 21497, loss=3.201, LR=0.0009755282581475768
# Validation Loss = 0.727
# Epoch=2, batch = 17000 of 21497, loss=2.835, LR=0.0009755282581475768
# Validation Loss = 0.831
# Epoch=2, batch = 18000 of 21497, loss=2.572, LR=0.0009755282581475768
# Validation Loss = 0.005
# Epoch=2, batch = 19000 of 21497, loss=2.764, LR=0.0009755282581475768
# Validation Loss = 0.080
# Epoch=2, batch = 20000 of 21497, loss=2.543, LR=0.0009755282581475768
# Validation Loss = 0.273
# Epoch=2, batch = 21000 of 21497, loss=2.727, LR=0.0009755282581475768
# Validation Loss = 1.247
# Epoch=3, batch = 0 of 21497, loss=2.922, LR=0.0009045084971874736
# Validation Loss = 0.029
# Epoch=3, batch = 1000 of 21497, loss=3.120, LR=0.0009045084971874736
# Validation Loss = 0.093
# Epoch=3, batch = 2000 of 21497, loss=2.939, LR=0.0009045084971874736
# Validation Loss = 1.136
# Epoch=3, batch = 3000 of 21497, loss=2.683, LR=0.0009045084971874736
# Validation Loss = 0.145
# Epoch=3, batch = 4000 of 21497, loss=2.907, LR=0.0009045084971874736
# Validation Loss = 0.104
# Epoch=3, batch = 5000 of 21497, loss=2.489, LR=0.0009045084971874736
# Validation Loss = 0.536
# Epoch=3, batch = 6000 of 21497, loss=2.566, LR=0.0009045084971874736
# Validation Loss = 0.011
# Epoch=3, batch = 7000 of 21497, loss=2.378, LR=0.0009045084971874736
# Validation Loss = 0.069
# Epoch=3, batch = 8000 of 21497, loss=2.569, LR=0.0009045084971874736
# Validation Loss = 0.475
# Epoch=3, batch = 9000 of 21497, loss=3.333, LR=0.0009045084971874736
# Validation Loss = 0.970
# Epoch=3, batch = 10000 of 21497, loss=2.559, LR=0.0009045084971874736
# Validation Loss = 0.713
# Epoch=3, batch = 11000 of 21497, loss=2.608, LR=0.0009045084971874736
# Validation Loss = 0.231
# Epoch=3, batch = 12000 of 21497, loss=3.187, LR=0.0009045084971874736
# Validation Loss = 1.089
# Epoch=3, batch = 13000 of 21497, loss=2.806, LR=0.0009045084971874736
# Validation Loss = 0.081
# Epoch=3, batch = 14000 of 21497, loss=2.984, LR=0.0009045084971874736
# Validation Loss = 1.124
# Epoch=3, batch = 15000 of 21497, loss=2.476, LR=0.0009045084971874736
# Validation Loss = 0.039
# Epoch=3, batch = 16000 of 21497, loss=3.051, LR=0.0009045084971874736
# Validation Loss = 0.319
# Epoch=3, batch = 17000 of 21497, loss=2.965, LR=0.0009045084971874736
# Validation Loss = 1.119
# Epoch=3, batch = 18000 of 21497, loss=3.387, LR=0.0009045084971874736
# Validation Loss = 0.532
# Epoch=3, batch = 19000 of 21497, loss=2.951, LR=0.0009045084971874736
# Validation Loss = 0.081
# Epoch=3, batch = 20000 of 21497, loss=2.647, LR=0.0009045084971874736
# Validation Loss = 0.891
# Epoch=3, batch = 21000 of 21497, loss=2.915, LR=0.0009045084971874736
# Validation Loss = 0.124
# Epoch=4, batch = 0 of 21497, loss=3.805, LR=0.0007938926261462366
# Validation Loss = 0.095
# Epoch=4, batch = 1000 of 21497, loss=2.480, LR=0.0007938926261462366
# Validation Loss = 0.133
# Epoch=4, batch = 2000 of 21497, loss=2.672, LR=0.0007938926261462366
# Validation Loss = 3.708
# Epoch=4, batch = 3000 of 21497, loss=4.122, LR=0.0007938926261462366
# Validation Loss = 0.663
# Epoch=4, batch = 4000 of 21497, loss=2.477, LR=0.0007938926261462366
# Validation Loss = 0.093
# Epoch=4, batch = 5000 of 21497, loss=2.537, LR=0.0007938926261462366
# Validation Loss = 0.000
# Epoch=4, batch = 6000 of 21497, loss=2.262, LR=0.0007938926261462366
# Validation Loss = 0.233
# Epoch=4, batch = 7000 of 21497, loss=2.388, LR=0.0007938926261462366
# Validation Loss = 0.003
# Epoch=4, batch = 8000 of 21497, loss=2.341, LR=0.0007938926261462366
# Validation Loss = 0.367
# Epoch=4, batch = 9000 of 21497, loss=3.955, LR=0.0007938926261462366
# Validation Loss = 0.125
# Epoch=4, batch = 10000 of 21497, loss=3.761, LR=0.0007938926261462366
# Validation Loss = 0.888
# Epoch=4, batch = 11000 of 21497, loss=2.526, LR=0.0007938926261462366
# Validation Loss = 0.065
# Epoch=4, batch = 12000 of 21497, loss=2.635, LR=0.0007938926261462366
# Validation Loss = 1.083
# Epoch=4, batch = 13000 of 21497, loss=3.108, LR=0.0007938926261462366
# Validation Loss = 0.313
# Epoch=4, batch = 14000 of 21497, loss=3.348, LR=0.0007938926261462366
# Validation Loss = 0.011
# Epoch=4, batch = 15000 of 21497, loss=3.027, LR=0.0007938926261462366
# Validation Loss = 0.448
# Epoch=4, batch = 16000 of 21497, loss=2.815, LR=0.0007938926261462366
# Validation Loss = 0.040
# Epoch=4, batch = 17000 of 21497, loss=2.920, LR=0.0007938926261462366
# Validation Loss = 0.106
# Epoch=4, batch = 18000 of 21497, loss=2.457, LR=0.0007938926261462366
# Validation Loss = 0.211
# Epoch=4, batch = 19000 of 21497, loss=2.848, LR=0.0007938926261462366
# Validation Loss = 0.772
# Epoch=4, batch = 20000 of 21497, loss=3.288, LR=0.0007938926261462366
# Validation Loss = 0.021
# Epoch=4, batch = 21000 of 21497, loss=2.542, LR=0.0007938926261462366
# Validation Loss = 0.588
# Epoch=5, batch = 0 of 21497, loss=2.627, LR=0.0006545084971874737
# Validation Loss = 0.188
# Epoch=5, batch = 1000 of 21497, loss=2.709, LR=0.0006545084971874737
# Validation Loss = 0.177
# Epoch=5, batch = 2000 of 21497, loss=3.063, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=5, batch = 3000 of 21497, loss=2.603, LR=0.0006545084971874737
# Validation Loss = 0.633
# Epoch=5, batch = 4000 of 21497, loss=2.696, LR=0.0006545084971874737
# Validation Loss = 0.652
# Epoch=5, batch = 5000 of 21497, loss=2.496, LR=0.0006545084971874737
# Validation Loss = 0.034
# Epoch=5, batch = 6000 of 21497, loss=2.954, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=5, batch = 7000 of 21497, loss=2.836, LR=0.0006545084971874737
# Validation Loss = 0.039
# Epoch=5, batch = 8000 of 21497, loss=3.313, LR=0.0006545084971874737
# Validation Loss = 0.026
# Epoch=5, batch = 9000 of 21497, loss=2.793, LR=0.0006545084971874737
# Validation Loss = 0.153
# Epoch=5, batch = 10000 of 21497, loss=2.484, LR=0.0006545084971874737
# Validation Loss = 0.309
# Epoch=5, batch = 11000 of 21497, loss=2.780, LR=0.0006545084971874737
# Validation Loss = 0.105
# Epoch=5, batch = 12000 of 21497, loss=2.150, LR=0.0006545084971874737
# Validation Loss = 0.309
# Epoch=5, batch = 13000 of 21497, loss=3.494, LR=0.0006545084971874737
# Validation Loss = 0.154
# Epoch=5, batch = 14000 of 21497, loss=2.529, LR=0.0006545084971874737
# Validation Loss = 0.026
# Epoch=5, batch = 15000 of 21497, loss=2.342, LR=0.0006545084971874737
# Validation Loss = 0.025
# Epoch=5, batch = 16000 of 21497, loss=2.917, LR=0.0006545084971874737
# Validation Loss = 1.415
# Epoch=5, batch = 17000 of 21497, loss=2.902, LR=0.0006545084971874737
# Validation Loss = 0.293
# Epoch=5, batch = 18000 of 21497, loss=2.923, LR=0.0006545084971874737
# Validation Loss = 0.435
# Epoch=5, batch = 19000 of 21497, loss=2.421, LR=0.0006545084971874737
# Validation Loss = 0.601
# Epoch=5, batch = 20000 of 21497, loss=2.676, LR=0.0006545084971874737
# Validation Loss = 0.136
# Epoch=5, batch = 21000 of 21497, loss=2.824, LR=0.0006545084971874737
# Validation Loss = 0.016
# Epoch=6, batch = 0 of 21497, loss=2.803, LR=0.0005
# Validation Loss = 0.065
# Epoch=6, batch = 1000 of 21497, loss=3.089, LR=0.0005
# Validation Loss = 0.992
# Epoch=6, batch = 2000 of 21497, loss=2.716, LR=0.0005
# Validation Loss = 0.385
# Epoch=6, batch = 3000 of 21497, loss=2.182, LR=0.0005
# Validation Loss = 0.143
# Epoch=6, batch = 4000 of 21497, loss=2.887, LR=0.0005
# Validation Loss = 0.753
# Epoch=6, batch = 5000 of 21497, loss=2.992, LR=0.0005
# Validation Loss = 0.250
# Epoch=6, batch = 6000 of 21497, loss=2.598, LR=0.0005
# Validation Loss = 0.260
# Epoch=6, batch = 7000 of 21497, loss=2.192, LR=0.0005
# Validation Loss = 0.024
# Epoch=6, batch = 8000 of 21497, loss=2.669, LR=0.0005
# Validation Loss = 0.038
# Epoch=6, batch = 9000 of 21497, loss=2.979, LR=0.0005
# Validation Loss = 0.071
# Epoch=6, batch = 10000 of 21497, loss=2.390, LR=0.0005
# Validation Loss = 0.036
# Epoch=6, batch = 11000 of 21497, loss=2.298, LR=0.0005
# Validation Loss = 0.095
# Epoch=6, batch = 12000 of 21497, loss=2.315, LR=0.0005
# Validation Loss = 1.792
# Epoch=6, batch = 13000 of 21497, loss=2.810, LR=0.0005
# Validation Loss = 0.260
# Epoch=6, batch = 14000 of 21497, loss=2.358, LR=0.0005
# Validation Loss = 1.218
# Epoch=6, batch = 15000 of 21497, loss=2.925, LR=0.0005
# Validation Loss = 0.198
# Epoch=6, batch = 16000 of 21497, loss=2.743, LR=0.0005
# Validation Loss = 0.113
# Epoch=6, batch = 17000 of 21497, loss=2.682, LR=0.0005
# Validation Loss = 0.027
# Epoch=6, batch = 18000 of 21497, loss=2.462, LR=0.0005
# Validation Loss = 0.099
# Epoch=6, batch = 19000 of 21497, loss=2.952, LR=0.0005
# Validation Loss = 0.393
# Epoch=6, batch = 20000 of 21497, loss=2.438, LR=0.0005
# Validation Loss = 0.701
# Epoch=6, batch = 21000 of 21497, loss=2.498, LR=0.0005
# Validation Loss = 0.071
# Epoch=7, batch = 0 of 21497, loss=2.096, LR=0.00034549150281252633
# Validation Loss = 0.074
# Epoch=7, batch = 1000 of 21497, loss=2.392, LR=0.00034549150281252633
# Validation Loss = 0.049
# Epoch=7, batch = 2000 of 21497, loss=2.330, LR=0.00034549150281252633
# Validation Loss = 0.189
# Epoch=7, batch = 3000 of 21497, loss=2.508, LR=0.00034549150281252633
# Validation Loss = 0.573
# Epoch=7, batch = 4000 of 21497, loss=2.477, LR=0.00034549150281252633
# Validation Loss = 0.006
# Epoch=7, batch = 5000 of 21497, loss=2.868, LR=0.00034549150281252633
# Validation Loss = 0.744
# Epoch=7, batch = 6000 of 21497, loss=2.648, LR=0.00034549150281252633
# Validation Loss = 0.255
# Epoch=7, batch = 7000 of 21497, loss=2.332, LR=0.00034549150281252633
# Validation Loss = 0.062
# Epoch=7, batch = 8000 of 21497, loss=2.160, LR=0.00034549150281252633
# Validation Loss = 0.108
# Epoch=7, batch = 9000 of 21497, loss=1.982, LR=0.00034549150281252633
# Validation Loss = 0.118
# Epoch=7, batch = 10000 of 21497, loss=2.827, LR=0.00034549150281252633
# Validation Loss = 0.436
# Epoch=7, batch = 11000 of 21497, loss=2.441, LR=0.00034549150281252633
# Validation Loss = 0.081
# Epoch=7, batch = 12000 of 21497, loss=2.796, LR=0.00034549150281252633
# Validation Loss = 0.705
# Epoch=7, batch = 13000 of 21497, loss=2.238, LR=0.00034549150281252633
# Validation Loss = 0.474
# Epoch=7, batch = 14000 of 21497, loss=3.471, LR=0.00034549150281252633
# Validation Loss = 0.098
# Epoch=7, batch = 15000 of 21497, loss=2.446, LR=0.00034549150281252633
# Validation Loss = 0.170
# Epoch=7, batch = 16000 of 21497, loss=2.719, LR=0.00034549150281252633
# Validation Loss = 0.068
# Epoch=7, batch = 17000 of 21497, loss=2.615, LR=0.00034549150281252633
# Validation Loss = 0.135
# Epoch=7, batch = 18000 of 21497, loss=2.380, LR=0.00034549150281252633
# Validation Loss = 0.044
# Epoch=7, batch = 19000 of 21497, loss=2.209, LR=0.00034549150281252633
# Validation Loss = 0.297
# Epoch=7, batch = 20000 of 21497, loss=2.768, LR=0.00034549150281252633
# Validation Loss = 1.066
# Epoch=7, batch = 21000 of 21497, loss=2.400, LR=0.00034549150281252633
# Validation Loss = 0.025
# Epoch=8, batch = 0 of 21497, loss=2.299, LR=0.0002061073738537635
# Validation Loss = 0.875
# Epoch=8, batch = 1000 of 21497, loss=2.360, LR=0.0002061073738537635
# Validation Loss = 0.337
# Epoch=8, batch = 2000 of 21497, loss=2.232, LR=0.0002061073738537635
# Validation Loss = 0.189
# Epoch=8, batch = 3000 of 21497, loss=3.174, LR=0.0002061073738537635
# Validation Loss = 0.218
# Epoch=8, batch = 4000 of 21497, loss=2.432, LR=0.0002061073738537635
# Validation Loss = 0.590
# Epoch=8, batch = 5000 of 21497, loss=2.075, LR=0.0002061073738537635
# Validation Loss = 0.709
# Epoch=8, batch = 6000 of 21497, loss=2.667, LR=0.0002061073738537635
# Validation Loss = 0.196
# Epoch=8, batch = 7000 of 21497, loss=2.316, LR=0.0002061073738537635
# Validation Loss = 0.081
# Epoch=8, batch = 8000 of 21497, loss=2.806, LR=0.0002061073738537635
# Validation Loss = 0.225
# Epoch=8, batch = 9000 of 21497, loss=2.397, LR=0.0002061073738537635
# Validation Loss = 0.056
# Epoch=8, batch = 10000 of 21497, loss=2.700, LR=0.0002061073738537635
# Validation Loss = 0.002
# Epoch=8, batch = 11000 of 21497, loss=2.477, LR=0.0002061073738537635
# Validation Loss = 0.111
# Epoch=8, batch = 12000 of 21497, loss=2.504, LR=0.0002061073738537635
# Validation Loss = 0.019
# Epoch=8, batch = 13000 of 21497, loss=2.203, LR=0.0002061073738537635
# Validation Loss = 0.187
# Epoch=8, batch = 14000 of 21497, loss=2.138, LR=0.0002061073738537635
# Validation Loss = 0.097
# Epoch=8, batch = 15000 of 21497, loss=2.618, LR=0.0002061073738537635
# Validation Loss = 0.334
# Epoch=8, batch = 16000 of 21497, loss=2.757, LR=0.0002061073738537635
# Validation Loss = 0.061
# Epoch=8, batch = 17000 of 21497, loss=2.169, LR=0.0002061073738537635
# Validation Loss = 0.303
# Epoch=8, batch = 18000 of 21497, loss=2.362, LR=0.0002061073738537635
# Validation Loss = 0.513
# Epoch=8, batch = 19000 of 21497, loss=2.283, LR=0.0002061073738537635
# Validation Loss = 0.374
# Epoch=8, batch = 20000 of 21497, loss=2.851, LR=0.0002061073738537635
# Validation Loss = 0.198
# Epoch=8, batch = 21000 of 21497, loss=2.621, LR=0.0002061073738537635
# Validation Loss = 0.001
# Epoch=9, batch = 0 of 21497, loss=3.576, LR=9.549150281252634e-05
# Validation Loss = 0.071
# Epoch=9, batch = 1000 of 21497, loss=2.977, LR=9.549150281252634e-05
# Validation Loss = 0.272
# Epoch=9, batch = 2000 of 21497, loss=2.125, LR=9.549150281252634e-05
# Validation Loss = 0.091
# Epoch=9, batch = 3000 of 21497, loss=2.285, LR=9.549150281252634e-05
# Validation Loss = 0.139
# Epoch=9, batch = 4000 of 21497, loss=2.411, LR=9.549150281252634e-05
# Validation Loss = 0.146
# Epoch=9, batch = 5000 of 21497, loss=2.670, LR=9.549150281252634e-05
# Validation Loss = 0.291
# Epoch=9, batch = 6000 of 21497, loss=2.299, LR=9.549150281252634e-05
# Validation Loss = 0.304
# Epoch=9, batch = 7000 of 21497, loss=2.458, LR=9.549150281252634e-05
# Validation Loss = 0.347
# Epoch=9, batch = 8000 of 21497, loss=2.540, LR=9.549150281252634e-05
# Validation Loss = 0.116
# Epoch=9, batch = 9000 of 21497, loss=2.214, LR=9.549150281252634e-05
# Validation Loss = 0.097
# Epoch=9, batch = 10000 of 21497, loss=2.332, LR=9.549150281252634e-05
# Validation Loss = 0.066
# Epoch=9, batch = 11000 of 21497, loss=2.564, LR=9.549150281252634e-05
# Validation Loss = 0.213
# Epoch=9, batch = 12000 of 21497, loss=2.544, LR=9.549150281252634e-05
# Validation Loss = 0.297
# Epoch=9, batch = 13000 of 21497, loss=2.646, LR=9.549150281252634e-05
# Validation Loss = 0.031
# Epoch=9, batch = 14000 of 21497, loss=2.361, LR=9.549150281252634e-05
# Validation Loss = 0.149
# Epoch=9, batch = 15000 of 21497, loss=2.373, LR=9.549150281252634e-05
# Validation Loss = 0.159
# Epoch=9, batch = 16000 of 21497, loss=2.592, LR=9.549150281252634e-05
# Validation Loss = 0.159
# Epoch=9, batch = 17000 of 21497, loss=2.466, LR=9.549150281252634e-05
# Validation Loss = 0.055
# Epoch=9, batch = 18000 of 21497, loss=2.979, LR=9.549150281252634e-05
# Validation Loss = 0.100
# Epoch=9, batch = 19000 of 21497, loss=2.129, LR=9.549150281252634e-05
# Validation Loss = 0.093
# Epoch=9, batch = 20000 of 21497, loss=2.068, LR=9.549150281252634e-05
# Validation Loss = 0.043
# Epoch=9, batch = 21000 of 21497, loss=2.221, LR=9.549150281252634e-05
# Validation Loss = 0.187
# Epoch=10, batch = 0 of 21497, loss=2.231, LR=2.4471741852423235e-05
# Validation Loss = 0.192
# Epoch=10, batch = 1000 of 21497, loss=2.420, LR=2.4471741852423235e-05
# Validation Loss = 0.153
# Epoch=10, batch = 2000 of 21497, loss=2.682, LR=2.4471741852423235e-05
# Validation Loss = 0.117
# Epoch=10, batch = 3000 of 21497, loss=1.969, LR=2.4471741852423235e-05
# Validation Loss = 0.076
# Epoch=10, batch = 4000 of 21497, loss=2.268, LR=2.4471741852423235e-05
# Validation Loss = 0.037
# Epoch=10, batch = 5000 of 21497, loss=2.159, LR=2.4471741852423235e-05
# Validation Loss = 0.207
# Epoch=10, batch = 6000 of 21497, loss=2.366, LR=2.4471741852423235e-05
# Validation Loss = 0.195
# Epoch=10, batch = 7000 of 21497, loss=2.205, LR=2.4471741852423235e-05
# Validation Loss = 0.036
# Epoch=10, batch = 8000 of 21497, loss=2.528, LR=2.4471741852423235e-05
# Validation Loss = 0.049
# Epoch=10, batch = 9000 of 21497, loss=2.880, LR=2.4471741852423235e-05
# Validation Loss = 0.305
# Epoch=10, batch = 10000 of 21497, loss=2.581, LR=2.4471741852423235e-05
# Validation Loss = 0.034
# Epoch=10, batch = 11000 of 21497, loss=2.189, LR=2.4471741852423235e-05
# Validation Loss = 0.134
# Epoch=10, batch = 12000 of 21497, loss=1.977, LR=2.4471741852423235e-05
# Validation Loss = 0.217
# Epoch=10, batch = 13000 of 21497, loss=2.536, LR=2.4471741852423235e-05
# Validation Loss = 0.109
# Epoch=10, batch = 14000 of 21497, loss=2.500, LR=2.4471741852423235e-05
# Validation Loss = 0.094
# Epoch=10, batch = 15000 of 21497, loss=2.464, LR=2.4471741852423235e-05
# Validation Loss = 0.015
# Epoch=10, batch = 16000 of 21497, loss=2.390, LR=2.4471741852423235e-05
# Validation Loss = 0.112
# Epoch=10, batch = 17000 of 21497, loss=2.235, LR=2.4471741852423235e-05
# Validation Loss = 0.145
# Epoch=10, batch = 18000 of 21497, loss=2.244, LR=2.4471741852423235e-05
# Validation Loss = 0.157
# Epoch=10, batch = 19000 of 21497, loss=1.928, LR=2.4471741852423235e-05
# Validation Loss = 0.102
# Epoch=10, batch = 20000 of 21497, loss=2.096, LR=2.4471741852423235e-05
# Validation Loss = 0.216
# Epoch=10, batch = 21000 of 21497, loss=2.989, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.123
# Epoch=1, batch = 0 of 21497, loss=2.328, LR=0.001
# Validation Loss = 0.043
# Epoch=1, batch = 1000 of 21497, loss=2.618, LR=0.001
# Validation Loss = 0.344
# Epoch=1, batch = 2000 of 21497, loss=2.449, LR=0.001
# Validation Loss = 1.563
# Epoch=1, batch = 3000 of 21497, loss=2.424, LR=0.001
# Validation Loss = 1.071
# Epoch=1, batch = 4000 of 21497, loss=4.401, LR=0.001
# Validation Loss = 1.260
# Epoch=1, batch = 5000 of 21497, loss=2.659, LR=0.001
# Validation Loss = 0.802
# Epoch=1, batch = 6000 of 21497, loss=2.650, LR=0.001
# Validation Loss = 0.536
# Epoch=1, batch = 7000 of 21497, loss=2.721, LR=0.001
# Validation Loss = 0.349
# Epoch=1, batch = 8000 of 21497, loss=2.988, LR=0.001
# Validation Loss = 0.576
# Epoch=1, batch = 9000 of 21497, loss=2.802, LR=0.001
# Validation Loss = 0.532
# Epoch=1, batch = 10000 of 21497, loss=2.416, LR=0.001
# Validation Loss = 0.007
# Epoch=1, batch = 11000 of 21497, loss=2.657, LR=0.001
# Validation Loss = 1.120
# Epoch=1, batch = 12000 of 21497, loss=3.109, LR=0.001
# Validation Loss = 0.071
# Epoch=1, batch = 13000 of 21497, loss=2.300, LR=0.001
# Validation Loss = 0.176
# Epoch=1, batch = 14000 of 21497, loss=2.874, LR=0.001
# Validation Loss = 0.488
# Epoch=1, batch = 15000 of 21497, loss=2.269, LR=0.001
# Validation Loss = 0.025
# Epoch=1, batch = 16000 of 21497, loss=2.148, LR=0.001
# Validation Loss = 0.173
# Epoch=1, batch = 17000 of 21497, loss=2.575, LR=0.001
# Validation Loss = 0.914
# Epoch=1, batch = 18000 of 21497, loss=3.065, LR=0.001
# Validation Loss = 0.383
# Epoch=1, batch = 19000 of 21497, loss=2.351, LR=0.001
# Validation Loss = 0.112
# Epoch=1, batch = 20000 of 21497, loss=2.748, LR=0.001
# Validation Loss = 0.404
# Epoch=1, batch = 21000 of 21497, loss=2.614, LR=0.001
# Validation Loss = 0.397
# Epoch=2, batch = 0 of 21497, loss=2.502, LR=0.0009938441702975688
# Validation Loss = 0.001
# Epoch=2, batch = 1000 of 21497, loss=2.971, LR=0.0009938441702975688
# Validation Loss = 0.010
# Epoch=2, batch = 2000 of 21497, loss=2.571, LR=0.0009938441702975688
# Validation Loss = 0.777
# Epoch=2, batch = 3000 of 21497, loss=3.245, LR=0.0009938441702975688
# Validation Loss = 0.000
# Epoch=2, batch = 4000 of 21497, loss=2.800, LR=0.0009938441702975688
# Validation Loss = 0.049
# Epoch=2, batch = 5000 of 21497, loss=2.884, LR=0.0009938441702975688
# Validation Loss = 0.407
# Epoch=2, batch = 6000 of 21497, loss=2.765, LR=0.0009938441702975688
# Validation Loss = 1.574
# Epoch=2, batch = 7000 of 21497, loss=2.334, LR=0.0009938441702975688
# Validation Loss = 0.517
# Epoch=2, batch = 8000 of 21497, loss=2.583, LR=0.0009938441702975688
# Validation Loss = 0.634
# Epoch=2, batch = 9000 of 21497, loss=2.316, LR=0.0009938441702975688
# Validation Loss = 1.532
# Epoch=2, batch = 10000 of 21497, loss=3.341, LR=0.0009938441702975688
# Validation Loss = 0.073
# Epoch=2, batch = 11000 of 21497, loss=2.850, LR=0.0009938441702975688
# Validation Loss = 2.048
# Epoch=2, batch = 12000 of 21497, loss=3.651, LR=0.0009938441702975688
# Validation Loss = 0.329
# Epoch=2, batch = 13000 of 21497, loss=2.466, LR=0.0009938441702975688
# Validation Loss = 0.477
# Epoch=2, batch = 14000 of 21497, loss=2.794, LR=0.0009938441702975688
# Validation Loss = 0.248
# Epoch=2, batch = 15000 of 21497, loss=2.665, LR=0.0009938441702975688
# Validation Loss = 0.067
# Epoch=2, batch = 16000 of 21497, loss=2.783, LR=0.0009938441702975688
# Validation Loss = 0.025
# Epoch=2, batch = 17000 of 21497, loss=2.395, LR=0.0009938441702975688
# Validation Loss = 0.201
# Epoch=2, batch = 18000 of 21497, loss=2.489, LR=0.0009938441702975688
# Validation Loss = 2.876
# Epoch=2, batch = 19000 of 21497, loss=3.513, LR=0.0009938441702975688
# Validation Loss = 1.703
# Epoch=2, batch = 20000 of 21497, loss=2.556, LR=0.0009938441702975688
# Validation Loss = 0.550
# Epoch=2, batch = 21000 of 21497, loss=2.132, LR=0.0009938441702975688
# Validation Loss = 0.306
# Epoch=3, batch = 0 of 21497, loss=2.494, LR=0.0009755282581475768
# Validation Loss = 0.365
# Epoch=3, batch = 1000 of 21497, loss=3.075, LR=0.0009755282581475768
# Validation Loss = 0.066
# Epoch=3, batch = 2000 of 21497, loss=2.578, LR=0.0009755282581475768
# Validation Loss = 0.078
# Epoch=3, batch = 3000 of 21497, loss=2.317, LR=0.0009755282581475768
# Validation Loss = 4.316
# Epoch=3, batch = 4000 of 21497, loss=3.902, LR=0.0009755282581475768
# Validation Loss = 0.571
# Epoch=3, batch = 5000 of 21497, loss=3.089, LR=0.0009755282581475768
# Validation Loss = 0.972
# Epoch=3, batch = 6000 of 21497, loss=2.430, LR=0.0009755282581475768
# Validation Loss = 0.236
# Epoch=3, batch = 7000 of 21497, loss=2.158, LR=0.0009755282581475768
# Validation Loss = 0.126
# Epoch=3, batch = 8000 of 21497, loss=2.502, LR=0.0009755282581475768
# Validation Loss = 0.845
# Epoch=3, batch = 9000 of 21497, loss=2.457, LR=0.0009755282581475768
# Validation Loss = 0.845
# Epoch=3, batch = 10000 of 21497, loss=2.497, LR=0.0009755282581475768
# Validation Loss = 0.130
# Epoch=3, batch = 11000 of 21497, loss=2.150, LR=0.0009755282581475768
# Validation Loss = 0.101
# Epoch=3, batch = 12000 of 21497, loss=2.911, LR=0.0009755282581475768
# Validation Loss = 0.678
# Epoch=3, batch = 13000 of 21497, loss=2.304, LR=0.0009755282581475768
# Validation Loss = 0.721
# Epoch=3, batch = 14000 of 21497, loss=4.107, LR=0.0009755282581475768
# Validation Loss = 0.263
# Epoch=3, batch = 15000 of 21497, loss=2.464, LR=0.0009755282581475768
# Validation Loss = 0.249
# Epoch=3, batch = 16000 of 21497, loss=2.774, LR=0.0009755282581475768
# Validation Loss = 0.463
# Epoch=3, batch = 17000 of 21497, loss=3.330, LR=0.0009755282581475768
# Validation Loss = 0.014
# Epoch=3, batch = 18000 of 21497, loss=3.309, LR=0.0009755282581475768
# Validation Loss = 0.623
# Epoch=3, batch = 19000 of 21497, loss=3.215, LR=0.0009755282581475768
# Validation Loss = 0.799
# Epoch=3, batch = 20000 of 21497, loss=3.240, LR=0.0009755282581475768
# Validation Loss = 0.084
# Epoch=3, batch = 21000 of 21497, loss=3.034, LR=0.0009755282581475768
# Validation Loss = 0.023
# Epoch=4, batch = 0 of 21497, loss=2.334, LR=0.0009455032620941839
# Validation Loss = 0.042
# Epoch=4, batch = 1000 of 21497, loss=3.289, LR=0.0009455032620941839
# Validation Loss = 0.084
# Epoch=4, batch = 2000 of 21497, loss=3.031, LR=0.0009455032620941839
# Validation Loss = 0.204
# Epoch=4, batch = 3000 of 21497, loss=2.218, LR=0.0009455032620941839
# Validation Loss = 0.162
# Epoch=4, batch = 4000 of 21497, loss=2.522, LR=0.0009455032620941839
# Validation Loss = 0.010
# Epoch=4, batch = 5000 of 21497, loss=2.626, LR=0.0009455032620941839
# Validation Loss = 0.138
# Epoch=4, batch = 6000 of 21497, loss=2.591, LR=0.0009455032620941839
# Validation Loss = 0.561
# Epoch=4, batch = 7000 of 21497, loss=2.219, LR=0.0009455032620941839
# Validation Loss = 0.345
# Epoch=4, batch = 8000 of 21497, loss=2.251, LR=0.0009455032620941839
# Validation Loss = 0.182
# Epoch=4, batch = 9000 of 21497, loss=2.446, LR=0.0009455032620941839
# Validation Loss = 0.644
# Epoch=4, batch = 10000 of 21497, loss=2.680, LR=0.0009455032620941839
# Validation Loss = 0.026
# Epoch=4, batch = 11000 of 21497, loss=2.265, LR=0.0009455032620941839
# Validation Loss = 0.526
# Epoch=4, batch = 12000 of 21497, loss=2.206, LR=0.0009455032620941839
# Validation Loss = 0.323
# Epoch=4, batch = 13000 of 21497, loss=2.816, LR=0.0009455032620941839
# Validation Loss = 0.189
# Epoch=4, batch = 14000 of 21497, loss=2.940, LR=0.0009455032620941839
# Validation Loss = 0.108
# Epoch=4, batch = 15000 of 21497, loss=2.395, LR=0.0009455032620941839
# Validation Loss = 0.122
# Epoch=5, batch = 3000 of 21497, loss=2.474, LR=0.0009045084971874737
# Validation Loss = 0.985
# Epoch=5, batch = 4000 of 21497, loss=3.431, LR=0.0009045084971874737
# Validation Loss = 0.101
# Epoch=5, batch = 5000 of 21497, loss=2.275, LR=0.0009045084971874737
# Validation Loss = 0.167
# Epoch=5, batch = 6000 of 21497, loss=2.568, LR=0.0009045084971874737
# Validation Loss = 0.007
# Epoch=5, batch = 7000 of 21497, loss=2.701, LR=0.0009045084971874737
# Validation Loss = 0.201
# Epoch=5, batch = 8000 of 21497, loss=2.801, LR=0.0009045084971874737
# Validation Loss = 0.336
# Epoch=5, batch = 9000 of 21497, loss=2.138, LR=0.0009045084971874737
# Validation Loss = 0.044
# Epoch=5, batch = 10000 of 21497, loss=2.555, LR=0.0009045084971874737
# Validation Loss = 0.063
# Epoch=5, batch = 11000 of 21497, loss=2.249, LR=0.0009045084971874737
# Validation Loss = 0.008
# Epoch=5, batch = 12000 of 21497, loss=2.827, LR=0.0009045084971874737
# Validation Loss = 0.013
# Epoch=5, batch = 13000 of 21497, loss=2.692, LR=0.0009045084971874737
# Validation Loss = 1.206
# Epoch=5, batch = 14000 of 21497, loss=2.680, LR=0.0009045084971874737
# Validation Loss = 0.666
# Epoch=5, batch = 15000 of 21497, loss=2.361, LR=0.0009045084971874737
# Validation Loss = 0.200
# Epoch=5, batch = 16000 of 21497, loss=2.082, LR=0.0009045084971874737
# Validation Loss = 0.000
# Epoch=5, batch = 17000 of 21497, loss=2.410, LR=0.0009045084971874737
# Validation Loss = 0.480
# Epoch=5, batch = 18000 of 21497, loss=2.808, LR=0.0009045084971874737
# Validation Loss = 0.207
# Epoch=5, batch = 19000 of 21497, loss=2.528, LR=0.0009045084971874737
# Validation Loss = 0.456
# Epoch=5, batch = 20000 of 21497, loss=2.395, LR=0.0009045084971874737
# Validation Loss = 0.049
# Epoch=5, batch = 21000 of 21497, loss=2.405, LR=0.0009045084971874737
# Validation Loss = 0.112
# Epoch=6, batch = 0 of 21497, loss=3.166, LR=0.0008535533905932737
# Validation Loss = 0.683
# Epoch=6, batch = 1000 of 21497, loss=3.140, LR=0.0008535533905932737
# Validation Loss = 0.342
# Epoch=6, batch = 2000 of 21497, loss=2.816, LR=0.0008535533905932737
# Validation Loss = 0.060
# Epoch=6, batch = 3000 of 21497, loss=2.438, LR=0.0008535533905932737
# Validation Loss = 0.175
# Epoch=6, batch = 4000 of 21497, loss=2.343, LR=0.0008535533905932737
# Validation Loss = 0.603
# Epoch=6, batch = 5000 of 21497, loss=2.821, LR=0.0008535533905932737
# Validation Loss = 0.479
# Epoch=6, batch = 6000 of 21497, loss=2.355, LR=0.0008535533905932737
# Validation Loss = 0.003
# Epoch=6, batch = 7000 of 21497, loss=2.456, LR=0.0008535533905932737
# Validation Loss = 0.544
# Epoch=6, batch = 8000 of 21497, loss=2.883, LR=0.0008535533905932737
# Validation Loss = 0.208
# Epoch=6, batch = 9000 of 21497, loss=2.593, LR=0.0008535533905932737
# Validation Loss = 0.025
# Epoch=6, batch = 10000 of 21497, loss=2.269, LR=0.0008535533905932737
# Validation Loss = 1.050
# Epoch=6, batch = 11000 of 21497, loss=2.962, LR=0.0008535533905932737
# Validation Loss = 0.343
# Epoch=6, batch = 12000 of 21497, loss=2.146, LR=0.0008535533905932737
# Validation Loss = 0.272
# Epoch=6, batch = 13000 of 21497, loss=2.712, LR=0.0008535533905932737
# Validation Loss = 0.006
# Epoch=6, batch = 14000 of 21497, loss=2.752, LR=0.0008535533905932737
# Validation Loss = 0.426
# Epoch=6, batch = 15000 of 21497, loss=2.454, LR=0.0008535533905932737
# Validation Loss = 0.049
# Epoch=6, batch = 16000 of 21497, loss=2.391, LR=0.0008535533905932737
# Validation Loss = 0.468
# Epoch=6, batch = 17000 of 21497, loss=3.078, LR=0.0008535533905932737
# Validation Loss = 0.122
# Epoch=6, batch = 18000 of 21497, loss=2.557, LR=0.0008535533905932737
# Validation Loss = 2.341
# Epoch=6, batch = 19000 of 21497, loss=2.524, LR=0.0008535533905932737
# Validation Loss = 0.160
# Epoch=6, batch = 20000 of 21497, loss=2.764, LR=0.0008535533905932737
# Validation Loss = 0.272
# Epoch=6, batch = 21000 of 21497, loss=2.280, LR=0.0008535533905932737
# Validation Loss = 0.003
# Epoch=7, batch = 0 of 21497, loss=2.238, LR=0.0007938926261462366
# Validation Loss = 0.078
# Epoch=7, batch = 1000 of 21497, loss=2.466, LR=0.0007938926261462366
# Validation Loss = 0.226
# Epoch=7, batch = 2000 of 21497, loss=2.734, LR=0.0007938926261462366
# Validation Loss = 0.072
# Epoch=7, batch = 3000 of 21497, loss=2.087, LR=0.0007938926261462366
# Validation Loss = 0.307
# Epoch=7, batch = 4000 of 21497, loss=2.408, LR=0.0007938926261462366
# Validation Loss = 0.025
# Epoch=7, batch = 5000 of 21497, loss=3.346, LR=0.0007938926261462366
# Validation Loss = 0.000
# Epoch=7, batch = 6000 of 21497, loss=2.487, LR=0.0007938926261462366
# Validation Loss = 0.674
# Epoch=7, batch = 7000 of 21497, loss=2.776, LR=0.0007938926261462366
# Validation Loss = 0.087
# Epoch=7, batch = 8000 of 21497, loss=2.500, LR=0.0007938926261462366
# Validation Loss = 0.432
# Epoch=7, batch = 9000 of 21497, loss=3.172, LR=0.0007938926261462366
# Validation Loss = 0.001
# Epoch=7, batch = 10000 of 21497, loss=2.892, LR=0.0007938926261462366
# Validation Loss = 0.014
# Epoch=7, batch = 11000 of 21497, loss=2.796, LR=0.0007938926261462366
# Validation Loss = 0.153
# Epoch=7, batch = 12000 of 21497, loss=2.351, LR=0.0007938926261462366
# Validation Loss = 0.627
# Epoch=7, batch = 13000 of 21497, loss=2.671, LR=0.0007938926261462366
# Validation Loss = 1.109
# Epoch=7, batch = 14000 of 21497, loss=2.747, LR=0.0007938926261462366
# Validation Loss = 0.047
# Epoch=7, batch = 15000 of 21497, loss=2.545, LR=0.0007938926261462366
# Validation Loss = 0.166
# Epoch=7, batch = 16000 of 21497, loss=2.847, LR=0.0007938926261462366
# Validation Loss = 0.246
# Epoch=7, batch = 17000 of 21497, loss=3.379, LR=0.0007938926261462366
# Validation Loss = 0.749
# Epoch=7, batch = 18000 of 21497, loss=2.221, LR=0.0007938926261462366
# Validation Loss = 0.581
# Epoch=7, batch = 19000 of 21497, loss=2.907, LR=0.0007938926261462366
# Validation Loss = 0.107
# Epoch=7, batch = 20000 of 21497, loss=3.461, LR=0.0007938926261462366
# Validation Loss = 0.096
# Epoch=7, batch = 21000 of 21497, loss=2.441, LR=0.0007938926261462366
# Validation Loss = 0.013
# Epoch=8, batch = 0 of 21497, loss=2.423, LR=0.0007269952498697733
# Validation Loss = 0.055
# Epoch=8, batch = 1000 of 21497, loss=2.489, LR=0.0007269952498697733
# Validation Loss = 0.379
# Epoch=8, batch = 2000 of 21497, loss=2.290, LR=0.0007269952498697733
# Validation Loss = 0.000
# Epoch=8, batch = 3000 of 21497, loss=2.373, LR=0.0007269952498697733
# Validation Loss = 0.451
# Epoch=8, batch = 4000 of 21497, loss=2.625, LR=0.0007269952498697733
# Validation Loss = 0.254
# Epoch=8, batch = 5000 of 21497, loss=2.468, LR=0.0007269952498697733
# Validation Loss = 2.083
# Epoch=8, batch = 6000 of 21497, loss=3.365, LR=0.0007269952498697733
# Validation Loss = 2.403
# Epoch=8, batch = 7000 of 21497, loss=3.527, LR=0.0007269952498697733
# Validation Loss = 0.007
# Epoch=8, batch = 8000 of 21497, loss=2.615, LR=0.0007269952498697733
# Validation Loss = 0.433
# Epoch=8, batch = 9000 of 21497, loss=2.607, LR=0.0007269952498697733
# Validation Loss = 0.053
# Epoch=8, batch = 10000 of 21497, loss=2.667, LR=0.0007269952498697733
# Validation Loss = 0.072
# Epoch=8, batch = 11000 of 21497, loss=2.521, LR=0.0007269952498697733
# Validation Loss = 0.043
# Epoch=8, batch = 12000 of 21497, loss=2.596, LR=0.0007269952498697733
# Validation Loss = 0.002
# Epoch=8, batch = 13000 of 21497, loss=2.027, LR=0.0007269952498697733
# Validation Loss = 0.008
# Epoch=8, batch = 14000 of 21497, loss=2.331, LR=0.0007269952498697733
# Validation Loss = 0.512
# Epoch=8, batch = 15000 of 21497, loss=2.449, LR=0.0007269952498697733
# Validation Loss = 0.426
# Epoch=8, batch = 16000 of 21497, loss=3.725, LR=0.0007269952498697733
# Validation Loss = 0.208
# Epoch=8, batch = 17000 of 21497, loss=2.292, LR=0.0007269952498697733
# Validation Loss = 0.040
# Epoch=8, batch = 18000 of 21497, loss=2.490, LR=0.0007269952498697733
# Validation Loss = 0.064
# Epoch=8, batch = 19000 of 21497, loss=2.189, LR=0.0007269952498697733
# Validation Loss = 0.890
# Epoch=8, batch = 20000 of 21497, loss=2.293, LR=0.0007269952498697733
# Validation Loss = 0.001
# Epoch=8, batch = 21000 of 21497, loss=2.526, LR=0.0007269952498697733
# Validation Loss = 0.003
# Epoch=9, batch = 0 of 21497, loss=2.468, LR=0.0006545084971874737
# Validation Loss = 0.832
# Epoch=9, batch = 1000 of 21497, loss=2.810, LR=0.0006545084971874737
# Validation Loss = 0.045
# Epoch=9, batch = 2000 of 21497, loss=2.269, LR=0.0006545084971874737
# Validation Loss = 0.050
# Epoch=9, batch = 3000 of 21497, loss=2.328, LR=0.0006545084971874737
# Validation Loss = 0.245
# Epoch=9, batch = 4000 of 21497, loss=2.187, LR=0.0006545084971874737
# Validation Loss = 0.037
# Epoch=9, batch = 5000 of 21497, loss=2.518, LR=0.0006545084971874737
# Validation Loss = 0.154
# Epoch=9, batch = 6000 of 21497, loss=2.697, LR=0.0006545084971874737
# Validation Loss = 0.034
# Epoch=9, batch = 7000 of 21497, loss=2.501, LR=0.0006545084971874737
# Validation Loss = 0.144
# Epoch=9, batch = 8000 of 21497, loss=2.284, LR=0.0006545084971874737
# Validation Loss = 0.452
# Epoch=9, batch = 9000 of 21497, loss=2.840, LR=0.0006545084971874737
# Validation Loss = 0.072
# Epoch=9, batch = 10000 of 21497, loss=2.008, LR=0.0006545084971874737
# Validation Loss = 0.313
# Epoch=9, batch = 11000 of 21497, loss=2.355, LR=0.0006545084971874737
# Validation Loss = 0.565
# Epoch=9, batch = 12000 of 21497, loss=2.804, LR=0.0006545084971874737
# Validation Loss = 0.358
# Epoch=9, batch = 13000 of 21497, loss=2.789, LR=0.0006545084971874737
# Validation Loss = 0.095
# Epoch=9, batch = 14000 of 21497, loss=2.448, LR=0.0006545084971874737
# Validation Loss = 0.127
# Epoch=9, batch = 15000 of 21497, loss=2.195, LR=0.0006545084971874737
# Validation Loss = 0.227
# Epoch=9, batch = 16000 of 21497, loss=2.141, LR=0.0006545084971874737
# Validation Loss = 0.175
# Epoch=9, batch = 17000 of 21497, loss=2.184, LR=0.0006545084971874737
# Validation Loss = 0.018
# Epoch=9, batch = 18000 of 21497, loss=2.636, LR=0.0006545084971874737
# Validation Loss = 0.462
# Epoch=9, batch = 19000 of 21497, loss=2.833, LR=0.0006545084971874737
# Validation Loss = 0.006
# Epoch=9, batch = 20000 of 21497, loss=2.290, LR=0.0006545084971874737
# Validation Loss = 0.152
# Epoch=9, batch = 21000 of 21497, loss=2.598, LR=0.0006545084971874737
# Validation Loss = 0.134
# Epoch=10, batch = 0 of 21497, loss=2.080, LR=0.0005782172325201155
# Validation Loss = 0.016
# Epoch=10, batch = 1000 of 21497, loss=3.196, LR=0.0005782172325201155
# Validation Loss = 0.385
# Epoch=10, batch = 2000 of 21497, loss=2.093, LR=0.0005782172325201155
# Validation Loss = 0.494
# Epoch=10, batch = 3000 of 21497, loss=2.326, LR=0.0005782172325201155
# Validation Loss = 0.473
# Epoch=10, batch = 4000 of 21497, loss=2.528, LR=0.0005782172325201155
# Validation Loss = 0.002
# Epoch=10, batch = 5000 of 21497, loss=2.437, LR=0.0005782172325201155
# Validation Loss = 0.244
# Epoch=10, batch = 6000 of 21497, loss=2.698, LR=0.0005782172325201155
# Validation Loss = 0.360
# ...
# Validation Loss = 0.608
# Epoch=4, batch = 16000 of 21497, loss=3.619, LR=0.0009455032620941839
# Validation Loss = 0.190
# Epoch=4, batch = 17000 of 21497, loss=3.653, LR=0.0009455032620941839
# Validation Loss = 2.486
# Epoch=4, batch = 18000 of 21497, loss=3.339, LR=0.0009455032620941839
# Validation Loss = 1.146
# Epoch=4, batch = 19000 of 21497, loss=3.297, LR=0.0009455032620941839
# Validation Loss = 3.511
# Epoch=4, batch = 20000 of 21497, loss=3.414, LR=0.0009455032620941839
# Validation Loss = 2.735
# Epoch=4, batch = 21000 of 21497, loss=3.145, LR=0.0009455032620941839
# Validation Loss = 3.468
# Epoch=5, batch = 0 of 21497, loss=3.636, LR=0.0009045084971874737
# Validation Loss = 1.284
# Epoch=5, batch = 1000 of 21497, loss=3.097, LR=0.0009045084971874737
# Validation Loss = 0.493
# Epoch=5, batch = 2000 of 21497, loss=3.656, LR=0.0009045084971874737
# Validation Loss = 1.770
# Epoch=5, batch = 3000 of 21497, loss=3.149, LR=0.0009045084971874737
# Validation Loss = 1.438
# Epoch=5, batch = 4000 of 21497, loss=3.068, LR=0.0009045084971874737
# Validation Loss = 1.848
# Epoch=5, batch = 5000 of 21497, loss=3.348, LR=0.0009045084971874737
# Validation Loss = 3.938
# Epoch=5, batch = 6000 of 21497, loss=3.429, LR=0.0009045084971874737
# Validation Loss = 2.091
# Epoch=5, batch = 7000 of 21497, loss=3.246, LR=0.0009045084971874737
# Validation Loss = 1.032
# Epoch=5, batch = 8000 of 21497, loss=3.361, LR=0.0009045084971874737
# Validation Loss = 1.462
# Epoch=5, batch = 9000 of 21497, loss=3.106, LR=0.0009045084971874737
# Validation Loss = 2.573
# Epoch=5, batch = 10000 of 21497, loss=3.240, LR=0.0009045084971874737
# Validation Loss = 2.182
# Epoch=5, batch = 11000 of 21497, loss=3.358, LR=0.0009045084971874737
# Validation Loss = 1.410
# Epoch=5, batch = 12000 of 21497, loss=3.146, LR=0.0009045084971874737
# Validation Loss = 1.419
# Epoch=5, batch = 13000 of 21497, loss=3.013, LR=0.0009045084971874737
# Validation Loss = 3.796
# Epoch=5, batch = 14000 of 21497, loss=3.903, LR=0.0009045084971874737
# Validation Loss = 1.719
# Epoch=5, batch = 15000 of 21497, loss=3.149, LR=0.0009045084971874737
# Validation Loss = 1.544
# Epoch=5, batch = 16000 of 21497, loss=3.005, LR=0.0009045084971874737
# Validation Loss = 1.435
# Epoch=5, batch = 17000 of 21497, loss=3.053, LR=0.0009045084971874737
# Validation Loss = 0.541
# Epoch=5, batch = 18000 of 21497, loss=3.440, LR=0.0009045084971874737
# Validation Loss = 0.951
# Epoch=5, batch = 19000 of 21497, loss=3.202, LR=0.0009045084971874737
# Validation Loss = 1.599
# Epoch=5, batch = 20000 of 21497, loss=3.205, LR=0.0009045084971874737
# Validation Loss = 1.933
# Epoch=5, batch = 21000 of 21497, loss=2.918, LR=0.0009045084971874737
# Validation Loss = 2.326
# Epoch=6, batch = 0 of 21497, loss=3.136, LR=0.0008535533905932737
# Validation Loss = 2.011
# Epoch=6, batch = 1000 of 21497, loss=3.333, LR=0.0008535533905932737
# Validation Loss = 1.694
# Epoch=6, batch = 2000 of 21497, loss=3.013, LR=0.0008535533905932737
# Validation Loss = 3.569
# Epoch=6, batch = 3000 of 21497, loss=3.481, LR=0.0008535533905932737
# Validation Loss = 2.729
# Epoch=6, batch = 4000 of 21497, loss=3.281, LR=0.0008535533905932737
# Validation Loss = 2.445
# Epoch=6, batch = 5000 of 21497, loss=3.384, LR=0.0008535533905932737
# Validation Loss = 1.881
# Epoch=6, batch = 6000 of 21497, loss=2.995, LR=0.0008535533905932737
# Validation Loss = 2.304
# Epoch=6, batch = 7000 of 21497, loss=3.308, LR=0.0008535533905932737
# Validation Loss = 2.456
# Epoch=6, batch = 8000 of 21497, loss=3.210, LR=0.0008535533905932737
# Validation Loss = 1.387
# Epoch=6, batch = 9000 of 21497, loss=3.176, LR=0.0008535533905932737
# Validation Loss = 0.529
# Epoch=6, batch = 10000 of 21497, loss=3.316, LR=0.0008535533905932737
# Validation Loss = 1.532
# Epoch=6, batch = 11000 of 21497, loss=3.258, LR=0.0008535533905932737
# Validation Loss = 1.211
# Epoch=6, batch = 12000 of 21497, loss=3.020, LR=0.0008535533905932737
# Validation Loss = 1.444
# Epoch=6, batch = 13000 of 21497, loss=2.939, LR=0.0008535533905932737
# Validation Loss = 1.648
# Epoch=6, batch = 14000 of 21497, loss=3.095, LR=0.0008535533905932737
# Validation Loss = 0.610
# Epoch=6, batch = 15000 of 21497, loss=3.069, LR=0.0008535533905932737
# Validation Loss = 1.882
# Epoch=6, batch = 16000 of 21497, loss=3.128, LR=0.0008535533905932737
# Validation Loss = 0.404
# Epoch=6, batch = 17000 of 21497, loss=3.473, LR=0.0008535533905932737
# Validation Loss = 1.916
# Epoch=6, batch = 18000 of 21497, loss=3.115, LR=0.0008535533905932737
# Validation Loss = 2.585
# Epoch=6, batch = 19000 of 21497, loss=3.413, LR=0.0008535533905932737
# Validation Loss = 0.663
# Epoch=6, batch = 20000 of 21497, loss=3.250, LR=0.0008535533905932737
# Validation Loss = 0.811
# Epoch=6, batch = 21000 of 21497, loss=3.169, LR=0.0008535533905932737
# Validation Loss = 1.884
# Epoch=7, batch = 0 of 21497, loss=2.843, LR=0.0007938926261462366
# Validation Loss = 0.791
# Epoch=7, batch = 1000 of 21497, loss=3.185, LR=0.0007938926261462366
# Validation Loss = 0.597
# Epoch=7, batch = 2000 of 21497, loss=3.410, LR=0.0007938926261462366
# Validation Loss = 1.033
# Epoch=7, batch = 3000 of 21497, loss=2.971, LR=0.0007938926261462366
# Validation Loss = 2.574
# Epoch=7, batch = 4000 of 21497, loss=3.138, LR=0.0007938926261462366
# Validation Loss = 2.471
# Epoch=7, batch = 5000 of 21497, loss=3.008, LR=0.0007938926261462366
# Validation Loss = 0.548
# Epoch=7, batch = 6000 of 21497, loss=3.201, LR=0.0007938926261462366
# Validation Loss = 4.464
# Epoch=7, batch = 7000 of 21497, loss=3.677, LR=0.0007938926261462366
# Validation Loss = 4.059
# Epoch=7, batch = 8000 of 21497, loss=3.542, LR=0.0007938926261462366
# Validation Loss = 0.454
# Epoch=7, batch = 9000 of 21497, loss=3.739, LR=0.0007938926261462366
# Validation Loss = 0.290
# Epoch=7, batch = 10000 of 21497, loss=3.575, LR=0.0007938926261462366
# Validation Loss = 1.008
# Epoch=7, batch = 11000 of 21497, loss=3.473, LR=0.0007938926261462366
# Validation Loss = 0.939
# Epoch=7, batch = 12000 of 21497, loss=3.006, LR=0.0007938926261462366
# Validation Loss = 1.815
# Epoch=7, batch = 13000 of 21497, loss=3.212, LR=0.0007938926261462366
# Validation Loss = 1.656
# Epoch=7, batch = 14000 of 21497, loss=3.075, LR=0.0007938926261462366
# Validation Loss = 2.951
# Epoch=7, batch = 15000 of 21497, loss=3.252, LR=0.0007938926261462366
# Validation Loss = 3.168
# Epoch=7, batch = 16000 of 21497, loss=3.297, LR=0.0007938926261462366
# Validation Loss = 1.769
# Epoch=7, batch = 17000 of 21497, loss=3.025, LR=0.0007938926261462366
# Validation Loss = 0.867
# Epoch=7, batch = 18000 of 21497, loss=3.423, LR=0.0007938926261462366
# Validation Loss = 2.911
# Epoch=7, batch = 19000 of 21497, loss=3.379, LR=0.0007938926261462366
# Validation Loss = 0.812
# Epoch=7, batch = 20000 of 21497, loss=3.273, LR=0.0007938926261462366
# Validation Loss = 1.724
# Epoch=7, batch = 21000 of 21497, loss=3.084, LR=0.0007938926261462366
# Validation Loss = 0.642
# Epoch=8, batch = 0 of 21497, loss=3.704, LR=0.0007269952498697733
# Validation Loss = 1.038
# Epoch=8, batch = 1000 of 21497, loss=3.161, LR=0.0007269952498697733
# Validation Loss = 2.434
# Epoch=8, batch = 2000 of 21497, loss=3.250, LR=0.0007269952498697733
# Validation Loss = 0.915
# Epoch=8, batch = 3000 of 21497, loss=3.111, LR=0.0007269952498697733
# Validation Loss = 1.489
# Epoch=8, batch = 4000 of 21497, loss=3.014, LR=0.0007269952498697733
# Validation Loss = 2.280
# Epoch=8, batch = 5000 of 21497, loss=3.151, LR=0.0007269952498697733
# Validation Loss = 1.200
# Epoch=8, batch = 6000 of 21497, loss=2.925, LR=0.0007269952498697733
# Validation Loss = 3.319
# Epoch=8, batch = 7000 of 21497, loss=3.409, LR=0.0007269952498697733
# Validation Loss = 1.994
# Epoch=8, batch = 8000 of 21497, loss=3.243, LR=0.0007269952498697733
# Validation Loss = 0.480
# Epoch=8, batch = 9000 of 21497, loss=3.239, LR=0.0007269952498697733
# Validation Loss = 0.969
# Epoch=8, batch = 10000 of 21497, loss=2.948, LR=0.0007269952498697733
# Validation Loss = 0.556
# Epoch=8, batch = 11000 of 21497, loss=3.339, LR=0.0007269952498697733
# Validation Loss = 0.829
# Epoch=8, batch = 12000 of 21497, loss=3.259, LR=0.0007269952498697733
# Validation Loss = 2.049
# Epoch=8, batch = 13000 of 21497, loss=3.414, LR=0.0007269952498697733
# Validation Loss = 0.270
# Epoch=8, batch = 14000 of 21497, loss=3.403, LR=0.0007269952498697733
# Validation Loss = 2.140
# Epoch=8, batch = 15000 of 21497, loss=3.053, LR=0.0007269952498697733
# Validation Loss = 1.320
# Epoch=8, batch = 16000 of 21497, loss=2.902, LR=0.0007269952498697733
# Validation Loss = 0.368
# Epoch=8, batch = 17000 of 21497, loss=3.729, LR=0.0007269952498697733
# Validation Loss = 1.205
# Epoch=8, batch = 18000 of 21497, loss=2.883, LR=0.0007269952498697733
# Validation Loss = 1.893
# Epoch=8, batch = 19000 of 21497, loss=3.219, LR=0.0007269952498697733
# Validation Loss = 1.848
# Epoch=8, batch = 20000 of 21497, loss=3.292, LR=0.0007269952498697733
# Validation Loss = 2.223
# Epoch=8, batch = 21000 of 21497, loss=2.920, LR=0.0007269952498697733
# Validation Loss = 1.693
# Epoch=9, batch = 0 of 21497, loss=2.924, LR=0.0006545084971874737
# Validation Loss = 2.527
# Epoch=9, batch = 1000 of 21497, loss=3.147, LR=0.0006545084971874737
# Validation Loss = 2.358
# Epoch=9, batch = 2000 of 21497, loss=3.332, LR=0.0006545084971874737
# Validation Loss = 1.916
# Epoch=9, batch = 3000 of 21497, loss=3.139, LR=0.0006545084971874737
# Validation Loss = 0.329
# Epoch=9, batch = 4000 of 21497, loss=3.403, LR=0.0006545084971874737
# Validation Loss = 1.185
# Epoch=9, batch = 5000 of 21497, loss=3.339, LR=0.0006545084971874737
# Validation Loss = 1.163
# Epoch=9, batch = 6000 of 21497, loss=3.222, LR=0.0006545084971874737
# Validation Loss = 2.127
# Epoch=9, batch = 7000 of 21497, loss=3.085, LR=0.0006545084971874737
# Validation Loss = 0.604
# Epoch=9, batch = 8000 of 21497, loss=3.289, LR=0.0006545084971874737
# Validation Loss = 1.456
# Epoch=9, batch = 9000 of 21497, loss=3.109, LR=0.0006545084971874737
# Validation Loss = 1.910
# Epoch=9, batch = 10000 of 21497, loss=2.993, LR=0.0006545084971874737
# Validation Loss = 1.762
# Epoch=9, batch = 11000 of 21497, loss=2.895, LR=0.0006545084971874737
# Validation Loss = 1.155
# Epoch=9, batch = 12000 of 21497, loss=3.241, LR=0.0006545084971874737
# Validation Loss = 1.765
# Epoch=9, batch = 13000 of 21497, loss=3.215, LR=0.0006545084971874737
# Validation Loss = 2.170
# Epoch=9, batch = 14000 of 21497, loss=2.853, LR=0.0006545084971874737
# Validation Loss = 3.698
# Epoch=9, batch = 15000 of 21497, loss=3.662, LR=0.0006545084971874737
# Validation Loss = 2.617
# Epoch=9, batch = 16000 of 21497, loss=2.953, LR=0.0006545084971874737
# Validation Loss = 2.119
# Epoch=9, batch = 17000 of 21497, loss=3.617, LR=0.0006545084971874737
# Validation Loss = 1.039
# Epoch=9, batch = 18000 of 21497, loss=3.132, LR=0.0006545084971874737
# Validation Loss = 1.094
# Epoch=9, batch = 19000 of 21497, loss=3.276, LR=0.0006545084971874737
# Validation Loss = 3.118
# Epoch=9, batch = 20000 of 21497, loss=3.235, LR=0.0006545084971874737
# Validation Loss = 2.349
# Epoch=9, batch = 21000 of 21497, loss=3.253, LR=0.0006545084971874737
# Validation Loss = 0.701
# Epoch=10, batch = 0 of 21497, loss=3.288, LR=0.0005782172325201155
# Validation Loss = 1.817
# Epoch=10, batch = 1000 of 21497, loss=2.894, LR=0.0005782172325201155
# Validation Loss = 1.877
# Epoch=10, batch = 2000 of 21497, loss=2.793, LR=0.0005782172325201155
# Validation Loss = 2.122
# Epoch=10, batch = 3000 of 21497, loss=3.143, LR=0.0005782172325201155
# Validation Loss = 2.242
# Epoch=10, batch = 4000 of 21497, loss=3.053, LR=0.0005782172325201155
# Validation Loss = 2.077
# Epoch=10, batch = 5000 of 21497, loss=3.209, LR=0.0005782172325201155
# Validation Loss = 1.324
# Epoch=10, batch = 6000 of 21497, loss=2.937, LR=0.0005782172325201155
# Validation Loss = 2.013
# Epoch=10, batch = 7000 of 21497, loss=3.352, LR=0.0005782172325201155
# Validation Loss = 1.849
# Epoch=10, batch = 8000 of 21497, loss=3.034, LR=0.0005782172325201155
# Validation Loss = 2.853
# Epoch=10, batch = 9000 of 21497, loss=3.516, LR=0.0005782172325201155
# Validation Loss = 1.989
# Epoch=10, batch = 10000 of 21497, loss=3.393, LR=0.0005782172325201155
# Validation Loss = 2.508
# Epoch=10, batch = 11000 of 21497, loss=3.323, LR=0.0005782172325201155
# Validation Loss = 1.179
# Epoch=10, batch = 12000 of 21497, loss=2.919, LR=0.0005782172325201155
# Validation Loss = 1.585
# Epoch=10, batch = 13000 of 21497, loss=3.057, LR=0.0005782172325201155
# Validation Loss = 3.898
# Epoch=10, batch = 14000 of 21497, loss=3.563, LR=0.0005782172325201155
# Validation Loss = 0.467
# Epoch=10, batch = 15000 of 21497, loss=3.547, LR=0.0005782172325201155
# Validation Loss = 2.120
# Epoch=10, batch = 16000 of 21497, loss=3.207, LR=0.0005782172325201155
# Validation Loss = 1.458
# Epoch=10, batch = 17000 of 21497, loss=2.865, LR=0.0005782172325201155
# Validation Loss = 1.894
# Epoch=10, batch = 18000 of 21497, loss=3.266, LR=0.0005782172325201155
# Validation Loss = 1.045
# Epoch=10, batch = 19000 of 21497, loss=2.956, LR=0.0005782172325201155
# Validation Loss = 0.886
# Epoch=10, batch = 20000 of 21497, loss=3.416, LR=0.0005782172325201155
# Validation Loss = 1.029
# Epoch=10, batch = 21000 of 21497, loss=3.237, LR=0.0005782172325201155
# Validation Loss = 1.190
# Epoch=11, batch = 0 of 21497, loss=3.088, LR=0.0005
# Validation Loss = 2.660
# Epoch=11, batch = 1000 of 21497, loss=2.877, LR=0.0005
# Validation Loss = 0.687
# Epoch=11, batch = 2000 of 21497, loss=3.449, LR=0.0005
# Validation Loss = 1.151
# Epoch=11, batch = 3000 of 21497, loss=3.224, LR=0.0005
# Validation Loss = 1.207
# Epoch=11, batch = 4000 of 21497, loss=3.006, LR=0.0005
# Validation Loss = 1.818
# Epoch=11, batch = 5000 of 21497, loss=3.066, LR=0.0005
# Validation Loss = 0.963
# Epoch=11, batch = 6000 of 21497, loss=3.295, LR=0.0005
# Validation Loss = 3.057
# Epoch=11, batch = 7000 of 21497, loss=3.213, LR=0.0005
# Validation Loss = 1.530
# Epoch=11, batch = 8000 of 21497, loss=3.329, LR=0.0005
# Validation Loss = 1.703
# Epoch=11, batch = 9000 of 21497, loss=3.058, LR=0.0005
# Validation Loss = 1.763
# Epoch=11, batch = 10000 of 21497, loss=3.080, LR=0.0005
# Validation Loss = 1.677
# Epoch=11, batch = 11000 of 21497, loss=3.022, LR=0.0005
# Validation Loss = 2.101
# Epoch=11, batch = 12000 of 21497, loss=2.940, LR=0.0005
# Validation Loss = 1.591
# Epoch=11, batch = 13000 of 21497, loss=3.035, LR=0.0005
# Validation Loss = 0.789
# Epoch=11, batch = 14000 of 21497, loss=3.194, LR=0.0005
# Validation Loss = 1.399
# Epoch=11, batch = 15000 of 21497, loss=2.915, LR=0.0005
# Validation Loss = 2.051
# Epoch=11, batch = 16000 of 21497, loss=3.247, LR=0.0005
# Validation Loss = 0.940
# Epoch=11, batch = 17000 of 21497, loss=3.183, LR=0.0005
# Validation Loss = 1.477
# Epoch=11, batch = 18000 of 21497, loss=3.146, LR=0.0005
# Validation Loss = 1.823
# Epoch=11, batch = 19000 of 21497, loss=3.079, LR=0.0005
# Validation Loss = 1.619
# Epoch=11, batch = 20000 of 21497, loss=3.143, LR=0.0005
# Validation Loss = 2.277
# Epoch=11, batch = 21000 of 21497, loss=3.143, LR=0.0005
# Validation Loss = 0.926
# Epoch=12, batch = 0 of 21497, loss=3.089, LR=0.0004217827674798847
# Validation Loss = 2.447
# Epoch=12, batch = 1000 of 21497, loss=3.219, LR=0.0004217827674798847
# Validation Loss = 0.610
# Epoch=12, batch = 2000 of 21497, loss=3.417, LR=0.0004217827674798847
# Validation Loss = 1.613
# Epoch=12, batch = 3000 of 21497, loss=2.900, LR=0.0004217827674798847
# Validation Loss = 1.632
# Epoch=12, batch = 4000 of 21497, loss=3.007, LR=0.0004217827674798847
# Validation Loss = 2.831
# Epoch=12, batch = 5000 of 21497, loss=3.076, LR=0.0004217827674798847
# Validation Loss = 1.518
# Epoch=12, batch = 6000 of 21497, loss=3.102, LR=0.0004217827674798847
# Validation Loss = 1.376
# Epoch=12, batch = 7000 of 21497, loss=3.057, LR=0.0004217827674798847
# Validation Loss = 1.211
# Epoch=12, batch = 8000 of 21497, loss=3.008, LR=0.0004217827674798847
# Validation Loss = 2.823
# Epoch=12, batch = 9000 of 21497, loss=3.170, LR=0.0004217827674798847
# Validation Loss = 2.930
# Epoch=12, batch = 10000 of 21497, loss=3.268, LR=0.0004217827674798847
# Validation Loss = 1.877
# Epoch=12, batch = 11000 of 21497, loss=3.116, LR=0.0004217827674798847
# Validation Loss = 2.086
# Epoch=12, batch = 12000 of 21497, loss=3.082, LR=0.0004217827674798847
# Validation Loss = 0.612
# Epoch=12, batch = 13000 of 21497, loss=3.491, LR=0.0004217827674798847
