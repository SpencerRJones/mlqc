# %% [markdown]
# # Channel Prediction Model for Quality Control
#
# This notebook contains the code and outlines the development of the
# SSMI Channel Prediction Neural Network for QC purposes of SSMIS L1C
# data. The simple Feed-Forward Neural Networks (FFNNs) are trained on
# good quality SSMIS brightness temperature observation vectors and are
# trained to predict one channel from all the others as predictors.
#
# The end product is a tree of FFNNs, discretized by surface (ocean or
# land), and by channel, since these are fully distinct problems.

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import glob
import torch
from torch import nn
import cartopy.crs as ccrs
from util_funcs.L1C import scantime2datetime
from util_funcs import data2xarray, array_funcs
import geography
from tqdm import tqdm

from dataset_class import dataset
from model_class import channel_predictor
import local_functions
import sensor_info


#General parameters:

satellite = sensor_info.satellite
sensor = sensor_info.sensor

nchans = sensor_info.nchannels
batch_size = 1000
input_size = nchans - 1
hidden_size = 256
output_size = 1

# %%
nchans
# Out:
# 12

# %%
'''
Function Definitions:
'''

chan_desc = sensor_info.channel_descriptions


def extract_channel(Tb_array, chan):

    '''
    Use in preparing training data.

    Assumes Tb array is [m x n] where m (rows) are samples
    and n (columns) is the number of channels.

    Passing in the channel description splits the data so
    that the specified channel is its own vector y and the
    rest are kept as predictors x.

    Inputs:
        Tb_array    |  ndarray of Tbs
        chan        |  string of channel name
    Outputs:
        x           |  matrix of predictors (other channels)
        y           |  vector of predictands (the missing channel)
        
    '''
    
    chan_desc = np.array(sensor_info.channel_descriptions)


    chan_indx = np.where(chan == chan_desc)[0]

    if np.size(chan_indx) == 0:
        raise ValueError(f'Channel description must be in list {chan_desc}.')

    y = Tb_array[:,chan_indx]
    x = Tb_array[:,np.delete(np.arange(0,len(chan_desc)),chan_indx)]

    return x, y


def train_model(model, nepochs, dataloader, learning_rate=0.001, quiet=False, stage=None, validation_dataloader=None):

    nbatches = len(dataloader)
    
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=nepochs)
    device = None

    if stage:
        print(f'Training stage: {stage}')

    loss_arr    = np.zeros([nbatches,nepochs], dtype='f')
    valloss_arr = np.zeros([nbatches,nepochs], dtype='f')
    
    for epoch in range(nepochs):
        for i, (profs, obs) in enumerate(dataloader):
            if device:
                profs, obs = profs.to(device), obs.to(device)

            if validation_dataloader and i%1000==0:
                valprofs, valobs = next(enumerate(validation_dataloader))[1]
                val_pred = model(valprofs)
                valloss  = criterion(val_pred, valobs)
                print(f'Validation Loss = {valloss.item():.3f}')

            #Forward pass:
            obs_pred = model(profs)
            loss     = criterion(obs_pred, obs)


            #Backward pass:
            optimizer.zero_grad()
            loss.backward()

            #Update neurons:
            optimizer.step()

            loss_arr[i,epoch] = loss.item()
            valloss_arr[i,epoch] = valloss.item()
            
            if not quiet:
                if i%1000 == 0:
                    print(f'Channel {channel}, Epoch={epoch+1}, batch = {i} of {nbatches}, loss={loss.item():.3f}, LR={scheduler.get_last_lr()[0]}')
        
        scheduler.step()




    return loss_arr, valloss_arr

# %%
'''

AMSR2 CHANNEL PREDICTION MODEL:
    1: Ocean

'''

sfc = [1]

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = np.isin(sfctype, sfc)
    sfcindcs = np.where(correct_sfc)[0]

    Tbs = f.Tbs.values[sfcindcs]

#---Don't shuffle data before splitting
#np.random.seed(40)
#Tbs = array_funcs.shuffle_data(Tbs, axis=0)

if Tbs.shape[0] > 10.0e+06:
    Tbs = Tbs[:10_000_000,:]


print(Tbs.shape)

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train = array_funcs.shuffle_data(Tbs_train, axis=0)
# Out:
# (10000000, 12)

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    print(channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_ocean_no89.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_ocean_no89.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 6V
# Training stage: 1
# Validation Loss = 24179.082
# Channel 6V, Epoch=1, batch = 0 of 8000, loss=26847.863, LR=0.001
# Validation Loss = 1.371
# Channel 6V, Epoch=1, batch = 1000 of 8000, loss=0.527, LR=0.001
# Validation Loss = 0.095
# Channel 6V, Epoch=1, batch = 2000 of 8000, loss=0.444, LR=0.001
# Validation Loss = 0.710
# Channel 6V, Epoch=1, batch = 3000 of 8000, loss=0.423, LR=0.001
# Validation Loss = 0.872
# Channel 6V, Epoch=1, batch = 4000 of 8000, loss=0.499, LR=0.001
# Validation Loss = 1.377
# Channel 6V, Epoch=1, batch = 5000 of 8000, loss=0.789, LR=0.001
# Validation Loss = 0.359
# Channel 6V, Epoch=1, batch = 6000 of 8000, loss=0.331, LR=0.001
# Validation Loss = 0.005
# Channel 6V, Epoch=1, batch = 7000 of 8000, loss=0.503, LR=0.001
# Validation Loss = 0.734
# Channel 6V, Epoch=2, batch = 0 of 8000, loss=0.446, LR=0.0009045084971874737
# Validation Loss = 0.000
# Channel 6V, Epoch=2, batch = 1000 of 8000, loss=0.417, LR=0.0009045084971874737
# Validation Loss = 0.055
# Channel 6V, Epoch=2, batch = 2000 of 8000, loss=0.264, LR=0.0009045084971874737
# Validation Loss = 0.048
# Channel 6V, Epoch=2, batch = 3000 of 8000, loss=0.261, LR=0.0009045084971874737
# Validation Loss = 0.476
# Channel 6V, Epoch=2, batch = 4000 of 8000, loss=1.473, LR=0.0009045084971874737
# Validation Loss = 0.122
# Channel 6V, Epoch=2, batch = 5000 of 8000, loss=0.755, LR=0.0009045084971874737
# Validation Loss = 0.774
# Channel 6V, Epoch=2, batch = 6000 of 8000, loss=1.998, LR=0.0009045084971874737
# Validation Loss = 0.003
# Channel 6V, Epoch=2, batch = 7000 of 8000, loss=0.315, LR=0.0009045084971874737
# Validation Loss = 0.152
# Channel 6V, Epoch=3, batch = 0 of 8000, loss=0.234, LR=0.0006545084971874737
# Validation Loss = 0.050
# Channel 6V, Epoch=3, batch = 1000 of 8000, loss=0.227, LR=0.0006545084971874737
# Validation Loss = 0.170
# Channel 6V, Epoch=3, batch = 2000 of 8000, loss=0.241, LR=0.0006545084971874737
# Validation Loss = 0.136
# Channel 6V, Epoch=3, batch = 3000 of 8000, loss=0.241, LR=0.0006545084971874737
# Validation Loss = 0.054
# Channel 6V, Epoch=3, batch = 4000 of 8000, loss=0.434, LR=0.0006545084971874737
# Validation Loss = 0.381
# Channel 6V, Epoch=3, batch = 5000 of 8000, loss=0.349, LR=0.0006545084971874737
# Validation Loss = 0.036
# Channel 6V, Epoch=3, batch = 6000 of 8000, loss=0.216, LR=0.0006545084971874737
# Validation Loss = 0.024
# Channel 6V, Epoch=3, batch = 7000 of 8000, loss=0.372, LR=0.0006545084971874737
# Validation Loss = 0.042
# Channel 6V, Epoch=4, batch = 0 of 8000, loss=0.399, LR=0.00034549150281252633
# Validation Loss = 0.000
# Channel 6V, Epoch=4, batch = 1000 of 8000, loss=0.259, LR=0.00034549150281252633
# Validation Loss = 0.083
# Channel 6V, Epoch=4, batch = 2000 of 8000, loss=0.212, LR=0.00034549150281252633
# Validation Loss = 0.001
# Channel 6V, Epoch=4, batch = 3000 of 8000, loss=0.267, LR=0.00034549150281252633
# Validation Loss = 0.416
# Channel 6V, Epoch=4, batch = 4000 of 8000, loss=0.440, LR=0.00034549150281252633
# Validation Loss = 0.016
# Channel 6V, Epoch=4, batch = 5000 of 8000, loss=0.223, LR=0.00034549150281252633
# Validation Loss = 0.020
# Channel 6V, Epoch=4, batch = 6000 of 8000, loss=0.217, LR=0.00034549150281252633
# Validation Loss = 0.060
# Channel 6V, Epoch=4, batch = 7000 of 8000, loss=0.364, LR=0.00034549150281252633
# Validation Loss = 0.182
# Channel 6V, Epoch=5, batch = 0 of 8000, loss=0.283, LR=9.549150281252633e-05
# Validation Loss = 0.028
# Channel 6V, Epoch=5, batch = 1000 of 8000, loss=0.205, LR=9.549150281252633e-05
# Validation Loss = 0.020
# Channel 6V, Epoch=5, batch = 2000 of 8000, loss=0.186, LR=9.549150281252633e-05
# Validation Loss = 0.030
# Channel 6V, Epoch=5, batch = 3000 of 8000, loss=0.207, LR=9.549150281252633e-05
# Validation Loss = 0.016
# Channel 6V, Epoch=5, batch = 4000 of 8000, loss=0.205, LR=9.549150281252633e-05
# Validation Loss = 0.058
# Channel 6V, Epoch=5, batch = 5000 of 8000, loss=0.244, LR=9.549150281252633e-05
# Validation Loss = 0.016
# Channel 6V, Epoch=5, batch = 6000 of 8000, loss=0.200, LR=9.549150281252633e-05
# Validation Loss = 0.029
# Channel 6V, Epoch=5, batch = 7000 of 8000, loss=0.192, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.002
# Channel 6V, Epoch=1, batch = 0 of 8000, loss=0.221, LR=0.001
# Validation Loss = 0.197
# Channel 6V, Epoch=1, batch = 1000 of 8000, loss=0.214, LR=0.001
# Validation Loss = 0.660
# Channel 6V, Epoch=1, batch = 2000 of 8000, loss=0.519, LR=0.001
# Validation Loss = 0.045
# Channel 6V, Epoch=1, batch = 3000 of 8000, loss=0.475, LR=0.001
# Validation Loss = 0.181
# Channel 6V, Epoch=1, batch = 4000 of 8000, loss=0.701, LR=0.001
# Validation Loss = 0.006
# Channel 6V, Epoch=1, batch = 5000 of 8000, loss=0.369, LR=0.001
# Validation Loss = 0.376
# Channel 6V, Epoch=1, batch = 6000 of 8000, loss=0.315, LR=0.001
# Validation Loss = 0.913
# Channel 6V, Epoch=1, batch = 7000 of 8000, loss=1.765, LR=0.001
# Validation Loss = 0.017
# Channel 6V, Epoch=2, batch = 0 of 8000, loss=0.374, LR=0.0009755282581475768
# Validation Loss = 0.297
# Channel 6V, Epoch=2, batch = 1000 of 8000, loss=0.348, LR=0.0009755282581475768
# Validation Loss = 0.092
# Channel 6V, Epoch=2, batch = 2000 of 8000, loss=0.523, LR=0.0009755282581475768
# Validation Loss = 0.258
# Channel 6V, Epoch=2, batch = 3000 of 8000, loss=0.314, LR=0.0009755282581475768
# Validation Loss = 0.417
# Channel 6V, Epoch=2, batch = 4000 of 8000, loss=0.387, LR=0.0009755282581475768
# Validation Loss = 2.430
# Channel 6V, Epoch=2, batch = 5000 of 8000, loss=1.992, LR=0.0009755282581475768
# Validation Loss = 0.069
# Channel 6V, Epoch=2, batch = 6000 of 8000, loss=0.192, LR=0.0009755282581475768
# Validation Loss = 0.059
# Channel 6V, Epoch=2, batch = 7000 of 8000, loss=0.207, LR=0.0009755282581475768
# Validation Loss = 0.003
# Channel 6V, Epoch=3, batch = 0 of 8000, loss=0.361, LR=0.0009045084971874736
# Validation Loss = 0.253
# Channel 6V, Epoch=3, batch = 1000 of 8000, loss=0.283, LR=0.0009045084971874736
# Validation Loss = 0.025
# Channel 6V, Epoch=3, batch = 2000 of 8000, loss=0.378, LR=0.0009045084971874736
# Validation Loss = 0.068
# Channel 6V, Epoch=3, batch = 3000 of 8000, loss=0.486, LR=0.0009045084971874736
# Validation Loss = 0.003
# Channel 6V, Epoch=3, batch = 4000 of 8000, loss=0.249, LR=0.0009045084971874736
# Validation Loss = 0.030
# Channel 6V, Epoch=3, batch = 5000 of 8000, loss=0.398, LR=0.0009045084971874736
# Validation Loss = 0.191
# Channel 6V, Epoch=3, batch = 6000 of 8000, loss=0.237, LR=0.0009045084971874736
# Validation Loss = 0.248
# Channel 6V, Epoch=3, batch = 7000 of 8000, loss=0.864, LR=0.0009045084971874736
# Validation Loss = 0.000
# Channel 6V, Epoch=4, batch = 0 of 8000, loss=0.290, LR=0.0007938926261462366
# Validation Loss = 0.586
# Channel 6V, Epoch=4, batch = 1000 of 8000, loss=0.495, LR=0.0007938926261462366
# Validation Loss = 0.162
# Channel 6V, Epoch=4, batch = 2000 of 8000, loss=0.229, LR=0.0007938926261462366
# Validation Loss = 0.474
# Channel 6V, Epoch=4, batch = 3000 of 8000, loss=0.436, LR=0.0007938926261462366
# Validation Loss = 0.521
# Channel 6V, Epoch=4, batch = 4000 of 8000, loss=0.481, LR=0.0007938926261462366
# Validation Loss = 0.000
# Channel 6V, Epoch=4, batch = 5000 of 8000, loss=0.258, LR=0.0007938926261462366
# Validation Loss = 0.346
# Channel 6V, Epoch=4, batch = 6000 of 8000, loss=0.421, LR=0.0007938926261462366
# Validation Loss = 0.310
# Channel 6V, Epoch=4, batch = 7000 of 8000, loss=0.757, LR=0.0007938926261462366
# Validation Loss = 0.069
# Channel 6V, Epoch=5, batch = 0 of 8000, loss=0.237, LR=0.0006545084971874737
# Validation Loss = 0.174
# Channel 6V, Epoch=5, batch = 1000 of 8000, loss=0.263, LR=0.0006545084971874737
# Validation Loss = 0.301
# Channel 6V, Epoch=5, batch = 2000 of 8000, loss=0.321, LR=0.0006545084971874737
# Validation Loss = 0.350
# Channel 6V, Epoch=5, batch = 3000 of 8000, loss=0.364, LR=0.0006545084971874737
# Validation Loss = 0.000
# Channel 6V, Epoch=5, batch = 4000 of 8000, loss=0.236, LR=0.0006545084971874737
# Validation Loss = 0.011
# Channel 6V, Epoch=5, batch = 5000 of 8000, loss=0.219, LR=0.0006545084971874737
# Validation Loss = 0.031
# Channel 6V, Epoch=5, batch = 6000 of 8000, loss=0.205, LR=0.0006545084971874737
# Validation Loss = 0.033
# Channel 6V, Epoch=5, batch = 7000 of 8000, loss=0.216, LR=0.0006545084971874737
# Validation Loss = 0.011
# Channel 6V, Epoch=6, batch = 0 of 8000, loss=0.202, LR=0.0005
# Validation Loss = 0.363
# Channel 6V, Epoch=6, batch = 1000 of 8000, loss=0.361, LR=0.0005
# Validation Loss = 0.010
# Channel 6V, Epoch=6, batch = 2000 of 8000, loss=0.302, LR=0.0005
# Validation Loss = 0.065
# Channel 6V, Epoch=6, batch = 3000 of 8000, loss=0.213, LR=0.0005
# Validation Loss = 0.001
# Channel 6V, Epoch=6, batch = 4000 of 8000, loss=0.248, LR=0.0005
# Validation Loss = 0.132
# Channel 6V, Epoch=6, batch = 5000 of 8000, loss=0.248, LR=0.0005
# Validation Loss = 0.027
# Channel 6V, Epoch=6, batch = 6000 of 8000, loss=0.201, LR=0.0005
# Validation Loss = 0.295
# Channel 6V, Epoch=6, batch = 7000 of 8000, loss=0.347, LR=0.0005
# Validation Loss = 0.007
# Channel 6V, Epoch=7, batch = 0 of 8000, loss=0.211, LR=0.00034549150281252633
# Validation Loss = 0.056
# Channel 6V, Epoch=7, batch = 1000 of 8000, loss=0.227, LR=0.00034549150281252633
# Validation Loss = 0.010
# Channel 6V, Epoch=7, batch = 2000 of 8000, loss=0.197, LR=0.00034549150281252633
# Validation Loss = 0.039
# Channel 6V, Epoch=7, batch = 3000 of 8000, loss=0.195, LR=0.00034549150281252633
# Validation Loss = 0.019
# Channel 6V, Epoch=7, batch = 4000 of 8000, loss=0.203, LR=0.00034549150281252633
# Validation Loss = 0.001
# Channel 6V, Epoch=7, batch = 5000 of 8000, loss=0.238, LR=0.00034549150281252633
# Validation Loss = 0.133
# Channel 6V, Epoch=7, batch = 6000 of 8000, loss=0.251, LR=0.00034549150281252633
# Validation Loss = 0.043
# Channel 6V, Epoch=7, batch = 7000 of 8000, loss=0.191, LR=0.00034549150281252633
# Validation Loss = 0.008
# Channel 6V, Epoch=8, batch = 0 of 8000, loss=0.285, LR=0.0002061073738537635
# Validation Loss = 0.058
# Channel 6V, Epoch=8, batch = 1000 of 8000, loss=0.192, LR=0.0002061073738537635
# Validation Loss = 0.000
# Channel 6V, Epoch=8, batch = 2000 of 8000, loss=0.238, LR=0.0002061073738537635
# Validation Loss = 0.000
# Channel 6V, Epoch=8, batch = 3000 of 8000, loss=0.238, LR=0.0002061073738537635
# Validation Loss = 0.046
# Channel 6V, Epoch=8, batch = 4000 of 8000, loss=0.203, LR=0.0002061073738537635
# Validation Loss = 0.003
# Channel 6V, Epoch=8, batch = 5000 of 8000, loss=0.203, LR=0.0002061073738537635
# Validation Loss = 0.038
# Channel 6V, Epoch=8, batch = 6000 of 8000, loss=0.219, LR=0.0002061073738537635
# Validation Loss = 0.076
# Channel 6V, Epoch=8, batch = 7000 of 8000, loss=0.215, LR=0.0002061073738537635
# Validation Loss = 0.085
# Channel 6V, Epoch=9, batch = 0 of 8000, loss=0.211, LR=9.549150281252634e-05
# Validation Loss = 0.022
# Channel 6V, Epoch=9, batch = 1000 of 8000, loss=0.188, LR=9.549150281252634e-05
# Validation Loss = 0.065
# Channel 6V, Epoch=9, batch = 2000 of 8000, loss=0.201, LR=9.549150281252634e-05
# Validation Loss = 0.011
# Channel 6V, Epoch=9, batch = 3000 of 8000, loss=0.209, LR=9.549150281252634e-05
# Validation Loss = 0.037
# Channel 6V, Epoch=9, batch = 4000 of 8000, loss=0.182, LR=9.549150281252634e-05
# Validation Loss = 0.019
# Channel 6V, Epoch=9, batch = 5000 of 8000, loss=0.208, LR=9.549150281252634e-05
# Validation Loss = 0.044
# Channel 6V, Epoch=9, batch = 6000 of 8000, loss=0.203, LR=9.549150281252634e-05
# Validation Loss = 0.067
# Channel 6V, Epoch=9, batch = 7000 of 8000, loss=0.215, LR=9.549150281252634e-05
# Validation Loss = 0.031
# Channel 6V, Epoch=10, batch = 0 of 8000, loss=0.201, LR=2.4471741852423235e-05
# Validation Loss = 0.045
# Channel 6V, Epoch=10, batch = 1000 of 8000, loss=0.196, LR=2.4471741852423235e-05
# Validation Loss = 0.030
# Channel 6V, Epoch=10, batch = 2000 of 8000, loss=0.202, LR=2.4471741852423235e-05
# Validation Loss = 0.026
# Channel 6V, Epoch=10, batch = 3000 of 8000, loss=0.203, LR=2.4471741852423235e-05
# Validation Loss = 0.021
# Channel 6V, Epoch=10, batch = 4000 of 8000, loss=0.195, LR=2.4471741852423235e-05
# Validation Loss = 0.016
# Channel 6V, Epoch=10, batch = 5000 of 8000, loss=0.203, LR=2.4471741852423235e-05
# Validation Loss = 0.023
# Channel 6V, Epoch=10, batch = 6000 of 8000, loss=0.187, LR=2.4471741852423235e-05
# Validation Loss = 0.041
# Channel 6V, Epoch=10, batch = 7000 of 8000, loss=0.197, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.031
# Channel 6V, Epoch=1, batch = 0 of 8000, loss=0.201, LR=0.001
# Validation Loss = 0.011
# Channel 6V, Epoch=1, batch = 1000 of 8000, loss=0.206, LR=0.001
# Validation Loss = 0.725
# Channel 6V, Epoch=1, batch = 2000 of 8000, loss=0.692, LR=0.001
# Validation Loss = 0.465
# Channel 6V, Epoch=1, batch = 3000 of 8000, loss=0.522, LR=0.001
# Validation Loss = 0.664
# Channel 6V, Epoch=1, batch = 4000 of 8000, loss=0.649, LR=0.001
# Validation Loss = 0.070
# Channel 6V, Epoch=1, batch = 5000 of 8000, loss=0.217, LR=0.001
# Validation Loss = 0.394
# Channel 6V, Epoch=1, batch = 6000 of 8000, loss=0.454, LR=0.001
# Validation Loss = 0.693
# Channel 6V, Epoch=1, batch = 7000 of 8000, loss=0.567, LR=0.001
# Validation Loss = 0.127
# Channel 6V, Epoch=2, batch = 0 of 8000, loss=0.243, LR=0.0009938441702975688
# Validation Loss = 0.081
# Channel 6V, Epoch=2, batch = 1000 of 8000, loss=0.221, LR=0.0009938441702975688
# Validation Loss = 0.260
# Channel 6V, Epoch=2, batch = 2000 of 8000, loss=0.328, LR=0.0009938441702975688
# Validation Loss = 0.001
# Channel 6V, Epoch=2, batch = 3000 of 8000, loss=0.289, LR=0.0009938441702975688
# Validation Loss = 0.096
# Channel 6V, Epoch=2, batch = 4000 of 8000, loss=0.227, LR=0.0009938441702975688
# Validation Loss = 0.706
# Channel 6V, Epoch=2, batch = 5000 of 8000, loss=0.627, LR=0.0009938441702975688
# Validation Loss = 0.171
# Channel 6V, Epoch=2, batch = 6000 of 8000, loss=0.246, LR=0.0009938441702975688
# Validation Loss = 0.683
# Channel 6V, Epoch=2, batch = 7000 of 8000, loss=0.577, LR=0.0009938441702975688
# Validation Loss = 0.110
# Channel 6V, Epoch=3, batch = 0 of 8000, loss=0.204, LR=0.0009755282581475768
# Validation Loss = 0.014
# Channel 6V, Epoch=3, batch = 1000 of 8000, loss=0.203, LR=0.0009755282581475768
# Validation Loss = 0.007
# Channel 6V, Epoch=3, batch = 2000 of 8000, loss=0.215, LR=0.0009755282581475768
# Validation Loss = 0.177
# Channel 6V, Epoch=3, batch = 3000 of 8000, loss=0.257, LR=0.0009755282581475768
# Validation Loss = 0.036
# Channel 6V, Epoch=3, batch = 4000 of 8000, loss=0.441, LR=0.0009755282581475768
# Validation Loss = 0.103
# Channel 6V, Epoch=3, batch = 5000 of 8000, loss=0.225, LR=0.0009755282581475768
# Validation Loss = 0.000
# Channel 6V, Epoch=3, batch = 6000 of 8000, loss=0.220, LR=0.0009755282581475768
# Validation Loss = 0.311
# Channel 6V, Epoch=3, batch = 7000 of 8000, loss=0.333, LR=0.0009755282581475768
# Validation Loss = 0.060
# Channel 6V, Epoch=4, batch = 0 of 8000, loss=0.394, LR=0.0009455032620941839
# Validation Loss = 0.000
# Channel 6V, Epoch=4, batch = 1000 of 8000, loss=0.253, LR=0.0009455032620941839
# Validation Loss = 0.001
# Channel 6V, Epoch=4, batch = 2000 of 8000, loss=0.259, LR=0.0009455032620941839
# Validation Loss = 0.409
# Channel 6V, Epoch=4, batch = 3000 of 8000, loss=0.404, LR=0.0009455032620941839
# Validation Loss = 0.153
# Channel 6V, Epoch=4, batch = 4000 of 8000, loss=0.268, LR=0.0009455032620941839
# Validation Loss = 0.151
# Channel 6V, Epoch=4, batch = 5000 of 8000, loss=0.209, LR=0.0009455032620941839
# Validation Loss = 0.040
# Channel 6V, Epoch=4, batch = 6000 of 8000, loss=0.217, LR=0.0009455032620941839
# Validation Loss = 0.343
# Channel 6V, Epoch=4, batch = 7000 of 8000, loss=0.339, LR=0.0009455032620941839
# Validation Loss = 0.033
# Channel 6V, Epoch=5, batch = 0 of 8000, loss=0.359, LR=0.0009045084971874737
# Validation Loss = 0.244
# Channel 6V, Epoch=5, batch = 1000 of 8000, loss=0.307, LR=0.0009045084971874737
# Validation Loss = 0.000
# Channel 6V, Epoch=5, batch = 2000 of 8000, loss=0.271, LR=0.0009045084971874737
# Validation Loss = 0.822
# Channel 6V, Epoch=5, batch = 3000 of 8000, loss=0.651, LR=0.0009045084971874737
# Validation Loss = 0.038
# Channel 6V, Epoch=5, batch = 4000 of 8000, loss=0.357, LR=0.0009045084971874737
# Validation Loss = 0.002
# Channel 6V, Epoch=5, batch = 5000 of 8000, loss=0.290, LR=0.0009045084971874737
# Validation Loss = 0.012
# Channel 6V, Epoch=5, batch = 6000 of 8000, loss=0.212, LR=0.0009045084971874737
# Validation Loss = 0.066
# Channel 6V, Epoch=5, batch = 7000 of 8000, loss=0.214, LR=0.0009045084971874737
# Validation Loss = 0.294
# Channel 6V, Epoch=6, batch = 0 of 8000, loss=0.790, LR=0.0008535533905932737
# Validation Loss = 0.007
# Channel 6V, Epoch=6, batch = 1000 of 8000, loss=0.211, LR=0.0008535533905932737
# Validation Loss = 0.026
# Channel 6V, Epoch=6, batch = 2000 of 8000, loss=0.345, LR=0.0008535533905932737
# Validation Loss = 0.022
# Channel 6V, Epoch=6, batch = 3000 of 8000, loss=0.318, LR=0.0008535533905932737
# Validation Loss = 0.000
# Channel 6V, Epoch=6, batch = 4000 of 8000, loss=0.257, LR=0.0008535533905932737
# Validation Loss = 0.000
# Channel 6V, Epoch=6, batch = 5000 of 8000, loss=0.242, LR=0.0008535533905932737
# Validation Loss = 0.047
# Channel 6V, Epoch=6, batch = 6000 of 8000, loss=0.221, LR=0.0008535533905932737
# Validation Loss = 0.055
# Channel 6V, Epoch=6, batch = 7000 of 8000, loss=0.194, LR=0.0008535533905932737
# Validation Loss = 0.235
# Channel 6V, Epoch=7, batch = 0 of 8000, loss=0.265, LR=0.0007938926261462366
# Validation Loss = 0.081
# Channel 6V, Epoch=7, batch = 1000 of 8000, loss=0.203, LR=0.0007938926261462366
# Validation Loss = 0.032
# Channel 6V, Epoch=7, batch = 2000 of 8000, loss=0.221, LR=0.0007938926261462366
# Validation Loss = 0.383
# Channel 6V, Epoch=7, batch = 3000 of 8000, loss=0.374, LR=0.0007938926261462366
# Validation Loss = 0.002
# Channel 6V, Epoch=7, batch = 4000 of 8000, loss=0.216, LR=0.0007938926261462366
# Validation Loss = 0.002
# Channel 6V, Epoch=7, batch = 5000 of 8000, loss=0.235, LR=0.0007938926261462366
# Validation Loss = 0.070
# Channel 6V, Epoch=7, batch = 6000 of 8000, loss=0.398, LR=0.0007938926261462366
# Validation Loss = 0.059
# Channel 6V, Epoch=7, batch = 7000 of 8000, loss=0.186, LR=0.0007938926261462366
# Validation Loss = 0.174
# Channel 6V, Epoch=8, batch = 0 of 8000, loss=0.279, LR=0.0007269952498697733
# Validation Loss = 0.855
# Channel 6V, Epoch=8, batch = 1000 of 8000, loss=0.748, LR=0.0007269952498697733
# Validation Loss = 0.058
# Channel 6V, Epoch=8, batch = 2000 of 8000, loss=0.407, LR=0.0007269952498697733
# Validation Loss = 0.337
# Channel 6V, Epoch=8, batch = 3000 of 8000, loss=0.339, LR=0.0007269952498697733
# Validation Loss = 0.319
# Channel 6V, Epoch=8, batch = 4000 of 8000, loss=0.368, LR=0.0007269952498697733
# Validation Loss = 0.155
# Channel 6V, Epoch=8, batch = 5000 of 8000, loss=0.268, LR=0.0007269952498697733
# Validation Loss = 0.025
# Channel 6V, Epoch=8, batch = 6000 of 8000, loss=0.213, LR=0.0007269952498697733
# Validation Loss = 0.057
# Channel 6V, Epoch=8, batch = 7000 of 8000, loss=0.221, LR=0.0007269952498697733
# Validation Loss = 0.003
# Channel 6V, Epoch=9, batch = 0 of 8000, loss=0.218, LR=0.0006545084971874737
# Validation Loss = 0.174
# Channel 6V, Epoch=9, batch = 1000 of 8000, loss=0.250, LR=0.0006545084971874737
# Validation Loss = 0.065
# Channel 6V, Epoch=9, batch = 2000 of 8000, loss=0.188, LR=0.0006545084971874737
# Validation Loss = 0.062
# Channel 6V, Epoch=9, batch = 3000 of 8000, loss=0.346, LR=0.0006545084971874737
# Validation Loss = 0.028
# Channel 6V, Epoch=9, batch = 4000 of 8000, loss=0.209, LR=0.0006545084971874737
# Validation Loss = 0.155
# Channel 6V, Epoch=9, batch = 5000 of 8000, loss=0.571, LR=0.0006545084971874737
# Validation Loss = 0.124
# Channel 6V, Epoch=9, batch = 6000 of 8000, loss=0.253, LR=0.0006545084971874737
# Validation Loss = 0.014
# Channel 6V, Epoch=9, batch = 7000 of 8000, loss=0.300, LR=0.0006545084971874737
# Validation Loss = 0.311
# Channel 6V, Epoch=10, batch = 0 of 8000, loss=0.363, LR=0.0005782172325201155
# Validation Loss = 0.206
# Channel 6V, Epoch=10, batch = 1000 of 8000, loss=0.281, LR=0.0005782172325201155
# Validation Loss = 0.078
# Channel 6V, Epoch=10, batch = 2000 of 8000, loss=0.228, LR=0.0005782172325201155
# Validation Loss = 0.117
# Channel 6V, Epoch=10, batch = 3000 of 8000, loss=0.214, LR=0.0005782172325201155
# Validation Loss = 0.013
# Channel 6V, Epoch=10, batch = 4000 of 8000, loss=0.195, LR=0.0005782172325201155
# Validation Loss = 0.016
# Channel 6V, Epoch=10, batch = 5000 of 8000, loss=0.201, LR=0.0005782172325201155
# Validation Loss = 0.019
# Channel 6V, Epoch=10, batch = 6000 of 8000, loss=0.204, LR=0.0005782172325201155
# Validation Loss = 0.031
# Channel 6V, Epoch=10, batch = 7000 of 8000, loss=0.192, LR=0.0005782172325201155
# Validation Loss = 0.010
# Channel 6V, Epoch=11, batch = 0 of 8000, loss=0.196, LR=0.0005
# Validation Loss = 0.100
# Channel 6V, Epoch=11, batch = 1000 of 8000, loss=0.217, LR=0.0005
# Validation Loss = 0.097
# Channel 6V, Epoch=11, batch = 2000 of 8000, loss=0.210, LR=0.0005
# Validation Loss = 0.035
# Channel 6V, Epoch=11, batch = 3000 of 8000, loss=0.212, LR=0.0005
# Validation Loss = 0.058
# Channel 6V, Epoch=11, batch = 4000 of 8000, loss=0.198, LR=0.0005
# Validation Loss = 0.035
# Channel 6V, Epoch=11, batch = 5000 of 8000, loss=0.189, LR=0.0005
# Validation Loss = 0.001
# Channel 6V, Epoch=11, batch = 6000 of 8000, loss=0.237, LR=0.0005
# Validation Loss = 0.022
# Channel 6V, Epoch=11, batch = 7000 of 8000, loss=0.186, LR=0.0005
# Validation Loss = 0.087
# Channel 6V, Epoch=12, batch = 0 of 8000, loss=0.220, LR=0.0004217827674798847
# Validation Loss = 0.081
# Channel 6V, Epoch=12, batch = 1000 of 8000, loss=0.206, LR=0.0004217827674798847
# Validation Loss = 0.009
# Channel 6V, Epoch=12, batch = 2000 of 8000, loss=0.203, LR=0.0004217827674798847
# Validation Loss = 0.018
# Channel 6V, Epoch=12, batch = 3000 of 8000, loss=0.215, LR=0.0004217827674798847
# Validation Loss = 0.062
# Channel 6V, Epoch=12, batch = 4000 of 8000, loss=0.210, LR=0.0004217827674798847
# Validation Loss = 0.164
# Channel 6V, Epoch=12, batch = 5000 of 8000, loss=0.237, LR=0.0004217827674798847
# Validation Loss = 0.072
# Channel 6V, Epoch=12, batch = 6000 of 8000, loss=0.206, LR=0.0004217827674798847
# Validation Loss = 0.030
# Channel 6V, Epoch=12, batch = 7000 of 8000, loss=0.196, LR=0.0004217827674798847
# Validation Loss = 0.018
# Channel 6V, Epoch=13, batch = 0 of 8000, loss=0.205, LR=0.00034549150281252633
# Validation Loss = 0.039
# Channel 6V, Epoch=13, batch = 1000 of 8000, loss=0.224, LR=0.00034549150281252633
# Validation Loss = 0.105
# Channel 6V, Epoch=13, batch = 2000 of 8000, loss=0.244, LR=0.00034549150281252633
# Validation Loss = 0.040
# Channel 6V, Epoch=13, batch = 3000 of 8000, loss=0.207, LR=0.00034549150281252633
# Validation Loss = 0.181
# Channel 6V, Epoch=13, batch = 4000 of 8000, loss=0.287, LR=0.00034549150281252633
# Validation Loss = 0.030
# Channel 6V, Epoch=13, batch = 5000 of 8000, loss=0.192, LR=0.00034549150281252633
# Validation Loss = 0.002
# Channel 6V, Epoch=13, batch = 6000 of 8000, loss=0.197, LR=0.00034549150281252633
# Validation Loss = 0.018
# Channel 6V, Epoch=13, batch = 7000 of 8000, loss=0.281, LR=0.00034549150281252633
# Validation Loss = 0.036
# Channel 6V, Epoch=14, batch = 0 of 8000, loss=0.209, LR=0.00027300475013022663
# Validation Loss = 0.001
# Channel 6V, Epoch=14, batch = 1000 of 8000, loss=0.220, LR=0.00027300475013022663
# Validation Loss = 0.057
# Channel 6V, Epoch=14, batch = 2000 of 8000, loss=0.201, LR=0.00027300475013022663
# Validation Loss = 0.002
# Channel 6V, Epoch=14, batch = 3000 of 8000, loss=0.224, LR=0.00027300475013022663
# Validation Loss = 0.052
# Channel 6V, Epoch=14, batch = 4000 of 8000, loss=0.186, LR=0.00027300475013022663
# Validation Loss = 0.056
# Channel 6V, Epoch=14, batch = 5000 of 8000, loss=0.214, LR=0.00027300475013022663
# Validation Loss = 0.003
# Channel 6V, Epoch=14, batch = 6000 of 8000, loss=0.248, LR=0.00027300475013022663
# Validation Loss = 0.076
# Channel 6V, Epoch=14, batch = 7000 of 8000, loss=0.212, LR=0.00027300475013022663
# Validation Loss = 0.016
# Channel 6V, Epoch=15, batch = 0 of 8000, loss=0.184, LR=0.00020610737385376348
# Validation Loss = 0.104
# Channel 6V, Epoch=15, batch = 1000 of 8000, loss=0.231, LR=0.00020610737385376348
# Validation Loss = 0.013
# Channel 6V, Epoch=15, batch = 2000 of 8000, loss=0.224, LR=0.00020610737385376348
# Validation Loss = 0.005
# Channel 6V, Epoch=15, batch = 3000 of 8000, loss=0.226, LR=0.00020610737385376348
# Validation Loss = 0.055
# Channel 6V, Epoch=15, batch = 4000 of 8000, loss=0.202, LR=0.00020610737385376348
# Validation Loss = 0.057
# Channel 6V, Epoch=15, batch = 5000 of 8000, loss=0.189, LR=0.00020610737385376348
# Validation Loss = 0.021
# Channel 6V, Epoch=15, batch = 6000 of 8000, loss=0.197, LR=0.00020610737385376348
# Validation Loss = 0.052
# Channel 6V, Epoch=15, batch = 7000 of 8000, loss=0.195, LR=0.00020610737385376348
# Validation Loss = 0.152
# Channel 6V, Epoch=16, batch = 0 of 8000, loss=0.247, LR=0.00014644660940672625
# Validation Loss = 0.083
# Channel 6V, Epoch=16, batch = 1000 of 8000, loss=0.219, LR=0.00014644660940672625
# Validation Loss = 0.005
# Channel 6V, Epoch=16, batch = 2000 of 8000, loss=0.199, LR=0.00014644660940672625
# Validation Loss = 0.068
# Channel 6V, Epoch=16, batch = 3000 of 8000, loss=0.250, LR=0.00014644660940672625
# Validation Loss = 0.034
# Channel 6V, Epoch=16, batch = 4000 of 8000, loss=0.191, LR=0.00014644660940672625
# Validation Loss = 0.032
# Channel 6V, Epoch=16, batch = 5000 of 8000, loss=0.205, LR=0.00014644660940672625
# Validation Loss = 0.029
# Channel 6V, Epoch=16, batch = 6000 of 8000, loss=0.213, LR=0.00014644660940672625
# Validation Loss = 0.011
# Channel 6V, Epoch=16, batch = 7000 of 8000, loss=0.200, LR=0.00014644660940672625
# Validation Loss = 0.076
# Channel 6V, Epoch=17, batch = 0 of 8000, loss=0.202, LR=9.549150281252631e-05
# Validation Loss = 0.014
# Channel 6V, Epoch=17, batch = 1000 of 8000, loss=0.215, LR=9.549150281252631e-05
# Validation Loss = 0.027
# Channel 6V, Epoch=17, batch = 2000 of 8000, loss=0.184, LR=9.549150281252631e-05
# Validation Loss = 0.011
# Channel 6V, Epoch=17, batch = 3000 of 8000, loss=0.213, LR=9.549150281252631e-05
# Validation Loss = 0.032
# Channel 6V, Epoch=17, batch = 4000 of 8000, loss=0.205, LR=9.549150281252631e-05
# Validation Loss = 0.019
# Channel 6V, Epoch=17, batch = 5000 of 8000, loss=0.198, LR=9.549150281252631e-05
# Validation Loss = 0.022
# Channel 6V, Epoch=17, batch = 6000 of 8000, loss=0.188, LR=9.549150281252631e-05
# Validation Loss = 0.082
# Channel 6V, Epoch=17, batch = 7000 of 8000, loss=0.202, LR=9.549150281252631e-05
# Validation Loss = 0.007
# Channel 6V, Epoch=18, batch = 0 of 8000, loss=0.218, LR=5.4496737905816096e-05
# Validation Loss = 0.040
# Channel 6V, Epoch=18, batch = 1000 of 8000, loss=0.197, LR=5.4496737905816096e-05
# Validation Loss = 0.026
# Channel 6V, Epoch=18, batch = 2000 of 8000, loss=0.193, LR=5.4496737905816096e-05
# Validation Loss = 0.022
# Channel 6V, Epoch=18, batch = 3000 of 8000, loss=0.202, LR=5.4496737905816096e-05
# Validation Loss = 0.069
# Channel 6V, Epoch=18, batch = 4000 of 8000, loss=0.212, LR=5.4496737905816096e-05
# Validation Loss = 0.015
# Channel 6V, Epoch=18, batch = 5000 of 8000, loss=0.206, LR=5.4496737905816096e-05
# Validation Loss = 0.038
# Channel 6V, Epoch=18, batch = 6000 of 8000, loss=0.205, LR=5.4496737905816096e-05
# Validation Loss = 0.013
# Channel 6V, Epoch=18, batch = 7000 of 8000, loss=0.196, LR=5.4496737905816096e-05
# Validation Loss = 0.042
# Channel 6V, Epoch=19, batch = 0 of 8000, loss=0.198, LR=2.447174185242323e-05
# Validation Loss = 0.024
# Channel 6V, Epoch=19, batch = 1000 of 8000, loss=0.187, LR=2.447174185242323e-05
# Validation Loss = 0.015
# Channel 6V, Epoch=19, batch = 2000 of 8000, loss=0.189, LR=2.447174185242323e-05
# Validation Loss = 0.022
# Channel 6V, Epoch=19, batch = 3000 of 8000, loss=0.193, LR=2.447174185242323e-05
# Validation Loss = 0.032
# Channel 6V, Epoch=19, batch = 4000 of 8000, loss=0.192, LR=2.447174185242323e-05
# Validation Loss = 0.020
# Channel 6V, Epoch=19, batch = 5000 of 8000, loss=0.194, LR=2.447174185242323e-05
# Validation Loss = 0.043
# Channel 6V, Epoch=19, batch = 6000 of 8000, loss=0.189, LR=2.447174185242323e-05
# Validation Loss = 0.027
# Channel 6V, Epoch=19, batch = 7000 of 8000, loss=0.193, LR=2.447174185242323e-05
# Validation Loss = 0.041
# Channel 6V, Epoch=20, batch = 0 of 8000, loss=0.198, LR=6.15582970243117e-06
# Validation Loss = 0.033
# Channel 6V, Epoch=20, batch = 1000 of 8000, loss=0.185, LR=6.15582970243117e-06
# Validation Loss = 0.023
# Channel 6V, Epoch=20, batch = 2000 of 8000, loss=0.201, LR=6.15582970243117e-06
# Validation Loss = 0.043
# Channel 6V, Epoch=20, batch = 3000 of 8000, loss=0.187, LR=6.15582970243117e-06
# Validation Loss = 0.038
# Channel 6V, Epoch=20, batch = 4000 of 8000, loss=0.183, LR=6.15582970243117e-06
# Validation Loss = 0.028
# Channel 6V, Epoch=20, batch = 5000 of 8000, loss=0.212, LR=6.15582970243117e-06
# Validation Loss = 0.031
# Channel 6V, Epoch=20, batch = 6000 of 8000, loss=0.212, LR=6.15582970243117e-06
# Validation Loss = 0.028
# Channel 6V, Epoch=20, batch = 7000 of 8000, loss=0.200, LR=6.15582970243117e-06
# Finished training model for channel 6V.
# 6H
# Training stage: 1
# Validation Loss = 6922.744
# Channel 6H, Epoch=1, batch = 0 of 8000, loss=7182.012, LR=0.001
# Validation Loss = 0.128
# Channel 6H, Epoch=1, batch = 1000 of 8000, loss=0.739, LR=0.001
# Validation Loss = 0.028
# Channel 6H, Epoch=1, batch = 2000 of 8000, loss=0.410, LR=0.001
# Validation Loss = 0.422
# Channel 6H, Epoch=1, batch = 3000 of 8000, loss=0.595, LR=0.001
# Validation Loss = 0.146
# Channel 6H, Epoch=1, batch = 4000 of 8000, loss=0.566, LR=0.001
# Validation Loss = 0.019
# Channel 6H, Epoch=1, batch = 5000 of 8000, loss=0.204, LR=0.001
# Validation Loss = 0.144
# Channel 6H, Epoch=1, batch = 6000 of 8000, loss=0.323, LR=0.001
# Validation Loss = 0.053
# Channel 6H, Epoch=1, batch = 7000 of 8000, loss=0.347, LR=0.001
# Validation Loss = 1.118
# Channel 6H, Epoch=2, batch = 0 of 8000, loss=1.194, LR=0.0009045084971874737
# Validation Loss = 0.033
# Channel 6H, Epoch=2, batch = 1000 of 8000, loss=0.165, LR=0.0009045084971874737
# Validation Loss = 0.110
# Channel 6H, Epoch=2, batch = 2000 of 8000, loss=0.348, LR=0.0009045084971874737
# Validation Loss = 0.359
# Channel 6H, Epoch=2, batch = 3000 of 8000, loss=0.615, LR=0.0009045084971874737
# Validation Loss = 0.011
# Channel 6H, Epoch=2, batch = 4000 of 8000, loss=0.176, LR=0.0009045084971874737
# Validation Loss = 0.001
# Channel 6H, Epoch=2, batch = 5000 of 8000, loss=0.174, LR=0.0009045084971874737
# Validation Loss = 0.036
# Channel 6H, Epoch=2, batch = 6000 of 8000, loss=0.194, LR=0.0009045084971874737
# Validation Loss = 0.021
# Channel 6H, Epoch=2, batch = 7000 of 8000, loss=0.184, LR=0.0009045084971874737
# Validation Loss = 0.012
# Channel 6H, Epoch=3, batch = 0 of 8000, loss=0.180, LR=0.0006545084971874737
# Validation Loss = 0.058
# Channel 6H, Epoch=3, batch = 1000 of 8000, loss=0.222, LR=0.0006545084971874737
# Validation Loss = 0.023
# Channel 6H, Epoch=3, batch = 2000 of 8000, loss=0.159, LR=0.0006545084971874737
# Validation Loss = 0.035
# Channel 6H, Epoch=3, batch = 3000 of 8000, loss=0.185, LR=0.0006545084971874737
# Validation Loss = 0.092
# Channel 6H, Epoch=3, batch = 4000 of 8000, loss=0.210, LR=0.0006545084971874737
# Validation Loss = 0.017
# Channel 6H, Epoch=3, batch = 5000 of 8000, loss=0.244, LR=0.0006545084971874737
# Validation Loss = 0.051
# Channel 6H, Epoch=3, batch = 6000 of 8000, loss=0.147, LR=0.0006545084971874737
# Validation Loss = 0.106
# Channel 6H, Epoch=3, batch = 7000 of 8000, loss=0.190, LR=0.0006545084971874737
# Validation Loss = 0.010
# Channel 6H, Epoch=4, batch = 0 of 8000, loss=0.178, LR=0.00034549150281252633
# Validation Loss = 0.012
# Channel 6H, Epoch=4, batch = 1000 of 8000, loss=0.125, LR=0.00034549150281252633
# Validation Loss = 0.002
# Channel 6H, Epoch=4, batch = 2000 of 8000, loss=0.166, LR=0.00034549150281252633
# Validation Loss = 0.006
# Channel 6H, Epoch=4, batch = 3000 of 8000, loss=0.145, LR=0.00034549150281252633
# Validation Loss = 0.017
# Channel 6H, Epoch=4, batch = 4000 of 8000, loss=0.258, LR=0.00034549150281252633
# Validation Loss = 0.156
# Channel 6H, Epoch=4, batch = 5000 of 8000, loss=0.248, LR=0.00034549150281252633
# Validation Loss = 0.014
# Channel 6H, Epoch=4, batch = 6000 of 8000, loss=0.195, LR=0.00034549150281252633
# Validation Loss = 0.011
# Channel 6H, Epoch=4, batch = 7000 of 8000, loss=0.131, LR=0.00034549150281252633
# Validation Loss = 0.001
# Channel 6H, Epoch=5, batch = 0 of 8000, loss=0.159, LR=9.549150281252633e-05
# Validation Loss = 0.026
# Channel 6H, Epoch=5, batch = 1000 of 8000, loss=0.136, LR=9.549150281252633e-05
# Validation Loss = 0.028
# Channel 6H, Epoch=5, batch = 2000 of 8000, loss=0.140, LR=9.549150281252633e-05
# Validation Loss = 0.009
# Channel 6H, Epoch=5, batch = 3000 of 8000, loss=0.145, LR=9.549150281252633e-05
# Validation Loss = 0.066
# Channel 6H, Epoch=5, batch = 4000 of 8000, loss=0.166, LR=9.549150281252633e-05
# Validation Loss = 0.013
# Channel 6H, Epoch=5, batch = 5000 of 8000, loss=0.141, LR=9.549150281252633e-05
# Validation Loss = 0.064
# Channel 6H, Epoch=5, batch = 6000 of 8000, loss=0.145, LR=9.549150281252633e-05
# Validation Loss = 0.080
# Channel 6H, Epoch=5, batch = 7000 of 8000, loss=0.170, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.052
# Channel 6H, Epoch=1, batch = 0 of 8000, loss=0.125, LR=0.001
# Validation Loss = 0.045
# Channel 6H, Epoch=1, batch = 1000 of 8000, loss=0.142, LR=0.001
# Validation Loss = 0.070
# Channel 6H, Epoch=1, batch = 2000 of 8000, loss=0.292, LR=0.001
# Validation Loss = 0.177
# Channel 6H, Epoch=1, batch = 3000 of 8000, loss=0.445, LR=0.001
# Validation Loss = 0.031
# Channel 6H, Epoch=1, batch = 4000 of 8000, loss=0.131, LR=0.001
# Validation Loss = 0.323
# Channel 6H, Epoch=1, batch = 5000 of 8000, loss=0.413, LR=0.001
# Validation Loss = 0.308
# Channel 6H, Epoch=1, batch = 6000 of 8000, loss=0.638, LR=0.001
# Validation Loss = 0.004
# Channel 6H, Epoch=1, batch = 7000 of 8000, loss=0.214, LR=0.001
# Validation Loss = 0.157
# Channel 6H, Epoch=2, batch = 0 of 8000, loss=0.215, LR=0.0009755282581475768
# Validation Loss = 0.077
# Channel 6H, Epoch=2, batch = 1000 of 8000, loss=0.190, LR=0.0009755282581475768
# Validation Loss = 0.403
# Channel 6H, Epoch=2, batch = 2000 of 8000, loss=0.462, LR=0.0009755282581475768
# Validation Loss = 0.037
# Channel 6H, Epoch=2, batch = 3000 of 8000, loss=0.253, LR=0.0009755282581475768
# Validation Loss = 0.018
# Channel 6H, Epoch=2, batch = 4000 of 8000, loss=0.225, LR=0.0009755282581475768
# Validation Loss = 0.012
# Channel 6H, Epoch=2, batch = 5000 of 8000, loss=0.128, LR=0.0009755282581475768
# Validation Loss = 0.906
# Channel 6H, Epoch=2, batch = 6000 of 8000, loss=0.879, LR=0.0009755282581475768
# Validation Loss = 0.007
# Channel 6H, Epoch=2, batch = 7000 of 8000, loss=0.134, LR=0.0009755282581475768
# Validation Loss = 0.000
# Channel 6H, Epoch=3, batch = 0 of 8000, loss=0.134, LR=0.0009045084971874736
# Validation Loss = 0.007
# Channel 6H, Epoch=3, batch = 1000 of 8000, loss=0.174, LR=0.0009045084971874736
# Validation Loss = 0.003
# Channel 6H, Epoch=3, batch = 2000 of 8000, loss=0.153, LR=0.0009045084971874736
# Validation Loss = 0.007
# Channel 6H, Epoch=3, batch = 3000 of 8000, loss=0.172, LR=0.0009045084971874736
# Validation Loss = 0.147
# Channel 6H, Epoch=3, batch = 4000 of 8000, loss=0.203, LR=0.0009045084971874736
# Validation Loss = 0.094
# Channel 6H, Epoch=3, batch = 5000 of 8000, loss=0.258, LR=0.0009045084971874736
# Validation Loss = 0.137
# Channel 6H, Epoch=3, batch = 6000 of 8000, loss=0.389, LR=0.0009045084971874736
# Validation Loss = 0.004
# Channel 6H, Epoch=3, batch = 7000 of 8000, loss=0.187, LR=0.0009045084971874736
# Validation Loss = 0.349
# Channel 6H, Epoch=4, batch = 0 of 8000, loss=0.341, LR=0.0007938926261462366
# Validation Loss = 0.064
# Channel 6H, Epoch=4, batch = 1000 of 8000, loss=0.268, LR=0.0007938926261462366
# Validation Loss = 0.114
# Channel 6H, Epoch=4, batch = 2000 of 8000, loss=0.206, LR=0.0007938926261462366
# Validation Loss = 0.093
# Channel 6H, Epoch=4, batch = 3000 of 8000, loss=0.169, LR=0.0007938926261462366
# Validation Loss = 0.000
# Channel 6H, Epoch=4, batch = 4000 of 8000, loss=0.171, LR=0.0007938926261462366
# Validation Loss = 0.137
# Channel 6H, Epoch=4, batch = 5000 of 8000, loss=0.155, LR=0.0007938926261462366
# Validation Loss = 0.027
# Channel 6H, Epoch=4, batch = 6000 of 8000, loss=0.152, LR=0.0007938926261462366
# Validation Loss = 0.008
# Channel 6H, Epoch=4, batch = 7000 of 8000, loss=0.212, LR=0.0007938926261462366
# Validation Loss = 0.000
# Channel 6H, Epoch=5, batch = 0 of 8000, loss=0.155, LR=0.0006545084971874737
# Validation Loss = 0.028
# Channel 6H, Epoch=5, batch = 1000 of 8000, loss=0.138, LR=0.0006545084971874737
# Validation Loss = 0.007
# Channel 6H, Epoch=5, batch = 2000 of 8000, loss=0.142, LR=0.0006545084971874737
# Validation Loss = 0.137
# Channel 6H, Epoch=5, batch = 3000 of 8000, loss=0.326, LR=0.0006545084971874737
# Validation Loss = 0.000
# Channel 6H, Epoch=5, batch = 4000 of 8000, loss=0.217, LR=0.0006545084971874737
# Validation Loss = 0.001
# Channel 6H, Epoch=5, batch = 5000 of 8000, loss=0.180, LR=0.0006545084971874737
# Validation Loss = 0.000
# Channel 6H, Epoch=5, batch = 6000 of 8000, loss=0.181, LR=0.0006545084971874737
# Validation Loss = 0.003
# Channel 6H, Epoch=5, batch = 7000 of 8000, loss=0.168, LR=0.0006545084971874737
# Validation Loss = 0.107
# Channel 6H, Epoch=6, batch = 0 of 8000, loss=0.172, LR=0.0005
# Validation Loss = 0.108
# Channel 6H, Epoch=6, batch = 1000 of 8000, loss=0.171, LR=0.0005
# Validation Loss = 0.035
# Channel 6H, Epoch=6, batch = 2000 of 8000, loss=0.148, LR=0.0005
# Validation Loss = 0.035
# Channel 6H, Epoch=6, batch = 3000 of 8000, loss=0.141, LR=0.0005
# Validation Loss = 0.053
# Channel 6H, Epoch=6, batch = 4000 of 8000, loss=0.167, LR=0.0005
# Validation Loss = 0.166
# Channel 6H, Epoch=6, batch = 5000 of 8000, loss=0.200, LR=0.0005
# Validation Loss = 0.050
# Channel 6H, Epoch=6, batch = 6000 of 8000, loss=0.143, LR=0.0005
# Validation Loss = 0.005
# Channel 6H, Epoch=6, batch = 7000 of 8000, loss=0.196, LR=0.0005
# Validation Loss = 0.046
# Channel 6H, Epoch=7, batch = 0 of 8000, loss=0.162, LR=0.00034549150281252633
# Validation Loss = 0.071
# Channel 6H, Epoch=7, batch = 1000 of 8000, loss=0.138, LR=0.00034549150281252633
# Validation Loss = 0.124
# Channel 6H, Epoch=7, batch = 2000 of 8000, loss=0.169, LR=0.00034549150281252633
# Validation Loss = 0.215
# Channel 6H, Epoch=7, batch = 3000 of 8000, loss=0.168, LR=0.00034549150281252633
# Validation Loss = 0.008
# Channel 6H, Epoch=7, batch = 4000 of 8000, loss=0.162, LR=0.00034549150281252633
# Validation Loss = 0.034
# Channel 6H, Epoch=7, batch = 5000 of 8000, loss=0.128, LR=0.00034549150281252633
# Validation Loss = 0.055
# Channel 6H, Epoch=7, batch = 6000 of 8000, loss=0.156, LR=0.00034549150281252633
# Validation Loss = 0.085
# Channel 6H, Epoch=7, batch = 7000 of 8000, loss=0.150, LR=0.00034549150281252633
# Validation Loss = 0.000
# Channel 6H, Epoch=8, batch = 0 of 8000, loss=0.168, LR=0.0002061073738537635
# Validation Loss = 0.088
# Channel 6H, Epoch=8, batch = 1000 of 8000, loss=0.129, LR=0.0002061073738537635
# Validation Loss = 0.014
# Channel 6H, Epoch=8, batch = 2000 of 8000, loss=0.149, LR=0.0002061073738537635
# Validation Loss = 0.059
# Channel 6H, Epoch=8, batch = 3000 of 8000, loss=0.149, LR=0.0002061073738537635
# Validation Loss = 0.040
# Channel 6H, Epoch=8, batch = 4000 of 8000, loss=0.134, LR=0.0002061073738537635
# Validation Loss = 0.119
# Channel 6H, Epoch=8, batch = 5000 of 8000, loss=0.141, LR=0.0002061073738537635
# Validation Loss = 0.025
# Channel 6H, Epoch=8, batch = 6000 of 8000, loss=0.139, LR=0.0002061073738537635
# Validation Loss = 0.108
# Channel 6H, Epoch=8, batch = 7000 of 8000, loss=0.159, LR=0.0002061073738537635
# Validation Loss = 0.123
# Channel 6H, Epoch=9, batch = 0 of 8000, loss=0.139, LR=9.549150281252634e-05
# Validation Loss = 0.074
# Channel 6H, Epoch=9, batch = 1000 of 8000, loss=0.144, LR=9.549150281252634e-05
# Validation Loss = 0.043
# Channel 6H, Epoch=9, batch = 2000 of 8000, loss=0.143, LR=9.549150281252634e-05
# Validation Loss = 0.037
# Channel 6H, Epoch=9, batch = 3000 of 8000, loss=0.122, LR=9.549150281252634e-05
# Validation Loss = 0.022
# Channel 6H, Epoch=9, batch = 4000 of 8000, loss=0.152, LR=9.549150281252634e-05
# Validation Loss = 0.017
# Channel 6H, Epoch=9, batch = 5000 of 8000, loss=0.137, LR=9.549150281252634e-05
# Validation Loss = 0.029
# Channel 6H, Epoch=9, batch = 6000 of 8000, loss=0.135, LR=9.549150281252634e-05
# Validation Loss = 0.084
# Channel 6H, Epoch=9, batch = 7000 of 8000, loss=0.142, LR=9.549150281252634e-05
# Validation Loss = 0.025
# Channel 6H, Epoch=10, batch = 0 of 8000, loss=0.124, LR=2.4471741852423235e-05
# Validation Loss = 0.032
# Channel 6H, Epoch=10, batch = 1000 of 8000, loss=0.129, LR=2.4471741852423235e-05
# Validation Loss = 0.043
# Channel 6H, Epoch=10, batch = 2000 of 8000, loss=0.129, LR=2.4471741852423235e-05
# Validation Loss = 0.049
# Channel 6H, Epoch=10, batch = 3000 of 8000, loss=0.157, LR=2.4471741852423235e-05
# Validation Loss = 0.037
# Channel 6H, Epoch=10, batch = 4000 of 8000, loss=0.136, LR=2.4471741852423235e-05
# Validation Loss = 0.045
# Channel 6H, Epoch=10, batch = 5000 of 8000, loss=0.142, LR=2.4471741852423235e-05
# Validation Loss = 0.057
# Channel 6H, Epoch=10, batch = 6000 of 8000, loss=0.130, LR=2.4471741852423235e-05
# Validation Loss = 0.048
# Channel 6H, Epoch=10, batch = 7000 of 8000, loss=0.141, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.033
# Channel 6H, Epoch=1, batch = 0 of 8000, loss=0.136, LR=0.001
# Validation Loss = 0.196
# Channel 6H, Epoch=1, batch = 1000 of 8000, loss=0.183, LR=0.001
# Validation Loss = 0.105
# Channel 6H, Epoch=1, batch = 2000 of 8000, loss=0.205, LR=0.001
# Validation Loss = 0.031
# Channel 6H, Epoch=1, batch = 3000 of 8000, loss=0.135, LR=0.001
# Validation Loss = 0.263
# Channel 6H, Epoch=1, batch = 4000 of 8000, loss=0.229, LR=0.001
# Validation Loss = 0.189
# Channel 6H, Epoch=1, batch = 5000 of 8000, loss=0.183, LR=0.001
# Validation Loss = 0.176
# Channel 6H, Epoch=1, batch = 6000 of 8000, loss=0.186, LR=0.001
# Validation Loss = 0.005
# Channel 6H, Epoch=1, batch = 7000 of 8000, loss=0.160, LR=0.001
# Validation Loss = 0.028
# Channel 6H, Epoch=2, batch = 0 of 8000, loss=0.150, LR=0.0009938441702975688
# Validation Loss = 0.064
# Channel 6H, Epoch=2, batch = 1000 of 8000, loss=0.157, LR=0.0009938441702975688
# Validation Loss = 0.017
# Channel 6H, Epoch=2, batch = 2000 of 8000, loss=0.259, LR=0.0009938441702975688
# Validation Loss = 0.000
# Channel 6H, Epoch=2, batch = 3000 of 8000, loss=0.195, LR=0.0009938441702975688
# Validation Loss = 0.190
# Channel 6H, Epoch=2, batch = 4000 of 8000, loss=0.227, LR=0.0009938441702975688
# Validation Loss = 0.002
# Channel 6H, Epoch=2, batch = 5000 of 8000, loss=0.156, LR=0.0009938441702975688
# Validation Loss = 0.044
# Channel 6H, Epoch=2, batch = 6000 of 8000, loss=0.137, LR=0.0009938441702975688
# Validation Loss = 0.182
# Channel 6H, Epoch=2, batch = 7000 of 8000, loss=0.490, LR=0.0009938441702975688
# Validation Loss = 0.017
# Channel 6H, Epoch=3, batch = 0 of 8000, loss=0.159, LR=0.0009755282581475768
# Validation Loss = 0.123
# Channel 6H, Epoch=3, batch = 1000 of 8000, loss=0.173, LR=0.0009755282581475768
# Validation Loss = 0.143
# Channel 6H, Epoch=3, batch = 2000 of 8000, loss=0.186, LR=0.0009755282581475768
# Validation Loss = 0.066
# Channel 6H, Epoch=3, batch = 3000 of 8000, loss=0.169, LR=0.0009755282581475768
# Validation Loss = 0.203
# Channel 6H, Epoch=3, batch = 4000 of 8000, loss=0.243, LR=0.0009755282581475768
# Validation Loss = 0.014
# Channel 6H, Epoch=3, batch = 5000 of 8000, loss=0.215, LR=0.0009755282581475768
# Validation Loss = 0.011
# Channel 6H, Epoch=3, batch = 6000 of 8000, loss=0.191, LR=0.0009755282581475768
# Validation Loss = 0.112
# Channel 6H, Epoch=3, batch = 7000 of 8000, loss=0.215, LR=0.0009755282581475768
# Validation Loss = 0.006
# Channel 6H, Epoch=4, batch = 0 of 8000, loss=0.168, LR=0.0009455032620941839
# Validation Loss = 0.311
# Channel 6H, Epoch=4, batch = 1000 of 8000, loss=0.339, LR=0.0009455032620941839
# Validation Loss = 0.109
# Channel 6H, Epoch=4, batch = 2000 of 8000, loss=0.163, LR=0.0009455032620941839
# Validation Loss = 0.182
# Channel 6H, Epoch=4, batch = 3000 of 8000, loss=0.214, LR=0.0009455032620941839
# Validation Loss = 0.003
# Channel 6H, Epoch=4, batch = 4000 of 8000, loss=0.168, LR=0.0009455032620941839
# Validation Loss = 0.004
# Channel 6H, Epoch=4, batch = 5000 of 8000, loss=0.146, LR=0.0009455032620941839
# Validation Loss = 0.202
# Channel 6H, Epoch=4, batch = 6000 of 8000, loss=0.198, LR=0.0009455032620941839
# Validation Loss = 0.019
# Channel 6H, Epoch=4, batch = 7000 of 8000, loss=0.134, LR=0.0009455032620941839
# Validation Loss = 0.006
# Channel 6H, Epoch=5, batch = 0 of 8000, loss=0.223, LR=0.0009045084971874737
# Validation Loss = 0.001
# Channel 6H, Epoch=5, batch = 1000 of 8000, loss=0.145, LR=0.0009045084971874737
# Validation Loss = 0.123
# Channel 6H, Epoch=5, batch = 2000 of 8000, loss=0.199, LR=0.0009045084971874737
# Validation Loss = 0.229
# Channel 6H, Epoch=5, batch = 3000 of 8000, loss=0.240, LR=0.0009045084971874737
# Validation Loss = 0.051
# Channel 6H, Epoch=5, batch = 4000 of 8000, loss=0.257, LR=0.0009045084971874737
# Validation Loss = 0.005
# Channel 6H, Epoch=5, batch = 5000 of 8000, loss=0.134, LR=0.0009045084971874737
# Validation Loss = 0.000
# Channel 6H, Epoch=5, batch = 6000 of 8000, loss=0.128, LR=0.0009045084971874737
# Validation Loss = 0.054
# Channel 6H, Epoch=5, batch = 7000 of 8000, loss=0.121, LR=0.0009045084971874737
# Validation Loss = 0.111
# Channel 6H, Epoch=6, batch = 0 of 8000, loss=0.176, LR=0.0008535533905932737
# Validation Loss = 0.007
# Channel 6H, Epoch=6, batch = 1000 of 8000, loss=0.142, LR=0.0008535533905932737
# Validation Loss = 0.063
# Channel 6H, Epoch=6, batch = 2000 of 8000, loss=0.141, LR=0.0008535533905932737
# Validation Loss = 0.159
# Channel 6H, Epoch=6, batch = 3000 of 8000, loss=0.280, LR=0.0008535533905932737
# Validation Loss = 0.039
# Channel 6H, Epoch=6, batch = 4000 of 8000, loss=0.143, LR=0.0008535533905932737
# Validation Loss = 0.005
# Channel 6H, Epoch=6, batch = 5000 of 8000, loss=0.212, LR=0.0008535533905932737
# Validation Loss = 0.016
# Channel 6H, Epoch=6, batch = 6000 of 8000, loss=0.143, LR=0.0008535533905932737
# Validation Loss = 0.078
# Channel 6H, Epoch=6, batch = 7000 of 8000, loss=0.167, LR=0.0008535533905932737
# Validation Loss = 0.000
# Channel 6H, Epoch=7, batch = 0 of 8000, loss=0.164, LR=0.0007938926261462366
# Validation Loss = 0.296
# Channel 6H, Epoch=7, batch = 1000 of 8000, loss=0.233, LR=0.0007938926261462366
# Validation Loss = 0.024
# Channel 6H, Epoch=7, batch = 2000 of 8000, loss=0.131, LR=0.0007938926261462366
# Validation Loss = 0.012
# Channel 6H, Epoch=7, batch = 3000 of 8000, loss=0.200, LR=0.0007938926261462366
# Validation Loss = 0.016
# Channel 6H, Epoch=7, batch = 4000 of 8000, loss=0.140, LR=0.0007938926261462366
# Validation Loss = 0.167
# Channel 6H, Epoch=7, batch = 5000 of 8000, loss=0.207, LR=0.0007938926261462366
# Validation Loss = 0.051
# Channel 6H, Epoch=7, batch = 6000 of 8000, loss=0.141, LR=0.0007938926261462366
# Validation Loss = 0.052
# Channel 6H, Epoch=7, batch = 7000 of 8000, loss=0.151, LR=0.0007938926261462366
# Validation Loss = 0.022
# Channel 6H, Epoch=8, batch = 0 of 8000, loss=0.168, LR=0.0007269952498697733
# Validation Loss = 0.022
# Channel 6H, Epoch=8, batch = 1000 of 8000, loss=0.123, LR=0.0007269952498697733
# Validation Loss = 0.018
# Channel 6H, Epoch=8, batch = 2000 of 8000, loss=0.151, LR=0.0007269952498697733
# Validation Loss = 0.053
# Channel 6H, Epoch=8, batch = 3000 of 8000, loss=0.138, LR=0.0007269952498697733
# Validation Loss = 0.000
# Channel 6H, Epoch=8, batch = 4000 of 8000, loss=0.185, LR=0.0007269952498697733
# Validation Loss = 0.003
# Channel 6H, Epoch=8, batch = 5000 of 8000, loss=0.148, LR=0.0007269952498697733
# Validation Loss = 0.028
# Channel 6H, Epoch=8, batch = 6000 of 8000, loss=0.208, LR=0.0007269952498697733
# Validation Loss = 0.143
# Channel 6H, Epoch=8, batch = 7000 of 8000, loss=0.180, LR=0.0007269952498697733
# Validation Loss = 0.083
# Channel 6H, Epoch=9, batch = 0 of 8000, loss=0.152, LR=0.0006545084971874737
# Validation Loss = 0.001
# Channel 6H, Epoch=9, batch = 1000 of 8000, loss=0.173, LR=0.0006545084971874737
# Validation Loss = 0.033
# Channel 6H, Epoch=9, batch = 2000 of 8000, loss=0.127, LR=0.0006545084971874737
# Validation Loss = 0.036
# Channel 6H, Epoch=9, batch = 3000 of 8000, loss=0.129, LR=0.0006545084971874737
# Validation Loss = 0.046
# Channel 6H, Epoch=9, batch = 4000 of 8000, loss=0.139, LR=0.0006545084971874737
# Validation Loss = 0.000
# Channel 6H, Epoch=9, batch = 5000 of 8000, loss=0.178, LR=0.0006545084971874737
# Validation Loss = 0.005
# ...
# Validation Loss = 0.465
# Channel 37H, Epoch=2, batch = 0 of 8000, loss=1.621, LR=0.0009938441702975688
# Validation Loss = 0.160
# Channel 37H, Epoch=2, batch = 1000 of 8000, loss=3.138, LR=0.0009938441702975688
# Validation Loss = 2.337
# Channel 37H, Epoch=2, batch = 2000 of 8000, loss=1.896, LR=0.0009938441702975688
# Validation Loss = 0.246
# Channel 37H, Epoch=2, batch = 3000 of 8000, loss=1.564, LR=0.0009938441702975688
# Validation Loss = 1.064
# Channel 37H, Epoch=2, batch = 4000 of 8000, loss=1.725, LR=0.0009938441702975688
# Validation Loss = 0.628
# Channel 37H, Epoch=2, batch = 5000 of 8000, loss=1.578, LR=0.0009938441702975688
# Validation Loss = 1.546
# Channel 37H, Epoch=2, batch = 6000 of 8000, loss=1.694, LR=0.0009938441702975688
# Validation Loss = 1.412
# Channel 37H, Epoch=2, batch = 7000 of 8000, loss=1.379, LR=0.0009938441702975688
# Validation Loss = 2.719
# Channel 37H, Epoch=3, batch = 0 of 8000, loss=2.050, LR=0.0009755282581475768
# Validation Loss = 0.124
# Channel 37H, Epoch=3, batch = 1000 of 8000, loss=2.877, LR=0.0009755282581475768
# Validation Loss = 0.608
# Channel 37H, Epoch=3, batch = 2000 of 8000, loss=1.684, LR=0.0009755282581475768
# Validation Loss = 0.050
# Channel 37H, Epoch=3, batch = 3000 of 8000, loss=2.099, LR=0.0009755282581475768
# Validation Loss = 0.754
# Channel 37H, Epoch=3, batch = 4000 of 8000, loss=1.630, LR=0.0009755282581475768
# Validation Loss = 0.485
# Channel 37H, Epoch=3, batch = 5000 of 8000, loss=2.037, LR=0.0009755282581475768
# Validation Loss = 0.000
# Channel 37H, Epoch=3, batch = 6000 of 8000, loss=2.216, LR=0.0009755282581475768
# Validation Loss = 0.021
# Channel 37H, Epoch=3, batch = 7000 of 8000, loss=2.747, LR=0.0009755282581475768
# Validation Loss = 0.016
# Channel 37H, Epoch=4, batch = 0 of 8000, loss=1.796, LR=0.0009455032620941839
# Validation Loss = 0.002
# Channel 37H, Epoch=4, batch = 1000 of 8000, loss=2.014, LR=0.0009455032620941839
# Validation Loss = 1.048
# Channel 37H, Epoch=4, batch = 2000 of 8000, loss=1.568, LR=0.0009455032620941839
# Validation Loss = 0.616
# Channel 37H, Epoch=4, batch = 3000 of 8000, loss=1.685, LR=0.0009455032620941839
# Validation Loss = 0.622
# Channel 37H, Epoch=4, batch = 4000 of 8000, loss=1.590, LR=0.0009455032620941839
# Validation Loss = 3.650
# Channel 37H, Epoch=4, batch = 5000 of 8000, loss=2.079, LR=0.0009455032620941839
# Validation Loss = 0.036
# Channel 37H, Epoch=4, batch = 6000 of 8000, loss=2.297, LR=0.0009455032620941839
# Validation Loss = 3.207
# Channel 37H, Epoch=4, batch = 7000 of 8000, loss=1.815, LR=0.0009455032620941839
# Validation Loss = 0.211
# Channel 37H, Epoch=5, batch = 0 of 8000, loss=2.372, LR=0.0009045084971874737
# Validation Loss = 2.238
# Channel 37H, Epoch=5, batch = 1000 of 8000, loss=1.558, LR=0.0009045084971874737
# Validation Loss = 0.000
# Channel 37H, Epoch=5, batch = 2000 of 8000, loss=1.960, LR=0.0009045084971874737
# Validation Loss = 1.206
# Channel 37H, Epoch=5, batch = 3000 of 8000, loss=1.411, LR=0.0009045084971874737
# Validation Loss = 1.588
# Channel 37H, Epoch=5, batch = 4000 of 8000, loss=1.626, LR=0.0009045084971874737
# Validation Loss = 0.106
# Channel 37H, Epoch=5, batch = 5000 of 8000, loss=1.655, LR=0.0009045084971874737
# Validation Loss = 0.592
# Channel 37H, Epoch=5, batch = 6000 of 8000, loss=1.393, LR=0.0009045084971874737
# Validation Loss = 0.057
# Channel 37H, Epoch=5, batch = 7000 of 8000, loss=1.651, LR=0.0009045084971874737
# Validation Loss = 0.786
# Channel 37H, Epoch=6, batch = 0 of 8000, loss=1.327, LR=0.0008535533905932737
# Validation Loss = 0.038
# Channel 37H, Epoch=6, batch = 1000 of 8000, loss=2.301, LR=0.0008535533905932737
# Validation Loss = 0.833
# Channel 37H, Epoch=6, batch = 2000 of 8000, loss=1.458, LR=0.0008535533905932737
# Validation Loss = 0.630
# Channel 37H, Epoch=6, batch = 3000 of 8000, loss=1.212, LR=0.0008535533905932737
# Validation Loss = 0.394
# Channel 37H, Epoch=6, batch = 4000 of 8000, loss=1.437, LR=0.0008535533905932737
# Validation Loss = 0.360
# Channel 37H, Epoch=6, batch = 5000 of 8000, loss=1.795, LR=0.0008535533905932737
# Validation Loss = 1.565
# Channel 37H, Epoch=6, batch = 6000 of 8000, loss=1.448, LR=0.0008535533905932737
# Validation Loss = 0.241
# Channel 37H, Epoch=6, batch = 7000 of 8000, loss=1.754, LR=0.0008535533905932737
# Validation Loss = 1.625
# Channel 37H, Epoch=7, batch = 0 of 8000, loss=1.588, LR=0.0007938926261462366
# Validation Loss = 0.664
# Channel 37H, Epoch=7, batch = 1000 of 8000, loss=1.374, LR=0.0007938926261462366
# Validation Loss = 1.833
# Channel 37H, Epoch=7, batch = 2000 of 8000, loss=1.481, LR=0.0007938926261462366
# Validation Loss = 0.902
# Channel 37H, Epoch=7, batch = 3000 of 8000, loss=1.350, LR=0.0007938926261462366
# Validation Loss = 2.286
# Channel 37H, Epoch=7, batch = 4000 of 8000, loss=1.533, LR=0.0007938926261462366
# Validation Loss = 2.184
# Channel 37H, Epoch=7, batch = 5000 of 8000, loss=1.631, LR=0.0007938926261462366
# Validation Loss = 0.768
# Channel 37H, Epoch=7, batch = 6000 of 8000, loss=1.413, LR=0.0007938926261462366
# Validation Loss = 0.782
# Channel 37H, Epoch=7, batch = 7000 of 8000, loss=1.286, LR=0.0007938926261462366
# Validation Loss = 5.214
# Channel 37H, Epoch=8, batch = 0 of 8000, loss=2.566, LR=0.0007269952498697733
# Validation Loss = 0.535
# Channel 37H, Epoch=8, batch = 1000 of 8000, loss=1.569, LR=0.0007269952498697733
# Validation Loss = 0.208
# Channel 37H, Epoch=8, batch = 2000 of 8000, loss=1.676, LR=0.0007269952498697733
# Validation Loss = 1.061
# Channel 37H, Epoch=8, batch = 3000 of 8000, loss=1.471, LR=0.0007269952498697733
# Validation Loss = 0.521
# Channel 37H, Epoch=8, batch = 4000 of 8000, loss=1.619, LR=0.0007269952498697733
# Validation Loss = 1.494
# Channel 37H, Epoch=8, batch = 5000 of 8000, loss=1.385, LR=0.0007269952498697733
# Validation Loss = 1.364
# Channel 37H, Epoch=8, batch = 6000 of 8000, loss=1.426, LR=0.0007269952498697733
# Validation Loss = 0.742
# Channel 37H, Epoch=8, batch = 7000 of 8000, loss=1.607, LR=0.0007269952498697733
# Validation Loss = 2.046
# Channel 37H, Epoch=9, batch = 0 of 8000, loss=1.326, LR=0.0006545084971874737
# Validation Loss = 3.030
# Channel 37H, Epoch=9, batch = 1000 of 8000, loss=1.747, LR=0.0006545084971874737
# Validation Loss = 1.226
# Channel 37H, Epoch=9, batch = 2000 of 8000, loss=1.284, LR=0.0006545084971874737
# Validation Loss = 0.915
# Channel 37H, Epoch=9, batch = 3000 of 8000, loss=1.513, LR=0.0006545084971874737
# Validation Loss = 1.888
# Channel 37H, Epoch=9, batch = 4000 of 8000, loss=1.524, LR=0.0006545084971874737
# Validation Loss = 0.527
# Channel 37H, Epoch=9, batch = 5000 of 8000, loss=1.485, LR=0.0006545084971874737
# Validation Loss = 3.472
# Channel 37H, Epoch=9, batch = 6000 of 8000, loss=1.822, LR=0.0006545084971874737
# Validation Loss = 0.785
# Channel 37H, Epoch=9, batch = 7000 of 8000, loss=1.646, LR=0.0006545084971874737
# Validation Loss = 2.593
# Channel 37H, Epoch=10, batch = 0 of 8000, loss=1.623, LR=0.0005782172325201155
# Validation Loss = 0.519
# Channel 37H, Epoch=10, batch = 1000 of 8000, loss=1.602, LR=0.0005782172325201155
# Validation Loss = 0.964
# Channel 37H, Epoch=10, batch = 2000 of 8000, loss=1.270, LR=0.0005782172325201155
# Validation Loss = 0.731
# Channel 37H, Epoch=10, batch = 3000 of 8000, loss=1.554, LR=0.0005782172325201155
# Validation Loss = 1.961
# Channel 37H, Epoch=10, batch = 4000 of 8000, loss=1.569, LR=0.0005782172325201155
# Validation Loss = 0.963
# Channel 37H, Epoch=10, batch = 5000 of 8000, loss=1.444, LR=0.0005782172325201155
# Validation Loss = 1.405
# Channel 37H, Epoch=10, batch = 6000 of 8000, loss=1.472, LR=0.0005782172325201155
# Validation Loss = 5.757
# Channel 37H, Epoch=10, batch = 7000 of 8000, loss=2.510, LR=0.0005782172325201155
# Validation Loss = 2.456
# Channel 37H, Epoch=11, batch = 0 of 8000, loss=1.530, LR=0.0005
# Validation Loss = 1.974
# Channel 37H, Epoch=11, batch = 1000 of 8000, loss=1.482, LR=0.0005
# Validation Loss = 1.624
# Channel 37H, Epoch=11, batch = 2000 of 8000, loss=1.524, LR=0.0005
# Validation Loss = 0.971
# Channel 37H, Epoch=11, batch = 3000 of 8000, loss=1.428, LR=0.0005
# Validation Loss = 1.513
# Channel 37H, Epoch=11, batch = 4000 of 8000, loss=1.418, LR=0.0005
# Validation Loss = 0.317
# Channel 37H, Epoch=11, batch = 5000 of 8000, loss=1.644, LR=0.0005
# Validation Loss = 1.856
# Channel 37H, Epoch=11, batch = 6000 of 8000, loss=1.488, LR=0.0005
# Validation Loss = 1.771
# Channel 37H, Epoch=11, batch = 7000 of 8000, loss=1.580, LR=0.0005
# Validation Loss = 0.659
# Channel 37H, Epoch=12, batch = 0 of 8000, loss=1.489, LR=0.0004217827674798847
# Validation Loss = 1.660
# Channel 37H, Epoch=12, batch = 1000 of 8000, loss=1.597, LR=0.0004217827674798847
# Validation Loss = 2.223
# Channel 37H, Epoch=12, batch = 2000 of 8000, loss=1.389, LR=0.0004217827674798847
# Validation Loss = 2.820
# Channel 37H, Epoch=12, batch = 3000 of 8000, loss=1.393, LR=0.0004217827674798847
# Validation Loss = 1.918
# Channel 37H, Epoch=12, batch = 4000 of 8000, loss=1.482, LR=0.0004217827674798847
# Validation Loss = 1.528
# Channel 37H, Epoch=12, batch = 5000 of 8000, loss=1.311, LR=0.0004217827674798847
# Validation Loss = 1.225
# Channel 37H, Epoch=12, batch = 6000 of 8000, loss=1.253, LR=0.0004217827674798847
# Validation Loss = 1.070
# Channel 37H, Epoch=12, batch = 7000 of 8000, loss=1.407, LR=0.0004217827674798847
# Validation Loss = 2.140
# Channel 37H, Epoch=13, batch = 0 of 8000, loss=1.377, LR=0.00034549150281252633
# Validation Loss = 1.123
# Channel 37H, Epoch=13, batch = 1000 of 8000, loss=1.309, LR=0.00034549150281252633
# Validation Loss = 2.296
# Channel 37H, Epoch=13, batch = 2000 of 8000, loss=1.500, LR=0.00034549150281252633
# Validation Loss = 1.374
# Channel 37H, Epoch=13, batch = 3000 of 8000, loss=1.347, LR=0.00034549150281252633
# Validation Loss = 1.412
# Channel 37H, Epoch=13, batch = 4000 of 8000, loss=1.904, LR=0.00034549150281252633
# Validation Loss = 2.189
# Channel 37H, Epoch=13, batch = 5000 of 8000, loss=1.604, LR=0.00034549150281252633
# Validation Loss = 1.107
# Channel 37H, Epoch=13, batch = 6000 of 8000, loss=1.467, LR=0.00034549150281252633
# Validation Loss = 0.978
# Channel 37H, Epoch=13, batch = 7000 of 8000, loss=1.375, LR=0.00034549150281252633
# Validation Loss = 0.684
# Channel 37H, Epoch=14, batch = 0 of 8000, loss=1.489, LR=0.00027300475013022663
# Validation Loss = 1.281
# Channel 37H, Epoch=14, batch = 1000 of 8000, loss=1.441, LR=0.00027300475013022663
# Validation Loss = 2.040
# Channel 37H, Epoch=14, batch = 2000 of 8000, loss=1.290, LR=0.00027300475013022663
# Validation Loss = 1.339
# Channel 37H, Epoch=14, batch = 3000 of 8000, loss=1.330, LR=0.00027300475013022663
# Validation Loss = 0.983
# Channel 37H, Epoch=14, batch = 4000 of 8000, loss=1.539, LR=0.00027300475013022663
# Validation Loss = 2.571
# Channel 37H, Epoch=14, batch = 5000 of 8000, loss=1.664, LR=0.00027300475013022663
# Validation Loss = 0.942
# Channel 37H, Epoch=14, batch = 6000 of 8000, loss=1.309, LR=0.00027300475013022663
# Validation Loss = 1.442
# Channel 37H, Epoch=14, batch = 7000 of 8000, loss=1.554, LR=0.00027300475013022663
# Validation Loss = 2.490
# Channel 37H, Epoch=15, batch = 0 of 8000, loss=1.726, LR=0.00020610737385376348
# Validation Loss = 2.019
# Channel 37H, Epoch=15, batch = 1000 of 8000, loss=1.498, LR=0.00020610737385376348
# Validation Loss = 1.758
# Channel 37H, Epoch=15, batch = 2000 of 8000, loss=1.518, LR=0.00020610737385376348
# Validation Loss = 1.951
# Channel 37H, Epoch=15, batch = 3000 of 8000, loss=1.308, LR=0.00020610737385376348
# Validation Loss = 1.538
# Channel 37H, Epoch=15, batch = 4000 of 8000, loss=1.300, LR=0.00020610737385376348
# Validation Loss = 0.609
# Channel 37H, Epoch=15, batch = 5000 of 8000, loss=1.491, LR=0.00020610737385376348
# Validation Loss = 0.320
# Channel 37H, Epoch=15, batch = 6000 of 8000, loss=1.781, LR=0.00020610737385376348
# Validation Loss = 0.875
# Channel 37H, Epoch=15, batch = 7000 of 8000, loss=2.694, LR=0.00020610737385376348
# Validation Loss = 1.333
# Channel 37H, Epoch=16, batch = 0 of 8000, loss=1.202, LR=0.00014644660940672625
# Validation Loss = 1.485
# Channel 37H, Epoch=16, batch = 1000 of 8000, loss=1.332, LR=0.00014644660940672625
# Validation Loss = 1.659
# Channel 37H, Epoch=16, batch = 2000 of 8000, loss=1.430, LR=0.00014644660940672625
# Validation Loss = 1.358
# Channel 37H, Epoch=16, batch = 3000 of 8000, loss=1.499, LR=0.00014644660940672625
# Validation Loss = 0.903
# Channel 37H, Epoch=16, batch = 4000 of 8000, loss=1.553, LR=0.00014644660940672625
# Validation Loss = 1.366
# Channel 37H, Epoch=16, batch = 5000 of 8000, loss=1.403, LR=0.00014644660940672625
# Validation Loss = 1.829
# Channel 37H, Epoch=16, batch = 6000 of 8000, loss=1.310, LR=0.00014644660940672625
# Validation Loss = 0.973
# Channel 37H, Epoch=16, batch = 7000 of 8000, loss=1.224, LR=0.00014644660940672625
# Validation Loss = 1.243
# Channel 37H, Epoch=17, batch = 0 of 8000, loss=1.327, LR=9.549150281252631e-05
# Validation Loss = 1.209
# Channel 37H, Epoch=17, batch = 1000 of 8000, loss=1.400, LR=9.549150281252631e-05
# Validation Loss = 1.137
# Channel 37H, Epoch=17, batch = 2000 of 8000, loss=1.332, LR=9.549150281252631e-05
# Validation Loss = 1.063
# Channel 37H, Epoch=17, batch = 3000 of 8000, loss=1.442, LR=9.549150281252631e-05
# Validation Loss = 2.231
# Channel 37H, Epoch=17, batch = 4000 of 8000, loss=1.512, LR=9.549150281252631e-05
# Validation Loss = 0.680
# Channel 37H, Epoch=17, batch = 5000 of 8000, loss=1.287, LR=9.549150281252631e-05
# Validation Loss = 1.080
# Channel 37H, Epoch=17, batch = 6000 of 8000, loss=1.310, LR=9.549150281252631e-05
# Validation Loss = 0.934
# Channel 37H, Epoch=17, batch = 7000 of 8000, loss=1.536, LR=9.549150281252631e-05
# Validation Loss = 1.414
# Channel 37H, Epoch=18, batch = 0 of 8000, loss=1.309, LR=5.4496737905816096e-05
# Validation Loss = 1.429
# Channel 37H, Epoch=18, batch = 1000 of 8000, loss=1.357, LR=5.4496737905816096e-05
# Validation Loss = 1.617
# Channel 37H, Epoch=18, batch = 2000 of 8000, loss=1.525, LR=5.4496737905816096e-05
# Validation Loss = 1.228
# Channel 37H, Epoch=18, batch = 3000 of 8000, loss=1.308, LR=5.4496737905816096e-05
# Validation Loss = 1.600
# Channel 37H, Epoch=18, batch = 4000 of 8000, loss=1.438, LR=5.4496737905816096e-05
# Validation Loss = 1.791
# Channel 37H, Epoch=18, batch = 5000 of 8000, loss=1.302, LR=5.4496737905816096e-05
# Validation Loss = 1.383
# Channel 37H, Epoch=18, batch = 6000 of 8000, loss=1.382, LR=5.4496737905816096e-05
# Validation Loss = 1.305
# Channel 37H, Epoch=18, batch = 7000 of 8000, loss=1.362, LR=5.4496737905816096e-05
# Validation Loss = 1.044
# Channel 37H, Epoch=19, batch = 0 of 8000, loss=1.195, LR=2.447174185242323e-05
# Validation Loss = 1.394
# Channel 37H, Epoch=19, batch = 1000 of 8000, loss=1.231, LR=2.447174185242323e-05
# Validation Loss = 1.357
# Channel 37H, Epoch=19, batch = 2000 of 8000, loss=1.440, LR=2.447174185242323e-05
# Validation Loss = 1.445
# Channel 37H, Epoch=19, batch = 3000 of 8000, loss=1.379, LR=2.447174185242323e-05
# Validation Loss = 1.050
# Channel 37H, Epoch=19, batch = 4000 of 8000, loss=1.427, LR=2.447174185242323e-05
# Validation Loss = 1.161
# Channel 37H, Epoch=19, batch = 5000 of 8000, loss=1.277, LR=2.447174185242323e-05
# Validation Loss = 1.472
# Channel 37H, Epoch=19, batch = 6000 of 8000, loss=1.211, LR=2.447174185242323e-05
# Validation Loss = 1.218
# Channel 37H, Epoch=19, batch = 7000 of 8000, loss=1.398, LR=2.447174185242323e-05
# Validation Loss = 1.084
# Channel 37H, Epoch=20, batch = 0 of 8000, loss=1.412, LR=6.15582970243117e-06
# Validation Loss = 1.331
# Channel 37H, Epoch=20, batch = 1000 of 8000, loss=1.338, LR=6.15582970243117e-06
# Validation Loss = 1.406
# Channel 37H, Epoch=20, batch = 2000 of 8000, loss=1.200, LR=6.15582970243117e-06
# Validation Loss = 1.246
# Channel 37H, Epoch=20, batch = 3000 of 8000, loss=1.566, LR=6.15582970243117e-06
# Validation Loss = 1.324
# Channel 37H, Epoch=20, batch = 4000 of 8000, loss=1.442, LR=6.15582970243117e-06
# Validation Loss = 1.243
# Channel 37H, Epoch=20, batch = 5000 of 8000, loss=1.275, LR=6.15582970243117e-06
# Validation Loss = 1.347
# Channel 37H, Epoch=20, batch = 6000 of 8000, loss=1.517, LR=6.15582970243117e-06
# Validation Loss = 1.416
# Channel 37H, Epoch=20, batch = 7000 of 8000, loss=1.243, LR=6.15582970243117e-06
# Finished training model for channel 37H.

# %%
#General parameters:
input_size = nchans - 1 + 1 #Remaining channels + surface type

# %%
'''

AMSR2 CHANNEL PREDICTION MODEL:
    2: Non-Ocean Surfaces

'''

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = sfctype > 1

    Tbs = f.Tbs.values[correct_sfc,:]
    sfctype = sfctype[correct_sfc]

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

sfctype_train = sfctype[train_indcs].astype(np.float32)
sfctype_test  = sfctype[test_indcs].astype(np.float32)
sfctype_val   = sfctype[val_indcs].astype(np.float32)

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train, shuffled_indcs = array_funcs.shuffle_data(Tbs_train, axis=0, return_indcs=True)
sfctype_train = sfctype_train[shuffled_indcs]

# %%
sfctype_train, sfctype_test, sfctype_val
# Out:
# (array([14., 11., 17., ...,  2., 12., 13.],
#        shape=(32186272,), dtype=float32),
#  array([14., 14., 14., ..., 15.,  5.,  5.], shape=(4023284,), dtype=float32),
#  array([ 2.,  2.,  2., ..., 11., 11., 11.], shape=(4023284,), dtype=float32))

# %%
chan_desc[10]
# Out:
# '37V'

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    #if ichan < 10: continue

    print(channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)

    x_train = np.concatenate((x_train, sfctype_train[:,None]), axis=1)
    x_test  = np.concatenate((x_test,  sfctype_test[:,None]), axis=1)
    x_val   = np.concatenate((x_val,   sfctype_val[:,None]), axis=1)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_nonocean_no89.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_nonocean_no89.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 6V
# Training stage: 1
# Validation Loss = 45295.352
# Channel 6V, Epoch=1, batch = 0 of 32186, loss=59913.645, LR=0.001
# Validation Loss = 0.178
# Channel 6V, Epoch=1, batch = 1000 of 32186, loss=1.547, LR=0.001
# Validation Loss = 0.021
# Channel 6V, Epoch=1, batch = 2000 of 32186, loss=1.006, LR=0.001
# Validation Loss = 0.231
# Channel 6V, Epoch=1, batch = 3000 of 32186, loss=1.101, LR=0.001
# Validation Loss = 0.663
# Channel 6V, Epoch=1, batch = 4000 of 32186, loss=1.943, LR=0.001
# Validation Loss = 0.010
# Channel 6V, Epoch=1, batch = 5000 of 32186, loss=0.894, LR=0.001
# Validation Loss = 1.130
# Channel 6V, Epoch=1, batch = 6000 of 32186, loss=3.162, LR=0.001
# Validation Loss = 0.060
# Channel 6V, Epoch=1, batch = 7000 of 32186, loss=0.798, LR=0.001
# Validation Loss = 0.021
# Channel 6V, Epoch=1, batch = 8000 of 32186, loss=1.202, LR=0.001
# Validation Loss = 4.172
# Channel 6V, Epoch=1, batch = 9000 of 32186, loss=3.899, LR=0.001
# Validation Loss = 0.010
# Channel 6V, Epoch=1, batch = 10000 of 32186, loss=0.882, LR=0.001
# Validation Loss = 0.220
# Channel 6V, Epoch=1, batch = 11000 of 32186, loss=0.597, LR=0.001
# Validation Loss = 1.143
# Channel 6V, Epoch=1, batch = 12000 of 32186, loss=1.133, LR=0.001
# Validation Loss = 0.027
# Channel 6V, Epoch=1, batch = 13000 of 32186, loss=0.771, LR=0.001
# Validation Loss = 0.104
# Channel 6V, Epoch=1, batch = 14000 of 32186, loss=1.442, LR=0.001
# Validation Loss = 0.539
# Channel 6V, Epoch=1, batch = 15000 of 32186, loss=0.682, LR=0.001
# Validation Loss = 0.038
# Channel 6V, Epoch=1, batch = 16000 of 32186, loss=0.794, LR=0.001
# Validation Loss = 0.992
# Channel 6V, Epoch=1, batch = 17000 of 32186, loss=1.012, LR=0.001
# Validation Loss = 0.435
# Channel 6V, Epoch=1, batch = 18000 of 32186, loss=0.758, LR=0.001
# Validation Loss = 0.463
# Channel 6V, Epoch=1, batch = 19000 of 32186, loss=0.791, LR=0.001
# Validation Loss = 0.490
# Channel 6V, Epoch=1, batch = 20000 of 32186, loss=1.883, LR=0.001
# Validation Loss = 0.052
# Channel 6V, Epoch=1, batch = 21000 of 32186, loss=0.635, LR=0.001
# Validation Loss = 0.815
# Channel 6V, Epoch=1, batch = 22000 of 32186, loss=2.337, LR=0.001
# Validation Loss = 5.346
# Channel 6V, Epoch=1, batch = 23000 of 32186, loss=6.365, LR=0.001
# Validation Loss = 4.625
# Channel 6V, Epoch=1, batch = 24000 of 32186, loss=5.375, LR=0.001
# Validation Loss = 0.005
# Channel 6V, Epoch=1, batch = 25000 of 32186, loss=0.839, LR=0.001
# Validation Loss = 1.294
# Channel 6V, Epoch=1, batch = 26000 of 32186, loss=3.266, LR=0.001
# Validation Loss = 0.086
# Channel 6V, Epoch=1, batch = 27000 of 32186, loss=0.492, LR=0.001
# Validation Loss = 0.002
# Channel 6V, Epoch=1, batch = 28000 of 32186, loss=0.727, LR=0.001
# Validation Loss = 0.090
# Channel 6V, Epoch=1, batch = 29000 of 32186, loss=0.623, LR=0.001
# Validation Loss = 0.013
# Channel 6V, Epoch=1, batch = 30000 of 32186, loss=0.875, LR=0.001
# Validation Loss = 2.970
# Channel 6V, Epoch=1, batch = 31000 of 32186, loss=5.233, LR=0.001
# Validation Loss = 0.126
# Channel 6V, Epoch=1, batch = 32000 of 32186, loss=0.560, LR=0.001
# Validation Loss = 0.103
# Channel 6V, Epoch=2, batch = 0 of 32186, loss=0.631, LR=0.0009045084971874737
# Validation Loss = 0.209
# Channel 6V, Epoch=2, batch = 1000 of 32186, loss=1.272, LR=0.0009045084971874737
# Validation Loss = 0.122
# Channel 6V, Epoch=2, batch = 2000 of 32186, loss=0.553, LR=0.0009045084971874737
# Validation Loss = 0.010
# Channel 6V, Epoch=2, batch = 3000 of 32186, loss=0.830, LR=0.0009045084971874737
# Validation Loss = 0.000
# Channel 6V, Epoch=2, batch = 4000 of 32186, loss=0.693, LR=0.0009045084971874737
# Validation Loss = 2.109
# Channel 6V, Epoch=2, batch = 5000 of 32186, loss=2.297, LR=0.0009045084971874737
# Validation Loss = 0.007
# Channel 6V, Epoch=2, batch = 6000 of 32186, loss=0.811, LR=0.0009045084971874737
# Validation Loss = 0.537
# Channel 6V, Epoch=2, batch = 7000 of 32186, loss=0.811, LR=0.0009045084971874737
# Validation Loss = 0.401
# Channel 6V, Epoch=2, batch = 8000 of 32186, loss=1.636, LR=0.0009045084971874737
# Validation Loss = 0.024
# Channel 6V, Epoch=2, batch = 9000 of 32186, loss=0.642, LR=0.0009045084971874737
# Validation Loss = 0.001
# Channel 6V, Epoch=2, batch = 10000 of 32186, loss=0.634, LR=0.0009045084971874737
# Validation Loss = 0.148
# Channel 6V, Epoch=2, batch = 11000 of 32186, loss=0.505, LR=0.0009045084971874737
# Validation Loss = 0.100
# Channel 6V, Epoch=2, batch = 12000 of 32186, loss=1.254, LR=0.0009045084971874737
# Validation Loss = 0.024
# Channel 6V, Epoch=2, batch = 13000 of 32186, loss=0.732, LR=0.0009045084971874737
# Validation Loss = 0.079
# Channel 6V, Epoch=2, batch = 14000 of 32186, loss=0.687, LR=0.0009045084971874737
# Validation Loss = 0.500
# Channel 6V, Epoch=2, batch = 15000 of 32186, loss=2.034, LR=0.0009045084971874737
# Validation Loss = 0.013
# Channel 6V, Epoch=2, batch = 16000 of 32186, loss=0.620, LR=0.0009045084971874737
# Validation Loss = 0.000
# Channel 6V, Epoch=2, batch = 17000 of 32186, loss=0.758, LR=0.0009045084971874737
# Validation Loss = 0.058
# Channel 6V, Epoch=2, batch = 18000 of 32186, loss=0.609, LR=0.0009045084971874737
# Validation Loss = 0.006
# Channel 6V, Epoch=2, batch = 19000 of 32186, loss=0.764, LR=0.0009045084971874737
# Validation Loss = 0.378
# Channel 6V, Epoch=2, batch = 20000 of 32186, loss=0.718, LR=0.0009045084971874737
# Validation Loss = 0.049
# Channel 6V, Epoch=2, batch = 21000 of 32186, loss=0.553, LR=0.0009045084971874737
# Validation Loss = 0.404
# Channel 6V, Epoch=2, batch = 22000 of 32186, loss=0.769, LR=0.0009045084971874737
# Validation Loss = 0.219
# Channel 6V, Epoch=2, batch = 23000 of 32186, loss=1.464, LR=0.0009045084971874737
# Validation Loss = 0.041
# Channel 6V, Epoch=2, batch = 24000 of 32186, loss=0.607, LR=0.0009045084971874737
# Validation Loss = 0.065
# Channel 6V, Epoch=2, batch = 25000 of 32186, loss=0.616, LR=0.0009045084971874737
# Validation Loss = 0.876
# Channel 6V, Epoch=2, batch = 26000 of 32186, loss=1.118, LR=0.0009045084971874737
# Validation Loss = 0.192
# Channel 6V, Epoch=2, batch = 27000 of 32186, loss=0.566, LR=0.0009045084971874737
# Validation Loss = 0.018
# Channel 6V, Epoch=2, batch = 28000 of 32186, loss=0.694, LR=0.0009045084971874737
# Validation Loss = 0.592
# Channel 6V, Epoch=2, batch = 29000 of 32186, loss=0.813, LR=0.0009045084971874737
# Validation Loss = 0.132
# Channel 6V, Epoch=2, batch = 30000 of 32186, loss=1.168, LR=0.0009045084971874737
# Validation Loss = 2.803
# Channel 6V, Epoch=2, batch = 31000 of 32186, loss=2.393, LR=0.0009045084971874737
# Validation Loss = 0.207
# Channel 6V, Epoch=2, batch = 32000 of 32186, loss=1.438, LR=0.0009045084971874737
# Validation Loss = 0.669
# Channel 6V, Epoch=3, batch = 0 of 32186, loss=0.993, LR=0.0006545084971874737
# Validation Loss = 0.081
# Channel 6V, Epoch=3, batch = 1000 of 32186, loss=0.548, LR=0.0006545084971874737
# Validation Loss = 0.352
# Channel 6V, Epoch=3, batch = 2000 of 32186, loss=1.638, LR=0.0006545084971874737
# Validation Loss = 0.440
# Channel 6V, Epoch=3, batch = 3000 of 32186, loss=0.693, LR=0.0006545084971874737
# Validation Loss = 0.451
# Channel 6V, Epoch=3, batch = 4000 of 32186, loss=0.706, LR=0.0006545084971874737
# Validation Loss = 0.752
# Channel 6V, Epoch=3, batch = 5000 of 32186, loss=0.962, LR=0.0006545084971874737
# Validation Loss = 0.062
# Channel 6V, Epoch=3, batch = 6000 of 32186, loss=0.584, LR=0.0006545084971874737
# Validation Loss = 0.001
# Channel 6V, Epoch=3, batch = 7000 of 32186, loss=0.836, LR=0.0006545084971874737
# Validation Loss = 0.298
# Channel 6V, Epoch=3, batch = 8000 of 32186, loss=0.552, LR=0.0006545084971874737
# Validation Loss = 0.040
# Channel 6V, Epoch=3, batch = 9000 of 32186, loss=1.029, LR=0.0006545084971874737
# Validation Loss = 0.007
# Channel 6V, Epoch=3, batch = 10000 of 32186, loss=0.869, LR=0.0006545084971874737
# Validation Loss = 0.289
# Channel 6V, Epoch=3, batch = 11000 of 32186, loss=0.655, LR=0.0006545084971874737
# Validation Loss = 0.068
# Channel 6V, Epoch=3, batch = 12000 of 32186, loss=0.532, LR=0.0006545084971874737
# Validation Loss = 0.862
# Channel 6V, Epoch=3, batch = 13000 of 32186, loss=1.007, LR=0.0006545084971874737
# Validation Loss = 0.007
# Channel 6V, Epoch=3, batch = 14000 of 32186, loss=0.607, LR=0.0006545084971874737
# Validation Loss = 0.653
# Channel 6V, Epoch=3, batch = 15000 of 32186, loss=0.824, LR=0.0006545084971874737
# Validation Loss = 0.003
# Channel 6V, Epoch=3, batch = 16000 of 32186, loss=0.769, LR=0.0006545084971874737
# Validation Loss = 0.149
# Channel 6V, Epoch=3, batch = 17000 of 32186, loss=1.276, LR=0.0006545084971874737
# Validation Loss = 0.170
# Channel 6V, Epoch=3, batch = 18000 of 32186, loss=0.526, LR=0.0006545084971874737
# Validation Loss = 0.620
# Channel 6V, Epoch=3, batch = 19000 of 32186, loss=0.806, LR=0.0006545084971874737
# Validation Loss = 0.076
# Channel 6V, Epoch=3, batch = 20000 of 32186, loss=0.532, LR=0.0006545084971874737
# Validation Loss = 0.113
# Channel 6V, Epoch=3, batch = 21000 of 32186, loss=0.535, LR=0.0006545084971874737
# Validation Loss = 1.526
# Channel 6V, Epoch=3, batch = 22000 of 32186, loss=1.829, LR=0.0006545084971874737
# Validation Loss = 0.220
# Channel 6V, Epoch=3, batch = 23000 of 32186, loss=0.611, LR=0.0006545084971874737
# Validation Loss = 0.026
# Channel 6V, Epoch=3, batch = 24000 of 32186, loss=0.542, LR=0.0006545084971874737
# Validation Loss = 0.125
# Channel 6V, Epoch=3, batch = 25000 of 32186, loss=0.531, LR=0.0006545084971874737
# Validation Loss = 0.290
# Channel 6V, Epoch=3, batch = 26000 of 32186, loss=0.573, LR=0.0006545084971874737
# Validation Loss = 0.570
# Channel 6V, Epoch=3, batch = 27000 of 32186, loss=0.716, LR=0.0006545084971874737
# Validation Loss = 0.186
# Channel 6V, Epoch=3, batch = 28000 of 32186, loss=0.601, LR=0.0006545084971874737
# Validation Loss = 0.309
# Channel 6V, Epoch=3, batch = 29000 of 32186, loss=0.637, LR=0.0006545084971874737
# Validation Loss = 0.120
# Channel 6V, Epoch=3, batch = 30000 of 32186, loss=1.010, LR=0.0006545084971874737
# Validation Loss = 0.569
# Channel 6V, Epoch=3, batch = 31000 of 32186, loss=0.846, LR=0.0006545084971874737
# Validation Loss = 0.718
# Channel 6V, Epoch=3, batch = 32000 of 32186, loss=0.966, LR=0.0006545084971874737
# Validation Loss = 0.697
# Channel 6V, Epoch=4, batch = 0 of 32186, loss=0.842, LR=0.00034549150281252633
# Validation Loss = 0.196
# Channel 6V, Epoch=4, batch = 1000 of 32186, loss=0.551, LR=0.00034549150281252633
# Validation Loss = 0.126
# Channel 6V, Epoch=4, batch = 2000 of 32186, loss=0.564, LR=0.00034549150281252633
# Validation Loss = 0.008
# Channel 6V, Epoch=4, batch = 3000 of 32186, loss=0.687, LR=0.00034549150281252633
# Validation Loss = 0.475
# Channel 6V, Epoch=4, batch = 4000 of 32186, loss=0.740, LR=0.00034549150281252633
# Validation Loss = 0.038
# Channel 6V, Epoch=4, batch = 5000 of 32186, loss=0.513, LR=0.00034549150281252633
# Validation Loss = 0.296
# Channel 6V, Epoch=4, batch = 6000 of 32186, loss=0.614, LR=0.00034549150281252633
# Validation Loss = 0.291
# Channel 6V, Epoch=4, batch = 7000 of 32186, loss=0.599, LR=0.00034549150281252633
# Validation Loss = 0.193
# Channel 6V, Epoch=4, batch = 8000 of 32186, loss=0.565, LR=0.00034549150281252633
# Validation Loss = 0.032
# Channel 6V, Epoch=4, batch = 9000 of 32186, loss=0.632, LR=0.00034549150281252633
# Validation Loss = 0.014
# Channel 6V, Epoch=4, batch = 10000 of 32186, loss=0.558, LR=0.00034549150281252633
# Validation Loss = 0.870
# Channel 6V, Epoch=4, batch = 11000 of 32186, loss=0.895, LR=0.00034549150281252633
# Validation Loss = 0.018
# Channel 6V, Epoch=4, batch = 12000 of 32186, loss=0.547, LR=0.00034549150281252633
# Validation Loss = 0.221
# Channel 6V, Epoch=4, batch = 13000 of 32186, loss=0.605, LR=0.00034549150281252633
# Validation Loss = 0.131
# Channel 6V, Epoch=4, batch = 14000 of 32186, loss=0.574, LR=0.00034549150281252633
# Validation Loss = 0.306
# Channel 6V, Epoch=4, batch = 15000 of 32186, loss=0.626, LR=0.00034549150281252633
# Validation Loss = 0.101
# Channel 6V, Epoch=4, batch = 16000 of 32186, loss=0.586, LR=0.00034549150281252633
# Validation Loss = 0.062
# Channel 6V, Epoch=4, batch = 17000 of 32186, loss=0.567, LR=0.00034549150281252633
# Validation Loss = 0.028
# Channel 6V, Epoch=4, batch = 18000 of 32186, loss=0.562, LR=0.00034549150281252633
# Validation Loss = 0.057
# Channel 6V, Epoch=4, batch = 19000 of 32186, loss=0.465, LR=0.00034549150281252633
# Validation Loss = 0.229
# Channel 6V, Epoch=4, batch = 20000 of 32186, loss=0.578, LR=0.00034549150281252633
# Validation Loss = 0.138
# Channel 6V, Epoch=4, batch = 21000 of 32186, loss=0.482, LR=0.00034549150281252633
# Validation Loss = 0.047
# Channel 6V, Epoch=4, batch = 22000 of 32186, loss=0.576, LR=0.00034549150281252633
# Validation Loss = 0.113
# Channel 6V, Epoch=4, batch = 23000 of 32186, loss=0.547, LR=0.00034549150281252633
# Validation Loss = 0.276
# Channel 6V, Epoch=4, batch = 24000 of 32186, loss=0.578, LR=0.00034549150281252633
# Validation Loss = 0.029
# Channel 6V, Epoch=4, batch = 25000 of 32186, loss=0.553, LR=0.00034549150281252633
# Validation Loss = 0.393
# Channel 6V, Epoch=4, batch = 26000 of 32186, loss=0.701, LR=0.00034549150281252633
# Validation Loss = 0.063
# Channel 6V, Epoch=4, batch = 27000 of 32186, loss=0.590, LR=0.00034549150281252633
# Validation Loss = 0.087
# Channel 6V, Epoch=4, batch = 28000 of 32186, loss=0.548, LR=0.00034549150281252633
# Validation Loss = 0.280
# Channel 6V, Epoch=4, batch = 29000 of 32186, loss=0.616, LR=0.00034549150281252633
# Validation Loss = 0.047
# Channel 6V, Epoch=4, batch = 30000 of 32186, loss=0.584, LR=0.00034549150281252633
# Validation Loss = 0.176
# Channel 6V, Epoch=4, batch = 31000 of 32186, loss=0.602, LR=0.00034549150281252633
# Validation Loss = 0.085
# Channel 6V, Epoch=4, batch = 32000 of 32186, loss=0.519, LR=0.00034549150281252633
# Validation Loss = 0.110
# Channel 6V, Epoch=5, batch = 0 of 32186, loss=0.495, LR=9.549150281252633e-05
# Validation Loss = 0.101
# Channel 6V, Epoch=5, batch = 1000 of 32186, loss=0.553, LR=9.549150281252633e-05
# Validation Loss = 0.085
# Channel 6V, Epoch=5, batch = 2000 of 32186, loss=0.552, LR=9.549150281252633e-05
# Validation Loss = 0.082
# Channel 6V, Epoch=5, batch = 3000 of 32186, loss=0.543, LR=9.549150281252633e-05
# Validation Loss = 0.058
# Channel 6V, Epoch=5, batch = 4000 of 32186, loss=0.530, LR=9.549150281252633e-05
# Validation Loss = 0.221
# Channel 6V, Epoch=5, batch = 5000 of 32186, loss=0.606, LR=9.549150281252633e-05
# Validation Loss = 0.020
# Channel 6V, Epoch=5, batch = 6000 of 32186, loss=0.658, LR=9.549150281252633e-05
# Validation Loss = 0.133
# Channel 6V, Epoch=5, batch = 7000 of 32186, loss=0.589, LR=9.549150281252633e-05
# Validation Loss = 0.094
# Channel 6V, Epoch=5, batch = 8000 of 32186, loss=0.542, LR=9.549150281252633e-05
# Validation Loss = 0.053
# Channel 6V, Epoch=5, batch = 9000 of 32186, loss=0.524, LR=9.549150281252633e-05
# Validation Loss = 0.091
# Channel 6V, Epoch=5, batch = 10000 of 32186, loss=0.562, LR=9.549150281252633e-05
# Validation Loss = 0.058
# Channel 6V, Epoch=5, batch = 11000 of 32186, loss=0.557, LR=9.549150281252633e-05
# Validation Loss = 0.018
# Channel 6V, Epoch=5, batch = 12000 of 32186, loss=0.486, LR=9.549150281252633e-05
# Validation Loss = 0.099
# Channel 6V, Epoch=5, batch = 13000 of 32186, loss=0.538, LR=9.549150281252633e-05
# Validation Loss = 0.042
# Channel 6V, Epoch=5, batch = 14000 of 32186, loss=0.503, LR=9.549150281252633e-05
# Validation Loss = 0.025
# Channel 6V, Epoch=5, batch = 15000 of 32186, loss=0.515, LR=9.549150281252633e-05
# Validation Loss = 0.001
# Channel 6V, Epoch=5, batch = 16000 of 32186, loss=0.615, LR=9.549150281252633e-05
# Validation Loss = 0.010
# Channel 6V, Epoch=5, batch = 17000 of 32186, loss=0.487, LR=9.549150281252633e-05
# Validation Loss = 0.131
# Channel 6V, Epoch=5, batch = 18000 of 32186, loss=0.564, LR=9.549150281252633e-05
# Validation Loss = 0.077
# Channel 6V, Epoch=5, batch = 19000 of 32186, loss=0.549, LR=9.549150281252633e-05
# Validation Loss = 0.128
# Channel 6V, Epoch=5, batch = 20000 of 32186, loss=0.520, LR=9.549150281252633e-05
# Validation Loss = 0.096
# Channel 6V, Epoch=5, batch = 21000 of 32186, loss=0.538, LR=9.549150281252633e-05
# Validation Loss = 0.031
# Channel 6V, Epoch=5, batch = 22000 of 32186, loss=0.562, LR=9.549150281252633e-05
# Validation Loss = 0.062
# Channel 6V, Epoch=5, batch = 23000 of 32186, loss=0.558, LR=9.549150281252633e-05
# Validation Loss = 0.013
# Channel 6V, Epoch=5, batch = 24000 of 32186, loss=0.614, LR=9.549150281252633e-05
# Validation Loss = 0.005
# Channel 6V, Epoch=5, batch = 25000 of 32186, loss=0.552, LR=9.549150281252633e-05
# Validation Loss = 0.008
# Channel 6V, Epoch=5, batch = 26000 of 32186, loss=0.553, LR=9.549150281252633e-05
# Validation Loss = 0.115
# Channel 6V, Epoch=5, batch = 27000 of 32186, loss=0.537, LR=9.549150281252633e-05
# Validation Loss = 0.010
# Channel 6V, Epoch=5, batch = 28000 of 32186, loss=0.711, LR=9.549150281252633e-05
# Validation Loss = 0.146
# Channel 6V, Epoch=5, batch = 29000 of 32186, loss=0.614, LR=9.549150281252633e-05
# Validation Loss = 0.036
# Channel 6V, Epoch=5, batch = 30000 of 32186, loss=0.508, LR=9.549150281252633e-05
# Validation Loss = 0.063
# Channel 6V, Epoch=5, batch = 31000 of 32186, loss=0.506, LR=9.549150281252633e-05
# Validation Loss = 0.056
# Channel 6V, Epoch=5, batch = 32000 of 32186, loss=0.504, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.161
# Channel 6V, Epoch=1, batch = 0 of 32186, loss=0.696, LR=0.001
# Validation Loss = 0.111
# Channel 6V, Epoch=1, batch = 1000 of 32186, loss=0.553, LR=0.001
# Validation Loss = 0.588
# Channel 6V, Epoch=1, batch = 2000 of 32186, loss=0.856, LR=0.001
# Validation Loss = 0.072
# Channel 6V, Epoch=1, batch = 3000 of 32186, loss=0.516, LR=0.001
# Validation Loss = 0.113
# Channel 6V, Epoch=1, batch = 4000 of 32186, loss=0.490, LR=0.001
# Validation Loss = 1.134
# Channel 6V, Epoch=1, batch = 5000 of 32186, loss=1.195, LR=0.001
# Validation Loss = 0.511
# Channel 6V, Epoch=1, batch = 6000 of 32186, loss=1.851, LR=0.001
# Validation Loss = 0.956
# Channel 6V, Epoch=1, batch = 7000 of 32186, loss=1.057, LR=0.001
# Validation Loss = 0.068
# Channel 6V, Epoch=1, batch = 8000 of 32186, loss=0.467, LR=0.001
# Validation Loss = 0.545
# Channel 6V, Epoch=1, batch = 9000 of 32186, loss=1.911, LR=0.001
# Validation Loss = 0.475
# Channel 6V, Epoch=1, batch = 10000 of 32186, loss=1.837, LR=0.001
# Validation Loss = 0.691
# Channel 6V, Epoch=1, batch = 11000 of 32186, loss=1.098, LR=0.001
# Validation Loss = 0.002
# Channel 6V, Epoch=1, batch = 12000 of 32186, loss=0.758, LR=0.001
# Validation Loss = 0.274
# Channel 6V, Epoch=1, batch = 13000 of 32186, loss=0.833, LR=0.001
# Validation Loss = 0.127
# Channel 6V, Epoch=1, batch = 14000 of 32186, loss=0.628, LR=0.001
# Validation Loss = 0.609
# Channel 6V, Epoch=1, batch = 15000 of 32186, loss=0.751, LR=0.001
# Validation Loss = 0.668
# Channel 6V, Epoch=1, batch = 16000 of 32186, loss=1.075, LR=0.001
# Validation Loss = 0.047
# Channel 6V, Epoch=1, batch = 17000 of 32186, loss=0.575, LR=0.001
# Validation Loss = 0.086
# Channel 6V, Epoch=1, batch = 18000 of 32186, loss=0.583, LR=0.001
# Validation Loss = 0.001
# Channel 6V, Epoch=1, batch = 19000 of 32186, loss=0.490, LR=0.001
# Validation Loss = 0.000
# Channel 6V, Epoch=1, batch = 20000 of 32186, loss=0.631, LR=0.001
# Validation Loss = 0.007
# Channel 6V, Epoch=1, batch = 21000 of 32186, loss=0.611, LR=0.001
# Validation Loss = 0.022
# Channel 6V, Epoch=1, batch = 22000 of 32186, loss=0.552, LR=0.001
# Validation Loss = 0.039
# Channel 6V, Epoch=1, batch = 23000 of 32186, loss=0.717, LR=0.001
# Validation Loss = 0.693
# Channel 6V, Epoch=1, batch = 24000 of 32186, loss=1.079, LR=0.001
# Validation Loss = 0.028
# Channel 6V, Epoch=1, batch = 25000 of 32186, loss=0.896, LR=0.001
# Validation Loss = 0.003
# Channel 6V, Epoch=1, batch = 26000 of 32186, loss=0.710, LR=0.001
# Validation Loss = 0.089
# Channel 6V, Epoch=1, batch = 27000 of 32186, loss=0.509, LR=0.001
# Validation Loss = 0.413
# Channel 6V, Epoch=1, batch = 28000 of 32186, loss=0.752, LR=0.001
# Validation Loss = 0.000
# Channel 6V, Epoch=1, batch = 29000 of 32186, loss=0.636, LR=0.001
# Validation Loss = 0.425
# Channel 6V, Epoch=1, batch = 30000 of 32186, loss=1.760, LR=0.001
# Validation Loss = 0.250
# Channel 6V, Epoch=1, batch = 31000 of 32186, loss=1.219, LR=0.001
# Validation Loss = 0.649
# Channel 6V, Epoch=1, batch = 32000 of 32186, loss=0.863, LR=0.001
# Validation Loss = 0.161
# Channel 6V, Epoch=2, batch = 0 of 32186, loss=0.552, LR=0.0009755282581475768
# Validation Loss = 0.835
# Channel 6V, Epoch=2, batch = 1000 of 32186, loss=1.070, LR=0.0009755282581475768
# Validation Loss = 0.308
# Channel 6V, Epoch=2, batch = 2000 of 32186, loss=0.523, LR=0.0009755282581475768
# Validation Loss = 0.030
# Channel 6V, Epoch=2, batch = 3000 of 32186, loss=0.512, LR=0.0009755282581475768
# Validation Loss = 0.543
# Channel 6V, Epoch=2, batch = 4000 of 32186, loss=0.909, LR=0.0009755282581475768
# Validation Loss = 0.293
# Channel 6V, Epoch=2, batch = 5000 of 32186, loss=1.372, LR=0.0009755282581475768
# Validation Loss = 0.569
# Channel 6V, Epoch=2, batch = 6000 of 32186, loss=0.722, LR=0.0009755282581475768
# Validation Loss = 0.054
# Channel 6V, Epoch=2, batch = 7000 of 32186, loss=0.920, LR=0.0009755282581475768
# Validation Loss = 0.086
# Channel 6V, Epoch=2, batch = 8000 of 32186, loss=0.525, LR=0.0009755282581475768
# Validation Loss = 0.157
# Channel 6V, Epoch=2, batch = 9000 of 32186, loss=0.593, LR=0.0009755282581475768
# Validation Loss = 0.008
# Channel 6V, Epoch=2, batch = 10000 of 32186, loss=0.667, LR=0.0009755282581475768
# Validation Loss = 0.144
# Channel 6V, Epoch=2, batch = 11000 of 32186, loss=0.594, LR=0.0009755282581475768
# Validation Loss = 0.939
# Channel 6V, Epoch=2, batch = 12000 of 32186, loss=0.990, LR=0.0009755282581475768
# Validation Loss = 0.407
# Channel 6V, Epoch=2, batch = 13000 of 32186, loss=1.636, LR=0.0009755282581475768
# Validation Loss = 0.420
# Channel 6V, Epoch=2, batch = 14000 of 32186, loss=1.501, LR=0.0009755282581475768
# Validation Loss = 0.021
# Channel 6V, Epoch=2, batch = 15000 of 32186, loss=0.685, LR=0.0009755282581475768
# Validation Loss = 1.136
# Channel 6V, Epoch=2, batch = 16000 of 32186, loss=1.285, LR=0.0009755282581475768
# Validation Loss = 0.238
# Channel 6V, Epoch=2, batch = 17000 of 32186, loss=0.611, LR=0.0009755282581475768
# Validation Loss = 0.159
# Channel 6V, Epoch=2, batch = 18000 of 32186, loss=0.495, LR=0.0009755282581475768
# Validation Loss = 0.045
# Channel 6V, Epoch=2, batch = 19000 of 32186, loss=0.563, LR=0.0009755282581475768
# Validation Loss = 0.066
# Channel 6V, Epoch=2, batch = 20000 of 32186, loss=0.567, LR=0.0009755282581475768
# Validation Loss = 0.516
# Channel 6V, Epoch=2, batch = 21000 of 32186, loss=0.851, LR=0.0009755282581475768
# Validation Loss = 0.108
# Channel 6V, Epoch=2, batch = 22000 of 32186, loss=0.612, LR=0.0009755282581475768
# Validation Loss = 0.485
# Channel 6V, Epoch=2, batch = 23000 of 32186, loss=0.768, LR=0.0009755282581475768
# Validation Loss = 0.241
# Channel 6V, Epoch=2, batch = 24000 of 32186, loss=0.545, LR=0.0009755282581475768
# Validation Loss = 0.015
# Channel 6V, Epoch=2, batch = 25000 of 32186, loss=0.716, LR=0.0009755282581475768
# Validation Loss = 0.253
# Channel 6V, Epoch=2, batch = 26000 of 32186, loss=0.540, LR=0.0009755282581475768
# Validation Loss = 0.102
# Channel 6V, Epoch=2, batch = 27000 of 32186, loss=0.513, LR=0.0009755282581475768
# Validation Loss = 0.000
# Channel 6V, Epoch=2, batch = 28000 of 32186, loss=0.596, LR=0.0009755282581475768
# Validation Loss = 0.395
# Channel 6V, Epoch=2, batch = 29000 of 32186, loss=0.727, LR=0.0009755282581475768
# Validation Loss = 0.188
# Channel 6V, Epoch=2, batch = 30000 of 32186, loss=1.143, LR=0.0009755282581475768
# Validation Loss = 0.408
# Channel 6V, Epoch=2, batch = 31000 of 32186, loss=0.721, LR=0.0009755282581475768
# Validation Loss = 0.243
# Channel 6V, Epoch=2, batch = 32000 of 32186, loss=0.648, LR=0.0009755282581475768
# Validation Loss = 0.012
# Channel 6V, Epoch=3, batch = 0 of 32186, loss=0.756, LR=0.0009045084971874736
# Validation Loss = 0.157
# Channel 6V, Epoch=3, batch = 1000 of 32186, loss=1.101, LR=0.0009045084971874736
# Validation Loss = 0.008
# Channel 6V, Epoch=3, batch = 2000 of 32186, loss=0.616, LR=0.0009045084971874736
# Validation Loss = 0.001
# Channel 6V, Epoch=3, batch = 3000 of 32186, loss=0.625, LR=0.0009045084971874736
# Validation Loss = 0.243
# Channel 6V, Epoch=3, batch = 4000 of 32186, loss=0.655, LR=0.0009045084971874736
# Validation Loss = 0.017
# Channel 6V, Epoch=3, batch = 5000 of 32186, loss=0.523, LR=0.0009045084971874736
# Validation Loss = 0.153
# Channel 6V, Epoch=3, batch = 6000 of 32186, loss=0.587, LR=0.0009045084971874736
# Validation Loss = 0.009
# Channel 6V, Epoch=3, batch = 7000 of 32186, loss=0.608, LR=0.0009045084971874736
# Validation Loss = 0.097
# Channel 6V, Epoch=3, batch = 8000 of 32186, loss=0.572, LR=0.0009045084971874736
# Validation Loss = 0.033
# Channel 6V, Epoch=3, batch = 9000 of 32186, loss=0.689, LR=0.0009045084971874736
# Validation Loss = 0.002
# Channel 6V, Epoch=3, batch = 10000 of 32186, loss=0.556, LR=0.0009045084971874736
# Validation Loss = 0.156
# Channel 6V, Epoch=3, batch = 11000 of 32186, loss=0.571, LR=0.0009045084971874736
# Validation Loss = 0.107
# Channel 6V, Epoch=3, batch = 12000 of 32186, loss=0.614, LR=0.0009045084971874736
# Validation Loss = 0.070
# Channel 6V, Epoch=3, batch = 13000 of 32186, loss=0.549, LR=0.0009045084971874736
# Validation Loss = 0.393
# Channel 6V, Epoch=3, batch = 14000 of 32186, loss=0.799, LR=0.0009045084971874736
# Validation Loss = 0.044
# Channel 6V, Epoch=3, batch = 15000 of 32186, loss=0.534, LR=0.0009045084971874736
# Validation Loss = 0.012
# Channel 6V, Epoch=3, batch = 16000 of 32186, loss=0.670, LR=0.0009045084971874736
# Validation Loss = 0.120
# Channel 6V, Epoch=3, batch = 17000 of 32186, loss=0.874, LR=0.0009045084971874736
# Validation Loss = 0.789
# Channel 6V, Epoch=3, batch = 18000 of 32186, loss=1.362, LR=0.0009045084971874736
# Validation Loss = 0.010
# Channel 6V, Epoch=3, batch = 19000 of 32186, loss=0.667, LR=0.0009045084971874736
# Validation Loss = 0.007
# Channel 6V, Epoch=3, batch = 20000 of 32186, loss=0.659, LR=0.0009045084971874736
# Validation Loss = 0.021
# Channel 6V, Epoch=3, batch = 21000 of 32186, loss=0.532, LR=0.0009045084971874736
# Validation Loss = 0.000
# Channel 6V, Epoch=3, batch = 22000 of 32186, loss=0.561, LR=0.0009045084971874736
# Validation Loss = 0.091
# Channel 6V, Epoch=3, batch = 23000 of 32186, loss=0.608, LR=0.0009045084971874736
# Validation Loss = 0.000
# Channel 6V, Epoch=3, batch = 24000 of 32186, loss=0.627, LR=0.0009045084971874736
# Validation Loss = 0.154
# Channel 6V, Epoch=3, batch = 25000 of 32186, loss=0.672, LR=0.0009045084971874736
# Validation Loss = 0.023
# Channel 6V, Epoch=3, batch = 26000 of 32186, loss=0.736, LR=0.0009045084971874736
# Validation Loss = 0.680
# Channel 6V, Epoch=3, batch = 27000 of 32186, loss=1.090, LR=0.0009045084971874736
# Validation Loss = 0.134
# Channel 6V, Epoch=3, batch = 28000 of 32186, loss=0.961, LR=0.0009045084971874736
# Validation Loss = 0.027
# Channel 6V, Epoch=3, batch = 29000 of 32186, loss=0.535, LR=0.0009045084971874736
# Validation Loss = 1.044
# Channel 6V, Epoch=3, batch = 30000 of 32186, loss=2.034, LR=0.0009045084971874736
# Validation Loss = 0.003
# Channel 6V, Epoch=3, batch = 31000 of 32186, loss=0.592, LR=0.0009045084971874736
# Validation Loss = 0.005
# Channel 6V, Epoch=3, batch = 32000 of 32186, loss=0.539, LR=0.0009045084971874736
# Validation Loss = 0.069
# Channel 6V, Epoch=4, batch = 0 of 32186, loss=0.619, LR=0.0007938926261462366
# Validation Loss = 0.108
# Channel 6V, Epoch=4, batch = 1000 of 32186, loss=0.631, LR=0.0007938926261462366
# Validation Loss = 0.086
# Channel 6V, Epoch=4, batch = 2000 of 32186, loss=0.596, LR=0.0007938926261462366
# Validation Loss = 0.004
# Channel 6V, Epoch=4, batch = 3000 of 32186, loss=0.579, LR=0.0007938926261462366
# Validation Loss = 0.325
# Channel 6V, Epoch=4, batch = 4000 of 32186, loss=0.725, LR=0.0007938926261462366
# Validation Loss = 0.125
# Channel 6V, Epoch=4, batch = 5000 of 32186, loss=0.594, LR=0.0007938926261462366
# Validation Loss = 0.327
# Channel 6V, Epoch=4, batch = 6000 of 32186, loss=0.778, LR=0.0007938926261462366
# Validation Loss = 0.012
# Channel 6V, Epoch=4, batch = 7000 of 32186, loss=0.539, LR=0.0007938926261462366
# Validation Loss = 0.349
# Channel 6V, Epoch=4, batch = 8000 of 32186, loss=0.763, LR=0.0007938926261462366
# Validation Loss = 0.109
# Channel 6V, Epoch=4, batch = 9000 of 32186, loss=0.569, LR=0.0007938926261462366
# Validation Loss = 0.102
# Channel 6V, Epoch=4, batch = 10000 of 32186, loss=0.548, LR=0.0007938926261462366
# Validation Loss = 0.199
# Channel 6V, Epoch=4, batch = 11000 of 32186, loss=0.774, LR=0.0007938926261462366
# Validation Loss = 0.052
# Channel 6V, Epoch=4, batch = 12000 of 32186, loss=0.593, LR=0.0007938926261462366
# Validation Loss = 0.047
# Channel 6V, Epoch=4, batch = 13000 of 32186, loss=0.521, LR=0.0007938926261462366
# Validation Loss = 0.167
# Channel 6V, Epoch=4, batch = 14000 of 32186, loss=0.660, LR=0.0007938926261462366
# Validation Loss = 0.031
# Channel 6V, Epoch=4, batch = 15000 of 32186, loss=0.694, LR=0.0007938926261462366
# Validation Loss = 0.033
# Channel 6V, Epoch=4, batch = 16000 of 32186, loss=0.705, LR=0.0007938926261462366
# Validation Loss = 0.031
# Channel 6V, Epoch=4, batch = 17000 of 32186, loss=0.685, LR=0.0007938926261462366
# Validation Loss = 0.403
# Channel 6V, Epoch=4, batch = 18000 of 32186, loss=0.922, LR=0.0007938926261462366
# Validation Loss = 0.228
# Channel 6V, Epoch=4, batch = 19000 of 32186, loss=0.589, LR=0.0007938926261462366
# Validation Loss = 0.078
# Channel 6V, Epoch=4, batch = 20000 of 32186, loss=1.010, LR=0.0007938926261462366
# Validation Loss = 0.149
# Channel 6V, Epoch=4, batch = 21000 of 32186, loss=0.591, LR=0.0007938926261462366
# Validation Loss = 0.091
# Channel 6V, Epoch=4, batch = 22000 of 32186, loss=0.555, LR=0.0007938926261462366
# Validation Loss = 0.009
# Channel 6V, Epoch=4, batch = 23000 of 32186, loss=0.517, LR=0.0007938926261462366
# Validation Loss = 0.067
# Channel 6V, Epoch=4, batch = 24000 of 32186, loss=0.566, LR=0.0007938926261462366
# Validation Loss = 0.031
# Channel 6V, Epoch=4, batch = 25000 of 32186, loss=0.501, LR=0.0007938926261462366
# Validation Loss = 0.065
# Channel 6V, Epoch=4, batch = 26000 of 32186, loss=0.740, LR=0.0007938926261462366
# Validation Loss = 0.136
# Channel 6V, Epoch=4, batch = 27000 of 32186, loss=0.620, LR=0.0007938926261462366
# Validation Loss = 0.165
# Channel 6V, Epoch=4, batch = 28000 of 32186, loss=0.603, LR=0.0007938926261462366
# Validation Loss = 0.731
# Channel 6V, Epoch=4, batch = 29000 of 32186, loss=1.047, LR=0.0007938926261462366
# Validation Loss = 0.014
# Channel 6V, Epoch=4, batch = 30000 of 32186, loss=0.537, LR=0.0007938926261462366
# Validation Loss = 0.043
# Channel 6V, Epoch=4, batch = 31000 of 32186, loss=0.532, LR=0.0007938926261462366
# Validation Loss = 0.069
# Channel 6V, Epoch=4, batch = 32000 of 32186, loss=0.532, LR=0.0007938926261462366
# Validation Loss = 0.357
# Channel 6V, Epoch=5, batch = 0 of 32186, loss=0.830, LR=0.0006545084971874737
# Validation Loss = 0.220
# Channel 6V, Epoch=5, batch = 1000 of 32186, loss=0.597, LR=0.0006545084971874737
# Validation Loss = 0.023
# Channel 6V, Epoch=5, batch = 2000 of 32186, loss=0.515, LR=0.0006545084971874737
# Validation Loss = 0.016
# Channel 6V, Epoch=5, batch = 3000 of 32186, loss=0.566, LR=0.0006545084971874737
# Validation Loss = 0.080
# Channel 6V, Epoch=5, batch = 4000 of 32186, loss=0.836, LR=0.0006545084971874737
# Validation Loss = 0.213
# Channel 6V, Epoch=5, batch = 5000 of 32186, loss=0.607, LR=0.0006545084971874737
# Validation Loss = 0.162
# Channel 6V, Epoch=5, batch = 6000 of 32186, loss=0.542, LR=0.0006545084971874737
# Validation Loss = 0.102
# Channel 6V, Epoch=5, batch = 7000 of 32186, loss=0.577, LR=0.0006545084971874737
# Validation Loss = 0.004
# Channel 6V, Epoch=5, batch = 8000 of 32186, loss=0.528, LR=0.0006545084971874737
# Validation Loss = 0.025
# Channel 6V, Epoch=5, batch = 9000 of 32186, loss=0.589, LR=0.0006545084971874737
# Validation Loss = 0.001
# Channel 6V, Epoch=5, batch = 10000 of 32186, loss=0.615, LR=0.0006545084971874737
# Validation Loss = 0.161
# Channel 6V, Epoch=5, batch = 11000 of 32186, loss=0.665, LR=0.0006545084971874737
# Validation Loss = 0.000
# Channel 6V, Epoch=5, batch = 12000 of 32186, loss=0.547, LR=0.0006545084971874737
# Validation Loss = 0.042
# Channel 6V, Epoch=5, batch = 13000 of 32186, loss=0.707, LR=0.0006545084971874737
# Validation Loss = 0.251
# Channel 6V, Epoch=5, batch = 14000 of 32186, loss=0.595, LR=0.0006545084971874737
# Validation Loss = 0.286
# Channel 6V, Epoch=5, batch = 15000 of 32186, loss=1.186, LR=0.0006545084971874737
# Validation Loss = 0.001
# Channel 6V, Epoch=5, batch = 16000 of 32186, loss=0.613, LR=0.0006545084971874737
# Validation Loss = 0.000
# Channel 6V, Epoch=5, batch = 17000 of 32186, loss=0.542, LR=0.0006545084971874737
# Validation Loss = 0.010
# Channel 6V, Epoch=5, batch = 18000 of 32186, loss=0.584, LR=0.0006545084971874737
# Validation Loss = 0.002
# Channel 6V, Epoch=5, batch = 19000 of 32186, loss=0.601, LR=0.0006545084971874737
# Validation Loss = 0.050
# Channel 6V, Epoch=5, batch = 20000 of 32186, loss=0.589, LR=0.0006545084971874737
# Validation Loss = 0.001
# Channel 6V, Epoch=5, batch = 21000 of 32186, loss=0.586, LR=0.0006545084971874737
# Validation Loss = 0.000
# Channel 6V, Epoch=5, batch = 22000 of 32186, loss=0.520, LR=0.0006545084971874737
# Validation Loss = 0.140
# Channel 6V, Epoch=5, batch = 23000 of 32186, loss=0.623, LR=0.0006545084971874737
# Validation Loss = 0.130
# Channel 6V, Epoch=5, batch = 24000 of 32186, loss=0.604, LR=0.0006545084971874737
# Validation Loss = 0.227
# Channel 6V, Epoch=5, batch = 25000 of 32186, loss=0.702, LR=0.0006545084971874737
# Validation Loss = 0.002
# Channel 6V, Epoch=5, batch = 26000 of 32186, loss=0.666, LR=0.0006545084971874737
# Validation Loss = 0.096
# Channel 6V, Epoch=5, batch = 27000 of 32186, loss=0.577, LR=0.0006545084971874737
# Validation Loss = 0.059
# Channel 6V, Epoch=5, batch = 28000 of 32186, loss=0.549, LR=0.0006545084971874737
# Validation Loss = 0.005
# Channel 6V, Epoch=5, batch = 29000 of 32186, loss=0.622, LR=0.0006545084971874737
# Validation Loss = 0.017
# Channel 6V, Epoch=5, batch = 30000 of 32186, loss=0.495, LR=0.0006545084971874737
# Validation Loss = 0.140
# Channel 6V, Epoch=5, batch = 31000 of 32186, loss=0.562, LR=0.0006545084971874737
# Validation Loss = 0.073
# Channel 6V, Epoch=5, batch = 32000 of 32186, loss=0.515, LR=0.0006545084971874737
# Validation Loss = 0.000
# Channel 6V, Epoch=6, batch = 0 of 32186, loss=0.610, LR=0.0005
# Validation Loss = 0.171
# Channel 6V, Epoch=6, batch = 1000 of 32186, loss=0.645, LR=0.0005
# Validation Loss = 0.113
# Channel 6V, Epoch=6, batch = 2000 of 32186, loss=0.611, LR=0.0005
# Validation Loss = 0.182
# Channel 6V, Epoch=6, batch = 3000 of 32186, loss=0.623, LR=0.0005
# Validation Loss = 0.029
# Channel 6V, Epoch=6, batch = 4000 of 32186, loss=0.613, LR=0.0005
# Validation Loss = 0.083
# Channel 6V, Epoch=6, batch = 5000 of 32186, loss=0.548, LR=0.0005
# Validation Loss = 0.000
# Channel 6V, Epoch=6, batch = 6000 of 32186, loss=0.561, LR=0.0005
# Validation Loss = 0.119
# Channel 6V, Epoch=6, batch = 7000 of 32186, loss=0.875, LR=0.0005
# Validation Loss = 0.230
# Channel 6V, Epoch=6, batch = 8000 of 32186, loss=0.605, LR=0.0005
# Validation Loss = 0.012
# Channel 6V, Epoch=6, batch = 9000 of 32186, loss=0.562, LR=0.0005
# Validation Loss = 0.020
# Channel 6V, Epoch=6, batch = 10000 of 32186, loss=0.548, LR=0.0005
# Validation Loss = 0.071
# Channel 6V, Epoch=6, batch = 11000 of 32186, loss=0.515, LR=0.0005
# Validation Loss = 0.159
# Channel 6V, Epoch=6, batch = 12000 of 32186, loss=0.523, LR=0.0005
# Validation Loss = 0.011
# Channel 6V, Epoch=6, batch = 13000 of 32186, loss=0.586, LR=0.0005
# Validation Loss = 0.031
# Channel 6V, Epoch=6, batch = 14000 of 32186, loss=0.517, LR=0.0005
# Validation Loss = 0.001
# Channel 6V, Epoch=6, batch = 15000 of 32186, loss=0.598, LR=0.0005
# Validation Loss = 0.157
# Channel 6V, Epoch=6, batch = 16000 of 32186, loss=0.523, LR=0.0005
# Validation Loss = 0.212
# Channel 6V, Epoch=6, batch = 17000 of 32186, loss=0.650, LR=0.0005
# Validation Loss = 0.080
# Channel 6V, Epoch=6, batch = 18000 of 32186, loss=0.550, LR=0.0005
# Validation Loss = 0.161
# Channel 6V, Epoch=6, batch = 19000 of 32186, loss=0.545, LR=0.0005
# Validation Loss = 0.098
# Channel 6V, Epoch=6, batch = 20000 of 32186, loss=0.520, LR=0.0005
# Validation Loss = 0.018
# Channel 6V, Epoch=6, batch = 21000 of 32186, loss=0.513, LR=0.0005
# Validation Loss = 0.056
# Channel 6V, Epoch=6, batch = 22000 of 32186, loss=0.570, LR=0.0005
# Validation Loss = 0.196
# Channel 6V, Epoch=6, batch = 23000 of 32186, loss=0.484, LR=0.0005
# Validation Loss = 0.032
# Channel 6V, Epoch=6, batch = 24000 of 32186, loss=0.583, LR=0.0005
# Validation Loss = 0.018
# Channel 6V, Epoch=6, batch = 25000 of 32186, loss=0.605, LR=0.0005
# Validation Loss = 0.056
# Channel 6V, Epoch=6, batch = 26000 of 32186, loss=0.503, LR=0.0005
# Validation Loss = 0.001
# Channel 6V, Epoch=6, batch = 27000 of 32186, loss=0.636, LR=0.0005
# Validation Loss = 0.193
# Channel 6V, Epoch=6, batch = 28000 of 32186, loss=0.519, LR=0.0005
# Validation Loss = 0.074
# Channel 6V, Epoch=6, batch = 29000 of 32186, loss=0.544, LR=0.0005
# Validation Loss = 0.058
# Channel 6V, Epoch=6, batch = 30000 of 32186, loss=0.498, LR=0.0005
# Validation Loss = 0.006
# Channel 6V, Epoch=6, batch = 31000 of 32186, loss=0.544, LR=0.0005
# Validation Loss = 0.219
# Channel 6V, Epoch=6, batch = 32000 of 32186, loss=0.525, LR=0.0005
# Validation Loss = 0.257
# Channel 6V, Epoch=7, batch = 0 of 32186, loss=0.546, LR=0.00034549150281252633
# Validation Loss = 0.097
# Channel 6V, Epoch=7, batch = 1000 of 32186, loss=0.565, LR=0.00034549150281252633
# Validation Loss = 0.030
# Channel 6V, Epoch=7, batch = 2000 of 32186, loss=0.522, LR=0.00034549150281252633
# Validation Loss = 0.002
# Channel 6V, Epoch=7, batch = 3000 of 32186, loss=0.657, LR=0.00034549150281252633
# Validation Loss = 0.005
# Channel 6V, Epoch=7, batch = 4000 of 32186, loss=0.560, LR=0.00034549150281252633
# Validation Loss = 0.038
# Channel 6V, Epoch=7, batch = 5000 of 32186, loss=0.716, LR=0.00034549150281252633
# Validation Loss = 0.103
# Channel 6V, Epoch=7, batch = 6000 of 32186, loss=0.516, LR=0.00034549150281252633
# Validation Loss = 0.092
# Channel 6V, Epoch=7, batch = 7000 of 32186, loss=0.499, LR=0.00034549150281252633
# Validation Loss = 0.009
# Channel 6V, Epoch=7, batch = 8000 of 32186, loss=0.572, LR=0.00034549150281252633
# Validation Loss = 0.047
# Channel 6V, Epoch=7, batch = 9000 of 32186, loss=0.577, LR=0.00034549150281252633
# Validation Loss = 0.043
# Channel 6V, Epoch=7, batch = 10000 of 32186, loss=0.517, LR=0.00034549150281252633
# Validation Loss = 0.073
# Channel 6V, Epoch=7, batch = 11000 of 32186, loss=0.529, LR=0.00034549150281252633
# Validation Loss = 0.000
# Channel 6V, Epoch=7, batch = 12000 of 32186, loss=0.641, LR=0.00034549150281252633
# Validation Loss = 0.076
# Channel 6V, Epoch=7, batch = 13000 of 32186, loss=0.534, LR=0.00034549150281252633
# Validation Loss = 0.011
# Channel 6V, Epoch=7, batch = 14000 of 32186, loss=0.538, LR=0.00034549150281252633
# Validation Loss = 0.015
# Channel 6V, Epoch=7, batch = 15000 of 32186, loss=0.510, LR=0.00034549150281252633
# Validation Loss = 0.148
# Channel 6V, Epoch=7, batch = 16000 of 32186, loss=0.546, LR=0.00034549150281252633
# Validation Loss = 0.173
# Channel 6V, Epoch=7, batch = 17000 of 32186, loss=0.448, LR=0.00034549150281252633
# Validation Loss = 0.022
# Channel 6V, Epoch=7, batch = 18000 of 32186, loss=0.526, LR=0.00034549150281252633
# Validation Loss = 0.072
# Channel 6V, Epoch=7, batch = 19000 of 32186, loss=0.529, LR=0.00034549150281252633
# Validation Loss = 0.014
# Channel 6V, Epoch=7, batch = 20000 of 32186, loss=0.534, LR=0.00034549150281252633
# Validation Loss = 0.178
# Channel 6V, Epoch=7, batch = 21000 of 32186, loss=0.591, LR=0.00034549150281252633
# Validation Loss = 0.325
# Channel 6V, Epoch=7, batch = 22000 of 32186, loss=0.626, LR=0.00034549150281252633
# Validation Loss = 0.069
# Channel 6V, Epoch=7, batch = 23000 of 32186, loss=0.536, LR=0.00034549150281252633
# Validation Loss = 0.238
# Channel 6V, Epoch=7, batch = 24000 of 32186, loss=0.490, LR=0.00034549150281252633
# Validation Loss = 0.181
# Channel 6V, Epoch=7, batch = 25000 of 32186, loss=0.599, LR=0.00034549150281252633
# Validation Loss = 0.101
# Channel 6V, Epoch=7, batch = 26000 of 32186, loss=0.523, LR=0.00034549150281252633
# Validation Loss = 0.057
# Channel 6V, Epoch=7, batch = 27000 of 32186, loss=0.517, LR=0.00034549150281252633
# Validation Loss = 0.222
# Channel 6V, Epoch=7, batch = 28000 of 32186, loss=0.435, LR=0.00034549150281252633
# Validation Loss = 0.149
# Channel 6V, Epoch=7, batch = 29000 of 32186, loss=0.521, LR=0.00034549150281252633
# Validation Loss = 0.102
# Channel 6V, Epoch=7, batch = 30000 of 32186, loss=0.557, LR=0.00034549150281252633
# Validation Loss = 0.076
# Channel 6V, Epoch=7, batch = 31000 of 32186, loss=0.538, LR=0.00034549150281252633
# Validation Loss = 0.113
# Channel 6V, Epoch=7, batch = 32000 of 32186, loss=0.517, LR=0.00034549150281252633
# Validation Loss = 0.156
# Channel 6V, Epoch=8, batch = 0 of 32186, loss=0.458, LR=0.0002061073738537635
# Validation Loss = 0.032
# Channel 6V, Epoch=8, batch = 1000 of 32186, loss=0.561, LR=0.0002061073738537635
# Validation Loss = 0.132
# Channel 6V, Epoch=8, batch = 2000 of 32186, loss=0.522, LR=0.0002061073738537635
# Validation Loss = 0.244
# Channel 6V, Epoch=8, batch = 3000 of 32186, loss=0.586, LR=0.0002061073738537635
# Validation Loss = 0.075
# Channel 6V, Epoch=8, batch = 4000 of 32186, loss=0.508, LR=0.0002061073738537635
# Validation Loss = 0.079
# Channel 6V, Epoch=8, batch = 5000 of 32186, loss=0.508, LR=0.0002061073738537635
# Validation Loss = 0.122
# Channel 6V, Epoch=8, batch = 6000 of 32186, loss=0.503, LR=0.0002061073738537635
# Validation Loss = 0.084
# Channel 6V, Epoch=8, batch = 7000 of 32186, loss=0.517, LR=0.0002061073738537635
# Validation Loss = 0.069
# Channel 6V, Epoch=8, batch = 8000 of 32186, loss=0.508, LR=0.0002061073738537635
# Validation Loss = 0.071
# Channel 6V, Epoch=8, batch = 9000 of 32186, loss=0.554, LR=0.0002061073738537635
# Validation Loss = 0.155
# Channel 6V, Epoch=8, batch = 10000 of 32186, loss=0.538, LR=0.0002061073738537635
# Validation Loss = 0.005
# Channel 6V, Epoch=8, batch = 11000 of 32186, loss=0.625, LR=0.0002061073738537635
# Validation Loss = 0.100
# Channel 6V, Epoch=8, batch = 12000 of 32186, loss=0.525, LR=0.0002061073738537635
# Validation Loss = 0.062
# Channel 6V, Epoch=8, batch = 13000 of 32186, loss=0.517, LR=0.0002061073738537635
# Validation Loss = 0.039
# Channel 6V, Epoch=8, batch = 14000 of 32186, loss=0.523, LR=0.0002061073738537635
# Validation Loss = 0.041
# Channel 6V, Epoch=8, batch = 15000 of 32186, loss=0.454, LR=0.0002061073738537635
# Validation Loss = 0.039
# Channel 6V, Epoch=8, batch = 16000 of 32186, loss=0.505, LR=0.0002061073738537635
# Validation Loss = 0.089
# Channel 6V, Epoch=8, batch = 17000 of 32186, loss=0.471, LR=0.0002061073738537635
# Validation Loss = 0.077
# Channel 6V, Epoch=8, batch = 18000 of 32186, loss=0.516, LR=0.0002061073738537635
# Validation Loss = 0.020
# Channel 6V, Epoch=8, batch = 19000 of 32186, loss=0.585, LR=0.0002061073738537635
# Validation Loss = 0.101
# Channel 6V, Epoch=8, batch = 20000 of 32186, loss=0.554, LR=0.0002061073738537635
# Validation Loss = 0.150
# Channel 6V, Epoch=8, batch = 21000 of 32186, loss=0.504, LR=0.0002061073738537635
# Validation Loss = 0.068
# Channel 6V, Epoch=8, batch = 22000 of 32186, loss=0.510, LR=0.0002061073738537635
# Validation Loss = 0.197
# Channel 6V, Epoch=8, batch = 23000 of 32186, loss=0.526, LR=0.0002061073738537635
# Validation Loss = 0.111
# Channel 6V, Epoch=8, batch = 24000 of 32186, loss=0.510, LR=0.0002061073738537635
# Validation Loss = 0.285
# Channel 6V, Epoch=8, batch = 25000 of 32186, loss=0.592, LR=0.0002061073738537635
# Validation Loss = 0.083
# Channel 6V, Epoch=8, batch = 26000 of 32186, loss=0.550, LR=0.0002061073738537635
# Validation Loss = 0.030
# Channel 6V, Epoch=8, batch = 27000 of 32186, loss=0.562, LR=0.0002061073738537635
# Validation Loss = 0.126
# Channel 6V, Epoch=8, batch = 28000 of 32186, loss=0.533, LR=0.0002061073738537635
# Validation Loss = 0.054
# Channel 6V, Epoch=8, batch = 29000 of 32186, loss=0.560, LR=0.0002061073738537635
# Validation Loss = 0.050
# Channel 6V, Epoch=8, batch = 30000 of 32186, loss=0.539, LR=0.0002061073738537635
# Validation Loss = 0.078
# Channel 6V, Epoch=8, batch = 31000 of 32186, loss=0.496, LR=0.0002061073738537635
# Validation Loss = 0.048
# Channel 6V, Epoch=8, batch = 32000 of 32186, loss=0.569, LR=0.0002061073738537635
# Validation Loss = 0.139
# Channel 6V, Epoch=9, batch = 0 of 32186, loss=0.591, LR=9.549150281252634e-05
# Validation Loss = 0.096
# Channel 6V, Epoch=9, batch = 1000 of 32186, loss=0.498, LR=9.549150281252634e-05
# Validation Loss = 0.041
# Channel 6V, Epoch=9, batch = 2000 of 32186, loss=0.505, LR=9.549150281252634e-05
# Validation Loss = 0.108
# Channel 6V, Epoch=9, batch = 3000 of 32186, loss=0.485, LR=9.549150281252634e-05
# Validation Loss = 0.057
# Channel 6V, Epoch=9, batch = 4000 of 32186, loss=0.526, LR=9.549150281252634e-05
# Validation Loss = 0.101
# Channel 6V, Epoch=9, batch = 5000 of 32186, loss=0.561, LR=9.549150281252634e-05
# Validation Loss = 0.025
# Channel 6V, Epoch=9, batch = 6000 of 32186, loss=0.491, LR=9.549150281252634e-05
# Validation Loss = 0.231
# Channel 6V, Epoch=9, batch = 7000 of 32186, loss=0.557, LR=9.549150281252634e-05
# Validation Loss = 0.035
# Channel 6V, Epoch=9, batch = 8000 of 32186, loss=0.502, LR=9.549150281252634e-05
# Validation Loss = 0.057
# Channel 6V, Epoch=9, batch = 9000 of 32186, loss=0.514, LR=9.549150281252634e-05
# Validation Loss = 0.090
# Channel 6V, Epoch=9, batch = 10000 of 32186, loss=0.535, LR=9.549150281252634e-05
# Validation Loss = 0.142
# Channel 6V, Epoch=9, batch = 11000 of 32186, loss=0.528, LR=9.549150281252634e-05
# Validation Loss = 0.102
# Channel 6V, Epoch=9, batch = 12000 of 32186, loss=0.460, LR=9.549150281252634e-05
# Validation Loss = 0.083
# Channel 6V, Epoch=9, batch = 13000 of 32186, loss=0.526, LR=9.549150281252634e-05
# Validation Loss = 0.054
# Channel 6V, Epoch=9, batch = 14000 of 32186, loss=0.521, LR=9.549150281252634e-05
# Validation Loss = 0.117
# Channel 6V, Epoch=9, batch = 15000 of 32186, loss=0.526, LR=9.549150281252634e-05
# Validation Loss = 0.065
# Channel 6V, Epoch=9, batch = 16000 of 32186, loss=0.511, LR=9.549150281252634e-05
# Validation Loss = 0.098
# Channel 6V, Epoch=9, batch = 17000 of 32186, loss=0.459, LR=9.549150281252634e-05
# Validation Loss = 0.039
# Channel 6V, Epoch=9, batch = 18000 of 32186, loss=0.454, LR=9.549150281252634e-05
# Validation Loss = 0.131
# Channel 6V, Epoch=9, batch = 19000 of 32186, loss=0.518, LR=9.549150281252634e-05
# Validation Loss = 0.049
# Channel 6V, Epoch=9, batch = 20000 of 32186, loss=0.533, LR=9.549150281252634e-05
# Validation Loss = 0.118
# Channel 6V, Epoch=9, batch = 21000 of 32186, loss=0.466, LR=9.549150281252634e-05
# Validation Loss = 0.030
# Channel 6V, Epoch=9, batch = 22000 of 32186, loss=0.556, LR=9.549150281252634e-05
# Validation Loss = 0.121
# Channel 6V, Epoch=9, batch = 23000 of 32186, loss=0.517, LR=9.549150281252634e-05
# Validation Loss = 0.066
# Channel 6V, Epoch=9, batch = 24000 of 32186, loss=0.525, LR=9.549150281252634e-05
# Validation Loss = 0.139
# Channel 6V, Epoch=9, batch = 25000 of 32186, loss=0.593, LR=9.549150281252634e-05
# Validation Loss = 0.067
# Channel 6V, Epoch=9, batch = 26000 of 32186, loss=0.552, LR=9.549150281252634e-05
# Validation Loss = 0.143
# Channel 6V, Epoch=9, batch = 27000 of 32186, loss=0.518, LR=9.549150281252634e-05
# Validation Loss = 0.057
# Channel 6V, Epoch=9, batch = 28000 of 32186, loss=0.485, LR=9.549150281252634e-05
# Validation Loss = 0.120
# Channel 6V, Epoch=9, batch = 29000 of 32186, loss=0.498, LR=9.549150281252634e-05
# Validation Loss = 0.065
# Channel 6V, Epoch=9, batch = 30000 of 32186, loss=0.464, LR=9.549150281252634e-05
# Validation Loss = 0.054
# Channel 6V, Epoch=9, batch = 31000 of 32186, loss=0.486, LR=9.549150281252634e-05
# Validation Loss = 0.110
# Channel 6V, Epoch=9, batch = 32000 of 32186, loss=0.500, LR=9.549150281252634e-05
# Validation Loss = 0.057
# Channel 6V, Epoch=10, batch = 0 of 32186, loss=0.567, LR=2.4471741852423235e-05
# Validation Loss = 0.066
# Channel 6V, Epoch=10, batch = 1000 of 32186, loss=0.465, LR=2.4471741852423235e-05
# Validation Loss = 0.109
# Channel 6V, Epoch=10, batch = 2000 of 32186, loss=0.536, LR=2.4471741852423235e-05
# Validation Loss = 0.105
# Channel 6V, Epoch=10, batch = 3000 of 32186, loss=0.535, LR=2.4471741852423235e-05
# Validation Loss = 0.084
# Channel 6V, Epoch=10, batch = 4000 of 32186, loss=0.519, LR=2.4471741852423235e-05
# Validation Loss = 0.079
# Channel 6V, Epoch=10, batch = 5000 of 32186, loss=0.523, LR=2.4471741852423235e-05
# ...
# Channel 37H, Epoch=16, batch = 18000 of 32186, loss=3.861, LR=0.00014644660940672625
# Validation Loss = 10.232
# Channel 37H, Epoch=16, batch = 19000 of 32186, loss=3.313, LR=0.00014644660940672625
# Validation Loss = 10.747
# Channel 37H, Epoch=16, batch = 20000 of 32186, loss=3.082, LR=0.00014644660940672625
# Validation Loss = 13.610
# Channel 37H, Epoch=16, batch = 21000 of 32186, loss=3.433, LR=0.00014644660940672625
# Validation Loss = 8.067
# Channel 37H, Epoch=16, batch = 22000 of 32186, loss=3.298, LR=0.00014644660940672625
# Validation Loss = 12.176
# Channel 37H, Epoch=16, batch = 23000 of 32186, loss=3.499, LR=0.00014644660940672625
# Validation Loss = 10.970
# Channel 37H, Epoch=16, batch = 24000 of 32186, loss=3.294, LR=0.00014644660940672625
# Validation Loss = 7.566
# Channel 37H, Epoch=16, batch = 25000 of 32186, loss=3.160, LR=0.00014644660940672625
# Validation Loss = 11.496
# Channel 37H, Epoch=16, batch = 26000 of 32186, loss=3.616, LR=0.00014644660940672625
# Validation Loss = 11.315
# Channel 37H, Epoch=16, batch = 27000 of 32186, loss=3.401, LR=0.00014644660940672625
# Validation Loss = 16.030
# Channel 37H, Epoch=16, batch = 28000 of 32186, loss=3.264, LR=0.00014644660940672625
# Validation Loss = 9.720
# Channel 37H, Epoch=16, batch = 29000 of 32186, loss=3.135, LR=0.00014644660940672625
# Validation Loss = 13.136
# Channel 37H, Epoch=16, batch = 30000 of 32186, loss=3.268, LR=0.00014644660940672625
# Validation Loss = 14.140
# Channel 37H, Epoch=16, batch = 31000 of 32186, loss=3.643, LR=0.00014644660940672625
# Validation Loss = 15.240
# Channel 37H, Epoch=16, batch = 32000 of 32186, loss=3.545, LR=0.00014644660940672625
# Validation Loss = 14.596
# Channel 37H, Epoch=17, batch = 0 of 32186, loss=3.353, LR=9.549150281252631e-05
# Validation Loss = 13.848
# Channel 37H, Epoch=17, batch = 1000 of 32186, loss=3.153, LR=9.549150281252631e-05
# Validation Loss = 10.550
# Channel 37H, Epoch=17, batch = 2000 of 32186, loss=3.701, LR=9.549150281252631e-05
# Validation Loss = 12.214
# Channel 37H, Epoch=17, batch = 3000 of 32186, loss=3.103, LR=9.549150281252631e-05
# Validation Loss = 13.598
# Channel 37H, Epoch=17, batch = 4000 of 32186, loss=3.361, LR=9.549150281252631e-05
# Validation Loss = 9.574
# Channel 37H, Epoch=17, batch = 5000 of 32186, loss=3.267, LR=9.549150281252631e-05
# Validation Loss = 11.714
# Channel 37H, Epoch=17, batch = 6000 of 32186, loss=3.253, LR=9.549150281252631e-05
# Validation Loss = 12.151
# Channel 37H, Epoch=17, batch = 7000 of 32186, loss=2.935, LR=9.549150281252631e-05
# Validation Loss = 11.512
# Channel 37H, Epoch=17, batch = 8000 of 32186, loss=3.103, LR=9.549150281252631e-05
# Validation Loss = 12.362
# Channel 37H, Epoch=17, batch = 9000 of 32186, loss=3.157, LR=9.549150281252631e-05
# Validation Loss = 11.254
# Channel 37H, Epoch=17, batch = 10000 of 32186, loss=3.952, LR=9.549150281252631e-05
# Validation Loss = 15.988
# Channel 37H, Epoch=17, batch = 11000 of 32186, loss=4.148, LR=9.549150281252631e-05
# Validation Loss = 12.343
# Channel 37H, Epoch=17, batch = 12000 of 32186, loss=3.134, LR=9.549150281252631e-05
# Validation Loss = 10.706
# Channel 37H, Epoch=17, batch = 13000 of 32186, loss=3.730, LR=9.549150281252631e-05
# Validation Loss = 9.225
# Channel 37H, Epoch=17, batch = 14000 of 32186, loss=3.923, LR=9.549150281252631e-05
# Validation Loss = 12.615
# Channel 37H, Epoch=17, batch = 15000 of 32186, loss=3.681, LR=9.549150281252631e-05
# Validation Loss = 12.038
# Channel 37H, Epoch=17, batch = 16000 of 32186, loss=3.116, LR=9.549150281252631e-05
# Validation Loss = 13.117
# Channel 37H, Epoch=17, batch = 17000 of 32186, loss=3.091, LR=9.549150281252631e-05
# Validation Loss = 11.304
# Channel 37H, Epoch=17, batch = 18000 of 32186, loss=3.470, LR=9.549150281252631e-05
# Validation Loss = 10.864
# Channel 37H, Epoch=17, batch = 19000 of 32186, loss=3.186, LR=9.549150281252631e-05
# Validation Loss = 11.858
# Channel 37H, Epoch=17, batch = 20000 of 32186, loss=3.508, LR=9.549150281252631e-05
# Validation Loss = 11.366
# Channel 37H, Epoch=17, batch = 21000 of 32186, loss=2.819, LR=9.549150281252631e-05
# Validation Loss = 8.949
# Channel 37H, Epoch=17, batch = 22000 of 32186, loss=3.704, LR=9.549150281252631e-05
# Validation Loss = 11.282
# Channel 37H, Epoch=17, batch = 23000 of 32186, loss=3.586, LR=9.549150281252631e-05
# Validation Loss = 9.310
# Channel 37H, Epoch=17, batch = 24000 of 32186, loss=3.502, LR=9.549150281252631e-05
# Validation Loss = 8.658
# Channel 37H, Epoch=17, batch = 25000 of 32186, loss=3.312, LR=9.549150281252631e-05
# Validation Loss = 12.779
# Channel 37H, Epoch=17, batch = 26000 of 32186, loss=3.486, LR=9.549150281252631e-05
# Validation Loss = 11.525
# Channel 37H, Epoch=17, batch = 27000 of 32186, loss=2.748, LR=9.549150281252631e-05
# Validation Loss = 11.703
# Channel 37H, Epoch=17, batch = 28000 of 32186, loss=3.284, LR=9.549150281252631e-05
# Validation Loss = 12.203
# Channel 37H, Epoch=17, batch = 29000 of 32186, loss=3.291, LR=9.549150281252631e-05
# Validation Loss = 9.977
# Channel 37H, Epoch=17, batch = 30000 of 32186, loss=3.839, LR=9.549150281252631e-05
# Validation Loss = 12.395
# Channel 37H, Epoch=17, batch = 31000 of 32186, loss=3.779, LR=9.549150281252631e-05
# Validation Loss = 9.207
# Channel 37H, Epoch=17, batch = 32000 of 32186, loss=3.132, LR=9.549150281252631e-05
# Validation Loss = 12.559
# Channel 37H, Epoch=18, batch = 0 of 32186, loss=3.343, LR=5.4496737905816096e-05
# Validation Loss = 11.456
# Channel 37H, Epoch=18, batch = 1000 of 32186, loss=3.213, LR=5.4496737905816096e-05
# Validation Loss = 11.064
# Channel 37H, Epoch=18, batch = 2000 of 32186, loss=3.351, LR=5.4496737905816096e-05
# Validation Loss = 11.940
# Channel 37H, Epoch=18, batch = 3000 of 32186, loss=3.543, LR=5.4496737905816096e-05
# Validation Loss = 10.059
# Channel 37H, Epoch=18, batch = 4000 of 32186, loss=3.093, LR=5.4496737905816096e-05
# Validation Loss = 10.486
# Channel 37H, Epoch=18, batch = 5000 of 32186, loss=2.944, LR=5.4496737905816096e-05
# Validation Loss = 8.509
# Channel 37H, Epoch=18, batch = 6000 of 32186, loss=3.516, LR=5.4496737905816096e-05
# Validation Loss = 9.083
# Channel 37H, Epoch=18, batch = 7000 of 32186, loss=3.069, LR=5.4496737905816096e-05
# Validation Loss = 14.067
# Channel 37H, Epoch=18, batch = 8000 of 32186, loss=2.945, LR=5.4496737905816096e-05
# Validation Loss = 12.547
# Channel 37H, Epoch=18, batch = 9000 of 32186, loss=3.091, LR=5.4496737905816096e-05
# Validation Loss = 11.680
# Channel 37H, Epoch=18, batch = 10000 of 32186, loss=3.562, LR=5.4496737905816096e-05
# Validation Loss = 9.680
# Channel 37H, Epoch=18, batch = 11000 of 32186, loss=3.714, LR=5.4496737905816096e-05
# Validation Loss = 11.767
# Channel 37H, Epoch=18, batch = 12000 of 32186, loss=2.923, LR=5.4496737905816096e-05
# Validation Loss = 9.927
# Channel 37H, Epoch=18, batch = 13000 of 32186, loss=3.368, LR=5.4496737905816096e-05
# Validation Loss = 9.519
# Channel 37H, Epoch=18, batch = 14000 of 32186, loss=3.348, LR=5.4496737905816096e-05
# Validation Loss = 12.892
# Channel 37H, Epoch=18, batch = 15000 of 32186, loss=3.346, LR=5.4496737905816096e-05
# Validation Loss = 13.539
# Channel 37H, Epoch=18, batch = 16000 of 32186, loss=2.996, LR=5.4496737905816096e-05
# Validation Loss = 11.092
# Channel 37H, Epoch=18, batch = 17000 of 32186, loss=3.088, LR=5.4496737905816096e-05
# Validation Loss = 11.652
# Channel 37H, Epoch=18, batch = 18000 of 32186, loss=3.130, LR=5.4496737905816096e-05
# Validation Loss = 8.414
# Channel 37H, Epoch=18, batch = 19000 of 32186, loss=3.398, LR=5.4496737905816096e-05
# Validation Loss = 14.530
# Channel 37H, Epoch=18, batch = 20000 of 32186, loss=3.058, LR=5.4496737905816096e-05
# Validation Loss = 11.318
# Channel 37H, Epoch=18, batch = 21000 of 32186, loss=3.693, LR=5.4496737905816096e-05
# Validation Loss = 10.768
# Channel 37H, Epoch=18, batch = 22000 of 32186, loss=3.296, LR=5.4496737905816096e-05
# Validation Loss = 13.158
# Channel 37H, Epoch=18, batch = 23000 of 32186, loss=3.452, LR=5.4496737905816096e-05
# Validation Loss = 11.229
# Channel 37H, Epoch=18, batch = 24000 of 32186, loss=3.310, LR=5.4496737905816096e-05
# Validation Loss = 12.697
# Channel 37H, Epoch=18, batch = 25000 of 32186, loss=2.820, LR=5.4496737905816096e-05
# Validation Loss = 12.514
# Channel 37H, Epoch=18, batch = 26000 of 32186, loss=3.192, LR=5.4496737905816096e-05
# Validation Loss = 11.249
# Channel 37H, Epoch=18, batch = 27000 of 32186, loss=2.920, LR=5.4496737905816096e-05
# Validation Loss = 13.420
# Channel 37H, Epoch=18, batch = 28000 of 32186, loss=3.170, LR=5.4496737905816096e-05
# Validation Loss = 12.678
# Channel 37H, Epoch=18, batch = 29000 of 32186, loss=3.643, LR=5.4496737905816096e-05
# Validation Loss = 11.633
# Channel 37H, Epoch=18, batch = 30000 of 32186, loss=3.248, LR=5.4496737905816096e-05
# Validation Loss = 10.302
# Channel 37H, Epoch=18, batch = 31000 of 32186, loss=3.086, LR=5.4496737905816096e-05
# Validation Loss = 11.265
# Channel 37H, Epoch=18, batch = 32000 of 32186, loss=3.290, LR=5.4496737905816096e-05
# Validation Loss = 10.680
# Channel 37H, Epoch=19, batch = 0 of 32186, loss=3.125, LR=2.447174185242323e-05
# Validation Loss = 13.695
# Channel 37H, Epoch=19, batch = 1000 of 32186, loss=3.048, LR=2.447174185242323e-05
# Validation Loss = 11.926
# Channel 37H, Epoch=19, batch = 2000 of 32186, loss=3.036, LR=2.447174185242323e-05
# Validation Loss = 13.221
# Channel 37H, Epoch=19, batch = 3000 of 32186, loss=2.985, LR=2.447174185242323e-05
# Validation Loss = 12.453
# Channel 37H, Epoch=19, batch = 4000 of 32186, loss=2.984, LR=2.447174185242323e-05
# Validation Loss = 12.067
# Channel 37H, Epoch=19, batch = 5000 of 32186, loss=3.419, LR=2.447174185242323e-05
# Validation Loss = 10.644
# Channel 37H, Epoch=19, batch = 6000 of 32186, loss=3.460, LR=2.447174185242323e-05
# Validation Loss = 12.079
# Channel 37H, Epoch=19, batch = 7000 of 32186, loss=3.385, LR=2.447174185242323e-05
# Validation Loss = 12.365
# Channel 37H, Epoch=19, batch = 8000 of 32186, loss=3.374, LR=2.447174185242323e-05
# Validation Loss = 11.970
# Channel 37H, Epoch=19, batch = 9000 of 32186, loss=3.309, LR=2.447174185242323e-05
# Validation Loss = 12.413
# Channel 37H, Epoch=19, batch = 10000 of 32186, loss=2.960, LR=2.447174185242323e-05
# Validation Loss = 12.041
# Channel 37H, Epoch=19, batch = 11000 of 32186, loss=3.257, LR=2.447174185242323e-05
# Validation Loss = 11.441
# Channel 37H, Epoch=19, batch = 12000 of 32186, loss=3.479, LR=2.447174185242323e-05
# Validation Loss = 12.557
# Channel 37H, Epoch=19, batch = 13000 of 32186, loss=3.131, LR=2.447174185242323e-05
# Validation Loss = 11.554
# Channel 37H, Epoch=19, batch = 14000 of 32186, loss=2.731, LR=2.447174185242323e-05
# Validation Loss = 10.571
# Channel 37H, Epoch=19, batch = 15000 of 32186, loss=3.241, LR=2.447174185242323e-05
# Validation Loss = 11.468
# Channel 37H, Epoch=19, batch = 16000 of 32186, loss=3.324, LR=2.447174185242323e-05
# Validation Loss = 13.059
# Channel 37H, Epoch=19, batch = 17000 of 32186, loss=3.745, LR=2.447174185242323e-05
# Validation Loss = 12.640
# Channel 37H, Epoch=19, batch = 18000 of 32186, loss=3.419, LR=2.447174185242323e-05
# Validation Loss = 11.748
# Channel 37H, Epoch=19, batch = 19000 of 32186, loss=3.545, LR=2.447174185242323e-05
# Validation Loss = 11.848
# Channel 37H, Epoch=19, batch = 20000 of 32186, loss=2.953, LR=2.447174185242323e-05
# Validation Loss = 11.859
# Channel 37H, Epoch=19, batch = 21000 of 32186, loss=3.349, LR=2.447174185242323e-05
# Validation Loss = 12.425
# Channel 37H, Epoch=19, batch = 22000 of 32186, loss=3.325, LR=2.447174185242323e-05
# Validation Loss = 11.884
# Channel 37H, Epoch=19, batch = 23000 of 32186, loss=2.959, LR=2.447174185242323e-05
# Validation Loss = 10.336
# Channel 37H, Epoch=19, batch = 24000 of 32186, loss=3.133, LR=2.447174185242323e-05
# Validation Loss = 11.547
# Channel 37H, Epoch=19, batch = 25000 of 32186, loss=4.110, LR=2.447174185242323e-05
# Validation Loss = 12.453
# Channel 37H, Epoch=19, batch = 26000 of 32186, loss=2.925, LR=2.447174185242323e-05
# Validation Loss = 10.716
# Channel 37H, Epoch=19, batch = 27000 of 32186, loss=2.925, LR=2.447174185242323e-05
# Validation Loss = 12.751
# Channel 37H, Epoch=19, batch = 28000 of 32186, loss=2.971, LR=2.447174185242323e-05
# Validation Loss = 12.893
# Channel 37H, Epoch=19, batch = 29000 of 32186, loss=3.089, LR=2.447174185242323e-05
# Validation Loss = 12.406
# Channel 37H, Epoch=19, batch = 30000 of 32186, loss=3.511, LR=2.447174185242323e-05
# Validation Loss = 12.169
# Channel 37H, Epoch=19, batch = 31000 of 32186, loss=3.256, LR=2.447174185242323e-05
# Validation Loss = 10.972
# Channel 37H, Epoch=19, batch = 32000 of 32186, loss=2.720, LR=2.447174185242323e-05
# Validation Loss = 9.946
# Channel 37H, Epoch=20, batch = 0 of 32186, loss=3.444, LR=6.15582970243117e-06
# Validation Loss = 12.356
# Channel 37H, Epoch=20, batch = 1000 of 32186, loss=2.823, LR=6.15582970243117e-06
# Validation Loss = 11.923
# Channel 37H, Epoch=20, batch = 2000 of 32186, loss=3.742, LR=6.15582970243117e-06
# Validation Loss = 11.143
# Channel 37H, Epoch=20, batch = 3000 of 32186, loss=3.364, LR=6.15582970243117e-06
# Validation Loss = 11.480
# Channel 37H, Epoch=20, batch = 4000 of 32186, loss=3.057, LR=6.15582970243117e-06
# Validation Loss = 11.819
# Channel 37H, Epoch=20, batch = 5000 of 32186, loss=3.221, LR=6.15582970243117e-06
# Validation Loss = 11.755
# Channel 37H, Epoch=20, batch = 6000 of 32186, loss=3.431, LR=6.15582970243117e-06
# Validation Loss = 11.725
# Channel 37H, Epoch=20, batch = 7000 of 32186, loss=3.280, LR=6.15582970243117e-06
# Validation Loss = 11.847
# Channel 37H, Epoch=20, batch = 8000 of 32186, loss=3.127, LR=6.15582970243117e-06
# Validation Loss = 11.686
# Channel 37H, Epoch=20, batch = 9000 of 32186, loss=3.067, LR=6.15582970243117e-06
# Validation Loss = 12.239
# Channel 37H, Epoch=20, batch = 10000 of 32186, loss=3.344, LR=6.15582970243117e-06
# Validation Loss = 11.122
# Channel 37H, Epoch=20, batch = 11000 of 32186, loss=2.867, LR=6.15582970243117e-06
# Validation Loss = 11.977
# Channel 37H, Epoch=20, batch = 12000 of 32186, loss=2.940, LR=6.15582970243117e-06
# Validation Loss = 12.233
# Channel 37H, Epoch=20, batch = 13000 of 32186, loss=2.738, LR=6.15582970243117e-06
# Validation Loss = 11.384
# Channel 37H, Epoch=20, batch = 14000 of 32186, loss=3.203, LR=6.15582970243117e-06
# Validation Loss = 12.574
# Channel 37H, Epoch=20, batch = 15000 of 32186, loss=3.048, LR=6.15582970243117e-06
# Validation Loss = 11.988
# Channel 37H, Epoch=20, batch = 16000 of 32186, loss=3.106, LR=6.15582970243117e-06
# Validation Loss = 12.705
# Channel 37H, Epoch=20, batch = 17000 of 32186, loss=3.166, LR=6.15582970243117e-06
# Validation Loss = 11.603
# Channel 37H, Epoch=20, batch = 18000 of 32186, loss=3.036, LR=6.15582970243117e-06
# Validation Loss = 11.981
# Channel 37H, Epoch=20, batch = 19000 of 32186, loss=3.197, LR=6.15582970243117e-06
# Validation Loss = 11.787
# Channel 37H, Epoch=20, batch = 20000 of 32186, loss=3.268, LR=6.15582970243117e-06
# Validation Loss = 11.972
# Channel 37H, Epoch=20, batch = 21000 of 32186, loss=2.995, LR=6.15582970243117e-06
# Validation Loss = 11.866
# Channel 37H, Epoch=20, batch = 22000 of 32186, loss=3.379, LR=6.15582970243117e-06
# Validation Loss = 12.347
# Channel 37H, Epoch=20, batch = 23000 of 32186, loss=3.426, LR=6.15582970243117e-06
# Validation Loss = 10.706
# Channel 37H, Epoch=20, batch = 24000 of 32186, loss=2.895, LR=6.15582970243117e-06
# Validation Loss = 13.045
# Channel 37H, Epoch=20, batch = 25000 of 32186, loss=3.251, LR=6.15582970243117e-06
# Validation Loss = 11.573
# Channel 37H, Epoch=20, batch = 26000 of 32186, loss=3.105, LR=6.15582970243117e-06
# Validation Loss = 11.878
# Channel 37H, Epoch=20, batch = 27000 of 32186, loss=3.662, LR=6.15582970243117e-06
# Validation Loss = 11.458
# Channel 37H, Epoch=20, batch = 28000 of 32186, loss=2.761, LR=6.15582970243117e-06
# Validation Loss = 12.021
# Channel 37H, Epoch=20, batch = 29000 of 32186, loss=3.070, LR=6.15582970243117e-06
# Validation Loss = 11.779
# Channel 37H, Epoch=20, batch = 30000 of 32186, loss=2.743, LR=6.15582970243117e-06
# Validation Loss = 10.991
# Channel 37H, Epoch=20, batch = 31000 of 32186, loss=3.001, LR=6.15582970243117e-06
# Validation Loss = 12.569
# Channel 37H, Epoch=20, batch = 32000 of 32186, loss=3.160, LR=6.15582970243117e-06
# Finished training model for channel 37H.
