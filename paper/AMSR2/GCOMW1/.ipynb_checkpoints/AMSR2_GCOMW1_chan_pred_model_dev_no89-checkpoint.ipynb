# %% [markdown]
# # Channel Prediction Model for Quality Control
#
# This notebook contains the code and outlines the development of the
# SSMI Channel Prediction Neural Network for QC purposes of SSMIS L1C
# data. The simple Feed-Forward Neural Networks (FFNNs) are trained on
# good quality SSMIS brightness temperature observation vectors and are
# trained to predict one channel from all the others as predictors.
#
# The end product is a tree of FFNNs, discretized by surface (ocean or
# land), and by channel, since these are fully distinct problems.

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import glob
import torch
from torch import nn
import cartopy.crs as ccrs
from util_funcs.L1C import scantime2datetime
from util_funcs import data2xarray, array_funcs
import geography
from tqdm import tqdm

from dataset_class import dataset
from model_class import channel_predictor
import local_functions
import sensor_info


#General parameters:

satellite = sensor_info.satellite
sensor = sensor_info.sensor

nchans = sensor_info.nchannels
batch_size = 1000
input_size = nchans - 1
hidden_size = 256
output_size = 1

# %%
nchans
# Out:
# 12

# %%
'''
Function Definitions:
'''

chan_desc = sensor_info.channel_descriptions


def extract_channel(Tb_array, chan):

    '''
    Use in preparing training data.

    Assumes Tb array is [m x n] where m (rows) are samples
    and n (columns) is the number of channels.

    Passing in the channel description splits the data so
    that the specified channel is its own vector y and the
    rest are kept as predictors x.

    Inputs:
        Tb_array    |  ndarray of Tbs
        chan        |  string of channel name
    Outputs:
        x           |  matrix of predictors (other channels)
        y           |  vector of predictands (the missing channel)
        
    '''
    
    chan_desc = np.array(sensor_info.channel_descriptions)


    chan_indx = np.where(chan == chan_desc)[0]

    if np.size(chan_indx) == 0:
        raise ValueError(f'Channel description must be in list {chan_desc}.')

    y = Tb_array[:,chan_indx]
    x = Tb_array[:,np.delete(np.arange(0,len(chan_desc)),chan_indx)]

    return x, y


def train_model(model, nepochs, dataloader, learning_rate=0.001, quiet=False, stage=None, validation_dataloader=None):

    nbatches = len(dataloader)
    
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=nepochs)
    device = None

    if stage:
        print(f'Training stage: {stage}')

    loss_arr    = np.zeros([nbatches,nepochs], dtype='f')
    valloss_arr = np.zeros([nbatches,nepochs], dtype='f')
    
    for epoch in range(nepochs):
        for i, (profs, obs) in enumerate(dataloader):
            if device:
                profs, obs = profs.to(device), obs.to(device)

            if validation_dataloader and i%1000==0:
                valprofs, valobs = next(enumerate(validation_dataloader))[1]
                val_pred = model(valprofs)
                valloss  = criterion(val_pred, valobs)
                print(f'Validation Loss = {valloss.item():.3f}')

            #Forward pass:
            obs_pred = model(profs)
            loss     = criterion(obs_pred, obs)


            #Backward pass:
            optimizer.zero_grad()
            loss.backward()

            #Update neurons:
            optimizer.step()

            loss_arr[i,epoch] = loss.item()
            valloss_arr[i,epoch] = valloss.item()
            
            if not quiet:
                if i%1000 == 0:
                    print(f'Channel {channel}, Epoch={epoch+1}, batch = {i} of {nbatches}, loss={loss.item():.3f}, LR={scheduler.get_last_lr()[0]}')
        
        scheduler.step()




    return loss_arr, valloss_arr

# %%
'''

AMSR2 CHANNEL PREDICTION MODEL:
    1: Ocean

'''

sfc = [1]

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = np.isin(sfctype, sfc)
    sfcindcs = np.where(correct_sfc)[0]

    Tbs = f.Tbs.values[sfcindcs]

#---Don't shuffle data before splitting
#np.random.seed(40)
#Tbs = array_funcs.shuffle_data(Tbs, axis=0)

if Tbs.shape[0] > 5.0e+06:
    Tbs = Tbs[:5_000_000,:]


print(Tbs.shape)

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train = array_funcs.shuffle_data(Tbs_train, axis=0)
# Out:
# (5000000, 12)

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    print(channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_ocean_no89.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_ocean_no89.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 6V
# Training stage: 1
# Validation Loss = 31840.910
# Channel 6V, Epoch=1, batch = 0 of 4000, loss=28001.924, LR=0.001
# Validation Loss = 0.061
# Channel 6V, Epoch=1, batch = 1000 of 4000, loss=0.624, LR=0.001
# Validation Loss = 0.155
# Channel 6V, Epoch=1, batch = 2000 of 4000, loss=0.389, LR=0.001
# Validation Loss = 0.411
# Channel 6V, Epoch=1, batch = 3000 of 4000, loss=0.332, LR=0.001
# Validation Loss = 4.540
# Channel 6V, Epoch=2, batch = 0 of 4000, loss=3.290, LR=0.0009045084971874737
# Validation Loss = 0.717
# Channel 6V, Epoch=2, batch = 1000 of 4000, loss=0.902, LR=0.0009045084971874737
# Validation Loss = 3.651
# Channel 6V, Epoch=2, batch = 2000 of 4000, loss=2.593, LR=0.0009045084971874737
# Validation Loss = 1.624
# Channel 6V, Epoch=2, batch = 3000 of 4000, loss=1.214, LR=0.0009045084971874737
# Validation Loss = 0.069
# Channel 6V, Epoch=3, batch = 0 of 4000, loss=0.243, LR=0.0006545084971874737
# Validation Loss = 0.061
# Channel 6V, Epoch=3, batch = 1000 of 4000, loss=0.237, LR=0.0006545084971874737
# Validation Loss = 0.000
# Channel 6V, Epoch=3, batch = 2000 of 4000, loss=0.256, LR=0.0006545084971874737
# Validation Loss = 0.418
# Channel 6V, Epoch=3, batch = 3000 of 4000, loss=0.686, LR=0.0006545084971874737
# Validation Loss = 0.031
# Channel 6V, Epoch=4, batch = 0 of 4000, loss=0.286, LR=0.00034549150281252633
# Validation Loss = 0.056
# Channel 6V, Epoch=4, batch = 1000 of 4000, loss=0.219, LR=0.00034549150281252633
# Validation Loss = 0.066
# Channel 6V, Epoch=4, batch = 2000 of 4000, loss=0.372, LR=0.00034549150281252633
# Validation Loss = 0.301
# Channel 6V, Epoch=4, batch = 3000 of 4000, loss=0.503, LR=0.00034549150281252633
# Validation Loss = 0.017
# Channel 6V, Epoch=5, batch = 0 of 4000, loss=0.217, LR=9.549150281252633e-05
# Validation Loss = 0.012
# Channel 6V, Epoch=5, batch = 1000 of 4000, loss=0.217, LR=9.549150281252633e-05
# Validation Loss = 0.001
# Channel 6V, Epoch=5, batch = 2000 of 4000, loss=0.222, LR=9.549150281252633e-05
# Validation Loss = 0.009
# Channel 6V, Epoch=5, batch = 3000 of 4000, loss=0.223, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.015
# Channel 6V, Epoch=1, batch = 0 of 4000, loss=0.205, LR=0.001
# Validation Loss = 0.000
# Channel 6V, Epoch=1, batch = 1000 of 4000, loss=0.230, LR=0.001
# Validation Loss = 0.019
# Channel 6V, Epoch=1, batch = 2000 of 4000, loss=0.209, LR=0.001
# Validation Loss = 0.117
# Channel 6V, Epoch=1, batch = 3000 of 4000, loss=0.395, LR=0.001
# Validation Loss = 1.013
# Channel 6V, Epoch=2, batch = 0 of 4000, loss=1.117, LR=0.0009755282581475768
# Validation Loss = 0.041
# Channel 6V, Epoch=2, batch = 1000 of 4000, loss=0.315, LR=0.0009755282581475768
# Validation Loss = 0.017
# Channel 6V, Epoch=2, batch = 2000 of 4000, loss=0.258, LR=0.0009755282581475768
# Validation Loss = 0.290
# Channel 6V, Epoch=2, batch = 3000 of 4000, loss=0.367, LR=0.0009755282581475768
# Validation Loss = 1.087
# Channel 6V, Epoch=3, batch = 0 of 4000, loss=0.845, LR=0.0009045084971874736
# Validation Loss = 0.811
# Channel 6V, Epoch=3, batch = 1000 of 4000, loss=0.714, LR=0.0009045084971874736
# Validation Loss = 0.176
# Channel 6V, Epoch=3, batch = 2000 of 4000, loss=0.452, LR=0.0009045084971874736
# Validation Loss = 1.592
# Channel 6V, Epoch=3, batch = 3000 of 4000, loss=1.921, LR=0.0009045084971874736
# Validation Loss = 0.019
# Channel 6V, Epoch=4, batch = 0 of 4000, loss=0.219, LR=0.0007938926261462366
# Validation Loss = 0.588
# Channel 6V, Epoch=4, batch = 1000 of 4000, loss=0.567, LR=0.0007938926261462366
# Validation Loss = 0.056
# Channel 6V, Epoch=4, batch = 2000 of 4000, loss=0.234, LR=0.0007938926261462366
# Validation Loss = 0.005
# Channel 6V, Epoch=4, batch = 3000 of 4000, loss=0.248, LR=0.0007938926261462366
# Validation Loss = 0.026
# Channel 6V, Epoch=5, batch = 0 of 4000, loss=0.273, LR=0.0006545084971874737
# Validation Loss = 0.059
# Channel 6V, Epoch=5, batch = 1000 of 4000, loss=0.244, LR=0.0006545084971874737
# Validation Loss = 0.004
# Channel 6V, Epoch=5, batch = 2000 of 4000, loss=0.231, LR=0.0006545084971874737
# Validation Loss = 0.417
# Channel 6V, Epoch=5, batch = 3000 of 4000, loss=0.718, LR=0.0006545084971874737
# Validation Loss = 0.039
# Channel 6V, Epoch=6, batch = 0 of 4000, loss=0.291, LR=0.0005
# Validation Loss = 0.091
# Channel 6V, Epoch=6, batch = 1000 of 4000, loss=0.351, LR=0.0005
# Validation Loss = 0.001
# Channel 6V, Epoch=6, batch = 2000 of 4000, loss=0.192, LR=0.0005
# Validation Loss = 0.150
# Channel 6V, Epoch=6, batch = 3000 of 4000, loss=0.235, LR=0.0005
# Validation Loss = 0.000
# Channel 6V, Epoch=7, batch = 0 of 4000, loss=0.232, LR=0.00034549150281252633
# Validation Loss = 0.202
# Channel 6V, Epoch=7, batch = 1000 of 4000, loss=0.241, LR=0.00034549150281252633
# Validation Loss = 0.123
# Channel 6V, Epoch=7, batch = 2000 of 4000, loss=0.228, LR=0.00034549150281252633
# Validation Loss = 0.079
# Channel 6V, Epoch=7, batch = 3000 of 4000, loss=0.209, LR=0.00034549150281252633
# Validation Loss = 0.031
# Channel 6V, Epoch=8, batch = 0 of 4000, loss=0.367, LR=0.0002061073738537635
# Validation Loss = 0.373
# Channel 6V, Epoch=8, batch = 1000 of 4000, loss=0.291, LR=0.0002061073738537635
# Validation Loss = 0.012
# Channel 6V, Epoch=8, batch = 2000 of 4000, loss=0.252, LR=0.0002061073738537635
# Validation Loss = 0.067
# Channel 6V, Epoch=8, batch = 3000 of 4000, loss=0.204, LR=0.0002061073738537635
# Validation Loss = 0.008
# Channel 6V, Epoch=9, batch = 0 of 4000, loss=0.234, LR=9.549150281252634e-05
# Validation Loss = 0.113
# Channel 6V, Epoch=9, batch = 1000 of 4000, loss=0.204, LR=9.549150281252634e-05
# Validation Loss = 0.182
# Channel 6V, Epoch=9, batch = 2000 of 4000, loss=0.204, LR=9.549150281252634e-05
# Validation Loss = 0.172
# Channel 6V, Epoch=9, batch = 3000 of 4000, loss=0.218, LR=9.549150281252634e-05
# Validation Loss = 0.216
# Channel 6V, Epoch=10, batch = 0 of 4000, loss=0.199, LR=2.4471741852423235e-05
# Validation Loss = 0.121
# Channel 6V, Epoch=10, batch = 1000 of 4000, loss=0.206, LR=2.4471741852423235e-05
# Validation Loss = 0.130
# Channel 6V, Epoch=10, batch = 2000 of 4000, loss=0.204, LR=2.4471741852423235e-05
# Validation Loss = 0.116
# Channel 6V, Epoch=10, batch = 3000 of 4000, loss=0.207, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.185
# Channel 6V, Epoch=1, batch = 0 of 4000, loss=0.218, LR=0.001
# Validation Loss = 0.024
# Channel 6V, Epoch=1, batch = 1000 of 4000, loss=0.221, LR=0.001
# Validation Loss = 0.004
# Channel 6V, Epoch=1, batch = 2000 of 4000, loss=0.231, LR=0.001
# Validation Loss = 0.131
# Channel 6V, Epoch=1, batch = 3000 of 4000, loss=0.280, LR=0.001
# Validation Loss = 0.172
# Channel 6V, Epoch=2, batch = 0 of 4000, loss=0.454, LR=0.0009938441702975688
# Validation Loss = 0.927
# Channel 6V, Epoch=2, batch = 1000 of 4000, loss=1.120, LR=0.0009938441702975688
# Validation Loss = 0.248
# Channel 6V, Epoch=2, batch = 2000 of 4000, loss=0.320, LR=0.0009938441702975688
# Validation Loss = 0.215
# Channel 6V, Epoch=2, batch = 3000 of 4000, loss=0.319, LR=0.0009938441702975688
# Validation Loss = 0.016
# Channel 6V, Epoch=3, batch = 0 of 4000, loss=0.201, LR=0.0009755282581475768
# Validation Loss = 0.883
# Channel 6V, Epoch=3, batch = 1000 of 4000, loss=0.679, LR=0.0009755282581475768
# Validation Loss = 0.132
# Channel 6V, Epoch=3, batch = 2000 of 4000, loss=0.285, LR=0.0009755282581475768
# Validation Loss = 0.070
# Channel 6V, Epoch=3, batch = 3000 of 4000, loss=0.211, LR=0.0009755282581475768
# Validation Loss = 0.001
# Channel 6V, Epoch=4, batch = 0 of 4000, loss=0.215, LR=0.0009455032620941839
# Validation Loss = 0.046
# Channel 6V, Epoch=4, batch = 1000 of 4000, loss=0.204, LR=0.0009455032620941839
# Validation Loss = 0.038
# Channel 6V, Epoch=4, batch = 2000 of 4000, loss=0.308, LR=0.0009455032620941839
# Validation Loss = 1.244
# Channel 6V, Epoch=4, batch = 3000 of 4000, loss=0.937, LR=0.0009455032620941839
# Validation Loss = 0.030
# Channel 6V, Epoch=5, batch = 0 of 4000, loss=0.185, LR=0.0009045084971874737
# Validation Loss = 0.059
# Channel 6V, Epoch=5, batch = 1000 of 4000, loss=0.338, LR=0.0009045084971874737
# Validation Loss = 0.012
# Channel 6V, Epoch=5, batch = 2000 of 4000, loss=0.225, LR=0.0009045084971874737
# Validation Loss = 0.019
# Channel 6V, Epoch=5, batch = 3000 of 4000, loss=0.201, LR=0.0009045084971874737
# Validation Loss = 0.033
# Channel 6V, Epoch=6, batch = 0 of 4000, loss=0.204, LR=0.0008535533905932737
# Validation Loss = 0.004
# Channel 6V, Epoch=6, batch = 1000 of 4000, loss=0.213, LR=0.0008535533905932737
# Validation Loss = 0.047
# Channel 6V, Epoch=6, batch = 2000 of 4000, loss=0.204, LR=0.0008535533905932737
# Validation Loss = 0.000
# Channel 6V, Epoch=6, batch = 3000 of 4000, loss=0.246, LR=0.0008535533905932737
# Validation Loss = 0.082
# Channel 6V, Epoch=7, batch = 0 of 4000, loss=0.387, LR=0.0007938926261462366
# Validation Loss = 0.109
# Channel 6V, Epoch=7, batch = 1000 of 4000, loss=0.197, LR=0.0007938926261462366
# Validation Loss = 0.099
# Channel 6V, Epoch=7, batch = 2000 of 4000, loss=0.218, LR=0.0007938926261462366
# Validation Loss = 0.396
# Channel 6V, Epoch=7, batch = 3000 of 4000, loss=0.322, LR=0.0007938926261462366
# Validation Loss = 1.174
# Channel 6V, Epoch=8, batch = 0 of 4000, loss=0.784, LR=0.0007269952498697733
# Validation Loss = 0.402
# Channel 6V, Epoch=8, batch = 1000 of 4000, loss=0.279, LR=0.0007269952498697733
# Validation Loss = 0.296
# Channel 6V, Epoch=8, batch = 2000 of 4000, loss=0.313, LR=0.0007269952498697733
# Validation Loss = 0.080
# Channel 6V, Epoch=8, batch = 3000 of 4000, loss=0.379, LR=0.0007269952498697733
# Validation Loss = 0.019
# Channel 6V, Epoch=9, batch = 0 of 4000, loss=0.343, LR=0.0006545084971874737
# Validation Loss = 0.004
# Channel 6V, Epoch=9, batch = 1000 of 4000, loss=0.297, LR=0.0006545084971874737
# Validation Loss = 0.012
# Channel 6V, Epoch=9, batch = 2000 of 4000, loss=0.236, LR=0.0006545084971874737
# Validation Loss = 0.070
# Channel 6V, Epoch=9, batch = 3000 of 4000, loss=0.222, LR=0.0006545084971874737
# Validation Loss = 0.000
# Channel 6V, Epoch=10, batch = 0 of 4000, loss=0.259, LR=0.0005782172325201155
# Validation Loss = 0.006
# Channel 6V, Epoch=10, batch = 1000 of 4000, loss=0.241, LR=0.0005782172325201155
# Validation Loss = 0.758
# Channel 6V, Epoch=10, batch = 2000 of 4000, loss=0.505, LR=0.0005782172325201155
# Validation Loss = 0.064
# Channel 6V, Epoch=10, batch = 3000 of 4000, loss=0.194, LR=0.0005782172325201155
# Validation Loss = 0.084
# Channel 6V, Epoch=11, batch = 0 of 4000, loss=0.210, LR=0.0005
# Validation Loss = 0.011
# Channel 6V, Epoch=11, batch = 1000 of 4000, loss=0.324, LR=0.0005
# Validation Loss = 0.222
# Channel 6V, Epoch=11, batch = 2000 of 4000, loss=0.239, LR=0.0005
# Validation Loss = 0.003
# Channel 6V, Epoch=11, batch = 3000 of 4000, loss=0.263, LR=0.0005
# Validation Loss = 0.011
# Channel 6V, Epoch=12, batch = 0 of 4000, loss=0.261, LR=0.0004217827674798847
# Validation Loss = 0.000
# Channel 6V, Epoch=12, batch = 1000 of 4000, loss=0.309, LR=0.0004217827674798847
# Validation Loss = 0.065
# Channel 6V, Epoch=12, batch = 2000 of 4000, loss=0.219, LR=0.0004217827674798847
# Validation Loss = 0.140
# Channel 6V, Epoch=12, batch = 3000 of 4000, loss=0.203, LR=0.0004217827674798847
# Validation Loss = 0.004
# Channel 6V, Epoch=13, batch = 0 of 4000, loss=0.240, LR=0.00034549150281252633
# Validation Loss = 0.000
# Channel 6V, Epoch=13, batch = 1000 of 4000, loss=0.277, LR=0.00034549150281252633
# Validation Loss = 0.011
# Channel 6V, Epoch=13, batch = 2000 of 4000, loss=0.259, LR=0.00034549150281252633
# Validation Loss = 0.049
# Channel 6V, Epoch=13, batch = 3000 of 4000, loss=0.240, LR=0.00034549150281252633
# Validation Loss = 0.099
# Channel 6V, Epoch=14, batch = 0 of 4000, loss=0.195, LR=0.00027300475013022663
# Validation Loss = 0.121
# Channel 6V, Epoch=14, batch = 1000 of 4000, loss=0.209, LR=0.00027300475013022663
# Validation Loss = 0.297
# Channel 6V, Epoch=14, batch = 2000 of 4000, loss=0.234, LR=0.00027300475013022663
# Validation Loss = 0.098
# Channel 6V, Epoch=14, batch = 3000 of 4000, loss=0.221, LR=0.00027300475013022663
# Validation Loss = 0.168
# Channel 6V, Epoch=15, batch = 0 of 4000, loss=0.195, LR=0.00020610737385376348
# Validation Loss = 0.032
# Channel 6V, Epoch=15, batch = 1000 of 4000, loss=0.246, LR=0.00020610737385376348
# Validation Loss = 0.294
# Channel 6V, Epoch=15, batch = 2000 of 4000, loss=0.209, LR=0.00020610737385376348
# Validation Loss = 0.152
# Channel 6V, Epoch=15, batch = 3000 of 4000, loss=0.207, LR=0.00020610737385376348
# Validation Loss = 0.170
# Channel 6V, Epoch=16, batch = 0 of 4000, loss=0.198, LR=0.00014644660940672625
# Validation Loss = 0.181
# Channel 6V, Epoch=16, batch = 1000 of 4000, loss=0.218, LR=0.00014644660940672625
# Validation Loss = 0.268
# Channel 6V, Epoch=16, batch = 2000 of 4000, loss=0.202, LR=0.00014644660940672625
# Validation Loss = 0.125
# Channel 6V, Epoch=16, batch = 3000 of 4000, loss=0.200, LR=0.00014644660940672625
# Validation Loss = 0.057
# Channel 6V, Epoch=17, batch = 0 of 4000, loss=0.212, LR=9.549150281252631e-05
# Validation Loss = 0.211
# Channel 6V, Epoch=17, batch = 1000 of 4000, loss=0.195, LR=9.549150281252631e-05
# Validation Loss = 0.183
# Channel 6V, Epoch=17, batch = 2000 of 4000, loss=0.192, LR=9.549150281252631e-05
# Validation Loss = 0.164
# Channel 6V, Epoch=17, batch = 3000 of 4000, loss=0.207, LR=9.549150281252631e-05
# Validation Loss = 0.136
# Channel 6V, Epoch=18, batch = 0 of 4000, loss=0.205, LR=5.4496737905816096e-05
# Validation Loss = 0.177
# Channel 6V, Epoch=18, batch = 1000 of 4000, loss=0.197, LR=5.4496737905816096e-05
# Validation Loss = 0.105
# Channel 6V, Epoch=18, batch = 2000 of 4000, loss=0.220, LR=5.4496737905816096e-05
# Validation Loss = 0.108
# Channel 6V, Epoch=18, batch = 3000 of 4000, loss=0.191, LR=5.4496737905816096e-05
# Validation Loss = 0.187
# Channel 6V, Epoch=19, batch = 0 of 4000, loss=0.213, LR=2.447174185242323e-05
# Validation Loss = 0.151
# Channel 6V, Epoch=19, batch = 1000 of 4000, loss=0.187, LR=2.447174185242323e-05
# Validation Loss = 0.153
# Channel 6V, Epoch=19, batch = 2000 of 4000, loss=0.189, LR=2.447174185242323e-05
# Validation Loss = 0.164
# Channel 6V, Epoch=19, batch = 3000 of 4000, loss=0.208, LR=2.447174185242323e-05
# Validation Loss = 0.141
# Channel 6V, Epoch=20, batch = 0 of 4000, loss=0.201, LR=6.15582970243117e-06
# Validation Loss = 0.178
# Channel 6V, Epoch=20, batch = 1000 of 4000, loss=0.213, LR=6.15582970243117e-06
# Validation Loss = 0.181
# Channel 6V, Epoch=20, batch = 2000 of 4000, loss=0.196, LR=6.15582970243117e-06
# Validation Loss = 0.161
# Channel 6V, Epoch=20, batch = 3000 of 4000, loss=0.207, LR=6.15582970243117e-06
# Finished training model for channel 6V.
# 6H
# Training stage: 1
# Validation Loss = 7227.785
# Channel 6H, Epoch=1, batch = 0 of 4000, loss=5268.374, LR=0.001
# Validation Loss = 0.001
# Channel 6H, Epoch=1, batch = 1000 of 4000, loss=0.642, LR=0.001
# Validation Loss = 2.170
# Channel 6H, Epoch=1, batch = 2000 of 4000, loss=0.449, LR=0.001
# Validation Loss = 0.776
# Channel 6H, Epoch=1, batch = 3000 of 4000, loss=0.265, LR=0.001
# Validation Loss = 0.313
# Channel 6H, Epoch=2, batch = 0 of 4000, loss=0.888, LR=0.0009045084971874737
# Validation Loss = 5.829
# Channel 6H, Epoch=2, batch = 1000 of 4000, loss=1.654, LR=0.0009045084971874737
# Validation Loss = 1.878
# Channel 6H, Epoch=2, batch = 2000 of 4000, loss=0.389, LR=0.0009045084971874737
# Validation Loss = 0.954
# Channel 6H, Epoch=2, batch = 3000 of 4000, loss=0.390, LR=0.0009045084971874737
# Validation Loss = 0.013
# Channel 6H, Epoch=3, batch = 0 of 4000, loss=0.434, LR=0.0006545084971874737
# Validation Loss = 0.005
# Channel 6H, Epoch=3, batch = 1000 of 4000, loss=0.183, LR=0.0006545084971874737
# Validation Loss = 0.067
# Channel 6H, Epoch=3, batch = 2000 of 4000, loss=0.306, LR=0.0006545084971874737
# Validation Loss = 0.028
# Channel 6H, Epoch=3, batch = 3000 of 4000, loss=0.189, LR=0.0006545084971874737
# Validation Loss = 0.005
# Channel 6H, Epoch=4, batch = 0 of 4000, loss=0.176, LR=0.00034549150281252633
# Validation Loss = 0.000
# Channel 6H, Epoch=4, batch = 1000 of 4000, loss=0.131, LR=0.00034549150281252633
# Validation Loss = 0.045
# Channel 6H, Epoch=4, batch = 2000 of 4000, loss=0.190, LR=0.00034549150281252633
# Validation Loss = 0.034
# Channel 6H, Epoch=4, batch = 3000 of 4000, loss=0.207, LR=0.00034549150281252633
# Validation Loss = 0.049
# Channel 6H, Epoch=5, batch = 0 of 4000, loss=0.137, LR=9.549150281252633e-05
# Validation Loss = 0.062
# Channel 6H, Epoch=5, batch = 1000 of 4000, loss=0.142, LR=9.549150281252633e-05
# Validation Loss = 0.070
# Channel 6H, Epoch=5, batch = 2000 of 4000, loss=0.155, LR=9.549150281252633e-05
# Validation Loss = 0.034
# Channel 6H, Epoch=5, batch = 3000 of 4000, loss=0.136, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.076
# Channel 6H, Epoch=1, batch = 0 of 4000, loss=0.155, LR=0.001
# Validation Loss = 0.037
# Channel 6H, Epoch=1, batch = 1000 of 4000, loss=0.151, LR=0.001
# Validation Loss = 1.427
# Channel 6H, Epoch=1, batch = 2000 of 4000, loss=0.876, LR=0.001
# Validation Loss = 0.456
# Channel 6H, Epoch=1, batch = 3000 of 4000, loss=0.472, LR=0.001
# Validation Loss = 0.021
# Channel 6H, Epoch=2, batch = 0 of 4000, loss=0.152, LR=0.0009755282581475768
# Validation Loss = 0.109
# Channel 6H, Epoch=2, batch = 1000 of 4000, loss=0.323, LR=0.0009755282581475768
# Validation Loss = 0.416
# Channel 6H, Epoch=2, batch = 2000 of 4000, loss=0.305, LR=0.0009755282581475768
# Validation Loss = 0.061
# Channel 6H, Epoch=2, batch = 3000 of 4000, loss=0.246, LR=0.0009755282581475768
# Validation Loss = 0.196
# Channel 6H, Epoch=3, batch = 0 of 4000, loss=0.273, LR=0.0009045084971874736
# Validation Loss = 0.632
# Channel 6H, Epoch=3, batch = 1000 of 4000, loss=0.410, LR=0.0009045084971874736
# Validation Loss = 0.023
# Channel 6H, Epoch=3, batch = 2000 of 4000, loss=0.153, LR=0.0009045084971874736
# Validation Loss = 0.348
# Channel 6H, Epoch=3, batch = 3000 of 4000, loss=0.360, LR=0.0009045084971874736
# Validation Loss = 0.017
# Channel 6H, Epoch=4, batch = 0 of 4000, loss=0.134, LR=0.0007938926261462366
# Validation Loss = 0.039
# Channel 6H, Epoch=4, batch = 1000 of 4000, loss=0.208, LR=0.0007938926261462366
# Validation Loss = 0.266
# Channel 6H, Epoch=4, batch = 2000 of 4000, loss=0.382, LR=0.0007938926261462366
# Validation Loss = 0.005
# Channel 6H, Epoch=4, batch = 3000 of 4000, loss=0.162, LR=0.0007938926261462366
# Validation Loss = 0.001
# Channel 6H, Epoch=5, batch = 0 of 4000, loss=0.149, LR=0.0006545084971874737
# Validation Loss = 0.036
# Channel 6H, Epoch=5, batch = 1000 of 4000, loss=0.211, LR=0.0006545084971874737
# Validation Loss = 0.032
# Channel 6H, Epoch=5, batch = 2000 of 4000, loss=0.157, LR=0.0006545084971874737
# Validation Loss = 0.043
# Channel 6H, Epoch=5, batch = 3000 of 4000, loss=0.146, LR=0.0006545084971874737
# Validation Loss = 0.069
# Channel 6H, Epoch=6, batch = 0 of 4000, loss=0.184, LR=0.0005
# Validation Loss = 0.001
# Channel 6H, Epoch=6, batch = 1000 of 4000, loss=0.177, LR=0.0005
# Validation Loss = 0.035
# Channel 6H, Epoch=6, batch = 2000 of 4000, loss=0.154, LR=0.0005
# Validation Loss = 0.019
# Channel 6H, Epoch=6, batch = 3000 of 4000, loss=0.164, LR=0.0005
# Validation Loss = 0.011
# Channel 6H, Epoch=7, batch = 0 of 4000, loss=0.175, LR=0.00034549150281252633
# Validation Loss = 0.042
# Channel 6H, Epoch=7, batch = 1000 of 4000, loss=0.147, LR=0.00034549150281252633
# Validation Loss = 0.001
# Channel 6H, Epoch=7, batch = 2000 of 4000, loss=0.152, LR=0.00034549150281252633
# Validation Loss = 0.219
# Channel 6H, Epoch=7, batch = 3000 of 4000, loss=0.204, LR=0.00034549150281252633
# Validation Loss = 0.027
# Channel 6H, Epoch=8, batch = 0 of 4000, loss=0.145, LR=0.0002061073738537635
# Validation Loss = 0.013
# Channel 6H, Epoch=8, batch = 1000 of 4000, loss=0.136, LR=0.0002061073738537635
# Validation Loss = 0.165
# Channel 6H, Epoch=8, batch = 2000 of 4000, loss=0.187, LR=0.0002061073738537635
# Validation Loss = 0.000
# Channel 6H, Epoch=8, batch = 3000 of 4000, loss=0.152, LR=0.0002061073738537635
# Validation Loss = 0.085
# Channel 6H, Epoch=9, batch = 0 of 4000, loss=0.153, LR=9.549150281252634e-05
# Validation Loss = 0.001
# Channel 6H, Epoch=9, batch = 1000 of 4000, loss=0.178, LR=9.549150281252634e-05
# Validation Loss = 0.007
# Channel 6H, Epoch=9, batch = 2000 of 4000, loss=0.151, LR=9.549150281252634e-05
# Validation Loss = 0.025
# Channel 6H, Epoch=9, batch = 3000 of 4000, loss=0.133, LR=9.549150281252634e-05
# Validation Loss = 0.003
# Channel 6H, Epoch=10, batch = 0 of 4000, loss=0.161, LR=2.4471741852423235e-05
# Validation Loss = 0.029
# Channel 6H, Epoch=10, batch = 1000 of 4000, loss=0.145, LR=2.4471741852423235e-05
# Validation Loss = 0.026
# Channel 6H, Epoch=10, batch = 2000 of 4000, loss=0.134, LR=2.4471741852423235e-05
# Validation Loss = 0.010
# Channel 6H, Epoch=10, batch = 3000 of 4000, loss=0.151, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.014
# Channel 6H, Epoch=1, batch = 0 of 4000, loss=0.140, LR=0.001
# Validation Loss = 0.001
# Channel 6H, Epoch=1, batch = 1000 of 4000, loss=0.142, LR=0.001
# Validation Loss = 0.026
# Channel 6H, Epoch=1, batch = 2000 of 4000, loss=0.208, LR=0.001
# Validation Loss = 0.033
# Channel 6H, Epoch=1, batch = 3000 of 4000, loss=0.125, LR=0.001
# Validation Loss = 0.445
# Channel 6H, Epoch=2, batch = 0 of 4000, loss=0.599, LR=0.0009938441702975688
# Validation Loss = 0.009
# Channel 6H, Epoch=2, batch = 1000 of 4000, loss=0.166, LR=0.0009938441702975688
# Validation Loss = 0.025
# Channel 6H, Epoch=2, batch = 2000 of 4000, loss=0.163, LR=0.0009938441702975688
# Validation Loss = 0.264
# Channel 6H, Epoch=2, batch = 3000 of 4000, loss=0.402, LR=0.0009938441702975688
# Validation Loss = 0.196
# Channel 6H, Epoch=3, batch = 0 of 4000, loss=0.179, LR=0.0009755282581475768
# Validation Loss = 0.246
# Channel 6H, Epoch=3, batch = 1000 of 4000, loss=0.244, LR=0.0009755282581475768
# Validation Loss = 0.023
# Channel 6H, Epoch=3, batch = 2000 of 4000, loss=0.212, LR=0.0009755282581475768
# Validation Loss = 0.113
# Channel 6H, Epoch=3, batch = 3000 of 4000, loss=0.137, LR=0.0009755282581475768
# Validation Loss = 0.204
# Channel 6H, Epoch=4, batch = 0 of 4000, loss=0.205, LR=0.0009455032620941839
# Validation Loss = 1.136
# Channel 6H, Epoch=4, batch = 1000 of 4000, loss=0.551, LR=0.0009455032620941839
# Validation Loss = 1.451
# Channel 6H, Epoch=4, batch = 2000 of 4000, loss=1.580, LR=0.0009455032620941839
# Validation Loss = 0.002
# Channel 6H, Epoch=4, batch = 3000 of 4000, loss=0.210, LR=0.0009455032620941839
# Validation Loss = 0.011
# Channel 6H, Epoch=5, batch = 0 of 4000, loss=0.198, LR=0.0009045084971874737
# Validation Loss = 0.001
# Channel 6H, Epoch=5, batch = 1000 of 4000, loss=0.237, LR=0.0009045084971874737
# Validation Loss = 0.264
# Channel 6H, Epoch=5, batch = 2000 of 4000, loss=0.247, LR=0.0009045084971874737
# Validation Loss = 0.193
# Channel 6H, Epoch=5, batch = 3000 of 4000, loss=0.147, LR=0.0009045084971874737
# Validation Loss = 0.217
# Channel 6H, Epoch=6, batch = 0 of 4000, loss=0.166, LR=0.0008535533905932737
# Validation Loss = 0.088
# Channel 6H, Epoch=6, batch = 1000 of 4000, loss=0.149, LR=0.0008535533905932737
# Validation Loss = 0.006
# Channel 6H, Epoch=6, batch = 2000 of 4000, loss=0.194, LR=0.0008535533905932737
# Validation Loss = 0.000
# Channel 6H, Epoch=6, batch = 3000 of 4000, loss=0.145, LR=0.0008535533905932737
# Validation Loss = 0.161
# Channel 6H, Epoch=7, batch = 0 of 4000, loss=0.382, LR=0.0007938926261462366
# Validation Loss = 0.031
# Channel 6H, Epoch=7, batch = 1000 of 4000, loss=0.133, LR=0.0007938926261462366
# Validation Loss = 0.169
# Channel 6H, Epoch=7, batch = 2000 of 4000, loss=0.150, LR=0.0007938926261462366
# Validation Loss = 0.023
# Channel 6H, Epoch=7, batch = 3000 of 4000, loss=0.147, LR=0.0007938926261462366
# Validation Loss = 0.113
# Channel 6H, Epoch=8, batch = 0 of 4000, loss=0.179, LR=0.0007269952498697733
# Validation Loss = 0.130
# Channel 6H, Epoch=8, batch = 1000 of 4000, loss=0.168, LR=0.0007269952498697733
# Validation Loss = 0.092
# Channel 6H, Epoch=8, batch = 2000 of 4000, loss=0.286, LR=0.0007269952498697733
# Validation Loss = 0.050
# Channel 6H, Epoch=8, batch = 3000 of 4000, loss=0.180, LR=0.0007269952498697733
# Validation Loss = 0.176
# Channel 6H, Epoch=9, batch = 0 of 4000, loss=0.159, LR=0.0006545084971874737
# Validation Loss = 0.071
# Channel 6H, Epoch=9, batch = 1000 of 4000, loss=0.151, LR=0.0006545084971874737
# Validation Loss = 0.042
# Channel 6H, Epoch=9, batch = 2000 of 4000, loss=0.129, LR=0.0006545084971874737
# Validation Loss = 0.001
# Channel 6H, Epoch=9, batch = 3000 of 4000, loss=0.209, LR=0.0006545084971874737
# Validation Loss = 0.002
# Channel 6H, Epoch=10, batch = 0 of 4000, loss=0.166, LR=0.0005782172325201155
# Validation Loss = 0.111
# Channel 6H, Epoch=10, batch = 1000 of 4000, loss=0.165, LR=0.0005782172325201155
# Validation Loss = 0.199
# Channel 6H, Epoch=10, batch = 2000 of 4000, loss=0.187, LR=0.0005782172325201155
# Validation Loss = 0.023
# Channel 6H, Epoch=10, batch = 3000 of 4000, loss=0.148, LR=0.0005782172325201155
# Validation Loss = 0.122
# Channel 6H, Epoch=11, batch = 0 of 4000, loss=0.281, LR=0.0005
# Validation Loss = 0.009
# Channel 6H, Epoch=11, batch = 1000 of 4000, loss=0.141, LR=0.0005
# Validation Loss = 0.007
# Channel 6H, Epoch=11, batch = 2000 of 4000, loss=0.151, LR=0.0005
# Validation Loss = 0.211
# Channel 6H, Epoch=11, batch = 3000 of 4000, loss=0.184, LR=0.0005
# Validation Loss = 0.017
# Channel 6H, Epoch=12, batch = 0 of 4000, loss=0.186, LR=0.0004217827674798847
# Validation Loss = 0.000
# Channel 6H, Epoch=12, batch = 1000 of 4000, loss=0.166, LR=0.0004217827674798847
# Validation Loss = 0.042
# Channel 6H, Epoch=12, batch = 2000 of 4000, loss=0.134, LR=0.0004217827674798847
# Validation Loss = 0.000
# Channel 6H, Epoch=12, batch = 3000 of 4000, loss=0.161, LR=0.0004217827674798847
# Validation Loss = 0.033
# Channel 6H, Epoch=13, batch = 0 of 4000, loss=0.233, LR=0.00034549150281252633
# Validation Loss = 0.061
# Channel 6H, Epoch=13, batch = 1000 of 4000, loss=0.147, LR=0.00034549150281252633
# Validation Loss = 0.126
# Channel 6H, Epoch=13, batch = 2000 of 4000, loss=0.170, LR=0.00034549150281252633
# Validation Loss = 0.058
# Channel 6H, Epoch=13, batch = 3000 of 4000, loss=0.142, LR=0.00034549150281252633
# Validation Loss = 0.015
# Channel 6H, Epoch=14, batch = 0 of 4000, loss=0.145, LR=0.00027300475013022663
# Validation Loss = 0.000
# Channel 6H, Epoch=14, batch = 1000 of 4000, loss=0.151, LR=0.00027300475013022663
# Validation Loss = 0.034
# Channel 6H, Epoch=14, batch = 2000 of 4000, loss=0.126, LR=0.00027300475013022663
# Validation Loss = 0.004
# Channel 6H, Epoch=14, batch = 3000 of 4000, loss=0.162, LR=0.00027300475013022663
# Validation Loss = 0.179
# Channel 6H, Epoch=15, batch = 0 of 4000, loss=0.171, LR=0.00020610737385376348
# Validation Loss = 0.037
# Channel 6H, Epoch=15, batch = 1000 of 4000, loss=0.150, LR=0.00020610737385376348
# Validation Loss = 0.023
# Channel 6H, Epoch=15, batch = 2000 of 4000, loss=0.150, LR=0.00020610737385376348
# Validation Loss = 0.067
# Channel 6H, Epoch=15, batch = 3000 of 4000, loss=0.139, LR=0.00020610737385376348
# Validation Loss = 0.012
# Channel 6H, Epoch=16, batch = 0 of 4000, loss=0.154, LR=0.00014644660940672625
# Validation Loss = 0.030
# Channel 6H, Epoch=16, batch = 1000 of 4000, loss=0.137, LR=0.00014644660940672625
# Validation Loss = 0.012
# Channel 6H, Epoch=16, batch = 2000 of 4000, loss=0.151, LR=0.00014644660940672625
# Validation Loss = 0.060
# Channel 6H, Epoch=16, batch = 3000 of 4000, loss=0.135, LR=0.00014644660940672625
# Validation Loss = 0.023
# Channel 6H, Epoch=17, batch = 0 of 4000, loss=0.144, LR=9.549150281252631e-05
# Validation Loss = 0.058
# Channel 6H, Epoch=17, batch = 1000 of 4000, loss=0.123, LR=9.549150281252631e-05
# Validation Loss = 0.045
# Channel 6H, Epoch=17, batch = 2000 of 4000, loss=0.134, LR=9.549150281252631e-05
# Validation Loss = 0.066
# Channel 6H, Epoch=17, batch = 3000 of 4000, loss=0.144, LR=9.549150281252631e-05
# Validation Loss = 0.036
# Channel 6H, Epoch=18, batch = 0 of 4000, loss=0.136, LR=5.4496737905816096e-05
# Validation Loss = 0.013
# Channel 6H, Epoch=18, batch = 1000 of 4000, loss=0.146, LR=5.4496737905816096e-05
# Validation Loss = 0.042
# Channel 6H, Epoch=18, batch = 2000 of 4000, loss=0.174, LR=5.4496737905816096e-05
# Validation Loss = 0.036
# Channel 6H, Epoch=18, batch = 3000 of 4000, loss=0.141, LR=5.4496737905816096e-05
# Validation Loss = 0.007
# Channel 6H, Epoch=19, batch = 0 of 4000, loss=0.139, LR=2.447174185242323e-05
# Validation Loss = 0.064
# Channel 6H, Epoch=19, batch = 1000 of 4000, loss=0.118, LR=2.447174185242323e-05
# Validation Loss = 0.022
# Channel 6H, Epoch=19, batch = 2000 of 4000, loss=0.152, LR=2.447174185242323e-05
# Validation Loss = 0.077
# Channel 6H, Epoch=19, batch = 3000 of 4000, loss=0.127, LR=2.447174185242323e-05
# Validation Loss = 0.084
# Channel 6H, Epoch=20, batch = 0 of 4000, loss=0.143, LR=6.15582970243117e-06
# Validation Loss = 0.039
# Channel 6H, Epoch=20, batch = 1000 of 4000, loss=0.126, LR=6.15582970243117e-06
# Validation Loss = 0.043
# Channel 6H, Epoch=20, batch = 2000 of 4000, loss=0.135, LR=6.15582970243117e-06
# Validation Loss = 0.033
# Channel 6H, Epoch=20, batch = 3000 of 4000, loss=0.149, LR=6.15582970243117e-06
# Finished training model for channel 6H.
# 7V
# Training stage: 1
# Validation Loss = 30217.666
# Channel 7V, Epoch=1, batch = 0 of 4000, loss=26590.885, LR=0.001
# Validation Loss = 0.067
# Channel 7V, Epoch=1, batch = 1000 of 4000, loss=0.472, LR=0.001
# Validation Loss = 0.054
# Channel 7V, Epoch=1, batch = 2000 of 4000, loss=0.455, LR=0.001
# Validation Loss = 0.033
# Channel 7V, Epoch=1, batch = 3000 of 4000, loss=0.402, LR=0.001
# Validation Loss = 0.126
# Channel 7V, Epoch=2, batch = 0 of 4000, loss=0.324, LR=0.0009045084971874737
# Validation Loss = 0.000
# Channel 7V, Epoch=2, batch = 1000 of 4000, loss=0.317, LR=0.0009045084971874737
# Validation Loss = 0.045
# Channel 7V, Epoch=2, batch = 2000 of 4000, loss=0.281, LR=0.0009045084971874737
# Validation Loss = 0.071
# Channel 7V, Epoch=2, batch = 3000 of 4000, loss=0.520, LR=0.0009045084971874737
# Validation Loss = 0.240
# Channel 7V, Epoch=3, batch = 0 of 4000, loss=0.272, LR=0.0006545084971874737
# Validation Loss = 2.910
# Channel 7V, Epoch=3, batch = 1000 of 4000, loss=1.426, LR=0.0006545084971874737
# Validation Loss = 1.431
# Channel 7V, Epoch=3, batch = 2000 of 4000, loss=0.726, LR=0.0006545084971874737
# Validation Loss = 0.492
# Channel 7V, Epoch=3, batch = 3000 of 4000, loss=0.281, LR=0.0006545084971874737
# Validation Loss = 0.000
# Channel 7V, Epoch=4, batch = 0 of 4000, loss=0.336, LR=0.00034549150281252633
# Validation Loss = 0.221
# Channel 7V, Epoch=4, batch = 1000 of 4000, loss=0.210, LR=0.00034549150281252633
# Validation Loss = 0.703
# Channel 7V, Epoch=4, batch = 2000 of 4000, loss=0.268, LR=0.00034549150281252633
# Validation Loss = 0.519
# Channel 7V, Epoch=4, batch = 3000 of 4000, loss=0.258, LR=0.00034549150281252633
# Validation Loss = 0.048
# Channel 7V, Epoch=5, batch = 0 of 4000, loss=0.234, LR=9.549150281252633e-05
# Validation Loss = 0.273
# Channel 7V, Epoch=5, batch = 1000 of 4000, loss=0.214, LR=9.549150281252633e-05
# Validation Loss = 0.239
# Channel 7V, Epoch=5, batch = 2000 of 4000, loss=0.231, LR=9.549150281252633e-05
# Validation Loss = 0.096
# Channel 7V, Epoch=5, batch = 3000 of 4000, loss=0.213, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.001
# Channel 7V, Epoch=1, batch = 0 of 4000, loss=0.272, LR=0.001
# Validation Loss = 0.272
# Channel 7V, Epoch=1, batch = 1000 of 4000, loss=0.223, LR=0.001
# Validation Loss = 0.002
# Channel 7V, Epoch=1, batch = 2000 of 4000, loss=0.370, LR=0.001
# Validation Loss = 0.911
# Channel 7V, Epoch=1, batch = 3000 of 4000, loss=1.832, LR=0.001
# Validation Loss = 0.079
# Channel 7V, Epoch=2, batch = 0 of 4000, loss=0.270, LR=0.0009755282581475768
# Validation Loss = 0.117
# Channel 7V, Epoch=2, batch = 1000 of 4000, loss=0.227, LR=0.0009755282581475768
# Validation Loss = 0.834
# Channel 7V, Epoch=2, batch = 2000 of 4000, loss=0.324, LR=0.0009755282581475768
# Validation Loss = 6.331
# Channel 7V, Epoch=2, batch = 3000 of 4000, loss=6.689, LR=0.0009755282581475768
# Validation Loss = 0.258
# Channel 7V, Epoch=3, batch = 0 of 4000, loss=0.194, LR=0.0009045084971874736
# Validation Loss = 1.550
# Channel 7V, Epoch=3, batch = 1000 of 4000, loss=0.708, LR=0.0009045084971874736
# Validation Loss = 0.083
# Channel 7V, Epoch=3, batch = 2000 of 4000, loss=0.228, LR=0.0009045084971874736
# Validation Loss = 0.027
# Channel 7V, Epoch=3, batch = 3000 of 4000, loss=0.638, LR=0.0009045084971874736
# Validation Loss = 0.303
# Channel 7V, Epoch=4, batch = 0 of 4000, loss=1.043, LR=0.0007938926261462366
# Validation Loss = 0.017
# Channel 7V, Epoch=4, batch = 1000 of 4000, loss=0.483, LR=0.0007938926261462366
# Validation Loss = 0.369
# Channel 7V, Epoch=4, batch = 2000 of 4000, loss=0.202, LR=0.0007938926261462366
# Validation Loss = 0.097
# Channel 7V, Epoch=4, batch = 3000 of 4000, loss=0.668, LR=0.0007938926261462366
# Validation Loss = 0.301
# Channel 7V, Epoch=5, batch = 0 of 4000, loss=0.211, LR=0.0006545084971874737
# Validation Loss = 0.216
# Channel 7V, Epoch=5, batch = 1000 of 4000, loss=0.190, LR=0.0006545084971874737
# Validation Loss = 0.331
# Channel 7V, Epoch=5, batch = 2000 of 4000, loss=0.217, LR=0.0006545084971874737
# Validation Loss = 0.102
# Channel 7V, Epoch=5, batch = 3000 of 4000, loss=0.241, LR=0.0006545084971874737
# Validation Loss = 0.072
# Channel 7V, Epoch=6, batch = 0 of 4000, loss=0.236, LR=0.0005
# Validation Loss = 0.008
# Channel 7V, Epoch=6, batch = 1000 of 4000, loss=0.335, LR=0.0005
# Validation Loss = 0.840
# Channel 7V, Epoch=6, batch = 2000 of 4000, loss=0.356, LR=0.0005
# Validation Loss = 0.406
# Channel 7V, Epoch=6, batch = 3000 of 4000, loss=0.218, LR=0.0005
# Validation Loss = 0.170
# Channel 7V, Epoch=7, batch = 0 of 4000, loss=0.219, LR=0.00034549150281252633
# Validation Loss = 0.164
# Channel 7V, Epoch=7, batch = 1000 of 4000, loss=0.203, LR=0.00034549150281252633
# Validation Loss = 1.154
# Channel 7V, Epoch=7, batch = 2000 of 4000, loss=0.532, LR=0.00034549150281252633
# Validation Loss = 0.248
# Channel 7V, Epoch=7, batch = 3000 of 4000, loss=0.210, LR=0.00034549150281252633
# Validation Loss = 0.339
# Channel 7V, Epoch=8, batch = 0 of 4000, loss=0.222, LR=0.0002061073738537635
# Validation Loss = 0.370
# Channel 7V, Epoch=8, batch = 1000 of 4000, loss=0.197, LR=0.0002061073738537635
# Validation Loss = 0.571
# Channel 7V, Epoch=8, batch = 2000 of 4000, loss=0.250, LR=0.0002061073738537635
# Validation Loss = 0.325
# Channel 7V, Epoch=8, batch = 3000 of 4000, loss=0.199, LR=0.0002061073738537635
# Validation Loss = 0.071
# Channel 7V, Epoch=9, batch = 0 of 4000, loss=0.221, LR=9.549150281252634e-05
# Validation Loss = 0.279
# Channel 7V, Epoch=9, batch = 1000 of 4000, loss=0.202, LR=9.549150281252634e-05
# Validation Loss = 0.259
# Channel 7V, Epoch=9, batch = 2000 of 4000, loss=0.204, LR=9.549150281252634e-05
# Validation Loss = 0.178
# Channel 7V, Epoch=9, batch = 3000 of 4000, loss=0.200, LR=9.549150281252634e-05
# Validation Loss = 0.145
# Channel 7V, Epoch=10, batch = 0 of 4000, loss=0.208, LR=2.4471741852423235e-05
# Validation Loss = 0.246
# Channel 7V, Epoch=10, batch = 1000 of 4000, loss=0.179, LR=2.4471741852423235e-05
# Validation Loss = 0.163
# Channel 7V, Epoch=10, batch = 2000 of 4000, loss=0.184, LR=2.4471741852423235e-05
# Validation Loss = 0.180
# Channel 7V, Epoch=10, batch = 3000 of 4000, loss=0.195, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.144
# Channel 7V, Epoch=1, batch = 0 of 4000, loss=0.200, LR=0.001
# Validation Loss = 0.135
# Channel 7V, Epoch=1, batch = 1000 of 4000, loss=0.212, LR=0.001
# Validation Loss = 2.243
# Channel 7V, Epoch=1, batch = 2000 of 4000, loss=1.159, LR=0.001
# Validation Loss = 0.038
# Channel 7V, Epoch=1, batch = 3000 of 4000, loss=0.348, LR=0.001
# Validation Loss = 0.486
# Channel 7V, Epoch=2, batch = 0 of 4000, loss=0.210, LR=0.0009938441702975688
# Validation Loss = 0.908
# Channel 7V, Epoch=2, batch = 1000 of 4000, loss=0.374, LR=0.0009938441702975688
# Validation Loss = 1.256
# Channel 7V, Epoch=2, batch = 2000 of 4000, loss=0.390, LR=0.0009938441702975688
# Validation Loss = 1.169
# Channel 7V, Epoch=2, batch = 3000 of 4000, loss=0.320, LR=0.0009938441702975688
# Validation Loss = 0.000
# Channel 7V, Epoch=3, batch = 0 of 4000, loss=0.466, LR=0.0009755282581475768
# Validation Loss = 1.512
# Channel 7V, Epoch=3, batch = 1000 of 4000, loss=0.611, LR=0.0009755282581475768
# Validation Loss = 0.217
# Channel 7V, Epoch=3, batch = 2000 of 4000, loss=0.903, LR=0.0009755282581475768
# Validation Loss = 3.157
# Channel 7V, Epoch=3, batch = 3000 of 4000, loss=1.259, LR=0.0009755282581475768
# Validation Loss = 1.719
# Channel 7V, Epoch=4, batch = 0 of 4000, loss=0.733, LR=0.0009455032620941839
# Validation Loss = 0.045
# Channel 7V, Epoch=4, batch = 1000 of 4000, loss=0.209, LR=0.0009455032620941839
# Validation Loss = 1.222
# Channel 7V, Epoch=4, batch = 2000 of 4000, loss=0.322, LR=0.0009455032620941839
# Validation Loss = 0.150
# Channel 7V, Epoch=4, batch = 3000 of 4000, loss=0.240, LR=0.0009455032620941839
# Validation Loss = 0.305
# Channel 7V, Epoch=5, batch = 0 of 4000, loss=0.854, LR=0.0009045084971874737
# Validation Loss = 0.365
# Channel 7V, Epoch=5, batch = 1000 of 4000, loss=0.209, LR=0.0009045084971874737
# Validation Loss = 1.608
# Channel 7V, Epoch=5, batch = 2000 of 4000, loss=0.680, LR=0.0009045084971874737
# Validation Loss = 0.124
# Channel 7V, Epoch=5, batch = 3000 of 4000, loss=0.244, LR=0.0009045084971874737
# Validation Loss = 0.000
# Channel 7V, Epoch=6, batch = 0 of 4000, loss=0.402, LR=0.0008535533905932737
# Validation Loss = 0.016
# Channel 7V, Epoch=6, batch = 1000 of 4000, loss=0.335, LR=0.0008535533905932737
# Validation Loss = 0.078
# Channel 7V, Epoch=6, batch = 2000 of 4000, loss=0.252, LR=0.0008535533905932737
# Validation Loss = 0.016
# Channel 7V, Epoch=6, batch = 3000 of 4000, loss=0.436, LR=0.0008535533905932737
# Validation Loss = 0.153
# Channel 7V, Epoch=7, batch = 0 of 4000, loss=0.198, LR=0.0007938926261462366
# Validation Loss = 0.334
# Channel 7V, Epoch=7, batch = 1000 of 4000, loss=0.198, LR=0.0007938926261462366
# Validation Loss = 0.343
# Channel 7V, Epoch=7, batch = 2000 of 4000, loss=0.212, LR=0.0007938926261462366
# Validation Loss = 0.539
# Channel 7V, Epoch=7, batch = 3000 of 4000, loss=0.252, LR=0.0007938926261462366
# Validation Loss = 1.251
# Channel 7V, Epoch=8, batch = 0 of 4000, loss=0.529, LR=0.0007269952498697733
# Validation Loss = 1.123
# Channel 7V, Epoch=8, batch = 1000 of 4000, loss=0.497, LR=0.0007269952498697733
# Validation Loss = 0.447
# Channel 7V, Epoch=8, batch = 2000 of 4000, loss=0.221, LR=0.0007269952498697733
# Validation Loss = 0.063
# Channel 7V, Epoch=8, batch = 3000 of 4000, loss=0.217, LR=0.0007269952498697733
# Validation Loss = 1.096
# Channel 7V, Epoch=9, batch = 0 of 4000, loss=0.457, LR=0.0006545084971874737
# Validation Loss = 0.416
# Channel 7V, Epoch=9, batch = 1000 of 4000, loss=0.220, LR=0.0006545084971874737
# Validation Loss = 0.064
# Channel 7V, Epoch=9, batch = 2000 of 4000, loss=0.259, LR=0.0006545084971874737
# Validation Loss = 0.127
# Channel 7V, Epoch=9, batch = 3000 of 4000, loss=0.200, LR=0.0006545084971874737
# Validation Loss = 0.312
# Channel 7V, Epoch=10, batch = 0 of 4000, loss=0.183, LR=0.0005782172325201155
# Validation Loss = 0.032
# Channel 7V, Epoch=10, batch = 1000 of 4000, loss=0.261, LR=0.0005782172325201155
# Validation Loss = 0.049
# Channel 7V, Epoch=10, batch = 2000 of 4000, loss=0.254, LR=0.0005782172325201155
# Validation Loss = 0.312
# Channel 7V, Epoch=10, batch = 3000 of 4000, loss=0.214, LR=0.0005782172325201155
# Validation Loss = 0.301
# Channel 7V, Epoch=11, batch = 0 of 4000, loss=0.210, LR=0.0005
# Validation Loss = 0.501
# Channel 7V, Epoch=11, batch = 1000 of 4000, loss=0.254, LR=0.0005
# Validation Loss = 0.531
# Channel 7V, Epoch=11, batch = 2000 of 4000, loss=0.278, LR=0.0005
# Validation Loss = 0.388
# Channel 7V, Epoch=11, batch = 3000 of 4000, loss=0.232, LR=0.0005
# Validation Loss = 0.225
# Channel 7V, Epoch=12, batch = 0 of 4000, loss=0.195, LR=0.0004217827674798847
# Validation Loss = 0.294
# Channel 7V, Epoch=12, batch = 1000 of 4000, loss=0.221, LR=0.0004217827674798847
# Validation Loss = 0.059
# Channel 7V, Epoch=12, batch = 2000 of 4000, loss=0.227, LR=0.0004217827674798847
# Validation Loss = 0.000
# Channel 7V, Epoch=12, batch = 3000 of 4000, loss=0.369, LR=0.0004217827674798847
# Validation Loss = 0.168
# Channel 7V, Epoch=13, batch = 0 of 4000, loss=0.216, LR=0.00034549150281252633
# Validation Loss = 0.589
# Channel 7V, Epoch=13, batch = 1000 of 4000, loss=0.242, LR=0.00034549150281252633
# Validation Loss = 0.340
# Channel 7V, Epoch=13, batch = 2000 of 4000, loss=0.206, LR=0.00034549150281252633
# Validation Loss = 0.100
# Channel 7V, Epoch=13, batch = 3000 of 4000, loss=0.195, LR=0.00034549150281252633
# Validation Loss = 0.336
# Channel 7V, Epoch=14, batch = 0 of 4000, loss=0.209, LR=0.00027300475013022663
# Validation Loss = 0.129
# Channel 7V, Epoch=14, batch = 1000 of 4000, loss=0.179, LR=0.00027300475013022663
# Validation Loss = 0.129
# Channel 7V, Epoch=14, batch = 2000 of 4000, loss=0.186, LR=0.00027300475013022663
# Validation Loss = 0.564
# Channel 7V, Epoch=14, batch = 3000 of 4000, loss=0.252, LR=0.00027300475013022663
# Validation Loss = 0.345
# Channel 7V, Epoch=15, batch = 0 of 4000, loss=0.222, LR=0.00020610737385376348
# Validation Loss = 0.288
# Channel 7V, Epoch=15, batch = 1000 of 4000, loss=0.206, LR=0.00020610737385376348
# Validation Loss = 0.167
# Channel 7V, Epoch=15, batch = 2000 of 4000, loss=0.170, LR=0.00020610737385376348
# Validation Loss = 0.049
# Channel 7V, Epoch=15, batch = 3000 of 4000, loss=0.273, LR=0.00020610737385376348
# Validation Loss = 0.249
# Channel 7V, Epoch=16, batch = 0 of 4000, loss=0.209, LR=0.00014644660940672625
# Validation Loss = 0.120
# Channel 7V, Epoch=16, batch = 1000 of 4000, loss=0.211, LR=0.00014644660940672625
# Validation Loss = 0.261
# Channel 7V, Epoch=16, batch = 2000 of 4000, loss=0.189, LR=0.00014644660940672625
# Validation Loss = 0.157
# Channel 7V, Epoch=16, batch = 3000 of 4000, loss=0.201, LR=0.00014644660940672625
# Validation Loss = 0.551
# Channel 7V, Epoch=17, batch = 0 of 4000, loss=0.276, LR=9.549150281252631e-05
# Validation Loss = 0.271
# Channel 7V, Epoch=17, batch = 1000 of 4000, loss=0.205, LR=9.549150281252631e-05
# Validation Loss = 0.134
# Channel 7V, Epoch=17, batch = 2000 of 4000, loss=0.200, LR=9.549150281252631e-05
# Validation Loss = 0.196
# Channel 7V, Epoch=17, batch = 3000 of 4000, loss=0.198, LR=9.549150281252631e-05
# Validation Loss = 0.099
# Channel 7V, Epoch=18, batch = 0 of 4000, loss=0.182, LR=5.4496737905816096e-05
# Validation Loss = 0.089
# Channel 7V, Epoch=18, batch = 1000 of 4000, loss=0.202, LR=5.4496737905816096e-05
# Validation Loss = 0.151
# Channel 7V, Epoch=18, batch = 2000 of 4000, loss=0.190, LR=5.4496737905816096e-05
# Validation Loss = 0.274
# Channel 7V, Epoch=18, batch = 3000 of 4000, loss=0.208, LR=5.4496737905816096e-05
# Validation Loss = 0.190
# Channel 7V, Epoch=19, batch = 0 of 4000, loss=0.189, LR=2.447174185242323e-05
# Validation Loss = 0.153
# Channel 7V, Epoch=19, batch = 1000 of 4000, loss=0.185, LR=2.447174185242323e-05
# Validation Loss = 0.101
# Channel 7V, Epoch=19, batch = 2000 of 4000, loss=0.192, LR=2.447174185242323e-05
# Validation Loss = 0.207
# Channel 7V, Epoch=19, batch = 3000 of 4000, loss=0.208, LR=2.447174185242323e-05
# Validation Loss = 0.197
# Channel 7V, Epoch=20, batch = 0 of 4000, loss=0.207, LR=6.15582970243117e-06
# Validation Loss = 0.179
# Channel 7V, Epoch=20, batch = 1000 of 4000, loss=0.191, LR=6.15582970243117e-06
# Validation Loss = 0.183
# Channel 7V, Epoch=20, batch = 2000 of 4000, loss=0.193, LR=6.15582970243117e-06
# Validation Loss = 0.170
# Channel 7V, Epoch=20, batch = 3000 of 4000, loss=0.210, LR=6.15582970243117e-06
# Finished training model for channel 7V.
# 7H
# Training stage: 1
# Validation Loss = 13540.048
# Channel 7H, Epoch=1, batch = 0 of 4000, loss=9107.341, LR=0.001
# Validation Loss = 2.610
# Channel 7H, Epoch=1, batch = 1000 of 4000, loss=0.496, LR=0.001
# Validation Loss = 3.843
# Channel 7H, Epoch=1, batch = 2000 of 4000, loss=0.585, LR=0.001
# Validation Loss = 1.043
# Channel 7H, Epoch=1, batch = 3000 of 4000, loss=0.244, LR=0.001
# Validation Loss = 0.545
# Channel 7H, Epoch=2, batch = 0 of 4000, loss=0.317, LR=0.0009045084971874737
# Validation Loss = 2.109
# Channel 7H, Epoch=2, batch = 1000 of 4000, loss=0.362, LR=0.0009045084971874737
# Validation Loss = 0.220
# Channel 7H, Epoch=2, batch = 2000 of 4000, loss=0.190, LR=0.0009045084971874737
# Validation Loss = 0.728
# Channel 7H, Epoch=2, batch = 3000 of 4000, loss=0.242, LR=0.0009045084971874737
# Validation Loss = 0.000
# Channel 7H, Epoch=3, batch = 0 of 4000, loss=0.329, LR=0.0006545084971874737
# Validation Loss = 0.049
# Channel 7H, Epoch=3, batch = 1000 of 4000, loss=0.177, LR=0.0006545084971874737
# Validation Loss = 1.061
# Channel 7H, Epoch=3, batch = 2000 of 4000, loss=0.298, LR=0.0006545084971874737
# Validation Loss = 0.022
# Channel 7H, Epoch=3, batch = 3000 of 4000, loss=0.158, LR=0.0006545084971874737
# Validation Loss = 0.696
# Channel 7H, Epoch=4, batch = 0 of 4000, loss=0.182, LR=0.00034549150281252633
# Validation Loss = 0.327
# Channel 7H, Epoch=4, batch = 1000 of 4000, loss=0.156, LR=0.00034549150281252633
# Validation Loss = 0.569
# Channel 7H, Epoch=4, batch = 2000 of 4000, loss=0.207, LR=0.00034549150281252633
# Validation Loss = 0.144
# Channel 7H, Epoch=4, batch = 3000 of 4000, loss=0.151, LR=0.00034549150281252633
# Validation Loss = 0.279
# Channel 7H, Epoch=5, batch = 0 of 4000, loss=0.152, LR=9.549150281252633e-05
# Validation Loss = 0.076
# Channel 7H, Epoch=5, batch = 1000 of 4000, loss=0.160, LR=9.549150281252633e-05
# Validation Loss = 0.078
# Channel 7H, Epoch=5, batch = 2000 of 4000, loss=0.163, LR=9.549150281252633e-05
# Validation Loss = 0.143
# Channel 7H, Epoch=5, batch = 3000 of 4000, loss=0.158, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.016
# Channel 7H, Epoch=1, batch = 0 of 4000, loss=0.163, LR=0.001
# Validation Loss = 0.316
# Channel 7H, Epoch=1, batch = 1000 of 4000, loss=0.192, LR=0.001
# Validation Loss = 0.205
# Channel 7H, Epoch=1, batch = 2000 of 4000, loss=0.167, LR=0.001
# Validation Loss = 0.266
# Channel 7H, Epoch=1, batch = 3000 of 4000, loss=0.325, LR=0.001
# Validation Loss = 0.067
# Channel 7H, Epoch=2, batch = 0 of 4000, loss=0.399, LR=0.0009755282581475768
# Validation Loss = 2.090
# Channel 7H, Epoch=2, batch = 1000 of 4000, loss=0.952, LR=0.0009755282581475768
# Validation Loss = 0.447
# Channel 7H, Epoch=2, batch = 2000 of 4000, loss=0.171, LR=0.0009755282581475768
# Validation Loss = 0.110
# Channel 7H, Epoch=2, batch = 3000 of 4000, loss=0.141, LR=0.0009755282581475768
# Validation Loss = 0.625
# Channel 7H, Epoch=3, batch = 0 of 4000, loss=0.184, LR=0.0009045084971874736
# Validation Loss = 0.135
# Channel 7H, Epoch=3, batch = 1000 of 4000, loss=0.164, LR=0.0009045084971874736
# Validation Loss = 0.000
# Channel 7H, Epoch=3, batch = 2000 of 4000, loss=0.250, LR=0.0009045084971874736
# Validation Loss = 0.028
# Channel 7H, Epoch=3, batch = 3000 of 4000, loss=0.151, LR=0.0009045084971874736
# Validation Loss = 0.025
# Channel 7H, Epoch=4, batch = 0 of 4000, loss=0.217, LR=0.0007938926261462366
# Validation Loss = 0.061
# Channel 7H, Epoch=4, batch = 1000 of 4000, loss=0.162, LR=0.0007938926261462366
# Validation Loss = 0.004
# Channel 7H, Epoch=4, batch = 2000 of 4000, loss=0.168, LR=0.0007938926261462366
# Validation Loss = 0.002
# Channel 7H, Epoch=4, batch = 3000 of 4000, loss=0.165, LR=0.0007938926261462366
# Validation Loss = 3.134
# Channel 7H, Epoch=5, batch = 0 of 4000, loss=0.384, LR=0.0006545084971874737
# Validation Loss = 0.018
# Channel 7H, Epoch=5, batch = 1000 of 4000, loss=0.166, LR=0.0006545084971874737
# Validation Loss = 0.013
# Channel 7H, Epoch=5, batch = 2000 of 4000, loss=0.162, LR=0.0006545084971874737
# Validation Loss = 0.415
# Channel 7H, Epoch=5, batch = 3000 of 4000, loss=0.488, LR=0.0006545084971874737
# Validation Loss = 0.013
# Channel 7H, Epoch=6, batch = 0 of 4000, loss=0.182, LR=0.0005
# Validation Loss = 0.368
# Channel 7H, Epoch=6, batch = 1000 of 4000, loss=0.154, LR=0.0005
# Validation Loss = 0.013
# Channel 7H, Epoch=6, batch = 2000 of 4000, loss=0.150, LR=0.0005
# Validation Loss = 0.048
# Channel 7H, Epoch=6, batch = 3000 of 4000, loss=0.156, LR=0.0005
# Validation Loss = 0.026
# Channel 7H, Epoch=7, batch = 0 of 4000, loss=0.143, LR=0.00034549150281252633
# Validation Loss = 0.007
# Channel 7H, Epoch=7, batch = 1000 of 4000, loss=0.194, LR=0.00034549150281252633
# Validation Loss = 0.083
# Channel 7H, Epoch=7, batch = 2000 of 4000, loss=0.142, LR=0.00034549150281252633
# Validation Loss = 0.439
# Channel 7H, Epoch=7, batch = 3000 of 4000, loss=0.194, LR=0.00034549150281252633
# Validation Loss = 0.368
# Channel 7H, Epoch=8, batch = 0 of 4000, loss=0.151, LR=0.0002061073738537635
# Validation Loss = 0.130
# Channel 7H, Epoch=8, batch = 1000 of 4000, loss=0.143, LR=0.0002061073738537635
# ...
# Validation Loss = 0.042
# Channel 37V, Epoch=17, batch = 2000 of 4000, loss=0.516, LR=9.549150281252631e-05
# Validation Loss = 0.016
# Channel 37V, Epoch=17, batch = 3000 of 4000, loss=0.556, LR=9.549150281252631e-05
# Validation Loss = 0.214
# Channel 37V, Epoch=18, batch = 0 of 4000, loss=0.463, LR=5.4496737905816096e-05
# Validation Loss = 0.136
# Channel 37V, Epoch=18, batch = 1000 of 4000, loss=0.555, LR=5.4496737905816096e-05
# Validation Loss = 0.209
# Channel 37V, Epoch=18, batch = 2000 of 4000, loss=0.510, LR=5.4496737905816096e-05
# Validation Loss = 0.092
# Channel 37V, Epoch=18, batch = 3000 of 4000, loss=0.494, LR=5.4496737905816096e-05
# Validation Loss = 0.095
# Channel 37V, Epoch=19, batch = 0 of 4000, loss=0.464, LR=2.447174185242323e-05
# Validation Loss = 0.119
# Channel 37V, Epoch=19, batch = 1000 of 4000, loss=0.493, LR=2.447174185242323e-05
# Validation Loss = 0.085
# Channel 37V, Epoch=19, batch = 2000 of 4000, loss=0.447, LR=2.447174185242323e-05
# Validation Loss = 0.121
# Channel 37V, Epoch=19, batch = 3000 of 4000, loss=0.446, LR=2.447174185242323e-05
# Validation Loss = 0.079
# Channel 37V, Epoch=20, batch = 0 of 4000, loss=0.454, LR=6.15582970243117e-06
# Validation Loss = 0.132
# Channel 37V, Epoch=20, batch = 1000 of 4000, loss=0.502, LR=6.15582970243117e-06
# Validation Loss = 0.103
# Channel 37V, Epoch=20, batch = 2000 of 4000, loss=0.484, LR=6.15582970243117e-06
# Validation Loss = 0.095
# Channel 37V, Epoch=20, batch = 3000 of 4000, loss=0.489, LR=6.15582970243117e-06
# Finished training model for channel 37V.
# 37H
# Training stage: 1
# Validation Loss = 54739.641
# Channel 37H, Epoch=1, batch = 0 of 4000, loss=29212.289, LR=0.001
# Validation Loss = 4.190
# Channel 37H, Epoch=1, batch = 1000 of 4000, loss=8.682, LR=0.001
# Validation Loss = 4.538
# Channel 37H, Epoch=1, batch = 2000 of 4000, loss=3.568, LR=0.001
# Validation Loss = 0.231
# Channel 37H, Epoch=1, batch = 3000 of 4000, loss=5.872, LR=0.001
# Validation Loss = 5.381
# Channel 37H, Epoch=2, batch = 0 of 4000, loss=2.375, LR=0.0009045084971874737
# Validation Loss = 10.483
# Channel 37H, Epoch=2, batch = 1000 of 4000, loss=2.503, LR=0.0009045084971874737
# Validation Loss = 4.126
# Channel 37H, Epoch=2, batch = 2000 of 4000, loss=2.749, LR=0.0009045084971874737
# Validation Loss = 15.116
# Channel 37H, Epoch=2, batch = 3000 of 4000, loss=2.199, LR=0.0009045084971874737
# Validation Loss = 46.712
# Channel 37H, Epoch=3, batch = 0 of 4000, loss=10.819, LR=0.0006545084971874737
# Validation Loss = 7.269
# Channel 37H, Epoch=3, batch = 1000 of 4000, loss=1.860, LR=0.0006545084971874737
# Validation Loss = 11.192
# Channel 37H, Epoch=3, batch = 2000 of 4000, loss=2.004, LR=0.0006545084971874737
# Validation Loss = 9.833
# Channel 37H, Epoch=3, batch = 3000 of 4000, loss=1.835, LR=0.0006545084971874737
# Validation Loss = 2.837
# Channel 37H, Epoch=4, batch = 0 of 4000, loss=2.039, LR=0.00034549150281252633
# Validation Loss = 16.882
# Channel 37H, Epoch=4, batch = 1000 of 4000, loss=2.002, LR=0.00034549150281252633
# Validation Loss = 8.217
# Channel 37H, Epoch=4, batch = 2000 of 4000, loss=1.670, LR=0.00034549150281252633
# Validation Loss = 5.753
# Channel 37H, Epoch=4, batch = 3000 of 4000, loss=1.380, LR=0.00034549150281252633
# Validation Loss = 9.802
# Channel 37H, Epoch=5, batch = 0 of 4000, loss=1.600, LR=9.549150281252633e-05
# Validation Loss = 4.812
# Channel 37H, Epoch=5, batch = 1000 of 4000, loss=1.603, LR=9.549150281252633e-05
# Validation Loss = 6.072
# Channel 37H, Epoch=5, batch = 2000 of 4000, loss=1.524, LR=9.549150281252633e-05
# Validation Loss = 4.344
# Channel 37H, Epoch=5, batch = 3000 of 4000, loss=1.476, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 4.116
# Channel 37H, Epoch=1, batch = 0 of 4000, loss=1.605, LR=0.001
# Validation Loss = 11.184
# Channel 37H, Epoch=1, batch = 1000 of 4000, loss=2.452, LR=0.001
# Validation Loss = 0.328
# Channel 37H, Epoch=1, batch = 2000 of 4000, loss=3.172, LR=0.001
# Validation Loss = 0.665
# Channel 37H, Epoch=1, batch = 3000 of 4000, loss=2.293, LR=0.001
# Validation Loss = 2.298
# Channel 37H, Epoch=2, batch = 0 of 4000, loss=1.791, LR=0.0009755282581475768
# Validation Loss = 0.792
# Channel 37H, Epoch=2, batch = 1000 of 4000, loss=1.943, LR=0.0009755282581475768
# Validation Loss = 0.400
# Channel 37H, Epoch=2, batch = 2000 of 4000, loss=2.481, LR=0.0009755282581475768
# Validation Loss = 7.552
# Channel 37H, Epoch=2, batch = 3000 of 4000, loss=1.785, LR=0.0009755282581475768
# Validation Loss = 11.103
# Channel 37H, Epoch=3, batch = 0 of 4000, loss=3.004, LR=0.0009045084971874736
# Validation Loss = 2.333
# Channel 37H, Epoch=3, batch = 1000 of 4000, loss=1.582, LR=0.0009045084971874736
# Validation Loss = 1.950
# Channel 37H, Epoch=3, batch = 2000 of 4000, loss=1.744, LR=0.0009045084971874736
# Validation Loss = 2.067
# Channel 37H, Epoch=3, batch = 3000 of 4000, loss=1.525, LR=0.0009045084971874736
# Validation Loss = 0.033
# Channel 37H, Epoch=4, batch = 0 of 4000, loss=3.011, LR=0.0007938926261462366
# Validation Loss = 8.729
# Channel 37H, Epoch=4, batch = 1000 of 4000, loss=2.910, LR=0.0007938926261462366
# Validation Loss = 8.878
# Channel 37H, Epoch=4, batch = 2000 of 4000, loss=2.184, LR=0.0007938926261462366
# Validation Loss = 6.456
# Channel 37H, Epoch=4, batch = 3000 of 4000, loss=1.810, LR=0.0007938926261462366
# Validation Loss = 1.444
# Channel 37H, Epoch=5, batch = 0 of 4000, loss=1.449, LR=0.0006545084971874737
# Validation Loss = 2.673
# Channel 37H, Epoch=5, batch = 1000 of 4000, loss=1.578, LR=0.0006545084971874737
# Validation Loss = 1.784
# Channel 37H, Epoch=5, batch = 2000 of 4000, loss=1.790, LR=0.0006545084971874737
# Validation Loss = 6.647
# Channel 37H, Epoch=5, batch = 3000 of 4000, loss=2.177, LR=0.0006545084971874737
# Validation Loss = 4.877
# Channel 37H, Epoch=6, batch = 0 of 4000, loss=1.328, LR=0.0005
# Validation Loss = 7.382
# Channel 37H, Epoch=6, batch = 1000 of 4000, loss=1.878, LR=0.0005
# Validation Loss = 6.839
# Channel 37H, Epoch=6, batch = 2000 of 4000, loss=1.492, LR=0.0005
# Validation Loss = 1.576
# Channel 37H, Epoch=6, batch = 3000 of 4000, loss=1.760, LR=0.0005
# Validation Loss = 4.295
# Channel 37H, Epoch=7, batch = 0 of 4000, loss=1.503, LR=0.00034549150281252633
# Validation Loss = 6.788
# Channel 37H, Epoch=7, batch = 1000 of 4000, loss=1.426, LR=0.00034549150281252633
# Validation Loss = 5.584
# Channel 37H, Epoch=7, batch = 2000 of 4000, loss=1.544, LR=0.00034549150281252633
# Validation Loss = 1.896
# Channel 37H, Epoch=7, batch = 3000 of 4000, loss=1.460, LR=0.00034549150281252633
# Validation Loss = 2.173
# Channel 37H, Epoch=8, batch = 0 of 4000, loss=1.460, LR=0.0002061073738537635
# Validation Loss = 3.914
# Channel 37H, Epoch=8, batch = 1000 of 4000, loss=1.624, LR=0.0002061073738537635
# Validation Loss = 2.839
# Channel 37H, Epoch=8, batch = 2000 of 4000, loss=1.377, LR=0.0002061073738537635
# Validation Loss = 2.744
# Channel 37H, Epoch=8, batch = 3000 of 4000, loss=1.410, LR=0.0002061073738537635
# Validation Loss = 2.551
# Channel 37H, Epoch=9, batch = 0 of 4000, loss=1.552, LR=9.549150281252634e-05
# Validation Loss = 2.856
# Channel 37H, Epoch=9, batch = 1000 of 4000, loss=1.482, LR=9.549150281252634e-05
# Validation Loss = 3.393
# Channel 37H, Epoch=9, batch = 2000 of 4000, loss=1.364, LR=9.549150281252634e-05
# Validation Loss = 2.792
# Channel 37H, Epoch=9, batch = 3000 of 4000, loss=1.524, LR=9.549150281252634e-05
# Validation Loss = 2.825
# Channel 37H, Epoch=10, batch = 0 of 4000, loss=1.338, LR=2.4471741852423235e-05
# Validation Loss = 2.608
# Channel 37H, Epoch=10, batch = 1000 of 4000, loss=1.343, LR=2.4471741852423235e-05
# Validation Loss = 3.173
# Channel 37H, Epoch=10, batch = 2000 of 4000, loss=1.367, LR=2.4471741852423235e-05
# Validation Loss = 2.570
# Channel 37H, Epoch=10, batch = 3000 of 4000, loss=1.356, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 3.243
# Channel 37H, Epoch=1, batch = 0 of 4000, loss=1.266, LR=0.001
# Validation Loss = 9.522
# Channel 37H, Epoch=1, batch = 1000 of 4000, loss=2.350, LR=0.001
# Validation Loss = 1.417
# Channel 37H, Epoch=1, batch = 2000 of 4000, loss=1.560, LR=0.001
# Validation Loss = 5.405
# Channel 37H, Epoch=1, batch = 3000 of 4000, loss=1.887, LR=0.001
# Validation Loss = 4.339
# Channel 37H, Epoch=2, batch = 0 of 4000, loss=2.225, LR=0.0009938441702975688
# Validation Loss = 6.353
# Channel 37H, Epoch=2, batch = 1000 of 4000, loss=2.210, LR=0.0009938441702975688
# Validation Loss = 5.648
# Channel 37H, Epoch=2, batch = 2000 of 4000, loss=1.551, LR=0.0009938441702975688
# Validation Loss = 2.502
# Channel 37H, Epoch=2, batch = 3000 of 4000, loss=1.599, LR=0.0009938441702975688
# Validation Loss = 0.142
# Channel 37H, Epoch=3, batch = 0 of 4000, loss=1.936, LR=0.0009755282581475768
# Validation Loss = 0.062
# Channel 37H, Epoch=3, batch = 1000 of 4000, loss=3.248, LR=0.0009755282581475768
# Validation Loss = 2.570
# Channel 37H, Epoch=3, batch = 2000 of 4000, loss=1.419, LR=0.0009755282581475768
# Validation Loss = 0.708
# Channel 37H, Epoch=3, batch = 3000 of 4000, loss=1.784, LR=0.0009755282581475768
# Validation Loss = 0.154
# Channel 37H, Epoch=4, batch = 0 of 4000, loss=1.606, LR=0.0009455032620941839
# Validation Loss = 2.155
# Channel 37H, Epoch=4, batch = 1000 of 4000, loss=1.534, LR=0.0009455032620941839
# Validation Loss = 3.621
# Channel 37H, Epoch=4, batch = 2000 of 4000, loss=1.323, LR=0.0009455032620941839
# Validation Loss = 0.114
# Channel 37H, Epoch=4, batch = 3000 of 4000, loss=1.950, LR=0.0009455032620941839
# Validation Loss = 0.898
# Channel 37H, Epoch=5, batch = 0 of 4000, loss=2.288, LR=0.0009045084971874737
# Validation Loss = 0.561
# Channel 37H, Epoch=5, batch = 1000 of 4000, loss=1.445, LR=0.0009045084971874737
# Validation Loss = 0.011
# Channel 37H, Epoch=5, batch = 2000 of 4000, loss=2.676, LR=0.0009045084971874737
# Validation Loss = 5.371
# Channel 37H, Epoch=5, batch = 3000 of 4000, loss=1.702, LR=0.0009045084971874737
# Validation Loss = 0.568
# Channel 37H, Epoch=6, batch = 0 of 4000, loss=1.896, LR=0.0008535533905932737
# Validation Loss = 0.419
# Channel 37H, Epoch=6, batch = 1000 of 4000, loss=1.979, LR=0.0008535533905932737
# Validation Loss = 4.099
# Channel 37H, Epoch=6, batch = 2000 of 4000, loss=1.405, LR=0.0008535533905932737
# Validation Loss = 8.122
# Channel 37H, Epoch=6, batch = 3000 of 4000, loss=2.361, LR=0.0008535533905932737
# Validation Loss = 13.113
# Channel 37H, Epoch=7, batch = 0 of 4000, loss=2.206, LR=0.0007938926261462366
# Validation Loss = 2.957
# Channel 37H, Epoch=7, batch = 1000 of 4000, loss=1.467, LR=0.0007938926261462366
# Validation Loss = 0.577
# Channel 37H, Epoch=7, batch = 2000 of 4000, loss=1.488, LR=0.0007938926261462366
# Validation Loss = 1.469
# Channel 37H, Epoch=7, batch = 3000 of 4000, loss=1.456, LR=0.0007938926261462366
# Validation Loss = 2.361
# Channel 37H, Epoch=8, batch = 0 of 4000, loss=1.688, LR=0.0007269952498697733
# Validation Loss = 4.909
# Channel 37H, Epoch=8, batch = 1000 of 4000, loss=1.704, LR=0.0007269952498697733
# Validation Loss = 2.149
# Channel 37H, Epoch=8, batch = 2000 of 4000, loss=1.304, LR=0.0007269952498697733
# Validation Loss = 3.904
# Channel 37H, Epoch=8, batch = 3000 of 4000, loss=1.590, LR=0.0007269952498697733
# Validation Loss = 7.039
# Channel 37H, Epoch=9, batch = 0 of 4000, loss=1.689, LR=0.0006545084971874737
# Validation Loss = 0.288
# Channel 37H, Epoch=9, batch = 1000 of 4000, loss=1.971, LR=0.0006545084971874737
# Validation Loss = 0.952
# Channel 37H, Epoch=9, batch = 2000 of 4000, loss=3.539, LR=0.0006545084971874737
# Validation Loss = 0.672
# Channel 37H, Epoch=9, batch = 3000 of 4000, loss=1.652, LR=0.0006545084971874737
# Validation Loss = 5.167
# Channel 37H, Epoch=10, batch = 0 of 4000, loss=1.342, LR=0.0005782172325201155
# Validation Loss = 2.293
# Channel 37H, Epoch=10, batch = 1000 of 4000, loss=1.365, LR=0.0005782172325201155
# Validation Loss = 4.314
# Channel 37H, Epoch=10, batch = 2000 of 4000, loss=1.405, LR=0.0005782172325201155
# Validation Loss = 0.930
# Channel 37H, Epoch=10, batch = 3000 of 4000, loss=1.514, LR=0.0005782172325201155
# Validation Loss = 5.132
# Channel 37H, Epoch=11, batch = 0 of 4000, loss=1.386, LR=0.0005
# Validation Loss = 4.225
# Channel 37H, Epoch=11, batch = 1000 of 4000, loss=1.626, LR=0.0005
# Validation Loss = 1.345
# Channel 37H, Epoch=11, batch = 2000 of 4000, loss=1.417, LR=0.0005
# Validation Loss = 3.784
# Channel 37H, Epoch=11, batch = 3000 of 4000, loss=1.297, LR=0.0005
# Validation Loss = 1.720
# Channel 37H, Epoch=12, batch = 0 of 4000, loss=1.596, LR=0.0004217827674798847
# Validation Loss = 2.090
# Channel 37H, Epoch=12, batch = 1000 of 4000, loss=1.846, LR=0.0004217827674798847
# Validation Loss = 3.343
# Channel 37H, Epoch=12, batch = 2000 of 4000, loss=1.366, LR=0.0004217827674798847
# Validation Loss = 1.835
# Channel 37H, Epoch=12, batch = 3000 of 4000, loss=1.266, LR=0.0004217827674798847
# Validation Loss = 1.813
# Channel 37H, Epoch=13, batch = 0 of 4000, loss=1.500, LR=0.00034549150281252633
# Validation Loss = 1.356
# Channel 37H, Epoch=13, batch = 1000 of 4000, loss=1.373, LR=0.00034549150281252633
# Validation Loss = 2.613
# Channel 37H, Epoch=13, batch = 2000 of 4000, loss=1.336, LR=0.00034549150281252633
# Validation Loss = 0.813
# Channel 37H, Epoch=13, batch = 3000 of 4000, loss=1.485, LR=0.00034549150281252633
# Validation Loss = 0.765
# Channel 37H, Epoch=14, batch = 0 of 4000, loss=1.434, LR=0.00027300475013022663
# Validation Loss = 2.004
# Channel 37H, Epoch=14, batch = 1000 of 4000, loss=1.330, LR=0.00027300475013022663
# Validation Loss = 2.934
# Channel 37H, Epoch=14, batch = 2000 of 4000, loss=1.199, LR=0.00027300475013022663
# Validation Loss = 0.279
# Channel 37H, Epoch=14, batch = 3000 of 4000, loss=1.691, LR=0.00027300475013022663
# Validation Loss = 3.097
# Channel 37H, Epoch=15, batch = 0 of 4000, loss=1.664, LR=0.00020610737385376348
# Validation Loss = 0.760
# Channel 37H, Epoch=15, batch = 1000 of 4000, loss=1.365, LR=0.00020610737385376348
# Validation Loss = 0.714
# Channel 37H, Epoch=15, batch = 2000 of 4000, loss=1.259, LR=0.00020610737385376348
# Validation Loss = 1.690
# Channel 37H, Epoch=15, batch = 3000 of 4000, loss=1.343, LR=0.00020610737385376348
# Validation Loss = 2.727
# Channel 37H, Epoch=16, batch = 0 of 4000, loss=1.245, LR=0.00014644660940672625
# Validation Loss = 1.664
# Channel 37H, Epoch=16, batch = 1000 of 4000, loss=1.334, LR=0.00014644660940672625
# Validation Loss = 2.506
# Channel 37H, Epoch=16, batch = 2000 of 4000, loss=1.301, LR=0.00014644660940672625
# Validation Loss = 1.108
# Channel 37H, Epoch=16, batch = 3000 of 4000, loss=1.321, LR=0.00014644660940672625
# Validation Loss = 1.790
# Channel 37H, Epoch=17, batch = 0 of 4000, loss=1.496, LR=9.549150281252631e-05
# Validation Loss = 1.894
# Channel 37H, Epoch=17, batch = 1000 of 4000, loss=1.311, LR=9.549150281252631e-05
# Validation Loss = 1.501
# Channel 37H, Epoch=17, batch = 2000 of 4000, loss=1.362, LR=9.549150281252631e-05
# Validation Loss = 0.773
# Channel 37H, Epoch=17, batch = 3000 of 4000, loss=1.584, LR=9.549150281252631e-05
# Validation Loss = 1.271
# Channel 37H, Epoch=18, batch = 0 of 4000, loss=1.417, LR=5.4496737905816096e-05
# Validation Loss = 1.749
# Channel 37H, Epoch=18, batch = 1000 of 4000, loss=1.307, LR=5.4496737905816096e-05
# Validation Loss = 1.225
# Channel 37H, Epoch=18, batch = 2000 of 4000, loss=1.351, LR=5.4496737905816096e-05
# Validation Loss = 0.943
# Channel 37H, Epoch=18, batch = 3000 of 4000, loss=1.453, LR=5.4496737905816096e-05
# Validation Loss = 2.124
# Channel 37H, Epoch=19, batch = 0 of 4000, loss=1.338, LR=2.447174185242323e-05
# Validation Loss = 1.689
# Channel 37H, Epoch=19, batch = 1000 of 4000, loss=1.451, LR=2.447174185242323e-05
# Validation Loss = 1.493
# Channel 37H, Epoch=19, batch = 2000 of 4000, loss=1.174, LR=2.447174185242323e-05
# Validation Loss = 1.346
# Channel 37H, Epoch=19, batch = 3000 of 4000, loss=1.228, LR=2.447174185242323e-05
# Validation Loss = 1.081
# Channel 37H, Epoch=20, batch = 0 of 4000, loss=1.252, LR=6.15582970243117e-06
# Validation Loss = 1.477
# Channel 37H, Epoch=20, batch = 1000 of 4000, loss=1.423, LR=6.15582970243117e-06
# Validation Loss = 1.358
# Channel 37H, Epoch=20, batch = 2000 of 4000, loss=1.190, LR=6.15582970243117e-06
# Validation Loss = 1.419
# Channel 37H, Epoch=20, batch = 3000 of 4000, loss=1.453, LR=6.15582970243117e-06
# Finished training model for channel 37H.

# %%
#General parameters:
input_size = nchans - 1 + 1 #Remaining channels + surface type

# %%
'''

SSMI CHANNEL PREDICTION MODEL:
    2: Non-Ocean Surfaces

'''

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = sfctype > 1

    Tbs = f.Tbs.values[correct_sfc,:]
    sfctype = sfctype[correct_sfc]

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

sfctype_train = sfctype[train_indcs].astype(np.float32)
sfctype_test  = sfctype[test_indcs].astype(np.float32)
sfctype_val   = sfctype[val_indcs].astype(np.float32)

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train, shuffled_indcs = array_funcs.shuffle_data(Tbs_train, axis=0, return_indcs=True)
sfctype_train = sfctype_train[shuffled_indcs]

# %%
sfctype_train, sfctype_test, sfctype_val
# Out:
# (array([14., 11., 11., ..., 10., 15.,  2.],
#        shape=(32384092,), dtype=float32),
#  array([4., 4., 4., ..., 2., 2., 2.], shape=(4048011,), dtype=float32),
#  array([ 2.,  2.,  2., ..., 11., 11., 11.], shape=(4048013,), dtype=float32))

# %%
chan_desc[10]
# Out:
# '37V'

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    if ichan < 10: continue

    print(channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)

    x_train = np.concatenate((x_train, sfctype_train[:,None]), axis=1)
    x_test  = np.concatenate((x_test,  sfctype_test[:,None]), axis=1)
    x_val   = np.concatenate((x_val,   sfctype_val[:,None]), axis=1)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_nonocean_no89.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_nonocean_no89.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 37V
# Training stage: 1
# Validation Loss = 44298.156
# Channel 37V, Epoch=1, batch = 0 of 32384, loss=60272.070, LR=0.001
# Validation Loss = 22.890
# Channel 37V, Epoch=1, batch = 1000 of 32384, loss=5.276, LR=0.001
# Validation Loss = 12.305
# Channel 37V, Epoch=1, batch = 2000 of 32384, loss=5.592, LR=0.001
# Validation Loss = 31.500
# Channel 37V, Epoch=1, batch = 3000 of 32384, loss=4.799, LR=0.001
# Validation Loss = 24.795
# Channel 37V, Epoch=1, batch = 4000 of 32384, loss=3.815, LR=0.001
# Validation Loss = 12.561
# Channel 37V, Epoch=1, batch = 5000 of 32384, loss=5.312, LR=0.001
# Validation Loss = 22.232
# Channel 37V, Epoch=1, batch = 6000 of 32384, loss=4.074, LR=0.001
# Validation Loss = 18.455
# Channel 37V, Epoch=1, batch = 7000 of 32384, loss=4.297, LR=0.001
# Validation Loss = 28.768
# Channel 37V, Epoch=1, batch = 8000 of 32384, loss=4.007, LR=0.001
# Validation Loss = 49.677
# Channel 37V, Epoch=1, batch = 9000 of 32384, loss=6.916, LR=0.001
# Validation Loss = 33.317
# Channel 37V, Epoch=1, batch = 10000 of 32384, loss=4.996, LR=0.001
# Validation Loss = 20.688
# Channel 37V, Epoch=1, batch = 11000 of 32384, loss=4.358, LR=0.001
# Validation Loss = 19.300
# Channel 37V, Epoch=1, batch = 12000 of 32384, loss=3.180, LR=0.001
# Validation Loss = 13.424
# Channel 37V, Epoch=1, batch = 13000 of 32384, loss=3.648, LR=0.001
# Validation Loss = 45.397
# Channel 37V, Epoch=1, batch = 14000 of 32384, loss=6.666, LR=0.001
# Validation Loss = 25.272
# Channel 37V, Epoch=1, batch = 15000 of 32384, loss=3.501, LR=0.001
# Validation Loss = 24.348
# Channel 37V, Epoch=1, batch = 16000 of 32384, loss=3.121, LR=0.001
# Validation Loss = 22.795
# Channel 37V, Epoch=1, batch = 17000 of 32384, loss=2.896, LR=0.001
# Validation Loss = 28.892
# Channel 37V, Epoch=1, batch = 18000 of 32384, loss=4.694, LR=0.001
# Validation Loss = 25.033
# Channel 37V, Epoch=1, batch = 19000 of 32384, loss=3.789, LR=0.001
# Validation Loss = 11.129
# Channel 37V, Epoch=1, batch = 20000 of 32384, loss=3.105, LR=0.001
# Validation Loss = 12.890
# Channel 37V, Epoch=1, batch = 21000 of 32384, loss=2.880, LR=0.001
# Validation Loss = 4.663
# Channel 37V, Epoch=1, batch = 22000 of 32384, loss=6.153, LR=0.001
# Validation Loss = 15.600
# Channel 37V, Epoch=1, batch = 23000 of 32384, loss=2.982, LR=0.001
# Validation Loss = 5.357
# Channel 37V, Epoch=1, batch = 24000 of 32384, loss=4.489, LR=0.001
# Validation Loss = 4.488
# Channel 37V, Epoch=1, batch = 25000 of 32384, loss=8.318, LR=0.001
# Validation Loss = 6.963
# Channel 37V, Epoch=1, batch = 26000 of 32384, loss=4.151, LR=0.001
# Validation Loss = 4.281
# Channel 37V, Epoch=1, batch = 27000 of 32384, loss=5.930, LR=0.001
# Validation Loss = 11.404
# Channel 37V, Epoch=1, batch = 28000 of 32384, loss=3.003, LR=0.001
# Validation Loss = 25.539
# Channel 37V, Epoch=1, batch = 29000 of 32384, loss=3.878, LR=0.001
# Validation Loss = 8.978
# Channel 37V, Epoch=1, batch = 30000 of 32384, loss=3.730, LR=0.001
# Validation Loss = 17.770
# Channel 37V, Epoch=1, batch = 31000 of 32384, loss=2.633, LR=0.001
# Validation Loss = 11.518
# Channel 37V, Epoch=1, batch = 32000 of 32384, loss=2.399, LR=0.001
# Validation Loss = 13.987
# Channel 37V, Epoch=2, batch = 0 of 32384, loss=2.944, LR=0.0009045084971874737
# Validation Loss = 14.741
# Channel 37V, Epoch=2, batch = 1000 of 32384, loss=3.437, LR=0.0009045084971874737
# Validation Loss = 12.930
# Channel 37V, Epoch=2, batch = 2000 of 32384, loss=2.856, LR=0.0009045084971874737
# Validation Loss = 34.339
# Channel 37V, Epoch=2, batch = 3000 of 32384, loss=2.621, LR=0.0009045084971874737
# Validation Loss = 16.381
# Channel 37V, Epoch=2, batch = 4000 of 32384, loss=2.622, LR=0.0009045084971874737
# Validation Loss = 33.868
# Channel 37V, Epoch=2, batch = 5000 of 32384, loss=2.952, LR=0.0009045084971874737
# Validation Loss = 11.091
# Channel 37V, Epoch=2, batch = 6000 of 32384, loss=3.898, LR=0.0009045084971874737
# Validation Loss = 18.572
# Channel 37V, Epoch=2, batch = 7000 of 32384, loss=2.996, LR=0.0009045084971874737
# Validation Loss = 12.339
# Channel 37V, Epoch=2, batch = 8000 of 32384, loss=3.085, LR=0.0009045084971874737
# Validation Loss = 11.509
# Channel 37V, Epoch=2, batch = 9000 of 32384, loss=2.567, LR=0.0009045084971874737
# Validation Loss = 12.628
# Channel 37V, Epoch=2, batch = 10000 of 32384, loss=2.585, LR=0.0009045084971874737
# Validation Loss = 27.963
# Channel 37V, Epoch=2, batch = 11000 of 32384, loss=2.909, LR=0.0009045084971874737
# Validation Loss = 3.008
# Channel 37V, Epoch=2, batch = 12000 of 32384, loss=5.618, LR=0.0009045084971874737
# Validation Loss = 24.226
# Channel 37V, Epoch=2, batch = 13000 of 32384, loss=2.523, LR=0.0009045084971874737
# Validation Loss = 7.701
# Channel 37V, Epoch=2, batch = 14000 of 32384, loss=2.501, LR=0.0009045084971874737
# Validation Loss = 9.870
# Channel 37V, Epoch=2, batch = 15000 of 32384, loss=2.872, LR=0.0009045084971874737
# Validation Loss = 27.120
# Channel 37V, Epoch=2, batch = 16000 of 32384, loss=5.148, LR=0.0009045084971874737
# Validation Loss = 15.712
# Channel 37V, Epoch=2, batch = 17000 of 32384, loss=3.145, LR=0.0009045084971874737
# Validation Loss = 31.474
# Channel 37V, Epoch=2, batch = 18000 of 32384, loss=2.957, LR=0.0009045084971874737
# Validation Loss = 6.629
# Channel 37V, Epoch=2, batch = 19000 of 32384, loss=3.279, LR=0.0009045084971874737
# Validation Loss = 27.860
# Channel 37V, Epoch=2, batch = 20000 of 32384, loss=3.372, LR=0.0009045084971874737
# Validation Loss = 12.537
# Channel 37V, Epoch=2, batch = 21000 of 32384, loss=2.997, LR=0.0009045084971874737
# Validation Loss = 27.127
# Channel 37V, Epoch=2, batch = 22000 of 32384, loss=2.742, LR=0.0009045084971874737
# Validation Loss = 22.441
# Channel 37V, Epoch=2, batch = 23000 of 32384, loss=2.592, LR=0.0009045084971874737
# Validation Loss = 12.032
# Channel 37V, Epoch=2, batch = 24000 of 32384, loss=2.337, LR=0.0009045084971874737
# Validation Loss = 18.315
# Channel 37V, Epoch=2, batch = 25000 of 32384, loss=2.708, LR=0.0009045084971874737
# Validation Loss = 26.498
# Channel 37V, Epoch=2, batch = 26000 of 32384, loss=2.382, LR=0.0009045084971874737
# Validation Loss = 28.322
# Channel 37V, Epoch=2, batch = 27000 of 32384, loss=2.985, LR=0.0009045084971874737
# Validation Loss = 18.812
# Channel 37V, Epoch=2, batch = 28000 of 32384, loss=2.404, LR=0.0009045084971874737
# Validation Loss = 20.461
# Channel 37V, Epoch=2, batch = 29000 of 32384, loss=2.680, LR=0.0009045084971874737
# Validation Loss = 11.106
# Channel 37V, Epoch=2, batch = 30000 of 32384, loss=2.470, LR=0.0009045084971874737
# Validation Loss = 19.894
# Channel 37V, Epoch=2, batch = 31000 of 32384, loss=3.021, LR=0.0009045084971874737
# Validation Loss = 37.777
# Channel 37V, Epoch=2, batch = 32000 of 32384, loss=3.130, LR=0.0009045084971874737
# Validation Loss = 22.281
# Channel 37V, Epoch=3, batch = 0 of 32384, loss=2.343, LR=0.0006545084971874737
# Validation Loss = 16.929
# Channel 37V, Epoch=3, batch = 1000 of 32384, loss=2.324, LR=0.0006545084971874737
# Validation Loss = 25.954
# Channel 37V, Epoch=3, batch = 2000 of 32384, loss=2.296, LR=0.0006545084971874737
# Validation Loss = 14.276
# Channel 37V, Epoch=3, batch = 3000 of 32384, loss=2.901, LR=0.0006545084971874737
# Validation Loss = 24.516
# Channel 37V, Epoch=3, batch = 4000 of 32384, loss=2.712, LR=0.0006545084971874737
# Validation Loss = 19.223
# Channel 37V, Epoch=3, batch = 5000 of 32384, loss=2.403, LR=0.0006545084971874737
# Validation Loss = 20.538
# Channel 37V, Epoch=3, batch = 6000 of 32384, loss=2.538, LR=0.0006545084971874737
# Validation Loss = 19.040
# Channel 37V, Epoch=3, batch = 7000 of 32384, loss=2.822, LR=0.0006545084971874737
# Validation Loss = 22.124
# Channel 37V, Epoch=3, batch = 8000 of 32384, loss=3.053, LR=0.0006545084971874737
# Validation Loss = 19.641
# Channel 37V, Epoch=3, batch = 9000 of 32384, loss=2.415, LR=0.0006545084971874737
# Validation Loss = 37.371
# Channel 37V, Epoch=3, batch = 10000 of 32384, loss=3.313, LR=0.0006545084971874737
# Validation Loss = 18.503
# Channel 37V, Epoch=3, batch = 11000 of 32384, loss=2.633, LR=0.0006545084971874737
# Validation Loss = 16.349
# Channel 37V, Epoch=3, batch = 12000 of 32384, loss=2.216, LR=0.0006545084971874737
# Validation Loss = 39.778
# Channel 37V, Epoch=3, batch = 13000 of 32384, loss=3.801, LR=0.0006545084971874737
# Validation Loss = 12.289
# Channel 37V, Epoch=3, batch = 14000 of 32384, loss=2.519, LR=0.0006545084971874737
# Validation Loss = 15.694
# Channel 37V, Epoch=3, batch = 15000 of 32384, loss=2.550, LR=0.0006545084971874737
# Validation Loss = 16.723
# Channel 37V, Epoch=3, batch = 16000 of 32384, loss=2.450, LR=0.0006545084971874737
# Validation Loss = 18.989
# Channel 37V, Epoch=3, batch = 17000 of 32384, loss=2.355, LR=0.0006545084971874737
# Validation Loss = 14.696
# Channel 37V, Epoch=3, batch = 18000 of 32384, loss=2.431, LR=0.0006545084971874737
# Validation Loss = 24.796
# Channel 37V, Epoch=3, batch = 19000 of 32384, loss=3.160, LR=0.0006545084971874737
# Validation Loss = 15.367
# Channel 37V, Epoch=3, batch = 20000 of 32384, loss=2.951, LR=0.0006545084971874737
# Validation Loss = 10.020
# Channel 37V, Epoch=3, batch = 21000 of 32384, loss=3.475, LR=0.0006545084971874737
# Validation Loss = 8.458
# Channel 37V, Epoch=3, batch = 22000 of 32384, loss=2.460, LR=0.0006545084971874737
# Validation Loss = 14.198
# Channel 37V, Epoch=3, batch = 23000 of 32384, loss=2.036, LR=0.0006545084971874737
# Validation Loss = 13.735
# Channel 37V, Epoch=3, batch = 24000 of 32384, loss=2.552, LR=0.0006545084971874737
# Validation Loss = 16.546
# Channel 37V, Epoch=3, batch = 25000 of 32384, loss=2.411, LR=0.0006545084971874737
# Validation Loss = 22.400
# Channel 37V, Epoch=3, batch = 26000 of 32384, loss=2.699, LR=0.0006545084971874737
# Validation Loss = 14.220
# Channel 37V, Epoch=3, batch = 27000 of 32384, loss=2.363, LR=0.0006545084971874737
# Validation Loss = 16.881
# Channel 37V, Epoch=3, batch = 28000 of 32384, loss=2.159, LR=0.0006545084971874737
# Validation Loss = 18.117
# Channel 37V, Epoch=3, batch = 29000 of 32384, loss=2.057, LR=0.0006545084971874737
# Validation Loss = 13.472
# Channel 37V, Epoch=3, batch = 30000 of 32384, loss=2.559, LR=0.0006545084971874737
# Validation Loss = 5.035
# Channel 37V, Epoch=3, batch = 31000 of 32384, loss=2.351, LR=0.0006545084971874737
# Validation Loss = 9.516
# Channel 37V, Epoch=3, batch = 32000 of 32384, loss=2.923, LR=0.0006545084971874737
# Validation Loss = 12.006
# Channel 37V, Epoch=4, batch = 0 of 32384, loss=2.374, LR=0.00034549150281252633
# Validation Loss = 17.037
# Channel 37V, Epoch=4, batch = 1000 of 32384, loss=2.224, LR=0.00034549150281252633
# Validation Loss = 12.116
# Channel 37V, Epoch=4, batch = 2000 of 32384, loss=2.297, LR=0.00034549150281252633
# Validation Loss = 14.064
# Channel 37V, Epoch=4, batch = 3000 of 32384, loss=2.263, LR=0.00034549150281252633
# Validation Loss = 17.699
# Channel 37V, Epoch=4, batch = 4000 of 32384, loss=2.607, LR=0.00034549150281252633
# Validation Loss = 15.751
# Channel 37V, Epoch=4, batch = 5000 of 32384, loss=2.206, LR=0.00034549150281252633
# Validation Loss = 12.539
# Channel 37V, Epoch=4, batch = 6000 of 32384, loss=2.301, LR=0.00034549150281252633
# Validation Loss = 13.498
# Channel 37V, Epoch=4, batch = 7000 of 32384, loss=2.399, LR=0.00034549150281252633
# Validation Loss = 13.941
# Channel 37V, Epoch=4, batch = 8000 of 32384, loss=2.334, LR=0.00034549150281252633
# Validation Loss = 9.316
# Channel 37V, Epoch=4, batch = 9000 of 32384, loss=1.995, LR=0.00034549150281252633
# Validation Loss = 21.948
# Channel 37V, Epoch=4, batch = 10000 of 32384, loss=2.242, LR=0.00034549150281252633
# Validation Loss = 10.247
# Channel 37V, Epoch=4, batch = 11000 of 32384, loss=2.903, LR=0.00034549150281252633
# Validation Loss = 13.059
# Channel 37V, Epoch=4, batch = 12000 of 32384, loss=2.175, LR=0.00034549150281252633
# Validation Loss = 18.798
# Channel 37V, Epoch=4, batch = 13000 of 32384, loss=2.413, LR=0.00034549150281252633
# Validation Loss = 36.792
# Channel 37V, Epoch=4, batch = 14000 of 32384, loss=2.400, LR=0.00034549150281252633
# Validation Loss = 9.016
# Channel 37V, Epoch=4, batch = 15000 of 32384, loss=2.101, LR=0.00034549150281252633
# Validation Loss = 13.661
# Channel 37V, Epoch=4, batch = 16000 of 32384, loss=2.442, LR=0.00034549150281252633
# Validation Loss = 12.763
# Channel 37V, Epoch=4, batch = 17000 of 32384, loss=2.040, LR=0.00034549150281252633
# Validation Loss = 16.559
# Channel 37V, Epoch=4, batch = 18000 of 32384, loss=2.006, LR=0.00034549150281252633
# Validation Loss = 20.231
# Channel 37V, Epoch=4, batch = 19000 of 32384, loss=2.441, LR=0.00034549150281252633
# Validation Loss = 17.667
# Channel 37V, Epoch=4, batch = 20000 of 32384, loss=2.706, LR=0.00034549150281252633
# Validation Loss = 11.247
# Channel 37V, Epoch=4, batch = 21000 of 32384, loss=1.976, LR=0.00034549150281252633
# Validation Loss = 17.708
# Channel 37V, Epoch=4, batch = 22000 of 32384, loss=2.392, LR=0.00034549150281252633
# Validation Loss = 14.292
# Channel 37V, Epoch=4, batch = 23000 of 32384, loss=2.529, LR=0.00034549150281252633
# Validation Loss = 9.565
# Channel 37V, Epoch=4, batch = 24000 of 32384, loss=2.186, LR=0.00034549150281252633
# Validation Loss = 9.772
# Channel 37V, Epoch=4, batch = 25000 of 32384, loss=2.230, LR=0.00034549150281252633
# Validation Loss = 13.169
# Channel 37V, Epoch=4, batch = 26000 of 32384, loss=2.030, LR=0.00034549150281252633
# Validation Loss = 12.726
# Channel 37V, Epoch=4, batch = 27000 of 32384, loss=1.976, LR=0.00034549150281252633
# Validation Loss = 12.005
# Channel 37V, Epoch=4, batch = 28000 of 32384, loss=2.088, LR=0.00034549150281252633
# Validation Loss = 17.529
# Channel 37V, Epoch=4, batch = 29000 of 32384, loss=2.448, LR=0.00034549150281252633
# Validation Loss = 9.742
# Channel 37V, Epoch=4, batch = 30000 of 32384, loss=2.604, LR=0.00034549150281252633
# Validation Loss = 9.390
# Channel 37V, Epoch=4, batch = 31000 of 32384, loss=1.982, LR=0.00034549150281252633
# Validation Loss = 19.056
# Channel 37V, Epoch=4, batch = 32000 of 32384, loss=2.418, LR=0.00034549150281252633
# Validation Loss = 13.374
# Channel 37V, Epoch=5, batch = 0 of 32384, loss=2.253, LR=9.549150281252633e-05
# Validation Loss = 15.018
# Channel 37V, Epoch=5, batch = 1000 of 32384, loss=2.534, LR=9.549150281252633e-05
# Validation Loss = 15.076
# Channel 37V, Epoch=5, batch = 2000 of 32384, loss=2.661, LR=9.549150281252633e-05
# Validation Loss = 16.412
# Channel 37V, Epoch=5, batch = 3000 of 32384, loss=1.934, LR=9.549150281252633e-05
# Validation Loss = 16.322
# Channel 37V, Epoch=5, batch = 4000 of 32384, loss=2.400, LR=9.549150281252633e-05
# Validation Loss = 10.797
# Channel 37V, Epoch=5, batch = 5000 of 32384, loss=2.199, LR=9.549150281252633e-05
# Validation Loss = 13.266
# Channel 37V, Epoch=5, batch = 6000 of 32384, loss=2.281, LR=9.549150281252633e-05
# Validation Loss = 15.054
# Channel 37V, Epoch=5, batch = 7000 of 32384, loss=2.265, LR=9.549150281252633e-05
# Validation Loss = 16.501
# Channel 37V, Epoch=5, batch = 8000 of 32384, loss=1.887, LR=9.549150281252633e-05
# Validation Loss = 15.902
# Channel 37V, Epoch=5, batch = 9000 of 32384, loss=2.574, LR=9.549150281252633e-05
# Validation Loss = 15.197
# Channel 37V, Epoch=5, batch = 10000 of 32384, loss=2.167, LR=9.549150281252633e-05
# Validation Loss = 14.421
# Channel 37V, Epoch=5, batch = 11000 of 32384, loss=2.374, LR=9.549150281252633e-05
# Validation Loss = 17.248
# Channel 37V, Epoch=5, batch = 12000 of 32384, loss=2.122, LR=9.549150281252633e-05
# Validation Loss = 13.235
# Channel 37V, Epoch=5, batch = 13000 of 32384, loss=2.162, LR=9.549150281252633e-05
# Validation Loss = 14.198
# Channel 37V, Epoch=5, batch = 14000 of 32384, loss=1.835, LR=9.549150281252633e-05
# Validation Loss = 15.122
# Channel 37V, Epoch=5, batch = 15000 of 32384, loss=1.997, LR=9.549150281252633e-05
# Validation Loss = 13.488
# Channel 37V, Epoch=5, batch = 16000 of 32384, loss=2.196, LR=9.549150281252633e-05
# Validation Loss = 14.968
# Channel 37V, Epoch=5, batch = 17000 of 32384, loss=2.161, LR=9.549150281252633e-05
# Validation Loss = 12.223
# Channel 37V, Epoch=5, batch = 18000 of 32384, loss=2.258, LR=9.549150281252633e-05
# Validation Loss = 15.259
# Channel 37V, Epoch=5, batch = 19000 of 32384, loss=2.198, LR=9.549150281252633e-05
# Validation Loss = 13.884
# Channel 37V, Epoch=5, batch = 20000 of 32384, loss=1.930, LR=9.549150281252633e-05
# Validation Loss = 15.437
# Channel 37V, Epoch=5, batch = 21000 of 32384, loss=2.071, LR=9.549150281252633e-05
# Validation Loss = 14.369
# Channel 37V, Epoch=5, batch = 22000 of 32384, loss=2.243, LR=9.549150281252633e-05
# Validation Loss = 15.897
# Channel 37V, Epoch=5, batch = 23000 of 32384, loss=2.336, LR=9.549150281252633e-05
# Validation Loss = 12.972
# Channel 37V, Epoch=5, batch = 24000 of 32384, loss=1.874, LR=9.549150281252633e-05
# Validation Loss = 12.316
# Channel 37V, Epoch=5, batch = 25000 of 32384, loss=2.162, LR=9.549150281252633e-05
# Validation Loss = 15.298
# Channel 37V, Epoch=5, batch = 26000 of 32384, loss=2.438, LR=9.549150281252633e-05
# Validation Loss = 13.404
# Channel 37V, Epoch=5, batch = 27000 of 32384, loss=2.051, LR=9.549150281252633e-05
# Validation Loss = 15.361
# Channel 37V, Epoch=5, batch = 28000 of 32384, loss=2.018, LR=9.549150281252633e-05
# Validation Loss = 16.974
# Channel 37V, Epoch=5, batch = 29000 of 32384, loss=2.244, LR=9.549150281252633e-05
# Validation Loss = 12.502
# Channel 37V, Epoch=5, batch = 30000 of 32384, loss=1.940, LR=9.549150281252633e-05
# Validation Loss = 15.279
# Channel 37V, Epoch=5, batch = 31000 of 32384, loss=2.136, LR=9.549150281252633e-05
# Validation Loss = 16.052
# Channel 37V, Epoch=5, batch = 32000 of 32384, loss=1.859, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 12.007
# Channel 37V, Epoch=1, batch = 0 of 32384, loss=2.327, LR=0.001
# Validation Loss = 22.648
# Channel 37V, Epoch=1, batch = 1000 of 32384, loss=3.314, LR=0.001
# Validation Loss = 12.558
# Channel 37V, Epoch=1, batch = 2000 of 32384, loss=3.197, LR=0.001
# Validation Loss = 19.733
# Channel 37V, Epoch=1, batch = 3000 of 32384, loss=2.903, LR=0.001
# Validation Loss = 15.425
# Channel 37V, Epoch=1, batch = 4000 of 32384, loss=2.665, LR=0.001
# Validation Loss = 33.358
# Channel 37V, Epoch=1, batch = 5000 of 32384, loss=3.341, LR=0.001
# Validation Loss = 12.561
# Channel 37V, Epoch=1, batch = 6000 of 32384, loss=2.187, LR=0.001
# Validation Loss = 20.424
# Channel 37V, Epoch=1, batch = 7000 of 32384, loss=2.541, LR=0.001
# Validation Loss = 21.760
# Channel 37V, Epoch=1, batch = 8000 of 32384, loss=3.614, LR=0.001
# Validation Loss = 20.677
# Channel 37V, Epoch=1, batch = 9000 of 32384, loss=2.503, LR=0.001
# Validation Loss = 13.413
# Channel 37V, Epoch=1, batch = 10000 of 32384, loss=2.331, LR=0.001
# Validation Loss = 31.006
# Channel 37V, Epoch=1, batch = 11000 of 32384, loss=2.800, LR=0.001
# Validation Loss = 22.152
# Channel 37V, Epoch=1, batch = 12000 of 32384, loss=2.755, LR=0.001
# Validation Loss = 25.451
# Channel 37V, Epoch=1, batch = 13000 of 32384, loss=2.610, LR=0.001
# Validation Loss = 19.201
# Channel 37V, Epoch=1, batch = 14000 of 32384, loss=2.441, LR=0.001
# Validation Loss = 17.367
# Channel 37V, Epoch=1, batch = 15000 of 32384, loss=2.289, LR=0.001
# Validation Loss = 13.783
# Channel 37V, Epoch=1, batch = 16000 of 32384, loss=2.957, LR=0.001
# Validation Loss = 19.217
# Channel 37V, Epoch=1, batch = 17000 of 32384, loss=2.187, LR=0.001
# Validation Loss = 24.139
# Channel 37V, Epoch=1, batch = 18000 of 32384, loss=2.196, LR=0.001
# Validation Loss = 19.212
# Channel 37V, Epoch=1, batch = 19000 of 32384, loss=2.862, LR=0.001
# Validation Loss = 26.444
# Channel 37V, Epoch=1, batch = 20000 of 32384, loss=2.744, LR=0.001
# Validation Loss = 20.325
# Channel 37V, Epoch=1, batch = 21000 of 32384, loss=2.132, LR=0.001
# Validation Loss = 16.553
# Channel 37V, Epoch=1, batch = 22000 of 32384, loss=2.414, LR=0.001
# Validation Loss = 21.275
# Channel 37V, Epoch=1, batch = 23000 of 32384, loss=2.661, LR=0.001
# Validation Loss = 41.274
# Channel 37V, Epoch=1, batch = 24000 of 32384, loss=2.430, LR=0.001
# Validation Loss = 37.789
# Channel 37V, Epoch=1, batch = 25000 of 32384, loss=3.464, LR=0.001
# Validation Loss = 22.043
# Channel 37V, Epoch=1, batch = 26000 of 32384, loss=2.377, LR=0.001
# Validation Loss = 10.236
# Channel 37V, Epoch=1, batch = 27000 of 32384, loss=2.368, LR=0.001
# Validation Loss = 12.136
# Channel 37V, Epoch=1, batch = 28000 of 32384, loss=2.489, LR=0.001
# Validation Loss = 31.042
# Channel 37V, Epoch=1, batch = 29000 of 32384, loss=3.347, LR=0.001
# Validation Loss = 9.586
# Channel 37V, Epoch=1, batch = 30000 of 32384, loss=2.739, LR=0.001
# Validation Loss = 20.103
# Channel 37V, Epoch=1, batch = 31000 of 32384, loss=2.159, LR=0.001
# Validation Loss = 30.797
# Channel 37V, Epoch=1, batch = 32000 of 32384, loss=2.895, LR=0.001
# Validation Loss = 14.797
# Channel 37V, Epoch=2, batch = 0 of 32384, loss=2.098, LR=0.0009755282581475768
# Validation Loss = 15.876
# Channel 37V, Epoch=2, batch = 1000 of 32384, loss=2.434, LR=0.0009755282581475768
# Validation Loss = 16.602
# Channel 37V, Epoch=2, batch = 2000 of 32384, loss=2.334, LR=0.0009755282581475768
# Validation Loss = 36.670
# Channel 37V, Epoch=2, batch = 3000 of 32384, loss=3.845, LR=0.0009755282581475768
# Validation Loss = 22.776
# Channel 37V, Epoch=2, batch = 4000 of 32384, loss=2.103, LR=0.0009755282581475768
# Validation Loss = 25.855
# Channel 37V, Epoch=2, batch = 5000 of 32384, loss=2.614, LR=0.0009755282581475768
# Validation Loss = 19.637
# Channel 37V, Epoch=2, batch = 6000 of 32384, loss=2.215, LR=0.0009755282581475768
# Validation Loss = 11.851
# Channel 37V, Epoch=2, batch = 7000 of 32384, loss=2.654, LR=0.0009755282581475768
# Validation Loss = 41.150
# Channel 37V, Epoch=2, batch = 8000 of 32384, loss=3.724, LR=0.0009755282581475768
# Validation Loss = 21.320
# Channel 37V, Epoch=2, batch = 9000 of 32384, loss=2.935, LR=0.0009755282581475768
# Validation Loss = 17.230
# Channel 37V, Epoch=2, batch = 10000 of 32384, loss=2.150, LR=0.0009755282581475768
# Validation Loss = 24.694
# Channel 37V, Epoch=2, batch = 11000 of 32384, loss=3.015, LR=0.0009755282581475768
# Validation Loss = 17.660
# Channel 37V, Epoch=2, batch = 12000 of 32384, loss=2.336, LR=0.0009755282581475768
# Validation Loss = 23.283
# Channel 37V, Epoch=2, batch = 13000 of 32384, loss=2.275, LR=0.0009755282581475768
# Validation Loss = 25.905
# Channel 37V, Epoch=2, batch = 14000 of 32384, loss=2.572, LR=0.0009755282581475768
# Validation Loss = 13.081
# Channel 37V, Epoch=2, batch = 15000 of 32384, loss=2.375, LR=0.0009755282581475768
# Validation Loss = 13.683
# Channel 37V, Epoch=2, batch = 16000 of 32384, loss=2.360, LR=0.0009755282581475768
# Validation Loss = 24.376
# Channel 37V, Epoch=2, batch = 17000 of 32384, loss=2.268, LR=0.0009755282581475768
# Validation Loss = 23.167
# Channel 37V, Epoch=2, batch = 18000 of 32384, loss=2.656, LR=0.0009755282581475768
# Validation Loss = 12.458
# Channel 37V, Epoch=2, batch = 19000 of 32384, loss=3.539, LR=0.0009755282581475768
# Validation Loss = 15.015
# Channel 37V, Epoch=2, batch = 20000 of 32384, loss=2.466, LR=0.0009755282581475768
# Validation Loss = 17.283
# Channel 37V, Epoch=2, batch = 21000 of 32384, loss=2.413, LR=0.0009755282581475768
# Validation Loss = 14.464
# Channel 37V, Epoch=2, batch = 22000 of 32384, loss=2.269, LR=0.0009755282581475768
# Validation Loss = 7.565
# Channel 37V, Epoch=2, batch = 23000 of 32384, loss=3.054, LR=0.0009755282581475768
# Validation Loss = 15.292
# Channel 37V, Epoch=2, batch = 24000 of 32384, loss=2.281, LR=0.0009755282581475768
# Validation Loss = 12.653
# Channel 37V, Epoch=2, batch = 25000 of 32384, loss=2.489, LR=0.0009755282581475768
# Validation Loss = 13.057
# Channel 37V, Epoch=2, batch = 26000 of 32384, loss=2.680, LR=0.0009755282581475768
# Validation Loss = 25.959
# Channel 37V, Epoch=2, batch = 27000 of 32384, loss=2.671, LR=0.0009755282581475768
# Validation Loss = 17.015
# Channel 37V, Epoch=2, batch = 28000 of 32384, loss=1.967, LR=0.0009755282581475768
# Validation Loss = 19.668
# Channel 37V, Epoch=2, batch = 29000 of 32384, loss=2.029, LR=0.0009755282581475768
# Validation Loss = 21.208
# Channel 37V, Epoch=2, batch = 30000 of 32384, loss=2.137, LR=0.0009755282581475768
# Validation Loss = 25.456
# Channel 37V, Epoch=2, batch = 31000 of 32384, loss=2.437, LR=0.0009755282581475768
# Validation Loss = 17.213
# Channel 37V, Epoch=2, batch = 32000 of 32384, loss=2.599, LR=0.0009755282581475768
# Validation Loss = 15.275
# Channel 37V, Epoch=3, batch = 0 of 32384, loss=1.896, LR=0.0009045084971874736
# Validation Loss = 15.909
# Channel 37V, Epoch=3, batch = 1000 of 32384, loss=2.291, LR=0.0009045084971874736
# Validation Loss = 12.122
# Channel 37V, Epoch=3, batch = 2000 of 32384, loss=2.262, LR=0.0009045084971874736
# Validation Loss = 12.456
# Channel 37V, Epoch=3, batch = 3000 of 32384, loss=2.237, LR=0.0009045084971874736
# Validation Loss = 17.094
# Channel 37V, Epoch=3, batch = 4000 of 32384, loss=2.468, LR=0.0009045084971874736
# Validation Loss = 4.681
# Channel 37V, Epoch=3, batch = 5000 of 32384, loss=3.516, LR=0.0009045084971874736
# Validation Loss = 17.772
# Channel 37V, Epoch=3, batch = 6000 of 32384, loss=1.886, LR=0.0009045084971874736
# Validation Loss = 17.476
# Channel 37V, Epoch=3, batch = 7000 of 32384, loss=2.263, LR=0.0009045084971874736
# Validation Loss = 22.017
# Channel 37V, Epoch=3, batch = 8000 of 32384, loss=2.157, LR=0.0009045084971874736
# Validation Loss = 24.127
# Channel 37V, Epoch=3, batch = 9000 of 32384, loss=2.433, LR=0.0009045084971874736
# Validation Loss = 18.296
# Channel 37V, Epoch=3, batch = 10000 of 32384, loss=2.138, LR=0.0009045084971874736
# Validation Loss = 16.473
# Channel 37V, Epoch=3, batch = 11000 of 32384, loss=2.145, LR=0.0009045084971874736
# Validation Loss = 11.957
# Channel 37V, Epoch=3, batch = 12000 of 32384, loss=1.992, LR=0.0009045084971874736
# Validation Loss = 19.943
# Channel 37V, Epoch=3, batch = 13000 of 32384, loss=2.055, LR=0.0009045084971874736
# Validation Loss = 23.101
# Channel 37V, Epoch=3, batch = 14000 of 32384, loss=2.317, LR=0.0009045084971874736
# Validation Loss = 17.916
# Channel 37V, Epoch=3, batch = 15000 of 32384, loss=2.111, LR=0.0009045084971874736
# Validation Loss = 23.892
# Channel 37V, Epoch=3, batch = 16000 of 32384, loss=2.592, LR=0.0009045084971874736
# Validation Loss = 11.655
# Channel 37V, Epoch=3, batch = 17000 of 32384, loss=2.312, LR=0.0009045084971874736
# Validation Loss = 18.355
# Channel 37V, Epoch=3, batch = 18000 of 32384, loss=2.255, LR=0.0009045084971874736
# Validation Loss = 20.843
# Channel 37V, Epoch=3, batch = 19000 of 32384, loss=2.062, LR=0.0009045084971874736
# Validation Loss = 21.355
# Channel 37V, Epoch=3, batch = 20000 of 32384, loss=2.505, LR=0.0009045084971874736
# Validation Loss = 24.259
# Channel 37V, Epoch=3, batch = 21000 of 32384, loss=2.464, LR=0.0009045084971874736
# Validation Loss = 23.833
# Channel 37V, Epoch=3, batch = 22000 of 32384, loss=2.930, LR=0.0009045084971874736
# Validation Loss = 17.377
# Channel 37V, Epoch=3, batch = 23000 of 32384, loss=2.193, LR=0.0009045084971874736
# Validation Loss = 14.491
# Channel 37V, Epoch=3, batch = 24000 of 32384, loss=2.235, LR=0.0009045084971874736
# Validation Loss = 12.543
# Channel 37V, Epoch=3, batch = 25000 of 32384, loss=2.100, LR=0.0009045084971874736
# Validation Loss = 15.198
# Channel 37V, Epoch=3, batch = 26000 of 32384, loss=2.173, LR=0.0009045084971874736
# Validation Loss = 32.908
# Channel 37V, Epoch=3, batch = 27000 of 32384, loss=3.369, LR=0.0009045084971874736
# Validation Loss = 29.240
# Channel 37V, Epoch=3, batch = 28000 of 32384, loss=2.644, LR=0.0009045084971874736
# Validation Loss = 16.110
# Channel 37V, Epoch=3, batch = 29000 of 32384, loss=1.974, LR=0.0009045084971874736
# Validation Loss = 17.827
# Channel 37V, Epoch=3, batch = 30000 of 32384, loss=2.404, LR=0.0009045084971874736
# Validation Loss = 22.043
# Channel 37V, Epoch=3, batch = 31000 of 32384, loss=1.969, LR=0.0009045084971874736
# Validation Loss = 21.556
# Channel 37V, Epoch=3, batch = 32000 of 32384, loss=1.933, LR=0.0009045084971874736
# Validation Loss = 25.123
# Channel 37V, Epoch=4, batch = 0 of 32384, loss=2.270, LR=0.0007938926261462366
# Validation Loss = 16.665
# Channel 37V, Epoch=4, batch = 1000 of 32384, loss=1.899, LR=0.0007938926261462366
# Validation Loss = 16.863
# Channel 37V, Epoch=4, batch = 2000 of 32384, loss=2.360, LR=0.0007938926261462366
# Validation Loss = 20.980
# Channel 37V, Epoch=4, batch = 3000 of 32384, loss=1.997, LR=0.0007938926261462366
# Validation Loss = 20.011
# Channel 37V, Epoch=4, batch = 4000 of 32384, loss=2.028, LR=0.0007938926261462366
# Validation Loss = 15.222
# Channel 37V, Epoch=4, batch = 5000 of 32384, loss=2.466, LR=0.0007938926261462366
# Validation Loss = 16.830
# Channel 37V, Epoch=4, batch = 6000 of 32384, loss=2.732, LR=0.0007938926261462366
# Validation Loss = 16.730
# Channel 37V, Epoch=4, batch = 7000 of 32384, loss=2.084, LR=0.0007938926261462366
# Validation Loss = 15.604
# Channel 37V, Epoch=4, batch = 8000 of 32384, loss=2.404, LR=0.0007938926261462366
# Validation Loss = 16.367
# Channel 37V, Epoch=4, batch = 9000 of 32384, loss=2.415, LR=0.0007938926261462366
# Validation Loss = 24.272
# Channel 37V, Epoch=4, batch = 10000 of 32384, loss=2.339, LR=0.0007938926261462366
# Validation Loss = 13.503
# Channel 37V, Epoch=4, batch = 11000 of 32384, loss=2.180, LR=0.0007938926261462366
# Validation Loss = 23.843
# Channel 37V, Epoch=4, batch = 12000 of 32384, loss=2.519, LR=0.0007938926261462366
# Validation Loss = 16.383
# Channel 37V, Epoch=4, batch = 13000 of 32384, loss=2.179, LR=0.0007938926261462366
# Validation Loss = 14.953
# Channel 37V, Epoch=4, batch = 14000 of 32384, loss=2.279, LR=0.0007938926261462366
# Validation Loss = 17.596
# Channel 37V, Epoch=4, batch = 15000 of 32384, loss=1.877, LR=0.0007938926261462366
# Validation Loss = 23.186
# Channel 37V, Epoch=4, batch = 16000 of 32384, loss=2.229, LR=0.0007938926261462366
# Validation Loss = 17.679
# Channel 37V, Epoch=4, batch = 17000 of 32384, loss=2.032, LR=0.0007938926261462366
# Validation Loss = 13.406
# Channel 37V, Epoch=4, batch = 18000 of 32384, loss=1.919, LR=0.0007938926261462366
# Validation Loss = 12.136
# Channel 37V, Epoch=4, batch = 19000 of 32384, loss=1.957, LR=0.0007938926261462366
# Validation Loss = 17.143
# Channel 37V, Epoch=4, batch = 20000 of 32384, loss=2.323, LR=0.0007938926261462366
# Validation Loss = 20.176
# Channel 37V, Epoch=4, batch = 21000 of 32384, loss=1.892, LR=0.0007938926261462366
# Validation Loss = 7.649
# Channel 37V, Epoch=4, batch = 22000 of 32384, loss=2.479, LR=0.0007938926261462366
# Validation Loss = 18.552
# Channel 37V, Epoch=4, batch = 23000 of 32384, loss=2.218, LR=0.0007938926261462366
# Validation Loss = 24.101
# Channel 37V, Epoch=4, batch = 24000 of 32384, loss=2.295, LR=0.0007938926261462366
# Validation Loss = 26.326
# Channel 37V, Epoch=4, batch = 25000 of 32384, loss=3.458, LR=0.0007938926261462366
# Validation Loss = 20.361
# Channel 37V, Epoch=4, batch = 26000 of 32384, loss=1.918, LR=0.0007938926261462366
# Validation Loss = 4.780
# Channel 37V, Epoch=4, batch = 27000 of 32384, loss=2.001, LR=0.0007938926261462366
# Validation Loss = 13.710
# Channel 37V, Epoch=4, batch = 28000 of 32384, loss=1.933, LR=0.0007938926261462366
# Validation Loss = 16.095
# Channel 37V, Epoch=4, batch = 29000 of 32384, loss=2.418, LR=0.0007938926261462366
# Validation Loss = 21.038
# Channel 37V, Epoch=4, batch = 30000 of 32384, loss=2.082, LR=0.0007938926261462366
# Validation Loss = 15.774
# Channel 37V, Epoch=4, batch = 31000 of 32384, loss=2.109, LR=0.0007938926261462366
# Validation Loss = 15.218
# Channel 37V, Epoch=4, batch = 32000 of 32384, loss=2.299, LR=0.0007938926261462366
# Validation Loss = 7.702
# Channel 37V, Epoch=5, batch = 0 of 32384, loss=2.111, LR=0.0006545084971874737
# Validation Loss = 16.178
# Channel 37V, Epoch=5, batch = 1000 of 32384, loss=2.282, LR=0.0006545084971874737
# Validation Loss = 16.677
# Channel 37V, Epoch=5, batch = 2000 of 32384, loss=2.164, LR=0.0006545084971874737
# Validation Loss = 11.639
# Channel 37V, Epoch=5, batch = 3000 of 32384, loss=2.417, LR=0.0006545084971874737
# Validation Loss = 11.918
# Channel 37V, Epoch=5, batch = 4000 of 32384, loss=2.124, LR=0.0006545084971874737
# Validation Loss = 7.507
# Channel 37V, Epoch=5, batch = 5000 of 32384, loss=2.084, LR=0.0006545084971874737
# Validation Loss = 23.185
# Channel 37V, Epoch=5, batch = 6000 of 32384, loss=2.422, LR=0.0006545084971874737
# Validation Loss = 22.248
# Channel 37V, Epoch=5, batch = 7000 of 32384, loss=1.866, LR=0.0006545084971874737
# Validation Loss = 14.920
# Channel 37V, Epoch=5, batch = 8000 of 32384, loss=2.400, LR=0.0006545084971874737
# Validation Loss = 18.437
# Channel 37V, Epoch=5, batch = 9000 of 32384, loss=2.255, LR=0.0006545084971874737
# Validation Loss = 15.101
# Channel 37V, Epoch=5, batch = 10000 of 32384, loss=2.228, LR=0.0006545084971874737
# Validation Loss = 15.260
# Channel 37V, Epoch=5, batch = 11000 of 32384, loss=1.937, LR=0.0006545084971874737
# Validation Loss = 15.066
# Channel 37V, Epoch=5, batch = 12000 of 32384, loss=2.572, LR=0.0006545084971874737
# Validation Loss = 9.246
# Channel 37V, Epoch=5, batch = 13000 of 32384, loss=1.940, LR=0.0006545084971874737
# Validation Loss = 14.814
# Channel 37V, Epoch=5, batch = 14000 of 32384, loss=2.206, LR=0.0006545084971874737
# Validation Loss = 14.261
# Channel 37V, Epoch=5, batch = 15000 of 32384, loss=2.061, LR=0.0006545084971874737
# Validation Loss = 13.821
# Channel 37V, Epoch=5, batch = 16000 of 32384, loss=1.907, LR=0.0006545084971874737
# Validation Loss = 20.603
# Channel 37V, Epoch=5, batch = 17000 of 32384, loss=2.208, LR=0.0006545084971874737
# Validation Loss = 17.534
# Channel 37V, Epoch=5, batch = 18000 of 32384, loss=2.223, LR=0.0006545084971874737
# Validation Loss = 14.514
# Channel 37V, Epoch=5, batch = 19000 of 32384, loss=2.153, LR=0.0006545084971874737
# Validation Loss = 13.447
# Channel 37V, Epoch=5, batch = 20000 of 32384, loss=2.124, LR=0.0006545084971874737
# Validation Loss = 20.396
# Channel 37V, Epoch=5, batch = 21000 of 32384, loss=1.932, LR=0.0006545084971874737
# Validation Loss = 13.623
# Channel 37V, Epoch=5, batch = 22000 of 32384, loss=2.429, LR=0.0006545084971874737
# Validation Loss = 23.202
# Channel 37V, Epoch=5, batch = 23000 of 32384, loss=2.362, LR=0.0006545084971874737
# Validation Loss = 15.869
# Channel 37V, Epoch=5, batch = 24000 of 32384, loss=2.045, LR=0.0006545084971874737
# Validation Loss = 14.755
# Channel 37V, Epoch=5, batch = 25000 of 32384, loss=1.978, LR=0.0006545084971874737
# Validation Loss = 11.774
# Channel 37V, Epoch=5, batch = 26000 of 32384, loss=1.963, LR=0.0006545084971874737
# Validation Loss = 12.059
# Channel 37V, Epoch=5, batch = 27000 of 32384, loss=1.965, LR=0.0006545084971874737
# Validation Loss = 7.263
# Channel 37V, Epoch=5, batch = 28000 of 32384, loss=1.982, LR=0.0006545084971874737
# Validation Loss = 18.614
# Channel 37V, Epoch=5, batch = 29000 of 32384, loss=1.992, LR=0.0006545084971874737
# Validation Loss = 19.034
# Channel 37V, Epoch=5, batch = 30000 of 32384, loss=2.132, LR=0.0006545084971874737
# Validation Loss = 15.831
# Channel 37V, Epoch=5, batch = 31000 of 32384, loss=2.341, LR=0.0006545084971874737
# Validation Loss = 20.095
# Channel 37V, Epoch=5, batch = 32000 of 32384, loss=2.308, LR=0.0006545084971874737
# Validation Loss = 16.601
# Channel 37V, Epoch=6, batch = 0 of 32384, loss=1.997, LR=0.0005
# Validation Loss = 17.576
# Channel 37V, Epoch=6, batch = 1000 of 32384, loss=2.091, LR=0.0005
# Validation Loss = 13.786
# Channel 37V, Epoch=6, batch = 2000 of 32384, loss=2.114, LR=0.0005
# Validation Loss = 13.343
# Channel 37V, Epoch=6, batch = 3000 of 32384, loss=2.068, LR=0.0005
# Validation Loss = 21.353
# Channel 37V, Epoch=6, batch = 4000 of 32384, loss=1.832, LR=0.0005
# Validation Loss = 12.214
# Channel 37V, Epoch=6, batch = 5000 of 32384, loss=2.004, LR=0.0005
# Validation Loss = 20.390
# Channel 37V, Epoch=6, batch = 6000 of 32384, loss=1.970, LR=0.0005
# Validation Loss = 17.628
# Channel 37V, Epoch=6, batch = 7000 of 32384, loss=2.063, LR=0.0005
# Validation Loss = 16.847
# Channel 37V, Epoch=6, batch = 8000 of 32384, loss=1.785, LR=0.0005
# Validation Loss = 22.516
# Channel 37V, Epoch=6, batch = 9000 of 32384, loss=1.967, LR=0.0005
# Validation Loss = 19.366
# Channel 37V, Epoch=6, batch = 10000 of 32384, loss=2.191, LR=0.0005
# Validation Loss = 17.603
# Channel 37V, Epoch=6, batch = 11000 of 32384, loss=1.931, LR=0.0005
# Validation Loss = 17.106
# Channel 37V, Epoch=6, batch = 12000 of 32384, loss=1.990, LR=0.0005
# Validation Loss = 21.979
# Channel 37V, Epoch=6, batch = 13000 of 32384, loss=2.293, LR=0.0005
# Validation Loss = 17.443
# Channel 37V, Epoch=6, batch = 14000 of 32384, loss=1.723, LR=0.0005
# Validation Loss = 17.198
# Channel 37V, Epoch=6, batch = 15000 of 32384, loss=2.053, LR=0.0005
# Validation Loss = 20.811
# Channel 37V, Epoch=6, batch = 16000 of 32384, loss=2.984, LR=0.0005
# Validation Loss = 13.415
# Channel 37V, Epoch=6, batch = 17000 of 32384, loss=1.926, LR=0.0005
# Validation Loss = 17.355
# Channel 37V, Epoch=6, batch = 18000 of 32384, loss=2.287, LR=0.0005
# Validation Loss = 14.567
# Channel 37V, Epoch=6, batch = 19000 of 32384, loss=2.152, LR=0.0005
# Validation Loss = 13.756
# Channel 37V, Epoch=6, batch = 20000 of 32384, loss=2.097, LR=0.0005
# Validation Loss = 12.940
# Channel 37V, Epoch=6, batch = 21000 of 32384, loss=2.050, LR=0.0005
# Validation Loss = 15.081
# Channel 37V, Epoch=6, batch = 22000 of 32384, loss=2.187, LR=0.0005
# Validation Loss = 15.809
# Channel 37V, Epoch=6, batch = 23000 of 32384, loss=1.810, LR=0.0005
# Validation Loss = 16.018
# Channel 37V, Epoch=6, batch = 24000 of 32384, loss=2.171, LR=0.0005
# Validation Loss = 21.427
# Channel 37V, Epoch=6, batch = 25000 of 32384, loss=2.204, LR=0.0005
# Validation Loss = 8.180
# Channel 37V, Epoch=6, batch = 26000 of 32384, loss=2.153, LR=0.0005
# Validation Loss = 12.169
# Channel 37V, Epoch=6, batch = 27000 of 32384, loss=2.294, LR=0.0005
# Validation Loss = 18.735
# Channel 37V, Epoch=6, batch = 28000 of 32384, loss=2.253, LR=0.0005
# Validation Loss = 16.650
# Channel 37V, Epoch=6, batch = 29000 of 32384, loss=1.921, LR=0.0005
# Validation Loss = 23.352
# Channel 37V, Epoch=6, batch = 30000 of 32384, loss=2.306, LR=0.0005
# Validation Loss = 11.696
# Channel 37V, Epoch=6, batch = 31000 of 32384, loss=2.023, LR=0.0005
# Validation Loss = 8.045
# Channel 37V, Epoch=6, batch = 32000 of 32384, loss=2.274, LR=0.0005
# Validation Loss = 14.136
# Channel 37V, Epoch=7, batch = 0 of 32384, loss=2.253, LR=0.00034549150281252633
# Validation Loss = 17.529
# Channel 37V, Epoch=7, batch = 1000 of 32384, loss=2.058, LR=0.00034549150281252633
# Validation Loss = 16.826
# Channel 37V, Epoch=7, batch = 2000 of 32384, loss=1.809, LR=0.00034549150281252633
# Validation Loss = 13.256
# Channel 37V, Epoch=7, batch = 3000 of 32384, loss=1.961, LR=0.00034549150281252633
# Validation Loss = 11.794
# Channel 37V, Epoch=7, batch = 4000 of 32384, loss=2.599, LR=0.00034549150281252633
# Validation Loss = 14.478
# Channel 37V, Epoch=7, batch = 5000 of 32384, loss=1.940, LR=0.00034549150281252633
# Validation Loss = 8.255
# Channel 37V, Epoch=7, batch = 6000 of 32384, loss=2.237, LR=0.00034549150281252633
# Validation Loss = 16.477
# Channel 37V, Epoch=7, batch = 7000 of 32384, loss=1.955, LR=0.00034549150281252633
# Validation Loss = 13.579
# Channel 37V, Epoch=7, batch = 8000 of 32384, loss=1.961, LR=0.00034549150281252633
# Validation Loss = 8.390
# Channel 37V, Epoch=7, batch = 9000 of 32384, loss=1.790, LR=0.00034549150281252633
# Validation Loss = 17.355
# Channel 37V, Epoch=7, batch = 10000 of 32384, loss=2.109, LR=0.00034549150281252633
# Validation Loss = 10.570
# Channel 37V, Epoch=7, batch = 11000 of 32384, loss=2.100, LR=0.00034549150281252633
# Validation Loss = 19.831
# Channel 37V, Epoch=7, batch = 12000 of 32384, loss=2.087, LR=0.00034549150281252633
# Validation Loss = 14.304
# Channel 37V, Epoch=7, batch = 13000 of 32384, loss=2.330, LR=0.00034549150281252633
# Validation Loss = 18.384
# Channel 37V, Epoch=7, batch = 14000 of 32384, loss=2.130, LR=0.00034549150281252633
# Validation Loss = 16.078
# Channel 37V, Epoch=7, batch = 15000 of 32384, loss=2.049, LR=0.00034549150281252633
# Validation Loss = 13.415
# Channel 37V, Epoch=7, batch = 16000 of 32384, loss=1.765, LR=0.00034549150281252633
# Validation Loss = 20.600
# Channel 37V, Epoch=7, batch = 17000 of 32384, loss=2.243, LR=0.00034549150281252633
# Validation Loss = 7.699
# Channel 37V, Epoch=7, batch = 18000 of 32384, loss=1.989, LR=0.00034549150281252633
# Validation Loss = 14.690
# Channel 37V, Epoch=7, batch = 19000 of 32384, loss=1.786, LR=0.00034549150281252633
# Validation Loss = 10.908
# Channel 37V, Epoch=7, batch = 20000 of 32384, loss=2.066, LR=0.00034549150281252633
# Validation Loss = 10.885
# Channel 37V, Epoch=7, batch = 21000 of 32384, loss=1.851, LR=0.00034549150281252633
# Validation Loss = 22.411
# Channel 37V, Epoch=7, batch = 22000 of 32384, loss=2.343, LR=0.00034549150281252633
# Validation Loss = 15.522
# Channel 37V, Epoch=7, batch = 23000 of 32384, loss=1.874, LR=0.00034549150281252633
# Validation Loss = 9.781
# Channel 37V, Epoch=7, batch = 24000 of 32384, loss=1.927, LR=0.00034549150281252633
# Validation Loss = 11.741
# Channel 37V, Epoch=7, batch = 25000 of 32384, loss=2.177, LR=0.00034549150281252633
# Validation Loss = 13.482
# Channel 37V, Epoch=7, batch = 26000 of 32384, loss=1.971, LR=0.00034549150281252633
# Validation Loss = 17.111
# Channel 37V, Epoch=7, batch = 27000 of 32384, loss=2.038, LR=0.00034549150281252633
# Validation Loss = 17.215
# Channel 37V, Epoch=7, batch = 28000 of 32384, loss=2.067, LR=0.00034549150281252633
# Validation Loss = 23.699
# Channel 37V, Epoch=7, batch = 29000 of 32384, loss=2.060, LR=0.00034549150281252633
# Validation Loss = 13.173
# Channel 37V, Epoch=7, batch = 30000 of 32384, loss=2.327, LR=0.00034549150281252633
# Validation Loss = 18.195
# Channel 37V, Epoch=7, batch = 31000 of 32384, loss=1.942, LR=0.00034549150281252633
# Validation Loss = 13.473
# Channel 37V, Epoch=7, batch = 32000 of 32384, loss=2.477, LR=0.00034549150281252633
# Validation Loss = 13.705
# Channel 37V, Epoch=8, batch = 0 of 32384, loss=1.980, LR=0.0002061073738537635
# Validation Loss = 17.182
# Channel 37V, Epoch=8, batch = 1000 of 32384, loss=1.899, LR=0.0002061073738537635
# Validation Loss = 11.096
# Channel 37V, Epoch=8, batch = 2000 of 32384, loss=1.932, LR=0.0002061073738537635
# Validation Loss = 13.905
# Channel 37V, Epoch=8, batch = 3000 of 32384, loss=2.008, LR=0.0002061073738537635
# Validation Loss = 12.366
# Channel 37V, Epoch=8, batch = 4000 of 32384, loss=2.100, LR=0.0002061073738537635
# Validation Loss = 8.653
# Channel 37V, Epoch=8, batch = 5000 of 32384, loss=1.909, LR=0.0002061073738537635
# Validation Loss = 13.164
# Channel 37V, Epoch=8, batch = 6000 of 32384, loss=1.813, LR=0.0002061073738537635
# Validation Loss = 9.760
# Channel 37V, Epoch=8, batch = 7000 of 32384, loss=1.985, LR=0.0002061073738537635
# Validation Loss = 9.456
# Channel 37V, Epoch=8, batch = 8000 of 32384, loss=1.991, LR=0.0002061073738537635
# Validation Loss = 13.169
# Channel 37V, Epoch=8, batch = 9000 of 32384, loss=1.946, LR=0.0002061073738537635
# Validation Loss = 13.640
# Channel 37V, Epoch=8, batch = 10000 of 32384, loss=2.036, LR=0.0002061073738537635
# Validation Loss = 14.802
# Channel 37V, Epoch=8, batch = 11000 of 32384, loss=1.926, LR=0.0002061073738537635
# Validation Loss = 12.193
# Channel 37V, Epoch=8, batch = 12000 of 32384, loss=2.227, LR=0.0002061073738537635
# Validation Loss = 11.930
# Channel 37V, Epoch=8, batch = 13000 of 32384, loss=2.142, LR=0.0002061073738537635
# Validation Loss = 12.867
# Channel 37V, Epoch=8, batch = 14000 of 32384, loss=2.226, LR=0.0002061073738537635
# Validation Loss = 11.754
# Channel 37V, Epoch=8, batch = 15000 of 32384, loss=2.034, LR=0.0002061073738537635
# Validation Loss = 14.503
# Channel 37V, Epoch=8, batch = 16000 of 32384, loss=1.762, LR=0.0002061073738537635
# Validation Loss = 13.549
# Channel 37V, Epoch=8, batch = 17000 of 32384, loss=1.829, LR=0.0002061073738537635
# Validation Loss = 11.462
# Channel 37V, Epoch=8, batch = 18000 of 32384, loss=1.936, LR=0.0002061073738537635
# Validation Loss = 10.029
# Channel 37V, Epoch=8, batch = 19000 of 32384, loss=2.264, LR=0.0002061073738537635
# Validation Loss = 14.133
# Channel 37V, Epoch=8, batch = 20000 of 32384, loss=1.864, LR=0.0002061073738537635
# Validation Loss = 11.220
# Channel 37V, Epoch=8, batch = 21000 of 32384, loss=1.714, LR=0.0002061073738537635
# Validation Loss = 9.971
# Channel 37V, Epoch=8, batch = 22000 of 32384, loss=2.139, LR=0.0002061073738537635
# Validation Loss = 13.652
# Channel 37V, Epoch=8, batch = 23000 of 32384, loss=2.027, LR=0.0002061073738537635
# Validation Loss = 11.368
# Channel 37V, Epoch=8, batch = 24000 of 32384, loss=2.075, LR=0.0002061073738537635
# Validation Loss = 7.160
# Channel 37V, Epoch=8, batch = 25000 of 32384, loss=2.007, LR=0.0002061073738537635
# Validation Loss = 9.787
# Channel 37V, Epoch=8, batch = 26000 of 32384, loss=1.989, LR=0.0002061073738537635
# Validation Loss = 11.212
# Channel 37V, Epoch=8, batch = 27000 of 32384, loss=1.708, LR=0.0002061073738537635
# Validation Loss = 11.883
# Channel 37V, Epoch=8, batch = 28000 of 32384, loss=1.695, LR=0.0002061073738537635
# Validation Loss = 7.725
# Channel 37V, Epoch=8, batch = 29000 of 32384, loss=1.827, LR=0.0002061073738537635
# Validation Loss = 13.213
# Channel 37V, Epoch=8, batch = 30000 of 32384, loss=2.051, LR=0.0002061073738537635
# Validation Loss = 9.548
# Channel 37H, Epoch=4, batch = 27000 of 32384, loss=3.586, LR=0.00034549150281252633
# Validation Loss = 12.595
# Channel 37H, Epoch=4, batch = 28000 of 32384, loss=3.875, LR=0.00034549150281252633
# Validation Loss = 8.388
# Channel 37H, Epoch=4, batch = 29000 of 32384, loss=3.859, LR=0.00034549150281252633
# Validation Loss = 4.572
# Channel 37H, Epoch=4, batch = 30000 of 32384, loss=3.762, LR=0.00034549150281252633
# Validation Loss = 9.728
# Channel 37H, Epoch=4, batch = 31000 of 32384, loss=3.847, LR=0.00034549150281252633
# Validation Loss = 6.846
# Channel 37H, Epoch=4, batch = 32000 of 32384, loss=3.687, LR=0.00034549150281252633
# Validation Loss = 6.644
# Channel 37H, Epoch=5, batch = 0 of 32384, loss=4.123, LR=9.549150281252633e-05
