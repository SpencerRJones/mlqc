# %%
'''
Creates training data for F17 channel predictor
'''


import numpy as np
import xarray as xr
import glob
from tqdm import tqdm
from util_funcs.L1C import scantime2datetime
from util_funcs import data2xarray, array_funcs
import geography

import sensor_info
import local_functions

satellite = sensor_info.satellite
sensor = sensor_info.sensor

datapath = f'/pdata4/archive/GPM/1Base_{sensor}_V7'

# %%
'''
Satellite: AMSR2

Get data and quality check for training.

nscans: generally around 3900
npixs: 243 and 486

    
Tb array will be set up as follows:
    Tbs =  [m x n], where m is the number of samples and n is the
           number of channels (features)

'''

#Set up a random seed for reproducibility
np.random.seed(12)

#Get a random list of files
file_list = glob.glob(f'{datapath}/*/*/1Base.{satellite}.{sensor}.*.HDF5'); file_list.sort()

#Everything looks good before about 04/2016:
good_files = [ifile for ifile in file_list]

flist = np.random.choice(good_files, size=100)

#Loop through files and get good quality data.
for i, ifile in enumerate(tqdm(flist, desc="Processing Files")):

    #print(f'{i+1} of {len(flist)}, {ifile}')

    data = local_functions.read_amsr2_l1b(ifile)

    #Level 1B doesn't screen for sunglint:
    with xr.open_dataset(ifile, group='S1', decode_timedelta=False) as f:
        glintang = f.Sun_Glint_Angle.values

    lat = data['lat']
    lon = data['lon']
    scantime = data['scantime']
    Tbs = data['Tbs']
    qual = data['qual']

    #Get only good quality data and reshape:
    goodqual = np.all(qual == 0, axis=2)
    all_bad = np.all(goodqual == False)
    if all_bad:
        print('all were bad.')
        continue
    lat = lat[goodqual]
    lon = lon[goodqual]
    scantime = scantime[np.where(goodqual)[0]]
    Tbs = Tbs[goodqual]
    glintang = glintang[goodqual]

    
    #Check for NaNs (shouldn't be any if all good, but I've seen some)
    nonans = local_functions.find_nan_rows(Tbs, return_good=True)
    Tbs = Tbs[nonans]
    lat = lat[nonans]
    lon = lon[nonans]
    scantime = scantime[nonans]
    glintang = glintang[nonans]

    #Final check for sunglint:
    maybeglint = np.logical_and(glintang > 0., glintang < 10.).reshape(-1)
    noglint = ~maybeglint
    Tbs = Tbs[noglint]
    lat = lat[noglint]
    lon = lon[noglint]
    scantime = scantime[noglint]

    #Attach GPROF surface map data to each pixel
    sfctype = local_functions.attach_gpm_sfctype(lat, lon, scantime, sensor=sensor)

    npixs = lat.size

    #Output as NetCDF
    dset = data2xarray(data_vars = [lat, lon, scantime, sfctype, Tbs],
                       var_names = ['latitude', 'longitude', 'scantime', 'sfctype', 'Tbs'],
                       dims = [npixs, sensor_info.nfeatures],
                       dim_names = ['pixels', 'channels'])


    if i == 0:
        training_dataset = dset
    else:
        training_dataset = xr.concat((training_dataset, dset), dim='pixels')

training_dataset.to_netcdf(f'training_data/{satellite}_training_data.nc', engine='netcdf4')
# Out:
# Processing Files:   0%|                                                                                                               | 0/100 [00:00<?, ?it/s]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:   1%|█                                                                                                      | 1/100 [00:11<18:09, 11.01s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:   3%|███                                                                                                    | 3/100 [00:20<09:41,  5.99s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:   4%|████                                                                                                   | 4/100 [00:26<09:31,  5.96s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:   6%|██████▏                                                                                                | 6/100 [00:43<12:04,  7.71s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:   7%|███████▏                                                                                               | 7/100 [00:52<12:29,  8.06s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:   9%|█████████▎                                                                                             | 9/100 [01:13<14:08,  9.33s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  10%|██████████▏                                                                                           | 10/100 [01:20<12:59,  8.66s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  11%|███████████▏                                                                                          | 11/100 [01:26<11:34,  7.80s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  14%|██████████████▎                                                                                       | 14/100 [01:44<09:39,  6.74s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  15%|███████████████▎                                                                                      | 15/100 [01:50<09:13,  6.51s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  16%|████████████████▎                                                                                     | 16/100 [01:59<10:10,  7.27s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:
/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  73%|██████████████████████████████████████████████████████████████████████████▍                           | 73/100 [10:20<05:38, 12.55s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  74%|███████████████████████████████████████████████████████████████████████████▍                          | 74/100 [10:36<05:48, 13.39s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  75%|████████████████████████████████████████████████████████████████████████████▌                         | 75/100 [10:49<05:31, 13.28s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  76%|█████████████████████████████████████████████████████████████████████████████▌                        | 76/100 [11:01<05:15, 13.14s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  77%|██████████████████████████████████████████████████████████████████████████████▌                       | 77/100 [11:15<05:02, 13.15s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  78%|███████████████████████████████████████████████████████████████████████████████▌                      | 78/100 [11:29<04:54, 13.41s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  79%|████████████████████████████████████████████████████████████████████████████████▌                     | 79/100 [11:37<04:09, 11.88s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  80%|█████████████████████████████████████████████████████████████████████████████████▌                    | 80/100 [11:46<03:43, 11.20s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  81%|██████████████████████████████████████████████████████████████████████████████████▌                   | 81/100 [11:58<03:35, 11.34s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  82%|███████████████████████████████████████████████████████████████████████████████████▋                  | 82/100 [12:10<03:26, 11.46s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  83%|████████████████████████████████████████████████████████████████████████████████████▋                 | 83/100 [12:27<03:45, 13.24s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  85%|██████████████████████████████████████████████████████████████████████████████████████▋               | 85/100 [12:49<02:59, 11.97s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  86%|███████████████████████████████████████████████████████████████████████████████████████▋              | 86/100 [13:02<02:53, 12.41s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  87%|████████████████████████████████████████████████████████████████████████████████████████▋             | 87/100 [13:16<02:49, 13.01s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  88%|█████████████████████████████████████████████████████████████████████████████████████████▊            | 88/100 [13:32<02:46, 13.84s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  89%|██████████████████████████████████████████████████████████████████████████████████████████▊           | 89/100 [13:45<02:30, 13.64s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  91%|████████████████████████████████████████████████████████████████████████████████████████████▊         | 91/100 [14:06<01:47, 11.98s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  92%|█████████████████████████████████████████████████████████████████████████████████████████████▊        | 92/100 [14:17<01:32, 11.60s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  93%|██████████████████████████████████████████████████████████████████████████████████████████████▊       | 93/100 [14:27<01:18, 11.17s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  95%|████████████████████████████████████████████████████████████████████████████████████████████████▉     | 95/100 [15:04<01:14, 14.84s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████▉    | 96/100 [15:17<00:58, 14.52s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  97%|██████████████████████████████████████████████████████████████████████████████████████████████████▉   | 97/100 [15:33<00:45, 15.01s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████▉  | 98/100 [15:55<00:34, 17.12s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████▉ | 99/100 [16:06<00:15, 15.05s/it]/edata2/spencer/rfi_prediction/AMSR2/GCOMW1/local_functions.py:54: RuntimeWarning: invalid value encountered in cast
#   qual[:,:,0] = f.Pixel_Data_Quality_6_to_36.values[:,::2]
# Processing Files: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [16:14<00:00,  9.75s/it]

# %%
with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    sfctype = f.sfctype.values

for i in range(19):
    print(f'Number of pixels with surface type {i}: {np.sum(sfctype == i)}')

print(f'Total number of ocean pixels: {np.sum(sfctype == 1)}')
print(f'Total number of nonocean pixels: {np.sum(sfctype > 1)}')
# Out:
# Number of pixels with surface type 0: 0
# Number of pixels with surface type 1: 49181233
# Number of pixels with surface type 2: 9588561
# Number of pixels with surface type 3: 2815932
# Number of pixels with surface type 4: 1478108
# Number of pixels with surface type 5: 1289208
# Number of pixels with surface type 6: 807957
# Number of pixels with surface type 7: 1922185
# Number of pixels with surface type 8: 126717
# Number of pixels with surface type 9: 252573
# Number of pixels with surface type 10: 1727101
# Number of pixels with surface type 11: 8812431
# Number of pixels with surface type 12: 1133003
# Number of pixels with surface type 13: 2227065
# Number of pixels with surface type 14: 1823080
# Number of pixels with surface type 15: 1500855
# Number of pixels with surface type 16: 502277
# Number of pixels with surface type 17: 2985376
# Number of pixels with surface type 18: 1240411
# Total number of ocean pixels: 49181233
# Total number of nonocean pixels: 40232840
