# %% [markdown]
# # Channel Prediction Model for Quality Control
#
# This notebook contains the code and outlines the development of the
# GMI Channel Prediction Neural Network for QC purposes of GMI L1C
# data. The simple Feed-Forward Neural Networks (FFNNs) are trained on
# good quality brightness temperature observation vectors and are
# trained to predict one channel from all the others as predictors.
#
# The end product is a tree of FFNNs, discretized by surface (ocean or
# land), and by channel, since these are fully distinct problems.

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import glob
import torch
from torch import nn
import cartopy.crs as ccrs
from util_funcs.L1C import scantime2datetime
from util_funcs import data2xarray, array_funcs
import geography
from tqdm import tqdm

from dataset_class import dataset
from model_class import channel_predictor
import local_functions
import sensor_info


#General parameters:

satellite = sensor_info.satellite
sensor = sensor_info.sensor

nchans = sensor_info.nchannels
batch_size = 1000
input_size = nchans - 1
hidden_size = 256
output_size = 1

# %%
'''
Function Definitions:
'''

chan_desc = sensor_info.channel_descriptions


def extract_channel(Tb_array, chan):

    '''
    Use in preparing training data.

    Assumes Tb array is [m x n] where m (rows) are samples
    and n (columns) is the number of channels.

    Passing in the channel description splits the data so
    that the specified channel is its own vector y and the
    rest are kept as predictors x.

    Inputs:
        Tb_array    |  ndarray of Tbs
        chan        |  string of channel name
    Outputs:
        x           |  matrix of predictors (other channels)
        y           |  vector of predictands (the missing channel)
        
    '''
    
    chan_desc = np.array(sensor_info.channel_descriptions)


    chan_indx = np.where(chan == chan_desc)[0]

    if np.size(chan_indx) == 0:
        raise ValueError(f'Channel description must be in list {chan_desc}.')

    y = Tb_array[:,chan_indx]
    x = Tb_array[:,np.delete(np.arange(0,len(chan_desc)),chan_indx)]

    return x, y


def train_model(model, nepochs, dataloader, learning_rate=0.001, quiet=False, stage=None, validation_dataloader=None):

    nbatches = len(dataloader)
    
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=nepochs)
    device = None

    if stage:
        print(f'Training stage: {stage}')

    loss_arr    = np.zeros([nbatches,nepochs], dtype='f')
    valloss_arr = np.zeros([nbatches,nepochs], dtype='f')
    
    for epoch in range(nepochs):
        for i, (profs, obs) in enumerate(dataloader):
            if device:
                profs, obs = profs.to(device), obs.to(device)

            if validation_dataloader and i%1000==0:
                valprofs, valobs = next(enumerate(validation_dataloader))[1]
                val_pred = model(valprofs)
                valloss  = criterion(val_pred, valobs)
                print(f'Validation Loss = {valloss.item():.3f}')

            #Forward pass:
            obs_pred = model(profs)
            loss     = criterion(obs_pred, obs)


            #Backward pass:
            optimizer.zero_grad()
            loss.backward()

            #Update neurons:
            optimizer.step()

            loss_arr[i,epoch] = loss.item()
            valloss_arr[i,epoch] = valloss.item()
            
            if not quiet:
                if i%1000 == 0:
                    print(f'Epoch={epoch+1}, batch = {i} of {nbatches}, loss={loss.item():.3f}, LR={scheduler.get_last_lr()[0]}')
        
        scheduler.step()




    return loss_arr, valloss_arr

# %%
'''

GMI CHANNEL PREDICTION MODEL:
    1: Ocean

'''

sfc = [1]

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = np.isin(sfctype, sfc)
    sfcindcs = np.where(correct_sfc)[0]

    Tbs = f.Tbs.values[sfcindcs]

#---Don't shuffle data before splitting
#np.random.seed(40)
#Tbs = array_funcs.shuffle_data(Tbs, axis=0)

if Tbs.shape[0] > 5.0e+06:
    Tbs = Tbs[:5_000_000,:]


print(Tbs.shape)

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train = array_funcs.shuffle_data(Tbs_train, axis=0)
# Out:
# (5000000, 13)

# %%
sensor_info.channel_descriptions[9]
# Out:
# '166V'

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    if ichan < 9: continue

    print(channel)

    x_train = Tbs_train
    y_train = extract_channel(Tbs_train, channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_ocean.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_ocean.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 166V
# Training stage: 1
# Validation Loss = 77910.578
# Epoch=1, batch = 0 of 4000, loss=75825.102, LR=0.001
# Validation Loss = 0.162
# Epoch=1, batch = 1000 of 4000, loss=1.095, LR=0.001
# Validation Loss = 0.009
# Epoch=1, batch = 2000 of 4000, loss=1.632, LR=0.001
# Validation Loss = 0.350
# Epoch=1, batch = 3000 of 4000, loss=1.210, LR=0.001
# Validation Loss = 0.165
# Epoch=2, batch = 0 of 4000, loss=1.261, LR=0.0009045084971874737
# Validation Loss = 0.998
# Epoch=2, batch = 1000 of 4000, loss=1.504, LR=0.0009045084971874737
# Validation Loss = 0.334
# Epoch=2, batch = 2000 of 4000, loss=2.019, LR=0.0009045084971874737
# Validation Loss = 0.268
# Epoch=2, batch = 3000 of 4000, loss=1.017, LR=0.0009045084971874737
# Validation Loss = 2.874
# Epoch=3, batch = 0 of 4000, loss=5.422, LR=0.0006545084971874737
# Validation Loss = 4.352
# Epoch=3, batch = 1000 of 4000, loss=3.768, LR=0.0006545084971874737
# Validation Loss = 0.079
# Epoch=3, batch = 2000 of 4000, loss=0.983, LR=0.0006545084971874737
# Validation Loss = 0.429
# Epoch=3, batch = 3000 of 4000, loss=1.814, LR=0.0006545084971874737
# Validation Loss = 4.014
# Epoch=4, batch = 0 of 4000, loss=3.512, LR=0.00034549150281252633
# Validation Loss = 0.207
# Epoch=4, batch = 1000 of 4000, loss=0.897, LR=0.00034549150281252633
# Validation Loss = 0.115
# Epoch=4, batch = 2000 of 4000, loss=0.931, LR=0.00034549150281252633
# Validation Loss = 0.531
# Epoch=4, batch = 3000 of 4000, loss=1.535, LR=0.00034549150281252633
# Validation Loss = 0.103
# Epoch=5, batch = 0 of 4000, loss=0.909, LR=9.549150281252633e-05
# Validation Loss = 0.000
# Epoch=5, batch = 1000 of 4000, loss=0.815, LR=9.549150281252633e-05
# Validation Loss = 0.012
# Epoch=5, batch = 2000 of 4000, loss=0.823, LR=9.549150281252633e-05
# Validation Loss = 0.115
# Epoch=5, batch = 3000 of 4000, loss=0.988, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.006
# Epoch=1, batch = 0 of 4000, loss=0.840, LR=0.001
# Validation Loss = 0.033
# Epoch=1, batch = 1000 of 4000, loss=1.096, LR=0.001
# Validation Loss = 1.425
# Epoch=1, batch = 2000 of 4000, loss=1.943, LR=0.001
# Validation Loss = 5.092
# Epoch=1, batch = 3000 of 4000, loss=5.404, LR=0.001
# Validation Loss = 1.460
# Epoch=2, batch = 0 of 4000, loss=2.699, LR=0.0009755282581475768
# Validation Loss = 0.368
# Epoch=2, batch = 1000 of 4000, loss=1.130, LR=0.0009755282581475768
# Validation Loss = 0.033
# Epoch=2, batch = 2000 of 4000, loss=0.983, LR=0.0009755282581475768
# Validation Loss = 0.351
# Epoch=2, batch = 3000 of 4000, loss=1.098, LR=0.0009755282581475768
# Validation Loss = 0.063
# Epoch=3, batch = 0 of 4000, loss=0.867, LR=0.0009045084971874736
# Validation Loss = 1.879
# Epoch=3, batch = 1000 of 4000, loss=2.106, LR=0.0009045084971874736
# Validation Loss = 0.183
# Epoch=3, batch = 2000 of 4000, loss=0.906, LR=0.0009045084971874736
# Validation Loss = 0.099
# Epoch=3, batch = 3000 of 4000, loss=1.138, LR=0.0009045084971874736
# Validation Loss = 0.820
# Epoch=4, batch = 0 of 4000, loss=2.240, LR=0.0007938926261462366
# Validation Loss = 0.061
# Epoch=4, batch = 1000 of 4000, loss=0.863, LR=0.0007938926261462366
# Validation Loss = 0.190
# Epoch=4, batch = 2000 of 4000, loss=0.938, LR=0.0007938926261462366
# Validation Loss = 0.656
# Epoch=4, batch = 3000 of 4000, loss=1.783, LR=0.0007938926261462366
# Validation Loss = 1.402
# Epoch=5, batch = 0 of 4000, loss=1.932, LR=0.0006545084971874737
# Validation Loss = 1.028
# Epoch=5, batch = 1000 of 4000, loss=2.285, LR=0.0006545084971874737
# Validation Loss = 0.002
# Epoch=5, batch = 2000 of 4000, loss=0.889, LR=0.0006545084971874737
# Validation Loss = 0.284
# Epoch=5, batch = 3000 of 4000, loss=1.405, LR=0.0006545084971874737
# Validation Loss = 0.103
# Epoch=6, batch = 0 of 4000, loss=0.846, LR=0.0005
# Validation Loss = 0.113
# Epoch=6, batch = 1000 of 4000, loss=1.083, LR=0.0005
# Validation Loss = 0.155
# Epoch=6, batch = 2000 of 4000, loss=1.074, LR=0.0005
# Validation Loss = 0.303
# Epoch=6, batch = 3000 of 4000, loss=1.302, LR=0.0005
# Validation Loss = 0.012
# Epoch=7, batch = 0 of 4000, loss=0.880, LR=0.00034549150281252633
# Validation Loss = 0.014
# Epoch=7, batch = 1000 of 4000, loss=0.862, LR=0.00034549150281252633
# Validation Loss = 0.341
# Epoch=7, batch = 2000 of 4000, loss=0.988, LR=0.00034549150281252633
# Validation Loss = 0.003
# Epoch=7, batch = 3000 of 4000, loss=0.821, LR=0.00034549150281252633
# Validation Loss = 0.035
# Epoch=8, batch = 0 of 4000, loss=0.856, LR=0.0002061073738537635
# Validation Loss = 0.165
# Epoch=8, batch = 1000 of 4000, loss=0.827, LR=0.0002061073738537635
# Validation Loss = 0.089
# Epoch=8, batch = 2000 of 4000, loss=0.818, LR=0.0002061073738537635
# Validation Loss = 0.017
# Epoch=8, batch = 3000 of 4000, loss=0.791, LR=0.0002061073738537635
# Validation Loss = 0.157
# Epoch=9, batch = 0 of 4000, loss=0.869, LR=9.549150281252634e-05
# Validation Loss = 0.048
# Epoch=9, batch = 1000 of 4000, loss=0.767, LR=9.549150281252634e-05
# Validation Loss = 0.044
# Epoch=9, batch = 2000 of 4000, loss=0.823, LR=9.549150281252634e-05
# Validation Loss = 0.007
# Epoch=9, batch = 3000 of 4000, loss=0.817, LR=9.549150281252634e-05
# Validation Loss = 0.008
# Epoch=10, batch = 0 of 4000, loss=0.750, LR=2.4471741852423235e-05
# Validation Loss = 0.065
# Epoch=10, batch = 1000 of 4000, loss=0.844, LR=2.4471741852423235e-05
# Validation Loss = 0.047
# Epoch=10, batch = 2000 of 4000, loss=0.830, LR=2.4471741852423235e-05
# Validation Loss = 0.033
# Epoch=10, batch = 3000 of 4000, loss=0.762, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.020
# Epoch=1, batch = 0 of 4000, loss=0.861, LR=0.001
# Validation Loss = 0.003
# Epoch=1, batch = 1000 of 4000, loss=1.051, LR=0.001
# Validation Loss = 0.423
# Epoch=1, batch = 2000 of 4000, loss=1.028, LR=0.001
# Validation Loss = 0.224
# Epoch=1, batch = 3000 of 4000, loss=0.894, LR=0.001
# Validation Loss = 0.287
# Epoch=2, batch = 0 of 4000, loss=0.895, LR=0.0009938441702975688
# Validation Loss = 0.076
# Epoch=2, batch = 1000 of 4000, loss=0.927, LR=0.0009938441702975688
# Validation Loss = 0.032
# Epoch=2, batch = 2000 of 4000, loss=1.049, LR=0.0009938441702975688
# Validation Loss = 0.962
# Epoch=2, batch = 3000 of 4000, loss=1.324, LR=0.0009938441702975688
# Validation Loss = 1.998
# Epoch=3, batch = 0 of 4000, loss=2.123, LR=0.0009755282581475768
# Validation Loss = 0.413
# Epoch=3, batch = 1000 of 4000, loss=1.547, LR=0.0009755282581475768
# Validation Loss = 0.265
# Epoch=3, batch = 2000 of 4000, loss=1.015, LR=0.0009755282581475768
# Validation Loss = 0.068
# Epoch=3, batch = 3000 of 4000, loss=1.177, LR=0.0009755282581475768
# Validation Loss = 2.813
# Epoch=4, batch = 0 of 4000, loss=2.594, LR=0.0009455032620941839
# Validation Loss = 0.017
# Epoch=4, batch = 1000 of 4000, loss=0.955, LR=0.0009455032620941839
# Validation Loss = 1.108
# Epoch=4, batch = 2000 of 4000, loss=1.396, LR=0.0009455032620941839
# Validation Loss = 1.573
# Epoch=4, batch = 3000 of 4000, loss=2.981, LR=0.0009455032620941839
# Validation Loss = 0.005
# Epoch=5, batch = 0 of 4000, loss=0.872, LR=0.0009045084971874737
# Validation Loss = 0.647
# Epoch=5, batch = 1000 of 4000, loss=1.285, LR=0.0009045084971874737
# Validation Loss = 1.000
# Epoch=5, batch = 2000 of 4000, loss=2.054, LR=0.0009045084971874737
# Validation Loss = 0.336
# Epoch=5, batch = 3000 of 4000, loss=1.009, LR=0.0009045084971874737
# Validation Loss = 1.794
# Epoch=6, batch = 0 of 4000, loss=3.238, LR=0.0008535533905932737
# Validation Loss = 0.056
# Epoch=6, batch = 1000 of 4000, loss=0.868, LR=0.0008535533905932737
# Validation Loss = 0.604
# Epoch=6, batch = 2000 of 4000, loss=1.078, LR=0.0008535533905932737
# Validation Loss = 0.330
# Epoch=6, batch = 3000 of 4000, loss=1.056, LR=0.0008535533905932737
# Validation Loss = 0.180
# Epoch=7, batch = 0 of 4000, loss=1.142, LR=0.0007938926261462366
# Validation Loss = 0.048
# Epoch=7, batch = 1000 of 4000, loss=1.026, LR=0.0007938926261462366
# Validation Loss = 1.757
# Epoch=7, batch = 2000 of 4000, loss=2.026, LR=0.0007938926261462366
# Validation Loss = 0.129
# Epoch=7, batch = 3000 of 4000, loss=0.912, LR=0.0007938926261462366
# Validation Loss = 0.051
# Epoch=8, batch = 0 of 4000, loss=0.944, LR=0.0007269952498697733
# Validation Loss = 0.000
# Epoch=8, batch = 1000 of 4000, loss=0.872, LR=0.0007269952498697733
# Validation Loss = 0.105
# Epoch=8, batch = 2000 of 4000, loss=1.171, LR=0.0007269952498697733
# Validation Loss = 0.916
# Epoch=8, batch = 3000 of 4000, loss=2.073, LR=0.0007269952498697733
# Validation Loss = 0.245
# Epoch=9, batch = 0 of 4000, loss=0.837, LR=0.0006545084971874737
# Validation Loss = 0.134
# Epoch=9, batch = 1000 of 4000, loss=0.828, LR=0.0006545084971874737
# Validation Loss = 0.041
# Epoch=9, batch = 2000 of 4000, loss=0.750, LR=0.0006545084971874737
# Validation Loss = 0.195
# Epoch=9, batch = 3000 of 4000, loss=0.908, LR=0.0006545084971874737
# Validation Loss = 0.023
# Epoch=10, batch = 0 of 4000, loss=0.940, LR=0.0005782172325201155
# Validation Loss = 0.087
# Epoch=10, batch = 1000 of 4000, loss=0.806, LR=0.0005782172325201155
# Validation Loss = 0.011
# Epoch=10, batch = 2000 of 4000, loss=1.035, LR=0.0005782172325201155
# Validation Loss = 0.009
# Epoch=10, batch = 3000 of 4000, loss=0.869, LR=0.0005782172325201155
# Validation Loss = 0.409
# Epoch=11, batch = 0 of 4000, loss=1.020, LR=0.0005
# Validation Loss = 0.217
# Epoch=11, batch = 1000 of 4000, loss=0.885, LR=0.0005
# Validation Loss = 0.002
# Epoch=11, batch = 2000 of 4000, loss=0.792, LR=0.0005
# Validation Loss = 0.484
# Epoch=11, batch = 3000 of 4000, loss=0.936, LR=0.0005
# Validation Loss = 0.182
# Epoch=12, batch = 0 of 4000, loss=0.906, LR=0.0004217827674798847
# Validation Loss = 0.017
# Epoch=12, batch = 1000 of 4000, loss=0.875, LR=0.0004217827674798847
# Validation Loss = 0.240
# Epoch=12, batch = 2000 of 4000, loss=0.945, LR=0.0004217827674798847
# Validation Loss = 0.618
# Epoch=12, batch = 3000 of 4000, loss=1.275, LR=0.0004217827674798847
# Validation Loss = 0.063
# Epoch=13, batch = 0 of 4000, loss=0.842, LR=0.00034549150281252633
# Validation Loss = 0.006
# Epoch=13, batch = 1000 of 4000, loss=0.770, LR=0.00034549150281252633
# Validation Loss = 0.065
# Epoch=13, batch = 2000 of 4000, loss=0.798, LR=0.00034549150281252633
# Validation Loss = 0.120
# Epoch=13, batch = 3000 of 4000, loss=1.113, LR=0.00034549150281252633
# Validation Loss = 0.002
# Epoch=14, batch = 0 of 4000, loss=0.865, LR=0.00027300475013022663
# Validation Loss = 0.063
# Epoch=14, batch = 1000 of 4000, loss=0.872, LR=0.00027300475013022663
# Validation Loss = 0.006
# Epoch=14, batch = 2000 of 4000, loss=0.850, LR=0.00027300475013022663
# Validation Loss = 0.002
# Epoch=14, batch = 3000 of 4000, loss=0.810, LR=0.00027300475013022663
# Validation Loss = 0.024
# Epoch=15, batch = 0 of 4000, loss=0.890, LR=0.00020610737385376348
# Validation Loss = 0.001
# Epoch=15, batch = 1000 of 4000, loss=0.878, LR=0.00020610737385376348
# Validation Loss = 0.047
# Epoch=15, batch = 2000 of 4000, loss=0.794, LR=0.00020610737385376348
# Validation Loss = 0.057
# Epoch=15, batch = 3000 of 4000, loss=0.861, LR=0.00020610737385376348
# Validation Loss = 0.133
# Epoch=16, batch = 0 of 4000, loss=0.894, LR=0.00014644660940672625
# Validation Loss = 0.061
# Epoch=16, batch = 1000 of 4000, loss=0.874, LR=0.00014644660940672625
# Validation Loss = 0.000
# Epoch=16, batch = 2000 of 4000, loss=0.940, LR=0.00014644660940672625
# Validation Loss = 0.016
# Epoch=16, batch = 3000 of 4000, loss=0.874, LR=0.00014644660940672625
# Validation Loss = 0.010
# Epoch=17, batch = 0 of 4000, loss=0.845, LR=9.549150281252631e-05
# Validation Loss = 0.001
# Epoch=17, batch = 1000 of 4000, loss=0.817, LR=9.549150281252631e-05
# Validation Loss = 0.032
# Epoch=17, batch = 2000 of 4000, loss=0.790, LR=9.549150281252631e-05
# Validation Loss = 0.041
# Epoch=17, batch = 3000 of 4000, loss=0.769, LR=9.549150281252631e-05
# Validation Loss = 0.006
# Epoch=18, batch = 0 of 4000, loss=0.759, LR=5.4496737905816096e-05
# Validation Loss = 0.037
# Epoch=18, batch = 1000 of 4000, loss=0.844, LR=5.4496737905816096e-05
# Validation Loss = 0.019
# Epoch=18, batch = 2000 of 4000, loss=0.832, LR=5.4496737905816096e-05
# Validation Loss = 0.013
# Epoch=18, batch = 3000 of 4000, loss=0.821, LR=5.4496737905816096e-05
# Validation Loss = 0.024
# Epoch=19, batch = 0 of 4000, loss=0.795, LR=2.447174185242323e-05
# Validation Loss = 0.048
# Epoch=19, batch = 1000 of 4000, loss=0.788, LR=2.447174185242323e-05
# Validation Loss = 0.012
# Epoch=19, batch = 2000 of 4000, loss=0.830, LR=2.447174185242323e-05
# Validation Loss = 0.013
# Epoch=19, batch = 3000 of 4000, loss=0.842, LR=2.447174185242323e-05
# Validation Loss = 0.004
# Epoch=20, batch = 0 of 4000, loss=0.812, LR=6.15582970243117e-06
# Validation Loss = 0.033
# Epoch=20, batch = 1000 of 4000, loss=0.796, LR=6.15582970243117e-06
# Validation Loss = 0.018
# Epoch=20, batch = 2000 of 4000, loss=0.733, LR=6.15582970243117e-06
# Validation Loss = 0.010
# Epoch=20, batch = 3000 of 4000, loss=0.889, LR=6.15582970243117e-06
# Finished training model for channel 166V.
# 166H
# Training stage: 1
# Validation Loss = 70875.086
# Epoch=1, batch = 0 of 4000, loss=66740.477, LR=0.001
# Validation Loss = 16.279
# Epoch=1, batch = 1000 of 4000, loss=7.187, LR=0.001
# Validation Loss = 0.175
# Epoch=1, batch = 2000 of 4000, loss=7.344, LR=0.001
# Validation Loss = 0.102
# Epoch=1, batch = 3000 of 4000, loss=6.436, LR=0.001
# Validation Loss = 4.343
# Epoch=2, batch = 0 of 4000, loss=3.817, LR=0.0009045084971874737
# Validation Loss = 0.003
# Epoch=2, batch = 1000 of 4000, loss=4.331, LR=0.0009045084971874737
# Validation Loss = 7.186
# Epoch=2, batch = 2000 of 4000, loss=6.559, LR=0.0009045084971874737
# Validation Loss = 0.564
# Epoch=2, batch = 3000 of 4000, loss=2.756, LR=0.0009045084971874737
# Validation Loss = 1.280
# Epoch=3, batch = 0 of 4000, loss=2.567, LR=0.0006545084971874737
# Validation Loss = 0.230
# Epoch=3, batch = 1000 of 4000, loss=2.618, LR=0.0006545084971874737
# Validation Loss = 0.535
# Epoch=3, batch = 2000 of 4000, loss=2.274, LR=0.0006545084971874737
# Validation Loss = 0.056
# Epoch=3, batch = 3000 of 4000, loss=2.438, LR=0.0006545084971874737
# Validation Loss = 0.278
# Epoch=4, batch = 0 of 4000, loss=2.128, LR=0.00034549150281252633
# Validation Loss = 0.118
# Epoch=4, batch = 1000 of 4000, loss=2.099, LR=0.00034549150281252633
# Validation Loss = 0.011
# Epoch=4, batch = 2000 of 4000, loss=2.002, LR=0.00034549150281252633
# Validation Loss = 0.168
# Epoch=4, batch = 3000 of 4000, loss=2.038, LR=0.00034549150281252633
# Validation Loss = 0.211
# Epoch=5, batch = 0 of 4000, loss=1.890, LR=9.549150281252633e-05
# Validation Loss = 0.003
# Epoch=5, batch = 1000 of 4000, loss=1.761, LR=9.549150281252633e-05
# Validation Loss = 0.015
# Epoch=5, batch = 2000 of 4000, loss=1.943, LR=9.549150281252633e-05
# Validation Loss = 0.001
# Epoch=5, batch = 3000 of 4000, loss=1.640, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.261
# Epoch=1, batch = 0 of 4000, loss=1.735, LR=0.001
# Validation Loss = 1.943
# Epoch=1, batch = 1000 of 4000, loss=3.287, LR=0.001
# Validation Loss = 3.044
# Epoch=1, batch = 2000 of 4000, loss=3.681, LR=0.001
# Validation Loss = 1.784
# Epoch=1, batch = 3000 of 4000, loss=3.576, LR=0.001
# Validation Loss = 0.699
# Epoch=2, batch = 0 of 4000, loss=2.563, LR=0.0009755282581475768
# Validation Loss = 3.398
# Epoch=2, batch = 1000 of 4000, loss=6.124, LR=0.0009755282581475768
# Validation Loss = 6.715
# Epoch=2, batch = 2000 of 4000, loss=8.450, LR=0.0009755282581475768
# Validation Loss = 0.316
# Epoch=2, batch = 3000 of 4000, loss=2.353, LR=0.0009755282581475768
# Validation Loss = 2.859
# Epoch=3, batch = 0 of 4000, loss=4.167, LR=0.0009045084971874736
# Validation Loss = 0.468
# Epoch=3, batch = 1000 of 4000, loss=2.865, LR=0.0009045084971874736
# Validation Loss = 0.650
# Epoch=3, batch = 2000 of 4000, loss=2.257, LR=0.0009045084971874736
# Validation Loss = 4.528
# Epoch=3, batch = 3000 of 4000, loss=5.049, LR=0.0009045084971874736
# Validation Loss = 0.201
# Epoch=4, batch = 0 of 4000, loss=2.383, LR=0.0007938926261462366
# Validation Loss = 0.500
# Epoch=4, batch = 1000 of 4000, loss=2.480, LR=0.0007938926261462366
# Validation Loss = 0.176
# Epoch=4, batch = 2000 of 4000, loss=2.475, LR=0.0007938926261462366
# Validation Loss = 0.829
# Epoch=4, batch = 3000 of 4000, loss=2.148, LR=0.0007938926261462366
# Validation Loss = 0.004
# Epoch=5, batch = 0 of 4000, loss=2.124, LR=0.0006545084971874737
# Validation Loss = 0.519
# Epoch=5, batch = 1000 of 4000, loss=2.669, LR=0.0006545084971874737
# Validation Loss = 0.059
# Epoch=5, batch = 2000 of 4000, loss=1.865, LR=0.0006545084971874737
# Validation Loss = 0.574
# Epoch=5, batch = 3000 of 4000, loss=2.884, LR=0.0006545084971874737
# Validation Loss = 1.857
# Epoch=6, batch = 0 of 4000, loss=4.822, LR=0.0005
# Validation Loss = 0.286
# Epoch=6, batch = 1000 of 4000, loss=2.667, LR=0.0005
# Validation Loss = 0.216
# Epoch=6, batch = 2000 of 4000, loss=1.703, LR=0.0005
# Validation Loss = 0.629
# Epoch=6, batch = 3000 of 4000, loss=1.952, LR=0.0005
# Validation Loss = 0.764
# Epoch=7, batch = 0 of 4000, loss=2.156, LR=0.00034549150281252633
# Validation Loss = 0.205
# Epoch=7, batch = 1000 of 4000, loss=1.851, LR=0.00034549150281252633
# Validation Loss = 0.349
# Epoch=7, batch = 2000 of 4000, loss=1.779, LR=0.00034549150281252633
# Validation Loss = 0.806
# Epoch=7, batch = 3000 of 4000, loss=1.968, LR=0.00034549150281252633
# Validation Loss = 0.211
# Epoch=8, batch = 0 of 4000, loss=1.672, LR=0.0002061073738537635
# Validation Loss = 0.060
# Epoch=8, batch = 1000 of 4000, loss=2.001, LR=0.0002061073738537635
# Validation Loss = 0.081
# Epoch=8, batch = 2000 of 4000, loss=1.593, LR=0.0002061073738537635
# Validation Loss = 0.278
# Epoch=8, batch = 3000 of 4000, loss=1.885, LR=0.0002061073738537635
# Validation Loss = 0.191
# Epoch=9, batch = 0 of 4000, loss=1.940, LR=9.549150281252634e-05
# Validation Loss = 0.032
# Epoch=9, batch = 1000 of 4000, loss=1.769, LR=9.549150281252634e-05
# Validation Loss = 0.000
# Epoch=9, batch = 2000 of 4000, loss=1.492, LR=9.549150281252634e-05
# Validation Loss = 0.002
# Epoch=9, batch = 3000 of 4000, loss=1.901, LR=9.549150281252634e-05
# Validation Loss = 0.026
# Epoch=10, batch = 0 of 4000, loss=1.486, LR=2.4471741852423235e-05
# Validation Loss = 0.000
# Epoch=10, batch = 1000 of 4000, loss=1.600, LR=2.4471741852423235e-05
# Validation Loss = 0.011
# Epoch=10, batch = 2000 of 4000, loss=1.460, LR=2.4471741852423235e-05
# Validation Loss = 0.000
# Epoch=10, batch = 3000 of 4000, loss=1.672, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.000
# Epoch=1, batch = 0 of 4000, loss=1.715, LR=0.001
# Validation Loss = 0.065
# Epoch=1, batch = 1000 of 4000, loss=2.309, LR=0.001
# Validation Loss = 0.005
# Epoch=1, batch = 2000 of 4000, loss=2.113, LR=0.001
# Validation Loss = 3.515
# Epoch=1, batch = 3000 of 4000, loss=4.955, LR=0.001
# Validation Loss = 0.006
# Epoch=2, batch = 0 of 4000, loss=1.920, LR=0.0009938441702975688
# Validation Loss = 2.083
# Epoch=2, batch = 1000 of 4000, loss=3.983, LR=0.0009938441702975688
# Validation Loss = 0.700
# Epoch=2, batch = 2000 of 4000, loss=2.898, LR=0.0009938441702975688
# Validation Loss = 0.005
# Epoch=2, batch = 3000 of 4000, loss=1.595, LR=0.0009938441702975688
# Validation Loss = 0.255
# Epoch=3, batch = 0 of 4000, loss=1.752, LR=0.0009755282581475768
# Validation Loss = 0.039
# Epoch=3, batch = 1000 of 4000, loss=1.980, LR=0.0009755282581475768
# Validation Loss = 0.151
# Epoch=3, batch = 2000 of 4000, loss=2.544, LR=0.0009755282581475768
# Validation Loss = 0.017
# Epoch=3, batch = 3000 of 4000, loss=1.997, LR=0.0009755282581475768
# Validation Loss = 0.148
# Epoch=4, batch = 0 of 4000, loss=1.606, LR=0.0009455032620941839
# Validation Loss = 0.403
# Epoch=4, batch = 1000 of 4000, loss=2.730, LR=0.0009455032620941839
# Validation Loss = 0.021
# Epoch=4, batch = 2000 of 4000, loss=2.059, LR=0.0009455032620941839
# Validation Loss = 0.939
# Epoch=4, batch = 3000 of 4000, loss=2.710, LR=0.0009455032620941839
# Validation Loss = 0.166
# Epoch=5, batch = 0 of 4000, loss=1.612, LR=0.0009045084971874737
# Validation Loss = 0.046
# Epoch=5, batch = 1000 of 4000, loss=1.782, LR=0.0009045084971874737
# Validation Loss = 0.015
# Epoch=5, batch = 2000 of 4000, loss=1.817, LR=0.0009045084971874737
# Validation Loss = 3.256
# Epoch=5, batch = 3000 of 4000, loss=6.472, LR=0.0009045084971874737
# Validation Loss = 2.602
# Epoch=6, batch = 0 of 4000, loss=3.153, LR=0.0008535533905932737
# Validation Loss = 0.591
# Epoch=6, batch = 1000 of 4000, loss=1.786, LR=0.0008535533905932737
# Validation Loss = 4.157
# Epoch=6, batch = 2000 of 4000, loss=4.567, LR=0.0008535533905932737
# Validation Loss = 0.245
# Epoch=6, batch = 3000 of 4000, loss=2.007, LR=0.0008535533905932737
# Validation Loss = 0.253
# Epoch=7, batch = 0 of 4000, loss=1.643, LR=0.0007938926261462366
# Validation Loss = 0.202
# Epoch=7, batch = 1000 of 4000, loss=1.692, LR=0.0007938926261462366
# Validation Loss = 0.261
# Epoch=7, batch = 2000 of 4000, loss=1.828, LR=0.0007938926261462366
# Validation Loss = 0.194
# Epoch=7, batch = 3000 of 4000, loss=2.104, LR=0.0007938926261462366
# Validation Loss = 0.190
# Epoch=8, batch = 0 of 4000, loss=1.633, LR=0.0007269952498697733
# Validation Loss = 0.015
# Epoch=8, batch = 1000 of 4000, loss=1.586, LR=0.0007269952498697733
# Validation Loss = 0.137
# Epoch=8, batch = 2000 of 4000, loss=2.048, LR=0.0007269952498697733
# Validation Loss = 1.154
# Epoch=8, batch = 3000 of 4000, loss=2.497, LR=0.0007269952498697733
# Validation Loss = 0.006
# Epoch=9, batch = 0 of 4000, loss=1.921, LR=0.0006545084971874737
# Validation Loss = 0.305
# Epoch=9, batch = 1000 of 4000, loss=2.055, LR=0.0006545084971874737
# Validation Loss = 0.256
# Epoch=9, batch = 2000 of 4000, loss=1.860, LR=0.0006545084971874737
# Validation Loss = 0.160
# Epoch=9, batch = 3000 of 4000, loss=2.381, LR=0.0006545084971874737
# Validation Loss = 0.051
# Epoch=10, batch = 0 of 4000, loss=1.598, LR=0.0005782172325201155
# Validation Loss = 0.040
# Epoch=10, batch = 1000 of 4000, loss=1.898, LR=0.0005782172325201155
# Validation Loss = 0.107
# Epoch=10, batch = 2000 of 4000, loss=1.692, LR=0.0005782172325201155
# Validation Loss = 0.046
# Epoch=10, batch = 3000 of 4000, loss=1.800, LR=0.0005782172325201155
# Validation Loss = 0.005
# Epoch=11, batch = 0 of 4000, loss=1.525, LR=0.0005
# Validation Loss = 0.533
# Epoch=11, batch = 1000 of 4000, loss=1.981, LR=0.0005
# Validation Loss = 0.002
# Epoch=11, batch = 2000 of 4000, loss=1.794, LR=0.0005
# Validation Loss = 0.287
# Epoch=11, batch = 3000 of 4000, loss=1.869, LR=0.0005
# Validation Loss = 0.482
# Epoch=12, batch = 0 of 4000, loss=1.768, LR=0.0004217827674798847
# Validation Loss = 0.145
# Epoch=12, batch = 1000 of 4000, loss=1.637, LR=0.0004217827674798847
# Validation Loss = 0.819
# Epoch=12, batch = 2000 of 4000, loss=2.435, LR=0.0004217827674798847
# Validation Loss = 0.384
# Epoch=12, batch = 3000 of 4000, loss=2.048, LR=0.0004217827674798847
# Validation Loss = 0.206
# Epoch=13, batch = 0 of 4000, loss=1.570, LR=0.00034549150281252633
# Validation Loss = 0.004
# Epoch=13, batch = 1000 of 4000, loss=1.512, LR=0.00034549150281252633
# Validation Loss = 0.024
# Epoch=13, batch = 2000 of 4000, loss=1.576, LR=0.00034549150281252633
# Validation Loss = 0.000
# Epoch=13, batch = 3000 of 4000, loss=1.782, LR=0.00034549150281252633
# Validation Loss = 0.004
# Epoch=14, batch = 0 of 4000, loss=1.689, LR=0.00027300475013022663
# Validation Loss = 0.064
# Epoch=14, batch = 1000 of 4000, loss=1.500, LR=0.00027300475013022663
# Validation Loss = 0.081
# Epoch=14, batch = 2000 of 4000, loss=1.670, LR=0.00027300475013022663
# Validation Loss = 0.392
# Epoch=14, batch = 3000 of 4000, loss=1.755, LR=0.00027300475013022663
# Validation Loss = 0.001
# Epoch=15, batch = 0 of 4000, loss=1.533, LR=0.00020610737385376348
# Validation Loss = 0.002
# Epoch=15, batch = 1000 of 4000, loss=1.475, LR=0.00020610737385376348
# Validation Loss = 0.028
# Epoch=15, batch = 2000 of 4000, loss=1.439, LR=0.00020610737385376348
# Validation Loss = 0.117
# Epoch=15, batch = 3000 of 4000, loss=1.678, LR=0.00020610737385376348
# Validation Loss = 0.063
# Epoch=16, batch = 0 of 4000, loss=1.690, LR=0.00014644660940672625
# Validation Loss = 0.006
# Epoch=16, batch = 1000 of 4000, loss=1.505, LR=0.00014644660940672625
# Validation Loss = 0.062
# Epoch=16, batch = 2000 of 4000, loss=1.726, LR=0.00014644660940672625
# Validation Loss = 0.085
# Epoch=16, batch = 3000 of 4000, loss=1.586, LR=0.00014644660940672625
# Validation Loss = 0.029
# Epoch=17, batch = 0 of 4000, loss=1.385, LR=9.549150281252631e-05
# Validation Loss = 0.003
# Epoch=17, batch = 1000 of 4000, loss=1.591, LR=9.549150281252631e-05
# Validation Loss = 0.005
# Epoch=17, batch = 2000 of 4000, loss=1.653, LR=9.549150281252631e-05
# Validation Loss = 0.045
# Epoch=17, batch = 3000 of 4000, loss=1.514, LR=9.549150281252631e-05
# Validation Loss = 0.001
# Epoch=18, batch = 0 of 4000, loss=1.576, LR=5.4496737905816096e-05
# Validation Loss = 0.002
# Epoch=18, batch = 1000 of 4000, loss=1.660, LR=5.4496737905816096e-05
# Validation Loss = 0.000
# Epoch=18, batch = 2000 of 4000, loss=1.480, LR=5.4496737905816096e-05
# Validation Loss = 0.000
# Epoch=18, batch = 3000 of 4000, loss=1.570, LR=5.4496737905816096e-05
# Validation Loss = 0.000
# Epoch=19, batch = 0 of 4000, loss=1.586, LR=2.447174185242323e-05
# Validation Loss = 0.032
# Epoch=19, batch = 1000 of 4000, loss=1.483, LR=2.447174185242323e-05
# Validation Loss = 0.036
# Epoch=19, batch = 2000 of 4000, loss=1.531, LR=2.447174185242323e-05
# Validation Loss = 0.001
# Epoch=19, batch = 3000 of 4000, loss=1.574, LR=2.447174185242323e-05
# Validation Loss = 0.002
# Epoch=20, batch = 0 of 4000, loss=1.442, LR=6.15582970243117e-06
# Validation Loss = 0.002
# Epoch=20, batch = 1000 of 4000, loss=1.667, LR=6.15582970243117e-06
# Validation Loss = 0.002
# Epoch=20, batch = 2000 of 4000, loss=1.422, LR=6.15582970243117e-06
# Validation Loss = 0.000
# Epoch=20, batch = 3000 of 4000, loss=1.607, LR=6.15582970243117e-06
# Finished training model for channel 166H.
# 183+-3V
# Training stage: 1
# Validation Loss = 65159.301
# Epoch=1, batch = 0 of 4000, loss=66607.375, LR=0.001
# Validation Loss = 0.188
# Epoch=1, batch = 1000 of 4000, loss=9.632, LR=0.001
# Validation Loss = 0.291
# Epoch=1, batch = 2000 of 4000, loss=7.202, LR=0.001
# Validation Loss = 1.345
# Epoch=1, batch = 3000 of 4000, loss=5.964, LR=0.001
# Validation Loss = 0.866
# Epoch=2, batch = 0 of 4000, loss=6.663, LR=0.0009045084971874737
# Validation Loss = 2.921
# Epoch=2, batch = 1000 of 4000, loss=9.743, LR=0.0009045084971874737
# Validation Loss = 0.814
# Epoch=2, batch = 2000 of 4000, loss=4.741, LR=0.0009045084971874737
# Validation Loss = 0.170
# Epoch=2, batch = 3000 of 4000, loss=4.542, LR=0.0009045084971874737
# Validation Loss = 0.319
# Epoch=3, batch = 0 of 4000, loss=4.362, LR=0.0006545084971874737
# Validation Loss = 0.936
# Epoch=3, batch = 1000 of 4000, loss=4.228, LR=0.0006545084971874737
# Validation Loss = 1.805
# Epoch=3, batch = 2000 of 4000, loss=4.007, LR=0.0006545084971874737
# Validation Loss = 2.195
# Epoch=3, batch = 3000 of 4000, loss=4.447, LR=0.0006545084971874737
# Validation Loss = 0.342
# Epoch=4, batch = 0 of 4000, loss=3.670, LR=0.00034549150281252633
# Validation Loss = 1.550
# Epoch=4, batch = 1000 of 4000, loss=3.927, LR=0.00034549150281252633
# Validation Loss = 0.160
# Epoch=4, batch = 2000 of 4000, loss=3.776, LR=0.00034549150281252633
# Validation Loss = 0.191
# Epoch=4, batch = 3000 of 4000, loss=3.930, LR=0.00034549150281252633
# Validation Loss = 0.048
# Epoch=5, batch = 0 of 4000, loss=4.077, LR=9.549150281252633e-05
# Validation Loss = 0.321
# Epoch=5, batch = 1000 of 4000, loss=3.456, LR=9.549150281252633e-05
# Validation Loss = 0.119
# Epoch=5, batch = 2000 of 4000, loss=3.693, LR=9.549150281252633e-05
# Validation Loss = 1.058
# Epoch=5, batch = 3000 of 4000, loss=3.624, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.966
# Epoch=1, batch = 0 of 4000, loss=4.198, LR=0.001
# Validation Loss = 0.884
# Epoch=1, batch = 1000 of 4000, loss=4.516, LR=0.001
# Validation Loss = 0.150
# Epoch=1, batch = 2000 of 4000, loss=3.926, LR=0.001
# Validation Loss = 0.561
# Epoch=1, batch = 3000 of 4000, loss=4.220, LR=0.001
# Validation Loss = 0.290
# Epoch=2, batch = 0 of 4000, loss=3.716, LR=0.0009755282581475768
# Validation Loss = 2.870
# Epoch=2, batch = 1000 of 4000, loss=4.884, LR=0.0009755282581475768
# Validation Loss = 0.278
# Epoch=2, batch = 2000 of 4000, loss=5.522, LR=0.0009755282581475768
# Validation Loss = 2.118
# Epoch=2, batch = 3000 of 4000, loss=4.580, LR=0.0009755282581475768
# Validation Loss = 1.422
# Epoch=3, batch = 0 of 4000, loss=4.129, LR=0.0009045084971874736
# Validation Loss = 0.014
# Epoch=3, batch = 1000 of 4000, loss=4.825, LR=0.0009045084971874736
# Validation Loss = 1.905
# Epoch=3, batch = 2000 of 4000, loss=4.513, LR=0.0009045084971874736
# Validation Loss = 11.333
# Epoch=3, batch = 3000 of 4000, loss=8.768, LR=0.0009045084971874736
# Validation Loss = 0.255
# Epoch=4, batch = 0 of 4000, loss=3.770, LR=0.0007938926261462366
# Validation Loss = 0.053
# Epoch=4, batch = 1000 of 4000, loss=4.142, LR=0.0007938926261462366
# Validation Loss = 0.036
# Epoch=4, batch = 2000 of 4000, loss=4.640, LR=0.0007938926261462366
# Validation Loss = 0.208
# Epoch=4, batch = 3000 of 4000, loss=4.874, LR=0.0007938926261462366
# Validation Loss = 0.795
# Epoch=5, batch = 0 of 4000, loss=6.585, LR=0.0006545084971874737
# Validation Loss = 1.710
# Epoch=5, batch = 1000 of 4000, loss=3.808, LR=0.0006545084971874737
# Validation Loss = 2.644
# Epoch=5, batch = 2000 of 4000, loss=4.398, LR=0.0006545084971874737
# Validation Loss = 0.127
# Epoch=5, batch = 3000 of 4000, loss=5.202, LR=0.0006545084971874737
# Validation Loss = 2.970
# Epoch=6, batch = 0 of 4000, loss=4.449, LR=0.0005
# Validation Loss = 0.024
# Epoch=6, batch = 1000 of 4000, loss=5.073, LR=0.0005
# Validation Loss = 0.926
# Epoch=6, batch = 2000 of 4000, loss=3.940, LR=0.0005
# Validation Loss = 0.020
# Epoch=6, batch = 3000 of 4000, loss=4.041, LR=0.0005
# Validation Loss = 0.710
# Epoch=7, batch = 0 of 4000, loss=3.651, LR=0.00034549150281252633
# Validation Loss = 0.091
# Epoch=7, batch = 1000 of 4000, loss=3.815, LR=0.00034549150281252633
# Validation Loss = 0.540
# Epoch=7, batch = 2000 of 4000, loss=3.679, LR=0.00034549150281252633
# Validation Loss = 0.253
# Epoch=7, batch = 3000 of 4000, loss=4.606, LR=0.00034549150281252633
# Validation Loss = 1.365
# Epoch=8, batch = 0 of 4000, loss=3.613, LR=0.0002061073738537635
# Validation Loss = 0.015
# Epoch=8, batch = 1000 of 4000, loss=4.010, LR=0.0002061073738537635
# Validation Loss = 0.548
# Epoch=8, batch = 2000 of 4000, loss=3.411, LR=0.0002061073738537635
# Validation Loss = 0.263
# Epoch=8, batch = 3000 of 4000, loss=3.616, LR=0.0002061073738537635
# Validation Loss = 0.021
# Epoch=9, batch = 0 of 4000, loss=3.730, LR=9.549150281252634e-05
# Validation Loss = 0.221
# Epoch=9, batch = 1000 of 4000, loss=3.258, LR=9.549150281252634e-05
# Validation Loss = 0.247
# Epoch=9, batch = 2000 of 4000, loss=3.323, LR=9.549150281252634e-05
# Validation Loss = 0.514
# Epoch=9, batch = 3000 of 4000, loss=3.093, LR=9.549150281252634e-05
# Validation Loss = 0.316
# Epoch=10, batch = 0 of 4000, loss=3.527, LR=2.4471741852423235e-05
# Validation Loss = 0.227
# Epoch=10, batch = 1000 of 4000, loss=3.319, LR=2.4471741852423235e-05
# Validation Loss = 0.056
# Epoch=10, batch = 2000 of 4000, loss=3.328, LR=2.4471741852423235e-05
# Validation Loss = 0.459
# Epoch=10, batch = 3000 of 4000, loss=3.401, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.255
# Epoch=1, batch = 0 of 4000, loss=3.367, LR=0.001
# Validation Loss = 0.418
# Epoch=1, batch = 1000 of 4000, loss=4.381, LR=0.001
# Validation Loss = 0.251
# Epoch=1, batch = 2000 of 4000, loss=3.828, LR=0.001
# Validation Loss = 0.624
# Epoch=1, batch = 3000 of 4000, loss=4.047, LR=0.001
# Validation Loss = 0.004
# Epoch=2, batch = 0 of 4000, loss=3.593, LR=0.0009938441702975688
# Validation Loss = 0.738
# Epoch=2, batch = 1000 of 4000, loss=3.628, LR=0.0009938441702975688
# Validation Loss = 0.019
# Epoch=2, batch = 2000 of 4000, loss=3.846, LR=0.0009938441702975688
# Validation Loss = 1.172
# Epoch=2, batch = 3000 of 4000, loss=3.736, LR=0.0009938441702975688
# Validation Loss = 0.780
# Epoch=3, batch = 0 of 4000, loss=6.570, LR=0.0009755282581475768
# Validation Loss = 0.188
# Epoch=3, batch = 1000 of 4000, loss=3.667, LR=0.0009755282581475768
# Validation Loss = 0.000
# Epoch=3, batch = 2000 of 4000, loss=4.317, LR=0.0009755282581475768
# Validation Loss = 5.009
# Epoch=3, batch = 3000 of 4000, loss=6.412, LR=0.0009755282581475768
# Validation Loss = 0.003
# Epoch=4, batch = 0 of 4000, loss=4.017, LR=0.0009455032620941839
# Validation Loss = 0.457
# Epoch=4, batch = 1000 of 4000, loss=3.361, LR=0.0009455032620941839
# Validation Loss = 0.779
# Epoch=4, batch = 2000 of 4000, loss=3.824, LR=0.0009455032620941839
# Validation Loss = 0.553
# Epoch=4, batch = 3000 of 4000, loss=5.914, LR=0.0009455032620941839
# Validation Loss = 0.000
# Epoch=5, batch = 0 of 4000, loss=4.256, LR=0.0009045084971874737
# Validation Loss = 1.195
# Epoch=5, batch = 1000 of 4000, loss=3.889, LR=0.0009045084971874737
# Validation Loss = 6.483
# Epoch=5, batch = 2000 of 4000, loss=5.882, LR=0.0009045084971874737
# Validation Loss = 0.867
# Epoch=5, batch = 3000 of 4000, loss=3.241, LR=0.0009045084971874737
# Validation Loss = 0.499
# Epoch=6, batch = 0 of 4000, loss=3.863, LR=0.0008535533905932737
# Validation Loss = 1.192
# Epoch=6, batch = 1000 of 4000, loss=3.122, LR=0.0008535533905932737
# Validation Loss = 0.380
# Epoch=6, batch = 2000 of 4000, loss=3.595, LR=0.0008535533905932737
# Validation Loss = 0.237
# Epoch=6, batch = 3000 of 4000, loss=3.812, LR=0.0008535533905932737
# Validation Loss = 0.516
# Epoch=7, batch = 0 of 4000, loss=3.646, LR=0.0007938926261462366
# Validation Loss = 0.206
# Epoch=7, batch = 1000 of 4000, loss=3.853, LR=0.0007938926261462366
# Validation Loss = 0.021
# Epoch=7, batch = 2000 of 4000, loss=4.046, LR=0.0007938926261462366
# Validation Loss = 3.593
# Epoch=7, batch = 3000 of 4000, loss=4.575, LR=0.0007938926261462366
# Validation Loss = 3.927
# Epoch=8, batch = 0 of 4000, loss=5.026, LR=0.0007269952498697733
# Validation Loss = 1.268
# Epoch=8, batch = 1000 of 4000, loss=3.761, LR=0.0007269952498697733
# Validation Loss = 0.278
# Epoch=8, batch = 2000 of 4000, loss=3.608, LR=0.0007269952498697733
# Validation Loss = 0.959
# Epoch=8, batch = 3000 of 4000, loss=3.625, LR=0.0007269952498697733
# Validation Loss = 1.504
# Epoch=9, batch = 0 of 4000, loss=3.394, LR=0.0006545084971874737
# Validation Loss = 0.234
# Epoch=9, batch = 1000 of 4000, loss=4.416, LR=0.0006545084971874737
# Validation Loss = 0.578
# Epoch=9, batch = 2000 of 4000, loss=3.501, LR=0.0006545084971874737
# Validation Loss = 0.470
# Epoch=9, batch = 3000 of 4000, loss=3.476, LR=0.0006545084971874737
# Validation Loss = 0.781
# Epoch=10, batch = 0 of 4000, loss=3.291, LR=0.0005782172325201155
# Validation Loss = 0.366
# Epoch=10, batch = 1000 of 4000, loss=5.191, LR=0.0005782172325201155
# Validation Loss = 0.418
# Epoch=10, batch = 2000 of 4000, loss=3.526, LR=0.0005782172325201155
# Validation Loss = 1.128
# Epoch=10, batch = 3000 of 4000, loss=3.414, LR=0.0005782172325201155
# Validation Loss = 0.413
# Epoch=11, batch = 0 of 4000, loss=2.965, LR=0.0005
# Validation Loss = 3.029
# Epoch=11, batch = 1000 of 4000, loss=4.214, LR=0.0005
# Validation Loss = 0.822
# Epoch=11, batch = 2000 of 4000, loss=3.237, LR=0.0005
# Validation Loss = 0.001
# Epoch=11, batch = 3000 of 4000, loss=3.814, LR=0.0005
# Validation Loss = 0.076
# Epoch=12, batch = 0 of 4000, loss=3.505, LR=0.0004217827674798847
# Validation Loss = 4.172
# Epoch=12, batch = 1000 of 4000, loss=4.484, LR=0.0004217827674798847
# Validation Loss = 0.281
# Epoch=12, batch = 2000 of 4000, loss=3.280, LR=0.0004217827674798847
# Validation Loss = 1.063
# Epoch=12, batch = 3000 of 4000, loss=3.309, LR=0.0004217827674798847
# Validation Loss = 0.540
# Epoch=13, batch = 0 of 4000, loss=3.365, LR=0.00034549150281252633
# Validation Loss = 1.151
# Epoch=13, batch = 1000 of 4000, loss=3.375, LR=0.00034549150281252633
# Validation Loss = 0.538
# Epoch=13, batch = 2000 of 4000, loss=3.170, LR=0.00034549150281252633
# Validation Loss = 0.352
# Epoch=13, batch = 3000 of 4000, loss=3.595, LR=0.00034549150281252633
# Validation Loss = 1.511
# Epoch=14, batch = 0 of 4000, loss=3.375, LR=0.00027300475013022663
# Validation Loss = 0.842
# Epoch=14, batch = 1000 of 4000, loss=3.311, LR=0.00027300475013022663
# Validation Loss = 0.165
# Epoch=14, batch = 2000 of 4000, loss=3.168, LR=0.00027300475013022663
# Validation Loss = 1.885
# Epoch=14, batch = 3000 of 4000, loss=3.842, LR=0.00027300475013022663
# Validation Loss = 0.614
# Epoch=15, batch = 0 of 4000, loss=3.399, LR=0.00020610737385376348
# Validation Loss = 0.532
# Epoch=15, batch = 1000 of 4000, loss=3.508, LR=0.00020610737385376348
# Validation Loss = 0.402
# Epoch=15, batch = 2000 of 4000, loss=3.327, LR=0.00020610737385376348
# Validation Loss = 1.160
# Epoch=15, batch = 3000 of 4000, loss=3.010, LR=0.00020610737385376348
# Validation Loss = 0.582
# Epoch=16, batch = 0 of 4000, loss=3.267, LR=0.00014644660940672625
# Validation Loss = 0.070
# Epoch=16, batch = 1000 of 4000, loss=3.779, LR=0.00014644660940672625
# Validation Loss = 0.280
# Epoch=16, batch = 2000 of 4000, loss=3.461, LR=0.00014644660940672625
# Validation Loss = 0.887
# Epoch=16, batch = 3000 of 4000, loss=3.281, LR=0.00014644660940672625
# Validation Loss = 0.520
# Epoch=17, batch = 0 of 4000, loss=3.209, LR=9.549150281252631e-05
# Validation Loss = 0.375
# Epoch=17, batch = 1000 of 4000, loss=3.361, LR=9.549150281252631e-05
# Validation Loss = 0.625
# Epoch=17, batch = 2000 of 4000, loss=3.199, LR=9.549150281252631e-05
# Validation Loss = 1.029
# Epoch=17, batch = 3000 of 4000, loss=2.981, LR=9.549150281252631e-05
# Validation Loss = 1.076
# Epoch=18, batch = 0 of 4000, loss=3.228, LR=5.4496737905816096e-05
# Validation Loss = 1.023
# Epoch=18, batch = 1000 of 4000, loss=3.045, LR=5.4496737905816096e-05
# Validation Loss = 0.288
# Epoch=18, batch = 2000 of 4000, loss=3.434, LR=5.4496737905816096e-05
# Validation Loss = 0.652
# Epoch=18, batch = 3000 of 4000, loss=3.552, LR=5.4496737905816096e-05
# Validation Loss = 1.011
# Epoch=19, batch = 0 of 4000, loss=3.028, LR=2.447174185242323e-05
# Validation Loss = 0.735
# Epoch=19, batch = 1000 of 4000, loss=3.411, LR=2.447174185242323e-05
# Validation Loss = 0.857
# Epoch=19, batch = 2000 of 4000, loss=3.317, LR=2.447174185242323e-05
# Validation Loss = 0.551
# Epoch=19, batch = 3000 of 4000, loss=3.052, LR=2.447174185242323e-05
# Validation Loss = 0.722
# Epoch=20, batch = 0 of 4000, loss=3.136, LR=6.15582970243117e-06
# Validation Loss = 0.463
# Epoch=20, batch = 1000 of 4000, loss=3.177, LR=6.15582970243117e-06
# Validation Loss = 0.690
# Epoch=20, batch = 2000 of 4000, loss=3.387, LR=6.15582970243117e-06
# Validation Loss = 0.602
# Epoch=20, batch = 3000 of 4000, loss=3.216, LR=6.15582970243117e-06
# Finished training model for channel 183+-3V.
# 183+-7V
# Training stage: 1
# Validation Loss = 70360.430
# Epoch=1, batch = 0 of 4000, loss=71141.266, LR=0.001
# Validation Loss = 0.177
# Epoch=1, batch = 1000 of 4000, loss=1.438, LR=0.001
# Validation Loss = 0.099
# Epoch=1, batch = 2000 of 4000, loss=1.408, LR=0.001
# Validation Loss = 2.643
# Epoch=1, batch = 3000 of 4000, loss=2.895, LR=0.001
# Validation Loss = 0.920
# Epoch=2, batch = 0 of 4000, loss=3.248, LR=0.0009045084971874737
# Validation Loss = 0.074
# Epoch=2, batch = 1000 of 4000, loss=1.944, LR=0.0009045084971874737
# Validation Loss = 4.124
# Epoch=2, batch = 2000 of 4000, loss=3.655, LR=0.0009045084971874737
# Validation Loss = 0.044
# Epoch=2, batch = 3000 of 4000, loss=1.728, LR=0.0009045084971874737
# Validation Loss = 0.313
# Epoch=3, batch = 0 of 4000, loss=2.171, LR=0.0006545084971874737
# Validation Loss = 0.001
# Epoch=3, batch = 1000 of 4000, loss=1.475, LR=0.0006545084971874737
# Validation Loss = 0.006
# Epoch=3, batch = 2000 of 4000, loss=1.386, LR=0.0006545084971874737
# Validation Loss = 0.401
# Epoch=3, batch = 3000 of 4000, loss=1.232, LR=0.0006545084971874737
# Validation Loss = 1.280
# Epoch=4, batch = 0 of 4000, loss=1.721, LR=0.00034549150281252633
# Validation Loss = 0.019
# Epoch=4, batch = 1000 of 4000, loss=1.440, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=4, batch = 2000 of 4000, loss=1.342, LR=0.00034549150281252633
# Validation Loss = 0.010
# Epoch=4, batch = 3000 of 4000, loss=1.368, LR=0.00034549150281252633
# Validation Loss = 0.285
# Epoch=5, batch = 0 of 4000, loss=1.249, LR=9.549150281252633e-05
# Validation Loss = 0.068
# Epoch=5, batch = 1000 of 4000, loss=1.205, LR=9.549150281252633e-05
# Validation Loss = 0.197
# Epoch=5, batch = 2000 of 4000, loss=1.173, LR=9.549150281252633e-05
# Validation Loss = 0.000
# Epoch=5, batch = 3000 of 4000, loss=1.147, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.002
# Epoch=1, batch = 0 of 4000, loss=1.166, LR=0.001
# Validation Loss = 0.241
# Epoch=1, batch = 1000 of 4000, loss=1.262, LR=0.001
# Validation Loss = 0.592
# Epoch=1, batch = 2000 of 4000, loss=1.279, LR=0.001
# Validation Loss = 0.450
# Epoch=1, batch = 3000 of 4000, loss=1.179, LR=0.001
# Validation Loss = 1.073
# Epoch=2, batch = 0 of 4000, loss=1.536, LR=0.0009755282581475768
# Validation Loss = 0.828
# Epoch=2, batch = 1000 of 4000, loss=2.712, LR=0.0009755282581475768
# Validation Loss = 0.160
# Epoch=2, batch = 2000 of 4000, loss=1.136, LR=0.0009755282581475768
# Validation Loss = 0.158
# Epoch=2, batch = 3000 of 4000, loss=1.096, LR=0.0009755282581475768
# Validation Loss = 1.221
# Epoch=3, batch = 0 of 4000, loss=1.688, LR=0.0009045084971874736
# Validation Loss = 4.152
# Epoch=3, batch = 1000 of 4000, loss=3.879, LR=0.0009045084971874736
# Validation Loss = 0.277
# Epoch=3, batch = 2000 of 4000, loss=1.910, LR=0.0009045084971874736
# Validation Loss = 0.217
# Epoch=3, batch = 3000 of 4000, loss=1.204, LR=0.0009045084971874736
# Validation Loss = 4.389
# Epoch=4, batch = 0 of 4000, loss=3.955, LR=0.0007938926261462366
# Validation Loss = 0.211
# Epoch=4, batch = 1000 of 4000, loss=1.622, LR=0.0007938926261462366
# Validation Loss = 0.013
# Epoch=4, batch = 2000 of 4000, loss=1.272, LR=0.0007938926261462366
# Validation Loss = 1.492
# Epoch=4, batch = 3000 of 4000, loss=1.896, LR=0.0007938926261462366
# Validation Loss = 0.070
# Epoch=5, batch = 0 of 4000, loss=1.126, LR=0.0006545084971874737
# Validation Loss = 0.025
# Epoch=5, batch = 1000 of 4000, loss=1.277, LR=0.0006545084971874737
# Validation Loss = 0.150
# Epoch=5, batch = 2000 of 4000, loss=1.048, LR=0.0006545084971874737
# Validation Loss = 0.119
# Epoch=5, batch = 3000 of 4000, loss=1.023, LR=0.0006545084971874737
# Validation Loss = 0.070
# Epoch=6, batch = 0 of 4000, loss=1.007, LR=0.0005
# Validation Loss = 0.033
# Epoch=6, batch = 1000 of 4000, loss=1.372, LR=0.0005
# Validation Loss = 0.002
# Epoch=6, batch = 2000 of 4000, loss=1.251, LR=0.0005
# Validation Loss = 0.621
# Epoch=6, batch = 3000 of 4000, loss=1.309, LR=0.0005
# Validation Loss = 0.122
# Epoch=7, batch = 0 of 4000, loss=1.092, LR=0.00034549150281252633
# Validation Loss = 0.514
# Epoch=7, batch = 1000 of 4000, loss=1.245, LR=0.00034549150281252633
# Validation Loss = 0.097
# Epoch=7, batch = 2000 of 4000, loss=1.036, LR=0.00034549150281252633
# Validation Loss = 0.033
# Epoch=7, batch = 3000 of 4000, loss=1.057, LR=0.00034549150281252633
# Validation Loss = 0.021
# Epoch=8, batch = 0 of 4000, loss=1.110, LR=0.0002061073738537635
# Validation Loss = 0.020
# Epoch=8, batch = 1000 of 4000, loss=0.952, LR=0.0002061073738537635
# Validation Loss = 0.042
# Epoch=8, batch = 2000 of 4000, loss=1.207, LR=0.0002061073738537635
# Validation Loss = 0.044
# Epoch=8, batch = 3000 of 4000, loss=1.138, LR=0.0002061073738537635
# Validation Loss = 0.025
# Epoch=9, batch = 0 of 4000, loss=0.987, LR=9.549150281252634e-05
# Validation Loss = 0.018
# Epoch=9, batch = 1000 of 4000, loss=0.982, LR=9.549150281252634e-05
# Validation Loss = 0.009
# Epoch=9, batch = 2000 of 4000, loss=1.060, LR=9.549150281252634e-05
# Validation Loss = 0.000
# Epoch=9, batch = 3000 of 4000, loss=1.090, LR=9.549150281252634e-05
# Validation Loss = 0.024
# Epoch=10, batch = 0 of 4000, loss=0.941, LR=2.4471741852423235e-05
# Validation Loss = 0.011
# Epoch=10, batch = 1000 of 4000, loss=0.924, LR=2.4471741852423235e-05
# Validation Loss = 0.031
# Epoch=10, batch = 2000 of 4000, loss=0.994, LR=2.4471741852423235e-05
# Validation Loss = 0.036
# Epoch=10, batch = 3000 of 4000, loss=0.927, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.000
# Epoch=1, batch = 0 of 4000, loss=0.989, LR=0.001
# Validation Loss = 0.087
# Epoch=1, batch = 1000 of 4000, loss=1.097, LR=0.001
# Validation Loss = 0.028
# Epoch=1, batch = 2000 of 4000, loss=1.072, LR=0.001
# Validation Loss = 0.074
# Epoch=1, batch = 3000 of 4000, loss=1.218, LR=0.001
# Validation Loss = 0.064
# Epoch=2, batch = 0 of 4000, loss=1.199, LR=0.0009938441702975688
# Validation Loss = 0.514
# Epoch=2, batch = 1000 of 4000, loss=1.601, LR=0.0009938441702975688
# Validation Loss = 1.353
# Epoch=2, batch = 2000 of 4000, loss=2.357, LR=0.0009938441702975688
# Validation Loss = 0.010
# Epoch=2, batch = 3000 of 4000, loss=1.102, LR=0.0009938441702975688
# Validation Loss = 0.065
# Epoch=3, batch = 0 of 4000, loss=1.113, LR=0.0009755282581475768
# Validation Loss = 2.690
# Epoch=3, batch = 1000 of 4000, loss=3.642, LR=0.0009755282581475768
# Validation Loss = 0.534
# Epoch=3, batch = 2000 of 4000, loss=1.457, LR=0.0009755282581475768
# Validation Loss = 0.081
# Epoch=3, batch = 3000 of 4000, loss=1.483, LR=0.0009755282581475768
# Validation Loss = 0.007
# Epoch=4, batch = 0 of 4000, loss=0.996, LR=0.0009455032620941839
# Validation Loss = 0.079
# Epoch=4, batch = 1000 of 4000, loss=1.039, LR=0.0009455032620941839
# Validation Loss = 0.097
# Epoch=4, batch = 2000 of 4000, loss=0.865, LR=0.0009455032620941839
# Validation Loss = 0.104
# Epoch=4, batch = 3000 of 4000, loss=0.997, LR=0.0009455032620941839
# Validation Loss = 0.642
# Epoch=5, batch = 0 of 4000, loss=1.383, LR=0.0009045084971874737
# Validation Loss = 0.019
# Epoch=5, batch = 1000 of 4000, loss=0.974, LR=0.0009045084971874737
# Validation Loss = 0.124
# Epoch=5, batch = 2000 of 4000, loss=1.034, LR=0.0009045084971874737
# Validation Loss = 0.000
# Epoch=5, batch = 3000 of 4000, loss=0.993, LR=0.0009045084971874737
# Validation Loss = 0.146
# Epoch=6, batch = 0 of 4000, loss=1.382, LR=0.0008535533905932737
# Validation Loss = 0.000
# Epoch=6, batch = 1000 of 4000, loss=0.971, LR=0.0008535533905932737
# Validation Loss = 0.577
# Epoch=6, batch = 2000 of 4000, loss=1.495, LR=0.0008535533905932737
# Validation Loss = 0.422
# Epoch=6, batch = 3000 of 4000, loss=1.284, LR=0.0008535533905932737
# Validation Loss = 0.295
# Epoch=7, batch = 0 of 4000, loss=1.188, LR=0.0007938926261462366
# Validation Loss = 0.039
# Epoch=7, batch = 1000 of 4000, loss=1.062, LR=0.0007938926261462366
# Validation Loss = 0.857
# Epoch=7, batch = 2000 of 4000, loss=1.802, LR=0.0007938926261462366
# Validation Loss = 0.006
# Epoch=7, batch = 3000 of 4000, loss=1.128, LR=0.0007938926261462366
# Validation Loss = 0.003
# Epoch=8, batch = 0 of 4000, loss=0.915, LR=0.0007269952498697733
# Validation Loss = 0.753
# Epoch=8, batch = 1000 of 4000, loss=1.647, LR=0.0007269952498697733
# Validation Loss = 0.447
# Epoch=8, batch = 2000 of 4000, loss=1.740, LR=0.0007269952498697733
# Validation Loss = 0.051
# Epoch=8, batch = 3000 of 4000, loss=1.092, LR=0.0007269952498697733
# Validation Loss = 1.032
# Epoch=9, batch = 0 of 4000, loss=1.786, LR=0.0006545084971874737
# Validation Loss = 0.277
# Epoch=9, batch = 1000 of 4000, loss=1.204, LR=0.0006545084971874737
# Validation Loss = 0.016
# Epoch=9, batch = 2000 of 4000, loss=0.966, LR=0.0006545084971874737
# Validation Loss = 0.323
# Epoch=9, batch = 3000 of 4000, loss=1.167, LR=0.0006545084971874737
# Validation Loss = 1.354
# Epoch=10, batch = 0 of 4000, loss=1.901, LR=0.0005782172325201155
# Validation Loss = 0.665
# Epoch=10, batch = 1000 of 4000, loss=1.716, LR=0.0005782172325201155
# Validation Loss = 0.045
# Epoch=10, batch = 2000 of 4000, loss=1.017, LR=0.0005782172325201155
# Validation Loss = 0.465
# Epoch=10, batch = 3000 of 4000, loss=1.334, LR=0.0005782172325201155
# Validation Loss = 0.124
# Epoch=11, batch = 0 of 4000, loss=1.323, LR=0.0005
# Validation Loss = 0.168
# Epoch=11, batch = 1000 of 4000, loss=1.250, LR=0.0005
# Validation Loss = 0.276
# Epoch=11, batch = 2000 of 4000, loss=1.285, LR=0.0005
# Validation Loss = 0.006
# Epoch=11, batch = 3000 of 4000, loss=0.941, LR=0.0005
# Validation Loss = 0.179
# Epoch=12, batch = 0 of 4000, loss=1.229, LR=0.0004217827674798847
# Validation Loss = 0.134
# Epoch=12, batch = 1000 of 4000, loss=1.040, LR=0.0004217827674798847
# Validation Loss = 0.295
# Epoch=12, batch = 2000 of 4000, loss=1.252, LR=0.0004217827674798847
# Validation Loss = 0.023
# Epoch=12, batch = 3000 of 4000, loss=0.892, LR=0.0004217827674798847
# Validation Loss = 0.012
# Epoch=13, batch = 0 of 4000, loss=0.932, LR=0.00034549150281252633
# Validation Loss = 0.031
# Epoch=13, batch = 1000 of 4000, loss=1.049, LR=0.00034549150281252633
# Validation Loss = 0.268
# Epoch=13, batch = 2000 of 4000, loss=1.207, LR=0.00034549150281252633
# Validation Loss = 0.134
# Epoch=13, batch = 3000 of 4000, loss=1.076, LR=0.00034549150281252633
# Validation Loss = 0.019
# Epoch=14, batch = 0 of 4000, loss=0.929, LR=0.00027300475013022663
# Validation Loss = 0.004
# Epoch=14, batch = 1000 of 4000, loss=0.959, LR=0.00027300475013022663
# Validation Loss = 0.076
# Epoch=14, batch = 2000 of 4000, loss=1.046, LR=0.00027300475013022663
# Validation Loss = 0.004
# Epoch=14, batch = 3000 of 4000, loss=0.923, LR=0.00027300475013022663
# Validation Loss = 0.053
# Epoch=15, batch = 0 of 4000, loss=0.947, LR=0.00020610737385376348
# Validation Loss = 0.068
# Epoch=15, batch = 1000 of 4000, loss=1.023, LR=0.00020610737385376348
# Validation Loss = 0.009
# Epoch=15, batch = 2000 of 4000, loss=0.931, LR=0.00020610737385376348
# Validation Loss = 0.006
# Epoch=15, batch = 3000 of 4000, loss=0.876, LR=0.00020610737385376348
# Validation Loss = 0.001
# Epoch=16, batch = 0 of 4000, loss=0.961, LR=0.00014644660940672625
# Validation Loss = 0.000
# Epoch=16, batch = 1000 of 4000, loss=0.902, LR=0.00014644660940672625
# Validation Loss = 0.010
# Epoch=16, batch = 2000 of 4000, loss=0.946, LR=0.00014644660940672625
# Validation Loss = 0.006
# Epoch=16, batch = 3000 of 4000, loss=0.955, LR=0.00014644660940672625
# Validation Loss = 0.078
# Epoch=17, batch = 0 of 4000, loss=0.990, LR=9.549150281252631e-05
# Validation Loss = 0.003
# Epoch=17, batch = 1000 of 4000, loss=0.872, LR=9.549150281252631e-05
# Validation Loss = 0.000
# Epoch=17, batch = 2000 of 4000, loss=0.921, LR=9.549150281252631e-05
# Validation Loss = 0.005
# Epoch=17, batch = 3000 of 4000, loss=0.951, LR=9.549150281252631e-05
# Validation Loss = 0.064
# Epoch=18, batch = 0 of 4000, loss=0.989, LR=5.4496737905816096e-05
# Validation Loss = 0.002
# Epoch=18, batch = 1000 of 4000, loss=0.959, LR=5.4496737905816096e-05
# Validation Loss = 0.003
# Epoch=18, batch = 2000 of 4000, loss=0.847, LR=5.4496737905816096e-05
# Validation Loss = 0.009
# Epoch=18, batch = 3000 of 4000, loss=0.907, LR=5.4496737905816096e-05
# Validation Loss = 0.018
# Epoch=19, batch = 0 of 4000, loss=1.014, LR=2.447174185242323e-05
# Validation Loss = 0.012
# Epoch=19, batch = 1000 of 4000, loss=0.887, LR=2.447174185242323e-05
# Validation Loss = 0.006
# Epoch=19, batch = 2000 of 4000, loss=0.857, LR=2.447174185242323e-05
# Validation Loss = 0.022
# Epoch=19, batch = 3000 of 4000, loss=0.936, LR=2.447174185242323e-05
# Validation Loss = 0.007
# Epoch=20, batch = 0 of 4000, loss=0.932, LR=6.15582970243117e-06
# Validation Loss = 0.005
# Epoch=20, batch = 1000 of 4000, loss=0.823, LR=6.15582970243117e-06
# Validation Loss = 0.006
# Epoch=20, batch = 2000 of 4000, loss=0.904, LR=6.15582970243117e-06
# Validation Loss = 0.006
# Epoch=20, batch = 3000 of 4000, loss=0.917, LR=6.15582970243117e-06
# Finished training model for channel 183+-7V.

# %%
#General parameters:
input_size = nchans - 1 + 1 #Remaining channels + surface type

# %%
'''

GMI CHANNEL PREDICTION MODEL:
    2: Non-Ocean Surfaces

'''

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = sfctype > 1

    Tbs = f.Tbs.values[correct_sfc,:]
    sfctype = sfctype[correct_sfc]

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

sfctype_train = sfctype[train_indcs].astype(np.float32)
sfctype_test  = sfctype[test_indcs].astype(np.float32)
sfctype_val   = sfctype[val_indcs].astype(np.float32)

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train, shuffled_indcs = array_funcs.shuffle_data(Tbs_train, axis=0, return_indcs=True)
sfctype_train = sfctype_train[shuffled_indcs]

# %%
sfctype_train, sfctype_test, sfctype_val
# Out:
# (array([ 8.,  5.,  2., ...,  5.,  9., 17.],
#        shape=(14253019,), dtype=float32),
#  array([10., 10., 10., ..., 18., 18., 18.], shape=(1781627,), dtype=float32),
#  array([18., 18., 18., ...,  2.,  2.,  2.], shape=(1781628,), dtype=float32))

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    print(channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)

    x_train = np.concatenate((x_train, sfctype_train[:,None]), axis=1)
    x_test  = np.concatenate((x_test,  sfctype_test[:,None]), axis=1)
    x_val   = np.concatenate((x_val,   sfctype_val[:,None]), axis=1)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_nonocean.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_nonocean.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 10V
# Training stage: 1
# Validation Loss = 55840.812
# Epoch=1, batch = 0 of 14253, loss=60496.824, LR=0.001
# Validation Loss = 0.734
# Epoch=1, batch = 1000 of 14253, loss=8.429, LR=0.001
# Validation Loss = 0.035
# Epoch=1, batch = 2000 of 14253, loss=6.647, LR=0.001
# Validation Loss = 6.607
# Epoch=1, batch = 3000 of 14253, loss=8.446, LR=0.001
# Validation Loss = 0.571
# Epoch=1, batch = 4000 of 14253, loss=10.387, LR=0.001
# Validation Loss = 2.909
# Epoch=1, batch = 5000 of 14253, loss=4.808, LR=0.001
# Validation Loss = 16.754
# Epoch=1, batch = 6000 of 14253, loss=10.081, LR=0.001
# Validation Loss = 0.420
# Epoch=1, batch = 7000 of 14253, loss=7.081, LR=0.001
# Validation Loss = 14.798
# Epoch=1, batch = 8000 of 14253, loss=6.174, LR=0.001
# Validation Loss = 1.715
# Epoch=1, batch = 9000 of 14253, loss=4.635, LR=0.001
# Validation Loss = 0.753
# Epoch=1, batch = 10000 of 14253, loss=3.960, LR=0.001
# Validation Loss = 2.848
# Epoch=1, batch = 11000 of 14253, loss=3.637, LR=0.001
# Validation Loss = 2.215
# Epoch=1, batch = 12000 of 14253, loss=3.395, LR=0.001
# Validation Loss = 1.015
# Epoch=1, batch = 13000 of 14253, loss=3.799, LR=0.001
# Validation Loss = 0.135
# Epoch=12, batch = 6000 of 14253, loss=0.741, LR=0.0004217827674798847
# Validation Loss = 0.717
# Epoch=12, batch = 7000 of 14253, loss=1.144, LR=0.0004217827674798847
# Validation Loss = 0.045
# Epoch=12, batch = 8000 of 14253, loss=0.862, LR=0.0004217827674798847
# Validation Loss = 0.001
# Epoch=12, batch = 9000 of 14253, loss=0.736, LR=0.0004217827674798847
# Validation Loss = 0.000
# Epoch=12, batch = 10000 of 14253, loss=0.782, LR=0.0004217827674798847
# Validation Loss = 0.171
# Epoch=12, batch = 11000 of 14253, loss=0.887, LR=0.0004217827674798847
# Validation Loss = 0.024
# Epoch=12, batch = 12000 of 14253, loss=0.791, LR=0.0004217827674798847
# Validation Loss = 0.001
# Epoch=12, batch = 13000 of 14253, loss=0.783, LR=0.0004217827674798847
# Validation Loss = 0.172
# Epoch=12, batch = 14000 of 14253, loss=1.065, LR=0.0004217827674798847
# Validation Loss = 0.118
# Epoch=13, batch = 0 of 14253, loss=0.791, LR=0.00034549150281252633
# Validation Loss = 0.101
# Epoch=13, batch = 1000 of 14253, loss=0.754, LR=0.00034549150281252633
# Validation Loss = 0.120
# Epoch=13, batch = 2000 of 14253, loss=0.867, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=13, batch = 3000 of 14253, loss=0.844, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=13, batch = 4000 of 14253, loss=0.812, LR=0.00034549150281252633
# Validation Loss = 0.010
# Epoch=13, batch = 5000 of 14253, loss=0.948, LR=0.00034549150281252633
# Validation Loss = 0.021
# Epoch=13, batch = 6000 of 14253, loss=0.818, LR=0.00034549150281252633
# Validation Loss = 0.174
# Epoch=13, batch = 7000 of 14253, loss=0.813, LR=0.00034549150281252633
# Validation Loss = 0.016
# Epoch=13, batch = 8000 of 14253, loss=0.716, LR=0.00034549150281252633
# Validation Loss = 0.349
# Epoch=13, batch = 9000 of 14253, loss=0.899, LR=0.00034549150281252633
# Validation Loss = 0.283
# Epoch=13, batch = 10000 of 14253, loss=0.917, LR=0.00034549150281252633
# Validation Loss = 0.015
# Epoch=13, batch = 11000 of 14253, loss=0.851, LR=0.00034549150281252633
# Validation Loss = 0.291
# Epoch=13, batch = 12000 of 14253, loss=0.832, LR=0.00034549150281252633
# Validation Loss = 0.029
# Epoch=13, batch = 13000 of 14253, loss=0.799, LR=0.00034549150281252633
# Validation Loss = 0.003
# Epoch=13, batch = 14000 of 14253, loss=0.885, LR=0.00034549150281252633
# Validation Loss = 0.029
# Epoch=14, batch = 0 of 14253, loss=0.748, LR=0.00027300475013022663
# Validation Loss = 0.017
# Epoch=14, batch = 1000 of 14253, loss=0.895, LR=0.00027300475013022663
# Validation Loss = 0.006
# Epoch=14, batch = 2000 of 14253, loss=0.815, LR=0.00027300475013022663
# Validation Loss = 0.011
# Epoch=14, batch = 3000 of 14253, loss=0.812, LR=0.00027300475013022663
# Validation Loss = 0.140
# Epoch=14, batch = 4000 of 14253, loss=0.836, LR=0.00027300475013022663
# Validation Loss = 0.204
# Epoch=14, batch = 5000 of 14253, loss=0.904, LR=0.00027300475013022663
# Validation Loss = 0.153
# Epoch=14, batch = 6000 of 14253, loss=0.750, LR=0.00027300475013022663
# Validation Loss = 0.108
# Epoch=14, batch = 7000 of 14253, loss=0.800, LR=0.00027300475013022663
# Validation Loss = 0.034
# Epoch=14, batch = 8000 of 14253, loss=0.796, LR=0.00027300475013022663
# Validation Loss = 0.005
# Epoch=14, batch = 9000 of 14253, loss=0.913, LR=0.00027300475013022663
# Validation Loss = 0.054
# Epoch=14, batch = 10000 of 14253, loss=0.910, LR=0.00027300475013022663
# Validation Loss = 0.169
# Epoch=14, batch = 11000 of 14253, loss=0.870, LR=0.00027300475013022663
# Validation Loss = 0.009
# Epoch=14, batch = 12000 of 14253, loss=0.861, LR=0.00027300475013022663
# Validation Loss = 0.002
# Epoch=14, batch = 13000 of 14253, loss=0.710, LR=0.00027300475013022663
# Validation Loss = 0.035
# Epoch=14, batch = 14000 of 14253, loss=0.792, LR=0.00027300475013022663
# Validation Loss = 0.039
# Epoch=15, batch = 0 of 14253, loss=0.816, LR=0.00020610737385376348
# Validation Loss = 0.001
# Epoch=15, batch = 1000 of 14253, loss=0.950, LR=0.00020610737385376348
# Validation Loss = 0.006
# Epoch=15, batch = 2000 of 14253, loss=0.776, LR=0.00020610737385376348
# Validation Loss = 0.078
# Epoch=15, batch = 3000 of 14253, loss=0.776, LR=0.00020610737385376348
# Validation Loss = 0.150
# Epoch=15, batch = 4000 of 14253, loss=0.805, LR=0.00020610737385376348
# Validation Loss = 0.048
# Epoch=15, batch = 5000 of 14253, loss=0.721, LR=0.00020610737385376348
# Validation Loss = 0.072
# Epoch=15, batch = 6000 of 14253, loss=0.822, LR=0.00020610737385376348
# Validation Loss = 0.004
# Epoch=15, batch = 7000 of 14253, loss=0.953, LR=0.00020610737385376348
# Validation Loss = 0.000
# Epoch=15, batch = 8000 of 14253, loss=0.709, LR=0.00020610737385376348
# Validation Loss = 0.108
# Epoch=15, batch = 9000 of 14253, loss=0.765, LR=0.00020610737385376348
# Validation Loss = 0.017
# Epoch=15, batch = 10000 of 14253, loss=0.842, LR=0.00020610737385376348
# Validation Loss = 0.021
# Epoch=15, batch = 11000 of 14253, loss=0.750, LR=0.00020610737385376348
# Validation Loss = 0.004
# Epoch=15, batch = 12000 of 14253, loss=0.746, LR=0.00020610737385376348
# Validation Loss = 0.046
# Epoch=15, batch = 13000 of 14253, loss=0.719, LR=0.00020610737385376348
# Validation Loss = 0.012
# Epoch=15, batch = 14000 of 14253, loss=0.833, LR=0.00020610737385376348
# Validation Loss = 0.068
# Epoch=16, batch = 0 of 14253, loss=0.774, LR=0.00014644660940672625
# Validation Loss = 0.258
# Epoch=16, batch = 1000 of 14253, loss=0.866, LR=0.00014644660940672625
# Validation Loss = 0.034
# Epoch=16, batch = 2000 of 14253, loss=0.817, LR=0.00014644660940672625
# Validation Loss = 0.005
# Epoch=16, batch = 3000 of 14253, loss=0.674, LR=0.00014644660940672625
# Validation Loss = 0.013
# Epoch=16, batch = 4000 of 14253, loss=0.800, LR=0.00014644660940672625
# Validation Loss = 0.000
# Epoch=16, batch = 5000 of 14253, loss=0.661, LR=0.00014644660940672625
# Validation Loss = 0.125
# Epoch=16, batch = 6000 of 14253, loss=0.773, LR=0.00014644660940672625
# Validation Loss = 0.000
# Epoch=16, batch = 7000 of 14253, loss=0.755, LR=0.00014644660940672625
# Validation Loss = 0.008
# Epoch=16, batch = 8000 of 14253, loss=0.829, LR=0.00014644660940672625
# Validation Loss = 0.078
# Epoch=16, batch = 9000 of 14253, loss=0.756, LR=0.00014644660940672625
# Validation Loss = 0.004
# Epoch=16, batch = 10000 of 14253, loss=0.849, LR=0.00014644660940672625
# Validation Loss = 0.002
# Epoch=16, batch = 11000 of 14253, loss=0.774, LR=0.00014644660940672625
# Validation Loss = 0.052
# Epoch=16, batch = 12000 of 14253, loss=0.911, LR=0.00014644660940672625
# Validation Loss = 0.001
# Epoch=16, batch = 13000 of 14253, loss=0.770, LR=0.00014644660940672625
# Validation Loss = 0.009
# Epoch=16, batch = 14000 of 14253, loss=0.792, LR=0.00014644660940672625
# Validation Loss = 0.008
# Epoch=17, batch = 0 of 14253, loss=0.760, LR=9.549150281252631e-05
# Validation Loss = 0.089
# Epoch=17, batch = 1000 of 14253, loss=0.806, LR=9.549150281252631e-05
# Validation Loss = 0.002
# Epoch=17, batch = 2000 of 14253, loss=0.729, LR=9.549150281252631e-05
# Validation Loss = 0.016
# Epoch=17, batch = 3000 of 14253, loss=0.703, LR=9.549150281252631e-05
# Validation Loss = 0.117
# Epoch=17, batch = 4000 of 14253, loss=0.826, LR=9.549150281252631e-05
# Validation Loss = 0.000
# Epoch=17, batch = 5000 of 14253, loss=0.740, LR=9.549150281252631e-05
# Validation Loss = 0.016
# Epoch=17, batch = 6000 of 14253, loss=0.812, LR=9.549150281252631e-05
# Validation Loss = 0.020
# Epoch=17, batch = 7000 of 14253, loss=0.745, LR=9.549150281252631e-05
# Validation Loss = 0.020
# Epoch=17, batch = 8000 of 14253, loss=0.796, LR=9.549150281252631e-05
# Validation Loss = 0.001
# Epoch=17, batch = 9000 of 14253, loss=0.807, LR=9.549150281252631e-05
# Validation Loss = 0.026
# Epoch=17, batch = 10000 of 14253, loss=0.698, LR=9.549150281252631e-05
# Validation Loss = 0.001
# Epoch=17, batch = 11000 of 14253, loss=0.773, LR=9.549150281252631e-05
# Validation Loss = 0.002
# Epoch=17, batch = 12000 of 14253, loss=0.696, LR=9.549150281252631e-05
# Validation Loss = 0.008
# Epoch=17, batch = 13000 of 14253, loss=0.693, LR=9.549150281252631e-05
# Validation Loss = 0.033
# Epoch=17, batch = 14000 of 14253, loss=0.835, LR=9.549150281252631e-05
# Validation Loss = 0.005
# Epoch=18, batch = 0 of 14253, loss=0.811, LR=5.4496737905816096e-05
# Validation Loss = 0.050
# Epoch=18, batch = 1000 of 14253, loss=0.745, LR=5.4496737905816096e-05
# Validation Loss = 0.033
# Epoch=18, batch = 2000 of 14253, loss=0.855, LR=5.4496737905816096e-05
# Validation Loss = 0.006
# Epoch=18, batch = 3000 of 14253, loss=0.729, LR=5.4496737905816096e-05
# Validation Loss = 0.007
# Epoch=18, batch = 4000 of 14253, loss=0.770, LR=5.4496737905816096e-05
# Validation Loss = 0.020
# Epoch=18, batch = 5000 of 14253, loss=0.713, LR=5.4496737905816096e-05
# Validation Loss = 0.012
# Epoch=18, batch = 6000 of 14253, loss=0.808, LR=5.4496737905816096e-05
# Validation Loss = 0.020
# Epoch=18, batch = 7000 of 14253, loss=0.872, LR=5.4496737905816096e-05
# Validation Loss = 0.034
# Epoch=18, batch = 8000 of 14253, loss=0.788, LR=5.4496737905816096e-05
# Validation Loss = 0.018
# Epoch=18, batch = 9000 of 14253, loss=0.816, LR=5.4496737905816096e-05
# Validation Loss = 0.011
# Epoch=18, batch = 10000 of 14253, loss=0.687, LR=5.4496737905816096e-05
# Validation Loss = 0.015
# Epoch=18, batch = 11000 of 14253, loss=0.846, LR=5.4496737905816096e-05
# Validation Loss = 0.007
# Epoch=18, batch = 12000 of 14253, loss=0.801, LR=5.4496737905816096e-05
# Validation Loss = 0.014
# Epoch=18, batch = 13000 of 14253, loss=0.819, LR=5.4496737905816096e-05
# Validation Loss = 0.001
# Epoch=18, batch = 14000 of 14253, loss=0.727, LR=5.4496737905816096e-05
# Validation Loss = 0.002
# Epoch=19, batch = 0 of 14253, loss=0.874, LR=2.447174185242323e-05
# Validation Loss = 0.000
# Epoch=19, batch = 1000 of 14253, loss=0.844, LR=2.447174185242323e-05
# Validation Loss = 0.000
# Epoch=19, batch = 2000 of 14253, loss=0.781, LR=2.447174185242323e-05
# Validation Loss = 0.033
# Epoch=19, batch = 3000 of 14253, loss=0.764, LR=2.447174185242323e-05
# Validation Loss = 0.000
# Epoch=19, batch = 4000 of 14253, loss=0.698, LR=2.447174185242323e-05
# Validation Loss = 0.018
# Epoch=19, batch = 5000 of 14253, loss=0.706, LR=2.447174185242323e-05
# Validation Loss = 0.015
# Epoch=19, batch = 6000 of 14253, loss=0.633, LR=2.447174185242323e-05
# Validation Loss = 0.009
# Epoch=19, batch = 7000 of 14253, loss=0.715, LR=2.447174185242323e-05
# Validation Loss = 0.025
# Epoch=19, batch = 8000 of 14253, loss=0.716, LR=2.447174185242323e-05
# Validation Loss = 0.009
# Epoch=19, batch = 9000 of 14253, loss=0.633, LR=2.447174185242323e-05
# Validation Loss = 0.013
# Epoch=19, batch = 10000 of 14253, loss=0.660, LR=2.447174185242323e-05
# Validation Loss = 0.055
# Epoch=19, batch = 11000 of 14253, loss=0.738, LR=2.447174185242323e-05
# Validation Loss = 0.031
# Epoch=19, batch = 12000 of 14253, loss=0.756, LR=2.447174185242323e-05
# Validation Loss = 0.007
# Epoch=19, batch = 13000 of 14253, loss=0.684, LR=2.447174185242323e-05
# Validation Loss = 0.005
# Epoch=19, batch = 14000 of 14253, loss=0.721, LR=2.447174185242323e-05
# Validation Loss = 0.000
# Epoch=20, batch = 0 of 14253, loss=0.710, LR=6.15582970243117e-06
# Validation Loss = 0.012
# Epoch=20, batch = 1000 of 14253, loss=0.840, LR=6.15582970243117e-06
# Validation Loss = 0.012
# Epoch=20, batch = 2000 of 14253, loss=0.718, LR=6.15582970243117e-06
# Validation Loss = 0.015
# Epoch=20, batch = 3000 of 14253, loss=0.718, LR=6.15582970243117e-06
# Validation Loss = 0.005
# Epoch=20, batch = 4000 of 14253, loss=0.678, LR=6.15582970243117e-06
# Validation Loss = 0.008
# Epoch=20, batch = 5000 of 14253, loss=0.680, LR=6.15582970243117e-06
# Validation Loss = 0.015
# Epoch=20, batch = 6000 of 14253, loss=0.872, LR=6.15582970243117e-06
# Validation Loss = 0.006
# Epoch=20, batch = 7000 of 14253, loss=0.773, LR=6.15582970243117e-06
# Validation Loss = 0.006
# Epoch=20, batch = 8000 of 14253, loss=0.747, LR=6.15582970243117e-06
# Validation Loss = 0.008
# Epoch=20, batch = 9000 of 14253, loss=0.765, LR=6.15582970243117e-06
# Validation Loss = 0.002
# Epoch=20, batch = 10000 of 14253, loss=0.776, LR=6.15582970243117e-06
# Validation Loss = 0.004
# Epoch=20, batch = 11000 of 14253, loss=0.802, LR=6.15582970243117e-06
# Validation Loss = 0.011
# Epoch=20, batch = 12000 of 14253, loss=0.830, LR=6.15582970243117e-06
# Validation Loss = 0.005
# Epoch=20, batch = 13000 of 14253, loss=0.748, LR=6.15582970243117e-06
# Validation Loss = 0.003
# Epoch=20, batch = 14000 of 14253, loss=0.705, LR=6.15582970243117e-06
# Finished training model for channel 37V.
# 37H
# Training stage: 1
# Validation Loss = 42538.199
# Epoch=1, batch = 0 of 14253, loss=57278.664, LR=0.001
# Validation Loss = 6.470
# Epoch=1, batch = 1000 of 14253, loss=7.186, LR=0.001
# Validation Loss = 4.247
# Epoch=1, batch = 2000 of 14253, loss=3.937, LR=0.001
# Validation Loss = 2.169
# Epoch=1, batch = 3000 of 14253, loss=3.246, LR=0.001
# Validation Loss = 6.739
# Epoch=1, batch = 4000 of 14253, loss=3.105, LR=0.001
# Validation Loss = 0.056
# Epoch=1, batch = 5000 of 14253, loss=5.123, LR=0.001
# Validation Loss = 0.592
# Epoch=1, batch = 6000 of 14253, loss=2.783, LR=0.001
# Validation Loss = 3.306
# Epoch=1, batch = 7000 of 14253, loss=2.639, LR=0.001
# Validation Loss = 5.837
# Epoch=1, batch = 8000 of 14253, loss=4.898, LR=0.001
# Validation Loss = 0.744
# Epoch=1, batch = 9000 of 14253, loss=4.032, LR=0.001
# Validation Loss = 0.723
# Epoch=1, batch = 10000 of 14253, loss=2.617, LR=0.001
# Validation Loss = 4.286
# Epoch=1, batch = 11000 of 14253, loss=2.062, LR=0.001
# Validation Loss = 0.113
# Epoch=1, batch = 12000 of 14253, loss=3.275, LR=0.001
# Validation Loss = 0.527
# Epoch=1, batch = 13000 of 14253, loss=2.066, LR=0.001
# Validation Loss = 2.927
# Epoch=1, batch = 14000 of 14253, loss=2.212, LR=0.001
# Validation Loss = 2.072
# Epoch=2, batch = 0 of 14253, loss=1.744, LR=0.0009045084971874737
# Validation Loss = 0.350
# Epoch=2, batch = 1000 of 14253, loss=1.959, LR=0.0009045084971874737
# Validation Loss = 2.145
# Epoch=2, batch = 2000 of 14253, loss=2.326, LR=0.0009045084971874737
# Validation Loss = 1.249
# Epoch=2, batch = 3000 of 14253, loss=1.695, LR=0.0009045084971874737
# Validation Loss = 0.740
# Epoch=2, batch = 4000 of 14253, loss=6.636, LR=0.0009045084971874737
# Validation Loss = 0.119
# Epoch=2, batch = 5000 of 14253, loss=2.180, LR=0.0009045084971874737
# Validation Loss = 0.009
# Epoch=2, batch = 6000 of 14253, loss=2.399, LR=0.0009045084971874737
# Validation Loss = 2.333
# Epoch=2, batch = 7000 of 14253, loss=2.204, LR=0.0009045084971874737
# Validation Loss = 0.208
# Epoch=2, batch = 8000 of 14253, loss=3.743, LR=0.0009045084971874737
# Validation Loss = 0.979
# Epoch=2, batch = 9000 of 14253, loss=1.710, LR=0.0009045084971874737
# Validation Loss = 1.584
# Epoch=2, batch = 10000 of 14253, loss=1.937, LR=0.0009045084971874737
# Validation Loss = 0.052
# Epoch=2, batch = 11000 of 14253, loss=2.394, LR=0.0009045084971874737
# Validation Loss = 0.623
# Epoch=2, batch = 12000 of 14253, loss=1.618, LR=0.0009045084971874737
# Validation Loss = 0.331
# Epoch=2, batch = 13000 of 14253, loss=4.798, LR=0.0009045084971874737
# Validation Loss = 0.327
# Epoch=2, batch = 14000 of 14253, loss=1.798, LR=0.0009045084971874737
# Validation Loss = 2.040
# Epoch=3, batch = 0 of 14253, loss=2.089, LR=0.0006545084971874737
# Validation Loss = 5.058
# Epoch=3, batch = 1000 of 14253, loss=3.628, LR=0.0006545084971874737
# Validation Loss = 0.490
# Epoch=3, batch = 2000 of 14253, loss=1.485, LR=0.0006545084971874737
# Validation Loss = 1.068
# Epoch=3, batch = 3000 of 14253, loss=1.944, LR=0.0006545084971874737
# Validation Loss = 0.217
# Epoch=3, batch = 4000 of 14253, loss=1.345, LR=0.0006545084971874737
# Validation Loss = 0.225
# Epoch=3, batch = 5000 of 14253, loss=2.029, LR=0.0006545084971874737
# Validation Loss = 0.097
# Epoch=3, batch = 6000 of 14253, loss=2.037, LR=0.0006545084971874737
# Validation Loss = 0.681
# Epoch=3, batch = 7000 of 14253, loss=1.601, LR=0.0006545084971874737
# Validation Loss = 0.964
# Epoch=3, batch = 8000 of 14253, loss=1.559, LR=0.0006545084971874737
# Validation Loss = 0.301
# Epoch=3, batch = 9000 of 14253, loss=3.338, LR=0.0006545084971874737
# Validation Loss = 1.123
# Epoch=3, batch = 10000 of 14253, loss=1.630, LR=0.0006545084971874737
# Validation Loss = 0.753
# Epoch=3, batch = 11000 of 14253, loss=1.588, LR=0.0006545084971874737
# Validation Loss = 0.544
# Epoch=3, batch = 12000 of 14253, loss=3.222, LR=0.0006545084971874737
# Validation Loss = 2.330
# Epoch=3, batch = 13000 of 14253, loss=2.504, LR=0.0006545084971874737
# Validation Loss = 1.192
# Epoch=3, batch = 14000 of 14253, loss=1.674, LR=0.0006545084971874737
# Validation Loss = 1.233
# Epoch=4, batch = 0 of 14253, loss=1.943, LR=0.00034549150281252633
# Validation Loss = 0.231
# Epoch=4, batch = 1000 of 14253, loss=1.471, LR=0.00034549150281252633
# Validation Loss = 1.372
# Epoch=4, batch = 2000 of 14253, loss=2.280, LR=0.00034549150281252633
# Validation Loss = 1.321
# Epoch=4, batch = 3000 of 14253, loss=1.905, LR=0.00034549150281252633
# Validation Loss = 0.983
# Epoch=4, batch = 4000 of 14253, loss=1.982, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=4, batch = 5000 of 14253, loss=2.725, LR=0.00034549150281252633
# Validation Loss = 1.291
# Epoch=4, batch = 6000 of 14253, loss=1.656, LR=0.00034549150281252633
# Validation Loss = 0.717
# Epoch=4, batch = 7000 of 14253, loss=1.436, LR=0.00034549150281252633
# Validation Loss = 0.640
# Epoch=4, batch = 8000 of 14253, loss=1.469, LR=0.00034549150281252633
# Validation Loss = 0.936
# Epoch=4, batch = 9000 of 14253, loss=1.814, LR=0.00034549150281252633
# Validation Loss = 0.730
# Epoch=4, batch = 10000 of 14253, loss=1.449, LR=0.00034549150281252633
# Validation Loss = 0.437
# Epoch=4, batch = 11000 of 14253, loss=1.419, LR=0.00034549150281252633
# Validation Loss = 0.876
# Epoch=4, batch = 12000 of 14253, loss=1.397, LR=0.00034549150281252633
# Validation Loss = 0.683
# Epoch=4, batch = 13000 of 14253, loss=1.550, LR=0.00034549150281252633
# Validation Loss = 0.214
# Epoch=4, batch = 14000 of 14253, loss=1.528, LR=0.00034549150281252633
# Validation Loss = 0.513
# Epoch=5, batch = 0 of 14253, loss=1.452, LR=9.549150281252633e-05
# Validation Loss = 0.282
# Epoch=5, batch = 1000 of 14253, loss=1.720, LR=9.549150281252633e-05
# Validation Loss = 0.503
# Epoch=5, batch = 2000 of 14253, loss=1.472, LR=9.549150281252633e-05
# Validation Loss = 0.400
# Epoch=5, batch = 3000 of 14253, loss=1.506, LR=9.549150281252633e-05
# Validation Loss = 0.397
# Epoch=5, batch = 4000 of 14253, loss=1.746, LR=9.549150281252633e-05
# Validation Loss = 0.438
# Epoch=5, batch = 5000 of 14253, loss=1.451, LR=9.549150281252633e-05
# Validation Loss = 0.619
# Epoch=5, batch = 6000 of 14253, loss=1.371, LR=9.549150281252633e-05
# Validation Loss = 0.492
# Epoch=5, batch = 7000 of 14253, loss=1.343, LR=9.549150281252633e-05
# Validation Loss = 1.123
# Epoch=5, batch = 8000 of 14253, loss=1.542, LR=9.549150281252633e-05
# Validation Loss = 0.338
# Epoch=5, batch = 9000 of 14253, loss=1.605, LR=9.549150281252633e-05
# Validation Loss = 0.217
# Epoch=5, batch = 10000 of 14253, loss=1.484, LR=9.549150281252633e-05
# Validation Loss = 0.671
# Epoch=5, batch = 11000 of 14253, loss=1.646, LR=9.549150281252633e-05
# Validation Loss = 0.305
# Epoch=5, batch = 12000 of 14253, loss=1.485, LR=9.549150281252633e-05
# Validation Loss = 0.745
# Epoch=5, batch = 13000 of 14253, loss=1.740, LR=9.549150281252633e-05
# Validation Loss = 0.338
# Epoch=5, batch = 14000 of 14253, loss=1.358, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.699
# Epoch=1, batch = 0 of 14253, loss=1.431, LR=0.001
# Validation Loss = 1.197
# Epoch=1, batch = 1000 of 14253, loss=1.945, LR=0.001
# Validation Loss = 0.003
# Epoch=1, batch = 2000 of 14253, loss=2.393, LR=0.001
# Validation Loss = 0.016
# Epoch=1, batch = 3000 of 14253, loss=2.585, LR=0.001
# Validation Loss = 0.702
# Epoch=1, batch = 4000 of 14253, loss=4.830, LR=0.001
# Validation Loss = 1.824
# Epoch=1, batch = 5000 of 14253, loss=2.560, LR=0.001
# Validation Loss = 0.445
# Epoch=1, batch = 6000 of 14253, loss=5.036, LR=0.001
# Validation Loss = 0.032
# Epoch=1, batch = 7000 of 14253, loss=1.931, LR=0.001
# Validation Loss = 2.973
# Epoch=1, batch = 8000 of 14253, loss=2.602, LR=0.001
# Validation Loss = 0.425
# Epoch=1, batch = 9000 of 14253, loss=1.777, LR=0.001
# Validation Loss = 3.280
# Epoch=1, batch = 10000 of 14253, loss=4.818, LR=0.001
# Validation Loss = 0.400
# Epoch=1, batch = 11000 of 14253, loss=1.543, LR=0.001
# Validation Loss = 0.013
# Epoch=1, batch = 12000 of 14253, loss=1.905, LR=0.001
# Validation Loss = 0.433
# Epoch=1, batch = 13000 of 14253, loss=1.731, LR=0.001
# Validation Loss = 1.191
# Epoch=1, batch = 14000 of 14253, loss=2.058, LR=0.001
# Validation Loss = 0.009
# Epoch=2, batch = 0 of 14253, loss=1.561, LR=0.0009755282581475768
# Validation Loss = 0.614
# Epoch=2, batch = 1000 of 14253, loss=2.368, LR=0.0009755282581475768
# Validation Loss = 0.048
# Epoch=2, batch = 2000 of 14253, loss=1.971, LR=0.0009755282581475768
# Validation Loss = 0.056
# Epoch=2, batch = 3000 of 14253, loss=2.023, LR=0.0009755282581475768
# Validation Loss = 1.148
# Epoch=2, batch = 4000 of 14253, loss=2.351, LR=0.0009755282581475768
# Validation Loss = 0.359
# Epoch=2, batch = 5000 of 14253, loss=2.799, LR=0.0009755282581475768
# Validation Loss = 0.671
# Epoch=2, batch = 6000 of 14253, loss=2.534, LR=0.0009755282581475768
# Validation Loss = 7.071
# Epoch=2, batch = 7000 of 14253, loss=7.657, LR=0.0009755282581475768
# Validation Loss = 0.254
# Epoch=2, batch = 8000 of 14253, loss=1.452, LR=0.0009755282581475768
# Validation Loss = 0.226
# Epoch=2, batch = 9000 of 14253, loss=3.101, LR=0.0009755282581475768
# Validation Loss = 0.001
# Epoch=2, batch = 10000 of 14253, loss=1.994, LR=0.0009755282581475768
# Validation Loss = 1.556
# Epoch=2, batch = 11000 of 14253, loss=2.354, LR=0.0009755282581475768
# Validation Loss = 1.480
# Epoch=2, batch = 12000 of 14253, loss=2.082, LR=0.0009755282581475768
# Validation Loss = 3.240
# Epoch=2, batch = 13000 of 14253, loss=3.419, LR=0.0009755282581475768
# Validation Loss = 0.000
# Epoch=2, batch = 14000 of 14253, loss=2.001, LR=0.0009755282581475768
# Validation Loss = 0.398
# Epoch=3, batch = 0 of 14253, loss=1.580, LR=0.0009045084971874736
# Validation Loss = 0.556
# Epoch=3, batch = 1000 of 14253, loss=2.333, LR=0.0009045084971874736
# Validation Loss = 0.286
# Epoch=3, batch = 2000 of 14253, loss=3.343, LR=0.0009045084971874736
# Validation Loss = 0.511
# Epoch=3, batch = 3000 of 14253, loss=1.593, LR=0.0009045084971874736
# Validation Loss = 0.231
# Epoch=3, batch = 4000 of 14253, loss=1.731, LR=0.0009045084971874736
# Validation Loss = 0.072
# Epoch=3, batch = 5000 of 14253, loss=1.940, LR=0.0009045084971874736
# Validation Loss = 0.393
# Epoch=3, batch = 6000 of 14253, loss=1.578, LR=0.0009045084971874736
# Validation Loss = 0.034
# Epoch=3, batch = 7000 of 14253, loss=1.815, LR=0.0009045084971874736
# Validation Loss = 0.731
# Epoch=3, batch = 8000 of 14253, loss=1.727, LR=0.0009045084971874736
# Validation Loss = 0.110
# Epoch=3, batch = 9000 of 14253, loss=1.770, LR=0.0009045084971874736
# Validation Loss = 2.093
# Epoch=3, batch = 10000 of 14253, loss=2.053, LR=0.0009045084971874736
# Validation Loss = 2.188
# Epoch=3, batch = 11000 of 14253, loss=1.844, LR=0.0009045084971874736
# Validation Loss = 0.460
# Epoch=3, batch = 12000 of 14253, loss=1.515, LR=0.0009045084971874736
# Validation Loss = 0.014
# Epoch=3, batch = 13000 of 14253, loss=1.978, LR=0.0009045084971874736
# Validation Loss = 1.740
# Epoch=3, batch = 14000 of 14253, loss=2.431, LR=0.0009045084971874736
# Validation Loss = 0.008
# Epoch=4, batch = 0 of 14253, loss=1.860, LR=0.0007938926261462366
# Validation Loss = 1.277
# Epoch=4, batch = 1000 of 14253, loss=1.463, LR=0.0007938926261462366
# Validation Loss = 0.693
# Epoch=4, batch = 2000 of 14253, loss=1.673, LR=0.0007938926261462366
# Validation Loss = 0.930
# Epoch=4, batch = 3000 of 14253, loss=1.624, LR=0.0007938926261462366
# Validation Loss = 0.043
# Epoch=4, batch = 4000 of 14253, loss=1.964, LR=0.0007938926261462366
# Validation Loss = 0.031
# Epoch=4, batch = 5000 of 14253, loss=1.552, LR=0.0007938926261462366
# Validation Loss = 0.046
# Epoch=4, batch = 6000 of 14253, loss=1.451, LR=0.0007938926261462366
# Validation Loss = 0.107
# Epoch=4, batch = 7000 of 14253, loss=1.615, LR=0.0007938926261462366
# Validation Loss = 0.047
# Epoch=4, batch = 8000 of 14253, loss=1.563, LR=0.0007938926261462366
# Validation Loss = 1.105
# Epoch=4, batch = 9000 of 14253, loss=1.897, LR=0.0007938926261462366
# Validation Loss = 0.501
# Epoch=4, batch = 10000 of 14253, loss=1.776, LR=0.0007938926261462366
# Validation Loss = 0.600
# Epoch=4, batch = 11000 of 14253, loss=1.722, LR=0.0007938926261462366
# Validation Loss = 0.872
# Epoch=4, batch = 12000 of 14253, loss=1.690, LR=0.0007938926261462366
# Validation Loss = 0.010
# Epoch=4, batch = 13000 of 14253, loss=1.799, LR=0.0007938926261462366
# Validation Loss = 0.106
# Epoch=4, batch = 14000 of 14253, loss=2.164, LR=0.0007938926261462366
# Validation Loss = 0.271
# Epoch=5, batch = 0 of 14253, loss=1.692, LR=0.0006545084971874737
# Validation Loss = 0.031
# Epoch=5, batch = 1000 of 14253, loss=1.675, LR=0.0006545084971874737
# Validation Loss = 0.322
# Epoch=5, batch = 2000 of 14253, loss=1.497, LR=0.0006545084971874737
# Validation Loss = 0.024
# Epoch=5, batch = 3000 of 14253, loss=2.021, LR=0.0006545084971874737
# Validation Loss = 0.286
# Epoch=5, batch = 4000 of 14253, loss=1.695, LR=0.0006545084971874737
# Validation Loss = 0.872
# Epoch=5, batch = 5000 of 14253, loss=1.957, LR=0.0006545084971874737
# Validation Loss = 0.575
# Epoch=5, batch = 6000 of 14253, loss=1.455, LR=0.0006545084971874737
# Validation Loss = 0.698
# Epoch=5, batch = 7000 of 14253, loss=1.334, LR=0.0006545084971874737
# Validation Loss = 0.002
# Epoch=5, batch = 8000 of 14253, loss=1.822, LR=0.0006545084971874737
# Validation Loss = 0.016
# Epoch=5, batch = 9000 of 14253, loss=2.063, LR=0.0006545084971874737
# Validation Loss = 0.077
# Epoch=5, batch = 10000 of 14253, loss=1.925, LR=0.0006545084971874737
# Validation Loss = 0.366
# Epoch=5, batch = 11000 of 14253, loss=1.698, LR=0.0006545084971874737
# Validation Loss = 0.262
# Epoch=5, batch = 12000 of 14253, loss=1.399, LR=0.0006545084971874737
# Validation Loss = 0.199
# Epoch=5, batch = 13000 of 14253, loss=1.688, LR=0.0006545084971874737
# Validation Loss = 0.009
# Epoch=5, batch = 14000 of 14253, loss=1.543, LR=0.0006545084971874737
# Validation Loss = 0.195
# Epoch=6, batch = 0 of 14253, loss=1.249, LR=0.0005
# Validation Loss = 0.158
# Epoch=6, batch = 1000 of 14253, loss=1.469, LR=0.0005
# Validation Loss = 0.260
# Epoch=6, batch = 2000 of 14253, loss=1.476, LR=0.0005
# Validation Loss = 0.456
# Epoch=6, batch = 3000 of 14253, loss=1.553, LR=0.0005
# Validation Loss = 0.105
# Epoch=6, batch = 4000 of 14253, loss=1.586, LR=0.0005
# Validation Loss = 0.811
# Epoch=6, batch = 5000 of 14253, loss=1.671, LR=0.0005
# Validation Loss = 0.025
# Epoch=6, batch = 6000 of 14253, loss=1.531, LR=0.0005
# Validation Loss = 0.023
# Epoch=6, batch = 7000 of 14253, loss=1.475, LR=0.0005
# Validation Loss = 0.615
# Epoch=6, batch = 8000 of 14253, loss=1.433, LR=0.0005
# Validation Loss = 0.158
# Epoch=6, batch = 9000 of 14253, loss=1.628, LR=0.0005
# Validation Loss = 0.787
# Epoch=6, batch = 10000 of 14253, loss=1.916, LR=0.0005
# Validation Loss = 0.009
# Epoch=6, batch = 11000 of 14253, loss=1.944, LR=0.0005
# Validation Loss = 0.206
# Epoch=6, batch = 12000 of 14253, loss=1.575, LR=0.0005
# Validation Loss = 0.083
# Epoch=6, batch = 13000 of 14253, loss=1.340, LR=0.0005
# Validation Loss = 0.047
# Epoch=6, batch = 14000 of 14253, loss=1.440, LR=0.0005
# Validation Loss = 0.574
# Epoch=7, batch = 0 of 14253, loss=1.464, LR=0.00034549150281252633
# Validation Loss = 0.034
# Epoch=7, batch = 1000 of 14253, loss=1.584, LR=0.00034549150281252633
# Validation Loss = 0.716
# Epoch=7, batch = 2000 of 14253, loss=1.452, LR=0.00034549150281252633
# Validation Loss = 0.040
# Epoch=7, batch = 3000 of 14253, loss=1.869, LR=0.00034549150281252633
# Validation Loss = 0.105
# Epoch=7, batch = 4000 of 14253, loss=1.368, LR=0.00034549150281252633
# Validation Loss = 0.397
# Epoch=7, batch = 5000 of 14253, loss=1.566, LR=0.00034549150281252633
# Validation Loss = 0.128
# Epoch=7, batch = 6000 of 14253, loss=1.952, LR=0.00034549150281252633
# Validation Loss = 0.275
# Epoch=7, batch = 7000 of 14253, loss=1.362, LR=0.00034549150281252633
# Validation Loss = 0.947
# Epoch=7, batch = 8000 of 14253, loss=1.464, LR=0.00034549150281252633
# Validation Loss = 0.509
# Epoch=7, batch = 9000 of 14253, loss=1.423, LR=0.00034549150281252633
# Validation Loss = 0.909
# Epoch=7, batch = 10000 of 14253, loss=1.718, LR=0.00034549150281252633
# Validation Loss = 0.497
# Epoch=7, batch = 11000 of 14253, loss=1.633, LR=0.00034549150281252633
# Validation Loss = 0.170
# Epoch=7, batch = 12000 of 14253, loss=1.501, LR=0.00034549150281252633
# Validation Loss = 0.140
# Epoch=7, batch = 13000 of 14253, loss=1.484, LR=0.00034549150281252633
# Validation Loss = 0.982
# Epoch=7, batch = 14000 of 14253, loss=1.879, LR=0.00034549150281252633
# Validation Loss = 0.925
# Epoch=8, batch = 0 of 14253, loss=1.430, LR=0.0002061073738537635
# Validation Loss = 0.493
# Epoch=8, batch = 1000 of 14253, loss=1.611, LR=0.0002061073738537635
# Validation Loss = 0.050
# Epoch=8, batch = 2000 of 14253, loss=1.382, LR=0.0002061073738537635
# Validation Loss = 0.096
# Epoch=8, batch = 3000 of 14253, loss=1.417, LR=0.0002061073738537635
# Validation Loss = 0.059
# Epoch=8, batch = 4000 of 14253, loss=1.490, LR=0.0002061073738537635
# Validation Loss = 0.366
# Epoch=8, batch = 5000 of 14253, loss=2.033, LR=0.0002061073738537635
# Validation Loss = 0.303
# Epoch=8, batch = 6000 of 14253, loss=1.482, LR=0.0002061073738537635
# Validation Loss = 0.008
# Epoch=8, batch = 7000 of 14253, loss=1.644, LR=0.0002061073738537635
# Validation Loss = 0.260
# Epoch=8, batch = 8000 of 14253, loss=1.363, LR=0.0002061073738537635
# Validation Loss = 0.375
# Epoch=8, batch = 9000 of 14253, loss=1.529, LR=0.0002061073738537635
# Validation Loss = 0.252
# Epoch=8, batch = 10000 of 14253, loss=1.476, LR=0.0002061073738537635
# Validation Loss = 0.241
# Epoch=8, batch = 11000 of 14253, loss=1.527, LR=0.0002061073738537635
# Validation Loss = 0.419
# Epoch=8, batch = 12000 of 14253, loss=1.838, LR=0.0002061073738537635
# Validation Loss = 0.244
# Epoch=8, batch = 13000 of 14253, loss=1.511, LR=0.0002061073738537635
# Validation Loss = 0.249
# Epoch=8, batch = 14000 of 14253, loss=1.385, LR=0.0002061073738537635
# Validation Loss = 0.145
# Epoch=9, batch = 0 of 14253, loss=1.471, LR=9.549150281252634e-05
# Validation Loss = 0.293
# Epoch=9, batch = 1000 of 14253, loss=1.670, LR=9.549150281252634e-05
# Validation Loss = 0.334
# Epoch=9, batch = 2000 of 14253, loss=1.381, LR=9.549150281252634e-05
# Validation Loss = 0.303
# Epoch=9, batch = 3000 of 14253, loss=1.256, LR=9.549150281252634e-05
# Validation Loss = 0.159
# Epoch=9, batch = 4000 of 14253, loss=1.346, LR=9.549150281252634e-05
# Validation Loss = 0.079
# Epoch=9, batch = 5000 of 14253, loss=1.440, LR=9.549150281252634e-05
# Validation Loss = 0.025
# Epoch=9, batch = 6000 of 14253, loss=1.479, LR=9.549150281252634e-05
# Validation Loss = 0.134
# Epoch=9, batch = 7000 of 14253, loss=1.367, LR=9.549150281252634e-05
# Validation Loss = 0.168
# Epoch=9, batch = 8000 of 14253, loss=1.427, LR=9.549150281252634e-05
# Validation Loss = 0.236
# Epoch=9, batch = 9000 of 14253, loss=1.416, LR=9.549150281252634e-05
# Validation Loss = 0.131
# Epoch=9, batch = 10000 of 14253, loss=1.511, LR=9.549150281252634e-05
# Validation Loss = 0.052
# Epoch=9, batch = 11000 of 14253, loss=1.447, LR=9.549150281252634e-05
# Validation Loss = 0.182
# Epoch=9, batch = 12000 of 14253, loss=1.354, LR=9.549150281252634e-05
# Validation Loss = 0.265
# Epoch=9, batch = 13000 of 14253, loss=1.369, LR=9.549150281252634e-05
# Validation Loss = 0.105
# Epoch=9, batch = 14000 of 14253, loss=1.367, LR=9.549150281252634e-05
# Validation Loss = 0.180
# Epoch=10, batch = 0 of 14253, loss=1.492, LR=2.4471741852423235e-05
# Validation Loss = 0.176
# Epoch=10, batch = 1000 of 14253, loss=1.228, LR=2.4471741852423235e-05
# Validation Loss = 0.151
# Epoch=10, batch = 2000 of 14253, loss=1.410, LR=2.4471741852423235e-05
# Validation Loss = 0.270
# Epoch=10, batch = 3000 of 14253, loss=1.403, LR=2.4471741852423235e-05
# Validation Loss = 0.360
# Epoch=10, batch = 4000 of 14253, loss=1.567, LR=2.4471741852423235e-05
# Validation Loss = 0.450
# Epoch=10, batch = 5000 of 14253, loss=1.245, LR=2.4471741852423235e-05
# Validation Loss = 0.209
# Epoch=10, batch = 6000 of 14253, loss=1.384, LR=2.4471741852423235e-05
# Validation Loss = 0.163
# Epoch=10, batch = 7000 of 14253, loss=1.481, LR=2.4471741852423235e-05
# Validation Loss = 0.252
# Epoch=10, batch = 8000 of 14253, loss=1.280, LR=2.4471741852423235e-05
# Validation Loss = 0.283
# Epoch=10, batch = 9000 of 14253, loss=1.294, LR=2.4471741852423235e-05
# Validation Loss = 0.090
# Epoch=10, batch = 10000 of 14253, loss=1.524, LR=2.4471741852423235e-05
# Validation Loss = 0.247
# Epoch=10, batch = 11000 of 14253, loss=1.336, LR=2.4471741852423235e-05
# Validation Loss = 0.105
# Epoch=10, batch = 12000 of 14253, loss=1.386, LR=2.4471741852423235e-05
# Validation Loss = 0.193
# Epoch=10, batch = 13000 of 14253, loss=1.662, LR=2.4471741852423235e-05
# Validation Loss = 0.273
# Epoch=10, batch = 14000 of 14253, loss=1.356, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.271
# Epoch=1, batch = 0 of 14253, loss=1.458, LR=0.001
# Validation Loss = 1.236
# Epoch=1, batch = 1000 of 14253, loss=1.674, LR=0.001
# Validation Loss = 1.250
# Epoch=1, batch = 2000 of 14253, loss=1.762, LR=0.001
# Validation Loss = 0.382
# Epoch=1, batch = 3000 of 14253, loss=1.792, LR=0.001
# Validation Loss = 1.020
# Epoch=1, batch = 4000 of 14253, loss=1.886, LR=0.001
# Validation Loss = 0.114
# Epoch=1, batch = 5000 of 14253, loss=1.377, LR=0.001
# Validation Loss = 0.083
# Epoch=1, batch = 6000 of 14253, loss=1.382, LR=0.001
# Validation Loss = 0.171
# Epoch=1, batch = 7000 of 14253, loss=1.529, LR=0.001
# Validation Loss = 3.235
# Epoch=1, batch = 8000 of 14253, loss=2.596, LR=0.001
# Validation Loss = 0.061
# Epoch=1, batch = 9000 of 14253, loss=1.761, LR=0.001
# Validation Loss = 0.847
# Epoch=1, batch = 10000 of 14253, loss=1.546, LR=0.001
# Validation Loss = 6.011
# Epoch=1, batch = 11000 of 14253, loss=4.628, LR=0.001
# Validation Loss = 1.209
# Epoch=1, batch = 12000 of 14253, loss=1.653, LR=0.001
# Validation Loss = 0.019
# Epoch=1, batch = 13000 of 14253, loss=2.298, LR=0.001
# Validation Loss = 1.761
# Epoch=1, batch = 14000 of 14253, loss=1.911, LR=0.001
# Validation Loss = 0.243
# Epoch=2, batch = 0 of 14253, loss=2.867, LR=0.0009938441702975688
# Validation Loss = 0.258
# Epoch=2, batch = 1000 of 14253, loss=1.420, LR=0.0009938441702975688
# Validation Loss = 2.154
# Epoch=2, batch = 2000 of 14253, loss=2.548, LR=0.0009938441702975688
# Validation Loss = 0.583
# Epoch=2, batch = 3000 of 14253, loss=1.417, LR=0.0009938441702975688
# Validation Loss = 0.001
# Epoch=2, batch = 4000 of 14253, loss=1.525, LR=0.0009938441702975688
# Validation Loss = 0.697
# Epoch=2, batch = 5000 of 14253, loss=1.580, LR=0.0009938441702975688
# Validation Loss = 0.289
# Epoch=2, batch = 6000 of 14253, loss=1.443, LR=0.0009938441702975688
# Validation Loss = 0.115
# Epoch=2, batch = 7000 of 14253, loss=1.594, LR=0.0009938441702975688
# Validation Loss = 0.399
# Epoch=2, batch = 8000 of 14253, loss=1.270, LR=0.0009938441702975688
# Validation Loss = 0.062
# Epoch=2, batch = 9000 of 14253, loss=1.953, LR=0.0009938441702975688
# Validation Loss = 0.011
# Epoch=2, batch = 10000 of 14253, loss=2.268, LR=0.0009938441702975688
# Validation Loss = 1.930
# Epoch=2, batch = 11000 of 14253, loss=2.284, LR=0.0009938441702975688
# Validation Loss = 1.410
# Epoch=2, batch = 12000 of 14253, loss=1.873, LR=0.0009938441702975688
# Validation Loss = 0.001
# Epoch=2, batch = 13000 of 14253, loss=1.996, LR=0.0009938441702975688
# Validation Loss = 2.875
# Epoch=2, batch = 14000 of 14253, loss=1.919, LR=0.0009938441702975688
# Validation Loss = 0.006
# Epoch=3, batch = 0 of 14253, loss=2.126, LR=0.0009755282581475768
# Validation Loss = 1.777
# Epoch=3, batch = 1000 of 14253, loss=1.839, LR=0.0009755282581475768
# Validation Loss = 2.023
# Epoch=3, batch = 2000 of 14253, loss=1.553, LR=0.0009755282581475768
# Validation Loss = 0.844
# Epoch=3, batch = 3000 of 14253, loss=1.767, LR=0.0009755282581475768
# Validation Loss = 1.045
# Epoch=3, batch = 4000 of 14253, loss=1.835, LR=0.0009755282581475768
# Validation Loss = 0.101
# Epoch=3, batch = 5000 of 14253, loss=1.448, LR=0.0009755282581475768
# Validation Loss = 1.495
# Epoch=3, batch = 6000 of 14253, loss=2.151, LR=0.0009755282581475768
# Validation Loss = 1.446
# Epoch=3, batch = 7000 of 14253, loss=1.605, LR=0.0009755282581475768
# Validation Loss = 0.599
# Epoch=3, batch = 8000 of 14253, loss=1.353, LR=0.0009755282581475768
# Validation Loss = 0.641
# Epoch=3, batch = 9000 of 14253, loss=1.882, LR=0.0009755282581475768
# Validation Loss = 0.715
# Epoch=3, batch = 10000 of 14253, loss=1.647, LR=0.0009755282581475768
# Validation Loss = 0.220
# Epoch=3, batch = 11000 of 14253, loss=1.435, LR=0.0009755282581475768
# Validation Loss = 0.405
# Epoch=3, batch = 12000 of 14253, loss=1.613, LR=0.0009755282581475768
# Validation Loss = 0.081
# Epoch=3, batch = 13000 of 14253, loss=1.764, LR=0.0009755282581475768
# Validation Loss = 1.920
# Epoch=3, batch = 14000 of 14253, loss=1.923, LR=0.0009755282581475768
# Validation Loss = 0.110
# Epoch=4, batch = 0 of 14253, loss=1.630, LR=0.0009455032620941839
# Validation Loss = 1.271
# Epoch=4, batch = 1000 of 14253, loss=1.962, LR=0.0009455032620941839
# Validation Loss = 0.001
# Epoch=4, batch = 2000 of 14253, loss=1.673, LR=0.0009455032620941839
# Validation Loss = 0.256
# Epoch=4, batch = 3000 of 14253, loss=1.377, LR=0.0009455032620941839
# Validation Loss = 0.498
# Epoch=4, batch = 4000 of 14253, loss=1.390, LR=0.0009455032620941839
# Validation Loss = 0.138
# Epoch=4, batch = 5000 of 14253, loss=1.316, LR=0.0009455032620941839
# Validation Loss = 0.011
# Epoch=4, batch = 6000 of 14253, loss=1.542, LR=0.0009455032620941839
# Validation Loss = 0.317
# Epoch=4, batch = 7000 of 14253, loss=1.372, LR=0.0009455032620941839
# Validation Loss = 0.152
# Epoch=4, batch = 8000 of 14253, loss=1.738, LR=0.0009455032620941839
# Validation Loss = 0.285
# Epoch=4, batch = 9000 of 14253, loss=1.509, LR=0.0009455032620941839
# Validation Loss = 1.425
# Epoch=4, batch = 10000 of 14253, loss=1.484, LR=0.0009455032620941839
# Validation Loss = 0.304
# Epoch=4, batch = 11000 of 14253, loss=1.353, LR=0.0009455032620941839
# Validation Loss = 0.921
# Epoch=4, batch = 12000 of 14253, loss=1.517, LR=0.0009455032620941839
# Validation Loss = 0.626
# Epoch=4, batch = 13000 of 14253, loss=1.499, LR=0.0009455032620941839
# Validation Loss = 0.105
# Epoch=4, batch = 14000 of 14253, loss=1.445, LR=0.0009455032620941839
# Validation Loss = 0.321
# Epoch=5, batch = 0 of 14253, loss=1.460, LR=0.0009045084971874737
# Validation Loss = 1.203
# Epoch=5, batch = 1000 of 14253, loss=1.531, LR=0.0009045084971874737
# Validation Loss = 0.001
# Epoch=5, batch = 2000 of 14253, loss=1.459, LR=0.0009045084971874737
# Validation Loss = 0.394
# Epoch=5, batch = 3000 of 14253, loss=1.388, LR=0.0009045084971874737
# Validation Loss = 0.114
# Epoch=5, batch = 4000 of 14253, loss=1.780, LR=0.0009045084971874737
# Validation Loss = 0.035
# Epoch=5, batch = 5000 of 14253, loss=1.566, LR=0.0009045084971874737
# Validation Loss = 0.031
# Epoch=5, batch = 6000 of 14253, loss=1.793, LR=0.0009045084971874737
# Validation Loss = 0.182
# Epoch=5, batch = 7000 of 14253, loss=1.530, LR=0.0009045084971874737
# Validation Loss = 0.202
# Epoch=5, batch = 8000 of 14253, loss=1.491, LR=0.0009045084971874737
# Validation Loss = 0.611
# Epoch=5, batch = 9000 of 14253, loss=1.392, LR=0.0009045084971874737
# Validation Loss = 0.002
# Epoch=5, batch = 10000 of 14253, loss=1.336, LR=0.0009045084971874737
# Validation Loss = 0.144
# Epoch=5, batch = 11000 of 14253, loss=1.413, LR=0.0009045084971874737
# Validation Loss = 0.480
# Epoch=5, batch = 12000 of 14253, loss=1.602, LR=0.0009045084971874737
# Validation Loss = 1.238
# Epoch=5, batch = 13000 of 14253, loss=2.079, LR=0.0009045084971874737
# Validation Loss = 0.827
# Epoch=5, batch = 14000 of 14253, loss=1.797, LR=0.0009045084971874737
# Validation Loss = 0.020
# Epoch=6, batch = 0 of 14253, loss=1.813, LR=0.0008535533905932737
# Validation Loss = 0.040
# Epoch=6, batch = 1000 of 14253, loss=1.393, LR=0.0008535533905932737
# Validation Loss = 0.000
# Epoch=6, batch = 2000 of 14253, loss=1.752, LR=0.0008535533905932737
# Validation Loss = 0.036
# Epoch=6, batch = 3000 of 14253, loss=1.470, LR=0.0008535533905932737
# Validation Loss = 0.416
# Epoch=6, batch = 4000 of 14253, loss=1.500, LR=0.0008535533905932737
# Validation Loss = 0.013
# Epoch=6, batch = 5000 of 14253, loss=1.645, LR=0.0008535533905932737
# Validation Loss = 0.007
# Epoch=6, batch = 6000 of 14253, loss=1.992, LR=0.0008535533905932737
# Validation Loss = 0.472
# Epoch=6, batch = 7000 of 14253, loss=1.651, LR=0.0008535533905932737
# Validation Loss = 0.004
# Epoch=6, batch = 8000 of 14253, loss=2.284, LR=0.0008535533905932737
# Validation Loss = 0.002
# Epoch=6, batch = 9000 of 14253, loss=1.563, LR=0.0008535533905932737
# Validation Loss = 0.013
# Epoch=6, batch = 10000 of 14253, loss=2.332, LR=0.0008535533905932737
# Validation Loss = 0.035
# Epoch=6, batch = 11000 of 14253, loss=1.931, LR=0.0008535533905932737
# Validation Loss = 0.072
# Epoch=6, batch = 12000 of 14253, loss=1.566, LR=0.0008535533905932737
# Validation Loss = 0.179
# Epoch=6, batch = 13000 of 14253, loss=1.491, LR=0.0008535533905932737
# Validation Loss = 0.181
# Epoch=6, batch = 14000 of 14253, loss=1.279, LR=0.0008535533905932737
# Validation Loss = 0.040
# Epoch=7, batch = 0 of 14253, loss=1.569, LR=0.0007938926261462366
# Validation Loss = 0.157
# Epoch=7, batch = 1000 of 14253, loss=1.293, LR=0.0007938926261462366
# Validation Loss = 0.062
# Epoch=7, batch = 2000 of 14253, loss=1.402, LR=0.0007938926261462366
# Validation Loss = 0.136
# Epoch=7, batch = 3000 of 14253, loss=1.517, LR=0.0007938926261462366
# Validation Loss = 1.020
# Epoch=7, batch = 4000 of 14253, loss=1.708, LR=0.0007938926261462366
# Validation Loss = 0.302
# Epoch=7, batch = 5000 of 14253, loss=1.888, LR=0.0007938926261462366
# Validation Loss = 0.505
# Epoch=7, batch = 6000 of 14253, loss=1.912, LR=0.0007938926261462366
# Validation Loss = 0.127
# Epoch=7, batch = 7000 of 14253, loss=2.293, LR=0.0007938926261462366
# Validation Loss = 0.341
# Epoch=7, batch = 8000 of 14253, loss=1.561, LR=0.0007938926261462366
# Validation Loss = 0.005
# Epoch=7, batch = 9000 of 14253, loss=1.522, LR=0.0007938926261462366
# Validation Loss = 0.001
# Epoch=7, batch = 10000 of 14253, loss=1.392, LR=0.0007938926261462366
# Validation Loss = 0.033
# Epoch=7, batch = 11000 of 14253, loss=1.428, LR=0.0007938926261462366
# Validation Loss = 0.005
# Epoch=7, batch = 12000 of 14253, loss=1.502, LR=0.0007938926261462366
# Validation Loss = 0.007
# Epoch=7, batch = 13000 of 14253, loss=1.361, LR=0.0007938926261462366
# Validation Loss = 0.008
# Epoch=7, batch = 14000 of 14253, loss=1.714, LR=0.0007938926261462366
# Validation Loss = 0.564
# Epoch=8, batch = 0 of 14253, loss=2.112, LR=0.0007269952498697733
# Validation Loss = 0.008
# Epoch=8, batch = 1000 of 14253, loss=1.629, LR=0.0007269952498697733
# Validation Loss = 0.527
# Epoch=8, batch = 2000 of 14253, loss=1.547, LR=0.0007269952498697733
# Validation Loss = 0.001
# Epoch=8, batch = 3000 of 14253, loss=1.504, LR=0.0007269952498697733
# Validation Loss = 0.369
# Epoch=8, batch = 4000 of 14253, loss=1.362, LR=0.0007269952498697733
# Validation Loss = 0.595
# Epoch=8, batch = 5000 of 14253, loss=1.784, LR=0.0007269952498697733
# Validation Loss = 0.664
# Epoch=8, batch = 6000 of 14253, loss=2.130, LR=0.0007269952498697733
# Validation Loss = 0.017
# Epoch=8, batch = 7000 of 14253, loss=2.234, LR=0.0007269952498697733
# Validation Loss = 0.279
# Epoch=8, batch = 8000 of 14253, loss=1.648, LR=0.0007269952498697733
# Validation Loss = 0.000
# Epoch=8, batch = 9000 of 14253, loss=1.409, LR=0.0007269952498697733
# Validation Loss = 0.000
# Epoch=8, batch = 10000 of 14253, loss=1.566, LR=0.0007269952498697733
# Validation Loss = 0.471
# Epoch=8, batch = 11000 of 14253, loss=1.520, LR=0.0007269952498697733
# Validation Loss = 0.008
# Epoch=8, batch = 12000 of 14253, loss=1.435, LR=0.0007269952498697733
# Validation Loss = 0.157
# Epoch=8, batch = 13000 of 14253, loss=1.618, LR=0.0007269952498697733
# Validation Loss = 0.691
# Epoch=8, batch = 14000 of 14253, loss=1.641, LR=0.0007269952498697733
# Validation Loss = 0.311
# Epoch=9, batch = 0 of 14253, loss=1.376, LR=0.0006545084971874737
# Validation Loss = 0.109
# Epoch=9, batch = 1000 of 14253, loss=1.790, LR=0.0006545084971874737
# Validation Loss = 0.003
# Epoch=9, batch = 2000 of 14253, loss=1.562, LR=0.0006545084971874737
# Validation Loss = 0.144
# Epoch=9, batch = 3000 of 14253, loss=1.364, LR=0.0006545084971874737
# Validation Loss = 0.780
# Epoch=9, batch = 4000 of 14253, loss=1.920, LR=0.0006545084971874737
# Validation Loss = 0.258
# Epoch=9, batch = 5000 of 14253, loss=1.491, LR=0.0006545084971874737
# Validation Loss = 0.267
# Epoch=9, batch = 6000 of 14253, loss=1.517, LR=0.0006545084971874737
# Validation Loss = 0.062
# Epoch=9, batch = 7000 of 14253, loss=1.498, LR=0.0006545084971874737
# Validation Loss = 0.533
# Epoch=9, batch = 8000 of 14253, loss=2.616, LR=0.0006545084971874737
# Validation Loss = 0.003
# Epoch=9, batch = 9000 of 14253, loss=1.660, LR=0.0006545084971874737
# Validation Loss = 0.455
# Epoch=9, batch = 10000 of 14253, loss=1.801, LR=0.0006545084971874737
# Validation Loss = 0.185
# Epoch=9, batch = 11000 of 14253, loss=1.392, LR=0.0006545084971874737
# Validation Loss = 0.193
# Epoch=9, batch = 12000 of 14253, loss=1.354, LR=0.0006545084971874737
# Validation Loss = 0.079
# Epoch=9, batch = 13000 of 14253, loss=1.376, LR=0.0006545084971874737
# Validation Loss = 0.820
# Epoch=9, batch = 14000 of 14253, loss=2.020, LR=0.0006545084971874737
# Validation Loss = 0.003
# Epoch=10, batch = 0 of 14253, loss=1.480, LR=0.0005782172325201155
# Validation Loss = 0.023
# Epoch=10, batch = 1000 of 14253, loss=1.436, LR=0.0005782172325201155
# Validation Loss = 0.622
# Epoch=10, batch = 2000 of 14253, loss=1.506, LR=0.0005782172325201155
# Validation Loss = 0.282
# Epoch=10, batch = 3000 of 14253, loss=1.389, LR=0.0005782172325201155
# Validation Loss = 0.000
# Epoch=10, batch = 4000 of 14253, loss=1.633, LR=0.0005782172325201155
# Validation Loss = 0.322
# Epoch=10, batch = 5000 of 14253, loss=1.434, LR=0.0005782172325201155
# Validation Loss = 0.202
# Epoch=10, batch = 6000 of 14253, loss=1.534, LR=0.0005782172325201155
# Validation Loss = 0.246
# Epoch=10, batch = 7000 of 14253, loss=1.474, LR=0.0005782172325201155
# Validation Loss = 0.008
# Epoch=10, batch = 8000 of 14253, loss=1.200, LR=0.0005782172325201155
# Validation Loss = 0.042
# Epoch=10, batch = 9000 of 14253, loss=1.346, LR=0.0005782172325201155
# Validation Loss = 0.061
# Epoch=10, batch = 10000 of 14253, loss=1.577, LR=0.0005782172325201155
# Validation Loss = 0.027
# Epoch=10, batch = 11000 of 14253, loss=1.662, LR=0.0005782172325201155
# Validation Loss = 0.062
# Epoch=10, batch = 12000 of 14253, loss=1.475, LR=0.0005782172325201155
# Validation Loss = 0.079
# Epoch=10, batch = 13000 of 14253, loss=1.615, LR=0.0005782172325201155
# Validation Loss = 0.000
# Epoch=10, batch = 14000 of 14253, loss=1.409, LR=0.0005782172325201155
# Validation Loss = 0.465
# Epoch=11, batch = 0 of 14253, loss=1.491, LR=0.0005
# Validation Loss = 0.130
# Epoch=11, batch = 1000 of 14253, loss=1.289, LR=0.0005
# Validation Loss = 0.037
# Epoch=11, batch = 2000 of 14253, loss=1.297, LR=0.0005
# Validation Loss = 0.538
# Epoch=11, batch = 3000 of 14253, loss=1.813, LR=0.0005
# Validation Loss = 0.106
# Epoch=11, batch = 4000 of 14253, loss=1.384, LR=0.0005
# Validation Loss = 0.047
# Epoch=11, batch = 5000 of 14253, loss=1.456, LR=0.0005
# Validation Loss = 0.020
# ...
# Epoch=7, batch = 11000 of 14253, loss=2.754, LR=0.0007938926261462366
# Validation Loss = 0.585
# Epoch=7, batch = 12000 of 14253, loss=2.593, LR=0.0007938926261462366
# Validation Loss = 0.738
# Epoch=7, batch = 13000 of 14253, loss=2.326, LR=0.0007938926261462366
# Validation Loss = 0.005
# Epoch=7, batch = 14000 of 14253, loss=2.993, LR=0.0007938926261462366
# Validation Loss = 0.001
# Epoch=8, batch = 0 of 14253, loss=2.562, LR=0.0007269952498697733
# Validation Loss = 0.050
# Epoch=8, batch = 1000 of 14253, loss=2.280, LR=0.0007269952498697733
# Validation Loss = 0.644
# Epoch=8, batch = 2000 of 14253, loss=2.690, LR=0.0007269952498697733
# Validation Loss = 2.464
# Epoch=8, batch = 3000 of 14253, loss=2.372, LR=0.0007269952498697733
# Validation Loss = 0.727
# Epoch=8, batch = 4000 of 14253, loss=2.588, LR=0.0007269952498697733
# Validation Loss = 1.997
# Epoch=8, batch = 5000 of 14253, loss=2.874, LR=0.0007269952498697733
# Validation Loss = 0.003
# Epoch=8, batch = 6000 of 14253, loss=2.597, LR=0.0007269952498697733
# Validation Loss = 0.112
# Epoch=8, batch = 7000 of 14253, loss=2.696, LR=0.0007269952498697733
# Validation Loss = 0.084
# Epoch=8, batch = 8000 of 14253, loss=2.601, LR=0.0007269952498697733
# Validation Loss = 0.595
# Epoch=8, batch = 9000 of 14253, loss=2.589, LR=0.0007269952498697733
# Validation Loss = 0.015
# Epoch=8, batch = 10000 of 14253, loss=2.418, LR=0.0007269952498697733
# Validation Loss = 0.085
# Epoch=8, batch = 11000 of 14253, loss=3.004, LR=0.0007269952498697733
# Validation Loss = 0.157
# Epoch=8, batch = 12000 of 14253, loss=2.462, LR=0.0007269952498697733
# Validation Loss = 1.030
# Epoch=8, batch = 13000 of 14253, loss=2.451, LR=0.0007269952498697733
# Validation Loss = 0.232
# Epoch=8, batch = 14000 of 14253, loss=2.736, LR=0.0007269952498697733
# Validation Loss = 0.221
# Epoch=9, batch = 0 of 14253, loss=2.181, LR=0.0006545084971874737
# Validation Loss = 0.064
# Epoch=9, batch = 1000 of 14253, loss=2.542, LR=0.0006545084971874737
# Validation Loss = 4.210
# Epoch=9, batch = 2000 of 14253, loss=2.832, LR=0.0006545084971874737
# Validation Loss = 0.252
# Epoch=9, batch = 3000 of 14253, loss=2.432, LR=0.0006545084971874737
# Validation Loss = 8.804
# Epoch=9, batch = 4000 of 14253, loss=2.567, LR=0.0006545084971874737
# Validation Loss = 0.436
# Epoch=9, batch = 5000 of 14253, loss=2.846, LR=0.0006545084971874737
# Validation Loss = 0.384
# Epoch=9, batch = 6000 of 14253, loss=2.885, LR=0.0006545084971874737
# Validation Loss = 0.287
# Epoch=9, batch = 7000 of 14253, loss=2.438, LR=0.0006545084971874737
# Validation Loss = 0.696
# Epoch=9, batch = 8000 of 14253, loss=2.343, LR=0.0006545084971874737
# Validation Loss = 0.559
# Epoch=9, batch = 9000 of 14253, loss=2.199, LR=0.0006545084971874737
# Validation Loss = 0.363
# Epoch=9, batch = 10000 of 14253, loss=2.798, LR=0.0006545084971874737
# Validation Loss = 0.918
# Epoch=9, batch = 11000 of 14253, loss=2.639, LR=0.0006545084971874737
# Validation Loss = 0.058
# Epoch=9, batch = 12000 of 14253, loss=2.366, LR=0.0006545084971874737
# Validation Loss = 0.201
# Epoch=9, batch = 13000 of 14253, loss=2.112, LR=0.0006545084971874737
# Validation Loss = 2.063
# Epoch=9, batch = 14000 of 14253, loss=2.705, LR=0.0006545084971874737
# Validation Loss = 0.376
# Epoch=10, batch = 0 of 14253, loss=2.636, LR=0.0005782172325201155
# Validation Loss = 0.252
# Epoch=10, batch = 1000 of 14253, loss=2.406, LR=0.0005782172325201155
# Validation Loss = 0.713
# Epoch=10, batch = 2000 of 14253, loss=2.325, LR=0.0005782172325201155
# Validation Loss = 0.003
# Epoch=10, batch = 3000 of 14253, loss=2.316, LR=0.0005782172325201155
# Validation Loss = 0.152
# Epoch=10, batch = 4000 of 14253, loss=2.604, LR=0.0005782172325201155
# Validation Loss = 0.275
# Epoch=10, batch = 5000 of 14253, loss=2.894, LR=0.0005782172325201155
# Validation Loss = 0.269
# Epoch=10, batch = 6000 of 14253, loss=2.057, LR=0.0005782172325201155
# Validation Loss = 2.381
# Epoch=10, batch = 7000 of 14253, loss=2.366, LR=0.0005782172325201155
# Validation Loss = 0.547
# Epoch=10, batch = 8000 of 14253, loss=2.485, LR=0.0005782172325201155
# Validation Loss = 0.521
# Epoch=10, batch = 9000 of 14253, loss=2.447, LR=0.0005782172325201155
# Validation Loss = 1.759
# Epoch=10, batch = 10000 of 14253, loss=2.621, LR=0.0005782172325201155
# Validation Loss = 0.002
# Epoch=10, batch = 11000 of 14253, loss=2.541, LR=0.0005782172325201155
# Validation Loss = 0.066
# Epoch=10, batch = 12000 of 14253, loss=2.647, LR=0.0005782172325201155
# Validation Loss = 1.434
# Epoch=10, batch = 13000 of 14253, loss=2.595, LR=0.0005782172325201155
# Validation Loss = 0.003
# Epoch=10, batch = 14000 of 14253, loss=2.170, LR=0.0005782172325201155
# Validation Loss = 0.469
# Epoch=11, batch = 0 of 14253, loss=2.465, LR=0.0005
# Validation Loss = 0.318
# Epoch=11, batch = 1000 of 14253, loss=2.431, LR=0.0005
# Validation Loss = 0.181
# Epoch=11, batch = 2000 of 14253, loss=2.542, LR=0.0005
# Validation Loss = 0.003
# Epoch=11, batch = 3000 of 14253, loss=2.450, LR=0.0005
# Validation Loss = 0.120
# Epoch=11, batch = 4000 of 14253, loss=2.150, LR=0.0005
# Validation Loss = 0.859
# Epoch=11, batch = 5000 of 14253, loss=2.337, LR=0.0005
# Validation Loss = 0.206
# Epoch=11, batch = 6000 of 14253, loss=2.236, LR=0.0005
# Validation Loss = 1.317
# Epoch=11, batch = 7000 of 14253, loss=2.309, LR=0.0005
# Validation Loss = 0.358
# Epoch=11, batch = 8000 of 14253, loss=2.190, LR=0.0005
# Validation Loss = 1.182
# Epoch=11, batch = 9000 of 14253, loss=2.529, LR=0.0005
# Validation Loss = 0.039
# Epoch=11, batch = 10000 of 14253, loss=2.536, LR=0.0005
# Validation Loss = 2.722
# Epoch=11, batch = 11000 of 14253, loss=2.668, LR=0.0005
# Validation Loss = 0.694
# Epoch=11, batch = 12000 of 14253, loss=2.094, LR=0.0005
# Validation Loss = 0.510
# Epoch=11, batch = 13000 of 14253, loss=2.246, LR=0.0005
# Validation Loss = 0.120
# Epoch=11, batch = 14000 of 14253, loss=2.557, LR=0.0005
# Validation Loss = 1.103
# Epoch=12, batch = 0 of 14253, loss=2.415, LR=0.0004217827674798847
# Validation Loss = 0.434
# Epoch=12, batch = 1000 of 14253, loss=1.881, LR=0.0004217827674798847
# Validation Loss = 0.077
# Epoch=12, batch = 2000 of 14253, loss=2.051, LR=0.0004217827674798847
# Validation Loss = 0.151
# Epoch=12, batch = 3000 of 14253, loss=2.421, LR=0.0004217827674798847
# Validation Loss = 0.007
# Epoch=12, batch = 4000 of 14253, loss=2.236, LR=0.0004217827674798847
# Validation Loss = 0.852
# Epoch=12, batch = 5000 of 14253, loss=2.568, LR=0.0004217827674798847
# Validation Loss = 0.018
# Epoch=12, batch = 6000 of 14253, loss=2.213, LR=0.0004217827674798847
# Validation Loss = 0.049
# Epoch=12, batch = 7000 of 14253, loss=2.177, LR=0.0004217827674798847
# Validation Loss = 0.181
# Epoch=12, batch = 8000 of 14253, loss=2.174, LR=0.0004217827674798847
# Validation Loss = 0.781
# Epoch=12, batch = 9000 of 14253, loss=2.176, LR=0.0004217827674798847
# Validation Loss = 0.790
# Epoch=12, batch = 10000 of 14253, loss=2.037, LR=0.0004217827674798847
# Validation Loss = 0.049
# Epoch=12, batch = 11000 of 14253, loss=2.530, LR=0.0004217827674798847
# Validation Loss = 1.094
# Epoch=12, batch = 12000 of 14253, loss=2.389, LR=0.0004217827674798847
# Validation Loss = 0.020
# Epoch=12, batch = 13000 of 14253, loss=2.499, LR=0.0004217827674798847
# Validation Loss = 0.005
# Epoch=12, batch = 14000 of 14253, loss=2.335, LR=0.0004217827674798847
# Validation Loss = 0.211
# Epoch=13, batch = 0 of 14253, loss=2.179, LR=0.00034549150281252633
# Validation Loss = 1.541
# Epoch=13, batch = 1000 of 14253, loss=2.619, LR=0.00034549150281252633
# Validation Loss = 0.004
# Epoch=13, batch = 2000 of 14253, loss=2.259, LR=0.00034549150281252633
# Validation Loss = 0.469
# Epoch=13, batch = 3000 of 14253, loss=2.125, LR=0.00034549150281252633
# Validation Loss = 0.018
# Epoch=13, batch = 4000 of 14253, loss=2.227, LR=0.00034549150281252633
# Validation Loss = 0.860
# Epoch=13, batch = 5000 of 14253, loss=2.308, LR=0.00034549150281252633
# Validation Loss = 0.501
# Epoch=13, batch = 6000 of 14253, loss=2.189, LR=0.00034549150281252633
# Validation Loss = 0.693
# Epoch=13, batch = 7000 of 14253, loss=2.206, LR=0.00034549150281252633
# Validation Loss = 0.025
# Epoch=13, batch = 8000 of 14253, loss=2.538, LR=0.00034549150281252633
# Validation Loss = 0.325
# Epoch=13, batch = 9000 of 14253, loss=2.605, LR=0.00034549150281252633
# Validation Loss = 0.032
# Epoch=13, batch = 10000 of 14253, loss=2.300, LR=0.00034549150281252633
# Validation Loss = 0.237
# Epoch=13, batch = 11000 of 14253, loss=2.529, LR=0.00034549150281252633
# Validation Loss = 2.603
# Epoch=13, batch = 12000 of 14253, loss=2.364, LR=0.00034549150281252633
# Validation Loss = 0.005
# Epoch=13, batch = 13000 of 14253, loss=2.605, LR=0.00034549150281252633
# Validation Loss = 0.002
# Epoch=13, batch = 14000 of 14253, loss=2.441, LR=0.00034549150281252633
# Validation Loss = 2.003
# Epoch=14, batch = 0 of 14253, loss=2.542, LR=0.00027300475013022663
# Validation Loss = 3.028
# Epoch=14, batch = 1000 of 14253, loss=2.144, LR=0.00027300475013022663
# Validation Loss = 0.008
# Epoch=14, batch = 2000 of 14253, loss=2.263, LR=0.00027300475013022663
# Validation Loss = 0.473
# Epoch=14, batch = 3000 of 14253, loss=2.266, LR=0.00027300475013022663
# Validation Loss = 0.081
# Epoch=14, batch = 4000 of 14253, loss=2.525, LR=0.00027300475013022663
# Validation Loss = 1.656
# Epoch=14, batch = 5000 of 14253, loss=2.514, LR=0.00027300475013022663
# Validation Loss = 1.396
# Epoch=14, batch = 6000 of 14253, loss=2.186, LR=0.00027300475013022663
# Validation Loss = 0.142
# Epoch=14, batch = 7000 of 14253, loss=2.122, LR=0.00027300475013022663
# Validation Loss = 1.007
# Epoch=14, batch = 8000 of 14253, loss=2.319, LR=0.00027300475013022663
# Validation Loss = 1.431
# Epoch=14, batch = 9000 of 14253, loss=2.469, LR=0.00027300475013022663
# Validation Loss = 0.473
# Epoch=14, batch = 10000 of 14253, loss=2.565, LR=0.00027300475013022663
# Validation Loss = 0.150
# Epoch=14, batch = 11000 of 14253, loss=2.139, LR=0.00027300475013022663
# Validation Loss = 0.417
# Epoch=14, batch = 12000 of 14253, loss=2.254, LR=0.00027300475013022663
# Validation Loss = 0.862
# Epoch=14, batch = 13000 of 14253, loss=2.369, LR=0.00027300475013022663
# Validation Loss = 0.815
# Epoch=14, batch = 14000 of 14253, loss=2.252, LR=0.00027300475013022663
# Validation Loss = 0.586
# Epoch=15, batch = 0 of 14253, loss=2.608, LR=0.00020610737385376348
# Validation Loss = 0.049
# Epoch=15, batch = 1000 of 14253, loss=2.103, LR=0.00020610737385376348
# Validation Loss = 0.907
# Epoch=15, batch = 2000 of 14253, loss=2.329, LR=0.00020610737385376348
# Validation Loss = 0.623
# Epoch=15, batch = 3000 of 14253, loss=2.679, LR=0.00020610737385376348
# Validation Loss = 0.324
# Epoch=15, batch = 4000 of 14253, loss=2.313, LR=0.00020610737385376348
# Validation Loss = 0.043
# Epoch=15, batch = 5000 of 14253, loss=2.120, LR=0.00020610737385376348
# Validation Loss = 0.629
# Epoch=15, batch = 6000 of 14253, loss=2.511, LR=0.00020610737385376348
# Validation Loss = 1.018
# Epoch=15, batch = 7000 of 14253, loss=2.138, LR=0.00020610737385376348
# Validation Loss = 0.001
# Epoch=15, batch = 8000 of 14253, loss=2.088, LR=0.00020610737385376348
# Validation Loss = 0.219
# Epoch=15, batch = 9000 of 14253, loss=2.250, LR=0.00020610737385376348
# Validation Loss = 0.746
# Epoch=15, batch = 10000 of 14253, loss=2.254, LR=0.00020610737385376348
# Validation Loss = 0.511
# Epoch=15, batch = 11000 of 14253, loss=2.558, LR=0.00020610737385376348
# Validation Loss = 0.772
# Epoch=15, batch = 12000 of 14253, loss=2.301, LR=0.00020610737385376348
# Validation Loss = 0.189
# Epoch=15, batch = 13000 of 14253, loss=2.119, LR=0.00020610737385376348
# Validation Loss = 0.003
# Epoch=15, batch = 14000 of 14253, loss=2.675, LR=0.00020610737385376348
# Validation Loss = 1.050
# Epoch=16, batch = 0 of 14253, loss=2.279, LR=0.00014644660940672625
# Validation Loss = 0.078
# Epoch=16, batch = 1000 of 14253, loss=2.302, LR=0.00014644660940672625
# Validation Loss = 0.427
# Epoch=16, batch = 2000 of 14253, loss=2.294, LR=0.00014644660940672625
# Validation Loss = 0.377
# Epoch=16, batch = 3000 of 14253, loss=2.204, LR=0.00014644660940672625
# Validation Loss = 0.112
# Epoch=16, batch = 4000 of 14253, loss=2.503, LR=0.00014644660940672625
# Validation Loss = 0.199
# Epoch=16, batch = 5000 of 14253, loss=2.194, LR=0.00014644660940672625
# Validation Loss = 0.149
# Epoch=16, batch = 6000 of 14253, loss=2.082, LR=0.00014644660940672625
# Validation Loss = 0.093
# Epoch=16, batch = 7000 of 14253, loss=2.178, LR=0.00014644660940672625
# Validation Loss = 0.296
# Epoch=16, batch = 8000 of 14253, loss=1.889, LR=0.00014644660940672625
# Validation Loss = 0.077
# Epoch=16, batch = 9000 of 14253, loss=2.007, LR=0.00014644660940672625
# Validation Loss = 0.569
# Epoch=16, batch = 10000 of 14253, loss=2.302, LR=0.00014644660940672625
# Validation Loss = 0.139
# Epoch=16, batch = 11000 of 14253, loss=2.382, LR=0.00014644660940672625
# Validation Loss = 0.371
# Epoch=16, batch = 12000 of 14253, loss=2.111, LR=0.00014644660940672625
# Validation Loss = 0.476
# Epoch=16, batch = 13000 of 14253, loss=2.451, LR=0.00014644660940672625
# Validation Loss = 0.617
# Epoch=16, batch = 14000 of 14253, loss=2.240, LR=0.00014644660940672625
# Validation Loss = 1.880
# Epoch=17, batch = 0 of 14253, loss=1.995, LR=9.549150281252631e-05
# Validation Loss = 0.825
# Epoch=17, batch = 1000 of 14253, loss=2.256, LR=9.549150281252631e-05
# Validation Loss = 0.000
# Epoch=17, batch = 2000 of 14253, loss=2.235, LR=9.549150281252631e-05
# Validation Loss = 0.178
# Epoch=17, batch = 3000 of 14253, loss=2.162, LR=9.549150281252631e-05
# Validation Loss = 0.060
# Epoch=17, batch = 4000 of 14253, loss=2.306, LR=9.549150281252631e-05
# Validation Loss = 0.024
# Epoch=17, batch = 5000 of 14253, loss=2.035, LR=9.549150281252631e-05
# Validation Loss = 0.374
# Epoch=17, batch = 6000 of 14253, loss=2.280, LR=9.549150281252631e-05
# Validation Loss = 0.044
# Epoch=17, batch = 7000 of 14253, loss=2.121, LR=9.549150281252631e-05
# Validation Loss = 0.000
# Epoch=17, batch = 8000 of 14253, loss=2.201, LR=9.549150281252631e-05
# Validation Loss = 0.606
# Epoch=17, batch = 9000 of 14253, loss=2.129, LR=9.549150281252631e-05
# Validation Loss = 0.072
# Epoch=17, batch = 10000 of 14253, loss=1.966, LR=9.549150281252631e-05
# Validation Loss = 0.371
# Epoch=17, batch = 11000 of 14253, loss=2.007, LR=9.549150281252631e-05
# Validation Loss = 0.415
# Epoch=17, batch = 12000 of 14253, loss=2.567, LR=9.549150281252631e-05
# Validation Loss = 0.305
# Epoch=17, batch = 13000 of 14253, loss=2.152, LR=9.549150281252631e-05
# Validation Loss = 0.026
# Epoch=17, batch = 14000 of 14253, loss=2.327, LR=9.549150281252631e-05
# Validation Loss = 0.003
# Epoch=18, batch = 0 of 14253, loss=2.298, LR=5.4496737905816096e-05
# Validation Loss = 0.000
# Epoch=18, batch = 1000 of 14253, loss=2.128, LR=5.4496737905816096e-05
# Validation Loss = 0.054
# Epoch=18, batch = 2000 of 14253, loss=2.243, LR=5.4496737905816096e-05
# Validation Loss = 0.019
# Epoch=18, batch = 3000 of 14253, loss=2.062, LR=5.4496737905816096e-05
# Validation Loss = 0.178
# Epoch=18, batch = 4000 of 14253, loss=2.008, LR=5.4496737905816096e-05
# Validation Loss = 0.010
# Epoch=18, batch = 5000 of 14253, loss=2.353, LR=5.4496737905816096e-05
# Validation Loss = 0.007
# Epoch=18, batch = 6000 of 14253, loss=2.229, LR=5.4496737905816096e-05
# Validation Loss = 0.066
# Epoch=18, batch = 7000 of 14253, loss=2.283, LR=5.4496737905816096e-05
# Validation Loss = 0.203
# Epoch=18, batch = 8000 of 14253, loss=2.239, LR=5.4496737905816096e-05
# Validation Loss = 0.296
# Epoch=18, batch = 9000 of 14253, loss=2.050, LR=5.4496737905816096e-05
# Validation Loss = 0.002
# Epoch=18, batch = 10000 of 14253, loss=2.308, LR=5.4496737905816096e-05
# Validation Loss = 0.197
# Epoch=18, batch = 11000 of 14253, loss=2.178, LR=5.4496737905816096e-05
# Validation Loss = 0.000
# Epoch=18, batch = 12000 of 14253, loss=2.280, LR=5.4496737905816096e-05
# Validation Loss = 0.062
# Epoch=18, batch = 13000 of 14253, loss=2.146, LR=5.4496737905816096e-05
# Validation Loss = 0.170
# Epoch=18, batch = 14000 of 14253, loss=1.957, LR=5.4496737905816096e-05
# Validation Loss = 0.044
# Epoch=19, batch = 0 of 14253, loss=2.157, LR=2.447174185242323e-05
# Validation Loss = 0.870
# Epoch=19, batch = 1000 of 14253, loss=2.230, LR=2.447174185242323e-05
# Validation Loss = 0.042
# Epoch=19, batch = 2000 of 14253, loss=2.290, LR=2.447174185242323e-05
