# %% [markdown]
# # Channel Prediction Model for Quality Control
#
# This notebook contains the code and outlines the development of the
# GMI Channel Prediction Neural Network for QC purposes of GMI L1C
# data. The simple Feed-Forward Neural Networks (FFNNs) are trained on
# good quality brightness temperature observation vectors and are
# trained to predict one channel from all the others as predictors.
#
# The end product is a tree of FFNNs, discretized by surface (ocean or
# land), and by channel, since these are fully distinct problems.

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import glob
import torch
from torch import nn
import cartopy.crs as ccrs
from util_funcs.L1C import scantime2datetime
from util_funcs import data2xarray, array_funcs
import geography
from tqdm import tqdm

from dataset_class import dataset
from model_class import channel_predictor
import local_functions
import sensor_info


#General parameters:

satellite = sensor_info.satellite
sensor = sensor_info.sensor

nchans = sensor_info.nchannels
batch_size = 1000
input_size = nchans - 1
hidden_size = 256
output_size = 1

# %%
'''
Function Definitions:
'''

chan_desc = sensor_info.channel_descriptions


def extract_channel(Tb_array, chan):

    '''
    Use in preparing training data.

    Assumes Tb array is [m x n] where m (rows) are samples
    and n (columns) is the number of channels.

    Passing in the channel description splits the data so
    that the specified channel is its own vector y and the
    rest are kept as predictors x.

    Inputs:
        Tb_array    |  ndarray of Tbs
        chan        |  string of channel name
    Outputs:
        x           |  matrix of predictors (other channels)
        y           |  vector of predictands (the missing channel)
        
    '''
    
    chan_desc = np.array(sensor_info.channel_descriptions)


    chan_indx = np.where(chan == chan_desc)[0]

    if np.size(chan_indx) == 0:
        raise ValueError(f'Channel description must be in list {chan_desc}.')

    y = Tb_array[:,chan_indx]
    x = Tb_array[:,np.delete(np.arange(0,len(chan_desc)),chan_indx)]

    return x, y


def train_model(model, nepochs, dataloader, learning_rate=0.001, quiet=False, stage=None, validation_dataloader=None):

    nbatches = len(dataloader)
    
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=nepochs)
    device = None

    if stage:
        print(f'Training stage: {stage}')

    loss_arr    = np.zeros([nbatches,nepochs], dtype='f')
    valloss_arr = np.zeros([nbatches,nepochs], dtype='f')
    
    for epoch in range(nepochs):
        for i, (profs, obs) in enumerate(dataloader):
            if device:
                profs, obs = profs.to(device), obs.to(device)

            if validation_dataloader and i%1000==0:
                valprofs, valobs = next(enumerate(validation_dataloader))[1]
                val_pred = model(valprofs)
                valloss  = criterion(val_pred, valobs)
                print(f'Validation Loss = {valloss.item():.3f}')

            #Forward pass:
            obs_pred = model(profs)
            loss     = criterion(obs_pred, obs)


            #Backward pass:
            optimizer.zero_grad()
            loss.backward()

            #Update neurons:
            optimizer.step()

            loss_arr[i,epoch] = loss.item()
            valloss_arr[i,epoch] = valloss.item()
            
            if not quiet:
                if i%1000 == 0:
                    print(f'Epoch={epoch+1}, batch = {i} of {nbatches}, loss={loss.item():.3f}, LR={scheduler.get_last_lr()[0]}')
        
        scheduler.step()




    return loss_arr, valloss_arr

# %%
chan_desc
# Out:
# ['10V',
#  '10H',
#  '19V',
#  '19H',
#  '24V',
#  '89V',
#  '89H',
#  '166V',
#  '166H',
#  '183+-3V',
#  '183+-7V']

# %%
'''

GMI CHANNEL PREDICTION MODEL:
    1: Ocean

'''

sfc = [1]

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = np.isin(sfctype, sfc)
    sfcindcs = np.where(correct_sfc)[0]

    Tbs = f.Tbs.values[sfcindcs]

#---Don't shuffle data before splitting
#np.random.seed(40)
#Tbs = array_funcs.shuffle_data(Tbs, axis=0)

if Tbs.shape[0] > 5.0e+06:
    Tbs = Tbs[:5_000_000,:]

Tbs = Tbs[:,[0,1,2,3,4,7,8,9,10,11,12]]

print(Tbs.shape)

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train = array_funcs.shuffle_data(Tbs_train, axis=0)
# Out:
# (5000000, 11)

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    print(channel)
    
    x_train = Tbs_train
    y_train = extract_channel(Tbs_train, channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_ocean_no37.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_ocean_no37.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 10V
# Training stage: 1
# Validation Loss = 29768.496
# Epoch=1, batch = 0 of 4000, loss=29187.730, LR=0.001
# Validation Loss = 2.678
# Epoch=1, batch = 1000 of 4000, loss=1.575, LR=0.001
# Validation Loss = 1.098
# Epoch=1, batch = 2000 of 4000, loss=1.119, LR=0.001
# Validation Loss = 6.439
# Epoch=1, batch = 3000 of 4000, loss=3.403, LR=0.001
# Validation Loss = 0.426
# Epoch=2, batch = 0 of 4000, loss=2.984, LR=0.0009045084971874737
# Validation Loss = 0.013
# Epoch=2, batch = 1000 of 4000, loss=1.376, LR=0.0009045084971874737
# Validation Loss = 0.019
# Epoch=2, batch = 2000 of 4000, loss=1.128, LR=0.0009045084971874737
# Validation Loss = 0.857
# Epoch=2, batch = 3000 of 4000, loss=3.300, LR=0.0009045084971874737
# Validation Loss = 0.596
# Epoch=3, batch = 0 of 4000, loss=2.827, LR=0.0006545084971874737
# Validation Loss = 0.083
# Epoch=3, batch = 1000 of 4000, loss=0.960, LR=0.0006545084971874737
# Validation Loss = 0.231
# Epoch=3, batch = 2000 of 4000, loss=0.805, LR=0.0006545084971874737
# Validation Loss = 0.097
# Epoch=3, batch = 3000 of 4000, loss=0.887, LR=0.0006545084971874737
# Validation Loss = 0.462
# Epoch=4, batch = 0 of 4000, loss=0.792, LR=0.00034549150281252633
# Validation Loss = 0.370
# Epoch=4, batch = 1000 of 4000, loss=0.814, LR=0.00034549150281252633
# Validation Loss = 1.330
# Epoch=4, batch = 2000 of 4000, loss=1.102, LR=0.00034549150281252633
# Validation Loss = 0.078
# Epoch=4, batch = 3000 of 4000, loss=0.882, LR=0.00034549150281252633
# Validation Loss = 0.497
# Epoch=5, batch = 0 of 4000, loss=0.769, LR=9.549150281252633e-05
# Validation Loss = 0.396
# Epoch=5, batch = 1000 of 4000, loss=0.752, LR=9.549150281252633e-05
# Validation Loss = 0.309
# Epoch=5, batch = 2000 of 4000, loss=0.702, LR=9.549150281252633e-05
# Validation Loss = 0.439
# Epoch=5, batch = 3000 of 4000, loss=0.781, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.447
# Epoch=1, batch = 0 of 4000, loss=0.715, LR=0.001
# Validation Loss = 0.637
# Epoch=1, batch = 1000 of 4000, loss=0.816, LR=0.001
# Validation Loss = 0.323
# Epoch=1, batch = 2000 of 4000, loss=0.725, LR=0.001
# Validation Loss = 0.219
# Epoch=1, batch = 3000 of 4000, loss=0.813, LR=0.001
# Validation Loss = 1.585
# Epoch=2, batch = 0 of 4000, loss=1.137, LR=0.0009755282581475768
# Validation Loss = 0.357
# Epoch=2, batch = 1000 of 4000, loss=0.741, LR=0.0009755282581475768
# Validation Loss = 0.060
# Epoch=2, batch = 2000 of 4000, loss=0.980, LR=0.0009755282581475768
# Validation Loss = 0.712
# Epoch=2, batch = 3000 of 4000, loss=0.802, LR=0.0009755282581475768
# Validation Loss = 1.958
# Epoch=3, batch = 0 of 4000, loss=1.203, LR=0.0009045084971874736
# Validation Loss = 0.834
# Epoch=3, batch = 1000 of 4000, loss=0.709, LR=0.0009045084971874736
# Validation Loss = 2.175
# Epoch=3, batch = 2000 of 4000, loss=1.289, LR=0.0009045084971874736
# Validation Loss = 1.167
# Epoch=3, batch = 3000 of 4000, loss=0.911, LR=0.0009045084971874736
# Validation Loss = 0.005
# Epoch=4, batch = 0 of 4000, loss=1.282, LR=0.0007938926261462366
# Validation Loss = 1.499
# Epoch=4, batch = 1000 of 4000, loss=1.043, LR=0.0007938926261462366
# Validation Loss = 0.000
# Epoch=4, batch = 2000 of 4000, loss=1.095, LR=0.0007938926261462366
# Validation Loss = 1.140
# Epoch=4, batch = 3000 of 4000, loss=0.861, LR=0.0007938926261462366
# Validation Loss = 0.255
# Epoch=5, batch = 0 of 4000, loss=1.838, LR=0.0006545084971874737
# Validation Loss = 0.985
# Epoch=5, batch = 1000 of 4000, loss=0.782, LR=0.0006545084971874737
# Validation Loss = 0.447
# Epoch=5, batch = 2000 of 4000, loss=0.712, LR=0.0006545084971874737
# Validation Loss = 0.060
# Epoch=5, batch = 3000 of 4000, loss=0.802, LR=0.0006545084971874737
# Validation Loss = 1.316
# Epoch=6, batch = 0 of 4000, loss=1.076, LR=0.0005
# Validation Loss = 0.094
# Epoch=6, batch = 1000 of 4000, loss=0.807, LR=0.0005
# Validation Loss = 0.112
# Epoch=6, batch = 2000 of 4000, loss=0.905, LR=0.0005
# Validation Loss = 0.501
# Epoch=6, batch = 3000 of 4000, loss=0.706, LR=0.0005
# Validation Loss = 0.142
# Epoch=7, batch = 0 of 4000, loss=0.803, LR=0.00034549150281252633
# Validation Loss = 0.753
# Epoch=7, batch = 1000 of 4000, loss=0.695, LR=0.00034549150281252633
# Validation Loss = 0.025
# Epoch=7, batch = 2000 of 4000, loss=1.038, LR=0.00034549150281252633
# Validation Loss = 0.409
# Epoch=7, batch = 3000 of 4000, loss=0.732, LR=0.00034549150281252633
# Validation Loss = 0.016
# Epoch=8, batch = 0 of 4000, loss=1.008, LR=0.0002061073738537635
# Validation Loss = 0.142
# Epoch=8, batch = 1000 of 4000, loss=0.758, LR=0.0002061073738537635
# Validation Loss = 0.592
# Epoch=8, batch = 2000 of 4000, loss=0.692, LR=0.0002061073738537635
# Validation Loss = 0.610
# Epoch=8, batch = 3000 of 4000, loss=0.716, LR=0.0002061073738537635
# Validation Loss = 0.151
# Epoch=9, batch = 0 of 4000, loss=0.797, LR=9.549150281252634e-05
# Validation Loss = 0.241
# Epoch=9, batch = 1000 of 4000, loss=0.731, LR=9.549150281252634e-05
# Validation Loss = 0.291
# Epoch=9, batch = 2000 of 4000, loss=0.700, LR=9.549150281252634e-05
# Validation Loss = 0.666
# Epoch=9, batch = 3000 of 4000, loss=0.866, LR=9.549150281252634e-05
# Validation Loss = 0.417
# Epoch=10, batch = 0 of 4000, loss=0.756, LR=2.4471741852423235e-05
# Validation Loss = 0.361
# Epoch=10, batch = 1000 of 4000, loss=0.679, LR=2.4471741852423235e-05
# Validation Loss = 0.346
# Epoch=10, batch = 2000 of 4000, loss=0.728, LR=2.4471741852423235e-05
# Validation Loss = 0.308
# Epoch=10, batch = 3000 of 4000, loss=0.710, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.370
# Epoch=1, batch = 0 of 4000, loss=0.701, LR=0.001
# Validation Loss = 0.217
# Epoch=1, batch = 1000 of 4000, loss=0.723, LR=0.001
# Validation Loss = 3.115
# Epoch=1, batch = 2000 of 4000, loss=2.220, LR=0.001
# Validation Loss = 0.198
# Epoch=1, batch = 3000 of 4000, loss=0.693, LR=0.001
# Validation Loss = 0.028
# Epoch=2, batch = 0 of 4000, loss=1.189, LR=0.0009938441702975688
# Validation Loss = 0.509
# Epoch=2, batch = 1000 of 4000, loss=0.773, LR=0.0009938441702975688
# Validation Loss = 0.711
# Epoch=2, batch = 2000 of 4000, loss=0.713, LR=0.0009938441702975688
# Validation Loss = 0.686
# Epoch=2, batch = 3000 of 4000, loss=0.880, LR=0.0009938441702975688
# Validation Loss = 0.001
# Epoch=3, batch = 0 of 4000, loss=1.039, LR=0.0009755282581475768
# Validation Loss = 0.072
# Epoch=3, batch = 1000 of 4000, loss=0.860, LR=0.0009755282581475768
# Validation Loss = 3.501
# Epoch=3, batch = 2000 of 4000, loss=2.243, LR=0.0009755282581475768
# Validation Loss = 0.045
# Epoch=3, batch = 3000 of 4000, loss=0.864, LR=0.0009755282581475768
# Validation Loss = 0.076
# Epoch=4, batch = 0 of 4000, loss=1.537, LR=0.0009455032620941839
# Validation Loss = 0.322
# Epoch=4, batch = 1000 of 4000, loss=0.719, LR=0.0009455032620941839
# Validation Loss = 0.421
# Epoch=4, batch = 2000 of 4000, loss=0.693, LR=0.0009455032620941839
# Validation Loss = 0.668
# Epoch=4, batch = 3000 of 4000, loss=0.812, LR=0.0009455032620941839
# Validation Loss = 1.841
# Epoch=5, batch = 0 of 4000, loss=1.250, LR=0.0009045084971874737
# Validation Loss = 1.376
# Epoch=5, batch = 1000 of 4000, loss=1.091, LR=0.0009045084971874737
# Validation Loss = 0.015
# Epoch=5, batch = 2000 of 4000, loss=0.843, LR=0.0009045084971874737
# Validation Loss = 0.157
# Epoch=5, batch = 3000 of 4000, loss=0.796, LR=0.0009045084971874737
# Validation Loss = 2.077
# Epoch=6, batch = 0 of 4000, loss=1.453, LR=0.0008535533905932737
# Validation Loss = 0.698
# Epoch=6, batch = 1000 of 4000, loss=0.816, LR=0.0008535533905932737
# Validation Loss = 0.142
# Epoch=6, batch = 2000 of 4000, loss=0.777, LR=0.0008535533905932737
# Validation Loss = 2.119
# Epoch=6, batch = 3000 of 4000, loss=1.502, LR=0.0008535533905932737
# Validation Loss = 0.086
# Epoch=7, batch = 0 of 4000, loss=0.809, LR=0.0007938926261462366
# Validation Loss = 0.457
# Epoch=7, batch = 1000 of 4000, loss=0.741, LR=0.0007938926261462366
# Validation Loss = 0.781
# Epoch=7, batch = 2000 of 4000, loss=0.861, LR=0.0007938926261462366
# Validation Loss = 0.343
# Epoch=7, batch = 3000 of 4000, loss=0.780, LR=0.0007938926261462366
# Validation Loss = 0.496
# Epoch=8, batch = 0 of 4000, loss=0.779, LR=0.0007269952498697733
# Validation Loss = 0.143
# Epoch=8, batch = 1000 of 4000, loss=0.801, LR=0.0007269952498697733
# Validation Loss = 0.002
# Epoch=8, batch = 2000 of 4000, loss=1.005, LR=0.0007269952498697733
# Validation Loss = 0.011
# Epoch=8, batch = 3000 of 4000, loss=1.154, LR=0.0007269952498697733
# Validation Loss = 0.037
# Epoch=9, batch = 0 of 4000, loss=0.803, LR=0.0006545084971874737
# Validation Loss = 0.325
# Epoch=9, batch = 1000 of 4000, loss=0.690, LR=0.0006545084971874737
# Validation Loss = 0.892
# Epoch=9, batch = 2000 of 4000, loss=0.893, LR=0.0006545084971874737
# Validation Loss = 0.916
# Epoch=9, batch = 3000 of 4000, loss=0.804, LR=0.0006545084971874737
# Validation Loss = 0.024
# Epoch=10, batch = 0 of 4000, loss=1.348, LR=0.0005782172325201155
# Validation Loss = 0.313
# Epoch=10, batch = 1000 of 4000, loss=0.719, LR=0.0005782172325201155
# Validation Loss = 0.356
# Epoch=10, batch = 2000 of 4000, loss=0.676, LR=0.0005782172325201155
# Validation Loss = 0.925
# Epoch=10, batch = 3000 of 4000, loss=0.781, LR=0.0005782172325201155
# Validation Loss = 0.345
# Epoch=11, batch = 0 of 4000, loss=0.699, LR=0.0005
# Validation Loss = 0.381
# Epoch=11, batch = 1000 of 4000, loss=0.734, LR=0.0005
# Validation Loss = 0.667
# Epoch=11, batch = 2000 of 4000, loss=0.816, LR=0.0005
# Validation Loss = 0.943
# Epoch=11, batch = 3000 of 4000, loss=0.777, LR=0.0005
# Validation Loss = 0.907
# Epoch=12, batch = 0 of 4000, loss=0.915, LR=0.0004217827674798847
# Validation Loss = 0.509
# Epoch=12, batch = 1000 of 4000, loss=0.623, LR=0.0004217827674798847
# Validation Loss = 0.566
# Epoch=12, batch = 2000 of 4000, loss=0.681, LR=0.0004217827674798847
# Validation Loss = 0.852
# Epoch=12, batch = 3000 of 4000, loss=0.800, LR=0.0004217827674798847
# Validation Loss = 0.389
# Epoch=13, batch = 0 of 4000, loss=0.692, LR=0.00034549150281252633
# Validation Loss = 0.054
# Epoch=13, batch = 1000 of 4000, loss=0.920, LR=0.00034549150281252633
# Validation Loss = 0.106
# Epoch=13, batch = 2000 of 4000, loss=0.796, LR=0.00034549150281252633
# Validation Loss = 0.087
# Epoch=13, batch = 3000 of 4000, loss=0.890, LR=0.00034549150281252633
# Validation Loss = 0.145
# Epoch=14, batch = 0 of 4000, loss=0.776, LR=0.00027300475013022663
# Validation Loss = 0.325
# Epoch=14, batch = 1000 of 4000, loss=0.713, LR=0.00027300475013022663
# Validation Loss = 0.449
# Epoch=14, batch = 2000 of 4000, loss=0.665, LR=0.00027300475013022663
# Validation Loss = 0.328
# Epoch=14, batch = 3000 of 4000, loss=0.697, LR=0.00027300475013022663
# Validation Loss = 0.356
# Epoch=15, batch = 0 of 4000, loss=0.708, LR=0.00020610737385376348
# Validation Loss = 0.332
# Epoch=15, batch = 1000 of 4000, loss=0.689, LR=0.00020610737385376348
# Validation Loss = 0.259
# Epoch=15, batch = 2000 of 4000, loss=0.776, LR=0.00020610737385376348
# Validation Loss = 0.373
# Epoch=15, batch = 3000 of 4000, loss=0.698, LR=0.00020610737385376348
# Validation Loss = 0.267
# Epoch=16, batch = 0 of 4000, loss=0.710, LR=0.00014644660940672625
# Validation Loss = 0.238
# Epoch=16, batch = 1000 of 4000, loss=0.739, LR=0.00014644660940672625
# Validation Loss = 0.479
# Epoch=16, batch = 2000 of 4000, loss=0.669, LR=0.00014644660940672625
# Validation Loss = 0.429
# Epoch=16, batch = 3000 of 4000, loss=0.675, LR=0.00014644660940672625
# Validation Loss = 0.317
# Epoch=17, batch = 0 of 4000, loss=0.725, LR=9.549150281252631e-05
# Validation Loss = 0.540
# Epoch=17, batch = 1000 of 4000, loss=0.717, LR=9.549150281252631e-05
# Validation Loss = 0.530
# Epoch=17, batch = 2000 of 4000, loss=0.709, LR=9.549150281252631e-05
# Validation Loss = 0.493
# Epoch=17, batch = 3000 of 4000, loss=0.734, LR=9.549150281252631e-05
# Validation Loss = 0.488
# Epoch=18, batch = 0 of 4000, loss=0.708, LR=5.4496737905816096e-05
# Validation Loss = 0.361
# Epoch=18, batch = 1000 of 4000, loss=0.698, LR=5.4496737905816096e-05
# Validation Loss = 0.352
# Epoch=18, batch = 2000 of 4000, loss=0.696, LR=5.4496737905816096e-05
# Validation Loss = 0.338
# Epoch=18, batch = 3000 of 4000, loss=0.726, LR=5.4496737905816096e-05
# Validation Loss = 0.559
# Epoch=19, batch = 0 of 4000, loss=0.760, LR=2.447174185242323e-05
# Validation Loss = 0.385
# Epoch=19, batch = 1000 of 4000, loss=0.687, LR=2.447174185242323e-05
# Validation Loss = 0.557
# Epoch=19, batch = 2000 of 4000, loss=0.740, LR=2.447174185242323e-05
# Validation Loss = 0.370
# Epoch=19, batch = 3000 of 4000, loss=0.727, LR=2.447174185242323e-05
# Validation Loss = 0.426
# Epoch=20, batch = 0 of 4000, loss=0.745, LR=6.15582970243117e-06
# Validation Loss = 0.407
# Epoch=20, batch = 1000 of 4000, loss=0.713, LR=6.15582970243117e-06
# Validation Loss = 0.437
# Epoch=20, batch = 2000 of 4000, loss=0.723, LR=6.15582970243117e-06
# Validation Loss = 0.436
# Epoch=20, batch = 3000 of 4000, loss=0.768, LR=6.15582970243117e-06
# Finished training model for channel 10V.
# 10H
# Training stage: 1
# Validation Loss = 9238.668
# Epoch=1, batch = 0 of 4000, loss=9041.542, LR=0.001
# Validation Loss = 4.763
# Epoch=1, batch = 1000 of 4000, loss=2.992, LR=0.001
# Validation Loss = 0.539
# Epoch=1, batch = 2000 of 4000, loss=1.144, LR=0.001
# Validation Loss = 0.754
# Epoch=1, batch = 3000 of 4000, loss=1.286, LR=0.001
# Validation Loss = 2.747
# Epoch=2, batch = 0 of 4000, loss=1.667, LR=0.0009045084971874737
# Validation Loss = 0.007
# Epoch=2, batch = 1000 of 4000, loss=1.887, LR=0.0009045084971874737
# Validation Loss = 1.260
# Epoch=2, batch = 2000 of 4000, loss=1.153, LR=0.0009045084971874737
# Validation Loss = 2.152
# Epoch=2, batch = 3000 of 4000, loss=1.268, LR=0.0009045084971874737
# Validation Loss = 0.052
# Epoch=3, batch = 0 of 4000, loss=1.220, LR=0.0006545084971874737
# Validation Loss = 2.799
# Epoch=3, batch = 1000 of 4000, loss=1.393, LR=0.0006545084971874737
# Validation Loss = 0.549
# Epoch=3, batch = 2000 of 4000, loss=0.847, LR=0.0006545084971874737
# Validation Loss = 0.104
# Epoch=3, batch = 3000 of 4000, loss=1.203, LR=0.0006545084971874737
# Validation Loss = 0.949
# Epoch=4, batch = 0 of 4000, loss=0.827, LR=0.00034549150281252633
# Validation Loss = 0.184
# Epoch=4, batch = 1000 of 4000, loss=0.881, LR=0.00034549150281252633
# Validation Loss = 0.623
# Epoch=4, batch = 2000 of 4000, loss=0.730, LR=0.00034549150281252633
# Validation Loss = 1.199
# Epoch=4, batch = 3000 of 4000, loss=0.718, LR=0.00034549150281252633
# Validation Loss = 0.639
# Epoch=5, batch = 0 of 4000, loss=0.642, LR=9.549150281252633e-05
# Validation Loss = 0.540
# Epoch=5, batch = 1000 of 4000, loss=0.676, LR=9.549150281252633e-05
# Validation Loss = 0.732
# Epoch=5, batch = 2000 of 4000, loss=0.703, LR=9.549150281252633e-05
# Validation Loss = 0.620
# Epoch=5, batch = 3000 of 4000, loss=0.632, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.801
# Epoch=1, batch = 0 of 4000, loss=0.626, LR=0.001
# Validation Loss = 0.932
# Epoch=1, batch = 1000 of 4000, loss=0.745, LR=0.001
# Validation Loss = 0.045
# Epoch=1, batch = 2000 of 4000, loss=1.538, LR=0.001
# Validation Loss = 0.011
# Epoch=1, batch = 3000 of 4000, loss=1.518, LR=0.001
# Validation Loss = 5.349
# Epoch=2, batch = 0 of 4000, loss=2.069, LR=0.0009755282581475768
# Validation Loss = 0.806
# Epoch=2, batch = 1000 of 4000, loss=0.728, LR=0.0009755282581475768
# Validation Loss = 0.065
# Epoch=2, batch = 2000 of 4000, loss=1.181, LR=0.0009755282581475768
# Validation Loss = 1.342
# Epoch=2, batch = 3000 of 4000, loss=0.913, LR=0.0009755282581475768
# Validation Loss = 0.681
# Epoch=3, batch = 0 of 4000, loss=0.711, LR=0.0009045084971874736
# Validation Loss = 2.638
# Epoch=3, batch = 1000 of 4000, loss=1.125, LR=0.0009045084971874736
# Validation Loss = 1.544
# Epoch=3, batch = 2000 of 4000, loss=0.791, LR=0.0009045084971874736
# Validation Loss = 1.787
# Epoch=3, batch = 3000 of 4000, loss=0.942, LR=0.0009045084971874736
# Validation Loss = 1.207
# Epoch=4, batch = 0 of 4000, loss=0.784, LR=0.0007938926261462366
# Validation Loss = 0.760
# Epoch=4, batch = 1000 of 4000, loss=0.664, LR=0.0007938926261462366
# Validation Loss = 0.004
# Epoch=4, batch = 2000 of 4000, loss=1.139, LR=0.0007938926261462366
# Validation Loss = 1.815
# Epoch=4, batch = 3000 of 4000, loss=0.740, LR=0.0007938926261462366
# Validation Loss = 0.166
# Epoch=5, batch = 0 of 4000, loss=0.805, LR=0.0006545084971874737
# Validation Loss = 1.032
# Epoch=5, batch = 1000 of 4000, loss=0.864, LR=0.0006545084971874737
# Validation Loss = 1.824
# Epoch=5, batch = 2000 of 4000, loss=0.676, LR=0.0006545084971874737
# Validation Loss = 3.002
# Epoch=5, batch = 3000 of 4000, loss=0.704, LR=0.0006545084971874737
# Validation Loss = 3.509
# Epoch=6, batch = 0 of 4000, loss=1.199, LR=0.0005
# Validation Loss = 1.278
# Epoch=6, batch = 1000 of 4000, loss=0.589, LR=0.0005
# Validation Loss = 1.367
# Epoch=6, batch = 2000 of 4000, loss=0.601, LR=0.0005
# Validation Loss = 1.464
# Epoch=6, batch = 3000 of 4000, loss=0.758, LR=0.0005
# Validation Loss = 1.350
# Epoch=7, batch = 0 of 4000, loss=0.727, LR=0.00034549150281252633
# Validation Loss = 0.521
# Epoch=7, batch = 1000 of 4000, loss=0.840, LR=0.00034549150281252633
# Validation Loss = 1.854
# Epoch=7, batch = 2000 of 4000, loss=0.627, LR=0.00034549150281252633
# Validation Loss = 1.724
# Epoch=7, batch = 3000 of 4000, loss=0.632, LR=0.00034549150281252633
# Validation Loss = 1.449
# Epoch=8, batch = 0 of 4000, loss=0.655, LR=0.0002061073738537635
# Validation Loss = 1.546
# Epoch=8, batch = 1000 of 4000, loss=0.655, LR=0.0002061073738537635
# Validation Loss = 1.520
# Epoch=8, batch = 2000 of 4000, loss=0.630, LR=0.0002061073738537635
# Validation Loss = 0.912
# Epoch=8, batch = 3000 of 4000, loss=0.562, LR=0.0002061073738537635
# Validation Loss = 2.283
# Epoch=9, batch = 0 of 4000, loss=0.705, LR=9.549150281252634e-05
# Validation Loss = 1.318
# Epoch=9, batch = 1000 of 4000, loss=0.621, LR=9.549150281252634e-05
# Validation Loss = 1.554
# Epoch=9, batch = 2000 of 4000, loss=0.770, LR=9.549150281252634e-05
# Validation Loss = 1.489
# Epoch=9, batch = 3000 of 4000, loss=0.572, LR=9.549150281252634e-05
# Validation Loss = 1.390
# Epoch=10, batch = 0 of 4000, loss=0.647, LR=2.4471741852423235e-05
# Validation Loss = 1.605
# Epoch=10, batch = 1000 of 4000, loss=0.662, LR=2.4471741852423235e-05
# Validation Loss = 1.498
# Epoch=10, batch = 2000 of 4000, loss=0.644, LR=2.4471741852423235e-05
# Validation Loss = 1.516
# Epoch=10, batch = 3000 of 4000, loss=0.646, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 1.542
# Epoch=1, batch = 0 of 4000, loss=0.605, LR=0.001
# Validation Loss = 1.839
# Epoch=1, batch = 1000 of 4000, loss=0.765, LR=0.001
# Validation Loss = 2.186
# Epoch=1, batch = 2000 of 4000, loss=0.688, LR=0.001
# Validation Loss = 2.003
# Epoch=1, batch = 3000 of 4000, loss=0.708, LR=0.001
# Validation Loss = 2.503
# Epoch=2, batch = 0 of 4000, loss=0.716, LR=0.0009938441702975688
# Validation Loss = 1.691
# Epoch=2, batch = 1000 of 4000, loss=0.666, LR=0.0009938441702975688
# Validation Loss = 2.104
# Epoch=2, batch = 2000 of 4000, loss=0.716, LR=0.0009938441702975688
# Validation Loss = 1.532
# Epoch=2, batch = 3000 of 4000, loss=0.742, LR=0.0009938441702975688
# Validation Loss = 4.103
# Epoch=3, batch = 0 of 4000, loss=1.120, LR=0.0009755282581475768
# Validation Loss = 2.334
# Epoch=3, batch = 1000 of 4000, loss=0.866, LR=0.0009755282581475768
# Validation Loss = 1.788
# Epoch=3, batch = 2000 of 4000, loss=0.684, LR=0.0009755282581475768
# Validation Loss = 1.774
# Epoch=3, batch = 3000 of 4000, loss=0.684, LR=0.0009755282581475768
# Validation Loss = 4.242
# Epoch=4, batch = 0 of 4000, loss=1.276, LR=0.0009455032620941839
# Validation Loss = 1.481
# Epoch=4, batch = 1000 of 4000, loss=0.582, LR=0.0009455032620941839
# Validation Loss = 0.187
# Epoch=4, batch = 2000 of 4000, loss=0.959, LR=0.0009455032620941839
# Validation Loss = 2.682
# Epoch=4, batch = 3000 of 4000, loss=0.749, LR=0.0009455032620941839
# Validation Loss = 0.854
# Epoch=5, batch = 0 of 4000, loss=0.784, LR=0.0009045084971874737
# Validation Loss = 2.065
# Epoch=5, batch = 1000 of 4000, loss=0.806, LR=0.0009045084971874737
# Validation Loss = 2.361
# Epoch=5, batch = 2000 of 4000, loss=0.644, LR=0.0009045084971874737
# Validation Loss = 2.488
# Epoch=5, batch = 3000 of 4000, loss=0.798, LR=0.0009045084971874737
# Validation Loss = 4.899
# Epoch=6, batch = 0 of 4000, loss=1.409, LR=0.0008535533905932737
# Validation Loss = 0.789
# Epoch=6, batch = 1000 of 4000, loss=0.815, LR=0.0008535533905932737
# Validation Loss = 1.971
# Epoch=6, batch = 2000 of 4000, loss=0.669, LR=0.0008535533905932737
# Validation Loss = 0.650
# Epoch=6, batch = 3000 of 4000, loss=0.644, LR=0.0008535533905932737
# Validation Loss = 1.044
# Epoch=7, batch = 0 of 4000, loss=0.738, LR=0.0007938926261462366
# Validation Loss = 0.987
# Epoch=7, batch = 1000 of 4000, loss=0.635, LR=0.0007938926261462366
# Validation Loss = 2.942
# Epoch=7, batch = 2000 of 4000, loss=0.682, LR=0.0007938926261462366
# Validation Loss = 1.485
# Epoch=7, batch = 3000 of 4000, loss=0.627, LR=0.0007938926261462366
# Validation Loss = 0.681
# Epoch=8, batch = 0 of 4000, loss=0.918, LR=0.0007269952498697733
# Validation Loss = 4.482
# Epoch=8, batch = 1000 of 4000, loss=1.077, LR=0.0007269952498697733
# Validation Loss = 2.694
# Epoch=8, batch = 2000 of 4000, loss=0.800, LR=0.0007269952498697733
# Validation Loss = 0.740
# Epoch=8, batch = 3000 of 4000, loss=0.801, LR=0.0007269952498697733
# Validation Loss = 1.406
# Epoch=9, batch = 0 of 4000, loss=0.683, LR=0.0006545084971874737
# Validation Loss = 2.432
# Epoch=9, batch = 1000 of 4000, loss=0.720, LR=0.0006545084971874737
# Validation Loss = 1.693
# Epoch=9, batch = 2000 of 4000, loss=0.665, LR=0.0006545084971874737
# Validation Loss = 2.575
# Epoch=9, batch = 3000 of 4000, loss=0.691, LR=0.0006545084971874737
# Validation Loss = 1.245
# Epoch=10, batch = 0 of 4000, loss=0.779, LR=0.0005782172325201155
# Validation Loss = 1.504
# Epoch=10, batch = 1000 of 4000, loss=0.644, LR=0.0005782172325201155
# Validation Loss = 2.135
# Epoch=10, batch = 2000 of 4000, loss=0.730, LR=0.0005782172325201155
# Validation Loss = 1.513
# Epoch=10, batch = 3000 of 4000, loss=0.672, LR=0.0005782172325201155
# Validation Loss = 1.600
# Epoch=11, batch = 0 of 4000, loss=0.739, LR=0.0005
# Validation Loss = 2.130
# Epoch=11, batch = 1000 of 4000, loss=0.637, LR=0.0005
# Validation Loss = 0.932
# Epoch=11, batch = 2000 of 4000, loss=0.681, LR=0.0005
# Validation Loss = 1.087
# Epoch=11, batch = 3000 of 4000, loss=0.815, LR=0.0005
# Validation Loss = 0.537
# Epoch=12, batch = 0 of 4000, loss=1.002, LR=0.0004217827674798847
# Validation Loss = 0.873
# Epoch=12, batch = 1000 of 4000, loss=0.727, LR=0.0004217827674798847
# Validation Loss = 1.843
# Epoch=12, batch = 2000 of 4000, loss=0.632, LR=0.0004217827674798847
# Validation Loss = 1.674
# Epoch=12, batch = 3000 of 4000, loss=0.561, LR=0.0004217827674798847
# Validation Loss = 2.425
# Epoch=13, batch = 0 of 4000, loss=0.725, LR=0.00034549150281252633
# Validation Loss = 2.041
# Epoch=13, batch = 1000 of 4000, loss=0.639, LR=0.00034549150281252633
# Validation Loss = 1.850
# Epoch=13, batch = 2000 of 4000, loss=0.579, LR=0.00034549150281252633
# Validation Loss = 2.189
# Epoch=13, batch = 3000 of 4000, loss=0.640, LR=0.00034549150281252633
# Validation Loss = 2.799
# Epoch=14, batch = 0 of 4000, loss=0.735, LR=0.00027300475013022663
# Validation Loss = 1.034
# Epoch=14, batch = 1000 of 4000, loss=0.641, LR=0.00027300475013022663
# Validation Loss = 2.111
# Epoch=14, batch = 2000 of 4000, loss=0.605, LR=0.00027300475013022663
# Validation Loss = 1.970
# Epoch=14, batch = 3000 of 4000, loss=0.751, LR=0.00027300475013022663
# Validation Loss = 2.114
# Epoch=15, batch = 0 of 4000, loss=0.649, LR=0.00020610737385376348
# Validation Loss = 2.233
# Epoch=15, batch = 1000 of 4000, loss=0.605, LR=0.00020610737385376348
# Validation Loss = 2.120
# Epoch=15, batch = 2000 of 4000, loss=0.705, LR=0.00020610737385376348
# Validation Loss = 1.742
# Epoch=15, batch = 3000 of 4000, loss=0.581, LR=0.00020610737385376348
# Validation Loss = 1.283
# Epoch=16, batch = 0 of 4000, loss=0.648, LR=0.00014644660940672625
# Validation Loss = 1.790
# Epoch=16, batch = 1000 of 4000, loss=0.707, LR=0.00014644660940672625
# Validation Loss = 2.303
# Epoch=16, batch = 2000 of 4000, loss=0.687, LR=0.00014644660940672625
# Validation Loss = 1.626
# Epoch=16, batch = 3000 of 4000, loss=0.595, LR=0.00014644660940672625
# Validation Loss = 1.497
# Epoch=17, batch = 0 of 4000, loss=0.704, LR=9.549150281252631e-05
# Validation Loss = 2.411
# Epoch=17, batch = 1000 of 4000, loss=0.642, LR=9.549150281252631e-05
# Validation Loss = 1.483
# Epoch=17, batch = 2000 of 4000, loss=0.578, LR=9.549150281252631e-05
# Validation Loss = 1.320
# Epoch=17, batch = 3000 of 4000, loss=0.623, LR=9.549150281252631e-05
# Validation Loss = 1.325
# Epoch=18, batch = 0 of 4000, loss=0.660, LR=5.4496737905816096e-05
# Validation Loss = 1.717
# Epoch=18, batch = 1000 of 4000, loss=0.614, LR=5.4496737905816096e-05
# Validation Loss = 1.526
# Epoch=18, batch = 2000 of 4000, loss=0.604, LR=5.4496737905816096e-05
# Validation Loss = 1.552
# Epoch=18, batch = 3000 of 4000, loss=0.641, LR=5.4496737905816096e-05
# Validation Loss = 1.957
# Epoch=19, batch = 0 of 4000, loss=0.627, LR=2.447174185242323e-05
# Validation Loss = 1.778
# Epoch=19, batch = 1000 of 4000, loss=0.604, LR=2.447174185242323e-05
# Validation Loss = 1.776
# Epoch=19, batch = 2000 of 4000, loss=0.633, LR=2.447174185242323e-05
# Validation Loss = 1.888
# Epoch=19, batch = 3000 of 4000, loss=0.631, LR=2.447174185242323e-05
# Validation Loss = 1.748
# Epoch=20, batch = 0 of 4000, loss=0.595, LR=6.15582970243117e-06
# Validation Loss = 1.794
# Epoch=20, batch = 1000 of 4000, loss=0.604, LR=6.15582970243117e-06
# Validation Loss = 1.789
# Epoch=20, batch = 2000 of 4000, loss=0.610, LR=6.15582970243117e-06
# Validation Loss = 1.482
# Epoch=20, batch = 3000 of 4000, loss=0.637, LR=6.15582970243117e-06
# Finished training model for channel 10H.
# 19V
# Training stage: 1
# Validation Loss = 37564.410
# Epoch=1, batch = 0 of 4000, loss=37154.008, LR=0.001
# Validation Loss = 0.808
# Epoch=1, batch = 1000 of 4000, loss=1.053, LR=0.001
# Validation Loss = 0.980
# Epoch=1, batch = 2000 of 4000, loss=0.836, LR=0.001
# Validation Loss = 0.839
# Epoch=1, batch = 3000 of 4000, loss=0.692, LR=0.001
# Validation Loss = 0.762
# Epoch=2, batch = 0 of 4000, loss=0.638, LR=0.0009045084971874737
# Validation Loss = 0.037
# Epoch=2, batch = 1000 of 4000, loss=0.908, LR=0.0009045084971874737
# Validation Loss = 3.145
# Epoch=2, batch = 2000 of 4000, loss=1.742, LR=0.0009045084971874737
# Validation Loss = 2.106
# Epoch=2, batch = 3000 of 4000, loss=1.218, LR=0.0009045084971874737
# Validation Loss = 0.045
# Epoch=3, batch = 0 of 4000, loss=0.849, LR=0.0006545084971874737
# Validation Loss = 1.796
# Epoch=3, batch = 1000 of 4000, loss=1.100, LR=0.0006545084971874737
# Validation Loss = 4.011
# Epoch=3, batch = 2000 of 4000, loss=2.557, LR=0.0006545084971874737
# Validation Loss = 2.285
# Epoch=3, batch = 3000 of 4000, loss=1.342, LR=0.0006545084971874737
# Validation Loss = 1.483
# Epoch=4, batch = 0 of 4000, loss=0.909, LR=0.00034549150281252633
# Validation Loss = 0.228
# Epoch=4, batch = 1000 of 4000, loss=0.641, LR=0.00034549150281252633
# Validation Loss = 0.181
# Epoch=4, batch = 2000 of 4000, loss=0.575, LR=0.00034549150281252633
# Validation Loss = 0.908
# Epoch=4, batch = 3000 of 4000, loss=0.632, LR=0.00034549150281252633
# Validation Loss = 0.470
# Epoch=5, batch = 0 of 4000, loss=0.538, LR=9.549150281252633e-05
# Validation Loss = 0.596
# Epoch=5, batch = 1000 of 4000, loss=0.562, LR=9.549150281252633e-05
# Validation Loss = 0.501
# Epoch=5, batch = 2000 of 4000, loss=0.545, LR=9.549150281252633e-05
# Validation Loss = 0.519
# Epoch=5, batch = 3000 of 4000, loss=0.530, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.539
# Epoch=1, batch = 0 of 4000, loss=0.490, LR=0.001
# Validation Loss = 0.484
# Epoch=1, batch = 1000 of 4000, loss=0.664, LR=0.001
# Validation Loss = 0.517
# Epoch=1, batch = 2000 of 4000, loss=0.605, LR=0.001
# Validation Loss = 0.233
# Epoch=1, batch = 3000 of 4000, loss=0.658, LR=0.001
# Validation Loss = 0.002
# Epoch=2, batch = 0 of 4000, loss=0.925, LR=0.0009755282581475768
# Validation Loss = 0.073
# Epoch=2, batch = 1000 of 4000, loss=0.807, LR=0.0009755282581475768
# Validation Loss = 0.015
# Epoch=2, batch = 2000 of 4000, loss=1.130, LR=0.0009755282581475768
# Validation Loss = 1.439
# Epoch=2, batch = 3000 of 4000, loss=0.905, LR=0.0009755282581475768
# Validation Loss = 0.328
# Epoch=3, batch = 0 of 4000, loss=0.549, LR=0.0009045084971874736
# Validation Loss = 0.202
# Epoch=3, batch = 1000 of 4000, loss=0.587, LR=0.0009045084971874736
# Validation Loss = 1.249
# Epoch=3, batch = 2000 of 4000, loss=0.761, LR=0.0009045084971874736
# Validation Loss = 4.306
# Epoch=3, batch = 3000 of 4000, loss=2.470, LR=0.0009045084971874736
# Validation Loss = 0.015
# Epoch=4, batch = 0 of 4000, loss=1.080, LR=0.0007938926261462366
# Validation Loss = 1.294
# Epoch=4, batch = 1000 of 4000, loss=0.689, LR=0.0007938926261462366
# Validation Loss = 0.447
# Epoch=4, batch = 2000 of 4000, loss=0.600, LR=0.0007938926261462366
# Validation Loss = 0.357
# Epoch=4, batch = 3000 of 4000, loss=0.595, LR=0.0007938926261462366
# Validation Loss = 0.945
# Epoch=5, batch = 0 of 4000, loss=0.620, LR=0.0006545084971874737
# Validation Loss = 0.612
# Epoch=5, batch = 1000 of 4000, loss=0.523, LR=0.0006545084971874737
# Validation Loss = 1.603
# Epoch=5, batch = 2000 of 4000, loss=0.895, LR=0.0006545084971874737
# Validation Loss = 2.431
# Epoch=5, batch = 3000 of 4000, loss=1.454, LR=0.0006545084971874737
# Validation Loss = 1.164
# Epoch=6, batch = 0 of 4000, loss=0.673, LR=0.0005
# Validation Loss = 1.133
# Epoch=6, batch = 1000 of 4000, loss=0.659, LR=0.0005
# Validation Loss = 0.073
# Epoch=6, batch = 2000 of 4000, loss=0.810, LR=0.0005
# Validation Loss = 0.765
# Epoch=6, batch = 3000 of 4000, loss=0.544, LR=0.0005
# Validation Loss = 0.693
# Epoch=7, batch = 0 of 4000, loss=0.527, LR=0.00034549150281252633
# Validation Loss = 1.157
# Epoch=7, batch = 1000 of 4000, loss=0.707, LR=0.00034549150281252633
# Validation Loss = 0.154
# Epoch=7, batch = 2000 of 4000, loss=0.630, LR=0.00034549150281252633
# Validation Loss = 0.339
# Epoch=7, batch = 3000 of 4000, loss=0.521, LR=0.00034549150281252633
# Validation Loss = 0.393
# Epoch=8, batch = 0 of 4000, loss=0.499, LR=0.0002061073738537635
# Validation Loss = 0.421
# Epoch=8, batch = 1000 of 4000, loss=0.525, LR=0.0002061073738537635
# Validation Loss = 0.566
# Epoch=8, batch = 2000 of 4000, loss=0.452, LR=0.0002061073738537635
# Validation Loss = 0.702
# Epoch=8, batch = 3000 of 4000, loss=0.537, LR=0.0002061073738537635
# Validation Loss = 0.822
# Epoch=9, batch = 0 of 4000, loss=0.525, LR=9.549150281252634e-05
# Validation Loss = 1.247
# Epoch=16, batch = 3000 of 4000, loss=3.457, LR=0.00014644660940672625
# Validation Loss = 0.000
# Epoch=17, batch = 0 of 4000, loss=3.390, LR=9.549150281252631e-05
# Validation Loss = 0.075
# Epoch=17, batch = 1000 of 4000, loss=3.284, LR=9.549150281252631e-05
# Validation Loss = 0.008
# Epoch=17, batch = 2000 of 4000, loss=3.193, LR=9.549150281252631e-05
# Validation Loss = 0.006
# Epoch=17, batch = 3000 of 4000, loss=3.304, LR=9.549150281252631e-05
# Validation Loss = 0.000
# Epoch=18, batch = 0 of 4000, loss=3.409, LR=5.4496737905816096e-05
# Validation Loss = 0.176
# Epoch=18, batch = 1000 of 4000, loss=3.280, LR=5.4496737905816096e-05
# Validation Loss = 0.165
# Epoch=18, batch = 2000 of 4000, loss=3.038, LR=5.4496737905816096e-05

# %%
#General parameters:
input_size = nchans - 1 + 1 #Remaining channels + surface type

# %%
'''

GMI CHANNEL PREDICTION MODEL:
    2: Non-Ocean Surfaces

'''

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = sfctype > 1

    Tbs = f.Tbs.values[correct_sfc,:]
    sfctype = sfctype[correct_sfc]

Tbs = Tbs[:,[0,1,2,3,4,7,8,9,10,11,12]]

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

sfctype_train = sfctype[train_indcs].astype(np.float32)
sfctype_test  = sfctype[test_indcs].astype(np.float32)
sfctype_val   = sfctype[val_indcs].astype(np.float32)

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train, shuffled_indcs = array_funcs.shuffle_data(Tbs_train, axis=0, return_indcs=True)
sfctype_train = sfctype_train[shuffled_indcs]

# %%
sfctype_train, sfctype_test, sfctype_val
# Out:
# (array([ 8.,  5.,  2., ...,  5.,  9., 17.],
#        shape=(14253019,), dtype=float32),
#  array([10., 10., 10., ..., 18., 18., 18.], shape=(1781627,), dtype=float32),
#  array([18., 18., 18., ...,  2.,  2.,  2.], shape=(1781628,), dtype=float32))

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    print(channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)

    x_train = np.concatenate((x_train, sfctype_train[:,None]), axis=1)
    x_test  = np.concatenate((x_test,  sfctype_test[:,None]), axis=1)
    x_val   = np.concatenate((x_val,   sfctype_val[:,None]), axis=1)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_nonocean_no37.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_nonocean_no37.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 10V
# Training stage: 1
# Validation Loss = 60983.789
# Epoch=1, batch = 0 of 14253, loss=68470.742, LR=0.001
# Validation Loss = 6.965
# Epoch=1, batch = 1000 of 14253, loss=5.594, LR=0.001
# Validation Loss = 2.432
# Epoch=1, batch = 2000 of 14253, loss=4.840, LR=0.001
# Validation Loss = 0.398
# Epoch=1, batch = 3000 of 14253, loss=10.929, LR=0.001
# Validation Loss = 2.092
# Epoch=1, batch = 4000 of 14253, loss=4.061, LR=0.001
# Validation Loss = 12.570
# Epoch=1, batch = 5000 of 14253, loss=12.580, LR=0.001
# Validation Loss = 12.586
# Epoch=1, batch = 6000 of 14253, loss=9.448, LR=0.001
# Validation Loss = 2.318
# Epoch=1, batch = 7000 of 14253, loss=7.630, LR=0.001
# Validation Loss = 2.653
# Epoch=1, batch = 8000 of 14253, loss=5.374, LR=0.001
# Validation Loss = 0.094
# Epoch=1, batch = 9000 of 14253, loss=3.685, LR=0.001
# Validation Loss = 1.136
# Epoch=1, batch = 10000 of 14253, loss=4.551, LR=0.001
# Validation Loss = 0.125
# Epoch=1, batch = 11000 of 14253, loss=3.499, LR=0.001
# Validation Loss = 3.974
# Epoch=1, batch = 12000 of 14253, loss=5.383, LR=0.001
# Validation Loss = 1.936
# Epoch=1, batch = 13000 of 14253, loss=4.687, LR=0.001
# Validation Loss = 1.064
# Epoch=1, batch = 14000 of 14253, loss=3.197, LR=0.001
# Validation Loss = 0.671
# Epoch=2, batch = 0 of 14253, loss=4.984, LR=0.0009045084971874737
# Validation Loss = 2.644
# Epoch=2, batch = 1000 of 14253, loss=4.274, LR=0.0009045084971874737
# Validation Loss = 0.081
# Epoch=2, batch = 2000 of 14253, loss=3.498, LR=0.0009045084971874737
# Validation Loss = 0.353
# Epoch=2, batch = 3000 of 14253, loss=3.291, LR=0.0009045084971874737
# Validation Loss = 2.139
# Epoch=2, batch = 4000 of 14253, loss=4.837, LR=0.0009045084971874737
# Validation Loss = 4.213
# Epoch=2, batch = 5000 of 14253, loss=4.190, LR=0.0009045084971874737
# Validation Loss = 4.880
# Epoch=2, batch = 6000 of 14253, loss=6.692, LR=0.0009045084971874737
# Validation Loss = 2.347
# Epoch=2, batch = 7000 of 14253, loss=3.720, LR=0.0009045084971874737
# Validation Loss = 1.155
# Epoch=2, batch = 8000 of 14253, loss=3.249, LR=0.0009045084971874737
# Validation Loss = 0.025
# Epoch=2, batch = 9000 of 14253, loss=3.570, LR=0.0009045084971874737
# Validation Loss = 0.710
# Epoch=2, batch = 10000 of 14253, loss=2.771, LR=0.0009045084971874737
# Validation Loss = 1.430
# Epoch=2, batch = 11000 of 14253, loss=2.907, LR=0.0009045084971874737
# Validation Loss = 0.213
# Epoch=2, batch = 12000 of 14253, loss=4.028, LR=0.0009045084971874737
# Validation Loss = 2.178
# Epoch=2, batch = 13000 of 14253, loss=5.720, LR=0.0009045084971874737
# Validation Loss = 0.122
# Epoch=2, batch = 14000 of 14253, loss=2.781, LR=0.0009045084971874737
# Validation Loss = 0.674
# Epoch=3, batch = 0 of 14253, loss=4.453, LR=0.0006545084971874737
# Validation Loss = 0.282
# Epoch=3, batch = 1000 of 14253, loss=3.052, LR=0.0006545084971874737
# Validation Loss = 0.037
# Epoch=3, batch = 2000 of 14253, loss=2.723, LR=0.0006545084971874737
# Validation Loss = 0.827
# Epoch=3, batch = 3000 of 14253, loss=2.667, LR=0.0006545084971874737
# Validation Loss = 0.284
# Epoch=3, batch = 4000 of 14253, loss=2.764, LR=0.0006545084971874737
# Validation Loss = 1.338
# Epoch=3, batch = 5000 of 14253, loss=4.229, LR=0.0006545084971874737
# Validation Loss = 0.670
# Epoch=3, batch = 6000 of 14253, loss=3.023, LR=0.0006545084971874737
# Validation Loss = 0.051
# Epoch=3, batch = 7000 of 14253, loss=2.760, LR=0.0006545084971874737
# Validation Loss = 0.182
# Epoch=3, batch = 8000 of 14253, loss=2.510, LR=0.0006545084971874737
# Validation Loss = 0.849
# Epoch=3, batch = 9000 of 14253, loss=3.098, LR=0.0006545084971874737
# Validation Loss = 0.191
# Epoch=3, batch = 10000 of 14253, loss=4.181, LR=0.0006545084971874737
# Validation Loss = 0.799
# Epoch=3, batch = 11000 of 14253, loss=4.380, LR=0.0006545084971874737
# Validation Loss = 1.280
# Epoch=3, batch = 12000 of 14253, loss=3.076, LR=0.0006545084971874737
# Validation Loss = 0.009
# Epoch=3, batch = 13000 of 14253, loss=3.024, LR=0.0006545084971874737
# Validation Loss = 0.270
# Epoch=3, batch = 14000 of 14253, loss=2.209, LR=0.0006545084971874737
# Validation Loss = 1.639
# Epoch=4, batch = 0 of 14253, loss=3.134, LR=0.00034549150281252633
# Validation Loss = 0.064
# Epoch=4, batch = 1000 of 14253, loss=2.750, LR=0.00034549150281252633
# Validation Loss = 0.375
# Epoch=4, batch = 2000 of 14253, loss=2.964, LR=0.00034549150281252633
# Validation Loss = 0.070
# Epoch=4, batch = 3000 of 14253, loss=2.751, LR=0.00034549150281252633
# Validation Loss = 0.353
# Epoch=4, batch = 4000 of 14253, loss=2.466, LR=0.00034549150281252633
# Validation Loss = 0.435
# Epoch=4, batch = 5000 of 14253, loss=2.336, LR=0.00034549150281252633
# Validation Loss = 0.069
# Epoch=4, batch = 6000 of 14253, loss=2.714, LR=0.00034549150281252633
# Validation Loss = 0.137
# Epoch=4, batch = 7000 of 14253, loss=2.605, LR=0.00034549150281252633
# Validation Loss = 0.004
# Epoch=4, batch = 8000 of 14253, loss=3.063, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=4, batch = 9000 of 14253, loss=2.376, LR=0.00034549150281252633
# Validation Loss = 0.772
# Epoch=4, batch = 10000 of 14253, loss=2.608, LR=0.00034549150281252633
# Validation Loss = 0.948
# Epoch=4, batch = 11000 of 14253, loss=2.635, LR=0.00034549150281252633
# Validation Loss = 0.518
# Epoch=4, batch = 12000 of 14253, loss=3.147, LR=0.00034549150281252633
# Validation Loss = 0.007
# Epoch=4, batch = 13000 of 14253, loss=2.636, LR=0.00034549150281252633
# Validation Loss = 0.818
# Epoch=4, batch = 14000 of 14253, loss=3.001, LR=0.00034549150281252633
# Validation Loss = 0.000
# Epoch=5, batch = 0 of 14253, loss=2.416, LR=9.549150281252633e-05
# Validation Loss = 0.117
# Epoch=5, batch = 1000 of 14253, loss=2.696, LR=9.549150281252633e-05
# Validation Loss = 0.075
# Epoch=5, batch = 2000 of 14253, loss=2.256, LR=9.549150281252633e-05
# Validation Loss = 0.030
# Epoch=5, batch = 3000 of 14253, loss=3.341, LR=9.549150281252633e-05
# Validation Loss = 0.101
# Epoch=5, batch = 4000 of 14253, loss=2.420, LR=9.549150281252633e-05
# Validation Loss = 0.013
# Epoch=5, batch = 5000 of 14253, loss=2.663, LR=9.549150281252633e-05
# Validation Loss = 0.033
# Epoch=5, batch = 6000 of 14253, loss=2.692, LR=9.549150281252633e-05
# Validation Loss = 0.090
# Epoch=5, batch = 7000 of 14253, loss=2.807, LR=9.549150281252633e-05
# Validation Loss = 0.002
# Epoch=5, batch = 8000 of 14253, loss=2.934, LR=9.549150281252633e-05
# Validation Loss = 0.545
# Epoch=5, batch = 9000 of 14253, loss=2.565, LR=9.549150281252633e-05
# Validation Loss = 0.022
# Epoch=5, batch = 10000 of 14253, loss=3.072, LR=9.549150281252633e-05
# Validation Loss = 0.112
# Epoch=5, batch = 11000 of 14253, loss=2.305, LR=9.549150281252633e-05
# Validation Loss = 0.129
# Epoch=5, batch = 12000 of 14253, loss=2.549, LR=9.549150281252633e-05
# Validation Loss = 0.142
# Epoch=5, batch = 13000 of 14253, loss=2.725, LR=9.549150281252633e-05
# Validation Loss = 0.067
# Epoch=5, batch = 14000 of 14253, loss=2.408, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.004
# Epoch=1, batch = 0 of 14253, loss=2.160, LR=0.001
# Validation Loss = 0.143
# Epoch=1, batch = 1000 of 14253, loss=2.723, LR=0.001
# Validation Loss = 0.005
# Epoch=1, batch = 2000 of 14253, loss=2.832, LR=0.001
# Validation Loss = 0.125
# Epoch=1, batch = 3000 of 14253, loss=3.080, LR=0.001
# Validation Loss = 0.089
# Epoch=1, batch = 4000 of 14253, loss=4.227, LR=0.001
# Validation Loss = 0.216
# Epoch=1, batch = 5000 of 14253, loss=2.480, LR=0.001
# Validation Loss = 0.242
# Epoch=1, batch = 6000 of 14253, loss=2.940, LR=0.001
# Validation Loss = 1.181
# Epoch=1, batch = 7000 of 14253, loss=4.913, LR=0.001
# Validation Loss = 0.587
# Epoch=1, batch = 8000 of 14253, loss=2.757, LR=0.001
# Validation Loss = 0.224
# Epoch=1, batch = 9000 of 14253, loss=3.100, LR=0.001
# Validation Loss = 0.012
# Epoch=1, batch = 10000 of 14253, loss=2.605, LR=0.001
# Validation Loss = 0.421
# Epoch=1, batch = 11000 of 14253, loss=3.620, LR=0.001
# Validation Loss = 0.000
# Epoch=1, batch = 12000 of 14253, loss=4.407, LR=0.001
# Validation Loss = 0.124
# Epoch=1, batch = 13000 of 14253, loss=2.970, LR=0.001
# Validation Loss = 0.258
# Epoch=1, batch = 14000 of 14253, loss=2.717, LR=0.001
# Validation Loss = 0.251
# Epoch=2, batch = 0 of 14253, loss=2.569, LR=0.0009755282581475768
# Validation Loss = 0.256
# Epoch=2, batch = 1000 of 14253, loss=3.306, LR=0.0009755282581475768
# Validation Loss = 0.669
# Epoch=2, batch = 2000 of 14253, loss=2.845, LR=0.0009755282581475768
# Validation Loss = 3.574
# Epoch=2, batch = 3000 of 14253, loss=4.327, LR=0.0009755282581475768
# Validation Loss = 0.389
# Epoch=2, batch = 4000 of 14253, loss=3.076, LR=0.0009755282581475768
# Validation Loss = 1.043
# Epoch=2, batch = 5000 of 14253, loss=3.073, LR=0.0009755282581475768
# Validation Loss = 0.445
# Epoch=2, batch = 6000 of 14253, loss=3.302, LR=0.0009755282581475768
# Validation Loss = 0.981
# Epoch=2, batch = 7000 of 14253, loss=2.612, LR=0.0009755282581475768
# Validation Loss = 0.927
# Epoch=2, batch = 8000 of 14253, loss=3.382, LR=0.0009755282581475768
# Validation Loss = 0.494
# Epoch=2, batch = 9000 of 14253, loss=2.755, LR=0.0009755282581475768
# Validation Loss = 1.586
# Epoch=2, batch = 10000 of 14253, loss=5.480, LR=0.0009755282581475768
# Validation Loss = 0.433
# Epoch=2, batch = 11000 of 14253, loss=2.463, LR=0.0009755282581475768
# Validation Loss = 0.009
# Epoch=2, batch = 12000 of 14253, loss=2.305, LR=0.0009755282581475768
# Validation Loss = 0.697
# Epoch=2, batch = 13000 of 14253, loss=3.683, LR=0.0009755282581475768
# Validation Loss = 0.359
# Epoch=2, batch = 14000 of 14253, loss=3.545, LR=0.0009755282581475768
# Validation Loss = 0.077
# Epoch=3, batch = 0 of 14253, loss=2.326, LR=0.0009045084971874736
# Validation Loss = 0.071
# Epoch=3, batch = 1000 of 14253, loss=2.547, LR=0.0009045084971874736
# Validation Loss = 0.230
# Epoch=3, batch = 2000 of 14253, loss=2.536, LR=0.0009045084971874736
# Validation Loss = 1.547
# Epoch=3, batch = 3000 of 14253, loss=3.051, LR=0.0009045084971874736
# Validation Loss = 0.688
# Epoch=3, batch = 4000 of 14253, loss=3.781, LR=0.0009045084971874736
# Validation Loss = 0.004
# Epoch=3, batch = 5000 of 14253, loss=2.466, LR=0.0009045084971874736
# Validation Loss = 0.903
# Epoch=3, batch = 6000 of 14253, loss=3.344, LR=0.0009045084971874736
# Validation Loss = 0.005
# Epoch=3, batch = 7000 of 14253, loss=2.781, LR=0.0009045084971874736
# Validation Loss = 0.020
# Epoch=3, batch = 8000 of 14253, loss=2.931, LR=0.0009045084971874736
# Validation Loss = 0.047
# Epoch=3, batch = 9000 of 14253, loss=2.899, LR=0.0009045084971874736
# Validation Loss = 0.097
# Epoch=3, batch = 10000 of 14253, loss=2.270, LR=0.0009045084971874736
# Validation Loss = 0.081
# Epoch=3, batch = 11000 of 14253, loss=2.713, LR=0.0009045084971874736
# Validation Loss = 0.765
# Epoch=3, batch = 12000 of 14253, loss=3.035, LR=0.0009045084971874736
# Validation Loss = 0.029
# Epoch=3, batch = 13000 of 14253, loss=2.855, LR=0.0009045084971874736
# Validation Loss = 0.741
# Epoch=3, batch = 14000 of 14253, loss=2.966, LR=0.0009045084971874736
# Validation Loss = 0.071
# Epoch=4, batch = 0 of 14253, loss=3.147, LR=0.0007938926261462366
# Validation Loss = 0.059
# Epoch=4, batch = 1000 of 14253, loss=2.554, LR=0.0007938926261462366
# Validation Loss = 0.006
# Epoch=4, batch = 2000 of 14253, loss=2.441, LR=0.0007938926261462366
# Validation Loss = 0.578
# Epoch=4, batch = 3000 of 14253, loss=2.984, LR=0.0007938926261462366
# Validation Loss = 0.140
# Epoch=4, batch = 4000 of 14253, loss=2.307, LR=0.0007938926261462366
# Validation Loss = 0.849
# Epoch=4, batch = 5000 of 14253, loss=2.652, LR=0.0007938926261462366
# Validation Loss = 0.002
# Epoch=4, batch = 6000 of 14253, loss=2.451, LR=0.0007938926261462366
# Validation Loss = 1.472
# Epoch=4, batch = 7000 of 14253, loss=2.787, LR=0.0007938926261462366
# Validation Loss = 0.359
# Epoch=4, batch = 8000 of 14253, loss=2.813, LR=0.0007938926261462366
# Validation Loss = 0.185
# Epoch=4, batch = 9000 of 14253, loss=2.687, LR=0.0007938926261462366
# Validation Loss = 0.253
# Epoch=4, batch = 10000 of 14253, loss=2.529, LR=0.0007938926261462366
# Validation Loss = 0.173
# Epoch=4, batch = 11000 of 14253, loss=2.635, LR=0.0007938926261462366
# Validation Loss = 0.185
# Epoch=4, batch = 12000 of 14253, loss=3.659, LR=0.0007938926261462366
# Validation Loss = 0.007
# Epoch=4, batch = 13000 of 14253, loss=2.894, LR=0.0007938926261462366
# Validation Loss = 0.102
# Epoch=4, batch = 14000 of 14253, loss=2.398, LR=0.0007938926261462366
# Validation Loss = 1.337
# Epoch=5, batch = 0 of 14253, loss=2.440, LR=0.0006545084971874737
# Validation Loss = 0.022
# Epoch=5, batch = 1000 of 14253, loss=2.675, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=5, batch = 2000 of 14253, loss=2.393, LR=0.0006545084971874737
# Validation Loss = 0.325
# Epoch=5, batch = 3000 of 14253, loss=2.467, LR=0.0006545084971874737
# Validation Loss = 0.356
# Epoch=5, batch = 4000 of 14253, loss=2.512, LR=0.0006545084971874737
# Validation Loss = 2.166
# Epoch=5, batch = 5000 of 14253, loss=3.486, LR=0.0006545084971874737
# Validation Loss = 1.215
# Epoch=5, batch = 6000 of 14253, loss=3.225, LR=0.0006545084971874737
# Validation Loss = 0.007
# Epoch=5, batch = 7000 of 14253, loss=2.570, LR=0.0006545084971874737
# Validation Loss = 0.010
# Epoch=5, batch = 8000 of 14253, loss=2.295, LR=0.0006545084971874737
# Validation Loss = 0.245
# Epoch=5, batch = 9000 of 14253, loss=2.394, LR=0.0006545084971874737
# Validation Loss = 0.172
# Epoch=5, batch = 10000 of 14253, loss=2.438, LR=0.0006545084971874737
# Validation Loss = 0.035
# Epoch=5, batch = 11000 of 14253, loss=2.563, LR=0.0006545084971874737
# Validation Loss = 0.004
# Epoch=5, batch = 12000 of 14253, loss=2.312, LR=0.0006545084971874737
# Validation Loss = 0.148
# Epoch=5, batch = 13000 of 14253, loss=2.484, LR=0.0006545084971874737
# Validation Loss = 0.148
# Epoch=5, batch = 14000 of 14253, loss=2.887, LR=0.0006545084971874737
# Validation Loss = 0.446
# Epoch=6, batch = 0 of 14253, loss=2.388, LR=0.0005
# Validation Loss = 0.030
# Epoch=6, batch = 1000 of 14253, loss=2.604, LR=0.0005
# Validation Loss = 0.002
# Epoch=6, batch = 2000 of 14253, loss=2.470, LR=0.0005
# Validation Loss = 0.093
# Epoch=6, batch = 3000 of 14253, loss=2.799, LR=0.0005
# Validation Loss = 0.041
# Epoch=6, batch = 4000 of 14253, loss=2.954, LR=0.0005
# Validation Loss = 0.012
# Epoch=6, batch = 5000 of 14253, loss=2.293, LR=0.0005
# Validation Loss = 0.448
# Epoch=6, batch = 6000 of 14253, loss=2.646, LR=0.0005
# Validation Loss = 0.000
# Epoch=6, batch = 7000 of 14253, loss=2.510, LR=0.0005
# Validation Loss = 0.128
# Epoch=6, batch = 8000 of 14253, loss=2.737, LR=0.0005
# Validation Loss = 0.072
# Epoch=6, batch = 9000 of 14253, loss=3.557, LR=0.0005
# Validation Loss = 0.011
# Epoch=6, batch = 10000 of 14253, loss=2.426, LR=0.0005
# Validation Loss = 0.138
# Epoch=6, batch = 11000 of 14253, loss=3.170, LR=0.0005
# Validation Loss = 0.186
# Epoch=6, batch = 12000 of 14253, loss=2.496, LR=0.0005
# Validation Loss = 0.200
# Epoch=6, batch = 13000 of 14253, loss=1.931, LR=0.0005
# Validation Loss = 0.055
# Epoch=6, batch = 14000 of 14253, loss=2.401, LR=0.0005
# Validation Loss = 0.762
# Epoch=7, batch = 0 of 14253, loss=4.751, LR=0.00034549150281252633
# Validation Loss = 0.574
# Epoch=7, batch = 1000 of 14253, loss=2.553, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=7, batch = 2000 of 14253, loss=2.510, LR=0.00034549150281252633
# Validation Loss = 0.019
# Epoch=7, batch = 3000 of 14253, loss=2.335, LR=0.00034549150281252633
# Validation Loss = 0.067
# Epoch=7, batch = 4000 of 14253, loss=2.294, LR=0.00034549150281252633
# Validation Loss = 0.249
# Epoch=7, batch = 5000 of 14253, loss=2.841, LR=0.00034549150281252633
# Validation Loss = 0.033
# Epoch=7, batch = 6000 of 14253, loss=2.566, LR=0.00034549150281252633
# Validation Loss = 0.047
# Epoch=7, batch = 7000 of 14253, loss=2.754, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=7, batch = 8000 of 14253, loss=2.544, LR=0.00034549150281252633
# Validation Loss = 0.248
# Epoch=7, batch = 9000 of 14253, loss=2.380, LR=0.00034549150281252633
# Validation Loss = 0.021
# Epoch=7, batch = 10000 of 14253, loss=2.560, LR=0.00034549150281252633
# Validation Loss = 0.000
# Epoch=7, batch = 11000 of 14253, loss=2.513, LR=0.00034549150281252633
# Validation Loss = 0.239
# Epoch=7, batch = 12000 of 14253, loss=2.340, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=7, batch = 13000 of 14253, loss=2.510, LR=0.00034549150281252633
# Validation Loss = 0.066
# Epoch=7, batch = 14000 of 14253, loss=2.547, LR=0.00034549150281252633
# Validation Loss = 0.210
# Epoch=8, batch = 0 of 14253, loss=2.745, LR=0.0002061073738537635
# Validation Loss = 0.045
# Epoch=8, batch = 1000 of 14253, loss=2.274, LR=0.0002061073738537635
# Validation Loss = 0.120
# Epoch=8, batch = 2000 of 14253, loss=2.364, LR=0.0002061073738537635
# Validation Loss = 0.060
# Epoch=8, batch = 3000 of 14253, loss=2.226, LR=0.0002061073738537635
# Validation Loss = 0.030
# Epoch=8, batch = 4000 of 14253, loss=2.430, LR=0.0002061073738537635
# Validation Loss = 0.052
# Epoch=8, batch = 5000 of 14253, loss=2.472, LR=0.0002061073738537635
# Validation Loss = 0.050
# Epoch=8, batch = 6000 of 14253, loss=2.457, LR=0.0002061073738537635
# Validation Loss = 0.056
# Epoch=8, batch = 7000 of 14253, loss=2.727, LR=0.0002061073738537635
# Validation Loss = 0.264
# Epoch=8, batch = 8000 of 14253, loss=2.585, LR=0.0002061073738537635
# Validation Loss = 0.066
# Epoch=8, batch = 9000 of 14253, loss=2.313, LR=0.0002061073738537635
# Validation Loss = 0.009
# Epoch=8, batch = 10000 of 14253, loss=2.827, LR=0.0002061073738537635
# Validation Loss = 0.035
# Epoch=8, batch = 11000 of 14253, loss=2.533, LR=0.0002061073738537635
# Validation Loss = 0.058
# Epoch=8, batch = 12000 of 14253, loss=2.256, LR=0.0002061073738537635
# Validation Loss = 0.071
# Epoch=8, batch = 13000 of 14253, loss=2.283, LR=0.0002061073738537635
# Validation Loss = 0.032
# Epoch=8, batch = 14000 of 14253, loss=2.405, LR=0.0002061073738537635
# Validation Loss = 0.074
# Epoch=9, batch = 0 of 14253, loss=2.755, LR=9.549150281252634e-05
# Validation Loss = 0.004
# Epoch=9, batch = 1000 of 14253, loss=2.633, LR=9.549150281252634e-05
# Validation Loss = 0.000
# Epoch=9, batch = 2000 of 14253, loss=2.427, LR=9.549150281252634e-05
# Validation Loss = 0.031
# Epoch=9, batch = 3000 of 14253, loss=2.247, LR=9.549150281252634e-05
# Validation Loss = 0.011
# Epoch=9, batch = 4000 of 14253, loss=2.570, LR=9.549150281252634e-05
# Validation Loss = 0.000
# Epoch=9, batch = 5000 of 14253, loss=2.612, LR=9.549150281252634e-05
# Validation Loss = 0.004
# Epoch=9, batch = 6000 of 14253, loss=2.173, LR=9.549150281252634e-05
# Validation Loss = 0.003
# Epoch=9, batch = 7000 of 14253, loss=2.483, LR=9.549150281252634e-05
# Validation Loss = 0.058
# Epoch=9, batch = 8000 of 14253, loss=2.281, LR=9.549150281252634e-05
# Validation Loss = 0.028
# Epoch=9, batch = 9000 of 14253, loss=2.075, LR=9.549150281252634e-05
# Validation Loss = 0.102
# Epoch=9, batch = 10000 of 14253, loss=2.521, LR=9.549150281252634e-05
# Validation Loss = 0.130
# Epoch=9, batch = 11000 of 14253, loss=2.040, LR=9.549150281252634e-05
# Validation Loss = 0.075
# Epoch=9, batch = 12000 of 14253, loss=2.696, LR=9.549150281252634e-05
# Validation Loss = 0.011
# Epoch=9, batch = 13000 of 14253, loss=2.270, LR=9.549150281252634e-05
# Validation Loss = 0.190
# Epoch=9, batch = 14000 of 14253, loss=2.235, LR=9.549150281252634e-05
# Validation Loss = 0.064
# Epoch=10, batch = 0 of 14253, loss=2.241, LR=2.4471741852423235e-05
# Validation Loss = 0.017
# Epoch=10, batch = 1000 of 14253, loss=2.345, LR=2.4471741852423235e-05
# Validation Loss = 0.000
# Epoch=10, batch = 2000 of 14253, loss=2.577, LR=2.4471741852423235e-05
# Validation Loss = 0.031
# Epoch=10, batch = 3000 of 14253, loss=2.481, LR=2.4471741852423235e-05
# Validation Loss = 0.002
# Epoch=10, batch = 4000 of 14253, loss=2.857, LR=2.4471741852423235e-05
# Validation Loss = 0.003
# Epoch=10, batch = 5000 of 14253, loss=3.218, LR=2.4471741852423235e-05
# Validation Loss = 0.041
# Epoch=10, batch = 6000 of 14253, loss=2.891, LR=2.4471741852423235e-05
# Validation Loss = 0.031
# Epoch=10, batch = 7000 of 14253, loss=2.260, LR=2.4471741852423235e-05
# Validation Loss = 0.013
# Epoch=10, batch = 8000 of 14253, loss=2.392, LR=2.4471741852423235e-05
# Validation Loss = 0.022
# Epoch=10, batch = 9000 of 14253, loss=2.393, LR=2.4471741852423235e-05
# Validation Loss = 0.035
# Epoch=10, batch = 10000 of 14253, loss=2.371, LR=2.4471741852423235e-05
# Validation Loss = 0.035
# Epoch=10, batch = 11000 of 14253, loss=2.367, LR=2.4471741852423235e-05
# Validation Loss = 0.006
# Epoch=10, batch = 12000 of 14253, loss=2.653, LR=2.4471741852423235e-05
# Validation Loss = 0.001
# Epoch=10, batch = 13000 of 14253, loss=2.401, LR=2.4471741852423235e-05
# Validation Loss = 0.004
# Epoch=10, batch = 14000 of 14253, loss=1.953, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.047
# Epoch=1, batch = 0 of 14253, loss=2.347, LR=0.001
# Validation Loss = 0.161
# Epoch=1, batch = 1000 of 14253, loss=2.882, LR=0.001
# Validation Loss = 0.241
# Epoch=1, batch = 2000 of 14253, loss=2.741, LR=0.001
# Validation Loss = 1.343
# Epoch=1, batch = 3000 of 14253, loss=2.933, LR=0.001
# Validation Loss = 0.314
# Epoch=1, batch = 4000 of 14253, loss=3.446, LR=0.001
# Validation Loss = 0.150
# Epoch=1, batch = 5000 of 14253, loss=2.379, LR=0.001
# Validation Loss = 0.804
# Epoch=1, batch = 6000 of 14253, loss=3.851, LR=0.001
# Validation Loss = 0.648
# Epoch=1, batch = 7000 of 14253, loss=2.417, LR=0.001
# Validation Loss = 0.842
# Epoch=1, batch = 8000 of 14253, loss=3.356, LR=0.001
# Validation Loss = 0.045
# Epoch=1, batch = 9000 of 14253, loss=2.733, LR=0.001
# Validation Loss = 0.860
# Epoch=1, batch = 10000 of 14253, loss=2.719, LR=0.001
# Validation Loss = 0.010
# Epoch=1, batch = 11000 of 14253, loss=2.592, LR=0.001
# Validation Loss = 0.002
# Epoch=1, batch = 12000 of 14253, loss=2.765, LR=0.001
# Validation Loss = 0.611
# Epoch=1, batch = 13000 of 14253, loss=2.917, LR=0.001
# Validation Loss = 0.165
# Epoch=1, batch = 14000 of 14253, loss=2.335, LR=0.001
# Validation Loss = 1.682
# Epoch=2, batch = 0 of 14253, loss=4.118, LR=0.0009938441702975688
# Validation Loss = 0.883
# Epoch=2, batch = 1000 of 14253, loss=3.041, LR=0.0009938441702975688
# Validation Loss = 1.975
# Epoch=2, batch = 2000 of 14253, loss=3.660, LR=0.0009938441702975688
# Validation Loss = 0.346
# Epoch=2, batch = 3000 of 14253, loss=2.998, LR=0.0009938441702975688
# Validation Loss = 0.051
# Epoch=2, batch = 4000 of 14253, loss=2.527, LR=0.0009938441702975688
# Validation Loss = 0.022
# Epoch=2, batch = 5000 of 14253, loss=2.364, LR=0.0009938441702975688
# Validation Loss = 0.414
# Epoch=2, batch = 6000 of 14253, loss=2.614, LR=0.0009938441702975688
# Validation Loss = 0.465
# Epoch=2, batch = 7000 of 14253, loss=3.295, LR=0.0009938441702975688
# Validation Loss = 1.503
# Epoch=2, batch = 8000 of 14253, loss=3.311, LR=0.0009938441702975688
# Validation Loss = 0.123
# Epoch=2, batch = 9000 of 14253, loss=2.395, LR=0.0009938441702975688
# Validation Loss = 0.445
# Epoch=2, batch = 10000 of 14253, loss=2.743, LR=0.0009938441702975688
# Validation Loss = 0.295
# Epoch=2, batch = 11000 of 14253, loss=2.726, LR=0.0009938441702975688
# Validation Loss = 0.218
# Epoch=2, batch = 12000 of 14253, loss=2.246, LR=0.0009938441702975688
# Validation Loss = 0.002
# Epoch=2, batch = 13000 of 14253, loss=2.666, LR=0.0009938441702975688
# Validation Loss = 0.001
# Epoch=2, batch = 14000 of 14253, loss=2.596, LR=0.0009938441702975688
# Validation Loss = 0.067
# Epoch=3, batch = 0 of 14253, loss=3.162, LR=0.0009755282581475768
# Validation Loss = 0.059
# Epoch=3, batch = 1000 of 14253, loss=2.607, LR=0.0009755282581475768
# Validation Loss = 0.136
# Epoch=3, batch = 2000 of 14253, loss=3.108, LR=0.0009755282581475768
# Validation Loss = 0.420
# Epoch=3, batch = 3000 of 14253, loss=3.249, LR=0.0009755282581475768
# Validation Loss = 0.131
# Epoch=3, batch = 4000 of 14253, loss=2.126, LR=0.0009755282581475768
# Validation Loss = 0.041
# Epoch=3, batch = 5000 of 14253, loss=2.405, LR=0.0009755282581475768
# Validation Loss = 0.053
# Epoch=3, batch = 6000 of 14253, loss=2.194, LR=0.0009755282581475768
# Validation Loss = 0.865
# Epoch=3, batch = 7000 of 14253, loss=2.292, LR=0.0009755282581475768
# Validation Loss = 0.081
# Epoch=3, batch = 8000 of 14253, loss=2.669, LR=0.0009755282581475768
# Validation Loss = 0.277
# Epoch=3, batch = 9000 of 14253, loss=2.693, LR=0.0009755282581475768
# Validation Loss = 0.909
# Epoch=3, batch = 10000 of 14253, loss=3.324, LR=0.0009755282581475768
# Validation Loss = 0.959
# Epoch=3, batch = 11000 of 14253, loss=3.323, LR=0.0009755282581475768
# Validation Loss = 0.092
# Epoch=3, batch = 12000 of 14253, loss=3.208, LR=0.0009755282581475768
# Validation Loss = 0.201
# Epoch=3, batch = 13000 of 14253, loss=2.555, LR=0.0009755282581475768
# Validation Loss = 0.991
# Epoch=3, batch = 14000 of 14253, loss=3.534, LR=0.0009755282581475768
# Validation Loss = 0.012
# Epoch=4, batch = 0 of 14253, loss=2.671, LR=0.0009455032620941839
# Validation Loss = 0.117
# Epoch=4, batch = 1000 of 14253, loss=2.094, LR=0.0009455032620941839
# Validation Loss = 0.265
# Epoch=4, batch = 2000 of 14253, loss=2.455, LR=0.0009455032620941839
# Validation Loss = 0.000
# Epoch=4, batch = 3000 of 14253, loss=2.234, LR=0.0009455032620941839
# Validation Loss = 0.073
# Epoch=4, batch = 4000 of 14253, loss=3.112, LR=0.0009455032620941839
# Validation Loss = 0.281
# Epoch=4, batch = 5000 of 14253, loss=3.086, LR=0.0009455032620941839
# Validation Loss = 0.684
# Epoch=4, batch = 6000 of 14253, loss=3.453, LR=0.0009455032620941839
# Validation Loss = 0.575
# Epoch=4, batch = 7000 of 14253, loss=2.878, LR=0.0009455032620941839
# Validation Loss = 0.054
# Epoch=4, batch = 8000 of 14253, loss=2.580, LR=0.0009455032620941839
# Validation Loss = 0.081
# Epoch=4, batch = 9000 of 14253, loss=2.653, LR=0.0009455032620941839
# Validation Loss = 1.339
# Epoch=4, batch = 10000 of 14253, loss=2.941, LR=0.0009455032620941839
# Validation Loss = 0.106
# Epoch=4, batch = 11000 of 14253, loss=2.708, LR=0.0009455032620941839
# Validation Loss = 0.042
# Epoch=4, batch = 12000 of 14253, loss=2.424, LR=0.0009455032620941839
# Validation Loss = 0.763
# Epoch=4, batch = 13000 of 14253, loss=3.402, LR=0.0009455032620941839
# Validation Loss = 0.007
# Epoch=4, batch = 14000 of 14253, loss=2.542, LR=0.0009455032620941839
# Validation Loss = 0.121
# Epoch=5, batch = 0 of 14253, loss=2.584, LR=0.0009045084971874737
# Validation Loss = 0.361
# Epoch=5, batch = 1000 of 14253, loss=3.150, LR=0.0009045084971874737
# Validation Loss = 0.290
# Epoch=5, batch = 2000 of 14253, loss=2.364, LR=0.0009045084971874737
# Validation Loss = 1.651
# Epoch=5, batch = 3000 of 14253, loss=3.061, LR=0.0009045084971874737
# Validation Loss = 0.876
# Epoch=5, batch = 4000 of 14253, loss=3.025, LR=0.0009045084971874737
# Validation Loss = 0.002
# Epoch=5, batch = 5000 of 14253, loss=2.553, LR=0.0009045084971874737
# Validation Loss = 0.000
# Epoch=5, batch = 6000 of 14253, loss=2.434, LR=0.0009045084971874737
# Validation Loss = 0.257
# Epoch=5, batch = 7000 of 14253, loss=3.280, LR=0.0009045084971874737
# Validation Loss = 0.239
# Epoch=5, batch = 8000 of 14253, loss=2.482, LR=0.0009045084971874737
# Validation Loss = 0.082
# Epoch=5, batch = 9000 of 14253, loss=3.499, LR=0.0009045084971874737
# Validation Loss = 0.286
# Epoch=5, batch = 10000 of 14253, loss=3.685, LR=0.0009045084971874737
# Validation Loss = 0.080
# Epoch=5, batch = 11000 of 14253, loss=2.366, LR=0.0009045084971874737
# Validation Loss = 0.004
# Epoch=5, batch = 12000 of 14253, loss=3.050, LR=0.0009045084971874737
# Validation Loss = 0.218
# Epoch=5, batch = 13000 of 14253, loss=3.438, LR=0.0009045084971874737
# Validation Loss = 0.100
# Epoch=5, batch = 14000 of 14253, loss=3.709, LR=0.0009045084971874737
# Validation Loss = 0.055
# Epoch=6, batch = 0 of 14253, loss=2.342, LR=0.0008535533905932737
# Validation Loss = 0.175
# Epoch=6, batch = 1000 of 14253, loss=2.625, LR=0.0008535533905932737
# Validation Loss = 0.058
# Epoch=6, batch = 2000 of 14253, loss=3.047, LR=0.0008535533905932737
# Validation Loss = 0.145
# Epoch=6, batch = 3000 of 14253, loss=2.612, LR=0.0008535533905932737
# Validation Loss = 0.458
# Epoch=6, batch = 4000 of 14253, loss=2.339, LR=0.0008535533905932737
# Validation Loss = 0.275
# Epoch=6, batch = 5000 of 14253, loss=2.711, LR=0.0008535533905932737
# Validation Loss = 0.471
# Epoch=6, batch = 6000 of 14253, loss=2.399, LR=0.0008535533905932737
# Validation Loss = 0.104
# Epoch=6, batch = 7000 of 14253, loss=2.707, LR=0.0008535533905932737
# Validation Loss = 0.016
# Epoch=6, batch = 8000 of 14253, loss=2.291, LR=0.0008535533905932737
# Validation Loss = 0.098
# Epoch=6, batch = 9000 of 14253, loss=2.689, LR=0.0008535533905932737
# Validation Loss = 0.048
# Epoch=6, batch = 10000 of 14253, loss=2.450, LR=0.0008535533905932737
# Validation Loss = 0.729
# Epoch=6, batch = 11000 of 14253, loss=2.780, LR=0.0008535533905932737
# Validation Loss = 0.336
# Epoch=6, batch = 12000 of 14253, loss=3.538, LR=0.0008535533905932737
# Validation Loss = 0.672
# Epoch=6, batch = 13000 of 14253, loss=2.622, LR=0.0008535533905932737
# Validation Loss = 0.642
# Epoch=6, batch = 14000 of 14253, loss=2.517, LR=0.0008535533905932737
# Validation Loss = 0.605
# Epoch=7, batch = 0 of 14253, loss=2.380, LR=0.0007938926261462366
# Validation Loss = 0.628
# Epoch=7, batch = 1000 of 14253, loss=2.963, LR=0.0007938926261462366
# Validation Loss = 0.070
# Epoch=7, batch = 2000 of 14253, loss=2.587, LR=0.0007938926261462366
# Validation Loss = 0.932
# Epoch=7, batch = 3000 of 14253, loss=2.636, LR=0.0007938926261462366
# Validation Loss = 0.657
# Epoch=7, batch = 4000 of 14253, loss=2.452, LR=0.0007938926261462366
# Validation Loss = 0.174
# Epoch=7, batch = 5000 of 14253, loss=3.126, LR=0.0007938926261462366
# Validation Loss = 2.803
# Epoch=7, batch = 6000 of 14253, loss=2.608, LR=0.0007938926261462366
# Validation Loss = 0.010
# Epoch=7, batch = 7000 of 14253, loss=2.311, LR=0.0007938926261462366
# Validation Loss = 0.166
# Epoch=7, batch = 8000 of 14253, loss=2.620, LR=0.0007938926261462366
# Validation Loss = 0.015
# Epoch=7, batch = 9000 of 14253, loss=2.740, LR=0.0007938926261462366
# Validation Loss = 0.167
# Epoch=7, batch = 10000 of 14253, loss=2.820, LR=0.0007938926261462366
# Validation Loss = 1.701
# Epoch=7, batch = 11000 of 14253, loss=2.498, LR=0.0007938926261462366
# Validation Loss = 0.481
# Epoch=7, batch = 12000 of 14253, loss=2.867, LR=0.0007938926261462366
# Validation Loss = 0.013
# Epoch=7, batch = 13000 of 14253, loss=2.714, LR=0.0007938926261462366
# Validation Loss = 0.192
# Epoch=7, batch = 14000 of 14253, loss=2.986, LR=0.0007938926261462366
# Validation Loss = 0.090
# Epoch=8, batch = 0 of 14253, loss=2.160, LR=0.0007269952498697733
# Validation Loss = 0.211
# Epoch=8, batch = 1000 of 14253, loss=2.178, LR=0.0007269952498697733
# Validation Loss = 1.282
# Epoch=8, batch = 2000 of 14253, loss=3.079, LR=0.0007269952498697733
# Validation Loss = 0.783
# Epoch=8, batch = 3000 of 14253, loss=2.561, LR=0.0007269952498697733
# Validation Loss = 0.674
# Epoch=8, batch = 4000 of 14253, loss=2.042, LR=0.0007269952498697733
# Validation Loss = 0.399
# Epoch=8, batch = 5000 of 14253, loss=2.754, LR=0.0007269952498697733
# Validation Loss = 0.002
# Epoch=8, batch = 6000 of 14253, loss=2.885, LR=0.0007269952498697733
# Validation Loss = 0.062
# Epoch=8, batch = 7000 of 14253, loss=2.581, LR=0.0007269952498697733
# Validation Loss = 0.050
# Epoch=8, batch = 8000 of 14253, loss=3.542, LR=0.0007269952498697733
# Validation Loss = 0.417
# Epoch=8, batch = 9000 of 14253, loss=2.305, LR=0.0007269952498697733
# Validation Loss = 0.913
# Epoch=8, batch = 10000 of 14253, loss=2.961, LR=0.0007269952498697733
# Validation Loss = 0.173
# Epoch=8, batch = 11000 of 14253, loss=2.294, LR=0.0007269952498697733
# Validation Loss = 0.033
# Epoch=8, batch = 12000 of 14253, loss=2.183, LR=0.0007269952498697733
# Validation Loss = 0.302
# Epoch=8, batch = 13000 of 14253, loss=2.541, LR=0.0007269952498697733
# Validation Loss = 0.055
# Epoch=8, batch = 14000 of 14253, loss=2.913, LR=0.0007269952498697733
# Validation Loss = 0.009
# Epoch=9, batch = 0 of 14253, loss=2.426, LR=0.0006545084971874737
# Validation Loss = 0.628
# Epoch=9, batch = 1000 of 14253, loss=2.206, LR=0.0006545084971874737
# Validation Loss = 0.432
# Epoch=9, batch = 2000 of 14253, loss=2.546, LR=0.0006545084971874737
# Validation Loss = 0.070
# Epoch=9, batch = 3000 of 14253, loss=2.626, LR=0.0006545084971874737
# Validation Loss = 1.761
# Epoch=9, batch = 4000 of 14253, loss=2.902, LR=0.0006545084971874737
# Validation Loss = 1.118
# Epoch=9, batch = 5000 of 14253, loss=2.844, LR=0.0006545084971874737
# Validation Loss = 0.011
# Epoch=9, batch = 6000 of 14253, loss=2.611, LR=0.0006545084971874737
# Validation Loss = 0.761
# Epoch=9, batch = 7000 of 14253, loss=2.650, LR=0.0006545084971874737
# Validation Loss = 0.017
# Epoch=9, batch = 8000 of 14253, loss=2.130, LR=0.0006545084971874737
# Validation Loss = 0.087
# Epoch=9, batch = 9000 of 14253, loss=2.441, LR=0.0006545084971874737
# Validation Loss = 0.835
# Epoch=9, batch = 10000 of 14253, loss=2.523, LR=0.0006545084971874737
# Validation Loss = 1.449
# Epoch=9, batch = 11000 of 14253, loss=3.056, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=9, batch = 12000 of 14253, loss=2.224, LR=0.0006545084971874737
# Validation Loss = 0.001
# Epoch=9, batch = 13000 of 14253, loss=2.595, LR=0.0006545084971874737
# Validation Loss = 0.058
# Epoch=9, batch = 14000 of 14253, loss=2.326, LR=0.0006545084971874737
# Validation Loss = 0.283
# Epoch=10, batch = 0 of 14253, loss=2.837, LR=0.0005782172325201155
# Validation Loss = 0.002
# Epoch=10, batch = 1000 of 14253, loss=2.434, LR=0.0005782172325201155
# Validation Loss = 0.001
# Epoch=10, batch = 2000 of 14253, loss=2.419, LR=0.0005782172325201155
# Validation Loss = 0.005
# Epoch=10, batch = 3000 of 14253, loss=2.323, LR=0.0005782172325201155
# Validation Loss = 0.001
# Epoch=10, batch = 4000 of 14253, loss=2.279, LR=0.0005782172325201155
# Validation Loss = 0.005
# Epoch=10, batch = 5000 of 14253, loss=2.309, LR=0.0005782172325201155
# Validation Loss = 0.127
# Epoch=10, batch = 6000 of 14253, loss=2.392, LR=0.0005782172325201155
# Validation Loss = 0.092
# Epoch=10, batch = 7000 of 14253, loss=2.552, LR=0.0005782172325201155
# Validation Loss = 0.036
# Epoch=10, batch = 8000 of 14253, loss=2.454, LR=0.0005782172325201155
# Validation Loss = 0.520
# Epoch=10, batch = 9000 of 14253, loss=2.895, LR=0.0005782172325201155
# Validation Loss = 0.093
# Epoch=10, batch = 10000 of 14253, loss=2.195, LR=0.0005782172325201155
# Validation Loss = 0.024
# Epoch=10, batch = 11000 of 14253, loss=2.568, LR=0.0005782172325201155
# Validation Loss = 0.100
# Epoch=10, batch = 12000 of 14253, loss=2.679, LR=0.0005782172325201155
# Validation Loss = 0.231
# Epoch=10, batch = 13000 of 14253, loss=2.657, LR=0.0005782172325201155
# Validation Loss = 0.497
# Epoch=10, batch = 14000 of 14253, loss=2.575, LR=0.0005782172325201155
# Validation Loss = 0.497
# Epoch=11, batch = 0 of 14253, loss=2.362, LR=0.0005
# Validation Loss = 0.362
# Epoch=11, batch = 1000 of 14253, loss=2.842, LR=0.0005
# Validation Loss = 0.007
# Epoch=11, batch = 2000 of 14253, loss=2.678, LR=0.0005
# Validation Loss = 0.127
# Epoch=11, batch = 3000 of 14253, loss=2.233, LR=0.0005
# Validation Loss = 0.076
# Epoch=11, batch = 4000 of 14253, loss=2.434, LR=0.0005
# Validation Loss = 0.485
# Epoch=11, batch = 5000 of 14253, loss=2.334, LR=0.0005
# Validation Loss = 0.002
# Epoch=11, batch = 6000 of 14253, loss=2.470, LR=0.0005
# Validation Loss = 0.001
# Epoch=11, batch = 7000 of 14253, loss=2.534, LR=0.0005
# Validation Loss = 0.130
# Epoch=11, batch = 8000 of 14253, loss=2.651, LR=0.0005
# Validation Loss = 0.533
# Epoch=11, batch = 9000 of 14253, loss=2.052, LR=0.0005
# Validation Loss = 0.083
# Epoch=11, batch = 10000 of 14253, loss=2.317, LR=0.0005
# Validation Loss = 0.095
# Epoch=11, batch = 11000 of 14253, loss=2.474, LR=0.0005
# Validation Loss = 0.218
# Epoch=11, batch = 12000 of 14253, loss=2.635, LR=0.0005
# Validation Loss = 0.123
# Epoch=11, batch = 13000 of 14253, loss=2.464, LR=0.0005
# Validation Loss = 0.023
# Epoch=11, batch = 14000 of 14253, loss=2.289, LR=0.0005
# Validation Loss = 0.097
# Epoch=12, batch = 0 of 14253, loss=2.600, LR=0.0004217827674798847
# Validation Loss = 0.063
# Epoch=12, batch = 1000 of 14253, loss=2.208, LR=0.0004217827674798847
# Validation Loss = 0.030
# Epoch=12, batch = 2000 of 14253, loss=2.947, LR=0.0004217827674798847
# Validation Loss = 0.010
# Epoch=12, batch = 3000 of 14253, loss=2.381, LR=0.0004217827674798847
# Validation Loss = 0.000
# Epoch=12, batch = 4000 of 14253, loss=2.161, LR=0.0004217827674798847
# Validation Loss = 0.239
# Epoch=12, batch = 5000 of 14253, loss=2.730, LR=0.0004217827674798847
# Validation Loss = 0.148
# Epoch=12, batch = 6000 of 14253, loss=2.057, LR=0.0004217827674798847
# Validation Loss = 0.264
# Epoch=12, batch = 7000 of 14253, loss=2.011, LR=0.0004217827674798847
# Validation Loss = 0.259
# Epoch=12, batch = 8000 of 14253, loss=2.539, LR=0.0004217827674798847
# Validation Loss = 0.101
# Epoch=12, batch = 9000 of 14253, loss=2.455, LR=0.0004217827674798847
# Validation Loss = 0.014
# Epoch=12, batch = 10000 of 14253, loss=2.612, LR=0.0004217827674798847
# Validation Loss = 0.101
# Epoch=12, batch = 11000 of 14253, loss=2.367, LR=0.0004217827674798847
# Validation Loss = 0.043
# Epoch=12, batch = 12000 of 14253, loss=2.273, LR=0.0004217827674798847
# Validation Loss = 0.330
# Epoch=12, batch = 13000 of 14253, loss=2.748, LR=0.0004217827674798847
# Validation Loss = 0.008
# Epoch=12, batch = 14000 of 14253, loss=2.307, LR=0.0004217827674798847
# Validation Loss = 0.001
# Epoch=13, batch = 0 of 14253, loss=2.517, LR=0.00034549150281252633
# Validation Loss = 0.183
# Epoch=13, batch = 1000 of 14253, loss=2.196, LR=0.00034549150281252633
# Validation Loss = 0.306
# Epoch=13, batch = 2000 of 14253, loss=2.380, LR=0.00034549150281252633
# Validation Loss = 0.194
# Epoch=13, batch = 3000 of 14253, loss=2.150, LR=0.00034549150281252633
# Validation Loss = 0.004
# Epoch=13, batch = 4000 of 14253, loss=2.609, LR=0.00034549150281252633
# Validation Loss = 0.062
# Epoch=13, batch = 5000 of 14253, loss=2.322, LR=0.00034549150281252633
# Validation Loss = 0.431
# Epoch=13, batch = 6000 of 14253, loss=2.656, LR=0.00034549150281252633
# Validation Loss = 0.106
# Epoch=13, batch = 7000 of 14253, loss=2.606, LR=0.00034549150281252633
# Validation Loss = 0.242
# Epoch=13, batch = 8000 of 14253, loss=4.173, LR=0.00034549150281252633
# Validation Loss = 0.036
# Epoch=13, batch = 9000 of 14253, loss=2.355, LR=0.00034549150281252633
# Validation Loss = 0.082
# Epoch=13, batch = 10000 of 14253, loss=2.119, LR=0.00034549150281252633
# Validation Loss = 0.010
# Epoch=13, batch = 11000 of 14253, loss=2.499, LR=0.00034549150281252633
# Validation Loss = 0.041
# Epoch=13, batch = 12000 of 14253, loss=2.016, LR=0.00034549150281252633
# Validation Loss = 0.160
# Epoch=13, batch = 13000 of 14253, loss=2.271, LR=0.00034549150281252633
# Validation Loss = 0.054
# Epoch=13, batch = 14000 of 14253, loss=2.529, LR=0.00034549150281252633
# Validation Loss = 0.162
# Epoch=14, batch = 0 of 14253, loss=2.644, LR=0.00027300475013022663
# Validation Loss = 0.046
# Epoch=14, batch = 1000 of 14253, loss=2.314, LR=0.00027300475013022663
# Validation Loss = 0.068
# Epoch=14, batch = 2000 of 14253, loss=2.370, LR=0.00027300475013022663
# Validation Loss = 0.083
# Epoch=14, batch = 3000 of 14253, loss=2.317, LR=0.00027300475013022663
# Validation Loss = 0.681
# Epoch=14, batch = 4000 of 14253, loss=2.984, LR=0.00027300475013022663
# Validation Loss = 0.125
# Epoch=14, batch = 5000 of 14253, loss=2.352, LR=0.00027300475013022663
# Validation Loss = 0.199
# Epoch=14, batch = 6000 of 14253, loss=2.489, LR=0.00027300475013022663
# Validation Loss = 0.156
# Epoch=14, batch = 7000 of 14253, loss=2.103, LR=0.00027300475013022663
# Validation Loss = 0.226
# Epoch=14, batch = 8000 of 14253, loss=2.612, LR=0.00027300475013022663
# Validation Loss = 0.268
# Epoch=14, batch = 9000 of 14253, loss=2.797, LR=0.00027300475013022663
# Validation Loss = 0.023
# Epoch=14, batch = 10000 of 14253, loss=2.299, LR=0.00027300475013022663
# Validation Loss = 0.000
# Epoch=14, batch = 11000 of 14253, loss=2.788, LR=0.00027300475013022663
# Validation Loss = 0.090
# Epoch=14, batch = 12000 of 14253, loss=2.267, LR=0.00027300475013022663
# Validation Loss = 0.291
# Epoch=14, batch = 13000 of 14253, loss=2.459, LR=0.00027300475013022663
# Validation Loss = 0.001
# Epoch=14, batch = 14000 of 14253, loss=2.271, LR=0.00027300475013022663
# Validation Loss = 0.045
# Epoch=15, batch = 0 of 14253, loss=2.322, LR=0.00020610737385376348
# Validation Loss = 0.014
# Epoch=15, batch = 1000 of 14253, loss=2.444, LR=0.00020610737385376348
# Validation Loss = 0.045
# Epoch=15, batch = 2000 of 14253, loss=2.462, LR=0.00020610737385376348
# Validation Loss = 0.339
# Epoch=15, batch = 3000 of 14253, loss=2.789, LR=0.00020610737385376348
# Validation Loss = 0.016
# Epoch=15, batch = 4000 of 14253, loss=2.369, LR=0.00020610737385376348
# Validation Loss = 0.000
# Epoch=15, batch = 5000 of 14253, loss=2.187, LR=0.00020610737385376348
# Validation Loss = 0.250
# Epoch=15, batch = 6000 of 14253, loss=2.351, LR=0.00020610737385376348
# Validation Loss = 0.185
# Epoch=15, batch = 7000 of 14253, loss=1.978, LR=0.00020610737385376348
# Validation Loss = 0.252
# Epoch=15, batch = 8000 of 14253, loss=2.421, LR=0.00020610737385376348
# Validation Loss = 0.365
# Epoch=15, batch = 9000 of 14253, loss=2.386, LR=0.00020610737385376348
# Validation Loss = 0.068
# Epoch=15, batch = 10000 of 14253, loss=2.252, LR=0.00020610737385376348
# Validation Loss = 0.410
# Epoch=15, batch = 11000 of 14253, loss=2.375, LR=0.00020610737385376348
# Validation Loss = 0.021
# Epoch=15, batch = 12000 of 14253, loss=2.212, LR=0.00020610737385376348
# Validation Loss = 0.040
# Epoch=15, batch = 13000 of 14253, loss=2.113, LR=0.00020610737385376348
# Validation Loss = 0.089
# Epoch=15, batch = 14000 of 14253, loss=2.319, LR=0.00020610737385376348
# Validation Loss = 0.010
# Epoch=16, batch = 0 of 14253, loss=2.401, LR=0.00014644660940672625
# Validation Loss = 0.116
# Epoch=16, batch = 1000 of 14253, loss=2.035, LR=0.00014644660940672625
# Validation Loss = 0.000
# Epoch=16, batch = 2000 of 14253, loss=2.329, LR=0.00014644660940672625
# Validation Loss = 0.002
# Epoch=16, batch = 3000 of 14253, loss=2.354, LR=0.00014644660940672625
# Validation Loss = 0.029
# Epoch=16, batch = 4000 of 14253, loss=2.549, LR=0.00014644660940672625
# Validation Loss = 0.317
# Epoch=16, batch = 5000 of 14253, loss=2.191, LR=0.00014644660940672625
# Validation Loss = 0.194
# Epoch=16, batch = 6000 of 14253, loss=2.093, LR=0.00014644660940672625
# Validation Loss = 0.013
# Epoch=16, batch = 7000 of 14253, loss=2.453, LR=0.00014644660940672625
# Validation Loss = 0.177
# Epoch=16, batch = 8000 of 14253, loss=2.583, LR=0.00014644660940672625
# Validation Loss = 0.048
# Epoch=16, batch = 9000 of 14253, loss=2.073, LR=0.00014644660940672625
# Validation Loss = 0.330
# Epoch=16, batch = 10000 of 14253, loss=2.244, LR=0.00014644660940672625
# Validation Loss = 0.012
# Epoch=16, batch = 11000 of 14253, loss=2.222, LR=0.00014644660940672625
# Validation Loss = 0.015
# Epoch=16, batch = 12000 of 14253, loss=2.321, LR=0.00014644660940672625
# Validation Loss = 0.277
# Epoch=16, batch = 13000 of 14253, loss=2.074, LR=0.00014644660940672625
# Validation Loss = 0.112
# Epoch=16, batch = 14000 of 14253, loss=2.349, LR=0.00014644660940672625
# Validation Loss = 0.169
# Epoch=17, batch = 0 of 14253, loss=2.178, LR=9.549150281252631e-05
# Validation Loss = 0.028
# Epoch=17, batch = 1000 of 14253, loss=2.430, LR=9.549150281252631e-05
# Validation Loss = 0.001
# Epoch=17, batch = 2000 of 14253, loss=2.281, LR=9.549150281252631e-05
# Validation Loss = 0.161
# Epoch=17, batch = 3000 of 14253, loss=2.752, LR=9.549150281252631e-05
# Validation Loss = 0.476
# Epoch=17, batch = 4000 of 14253, loss=2.183, LR=9.549150281252631e-05
# Validation Loss = 0.132
# Epoch=17, batch = 5000 of 14253, loss=2.414, LR=9.549150281252631e-05
# Validation Loss = 0.479
# Epoch=17, batch = 6000 of 14253, loss=2.515, LR=9.549150281252631e-05
# Validation Loss = 0.175
# Epoch=17, batch = 7000 of 14253, loss=2.583, LR=9.549150281252631e-05
# Validation Loss = 0.058
# Epoch=17, batch = 8000 of 14253, loss=1.997, LR=9.549150281252631e-05
# Validation Loss = 0.004
# Epoch=17, batch = 9000 of 14253, loss=2.463, LR=9.549150281252631e-05
# Validation Loss = 0.002
# Epoch=17, batch = 10000 of 14253, loss=2.219, LR=9.549150281252631e-05
# Validation Loss = 0.035
# Epoch=17, batch = 11000 of 14253, loss=2.139, LR=9.549150281252631e-05
# Validation Loss = 0.336
# Epoch=17, batch = 12000 of 14253, loss=2.395, LR=9.549150281252631e-05
# Validation Loss = 0.174
# Epoch=17, batch = 13000 of 14253, loss=2.228, LR=9.549150281252631e-05
# Validation Loss = 0.475
# Epoch=17, batch = 14000 of 14253, loss=2.638, LR=9.549150281252631e-05
# Validation Loss = 0.188
# Epoch=18, batch = 0 of 14253, loss=2.116, LR=5.4496737905816096e-05
# Validation Loss = 0.141
# Epoch=18, batch = 1000 of 14253, loss=2.432, LR=5.4496737905816096e-05
# Validation Loss = 0.147
# Epoch=18, batch = 2000 of 14253, loss=2.363, LR=5.4496737905816096e-05
# Validation Loss = 0.062
# Epoch=18, batch = 3000 of 14253, loss=2.559, LR=5.4496737905816096e-05
# Validation Loss = 0.159
# Epoch=18, batch = 4000 of 14253, loss=2.209, LR=5.4496737905816096e-05
# Validation Loss = 0.015
# Epoch=18, batch = 5000 of 14253, loss=2.761, LR=5.4496737905816096e-05
# Validation Loss = 0.126
# Epoch=18, batch = 6000 of 14253, loss=2.242, LR=5.4496737905816096e-05
# Validation Loss = 0.071
# Epoch=18, batch = 7000 of 14253, loss=1.955, LR=5.4496737905816096e-05
# Validation Loss = 0.022
# Epoch=18, batch = 8000 of 14253, loss=2.544, LR=5.4496737905816096e-05
# Validation Loss = 0.018
# Epoch=18, batch = 9000 of 14253, loss=2.048, LR=5.4496737905816096e-05
# Validation Loss = 0.179
# Epoch=18, batch = 10000 of 14253, loss=2.062, LR=5.4496737905816096e-05
# Validation Loss = 0.199
# Epoch=18, batch = 11000 of 14253, loss=2.442, LR=5.4496737905816096e-05
# Validation Loss = 0.068
# Epoch=18, batch = 12000 of 14253, loss=2.531, LR=5.4496737905816096e-05
# Validation Loss = 0.074
# Epoch=18, batch = 13000 of 14253, loss=2.328, LR=5.4496737905816096e-05
# Validation Loss = 0.114
# Epoch=18, batch = 14000 of 14253, loss=2.287, LR=5.4496737905816096e-05
# Validation Loss = 0.134
# Epoch=19, batch = 0 of 14253, loss=2.483, LR=2.447174185242323e-05
# Validation Loss = 0.103
# Epoch=19, batch = 1000 of 14253, loss=2.644, LR=2.447174185242323e-05
# Validation Loss = 0.187
# Epoch=19, batch = 2000 of 14253, loss=2.239, LR=2.447174185242323e-05
# Validation Loss = 0.145
# Epoch=19, batch = 3000 of 14253, loss=2.232, LR=2.447174185242323e-05
# Validation Loss = 0.140
# Epoch=19, batch = 4000 of 14253, loss=2.034, LR=2.447174185242323e-05
# Validation Loss = 0.071
# Epoch=19, batch = 5000 of 14253, loss=2.307, LR=2.447174185242323e-05
# Validation Loss = 0.158
# Epoch=19, batch = 6000 of 14253, loss=2.238, LR=2.447174185242323e-05
# Validation Loss = 0.224
# Epoch=19, batch = 7000 of 14253, loss=2.612, LR=2.447174185242323e-05
# Validation Loss = 0.208
# Epoch=19, batch = 8000 of 14253, loss=2.383, LR=2.447174185242323e-05
# Validation Loss = 0.058
# Epoch=19, batch = 9000 of 14253, loss=2.188, LR=2.447174185242323e-05
# Validation Loss = 0.262
# Epoch=19, batch = 10000 of 14253, loss=2.517, LR=2.447174185242323e-05
# Validation Loss = 0.091
# Epoch=19, batch = 11000 of 14253, loss=2.364, LR=2.447174185242323e-05
# Validation Loss = 0.133
# Epoch=19, batch = 12000 of 14253, loss=2.443, LR=2.447174185242323e-05
# Validation Loss = 0.226
# Epoch=19, batch = 13000 of 14253, loss=2.508, LR=2.447174185242323e-05
# Validation Loss = 0.215
# Epoch=19, batch = 14000 of 14253, loss=2.515, LR=2.447174185242323e-05
# Validation Loss = 0.126
# Epoch=20, batch = 0 of 14253, loss=2.531, LR=6.15582970243117e-06
# Validation Loss = 0.149
# Epoch=20, batch = 1000 of 14253, loss=2.451, LR=6.15582970243117e-06
# Validation Loss = 0.163
# Epoch=20, batch = 2000 of 14253, loss=2.351, LR=6.15582970243117e-06
# Validation Loss = 0.090
# Epoch=20, batch = 3000 of 14253, loss=2.204, LR=6.15582970243117e-06
# Validation Loss = 0.118
# Epoch=20, batch = 4000 of 14253, loss=2.307, LR=6.15582970243117e-06
# Validation Loss = 0.139
# Epoch=20, batch = 5000 of 14253, loss=2.439, LR=6.15582970243117e-06
# Validation Loss = 0.089
# Epoch=20, batch = 6000 of 14253, loss=2.686, LR=6.15582970243117e-06
# Validation Loss = 0.097
# Epoch=20, batch = 7000 of 14253, loss=2.376, LR=6.15582970243117e-06
# Validation Loss = 0.122
# Epoch=20, batch = 8000 of 14253, loss=2.202, LR=6.15582970243117e-06
# Validation Loss = 0.139
# Epoch=20, batch = 9000 of 14253, loss=2.269, LR=6.15582970243117e-06
# Validation Loss = 0.114
# Epoch=20, batch = 10000 of 14253, loss=2.107, LR=6.15582970243117e-06
# Validation Loss = 0.171
# Epoch=20, batch = 11000 of 14253, loss=2.109, LR=6.15582970243117e-06
# Validation Loss = 0.170
# Epoch=20, batch = 12000 of 14253, loss=2.041, LR=6.15582970243117e-06
# Validation Loss = 0.095
# Epoch=20, batch = 13000 of 14253, loss=2.390, LR=6.15582970243117e-06
# ...
# Validation Loss = 0.475
# Epoch=4, batch = 9000 of 14253, loss=1.471, LR=0.0007938926261462366
# Validation Loss = 4.076
# Epoch=4, batch = 10000 of 14253, loss=1.822, LR=0.0007938926261462366
# Validation Loss = 3.974
# Epoch=4, batch = 11000 of 14253, loss=2.087, LR=0.0007938926261462366
# Validation Loss = 0.985
# Epoch=4, batch = 12000 of 14253, loss=1.492, LR=0.0007938926261462366
# Validation Loss = 0.780
# Epoch=4, batch = 13000 of 14253, loss=1.523, LR=0.0007938926261462366
# Validation Loss = 2.609
# Epoch=4, batch = 14000 of 14253, loss=1.418, LR=0.0007938926261462366
# Validation Loss = 1.763
# Epoch=5, batch = 0 of 14253, loss=1.321, LR=0.0006545084971874737
# Validation Loss = 0.130
# Epoch=5, batch = 1000 of 14253, loss=1.713, LR=0.0006545084971874737
# Validation Loss = 1.285
# Epoch=5, batch = 2000 of 14253, loss=1.668, LR=0.0006545084971874737
# Validation Loss = 1.109
# Epoch=5, batch = 3000 of 14253, loss=1.325, LR=0.0006545084971874737
# Validation Loss = 1.809
# Epoch=5, batch = 4000 of 14253, loss=1.202, LR=0.0006545084971874737
# Validation Loss = 1.805
# Epoch=5, batch = 5000 of 14253, loss=1.393, LR=0.0006545084971874737
# Validation Loss = 4.217
# Epoch=5, batch = 6000 of 14253, loss=1.255, LR=0.0006545084971874737
# Validation Loss = 1.116
# Epoch=5, batch = 7000 of 14253, loss=1.439, LR=0.0006545084971874737
# Validation Loss = 1.818
# Epoch=5, batch = 8000 of 14253, loss=1.420, LR=0.0006545084971874737
# Validation Loss = 1.284
# Epoch=5, batch = 9000 of 14253, loss=1.318, LR=0.0006545084971874737
# Validation Loss = 1.397
# Epoch=5, batch = 10000 of 14253, loss=1.449, LR=0.0006545084971874737
# Validation Loss = 5.526
# Epoch=5, batch = 11000 of 14253, loss=1.637, LR=0.0006545084971874737
# Validation Loss = 5.235
# Epoch=5, batch = 12000 of 14253, loss=1.839, LR=0.0006545084971874737
# Validation Loss = 1.136
# Epoch=5, batch = 13000 of 14253, loss=1.233, LR=0.0006545084971874737
# Validation Loss = 1.298
# Epoch=5, batch = 14000 of 14253, loss=1.290, LR=0.0006545084971874737
# Validation Loss = 0.159
# Epoch=6, batch = 0 of 14253, loss=1.876, LR=0.0005
# Validation Loss = 2.162
# Epoch=6, batch = 1000 of 14253, loss=1.334, LR=0.0005
# Validation Loss = 1.720
# Epoch=6, batch = 2000 of 14253, loss=1.210, LR=0.0005
# Validation Loss = 3.820
# Epoch=6, batch = 3000 of 14253, loss=1.480, LR=0.0005
# Validation Loss = 2.458
# Epoch=6, batch = 4000 of 14253, loss=1.263, LR=0.0005
# Validation Loss = 0.370
# Epoch=6, batch = 5000 of 14253, loss=1.525, LR=0.0005
# Validation Loss = 0.628
# Epoch=6, batch = 6000 of 14253, loss=1.336, LR=0.0005
# Validation Loss = 0.782
# Epoch=6, batch = 7000 of 14253, loss=1.444, LR=0.0005
# Validation Loss = 3.671
# Epoch=6, batch = 8000 of 14253, loss=1.529, LR=0.0005
# Validation Loss = 1.732
# Epoch=6, batch = 9000 of 14253, loss=1.394, LR=0.0005
# Validation Loss = 2.520
# Epoch=6, batch = 10000 of 14253, loss=1.237, LR=0.0005
# Validation Loss = 1.258
# Epoch=6, batch = 11000 of 14253, loss=1.378, LR=0.0005
# Validation Loss = 1.277
# Epoch=6, batch = 12000 of 14253, loss=1.240, LR=0.0005
# Validation Loss = 3.350
# Epoch=6, batch = 13000 of 14253, loss=1.657, LR=0.0005
# Validation Loss = 1.877
# Epoch=6, batch = 14000 of 14253, loss=1.344, LR=0.0005
# Validation Loss = 2.719
# Epoch=7, batch = 0 of 14253, loss=1.316, LR=0.00034549150281252633
# Validation Loss = 0.816
# Epoch=7, batch = 1000 of 14253, loss=1.416, LR=0.00034549150281252633
# Validation Loss = 2.173
# Epoch=7, batch = 2000 of 14253, loss=1.528, LR=0.00034549150281252633
# Validation Loss = 1.553
# Epoch=7, batch = 3000 of 14253, loss=1.297, LR=0.00034549150281252633
# Validation Loss = 1.702
# Epoch=7, batch = 4000 of 14253, loss=1.394, LR=0.00034549150281252633
# Validation Loss = 2.178
# Epoch=7, batch = 5000 of 14253, loss=1.520, LR=0.00034549150281252633
# Validation Loss = 3.244
# Epoch=7, batch = 6000 of 14253, loss=1.647, LR=0.00034549150281252633
# Validation Loss = 1.638
# Epoch=7, batch = 7000 of 14253, loss=1.196, LR=0.00034549150281252633
# Validation Loss = 0.461
# Epoch=7, batch = 8000 of 14253, loss=1.782, LR=0.00034549150281252633
# Validation Loss = 3.656
# Epoch=7, batch = 9000 of 14253, loss=1.241, LR=0.00034549150281252633
# Validation Loss = 1.858
# Epoch=7, batch = 10000 of 14253, loss=1.268, LR=0.00034549150281252633
# Validation Loss = 1.687
# Epoch=7, batch = 11000 of 14253, loss=1.210, LR=0.00034549150281252633
# Validation Loss = 0.123
# Epoch=7, batch = 12000 of 14253, loss=1.636, LR=0.00034549150281252633
# Validation Loss = 0.511
# Epoch=7, batch = 13000 of 14253, loss=1.170, LR=0.00034549150281252633
# Validation Loss = 1.535
# Epoch=7, batch = 14000 of 14253, loss=1.381, LR=0.00034549150281252633
# Validation Loss = 1.820
# Epoch=8, batch = 0 of 14253, loss=1.364, LR=0.0002061073738537635
# Validation Loss = 1.464
# Epoch=8, batch = 1000 of 14253, loss=1.426, LR=0.0002061073738537635
# Validation Loss = 2.068
# Epoch=8, batch = 2000 of 14253, loss=1.271, LR=0.0002061073738537635
# Validation Loss = 1.204
# Epoch=8, batch = 3000 of 14253, loss=1.331, LR=0.0002061073738537635
# Validation Loss = 1.322
# Epoch=8, batch = 4000 of 14253, loss=1.091, LR=0.0002061073738537635
# Validation Loss = 2.435
# Epoch=8, batch = 5000 of 14253, loss=1.245, LR=0.0002061073738537635
# Validation Loss = 1.375
# Epoch=8, batch = 6000 of 14253, loss=1.402, LR=0.0002061073738537635
# Validation Loss = 2.501
# Epoch=8, batch = 7000 of 14253, loss=1.272, LR=0.0002061073738537635
# Validation Loss = 1.931
# Epoch=8, batch = 8000 of 14253, loss=1.245, LR=0.0002061073738537635
# Validation Loss = 1.959
# Epoch=8, batch = 9000 of 14253, loss=1.209, LR=0.0002061073738537635
# Validation Loss = 1.266
# Epoch=8, batch = 10000 of 14253, loss=1.289, LR=0.0002061073738537635
# Validation Loss = 2.071
# Epoch=8, batch = 11000 of 14253, loss=1.348, LR=0.0002061073738537635
# Validation Loss = 1.657
# Epoch=8, batch = 12000 of 14253, loss=1.139, LR=0.0002061073738537635
# Validation Loss = 0.949
# Epoch=8, batch = 13000 of 14253, loss=1.327, LR=0.0002061073738537635
# Validation Loss = 1.813
# Epoch=8, batch = 14000 of 14253, loss=1.234, LR=0.0002061073738537635
# Validation Loss = 1.676
# Epoch=9, batch = 0 of 14253, loss=1.353, LR=9.549150281252634e-05
# Validation Loss = 2.429
# Epoch=9, batch = 1000 of 14253, loss=1.256, LR=9.549150281252634e-05
# Validation Loss = 1.031
# Epoch=9, batch = 2000 of 14253, loss=1.296, LR=9.549150281252634e-05
# Validation Loss = 1.342
# Epoch=9, batch = 3000 of 14253, loss=1.320, LR=9.549150281252634e-05
# Validation Loss = 1.144
# Epoch=9, batch = 4000 of 14253, loss=1.199, LR=9.549150281252634e-05
# Validation Loss = 1.858
# Epoch=9, batch = 5000 of 14253, loss=1.274, LR=9.549150281252634e-05
# Validation Loss = 2.565
# Epoch=9, batch = 6000 of 14253, loss=1.265, LR=9.549150281252634e-05
# Validation Loss = 0.949
# Epoch=9, batch = 7000 of 14253, loss=1.262, LR=9.549150281252634e-05
# Validation Loss = 1.261
# Epoch=9, batch = 8000 of 14253, loss=1.331, LR=9.549150281252634e-05
# Validation Loss = 1.903
# Epoch=9, batch = 9000 of 14253, loss=1.619, LR=9.549150281252634e-05
# Validation Loss = 1.126
# Epoch=9, batch = 10000 of 14253, loss=1.423, LR=9.549150281252634e-05
# Validation Loss = 2.230
# Epoch=9, batch = 11000 of 14253, loss=1.353, LR=9.549150281252634e-05
# Validation Loss = 1.143
# Epoch=9, batch = 12000 of 14253, loss=1.273, LR=9.549150281252634e-05
# Validation Loss = 1.060
# Epoch=9, batch = 13000 of 14253, loss=1.300, LR=9.549150281252634e-05
# Validation Loss = 1.850
# Epoch=9, batch = 14000 of 14253, loss=1.421, LR=9.549150281252634e-05
# Validation Loss = 1.949
# Epoch=10, batch = 0 of 14253, loss=1.307, LR=2.4471741852423235e-05
# Validation Loss = 1.474
# Epoch=10, batch = 1000 of 14253, loss=1.209, LR=2.4471741852423235e-05
# Validation Loss = 1.141
# Epoch=10, batch = 2000 of 14253, loss=1.278, LR=2.4471741852423235e-05
# Validation Loss = 1.153
# Epoch=10, batch = 3000 of 14253, loss=1.239, LR=2.4471741852423235e-05
# Validation Loss = 1.319
# Epoch=10, batch = 4000 of 14253, loss=1.267, LR=2.4471741852423235e-05
# Validation Loss = 1.406
# Epoch=10, batch = 5000 of 14253, loss=1.282, LR=2.4471741852423235e-05
# Validation Loss = 1.504
# Epoch=10, batch = 6000 of 14253, loss=1.175, LR=2.4471741852423235e-05
# Validation Loss = 1.530
# Epoch=10, batch = 7000 of 14253, loss=1.376, LR=2.4471741852423235e-05
# Validation Loss = 1.772
# Epoch=10, batch = 8000 of 14253, loss=1.218, LR=2.4471741852423235e-05
# Validation Loss = 1.779
# Epoch=10, batch = 9000 of 14253, loss=1.154, LR=2.4471741852423235e-05
# Validation Loss = 1.253
# Epoch=10, batch = 10000 of 14253, loss=1.224, LR=2.4471741852423235e-05
# Validation Loss = 0.898
# Epoch=10, batch = 11000 of 14253, loss=1.303, LR=2.4471741852423235e-05
# Validation Loss = 1.748
# Epoch=10, batch = 12000 of 14253, loss=1.256, LR=2.4471741852423235e-05
# Validation Loss = 1.792
# Epoch=10, batch = 13000 of 14253, loss=1.203, LR=2.4471741852423235e-05
# Validation Loss = 2.308
# Epoch=10, batch = 14000 of 14253, loss=1.288, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 1.984
# Epoch=1, batch = 0 of 14253, loss=1.205, LR=0.001
# Validation Loss = 6.718
# Epoch=1, batch = 1000 of 14253, loss=1.376, LR=0.001
# Validation Loss = 0.481
# Epoch=1, batch = 2000 of 14253, loss=1.619, LR=0.001
# Validation Loss = 0.815
# Epoch=1, batch = 3000 of 14253, loss=1.670, LR=0.001
# Validation Loss = 3.575
# Epoch=1, batch = 4000 of 14253, loss=1.638, LR=0.001
# Validation Loss = 3.177
# Epoch=1, batch = 5000 of 14253, loss=1.482, LR=0.001
# Validation Loss = 1.213
# Epoch=1, batch = 6000 of 14253, loss=1.325, LR=0.001
# Validation Loss = 1.645
# Epoch=1, batch = 7000 of 14253, loss=1.132, LR=0.001
# Validation Loss = 0.730
# Epoch=1, batch = 8000 of 14253, loss=1.541, LR=0.001
# Validation Loss = 0.321
# Epoch=1, batch = 9000 of 14253, loss=1.963, LR=0.001
# Validation Loss = 1.249
# Epoch=1, batch = 10000 of 14253, loss=1.533, LR=0.001
# Validation Loss = 1.517
# Epoch=1, batch = 11000 of 14253, loss=1.415, LR=0.001
# Validation Loss = 6.254
# Epoch=1, batch = 12000 of 14253, loss=1.568, LR=0.001
# Validation Loss = 0.395
# Epoch=1, batch = 13000 of 14253, loss=1.264, LR=0.001
# Validation Loss = 1.124
# Epoch=1, batch = 14000 of 14253, loss=1.258, LR=0.001
# Validation Loss = 2.652
# Epoch=2, batch = 0 of 14253, loss=1.679, LR=0.0009938441702975688
# Validation Loss = 3.628
# Epoch=2, batch = 1000 of 14253, loss=1.799, LR=0.0009938441702975688
# Validation Loss = 0.084
# Epoch=2, batch = 2000 of 14253, loss=2.075, LR=0.0009938441702975688
# Validation Loss = 0.256
# Epoch=2, batch = 3000 of 14253, loss=3.255, LR=0.0009938441702975688
# Validation Loss = 2.128
# Epoch=2, batch = 4000 of 14253, loss=1.388, LR=0.0009938441702975688
# Validation Loss = 0.728
# Epoch=2, batch = 5000 of 14253, loss=1.669, LR=0.0009938441702975688
# Validation Loss = 3.652
# Epoch=2, batch = 6000 of 14253, loss=1.749, LR=0.0009938441702975688
# Validation Loss = 0.393
# Epoch=2, batch = 7000 of 14253, loss=1.508, LR=0.0009938441702975688
# Validation Loss = 0.796
# Epoch=2, batch = 8000 of 14253, loss=1.338, LR=0.0009938441702975688
# Validation Loss = 0.059
# Epoch=2, batch = 9000 of 14253, loss=1.618, LR=0.0009938441702975688
# Validation Loss = 1.012
# Epoch=2, batch = 10000 of 14253, loss=1.170, LR=0.0009938441702975688
# Validation Loss = 0.452
# Epoch=2, batch = 11000 of 14253, loss=1.278, LR=0.0009938441702975688
# Validation Loss = 1.263
# Epoch=2, batch = 12000 of 14253, loss=1.349, LR=0.0009938441702975688
# Validation Loss = 4.501
# Epoch=2, batch = 13000 of 14253, loss=1.456, LR=0.0009938441702975688
# Validation Loss = 0.774
# Epoch=2, batch = 14000 of 14253, loss=1.354, LR=0.0009938441702975688
# Validation Loss = 2.443
# Epoch=3, batch = 0 of 14253, loss=1.324, LR=0.0009755282581475768
# Validation Loss = 0.396
# Epoch=3, batch = 1000 of 14253, loss=3.207, LR=0.0009755282581475768
# Validation Loss = 0.017
# Epoch=3, batch = 2000 of 14253, loss=2.423, LR=0.0009755282581475768
# Validation Loss = 1.793
# Epoch=3, batch = 3000 of 14253, loss=1.370, LR=0.0009755282581475768
# Validation Loss = 3.648
# Epoch=3, batch = 4000 of 14253, loss=1.342, LR=0.0009755282581475768
# Validation Loss = 1.636
# Epoch=3, batch = 5000 of 14253, loss=1.720, LR=0.0009755282581475768
# Validation Loss = 3.563
# Epoch=3, batch = 6000 of 14253, loss=1.432, LR=0.0009755282581475768
# Validation Loss = 1.259
# Epoch=3, batch = 7000 of 14253, loss=1.268, LR=0.0009755282581475768
# Validation Loss = 0.925
# Epoch=3, batch = 8000 of 14253, loss=1.327, LR=0.0009755282581475768
# Validation Loss = 1.757
# Epoch=3, batch = 9000 of 14253, loss=1.470, LR=0.0009755282581475768
# Validation Loss = 0.350
# Epoch=3, batch = 10000 of 14253, loss=1.458, LR=0.0009755282581475768
# Validation Loss = 0.446
# Epoch=3, batch = 11000 of 14253, loss=1.732, LR=0.0009755282581475768
# Validation Loss = 1.776
# Epoch=3, batch = 12000 of 14253, loss=1.512, LR=0.0009755282581475768
# Validation Loss = 0.577
# Epoch=3, batch = 13000 of 14253, loss=1.529, LR=0.0009755282581475768
# Validation Loss = 1.534
# Epoch=3, batch = 14000 of 14253, loss=1.352, LR=0.0009755282581475768
# Validation Loss = 5.113
# Epoch=4, batch = 0 of 14253, loss=1.836, LR=0.0009455032620941839
# Validation Loss = 1.786
# Epoch=4, batch = 1000 of 14253, loss=1.802, LR=0.0009455032620941839
# Validation Loss = 0.034
# Epoch=4, batch = 2000 of 14253, loss=2.021, LR=0.0009455032620941839
# Validation Loss = 3.641
# Epoch=4, batch = 3000 of 14253, loss=1.573, LR=0.0009455032620941839
# Validation Loss = 4.044
# Epoch=4, batch = 4000 of 14253, loss=1.230, LR=0.0009455032620941839
# Validation Loss = 0.780
# Epoch=4, batch = 5000 of 14253, loss=1.749, LR=0.0009455032620941839
# Validation Loss = 1.474
# Epoch=4, batch = 6000 of 14253, loss=1.391, LR=0.0009455032620941839
# Validation Loss = 2.744
# Epoch=4, batch = 7000 of 14253, loss=1.423, LR=0.0009455032620941839
# Validation Loss = 1.443
# Epoch=4, batch = 8000 of 14253, loss=1.747, LR=0.0009455032620941839
# Validation Loss = 0.796
# Epoch=4, batch = 9000 of 14253, loss=1.252, LR=0.0009455032620941839
# Validation Loss = 2.142
# Epoch=4, batch = 10000 of 14253, loss=1.599, LR=0.0009455032620941839
# Validation Loss = 1.018
# Epoch=4, batch = 11000 of 14253, loss=1.623, LR=0.0009455032620941839
# Validation Loss = 1.002
# Epoch=4, batch = 12000 of 14253, loss=1.270, LR=0.0009455032620941839
# Validation Loss = 3.093
# Epoch=4, batch = 13000 of 14253, loss=1.485, LR=0.0009455032620941839
# Validation Loss = 2.435
# Epoch=4, batch = 14000 of 14253, loss=1.560, LR=0.0009455032620941839
# Validation Loss = 1.555
# Epoch=5, batch = 0 of 14253, loss=2.517, LR=0.0009045084971874737
# Validation Loss = 9.594
# Epoch=5, batch = 1000 of 14253, loss=2.670, LR=0.0009045084971874737
# Validation Loss = 1.681
# Epoch=5, batch = 2000 of 14253, loss=1.379, LR=0.0009045084971874737
# Validation Loss = 1.292
# Epoch=5, batch = 3000 of 14253, loss=1.247, LR=0.0009045084971874737
# Validation Loss = 2.416
# Epoch=5, batch = 4000 of 14253, loss=1.307, LR=0.0009045084971874737
# Validation Loss = 3.839
# Epoch=5, batch = 5000 of 14253, loss=1.403, LR=0.0009045084971874737
# Validation Loss = 0.693
# Epoch=5, batch = 6000 of 14253, loss=1.758, LR=0.0009045084971874737
# Validation Loss = 1.821
# Epoch=5, batch = 7000 of 14253, loss=1.655, LR=0.0009045084971874737
# Validation Loss = 1.137
# Epoch=5, batch = 8000 of 14253, loss=1.387, LR=0.0009045084971874737
# Validation Loss = 2.047
# Epoch=5, batch = 9000 of 14253, loss=1.339, LR=0.0009045084971874737
# Validation Loss = 1.790
# Epoch=5, batch = 10000 of 14253, loss=1.533, LR=0.0009045084971874737
# Validation Loss = 1.466
# Epoch=5, batch = 11000 of 14253, loss=1.496, LR=0.0009045084971874737
# Validation Loss = 1.077
# Epoch=5, batch = 12000 of 14253, loss=1.212, LR=0.0009045084971874737
# Validation Loss = 0.004
# Epoch=5, batch = 13000 of 14253, loss=1.426, LR=0.0009045084971874737
# Validation Loss = 2.584
# Epoch=5, batch = 14000 of 14253, loss=1.440, LR=0.0009045084971874737
# Validation Loss = 1.687
# Epoch=6, batch = 0 of 14253, loss=1.277, LR=0.0008535533905932737
# Validation Loss = 3.798
# Epoch=6, batch = 1000 of 14253, loss=1.510, LR=0.0008535533905932737
# Validation Loss = 2.339
# Epoch=6, batch = 2000 of 14253, loss=1.343, LR=0.0008535533905932737
# Validation Loss = 1.615
# Epoch=6, batch = 3000 of 14253, loss=1.287, LR=0.0008535533905932737
# Validation Loss = 2.270
# Epoch=6, batch = 4000 of 14253, loss=1.341, LR=0.0008535533905932737
