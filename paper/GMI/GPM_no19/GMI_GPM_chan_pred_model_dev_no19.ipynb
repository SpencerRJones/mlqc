# %% [markdown]
# # Channel Prediction Model for Quality Control
#
# This notebook contains the code and outlines the development of the
# GMI Channel Prediction Neural Network for QC purposes of GMI L1C
# data. The simple Feed-Forward Neural Networks (FFNNs) are trained on
# good quality brightness temperature observation vectors and are
# trained to predict one channel from all the others as predictors.
#
# The end product is a tree of FFNNs, discretized by surface (ocean or
# land), and by channel, since these are fully distinct problems.

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import glob
import torch
from torch import nn
import cartopy.crs as ccrs
from util_funcs.L1C import scantime2datetime
from util_funcs import data2xarray, array_funcs
import geography
from tqdm import tqdm

from dataset_class import dataset
from model_class import channel_predictor
import local_functions
import sensor_info


#General parameters:

satellite = sensor_info.satellite
sensor = sensor_info.sensor

nchans = sensor_info.nchannels
batch_size = 1000
input_size = nchans - 1
hidden_size = 256
output_size = 1

# %%
'''
Function Definitions:
'''

chan_desc = sensor_info.channel_descriptions


def extract_channel(Tb_array, chan):

    '''
    Use in preparing training data.

    Assumes Tb array is [m x n] where m (rows) are samples
    and n (columns) is the number of channels.

    Passing in the channel description splits the data so
    that the specified channel is its own vector y and the
    rest are kept as predictors x.

    Inputs:
        Tb_array    |  ndarray of Tbs
        chan        |  string of channel name
    Outputs:
        x           |  matrix of predictors (other channels)
        y           |  vector of predictands (the missing channel)
        
    '''
    
    chan_desc = np.array(sensor_info.channel_descriptions)


    chan_indx = np.where(chan == chan_desc)[0]

    if np.size(chan_indx) == 0:
        raise ValueError(f'Channel description must be in list {chan_desc}.')

    y = Tb_array[:,chan_indx]
    x = Tb_array[:,np.delete(np.arange(0,len(chan_desc)),chan_indx)]

    return x, y


def train_model(model, nepochs, dataloader, learning_rate=0.001, quiet=False, stage=None, validation_dataloader=None):

    nbatches = len(dataloader)
    
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=nepochs)
    device = None

    if stage:
        print(f'Training stage: {stage}')

    loss_arr    = np.zeros([nbatches,nepochs], dtype='f')
    valloss_arr = np.zeros([nbatches,nepochs], dtype='f')
    
    for epoch in range(nepochs):
        for i, (profs, obs) in enumerate(dataloader):
            if device:
                profs, obs = profs.to(device), obs.to(device)

            if validation_dataloader and i%1000==0:
                valprofs, valobs = next(enumerate(validation_dataloader))[1]
                val_pred = model(valprofs)
                valloss  = criterion(val_pred, valobs)
                print(f'Validation Loss = {valloss.item():.3f}')

            #Forward pass:
            obs_pred = model(profs)
            loss     = criterion(obs_pred, obs)


            #Backward pass:
            optimizer.zero_grad()
            loss.backward()

            #Update neurons:
            optimizer.step()

            loss_arr[i,epoch] = loss.item()
            valloss_arr[i,epoch] = valloss.item()
            
            if not quiet:
                if i%1000 == 0:
                    print(f'Epoch={epoch+1}, batch = {i} of {nbatches}, loss={loss.item():.3f}, LR={scheduler.get_last_lr()[0]}')
        
        scheduler.step()




    return loss_arr, valloss_arr

# %%
chan_desc
# Out:
# ['10V',
#  '10H',
#  '24V',
#  '37V',
#  '37H',
#  '89V',
#  '89H',
#  '166V',
#  '166H',
#  '183+-3V',
#  '183+-7V']

# %%
'''

GMI CHANNEL PREDICTION MODEL:
    1: Ocean

'''

sfc = [1]

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = np.isin(sfctype, sfc)
    sfcindcs = np.where(correct_sfc)[0]

    Tbs = f.Tbs.values[sfcindcs]

#---Don't shuffle data before splitting
#np.random.seed(40)
#Tbs = array_funcs.shuffle_data(Tbs, axis=0)

if Tbs.shape[0] > 5.0e+06:
    Tbs = Tbs[:5_000_000,:]

Tbs = Tbs[:,[0,1,4,5,6,7,8,9,10,11,12]]

print(Tbs.shape)

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train = array_funcs.shuffle_data(Tbs_train, axis=0)
# Out:
# (5000000, 11)

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    print(channel)
    
    x_train = Tbs_train
    y_train = extract_channel(Tbs_train, channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_ocean_no19.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_ocean_no19.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 10V
# Training stage: 1
# Validation Loss = 23307.547
# Epoch=1, batch = 0 of 4000, loss=22841.721, LR=0.001
# Validation Loss = 1.225
# Epoch=1, batch = 1000 of 4000, loss=1.682, LR=0.001
# Validation Loss = 0.003
# Epoch=1, batch = 2000 of 4000, loss=1.673, LR=0.001
# Validation Loss = 0.019
# Epoch=1, batch = 3000 of 4000, loss=1.414, LR=0.001
# Validation Loss = 4.311
# Epoch=2, batch = 0 of 4000, loss=2.568, LR=0.0009045084971874737
# Validation Loss = 0.000
# Epoch=2, batch = 1000 of 4000, loss=1.517, LR=0.0009045084971874737
# Validation Loss = 0.020
# Epoch=2, batch = 2000 of 4000, loss=1.555, LR=0.0009045084971874737
# Validation Loss = 6.095
# Epoch=2, batch = 3000 of 4000, loss=3.903, LR=0.0009045084971874737
# Validation Loss = 0.441
# Epoch=3, batch = 0 of 4000, loss=0.918, LR=0.0006545084971874737
# Validation Loss = 4.086
# Epoch=3, batch = 1000 of 4000, loss=2.551, LR=0.0006545084971874737
# Validation Loss = 0.417
# Epoch=3, batch = 2000 of 4000, loss=3.004, LR=0.0006545084971874737
# Validation Loss = 1.544
# Epoch=3, batch = 3000 of 4000, loss=1.238, LR=0.0006545084971874737
# Validation Loss = 0.772
# Epoch=4, batch = 0 of 4000, loss=0.842, LR=0.00034549150281252633
# Validation Loss = 0.171
# Epoch=4, batch = 1000 of 4000, loss=1.178, LR=0.00034549150281252633
# Validation Loss = 1.770
# Epoch=4, batch = 2000 of 4000, loss=1.118, LR=0.00034549150281252633
# Validation Loss = 0.756
# Epoch=4, batch = 3000 of 4000, loss=1.033, LR=0.00034549150281252633
# Validation Loss = 0.890
# Epoch=5, batch = 0 of 4000, loss=0.912, LR=9.549150281252633e-05
# Validation Loss = 0.647
# Epoch=5, batch = 1000 of 4000, loss=0.926, LR=9.549150281252633e-05
# Validation Loss = 0.467
# Epoch=5, batch = 2000 of 4000, loss=0.840, LR=9.549150281252633e-05
# Validation Loss = 0.483
# Epoch=5, batch = 3000 of 4000, loss=0.909, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.320
# Epoch=1, batch = 0 of 4000, loss=0.895, LR=0.001
# Validation Loss = 0.306
# Epoch=1, batch = 1000 of 4000, loss=0.950, LR=0.001
# Validation Loss = 0.751
# Epoch=1, batch = 2000 of 4000, loss=1.030, LR=0.001
# Validation Loss = 0.848
# Epoch=1, batch = 3000 of 4000, loss=1.032, LR=0.001
# Validation Loss = 0.890
# Epoch=2, batch = 0 of 4000, loss=1.057, LR=0.0009755282581475768
# Validation Loss = 0.323
# Epoch=2, batch = 1000 of 4000, loss=2.561, LR=0.0009755282581475768
# Validation Loss = 1.667
# Epoch=2, batch = 2000 of 4000, loss=1.287, LR=0.0009755282581475768
# Validation Loss = 0.050
# Epoch=2, batch = 3000 of 4000, loss=1.024, LR=0.0009755282581475768
# Validation Loss = 4.337
# Epoch=3, batch = 0 of 4000, loss=2.875, LR=0.0009045084971874736
# Validation Loss = 1.379
# Epoch=3, batch = 1000 of 4000, loss=1.095, LR=0.0009045084971874736
# Validation Loss = 1.665
# Epoch=3, batch = 2000 of 4000, loss=1.034, LR=0.0009045084971874736
# Validation Loss = 1.173
# Epoch=3, batch = 3000 of 4000, loss=0.925, LR=0.0009045084971874736
# Validation Loss = 0.298
# Epoch=4, batch = 0 of 4000, loss=0.980, LR=0.0007938926261462366
# Validation Loss = 1.305
# Epoch=4, batch = 1000 of 4000, loss=1.050, LR=0.0007938926261462366
# Validation Loss = 0.024
# Epoch=4, batch = 2000 of 4000, loss=1.270, LR=0.0007938926261462366
# Validation Loss = 1.635
# Epoch=4, batch = 3000 of 4000, loss=1.042, LR=0.0007938926261462366
# Validation Loss = 1.021
# Epoch=5, batch = 0 of 4000, loss=0.874, LR=0.0006545084971874737
# Validation Loss = 0.327
# Epoch=5, batch = 1000 of 4000, loss=0.882, LR=0.0006545084971874737
# Validation Loss = 0.223
# Epoch=5, batch = 2000 of 4000, loss=0.988, LR=0.0006545084971874737
# Validation Loss = 0.915
# Epoch=5, batch = 3000 of 4000, loss=0.905, LR=0.0006545084971874737
# Validation Loss = 0.738
# Epoch=6, batch = 0 of 4000, loss=0.906, LR=0.0005
# Validation Loss = 1.815
# Epoch=6, batch = 1000 of 4000, loss=1.289, LR=0.0005
# Validation Loss = 1.523
# Epoch=6, batch = 2000 of 4000, loss=1.025, LR=0.0005
# Validation Loss = 0.096
# Epoch=6, batch = 3000 of 4000, loss=1.124, LR=0.0005
# Validation Loss = 0.930
# Epoch=7, batch = 0 of 4000, loss=0.799, LR=0.00034549150281252633
# Validation Loss = 1.144
# Epoch=7, batch = 1000 of 4000, loss=0.934, LR=0.00034549150281252633
# Validation Loss = 0.815
# Epoch=7, batch = 2000 of 4000, loss=0.797, LR=0.00034549150281252633
# Validation Loss = 0.530
# Epoch=7, batch = 3000 of 4000, loss=0.831, LR=0.00034549150281252633
# Validation Loss = 0.010
# Epoch=8, batch = 0 of 4000, loss=1.301, LR=0.0002061073738537635
# Validation Loss = 0.899
# Epoch=8, batch = 1000 of 4000, loss=0.873, LR=0.0002061073738537635
# Validation Loss = 0.372
# Epoch=8, batch = 2000 of 4000, loss=0.864, LR=0.0002061073738537635
# Validation Loss = 0.095
# Epoch=8, batch = 3000 of 4000, loss=1.053, LR=0.0002061073738537635
# Validation Loss = 1.156
# Epoch=9, batch = 0 of 4000, loss=0.914, LR=9.549150281252634e-05
# Validation Loss = 0.363
# Epoch=9, batch = 1000 of 4000, loss=0.894, LR=9.549150281252634e-05
# Validation Loss = 0.784
# Epoch=9, batch = 2000 of 4000, loss=0.857, LR=9.549150281252634e-05
# Validation Loss = 0.927
# Epoch=9, batch = 3000 of 4000, loss=0.771, LR=9.549150281252634e-05
# Validation Loss = 0.668
# Epoch=10, batch = 0 of 4000, loss=0.863, LR=2.4471741852423235e-05
# Validation Loss = 0.557
# Epoch=10, batch = 1000 of 4000, loss=0.824, LR=2.4471741852423235e-05
# Validation Loss = 0.657
# Epoch=10, batch = 2000 of 4000, loss=0.901, LR=2.4471741852423235e-05
# Validation Loss = 0.625
# Epoch=10, batch = 3000 of 4000, loss=0.808, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.482
# Epoch=1, batch = 0 of 4000, loss=0.894, LR=0.001
# Validation Loss = 0.908
# Epoch=1, batch = 1000 of 4000, loss=0.914, LR=0.001
# Validation Loss = 1.123
# Epoch=1, batch = 2000 of 4000, loss=1.047, LR=0.001
# Validation Loss = 1.800
# Epoch=1, batch = 3000 of 4000, loss=1.250, LR=0.001
# Validation Loss = 0.003
# Epoch=2, batch = 0 of 4000, loss=1.300, LR=0.0009938441702975688
# Validation Loss = 0.763
# Epoch=2, batch = 1000 of 4000, loss=0.854, LR=0.0009938441702975688
# Validation Loss = 0.145
# Epoch=2, batch = 2000 of 4000, loss=0.922, LR=0.0009938441702975688
# Validation Loss = 0.118
# Epoch=2, batch = 3000 of 4000, loss=0.991, LR=0.0009938441702975688
# Validation Loss = 4.640
# Epoch=3, batch = 0 of 4000, loss=3.172, LR=0.0009755282581475768
# Validation Loss = 0.480
# Epoch=3, batch = 1000 of 4000, loss=0.872, LR=0.0009755282581475768
# Validation Loss = 1.716
# Epoch=3, batch = 2000 of 4000, loss=1.236, LR=0.0009755282581475768
# Validation Loss = 0.182
# Epoch=3, batch = 3000 of 4000, loss=0.930, LR=0.0009755282581475768
# Validation Loss = 0.224
# Epoch=4, batch = 0 of 4000, loss=1.008, LR=0.0009455032620941839
# Validation Loss = 0.948
# Epoch=4, batch = 1000 of 4000, loss=0.945, LR=0.0009455032620941839
# Validation Loss = 0.034
# Epoch=4, batch = 2000 of 4000, loss=1.085, LR=0.0009455032620941839
# Validation Loss = 0.557
# Epoch=4, batch = 3000 of 4000, loss=0.878, LR=0.0009455032620941839
# Validation Loss = 0.778
# Epoch=5, batch = 0 of 4000, loss=0.990, LR=0.0009045084971874737
# Validation Loss = 0.171
# Epoch=5, batch = 1000 of 4000, loss=0.902, LR=0.0009045084971874737
# Validation Loss = 2.648
# Epoch=5, batch = 2000 of 4000, loss=1.755, LR=0.0009045084971874737
# Validation Loss = 0.012
# Epoch=5, batch = 3000 of 4000, loss=1.335, LR=0.0009045084971874737
# Validation Loss = 0.145
# Epoch=6, batch = 0 of 4000, loss=1.005, LR=0.0008535533905932737
# Validation Loss = 1.515
# Epoch=6, batch = 1000 of 4000, loss=1.293, LR=0.0008535533905932737
# Validation Loss = 1.278
# Epoch=6, batch = 2000 of 4000, loss=0.979, LR=0.0008535533905932737
# Validation Loss = 0.101
# Epoch=6, batch = 3000 of 4000, loss=1.101, LR=0.0008535533905932737
# Validation Loss = 0.263
# Epoch=7, batch = 0 of 4000, loss=0.889, LR=0.0007938926261462366
# Validation Loss = 0.588
# Epoch=7, batch = 1000 of 4000, loss=0.867, LR=0.0007938926261462366
# Validation Loss = 2.144
# Epoch=7, batch = 2000 of 4000, loss=1.295, LR=0.0007938926261462366
# Validation Loss = 0.115
# Epoch=7, batch = 3000 of 4000, loss=0.914, LR=0.0007938926261462366
# Validation Loss = 0.168
# Epoch=8, batch = 0 of 4000, loss=0.950, LR=0.0007269952498697733
# Validation Loss = 0.496
# Epoch=8, batch = 1000 of 4000, loss=0.800, LR=0.0007269952498697733
# Validation Loss = 0.103
# Epoch=8, batch = 2000 of 4000, loss=1.024, LR=0.0007269952498697733
# Validation Loss = 0.282
# Epoch=8, batch = 3000 of 4000, loss=0.858, LR=0.0007269952498697733
# Validation Loss = 1.183
# Epoch=9, batch = 0 of 4000, loss=1.022, LR=0.0006545084971874737
# Validation Loss = 1.348
# Epoch=9, batch = 1000 of 4000, loss=1.075, LR=0.0006545084971874737
# Validation Loss = 0.825
# Epoch=9, batch = 2000 of 4000, loss=0.859, LR=0.0006545084971874737
# Validation Loss = 0.800
# Epoch=9, batch = 3000 of 4000, loss=0.913, LR=0.0006545084971874737
# Validation Loss = 0.488
# Epoch=10, batch = 0 of 4000, loss=0.822, LR=0.0005782172325201155
# Validation Loss = 1.147
# Epoch=10, batch = 1000 of 4000, loss=0.922, LR=0.0005782172325201155
# Validation Loss = 0.094
# Epoch=10, batch = 2000 of 4000, loss=1.089, LR=0.0005782172325201155
# Validation Loss = 0.784
# Epoch=10, batch = 3000 of 4000, loss=0.917, LR=0.0005782172325201155
# Validation Loss = 0.357
# Epoch=11, batch = 0 of 4000, loss=0.749, LR=0.0005
# Validation Loss = 0.114
# Epoch=11, batch = 1000 of 4000, loss=0.882, LR=0.0005
# Validation Loss = 1.275
# Epoch=11, batch = 2000 of 4000, loss=1.005, LR=0.0005
# Validation Loss = 0.380
# Epoch=11, batch = 3000 of 4000, loss=0.859, LR=0.0005
# Validation Loss = 1.182
# Epoch=12, batch = 0 of 4000, loss=0.810, LR=0.0004217827674798847
# Validation Loss = 0.244
# Epoch=12, batch = 1000 of 4000, loss=0.936, LR=0.0004217827674798847
# Validation Loss = 0.522
# Epoch=12, batch = 2000 of 4000, loss=0.815, LR=0.0004217827674798847
# Validation Loss = 0.623
# Epoch=12, batch = 3000 of 4000, loss=0.900, LR=0.0004217827674798847
# Validation Loss = 0.555
# Epoch=13, batch = 0 of 4000, loss=0.765, LR=0.00034549150281252633
# Validation Loss = 0.179
# Epoch=13, batch = 1000 of 4000, loss=0.933, LR=0.00034549150281252633
# Validation Loss = 0.265
# Epoch=13, batch = 2000 of 4000, loss=0.839, LR=0.00034549150281252633
# Validation Loss = 0.606
# Epoch=13, batch = 3000 of 4000, loss=0.833, LR=0.00034549150281252633
# Validation Loss = 0.618
# Epoch=14, batch = 0 of 4000, loss=0.903, LR=0.00027300475013022663
# Validation Loss = 0.149
# Epoch=14, batch = 1000 of 4000, loss=0.897, LR=0.00027300475013022663
# Validation Loss = 0.615
# Epoch=14, batch = 2000 of 4000, loss=0.825, LR=0.00027300475013022663
# Validation Loss = 0.611
# Epoch=14, batch = 3000 of 4000, loss=0.890, LR=0.00027300475013022663
# Validation Loss = 0.607
# Epoch=15, batch = 0 of 4000, loss=0.782, LR=0.00020610737385376348
# Validation Loss = 0.397
# Epoch=15, batch = 1000 of 4000, loss=0.811, LR=0.00020610737385376348
# Validation Loss = 0.726
# Epoch=15, batch = 2000 of 4000, loss=0.814, LR=0.00020610737385376348
# Validation Loss = 0.624
# Epoch=15, batch = 3000 of 4000, loss=0.845, LR=0.00020610737385376348
# Validation Loss = 0.332
# Epoch=16, batch = 0 of 4000, loss=0.817, LR=0.00014644660940672625
# Validation Loss = 0.656
# Epoch=16, batch = 1000 of 4000, loss=0.859, LR=0.00014644660940672625
# Validation Loss = 0.651
# Epoch=16, batch = 2000 of 4000, loss=0.909, LR=0.00014644660940672625
# Validation Loss = 0.610
# Epoch=16, batch = 3000 of 4000, loss=0.797, LR=0.00014644660940672625
# Validation Loss = 0.633
# Epoch=17, batch = 0 of 4000, loss=0.831, LR=9.549150281252631e-05
# Validation Loss = 0.629
# Epoch=17, batch = 1000 of 4000, loss=0.781, LR=9.549150281252631e-05
# Validation Loss = 1.061
# Epoch=17, batch = 2000 of 4000, loss=0.858, LR=9.549150281252631e-05
# Validation Loss = 0.571
# Epoch=17, batch = 3000 of 4000, loss=0.914, LR=9.549150281252631e-05
# Validation Loss = 0.726
# Epoch=18, batch = 0 of 4000, loss=0.883, LR=5.4496737905816096e-05
# Validation Loss = 0.509
# Epoch=18, batch = 1000 of 4000, loss=0.816, LR=5.4496737905816096e-05
# Validation Loss = 0.375
# Epoch=18, batch = 2000 of 4000, loss=0.841, LR=5.4496737905816096e-05
# Validation Loss = 0.379
# Epoch=18, batch = 3000 of 4000, loss=0.899, LR=5.4496737905816096e-05
# Validation Loss = 0.422
# Epoch=19, batch = 0 of 4000, loss=0.805, LR=2.447174185242323e-05
# Validation Loss = 0.522
# Epoch=19, batch = 1000 of 4000, loss=0.731, LR=2.447174185242323e-05
# Validation Loss = 0.601
# Epoch=19, batch = 2000 of 4000, loss=0.916, LR=2.447174185242323e-05
# Validation Loss = 0.458
# Epoch=19, batch = 3000 of 4000, loss=0.828, LR=2.447174185242323e-05
# Validation Loss = 0.307
# Epoch=20, batch = 0 of 4000, loss=0.829, LR=6.15582970243117e-06
# Validation Loss = 0.423
# Epoch=20, batch = 1000 of 4000, loss=0.768, LR=6.15582970243117e-06
# Validation Loss = 0.472
# Epoch=20, batch = 2000 of 4000, loss=0.898, LR=6.15582970243117e-06
# Validation Loss = 0.471
# Epoch=20, batch = 3000 of 4000, loss=0.858, LR=6.15582970243117e-06
# Finished training model for channel 10V.
# 10H
# Training stage: 1
# Validation Loss = 11544.695
# Epoch=1, batch = 0 of 4000, loss=11332.455, LR=0.001
# Validation Loss = 0.688
# Epoch=1, batch = 1000 of 4000, loss=2.622, LR=0.001
# Validation Loss = 0.055
# Epoch=1, batch = 2000 of 4000, loss=1.745, LR=0.001
# Validation Loss = 0.508
# Epoch=1, batch = 3000 of 4000, loss=1.999, LR=0.001
# Validation Loss = 0.012
# Epoch=3, batch = 2000 of 4000, loss=0.908, LR=0.0009045084971874736
# Validation Loss = 0.231
# Epoch=6, batch = 1000 of 4000, loss=0.594, LR=0.0005
# Validation Loss = 0.665
# Epoch=6, batch = 2000 of 4000, loss=0.725, LR=0.0005
# Validation Loss = 0.411
# Epoch=6, batch = 3000 of 4000, loss=0.629, LR=0.0005
# Validation Loss = 0.163
# Epoch=7, batch = 0 of 4000, loss=0.627, LR=0.00034549150281252633
# Validation Loss = 0.338
# Epoch=7, batch = 1000 of 4000, loss=0.598, LR=0.00034549150281252633
# Validation Loss = 0.000
# Epoch=7, batch = 2000 of 4000, loss=0.818, LR=0.00034549150281252633
# Validation Loss = 0.100
# Epoch=7, batch = 3000 of 4000, loss=0.653, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=8, batch = 0 of 4000, loss=0.769, LR=0.0002061073738537635
# Validation Loss = 0.076
# Epoch=8, batch = 1000 of 4000, loss=0.616, LR=0.0002061073738537635
# Validation Loss = 0.073
# Epoch=8, batch = 2000 of 4000, loss=0.712, LR=0.0002061073738537635
# Validation Loss = 0.056
# Epoch=8, batch = 3000 of 4000, loss=0.705, LR=0.0002061073738537635
# Validation Loss = 0.319
# Epoch=9, batch = 0 of 4000, loss=0.635, LR=9.549150281252634e-05
# Validation Loss = 0.277
# Epoch=9, batch = 1000 of 4000, loss=0.561, LR=9.549150281252634e-05
# Validation Loss = 0.295
# Epoch=9, batch = 2000 of 4000, loss=0.588, LR=9.549150281252634e-05
# Validation Loss = 0.033
# Epoch=9, batch = 3000 of 4000, loss=0.602, LR=9.549150281252634e-05
# Validation Loss = 0.395
# Epoch=10, batch = 0 of 4000, loss=0.599, LR=2.4471741852423235e-05
# Validation Loss = 0.245
# Epoch=10, batch = 1000 of 4000, loss=0.610, LR=2.4471741852423235e-05
# Validation Loss = 0.210
# Epoch=10, batch = 2000 of 4000, loss=0.587, LR=2.4471741852423235e-05
# Validation Loss = 0.294
# Epoch=10, batch = 3000 of 4000, loss=0.626, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.241
# Epoch=1, batch = 0 of 4000, loss=0.591, LR=0.001
# Validation Loss = 0.207
# Epoch=1, batch = 1000 of 4000, loss=0.619, LR=0.001
# Validation Loss = 0.089
# Epoch=1, batch = 2000 of 4000, loss=0.605, LR=0.001
# Validation Loss = 0.001
# Epoch=1, batch = 3000 of 4000, loss=0.641, LR=0.001
# Validation Loss = 0.008
# Epoch=2, batch = 0 of 4000, loss=0.722, LR=0.0009938441702975688
# Validation Loss = 2.647
# Epoch=2, batch = 1000 of 4000, loss=1.893, LR=0.0009938441702975688
# Validation Loss = 1.662
# Epoch=2, batch = 2000 of 4000, loss=1.406, LR=0.0009938441702975688
# Validation Loss = 0.141
# Epoch=2, batch = 3000 of 4000, loss=0.849, LR=0.0009938441702975688
# Validation Loss = 0.477
# Epoch=3, batch = 0 of 4000, loss=0.939, LR=0.0009755282581475768
# Validation Loss = 2.677
# Epoch=3, batch = 1000 of 4000, loss=2.258, LR=0.0009755282581475768
# Validation Loss = 0.653
# Epoch=3, batch = 2000 of 4000, loss=0.943, LR=0.0009755282581475768
# Validation Loss = 3.833
# Epoch=3, batch = 3000 of 4000, loss=2.893, LR=0.0009755282581475768
# Validation Loss = 1.055
# Epoch=4, batch = 0 of 4000, loss=1.832, LR=0.0009455032620941839
# Validation Loss = 0.000
# Epoch=4, batch = 1000 of 4000, loss=0.679, LR=0.0009455032620941839
# Validation Loss = 0.093
# Epoch=4, batch = 2000 of 4000, loss=0.843, LR=0.0009455032620941839
# Validation Loss = 0.039
# Epoch=4, batch = 3000 of 4000, loss=0.635, LR=0.0009455032620941839
# Validation Loss = 0.000
# Epoch=5, batch = 0 of 4000, loss=0.623, LR=0.0009045084971874737
# Validation Loss = 0.103
# Epoch=5, batch = 1000 of 4000, loss=0.597, LR=0.0009045084971874737
# Validation Loss = 0.021
# Epoch=5, batch = 2000 of 4000, loss=0.573, LR=0.0009045084971874737
# Validation Loss = 0.644
# Epoch=5, batch = 3000 of 4000, loss=0.835, LR=0.0009045084971874737
# Validation Loss = 0.096
# Epoch=6, batch = 0 of 4000, loss=0.862, LR=0.0008535533905932737
# Validation Loss = 1.262
# Epoch=6, batch = 1000 of 4000, loss=2.561, LR=0.0008535533905932737
# Validation Loss = 0.061
# Epoch=6, batch = 2000 of 4000, loss=0.747, LR=0.0008535533905932737
# Validation Loss = 0.097
# Epoch=6, batch = 3000 of 4000, loss=0.854, LR=0.0008535533905932737
# Validation Loss = 0.152
# Epoch=7, batch = 0 of 4000, loss=0.545, LR=0.0007938926261462366
# Validation Loss = 0.079
# Epoch=7, batch = 1000 of 4000, loss=0.597, LR=0.0007938926261462366
# Validation Loss = 0.072
# Epoch=7, batch = 2000 of 4000, loss=0.601, LR=0.0007938926261462366
# Validation Loss = 0.072
# Epoch=7, batch = 3000 of 4000, loss=0.850, LR=0.0007938926261462366
# Validation Loss = 0.285
# Epoch=8, batch = 0 of 4000, loss=0.667, LR=0.0007269952498697733
# Validation Loss = 0.742
# Epoch=8, batch = 1000 of 4000, loss=1.053, LR=0.0007269952498697733
# Validation Loss = 0.000
# Epoch=8, batch = 2000 of 4000, loss=0.574, LR=0.0007269952498697733
# Validation Loss = 0.057
# Epoch=8, batch = 3000 of 4000, loss=0.720, LR=0.0007269952498697733
# Validation Loss = 0.004
# Epoch=9, batch = 0 of 4000, loss=0.611, LR=0.0006545084971874737
# Validation Loss = 0.329
# Epoch=9, batch = 1000 of 4000, loss=1.080, LR=0.0006545084971874737
# Validation Loss = 0.006
# Epoch=9, batch = 2000 of 4000, loss=0.761, LR=0.0006545084971874737
# Validation Loss = 0.029
# Epoch=9, batch = 3000 of 4000, loss=0.674, LR=0.0006545084971874737
# Validation Loss = 0.505
# Epoch=10, batch = 0 of 4000, loss=0.841, LR=0.0005782172325201155
# Validation Loss = 0.317
# Epoch=10, batch = 1000 of 4000, loss=0.730, LR=0.0005782172325201155
# Validation Loss = 0.034
# Epoch=10, batch = 2000 of 4000, loss=0.577, LR=0.0005782172325201155
# Validation Loss = 0.164
# Epoch=10, batch = 3000 of 4000, loss=0.810, LR=0.0005782172325201155
# Validation Loss = 0.097
# Epoch=11, batch = 0 of 4000, loss=0.538, LR=0.0005
# Validation Loss = 0.000
# Epoch=11, batch = 1000 of 4000, loss=0.637, LR=0.0005
# Validation Loss = 0.048
# Epoch=11, batch = 2000 of 4000, loss=0.685, LR=0.0005
# Validation Loss = 0.040
# Epoch=11, batch = 3000 of 4000, loss=0.589, LR=0.0005
# Validation Loss = 0.006
# Epoch=12, batch = 0 of 4000, loss=0.635, LR=0.0004217827674798847
# Validation Loss = 0.212
# Epoch=12, batch = 1000 of 4000, loss=0.785, LR=0.0004217827674798847
# Validation Loss = 0.007
# Epoch=12, batch = 2000 of 4000, loss=0.582, LR=0.0004217827674798847
# Validation Loss = 0.071
# Epoch=12, batch = 3000 of 4000, loss=0.565, LR=0.0004217827674798847
# Validation Loss = 0.245
# Epoch=13, batch = 0 of 4000, loss=0.599, LR=0.00034549150281252633
# Validation Loss = 0.025
# Epoch=13, batch = 1000 of 4000, loss=0.552, LR=0.00034549150281252633
# Validation Loss = 0.104
# Epoch=13, batch = 2000 of 4000, loss=0.587, LR=0.00034549150281252633
# Validation Loss = 0.000
# Epoch=13, batch = 3000 of 4000, loss=0.623, LR=0.00034549150281252633
# Validation Loss = 0.011
# Epoch=14, batch = 0 of 4000, loss=0.549, LR=0.00027300475013022663
# Validation Loss = 0.001
# Epoch=14, batch = 1000 of 4000, loss=0.532, LR=0.00027300475013022663
# Validation Loss = 0.105
# Epoch=14, batch = 2000 of 4000, loss=0.562, LR=0.00027300475013022663
# Validation Loss = 0.062
# Epoch=14, batch = 3000 of 4000, loss=0.592, LR=0.00027300475013022663
# Validation Loss = 0.017
# Epoch=15, batch = 0 of 4000, loss=0.523, LR=0.00020610737385376348
# Validation Loss = 0.004
# Epoch=15, batch = 1000 of 4000, loss=0.552, LR=0.00020610737385376348
# Validation Loss = 0.018
# Epoch=15, batch = 2000 of 4000, loss=0.512, LR=0.00020610737385376348
# Validation Loss = 0.058
# Epoch=15, batch = 3000 of 4000, loss=0.515, LR=0.00020610737385376348
# Validation Loss = 0.000
# Epoch=16, batch = 0 of 4000, loss=0.652, LR=0.00014644660940672625
# Validation Loss = 0.073
# Epoch=16, batch = 1000 of 4000, loss=0.498, LR=0.00014644660940672625
# Validation Loss = 0.004
# Epoch=16, batch = 2000 of 4000, loss=0.543, LR=0.00014644660940672625
# Validation Loss = 0.350
# Epoch=16, batch = 3000 of 4000, loss=0.624, LR=0.00014644660940672625
# Validation Loss = 0.025
# Epoch=17, batch = 0 of 4000, loss=0.477, LR=9.549150281252631e-05
# Validation Loss = 0.075
# Epoch=17, batch = 1000 of 4000, loss=0.568, LR=9.549150281252631e-05
# Validation Loss = 0.102
# Epoch=17, batch = 2000 of 4000, loss=0.586, LR=9.549150281252631e-05
# Validation Loss = 0.000
# Epoch=17, batch = 3000 of 4000, loss=0.511, LR=9.549150281252631e-05
# Validation Loss = 0.109
# Epoch=18, batch = 0 of 4000, loss=0.573, LR=5.4496737905816096e-05
# Validation Loss = 0.014
# Epoch=18, batch = 1000 of 4000, loss=0.511, LR=5.4496737905816096e-05
# Validation Loss = 0.029
# Epoch=18, batch = 2000 of 4000, loss=0.473, LR=5.4496737905816096e-05
# Validation Loss = 0.036
# Epoch=18, batch = 3000 of 4000, loss=0.556, LR=5.4496737905816096e-05
# Validation Loss = 0.067
# Epoch=19, batch = 0 of 4000, loss=0.579, LR=2.447174185242323e-05
# Validation Loss = 0.074
# Epoch=19, batch = 1000 of 4000, loss=0.503, LR=2.447174185242323e-05
# Validation Loss = 0.033
# Epoch=19, batch = 2000 of 4000, loss=0.502, LR=2.447174185242323e-05
# Validation Loss = 0.056
# Epoch=19, batch = 3000 of 4000, loss=0.546, LR=2.447174185242323e-05
# Validation Loss = 0.014
# Epoch=20, batch = 0 of 4000, loss=0.571, LR=6.15582970243117e-06
# Validation Loss = 0.081
# Epoch=20, batch = 1000 of 4000, loss=0.536, LR=6.15582970243117e-06
# Validation Loss = 0.037
# Epoch=20, batch = 2000 of 4000, loss=0.497, LR=6.15582970243117e-06
# Validation Loss = 0.031
# Epoch=20, batch = 3000 of 4000, loss=0.516, LR=6.15582970243117e-06
# Finished training model for channel 37V.
# 37H
# Training stage: 1
# Validation Loss = 21458.244
# Epoch=1, batch = 0 of 4000, loss=21664.074, LR=0.001
# Validation Loss = 3.368
# Epoch=1, batch = 1000 of 4000, loss=3.404, LR=0.001
# Validation Loss = 0.847
# Epoch=1, batch = 2000 of 4000, loss=4.145, LR=0.001
# Validation Loss = 0.036
# Epoch=1, batch = 3000 of 4000, loss=2.252, LR=0.001
# Validation Loss = 0.032
# Epoch=2, batch = 0 of 4000, loss=1.696, LR=0.0009045084971874737
# Validation Loss = 0.016
# Epoch=2, batch = 1000 of 4000, loss=1.715, LR=0.0009045084971874737
# Validation Loss = 0.530
# Epoch=2, batch = 2000 of 4000, loss=1.471, LR=0.0009045084971874737
# Validation Loss = 1.246
# Epoch=2, batch = 3000 of 4000, loss=2.554, LR=0.0009045084971874737
# Validation Loss = 0.778
# Epoch=3, batch = 0 of 4000, loss=2.960, LR=0.0006545084971874737
# Validation Loss = 0.004
# Epoch=3, batch = 1000 of 4000, loss=1.696, LR=0.0006545084971874737
# Validation Loss = 0.003
# Epoch=3, batch = 2000 of 4000, loss=1.491, LR=0.0006545084971874737
# Validation Loss = 0.821
# Epoch=3, batch = 3000 of 4000, loss=1.596, LR=0.0006545084971874737
# Validation Loss = 0.077
# Epoch=4, batch = 0 of 4000, loss=1.276, LR=0.00034549150281252633
# Validation Loss = 0.123
# Epoch=4, batch = 1000 of 4000, loss=1.579, LR=0.00034549150281252633
# Validation Loss = 0.002
# Epoch=4, batch = 2000 of 4000, loss=1.260, LR=0.00034549150281252633
# Validation Loss = 0.114
# Epoch=4, batch = 3000 of 4000, loss=1.388, LR=0.00034549150281252633
# Validation Loss = 0.028
# Epoch=5, batch = 0 of 4000, loss=1.349, LR=9.549150281252633e-05
# Validation Loss = 0.010
# Epoch=5, batch = 1000 of 4000, loss=1.300, LR=9.549150281252633e-05
# Validation Loss = 0.005
# Epoch=5, batch = 2000 of 4000, loss=1.289, LR=9.549150281252633e-05
# Validation Loss = 0.096
# Epoch=5, batch = 3000 of 4000, loss=1.320, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.000
# Epoch=1, batch = 0 of 4000, loss=1.257, LR=0.001
# Validation Loss = 0.009
# Epoch=1, batch = 1000 of 4000, loss=1.242, LR=0.001
# Validation Loss = 1.675
# Epoch=1, batch = 2000 of 4000, loss=3.001, LR=0.001
# Validation Loss = 0.162
# Epoch=1, batch = 3000 of 4000, loss=1.540, LR=0.001
# Validation Loss = 0.683
# Epoch=2, batch = 0 of 4000, loss=2.022, LR=0.0009755282581475768
# Validation Loss = 0.215
# Epoch=2, batch = 1000 of 4000, loss=1.317, LR=0.0009755282581475768
# Validation Loss = 0.433
# Epoch=2, batch = 2000 of 4000, loss=1.461, LR=0.0009755282581475768
# Validation Loss = 0.124
# Epoch=2, batch = 3000 of 4000, loss=1.608, LR=0.0009755282581475768
# Validation Loss = 1.035
# Epoch=3, batch = 0 of 4000, loss=2.513, LR=0.0009045084971874736
# Validation Loss = 0.529
# Epoch=3, batch = 1000 of 4000, loss=1.871, LR=0.0009045084971874736
# Validation Loss = 0.535
# Epoch=3, batch = 2000 of 4000, loss=2.170, LR=0.0009045084971874736
# Validation Loss = 0.028
# Epoch=3, batch = 3000 of 4000, loss=1.107, LR=0.0009045084971874736
# Validation Loss = 0.014
# Epoch=4, batch = 0 of 4000, loss=1.248, LR=0.0007938926261462366
# Validation Loss = 0.494
# Epoch=4, batch = 1000 of 4000, loss=1.737, LR=0.0007938926261462366
# Validation Loss = 0.810
# Epoch=4, batch = 2000 of 4000, loss=1.763, LR=0.0007938926261462366
# Validation Loss = 0.025
# Epoch=4, batch = 3000 of 4000, loss=1.289, LR=0.0007938926261462366
# Validation Loss = 0.088
# Epoch=5, batch = 0 of 4000, loss=1.313, LR=0.0006545084971874737
# Validation Loss = 0.267
# Epoch=5, batch = 1000 of 4000, loss=1.173, LR=0.0006545084971874737
# Validation Loss = 0.746
# Epoch=5, batch = 2000 of 4000, loss=1.532, LR=0.0006545084971874737
# Validation Loss = 0.117
# Epoch=5, batch = 3000 of 4000, loss=1.201, LR=0.0006545084971874737
# Validation Loss = 0.005
# Epoch=6, batch = 0 of 4000, loss=1.361, LR=0.0005
# Validation Loss = 1.142
# Epoch=6, batch = 1000 of 4000, loss=1.816, LR=0.0005
# Validation Loss = 0.478
# Epoch=6, batch = 2000 of 4000, loss=1.658, LR=0.0005
# Validation Loss = 0.229
# Epoch=6, batch = 3000 of 4000, loss=1.039, LR=0.0005
# Validation Loss = 0.030
# Epoch=7, batch = 0 of 4000, loss=1.202, LR=0.00034549150281252633
# Validation Loss = 0.044
# Epoch=7, batch = 1000 of 4000, loss=1.125, LR=0.00034549150281252633
# Validation Loss = 0.072
# Epoch=7, batch = 2000 of 4000, loss=1.358, LR=0.00034549150281252633
# Validation Loss = 0.201
# Epoch=7, batch = 3000 of 4000, loss=1.331, LR=0.00034549150281252633
# Validation Loss = 0.116
# Epoch=8, batch = 0 of 4000, loss=1.234, LR=0.0002061073738537635
# Validation Loss = 0.043
# Epoch=8, batch = 1000 of 4000, loss=1.141, LR=0.0002061073738537635
# Validation Loss = 0.085
# Epoch=8, batch = 2000 of 4000, loss=1.262, LR=0.0002061073738537635
# Validation Loss = 0.048
# Epoch=8, batch = 3000 of 4000, loss=1.152, LR=0.0002061073738537635
# Validation Loss = 0.023
# Epoch=9, batch = 0 of 4000, loss=1.094, LR=9.549150281252634e-05
# Validation Loss = 0.006
# Epoch=9, batch = 1000 of 4000, loss=1.144, LR=9.549150281252634e-05
# Validation Loss = 0.008
# Epoch=9, batch = 2000 of 4000, loss=1.205, LR=9.549150281252634e-05
# Validation Loss = 0.023
# Epoch=9, batch = 3000 of 4000, loss=1.265, LR=9.549150281252634e-05
# Validation Loss = 0.014
# Epoch=10, batch = 0 of 4000, loss=1.030, LR=2.4471741852423235e-05
# Validation Loss = 0.040
# Epoch=10, batch = 1000 of 4000, loss=1.157, LR=2.4471741852423235e-05
# Validation Loss = 0.009
# Epoch=10, batch = 2000 of 4000, loss=1.147, LR=2.4471741852423235e-05
# Validation Loss = 0.010
# Epoch=10, batch = 3000 of 4000, loss=1.219, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.002
# Epoch=1, batch = 0 of 4000, loss=1.001, LR=0.001
# Validation Loss = 0.087
# Epoch=1, batch = 1000 of 4000, loss=1.297, LR=0.001
# Validation Loss = 0.157
# Epoch=1, batch = 2000 of 4000, loss=1.523, LR=0.001
# Validation Loss = 0.000
# Epoch=1, batch = 3000 of 4000, loss=1.267, LR=0.001
# Validation Loss = 0.249
# Epoch=2, batch = 0 of 4000, loss=1.409, LR=0.0009938441702975688
# Validation Loss = 0.030
# Epoch=2, batch = 1000 of 4000, loss=1.331, LR=0.0009938441702975688
# Validation Loss = 0.170
# Epoch=2, batch = 2000 of 4000, loss=1.089, LR=0.0009938441702975688
# Validation Loss = 0.185
# Epoch=2, batch = 3000 of 4000, loss=1.292, LR=0.0009938441702975688
# Validation Loss = 0.080
# Epoch=3, batch = 0 of 4000, loss=1.480, LR=0.0009755282581475768
# Validation Loss = 0.010
# Epoch=3, batch = 1000 of 4000, loss=1.196, LR=0.0009755282581475768
# Validation Loss = 0.009
# Epoch=3, batch = 2000 of 4000, loss=1.259, LR=0.0009755282581475768
# Validation Loss = 0.248
# Epoch=3, batch = 3000 of 4000, loss=1.527, LR=0.0009755282581475768
# Validation Loss = 0.007
# Epoch=4, batch = 0 of 4000, loss=1.380, LR=0.0009455032620941839
# Validation Loss = 0.000
# Epoch=4, batch = 1000 of 4000, loss=1.203, LR=0.0009455032620941839
# Validation Loss = 0.011
# Epoch=4, batch = 2000 of 4000, loss=1.212, LR=0.0009455032620941839
# Validation Loss = 0.001
# Epoch=4, batch = 3000 of 4000, loss=1.127, LR=0.0009455032620941839
# Validation Loss = 0.307
# Epoch=5, batch = 0 of 4000, loss=1.523, LR=0.0009045084971874737
# Validation Loss = 0.042
# Epoch=5, batch = 1000 of 4000, loss=1.300, LR=0.0009045084971874737
# Validation Loss = 2.135
# Epoch=5, batch = 2000 of 4000, loss=2.599, LR=0.0009045084971874737
# Validation Loss = 0.078
# Epoch=5, batch = 3000 of 4000, loss=1.280, LR=0.0009045084971874737
# Validation Loss = 0.848
# Epoch=6, batch = 0 of 4000, loss=2.350, LR=0.0008535533905932737
# Validation Loss = 0.000
# Epoch=6, batch = 1000 of 4000, loss=1.097, LR=0.0008535533905932737
# Validation Loss = 0.427
# Epoch=6, batch = 2000 of 4000, loss=1.512, LR=0.0008535533905932737
# Validation Loss = 0.253
# Epoch=6, batch = 3000 of 4000, loss=1.144, LR=0.0008535533905932737
# Validation Loss = 0.067
# Epoch=7, batch = 0 of 4000, loss=1.191, LR=0.0007938926261462366
# Validation Loss = 0.013
# Epoch=7, batch = 1000 of 4000, loss=1.040, LR=0.0007938926261462366
# Validation Loss = 0.017
# Epoch=7, batch = 2000 of 4000, loss=1.231, LR=0.0007938926261462366
# Validation Loss = 0.037
# Epoch=7, batch = 3000 of 4000, loss=1.110, LR=0.0007938926261462366
# Validation Loss = 0.069
# Epoch=8, batch = 0 of 4000, loss=1.052, LR=0.0007269952498697733
# Validation Loss = 0.035
# Epoch=8, batch = 1000 of 4000, loss=1.349, LR=0.0007269952498697733
# Validation Loss = 0.202
# Epoch=8, batch = 2000 of 4000, loss=1.613, LR=0.0007269952498697733
# Validation Loss = 0.143
# Epoch=8, batch = 3000 of 4000, loss=1.499, LR=0.0007269952498697733
# Validation Loss = 0.002
# Epoch=9, batch = 0 of 4000, loss=1.202, LR=0.0006545084971874737
# Validation Loss = 0.001
# Epoch=9, batch = 1000 of 4000, loss=1.162, LR=0.0006545084971874737
# Validation Loss = 0.073
# Epoch=9, batch = 2000 of 4000, loss=1.160, LR=0.0006545084971874737
# Validation Loss = 0.218
# Epoch=9, batch = 3000 of 4000, loss=1.451, LR=0.0006545084971874737
# Validation Loss = 0.290
# Epoch=10, batch = 0 of 4000, loss=1.186, LR=0.0005782172325201155
# Validation Loss = 0.035
# Epoch=10, batch = 1000 of 4000, loss=1.168, LR=0.0005782172325201155
# Validation Loss = 0.002
# Epoch=10, batch = 2000 of 4000, loss=1.091, LR=0.0005782172325201155
# Validation Loss = 0.008
# Epoch=10, batch = 3000 of 4000, loss=1.280, LR=0.0005782172325201155
# Validation Loss = 0.042
# Epoch=11, batch = 0 of 4000, loss=1.177, LR=0.0005
# Validation Loss = 0.007
# Epoch=11, batch = 1000 of 4000, loss=1.136, LR=0.0005
# Validation Loss = 0.640
# Epoch=11, batch = 2000 of 4000, loss=1.686, LR=0.0005
# Validation Loss = 0.091
# Epoch=11, batch = 3000 of 4000, loss=1.214, LR=0.0005
# Validation Loss = 0.009
# Epoch=12, batch = 0 of 4000, loss=1.222, LR=0.0004217827674798847
# Validation Loss = 0.010
# Epoch=12, batch = 1000 of 4000, loss=1.194, LR=0.0004217827674798847
# Validation Loss = 0.164
# Epoch=12, batch = 2000 of 4000, loss=1.162, LR=0.0004217827674798847
# Validation Loss = 0.004
# Epoch=12, batch = 3000 of 4000, loss=1.086, LR=0.0004217827674798847
# Validation Loss = 0.117
# Epoch=13, batch = 0 of 4000, loss=1.210, LR=0.00034549150281252633
# Validation Loss = 0.142
# Epoch=13, batch = 1000 of 4000, loss=1.123, LR=0.00034549150281252633
# Validation Loss = 0.010
# Epoch=13, batch = 2000 of 4000, loss=1.204, LR=0.00034549150281252633
# Validation Loss = 0.047
# Epoch=13, batch = 3000 of 4000, loss=1.084, LR=0.00034549150281252633
# Validation Loss = 0.112
# Epoch=14, batch = 0 of 4000, loss=1.348, LR=0.00027300475013022663
# Validation Loss = 0.067
# Epoch=14, batch = 1000 of 4000, loss=1.201, LR=0.00027300475013022663
# Validation Loss = 0.003
# Epoch=14, batch = 2000 of 4000, loss=1.234, LR=0.00027300475013022663
# Validation Loss = 0.150
# Epoch=14, batch = 3000 of 4000, loss=0.989, LR=0.00027300475013022663
# Validation Loss = 0.001
# Epoch=15, batch = 0 of 4000, loss=1.120, LR=0.00020610737385376348
# Validation Loss = 0.119
# Epoch=15, batch = 1000 of 4000, loss=0.999, LR=0.00020610737385376348
# Validation Loss = 0.278
# Epoch=15, batch = 2000 of 4000, loss=1.286, LR=0.00020610737385376348
# Validation Loss = 0.294
# Epoch=15, batch = 3000 of 4000, loss=1.268, LR=0.00020610737385376348
# Validation Loss = 0.034
# Epoch=16, batch = 0 of 4000, loss=1.053, LR=0.00014644660940672625
# Validation Loss = 0.051
# Epoch=16, batch = 1000 of 4000, loss=1.025, LR=0.00014644660940672625
# Validation Loss = 0.063
# Epoch=16, batch = 2000 of 4000, loss=1.028, LR=0.00014644660940672625
# Validation Loss = 0.028
# Epoch=16, batch = 3000 of 4000, loss=1.056, LR=0.00014644660940672625
# Validation Loss = 0.003
# Epoch=17, batch = 0 of 4000, loss=1.088, LR=9.549150281252631e-05
# Validation Loss = 0.084
# Epoch=17, batch = 1000 of 4000, loss=1.120, LR=9.549150281252631e-05
# Validation Loss = 0.109
# Epoch=17, batch = 2000 of 4000, loss=1.122, LR=9.549150281252631e-05
# Validation Loss = 0.266
# Epoch=17, batch = 3000 of 4000, loss=1.071, LR=9.549150281252631e-05
# Validation Loss = 0.085
# Epoch=18, batch = 0 of 4000, loss=1.084, LR=5.4496737905816096e-05
# Validation Loss = 0.107
# Epoch=18, batch = 1000 of 4000, loss=1.019, LR=5.4496737905816096e-05
# Validation Loss = 0.047
# Epoch=18, batch = 2000 of 4000, loss=1.226, LR=5.4496737905816096e-05
# Validation Loss = 0.162
# Epoch=18, batch = 3000 of 4000, loss=1.114, LR=5.4496737905816096e-05
# Validation Loss = 0.014
# Epoch=19, batch = 0 of 4000, loss=1.036, LR=2.447174185242323e-05
# Validation Loss = 0.082
# Epoch=19, batch = 1000 of 4000, loss=1.151, LR=2.447174185242323e-05
# Validation Loss = 0.100
# Epoch=19, batch = 2000 of 4000, loss=1.072, LR=2.447174185242323e-05
# Validation Loss = 0.094
# Epoch=19, batch = 3000 of 4000, loss=1.077, LR=2.447174185242323e-05
# Validation Loss = 0.100
# Epoch=20, batch = 0 of 4000, loss=1.066, LR=6.15582970243117e-06
# Validation Loss = 0.084
# Epoch=20, batch = 1000 of 4000, loss=1.043, LR=6.15582970243117e-06
# Validation Loss = 0.095
# Epoch=20, batch = 2000 of 4000, loss=1.033, LR=6.15582970243117e-06
# Validation Loss = 0.074
# Epoch=20, batch = 3000 of 4000, loss=0.984, LR=6.15582970243117e-06
# Finished training model for channel 37H.
# 89V
# Training stage: 1
# Validation Loss = 62359.035
# Epoch=1, batch = 0 of 4000, loss=60774.453, LR=0.001
# Validation Loss = 0.185
# Epoch=1, batch = 1000 of 4000, loss=0.795, LR=0.001
# Validation Loss = 0.259
# Epoch=1, batch = 2000 of 4000, loss=0.725, LR=0.001
# Validation Loss = 0.018
# Epoch=1, batch = 3000 of 4000, loss=0.715, LR=0.001
# Validation Loss = 0.000
# Epoch=2, batch = 0 of 4000, loss=0.883, LR=0.0009045084971874737
# Validation Loss = 0.434
# Epoch=2, batch = 1000 of 4000, loss=0.834, LR=0.0009045084971874737
# Validation Loss = 0.313
# Epoch=2, batch = 2000 of 4000, loss=0.768, LR=0.0009045084971874737
# Validation Loss = 4.926
# Epoch=2, batch = 3000 of 4000, loss=3.474, LR=0.0009045084971874737
# Validation Loss = 9.009
# Epoch=3, batch = 0 of 4000, loss=6.729, LR=0.0006545084971874737
# Validation Loss = 1.309
# Epoch=3, batch = 1000 of 4000, loss=1.060, LR=0.0006545084971874737
# Validation Loss = 0.404
# Epoch=3, batch = 2000 of 4000, loss=2.053, LR=0.0006545084971874737
# Validation Loss = 2.763
# Epoch=3, batch = 3000 of 4000, loss=1.932, LR=0.0006545084971874737
# Validation Loss = 2.747
# Epoch=4, batch = 0 of 4000, loss=1.776, LR=0.00034549150281252633
# Validation Loss = 0.700
# Epoch=4, batch = 1000 of 4000, loss=0.761, LR=0.00034549150281252633
# Validation Loss = 0.866
# Epoch=4, batch = 2000 of 4000, loss=0.669, LR=0.00034549150281252633
# Validation Loss = 0.474
# Epoch=4, batch = 3000 of 4000, loss=0.541, LR=0.00034549150281252633
# Validation Loss = 0.057
# Epoch=5, batch = 0 of 4000, loss=0.630, LR=9.549150281252633e-05
# Validation Loss = 0.495
# Epoch=5, batch = 1000 of 4000, loss=0.479, LR=9.549150281252633e-05
# Validation Loss = 0.595
# Epoch=5, batch = 2000 of 4000, loss=0.527, LR=9.549150281252633e-05
# Validation Loss = 0.915
# Epoch=5, batch = 3000 of 4000, loss=0.648, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.638
# Epoch=1, batch = 0 of 4000, loss=0.492, LR=0.001
# Validation Loss = 0.319
# Epoch=1, batch = 1000 of 4000, loss=0.948, LR=0.001
# Validation Loss = 0.758
# Epoch=1, batch = 2000 of 4000, loss=0.939, LR=0.001
# Validation Loss = 0.079
# Epoch=1, batch = 3000 of 4000, loss=1.010, LR=0.001
# Validation Loss = 0.722
# Epoch=2, batch = 0 of 4000, loss=2.173, LR=0.0009755282581475768
# Validation Loss = 1.939
# Epoch=2, batch = 1000 of 4000, loss=1.287, LR=0.0009755282581475768
# Validation Loss = 0.299
# Epoch=2, batch = 2000 of 4000, loss=1.428, LR=0.0009755282581475768
# Validation Loss = 0.619
# Epoch=2, batch = 3000 of 4000, loss=0.570, LR=0.0009755282581475768
# Validation Loss = 0.034
# Epoch=3, batch = 0 of 4000, loss=1.050, LR=0.0009045084971874736
# Validation Loss = 1.910
# Epoch=3, batch = 1000 of 4000, loss=4.587, LR=0.0009045084971874736
# Validation Loss = 0.002
# Epoch=3, batch = 2000 of 4000, loss=0.601, LR=0.0009045084971874736
# Validation Loss = 0.154
# Epoch=3, batch = 3000 of 4000, loss=0.541, LR=0.0009045084971874736
# Validation Loss = 0.020
# Epoch=4, batch = 0 of 4000, loss=0.711, LR=0.0007938926261462366
# Validation Loss = 0.121
# Epoch=4, batch = 1000 of 4000, loss=1.605, LR=0.0007938926261462366
# Validation Loss = 0.127
# Epoch=4, batch = 2000 of 4000, loss=1.391, LR=0.0007938926261462366
# Validation Loss = 0.285
# Epoch=4, batch = 3000 of 4000, loss=0.541, LR=0.0007938926261462366
# Validation Loss = 0.143
# Epoch=5, batch = 0 of 4000, loss=0.542, LR=0.0006545084971874737
# Validation Loss = 0.336
# Epoch=5, batch = 1000 of 4000, loss=0.507, LR=0.0006545084971874737
# Validation Loss = 1.567
# Epoch=5, batch = 2000 of 4000, loss=0.988, LR=0.0006545084971874737
# Validation Loss = 0.001
# Epoch=5, batch = 3000 of 4000, loss=0.859, LR=0.0006545084971874737
# Validation Loss = 0.120
# Epoch=6, batch = 0 of 4000, loss=0.549, LR=0.0005
# Validation Loss = 1.749
# Epoch=6, batch = 1000 of 4000, loss=1.037, LR=0.0005
# Validation Loss = 0.830
# Epoch=6, batch = 2000 of 4000, loss=0.528, LR=0.0005
# Validation Loss = 0.317
# Epoch=6, batch = 3000 of 4000, loss=0.546, LR=0.0005
# Validation Loss = 0.155
# Epoch=7, batch = 0 of 4000, loss=1.536, LR=0.00034549150281252633
# Validation Loss = 0.005
# Epoch=7, batch = 1000 of 4000, loss=0.768, LR=0.00034549150281252633
# Validation Loss = 0.162
# Epoch=7, batch = 2000 of 4000, loss=0.593, LR=0.00034549150281252633
# Validation Loss = 0.859
# Epoch=7, batch = 3000 of 4000, loss=0.640, LR=0.00034549150281252633
# Validation Loss = 0.102
# Epoch=8, batch = 0 of 4000, loss=0.649, LR=0.0002061073738537635
# Validation Loss = 0.357
# Epoch=8, batch = 1000 of 4000, loss=0.539, LR=0.0002061073738537635
# Validation Loss = 0.054
# Epoch=8, batch = 2000 of 4000, loss=0.594, LR=0.0002061073738537635
# Validation Loss = 0.672
# Epoch=8, batch = 3000 of 4000, loss=0.607, LR=0.0002061073738537635
# Validation Loss = 0.269
# Epoch=9, batch = 0 of 4000, loss=0.639, LR=9.549150281252634e-05
# Validation Loss = 0.378
# Epoch=9, batch = 1000 of 4000, loss=0.556, LR=9.549150281252634e-05
# Validation Loss = 0.344
# Epoch=9, batch = 2000 of 4000, loss=0.471, LR=9.549150281252634e-05
# Validation Loss = 0.316
# Epoch=9, batch = 3000 of 4000, loss=0.565, LR=9.549150281252634e-05
# Validation Loss = 0.712
# Epoch=10, batch = 0 of 4000, loss=0.499, LR=2.4471741852423235e-05
# Validation Loss = 0.372
# Epoch=10, batch = 1000 of 4000, loss=0.462, LR=2.4471741852423235e-05
# Validation Loss = 0.288
# Epoch=10, batch = 2000 of 4000, loss=0.444, LR=2.4471741852423235e-05
# Validation Loss = 0.338
# Epoch=10, batch = 3000 of 4000, loss=0.549, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.477
# Epoch=1, batch = 0 of 4000, loss=0.697, LR=0.001
# Validation Loss = 0.322
# Epoch=1, batch = 1000 of 4000, loss=0.510, LR=0.001
# Validation Loss = 0.376
# Epoch=1, batch = 2000 of 4000, loss=0.532, LR=0.001
# Validation Loss = 0.220
# Epoch=1, batch = 3000 of 4000, loss=0.473, LR=0.001
# Validation Loss = 0.845
# Epoch=2, batch = 0 of 4000, loss=0.572, LR=0.0009938441702975688
# Validation Loss = 0.001
# Epoch=2, batch = 1000 of 4000, loss=1.045, LR=0.0009938441702975688
# Validation Loss = 0.063
# Epoch=2, batch = 2000 of 4000, loss=0.724, LR=0.0009938441702975688
# Validation Loss = 5.303
# Epoch=2, batch = 3000 of 4000, loss=3.196, LR=0.0009938441702975688
# Validation Loss = 0.630
# Epoch=3, batch = 0 of 4000, loss=0.565, LR=0.0009755282581475768
# Validation Loss = 6.448
# Epoch=3, batch = 1000 of 4000, loss=4.040, LR=0.0009755282581475768
# Validation Loss = 0.877
# Epoch=3, batch = 2000 of 4000, loss=0.608, LR=0.0009755282581475768
# Validation Loss = 0.014
# Epoch=3, batch = 3000 of 4000, loss=0.960, LR=0.0009755282581475768
# Validation Loss = 2.057
# Epoch=4, batch = 0 of 4000, loss=1.016, LR=0.0009455032620941839
# Validation Loss = 0.785
# Epoch=4, batch = 1000 of 4000, loss=0.584, LR=0.0009455032620941839
# Validation Loss = 0.099
# Epoch=4, batch = 2000 of 4000, loss=0.646, LR=0.0009455032620941839
# Validation Loss = 0.001
# Epoch=4, batch = 3000 of 4000, loss=0.805, LR=0.0009455032620941839
# Validation Loss = 0.404
# Epoch=5, batch = 0 of 4000, loss=0.587, LR=0.0009045084971874737
# Validation Loss = 1.871
# Epoch=5, batch = 1000 of 4000, loss=0.990, LR=0.0009045084971874737
# Validation Loss = 2.316
# Epoch=5, batch = 2000 of 4000, loss=1.289, LR=0.0009045084971874737
# Validation Loss = 1.955
# Epoch=5, batch = 3000 of 4000, loss=1.062, LR=0.0009045084971874737
# Validation Loss = 1.001
# Epoch=6, batch = 0 of 4000, loss=0.714, LR=0.0008535533905932737
# Validation Loss = 4.820
# Epoch=6, batch = 1000 of 4000, loss=3.189, LR=0.0008535533905932737
# Validation Loss = 0.216
# Epoch=6, batch = 2000 of 4000, loss=0.603, LR=0.0008535533905932737
# Validation Loss = 1.744
# Epoch=6, batch = 3000 of 4000, loss=0.892, LR=0.0008535533905932737
# Validation Loss = 0.305
# Epoch=7, batch = 0 of 4000, loss=0.491, LR=0.0007938926261462366
# Validation Loss = 1.728
# Epoch=7, batch = 1000 of 4000, loss=1.019, LR=0.0007938926261462366
# Validation Loss = 0.022
# Epoch=7, batch = 2000 of 4000, loss=0.907, LR=0.0007938926261462366
# Validation Loss = 2.388
# Epoch=1, batch = 1000 of 4000, loss=2.875, LR=0.001
# Validation Loss = 0.619
# Epoch=1, batch = 2000 of 4000, loss=2.126, LR=0.001
# Validation Loss = 0.407
# Epoch=1, batch = 3000 of 4000, loss=2.025, LR=0.001
# Validation Loss = 0.154
# Epoch=3, batch = 2000 of 4000, loss=1.834, LR=0.0009045084971874736
# Validation Loss = 4.169
# Epoch=3, batch = 3000 of 4000, loss=3.733, LR=0.0009045084971874736
# Validation Loss = 3.481
# Epoch=4, batch = 0 of 4000, loss=5.270, LR=0.0007938926261462366
# Validation Loss = 0.035
# Epoch=4, batch = 1000 of 4000, loss=1.848, LR=0.0007938926261462366
# Validation Loss = 2.305
# Epoch=4, batch = 2000 of 4000, loss=2.569, LR=0.0007938926261462366
# Validation Loss = 1.994
# Epoch=4, batch = 3000 of 4000, loss=2.107, LR=0.0007938926261462366
# Validation Loss = 0.012
# Epoch=5, batch = 0 of 4000, loss=1.775, LR=0.0006545084971874737
# Validation Loss = 0.332
# Epoch=5, batch = 1000 of 4000, loss=1.878, LR=0.0006545084971874737
# Validation Loss = 0.640
# Epoch=5, batch = 2000 of 4000, loss=1.970, LR=0.0006545084971874737
# Validation Loss = 0.146
# Epoch=5, batch = 3000 of 4000, loss=1.736, LR=0.0006545084971874737
# Validation Loss = 0.609
# Epoch=6, batch = 0 of 4000, loss=1.723, LR=0.0005
# Validation Loss = 0.784
# Epoch=6, batch = 1000 of 4000, loss=2.856, LR=0.0005
# Validation Loss = 0.736
# Epoch=6, batch = 2000 of 4000, loss=1.967, LR=0.0005
# Validation Loss = 0.218
# Epoch=6, batch = 3000 of 4000, loss=1.427, LR=0.0005
# Validation Loss = 1.822
# Epoch=7, batch = 0 of 4000, loss=2.168, LR=0.00034549150281252633
# Validation Loss = 0.172
# Epoch=7, batch = 1000 of 4000, loss=1.624, LR=0.00034549150281252633
# Validation Loss = 0.145
# Epoch=7, batch = 2000 of 4000, loss=2.168, LR=0.00034549150281252633
# Validation Loss = 0.136
# Epoch=7, batch = 3000 of 4000, loss=1.689, LR=0.00034549150281252633
# Validation Loss = 1.672
# Epoch=8, batch = 0 of 4000, loss=2.380, LR=0.0002061073738537635
# Validation Loss = 0.001
# Epoch=8, batch = 1000 of 4000, loss=1.979, LR=0.0002061073738537635
# Validation Loss = 0.206
# Epoch=8, batch = 2000 of 4000, loss=1.561, LR=0.0002061073738537635
# Validation Loss = 0.885
# Epoch=8, batch = 3000 of 4000, loss=1.633, LR=0.0002061073738537635
# Validation Loss = 0.033
# Epoch=9, batch = 0 of 4000, loss=1.665, LR=9.549150281252634e-05
# Validation Loss = 0.401
# Epoch=9, batch = 1000 of 4000, loss=1.709, LR=9.549150281252634e-05
# Validation Loss = 0.000
# Epoch=9, batch = 2000 of 4000, loss=1.525, LR=9.549150281252634e-05
# Validation Loss = 0.000
# Epoch=9, batch = 3000 of 4000, loss=1.643, LR=9.549150281252634e-05
# Validation Loss = 0.322
# Epoch=10, batch = 0 of 4000, loss=1.776, LR=2.4471741852423235e-05
# Validation Loss = 0.068
# Epoch=10, batch = 1000 of 4000, loss=1.500, LR=2.4471741852423235e-05
# Validation Loss = 0.005
# Epoch=10, batch = 2000 of 4000, loss=1.398, LR=2.4471741852423235e-05
# Validation Loss = 0.031
# Epoch=10, batch = 3000 of 4000, loss=1.435, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.105
# Epoch=1, batch = 0 of 4000, loss=1.588, LR=0.001
# Validation Loss = 0.040
# Epoch=1, batch = 1000 of 4000, loss=2.175, LR=0.001
# Validation Loss = 2.559
# Epoch=1, batch = 2000 of 4000, loss=4.185, LR=0.001
# Validation Loss = 1.344
# Epoch=1, batch = 3000 of 4000, loss=2.515, LR=0.001
# Validation Loss = 2.123
# Epoch=2, batch = 0 of 4000, loss=3.121, LR=0.0009938441702975688
# Validation Loss = 0.657
# Epoch=2, batch = 1000 of 4000, loss=2.237, LR=0.0009938441702975688
# Validation Loss = 0.499
# Epoch=2, batch = 2000 of 4000, loss=2.132, LR=0.0009938441702975688
# Validation Loss = 0.021
# Epoch=2, batch = 3000 of 4000, loss=1.764, LR=0.0009938441702975688
# Validation Loss = 0.009
# Epoch=3, batch = 0 of 4000, loss=1.852, LR=0.0009755282581475768
# Validation Loss = 0.402
# Epoch=3, batch = 1000 of 4000, loss=2.123, LR=0.0009755282581475768
# Validation Loss = 1.973
# Epoch=3, batch = 2000 of 4000, loss=2.876, LR=0.0009755282581475768
# Validation Loss = 0.889
# Epoch=3, batch = 3000 of 4000, loss=2.089, LR=0.0009755282581475768
# Validation Loss = 0.007
# Epoch=4, batch = 0 of 4000, loss=1.727, LR=0.0009455032620941839
# Validation Loss = 0.326
# Epoch=4, batch = 1000 of 4000, loss=1.712, LR=0.0009455032620941839
# Validation Loss = 0.541
# Epoch=4, batch = 2000 of 4000, loss=2.302, LR=0.0009455032620941839
# Validation Loss = 0.272
# Epoch=4, batch = 3000 of 4000, loss=1.744, LR=0.0009455032620941839
# Validation Loss = 0.367
# Epoch=5, batch = 0 of 4000, loss=1.829, LR=0.0009045084971874737
# Validation Loss = 0.397
# Epoch=5, batch = 1000 of 4000, loss=3.345, LR=0.0009045084971874737
# Validation Loss = 1.147
# Epoch=5, batch = 2000 of 4000, loss=2.605, LR=0.0009045084971874737
# Validation Loss = 0.248
# Epoch=5, batch = 3000 of 4000, loss=2.082, LR=0.0009045084971874737
# Validation Loss = 0.337
# Epoch=6, batch = 0 of 4000, loss=1.649, LR=0.0008535533905932737
# Validation Loss = 1.382
# Epoch=6, batch = 1000 of 4000, loss=2.524, LR=0.0008535533905932737
# Validation Loss = 0.005
# Epoch=6, batch = 2000 of 4000, loss=1.722, LR=0.0008535533905932737
# Validation Loss = 0.000
# Epoch=6, batch = 3000 of 4000, loss=1.627, LR=0.0008535533905932737
# Validation Loss = 2.003
# Epoch=7, batch = 0 of 4000, loss=2.847, LR=0.0007938926261462366
# Validation Loss = 0.001
# Epoch=7, batch = 1000 of 4000, loss=1.724, LR=0.0007938926261462366
# Validation Loss = 0.006
# Epoch=7, batch = 2000 of 4000, loss=1.627, LR=0.0007938926261462366
# Validation Loss = 1.388
# Epoch=7, batch = 3000 of 4000, loss=2.551, LR=0.0007938926261462366
# Validation Loss = 0.360
# Epoch=8, batch = 0 of 4000, loss=3.792, LR=0.0007269952498697733
# ...
# Validation Loss = 0.059
# Epoch=10, batch = 3000 of 4000, loss=2.015, LR=0.0005782172325201155
# Validation Loss = 0.043
# Epoch=11, batch = 0 of 4000, loss=1.694, LR=0.0005
# Validation Loss = 0.192
# Epoch=11, batch = 1000 of 4000, loss=1.592, LR=0.0005
# Validation Loss = 0.688
# Epoch=11, batch = 2000 of 4000, loss=2.341, LR=0.0005
# Validation Loss = 0.204
# Epoch=11, batch = 3000 of 4000, loss=1.487, LR=0.0005
# Validation Loss = 0.406
# Epoch=12, batch = 0 of 4000, loss=1.934, LR=0.0004217827674798847
# Validation Loss = 0.018
# Epoch=12, batch = 1000 of 4000, loss=1.872, LR=0.0004217827674798847
# Validation Loss = 0.241
# Epoch=12, batch = 2000 of 4000, loss=1.952, LR=0.0004217827674798847
# Validation Loss = 0.001
# Epoch=12, batch = 3000 of 4000, loss=1.694, LR=0.0004217827674798847
# Validation Loss = 0.006
# Epoch=13, batch = 0 of 4000, loss=1.657, LR=0.00034549150281252633
# Validation Loss = 0.211
# Epoch=13, batch = 1000 of 4000, loss=1.729, LR=0.00034549150281252633
# Validation Loss = 0.010
# Epoch=13, batch = 2000 of 4000, loss=1.391, LR=0.00034549150281252633
# Validation Loss = 0.012
# Epoch=13, batch = 3000 of 4000, loss=1.552, LR=0.00034549150281252633
# Validation Loss = 0.139
# Epoch=14, batch = 0 of 4000, loss=1.819, LR=0.00027300475013022663
# Validation Loss = 0.025
# Epoch=14, batch = 1000 of 4000, loss=1.806, LR=0.00027300475013022663
# Validation Loss = 0.003
# Epoch=14, batch = 2000 of 4000, loss=1.502, LR=0.00027300475013022663
# Validation Loss = 0.055
# Epoch=14, batch = 3000 of 4000, loss=1.964, LR=0.00027300475013022663
# Validation Loss = 0.003
# Epoch=15, batch = 0 of 4000, loss=1.720, LR=0.00020610737385376348
# Validation Loss = 0.244
# Epoch=15, batch = 1000 of 4000, loss=1.874, LR=0.00020610737385376348
# Validation Loss = 0.077
# Epoch=15, batch = 2000 of 4000, loss=1.757, LR=0.00020610737385376348
# Validation Loss = 0.164
# Epoch=15, batch = 3000 of 4000, loss=1.603, LR=0.00020610737385376348
# Validation Loss = 0.412
# Epoch=16, batch = 0 of 4000, loss=1.874, LR=0.00014644660940672625
# Validation Loss = 0.002
# Epoch=16, batch = 1000 of 4000, loss=1.579, LR=0.00014644660940672625
# Validation Loss = 0.101
# Epoch=16, batch = 2000 of 4000, loss=1.628, LR=0.00014644660940672625
# Validation Loss = 0.059
# Epoch=16, batch = 3000 of 4000, loss=1.717, LR=0.00014644660940672625
# Validation Loss = 0.011
# Epoch=17, batch = 0 of 4000, loss=1.596, LR=9.549150281252631e-05
# Validation Loss = 0.062
# Epoch=17, batch = 1000 of 4000, loss=1.796, LR=9.549150281252631e-05
# Validation Loss = 0.142
# Epoch=17, batch = 2000 of 4000, loss=1.647, LR=9.549150281252631e-05
# Validation Loss = 0.071
# Epoch=17, batch = 3000 of 4000, loss=1.684, LR=9.549150281252631e-05
# Validation Loss = 0.110
# Epoch=18, batch = 0 of 4000, loss=1.582, LR=5.4496737905816096e-05
# Validation Loss = 0.038
# Epoch=18, batch = 1000 of 4000, loss=1.534, LR=5.4496737905816096e-05
# Validation Loss = 0.049
# Epoch=18, batch = 2000 of 4000, loss=1.570, LR=5.4496737905816096e-05
# Validation Loss = 0.000
# Epoch=18, batch = 3000 of 4000, loss=1.741, LR=5.4496737905816096e-05
# Validation Loss = 0.009
# Epoch=19, batch = 0 of 4000, loss=1.684, LR=2.447174185242323e-05
# Validation Loss = 0.030
# Epoch=19, batch = 1000 of 4000, loss=1.629, LR=2.447174185242323e-05
# Validation Loss = 0.052
# Epoch=19, batch = 2000 of 4000, loss=1.426, LR=2.447174185242323e-05
# Validation Loss = 0.016
# Epoch=19, batch = 3000 of 4000, loss=1.800, LR=2.447174185242323e-05
# Validation Loss = 0.027
# Epoch=20, batch = 0 of 4000, loss=1.735, LR=6.15582970243117e-06
# Validation Loss = 0.021
# Epoch=20, batch = 1000 of 4000, loss=1.442, LR=6.15582970243117e-06
# Validation Loss = 0.033
# Epoch=20, batch = 2000 of 4000, loss=1.496, LR=6.15582970243117e-06
# Validation Loss = 0.037
# Epoch=20, batch = 3000 of 4000, loss=1.494, LR=6.15582970243117e-06
# Finished training model for channel 166H.
# 183+-3V
# Training stage: 1
# Validation Loss = 64479.496
# Epoch=1, batch = 0 of 4000, loss=65677.219, LR=0.001
# Validation Loss = 0.306
# Epoch=1, batch = 1000 of 4000, loss=10.045, LR=0.001
# Validation Loss = 0.198
# Epoch=1, batch = 2000 of 4000, loss=5.907, LR=0.001
# Validation Loss = 2.123
# Epoch=1, batch = 3000 of 4000, loss=5.180, LR=0.001
# Validation Loss = 0.019
# Epoch=2, batch = 0 of 4000, loss=6.408, LR=0.0009045084971874737
# Validation Loss = 1.291
# Epoch=2, batch = 1000 of 4000, loss=4.851, LR=0.0009045084971874737
# Validation Loss = 0.336
# Epoch=2, batch = 2000 of 4000, loss=4.640, LR=0.0009045084971874737
# Validation Loss = 3.728
# Epoch=2, batch = 3000 of 4000, loss=6.149, LR=0.0009045084971874737
# Validation Loss = 1.369
# Epoch=3, batch = 0 of 4000, loss=4.770, LR=0.0006545084971874737
# Validation Loss = 1.310
# Epoch=3, batch = 1000 of 4000, loss=4.368, LR=0.0006545084971874737
# Validation Loss = 11.081
# Epoch=3, batch = 2000 of 4000, loss=9.969, LR=0.0006545084971874737
# Validation Loss = 1.746
# Epoch=3, batch = 3000 of 4000, loss=3.786, LR=0.0006545084971874737
# Validation Loss = 0.958
# Epoch=4, batch = 0 of 4000, loss=4.010, LR=0.00034549150281252633
# Validation Loss = 0.002
# Epoch=4, batch = 1000 of 4000, loss=4.499, LR=0.00034549150281252633
# Validation Loss = 0.117
# Epoch=4, batch = 2000 of 4000, loss=4.647, LR=0.00034549150281252633
# Validation Loss = 0.378
# Epoch=4, batch = 3000 of 4000, loss=3.871, LR=0.00034549150281252633
# Validation Loss = 0.044
# Epoch=5, batch = 0 of 4000, loss=3.959, LR=9.549150281252633e-05
# Validation Loss = 0.281
# Epoch=5, batch = 1000 of 4000, loss=3.514, LR=9.549150281252633e-05
# Validation Loss = 0.274
# Epoch=5, batch = 2000 of 4000, loss=3.575, LR=9.549150281252633e-05
# Validation Loss = 0.316
# Epoch=5, batch = 3000 of 4000, loss=3.621, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.058
# Epoch=1, batch = 0 of 4000, loss=3.487, LR=0.001
# Validation Loss = 1.282
# Epoch=1, batch = 1000 of 4000, loss=4.235, LR=0.001
# Validation Loss = 3.126
# Epoch=1, batch = 2000 of 4000, loss=4.671, LR=0.001
# Validation Loss = 5.297
# Epoch=1, batch = 3000 of 4000, loss=6.186, LR=0.001
# Validation Loss = 1.941
# Epoch=2, batch = 0 of 4000, loss=3.748, LR=0.0009755282581475768
# Validation Loss = 3.360
# Epoch=2, batch = 1000 of 4000, loss=5.168, LR=0.0009755282581475768
# Validation Loss = 3.974
# Epoch=2, batch = 2000 of 4000, loss=5.394, LR=0.0009755282581475768
# Validation Loss = 2.145
# Epoch=2, batch = 3000 of 4000, loss=3.890, LR=0.0009755282581475768
# Validation Loss = 3.176
# Epoch=3, batch = 0 of 4000, loss=5.821, LR=0.0009045084971874736
# Validation Loss = 0.274
# Epoch=3, batch = 1000 of 4000, loss=3.832, LR=0.0009045084971874736
# Validation Loss = 0.136
# Epoch=3, batch = 2000 of 4000, loss=3.914, LR=0.0009045084971874736
# Validation Loss = 6.516
# Epoch=3, batch = 3000 of 4000, loss=7.991, LR=0.0009045084971874736
# Validation Loss = 0.921
# Epoch=4, batch = 0 of 4000, loss=6.479, LR=0.0007938926261462366
# Validation Loss = 1.404
# Epoch=4, batch = 1000 of 4000, loss=3.800, LR=0.0007938926261462366
# Validation Loss = 2.000
# Epoch=4, batch = 2000 of 4000, loss=6.783, LR=0.0007938926261462366
# Validation Loss = 0.010
# Epoch=4, batch = 3000 of 4000, loss=4.004, LR=0.0007938926261462366
# Validation Loss = 0.130
# Epoch=5, batch = 0 of 4000, loss=3.793, LR=0.0006545084971874737
# Validation Loss = 0.789
# Epoch=5, batch = 1000 of 4000, loss=3.713, LR=0.0006545084971874737
# Validation Loss = 1.883
# Epoch=5, batch = 2000 of 4000, loss=4.418, LR=0.0006545084971874737
# Validation Loss = 0.502
# Epoch=5, batch = 3000 of 4000, loss=3.638, LR=0.0006545084971874737
# Validation Loss = 2.561
# Epoch=6, batch = 0 of 4000, loss=4.953, LR=0.0005
# Validation Loss = 0.045
# Epoch=6, batch = 1000 of 4000, loss=3.330, LR=0.0005
# Validation Loss = 0.002
# Epoch=6, batch = 2000 of 4000, loss=4.164, LR=0.0005
# Validation Loss = 0.108
# Epoch=6, batch = 3000 of 4000, loss=3.442, LR=0.0005
# Validation Loss = 0.695
# Epoch=7, batch = 0 of 4000, loss=4.919, LR=0.00034549150281252633
# Validation Loss = 1.759
# Epoch=7, batch = 1000 of 4000, loss=4.123, LR=0.00034549150281252633
# Validation Loss = 0.049
# Epoch=7, batch = 2000 of 4000, loss=3.783, LR=0.00034549150281252633
# Validation Loss = 1.220
# Epoch=7, batch = 3000 of 4000, loss=4.285, LR=0.00034549150281252633
# Validation Loss = 0.339
# Epoch=8, batch = 0 of 4000, loss=3.689, LR=0.0002061073738537635
# Validation Loss = 0.270
# Epoch=8, batch = 1000 of 4000, loss=3.363, LR=0.0002061073738537635
# Validation Loss = 0.358
# Epoch=8, batch = 2000 of 4000, loss=3.680, LR=0.0002061073738537635
# Validation Loss = 0.001
# Epoch=8, batch = 3000 of 4000, loss=3.519, LR=0.0002061073738537635
# Validation Loss = 0.036
# Epoch=9, batch = 0 of 4000, loss=3.598, LR=9.549150281252634e-05
# Validation Loss = 0.039
# Epoch=9, batch = 1000 of 4000, loss=3.392, LR=9.549150281252634e-05
# Validation Loss = 0.051
# Epoch=9, batch = 2000 of 4000, loss=3.358, LR=9.549150281252634e-05
# Validation Loss = 0.148
# Epoch=9, batch = 3000 of 4000, loss=3.539, LR=9.549150281252634e-05
# Validation Loss = 0.108
# Epoch=10, batch = 0 of 4000, loss=3.351, LR=2.4471741852423235e-05
# Validation Loss = 0.028
# Epoch=10, batch = 1000 of 4000, loss=3.286, LR=2.4471741852423235e-05
# Validation Loss = 0.001
# Epoch=10, batch = 2000 of 4000, loss=3.464, LR=2.4471741852423235e-05
# Validation Loss = 0.076
# Epoch=10, batch = 3000 of 4000, loss=3.100, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.129
# Epoch=1, batch = 0 of 4000, loss=3.479, LR=0.001
# Validation Loss = 0.008
# Epoch=1, batch = 1000 of 4000, loss=4.473, LR=0.001
# Validation Loss = 1.381
# Epoch=1, batch = 2000 of 4000, loss=6.016, LR=0.001
# Validation Loss = 2.749
# Epoch=1, batch = 3000 of 4000, loss=7.507, LR=0.001
# Validation Loss = 0.598
# Epoch=2, batch = 0 of 4000, loss=4.256, LR=0.0009938441702975688
# Validation Loss = 1.095
# Epoch=2, batch = 1000 of 4000, loss=4.380, LR=0.0009938441702975688
# Validation Loss = 4.509
# Epoch=2, batch = 2000 of 4000, loss=6.807, LR=0.0009938441702975688
# Validation Loss = 0.020
# Epoch=2, batch = 3000 of 4000, loss=3.968, LR=0.0009938441702975688
# Validation Loss = 1.414
# Epoch=3, batch = 0 of 4000, loss=4.982, LR=0.0009755282581475768
# Validation Loss = 0.381
# Epoch=3, batch = 1000 of 4000, loss=4.348, LR=0.0009755282581475768
# Validation Loss = 0.320
# Epoch=3, batch = 2000 of 4000, loss=3.874, LR=0.0009755282581475768
# Validation Loss = 2.324
# Epoch=3, batch = 3000 of 4000, loss=5.434, LR=0.0009755282581475768
# Validation Loss = 1.831
# Epoch=4, batch = 0 of 4000, loss=4.496, LR=0.0009455032620941839
# Validation Loss = 0.015
# Epoch=4, batch = 1000 of 4000, loss=3.984, LR=0.0009455032620941839
# Validation Loss = 0.887
# Epoch=4, batch = 2000 of 4000, loss=3.874, LR=0.0009455032620941839
# Validation Loss = 0.693
# Epoch=4, batch = 3000 of 4000, loss=3.834, LR=0.0009455032620941839
# Validation Loss = 1.227
# Epoch=5, batch = 0 of 4000, loss=4.127, LR=0.0009045084971874737
# Validation Loss = 1.287
# Epoch=5, batch = 1000 of 4000, loss=3.776, LR=0.0009045084971874737
# Validation Loss = 0.000
# Epoch=5, batch = 2000 of 4000, loss=3.580, LR=0.0009045084971874737
# Validation Loss = 1.519
# Epoch=5, batch = 3000 of 4000, loss=3.945, LR=0.0009045084971874737
# Validation Loss = 0.291
# Epoch=6, batch = 0 of 4000, loss=3.498, LR=0.0008535533905932737
# Validation Loss = 0.095
# Epoch=6, batch = 1000 of 4000, loss=3.577, LR=0.0008535533905932737
# Validation Loss = 1.962
# Epoch=6, batch = 2000 of 4000, loss=4.119, LR=0.0008535533905932737
# Validation Loss = 0.266
# Epoch=6, batch = 3000 of 4000, loss=3.410, LR=0.0008535533905932737
# Validation Loss = 8.880
# Epoch=7, batch = 0 of 4000, loss=9.204, LR=0.0007938926261462366
# Validation Loss = 0.009
# Epoch=7, batch = 1000 of 4000, loss=3.500, LR=0.0007938926261462366
# Validation Loss = 0.142
# Epoch=7, batch = 2000 of 4000, loss=3.517, LR=0.0007938926261462366
# Validation Loss = 0.043
# Epoch=7, batch = 3000 of 4000, loss=3.722, LR=0.0007938926261462366
# Validation Loss = 0.333
# Epoch=8, batch = 0 of 4000, loss=3.611, LR=0.0007269952498697733
# Validation Loss = 0.012
# Epoch=8, batch = 1000 of 4000, loss=4.035, LR=0.0007269952498697733
# Validation Loss = 0.005
# Epoch=8, batch = 2000 of 4000, loss=3.751, LR=0.0007269952498697733
# Validation Loss = 0.018
# Epoch=8, batch = 3000 of 4000, loss=3.107, LR=0.0007269952498697733
# Validation Loss = 0.681
# Epoch=9, batch = 0 of 4000, loss=3.478, LR=0.0006545084971874737
# Validation Loss = 0.001
# Epoch=9, batch = 1000 of 4000, loss=3.749, LR=0.0006545084971874737
# Validation Loss = 1.104
# Epoch=9, batch = 2000 of 4000, loss=5.879, LR=0.0006545084971874737
# Validation Loss = 0.070
# Epoch=9, batch = 3000 of 4000, loss=4.008, LR=0.0006545084971874737
# Validation Loss = 0.420
# Epoch=10, batch = 0 of 4000, loss=3.507, LR=0.0005782172325201155
# Validation Loss = 0.035
# Epoch=10, batch = 1000 of 4000, loss=3.491, LR=0.0005782172325201155
# Validation Loss = 0.023
# Epoch=10, batch = 2000 of 4000, loss=4.053, LR=0.0005782172325201155
# Validation Loss = 0.865
# Epoch=10, batch = 3000 of 4000, loss=3.775, LR=0.0005782172325201155
# Validation Loss = 0.752
# Epoch=11, batch = 0 of 4000, loss=3.694, LR=0.0005
# Validation Loss = 0.684
# Epoch=11, batch = 1000 of 4000, loss=3.565, LR=0.0005
# Validation Loss = 0.056
# Epoch=11, batch = 2000 of 4000, loss=3.626, LR=0.0005
# Validation Loss = 0.445
# Epoch=11, batch = 3000 of 4000, loss=3.498, LR=0.0005
# Validation Loss = 0.003
# Epoch=12, batch = 0 of 4000, loss=3.754, LR=0.0004217827674798847
# Validation Loss = 1.887
# Epoch=12, batch = 1000 of 4000, loss=4.387, LR=0.0004217827674798847
# Validation Loss = 0.004
# Epoch=12, batch = 2000 of 4000, loss=3.746, LR=0.0004217827674798847
# Validation Loss = 0.283
# Epoch=12, batch = 3000 of 4000, loss=3.646, LR=0.0004217827674798847
# Validation Loss = 0.556
# Epoch=13, batch = 0 of 4000, loss=3.526, LR=0.00034549150281252633
# Validation Loss = 0.177
# Epoch=13, batch = 1000 of 4000, loss=3.446, LR=0.00034549150281252633
# Validation Loss = 0.009
# Epoch=13, batch = 2000 of 4000, loss=3.459, LR=0.00034549150281252633
# Validation Loss = 0.118
# Epoch=13, batch = 3000 of 4000, loss=3.312, LR=0.00034549150281252633
# Validation Loss = 0.179
# Epoch=14, batch = 0 of 4000, loss=3.481, LR=0.00027300475013022663
# Validation Loss = 0.886
# Epoch=14, batch = 1000 of 4000, loss=3.729, LR=0.00027300475013022663
# Validation Loss = 0.032
# Epoch=14, batch = 2000 of 4000, loss=3.225, LR=0.00027300475013022663
# Validation Loss = 0.381
# Epoch=14, batch = 3000 of 4000, loss=3.559, LR=0.00027300475013022663
# Validation Loss = 0.087
# Epoch=15, batch = 0 of 4000, loss=2.942, LR=0.00020610737385376348
# Validation Loss = 0.571
# Epoch=15, batch = 1000 of 4000, loss=3.397, LR=0.00020610737385376348
# Validation Loss = 0.239
# Epoch=15, batch = 2000 of 4000, loss=3.383, LR=0.00020610737385376348
# Validation Loss = 0.044
# Epoch=15, batch = 3000 of 4000, loss=3.234, LR=0.00020610737385376348
# Validation Loss = 0.006
# Epoch=16, batch = 0 of 4000, loss=3.317, LR=0.00014644660940672625
# Validation Loss = 0.218
# Epoch=16, batch = 1000 of 4000, loss=2.984, LR=0.00014644660940672625
# Validation Loss = 0.024
# Epoch=16, batch = 2000 of 4000, loss=3.106, LR=0.00014644660940672625
# Validation Loss = 0.067
# Epoch=16, batch = 3000 of 4000, loss=3.164, LR=0.00014644660940672625
# Validation Loss = 0.868
# Epoch=17, batch = 0 of 4000, loss=3.386, LR=9.549150281252631e-05
# Validation Loss = 0.179
# Epoch=17, batch = 1000 of 4000, loss=3.186, LR=9.549150281252631e-05
# Validation Loss = 0.047
# Epoch=17, batch = 2000 of 4000, loss=3.578, LR=9.549150281252631e-05
# Validation Loss = 0.524
# Epoch=17, batch = 3000 of 4000, loss=3.287, LR=9.549150281252631e-05
# Validation Loss = 0.056
# Epoch=18, batch = 0 of 4000, loss=3.169, LR=5.4496737905816096e-05
# Validation Loss = 0.193
# Epoch=18, batch = 1000 of 4000, loss=3.340, LR=5.4496737905816096e-05
# Validation Loss = 0.042
# Epoch=18, batch = 2000 of 4000, loss=3.403, LR=5.4496737905816096e-05
# Validation Loss = 0.016
# Epoch=18, batch = 3000 of 4000, loss=3.000, LR=5.4496737905816096e-05
# Validation Loss = 0.351
# Epoch=19, batch = 0 of 4000, loss=3.331, LR=2.447174185242323e-05
# Validation Loss = 0.147
# Epoch=19, batch = 1000 of 4000, loss=3.101, LR=2.447174185242323e-05
# Validation Loss = 0.051
# Epoch=19, batch = 2000 of 4000, loss=3.202, LR=2.447174185242323e-05

# %%
#General parameters:
input_size = nchans - 1 + 1 #Remaining channels + surface type

# %%
'''

GMI CHANNEL PREDICTION MODEL:
    2: Non-Ocean Surfaces

'''

with xr.open_dataset(f'../../GMI/GPM/training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = sfctype > 1

    Tbs = f.Tbs.values[correct_sfc,:]
    sfctype = sfctype[correct_sfc]

Tbs = Tbs[:,[0,1,4,5,6,7,8,9,10,11,12]]

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

sfctype_train = sfctype[train_indcs].astype(np.float32)
sfctype_test  = sfctype[test_indcs].astype(np.float32)
sfctype_val   = sfctype[val_indcs].astype(np.float32)

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train, shuffled_indcs = array_funcs.shuffle_data(Tbs_train, axis=0, return_indcs=True)
sfctype_train = sfctype_train[shuffled_indcs]

# %%
sfctype_train, sfctype_test, sfctype_val
# Out:
# (array([ 8.,  5.,  2., ...,  5.,  9., 17.],
#        shape=(14253019,), dtype=float32),
#  array([10., 10., 10., ..., 18., 18., 18.], shape=(1781627,), dtype=float32),
#  array([18., 18., 18., ...,  2.,  2.,  2.], shape=(1781628,), dtype=float32))

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    print(channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)

    x_train = np.concatenate((x_train, sfctype_train[:,None]), axis=1)
    x_test  = np.concatenate((x_test,  sfctype_test[:,None]), axis=1)
    x_val   = np.concatenate((x_val,   sfctype_val[:,None]), axis=1)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_nonocean_no19.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_nonocean_no19.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 10V
# Training stage: 1
# Validation Loss = 63858.691
# Epoch=1, batch = 0 of 14253, loss=70974.477, LR=0.001
# Validation Loss = 8.069
# Epoch=1, batch = 1000 of 14253, loss=12.190, LR=0.001
# Validation Loss = 15.629
# Epoch=1, batch = 2000 of 14253, loss=10.634, LR=0.001
# Validation Loss = 5.244
# Epoch=1, batch = 3000 of 14253, loss=9.045, LR=0.001
# Validation Loss = 0.939
# Epoch=1, batch = 4000 of 14253, loss=12.535, LR=0.001
# Validation Loss = 18.422
# Epoch=1, batch = 5000 of 14253, loss=8.451, LR=0.001
# Validation Loss = 23.253
# Epoch=1, batch = 6000 of 14253, loss=9.316, LR=0.001
# Validation Loss = 4.673
# Epoch=1, batch = 7000 of 14253, loss=7.884, LR=0.001
# Validation Loss = 0.492
# Epoch=1, batch = 8000 of 14253, loss=12.911, LR=0.001
# Validation Loss = 5.700
# Epoch=1, batch = 9000 of 14253, loss=6.982, LR=0.001
# Validation Loss = 2.507
# Epoch=1, batch = 10000 of 14253, loss=6.714, LR=0.001
# Validation Loss = 0.855
# Epoch=1, batch = 11000 of 14253, loss=7.680, LR=0.001
# Validation Loss = 12.192
# Epoch=1, batch = 12000 of 14253, loss=6.889, LR=0.001
# Validation Loss = 3.553
# Epoch=1, batch = 13000 of 14253, loss=5.576, LR=0.001
# Validation Loss = 2.241
# Epoch=1, batch = 14000 of 14253, loss=8.602, LR=0.001
# Validation Loss = 5.967
# Epoch=2, batch = 0 of 14253, loss=5.416, LR=0.0009045084971874737
# Validation Loss = 2.630
# Epoch=2, batch = 1000 of 14253, loss=5.041, LR=0.0009045084971874737
# Validation Loss = 3.304
# Epoch=2, batch = 2000 of 14253, loss=5.102, LR=0.0009045084971874737
# Validation Loss = 18.051
# Epoch=2, batch = 3000 of 14253, loss=6.734, LR=0.0009045084971874737
# Validation Loss = 1.453
# Epoch=2, batch = 4000 of 14253, loss=5.619, LR=0.0009045084971874737
# Validation Loss = 6.663
# Epoch=2, batch = 5000 of 14253, loss=5.532, LR=0.0009045084971874737
# Validation Loss = 2.647
# Epoch=2, batch = 6000 of 14253, loss=5.757, LR=0.0009045084971874737
# Validation Loss = 5.065
# Epoch=2, batch = 7000 of 14253, loss=3.903, LR=0.0009045084971874737
# Validation Loss = 6.670
# Epoch=2, batch = 8000 of 14253, loss=6.085, LR=0.0009045084971874737
# Validation Loss = 4.121
# Epoch=2, batch = 9000 of 14253, loss=5.176, LR=0.0009045084971874737
# Validation Loss = 14.006
# Epoch=2, batch = 10000 of 14253, loss=5.439, LR=0.0009045084971874737
# Validation Loss = 1.239
# Epoch=2, batch = 11000 of 14253, loss=5.928, LR=0.0009045084971874737
# Validation Loss = 11.666
# Epoch=2, batch = 12000 of 14253, loss=5.418, LR=0.0009045084971874737
# Validation Loss = 5.781
# Epoch=2, batch = 13000 of 14253, loss=5.852, LR=0.0009045084971874737
# Validation Loss = 8.551
# Epoch=2, batch = 14000 of 14253, loss=4.526, LR=0.0009045084971874737
# Validation Loss = 14.342
# Epoch=3, batch = 0 of 14253, loss=6.614, LR=0.0006545084971874737
# Validation Loss = 5.632
# Epoch=3, batch = 1000 of 14253, loss=5.573, LR=0.0006545084971874737
# Validation Loss = 4.047
# Epoch=3, batch = 2000 of 14253, loss=5.194, LR=0.0006545084971874737
# Validation Loss = 1.336
# Epoch=3, batch = 3000 of 14253, loss=4.771, LR=0.0006545084971874737
# Validation Loss = 6.512
# Epoch=3, batch = 4000 of 14253, loss=4.206, LR=0.0006545084971874737
# Validation Loss = 7.325
# Epoch=3, batch = 5000 of 14253, loss=5.448, LR=0.0006545084971874737
# Validation Loss = 2.111
# Epoch=3, batch = 6000 of 14253, loss=4.206, LR=0.0006545084971874737
# Validation Loss = 4.455
# Epoch=3, batch = 7000 of 14253, loss=4.885, LR=0.0006545084971874737
# Validation Loss = 3.167
# Epoch=3, batch = 8000 of 14253, loss=4.844, LR=0.0006545084971874737
# Validation Loss = 3.653
# Epoch=3, batch = 9000 of 14253, loss=4.590, LR=0.0006545084971874737
# Validation Loss = 5.023
# Epoch=3, batch = 10000 of 14253, loss=4.450, LR=0.0006545084971874737
# Validation Loss = 4.816
# Epoch=3, batch = 11000 of 14253, loss=4.665, LR=0.0006545084971874737
# Validation Loss = 11.458
# Epoch=3, batch = 12000 of 14253, loss=4.921, LR=0.0006545084971874737
# Validation Loss = 8.194
# Epoch=3, batch = 13000 of 14253, loss=4.523, LR=0.0006545084971874737
# Validation Loss = 7.205
# Epoch=3, batch = 14000 of 14253, loss=4.169, LR=0.0006545084971874737
# Validation Loss = 7.974
# Epoch=4, batch = 0 of 14253, loss=4.016, LR=0.00034549150281252633
# Validation Loss = 6.262
# Epoch=4, batch = 1000 of 14253, loss=4.090, LR=0.00034549150281252633
# Validation Loss = 1.545
# Epoch=4, batch = 2000 of 14253, loss=4.908, LR=0.00034549150281252633
# Validation Loss = 5.855
# Epoch=4, batch = 3000 of 14253, loss=4.233, LR=0.00034549150281252633
# Validation Loss = 3.757
# Epoch=4, batch = 4000 of 14253, loss=4.378, LR=0.00034549150281252633
# Validation Loss = 4.489
# Epoch=4, batch = 5000 of 14253, loss=4.015, LR=0.00034549150281252633
# Validation Loss = 3.378
# Epoch=4, batch = 6000 of 14253, loss=4.094, LR=0.00034549150281252633
# Validation Loss = 2.632
# Epoch=4, batch = 7000 of 14253, loss=4.350, LR=0.00034549150281252633
# Validation Loss = 9.869
# Epoch=4, batch = 8000 of 14253, loss=4.486, LR=0.00034549150281252633
# Validation Loss = 2.902
# Epoch=4, batch = 9000 of 14253, loss=4.073, LR=0.00034549150281252633
# Validation Loss = 1.844
# Epoch=4, batch = 10000 of 14253, loss=4.155, LR=0.00034549150281252633
# Validation Loss = 7.031
# Epoch=4, batch = 11000 of 14253, loss=4.523, LR=0.00034549150281252633
# Validation Loss = 2.828
# Epoch=4, batch = 12000 of 14253, loss=3.806, LR=0.00034549150281252633
# Validation Loss = 4.281
# Epoch=4, batch = 13000 of 14253, loss=4.257, LR=0.00034549150281252633
# Validation Loss = 8.111
# Epoch=4, batch = 14000 of 14253, loss=4.961, LR=0.00034549150281252633
# Validation Loss = 4.930
# Epoch=5, batch = 0 of 14253, loss=4.482, LR=9.549150281252633e-05
# Validation Loss = 2.923
# Epoch=5, batch = 1000 of 14253, loss=3.968, LR=9.549150281252633e-05
# Validation Loss = 2.057
# Epoch=5, batch = 2000 of 14253, loss=3.506, LR=9.549150281252633e-05
# Validation Loss = 4.929
# Epoch=5, batch = 3000 of 14253, loss=4.060, LR=9.549150281252633e-05
# Validation Loss = 4.892
# Epoch=5, batch = 4000 of 14253, loss=4.362, LR=9.549150281252633e-05
# Validation Loss = 2.115
# Epoch=5, batch = 5000 of 14253, loss=3.948, LR=9.549150281252633e-05
# Validation Loss = 5.383
# Epoch=5, batch = 6000 of 14253, loss=4.225, LR=9.549150281252633e-05
# Validation Loss = 2.826
# Epoch=5, batch = 7000 of 14253, loss=3.573, LR=9.549150281252633e-05
# Validation Loss = 3.968
# Epoch=5, batch = 8000 of 14253, loss=3.827, LR=9.549150281252633e-05
# Validation Loss = 5.535
# Epoch=5, batch = 9000 of 14253, loss=3.975, LR=9.549150281252633e-05
# Validation Loss = 5.516
# Epoch=5, batch = 10000 of 14253, loss=4.326, LR=9.549150281252633e-05
# Validation Loss = 4.005
# Epoch=5, batch = 11000 of 14253, loss=4.029, LR=9.549150281252633e-05
# Validation Loss = 4.963
# Epoch=5, batch = 12000 of 14253, loss=3.708, LR=9.549150281252633e-05
# Validation Loss = 3.757
# Epoch=5, batch = 13000 of 14253, loss=4.576, LR=9.549150281252633e-05
# Validation Loss = 5.035
# Epoch=5, batch = 14000 of 14253, loss=3.543, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 4.729
# Epoch=1, batch = 0 of 14253, loss=4.135, LR=0.001
# Validation Loss = 10.915
# Epoch=1, batch = 1000 of 14253, loss=5.148, LR=0.001
# Validation Loss = 6.217
# Epoch=1, batch = 2000 of 14253, loss=4.823, LR=0.001
# Validation Loss = 2.692
# Epoch=1, batch = 3000 of 14253, loss=7.011, LR=0.001
# Validation Loss = 7.107
# Epoch=1, batch = 4000 of 14253, loss=4.513, LR=0.001
# Validation Loss = 0.947
# Epoch=1, batch = 5000 of 14253, loss=8.432, LR=0.001
# Validation Loss = 5.062
# Epoch=1, batch = 6000 of 14253, loss=5.370, LR=0.001
# Validation Loss = 9.465
# Epoch=1, batch = 7000 of 14253, loss=4.401, LR=0.001
# Validation Loss = 6.868
# Epoch=1, batch = 8000 of 14253, loss=3.793, LR=0.001
# Validation Loss = 7.764
# Epoch=1, batch = 9000 of 14253, loss=4.347, LR=0.001
# Validation Loss = 11.871
# Epoch=1, batch = 10000 of 14253, loss=4.745, LR=0.001
# Validation Loss = 2.984
# Epoch=1, batch = 11000 of 14253, loss=4.034, LR=0.001
# Validation Loss = 7.118
# Epoch=1, batch = 12000 of 14253, loss=4.745, LR=0.001
# Validation Loss = 0.147
# Epoch=1, batch = 13000 of 14253, loss=6.516, LR=0.001
# Validation Loss = 2.862
# Epoch=1, batch = 14000 of 14253, loss=4.622, LR=0.001
# Validation Loss = 0.157
# Epoch=2, batch = 0 of 14253, loss=6.897, LR=0.0009755282581475768
# Validation Loss = 2.637
# Epoch=2, batch = 1000 of 14253, loss=5.734, LR=0.0009755282581475768
# Validation Loss = 11.499
# Epoch=2, batch = 2000 of 14253, loss=5.197, LR=0.0009755282581475768
# Validation Loss = 0.739
# Epoch=2, batch = 3000 of 14253, loss=5.830, LR=0.0009755282581475768
# Validation Loss = 14.782
# Epoch=2, batch = 4000 of 14253, loss=5.814, LR=0.0009755282581475768
# Validation Loss = 19.868
# Epoch=2, batch = 5000 of 14253, loss=7.725, LR=0.0009755282581475768
# Validation Loss = 6.898
# Epoch=2, batch = 6000 of 14253, loss=4.557, LR=0.0009755282581475768
# Validation Loss = 2.405
# Epoch=2, batch = 7000 of 14253, loss=4.509, LR=0.0009755282581475768
# Validation Loss = 0.475
# Epoch=2, batch = 8000 of 14253, loss=4.994, LR=0.0009755282581475768
# Validation Loss = 15.458
# Epoch=2, batch = 9000 of 14253, loss=7.407, LR=0.0009755282581475768
# Validation Loss = 7.078
# Epoch=2, batch = 10000 of 14253, loss=4.864, LR=0.0009755282581475768
# Validation Loss = 4.592
# Epoch=2, batch = 11000 of 14253, loss=4.253, LR=0.0009755282581475768
# Validation Loss = 14.830
# Epoch=2, batch = 12000 of 14253, loss=5.383, LR=0.0009755282581475768
# Validation Loss = 6.248
# Epoch=2, batch = 13000 of 14253, loss=4.076, LR=0.0009755282581475768
# Validation Loss = 1.238
# Epoch=2, batch = 14000 of 14253, loss=5.345, LR=0.0009755282581475768
# Validation Loss = 1.899
# Epoch=3, batch = 0 of 14253, loss=3.742, LR=0.0009045084971874736
# Validation Loss = 11.786
# Epoch=3, batch = 1000 of 14253, loss=4.161, LR=0.0009045084971874736
# Validation Loss = 0.429
# Epoch=3, batch = 2000 of 14253, loss=4.542, LR=0.0009045084971874736
# Validation Loss = 1.978
# Epoch=3, batch = 3000 of 14253, loss=3.954, LR=0.0009045084971874736
# Validation Loss = 7.197
# Epoch=3, batch = 4000 of 14253, loss=4.225, LR=0.0009045084971874736
# Validation Loss = 3.310
# Epoch=3, batch = 5000 of 14253, loss=3.906, LR=0.0009045084971874736
# Validation Loss = 0.097
# Epoch=3, batch = 6000 of 14253, loss=4.951, LR=0.0009045084971874736
# Validation Loss = 4.707
# Epoch=3, batch = 7000 of 14253, loss=4.971, LR=0.0009045084971874736
# Validation Loss = 1.233
# Epoch=3, batch = 8000 of 14253, loss=4.707, LR=0.0009045084971874736
# Validation Loss = 2.122
# Epoch=3, batch = 9000 of 14253, loss=4.265, LR=0.0009045084971874736
# Validation Loss = 12.187
# Epoch=3, batch = 10000 of 14253, loss=6.575, LR=0.0009045084971874736
# Validation Loss = 6.893
# Epoch=3, batch = 11000 of 14253, loss=4.562, LR=0.0009045084971874736
# Validation Loss = 2.300
# Epoch=3, batch = 12000 of 14253, loss=4.671, LR=0.0009045084971874736
# Validation Loss = 3.306
# Epoch=3, batch = 13000 of 14253, loss=4.485, LR=0.0009045084971874736
# Validation Loss = 2.546
# Epoch=3, batch = 14000 of 14253, loss=4.322, LR=0.0009045084971874736
# Validation Loss = 2.885
# Epoch=4, batch = 0 of 14253, loss=3.859, LR=0.0007938926261462366
# Validation Loss = 5.288
# Epoch=4, batch = 1000 of 14253, loss=5.275, LR=0.0007938926261462366
# Validation Loss = 3.296
# Epoch=4, batch = 2000 of 14253, loss=4.839, LR=0.0007938926261462366
# Validation Loss = 3.304
# Epoch=4, batch = 3000 of 14253, loss=4.327, LR=0.0007938926261462366
# Validation Loss = 4.056
# Epoch=4, batch = 4000 of 14253, loss=4.253, LR=0.0007938926261462366
# Validation Loss = 0.769
# Epoch=4, batch = 5000 of 14253, loss=4.048, LR=0.0007938926261462366
# Validation Loss = 2.336
# Epoch=4, batch = 6000 of 14253, loss=4.791, LR=0.0007938926261462366
# Validation Loss = 0.002
# Epoch=4, batch = 7000 of 14253, loss=5.662, LR=0.0007938926261462366
# Validation Loss = 3.797
# Epoch=4, batch = 8000 of 14253, loss=4.811, LR=0.0007938926261462366
# Validation Loss = 3.913
# Epoch=4, batch = 9000 of 14253, loss=4.284, LR=0.0007938926261462366
# Validation Loss = 0.994
# Epoch=4, batch = 10000 of 14253, loss=3.941, LR=0.0007938926261462366
# Validation Loss = 5.001
# Epoch=4, batch = 11000 of 14253, loss=4.495, LR=0.0007938926261462366
# Validation Loss = 1.242
# Epoch=4, batch = 12000 of 14253, loss=4.249, LR=0.0007938926261462366
# Validation Loss = 4.271
# Epoch=4, batch = 13000 of 14253, loss=3.900, LR=0.0007938926261462366
# Validation Loss = 0.206
# Epoch=4, batch = 14000 of 14253, loss=4.809, LR=0.0007938926261462366
# Validation Loss = 2.153
# Epoch=5, batch = 0 of 14253, loss=4.030, LR=0.0006545084971874737
# Validation Loss = 1.896
# Epoch=5, batch = 1000 of 14253, loss=3.877, LR=0.0006545084971874737
# Validation Loss = 1.213
# Epoch=5, batch = 2000 of 14253, loss=4.145, LR=0.0006545084971874737
# Validation Loss = 0.114
# Epoch=5, batch = 3000 of 14253, loss=3.993, LR=0.0006545084971874737
# Validation Loss = 2.370
# Epoch=5, batch = 4000 of 14253, loss=4.090, LR=0.0006545084971874737
# Validation Loss = 1.718
# Epoch=5, batch = 5000 of 14253, loss=3.657, LR=0.0006545084971874737
# Validation Loss = 1.447
# Epoch=5, batch = 6000 of 14253, loss=3.930, LR=0.0006545084971874737
# Validation Loss = 1.594
# Epoch=5, batch = 7000 of 14253, loss=3.815, LR=0.0006545084971874737
# Validation Loss = 0.765
# Epoch=5, batch = 8000 of 14253, loss=3.772, LR=0.0006545084971874737
# Validation Loss = 2.742
# Epoch=5, batch = 9000 of 14253, loss=3.997, LR=0.0006545084971874737
# Validation Loss = 0.131
# Epoch=5, batch = 10000 of 14253, loss=4.074, LR=0.0006545084971874737
# Validation Loss = 1.878
# Epoch=5, batch = 11000 of 14253, loss=3.939, LR=0.0006545084971874737
# Validation Loss = 2.059
# Epoch=5, batch = 12000 of 14253, loss=4.791, LR=0.0006545084971874737
# Validation Loss = 1.676
# Epoch=5, batch = 13000 of 14253, loss=4.123, LR=0.0006545084971874737
# Validation Loss = 1.093
# Epoch=5, batch = 14000 of 14253, loss=4.440, LR=0.0006545084971874737
# Validation Loss = 0.118
# Epoch=6, batch = 0 of 14253, loss=5.136, LR=0.0005
# Validation Loss = 3.649
# Epoch=6, batch = 1000 of 14253, loss=3.973, LR=0.0005
# Validation Loss = 2.374
# Epoch=6, batch = 2000 of 14253, loss=4.376, LR=0.0005
# Validation Loss = 3.380
# Epoch=6, batch = 3000 of 14253, loss=3.867, LR=0.0005
# Validation Loss = 2.060
# Epoch=6, batch = 4000 of 14253, loss=3.565, LR=0.0005
# Validation Loss = 1.445
# Epoch=6, batch = 5000 of 14253, loss=3.498, LR=0.0005
# Validation Loss = 1.262
# Epoch=6, batch = 6000 of 14253, loss=3.990, LR=0.0005
# Validation Loss = 3.500
# Epoch=6, batch = 7000 of 14253, loss=5.171, LR=0.0005
# Validation Loss = 1.072
# Epoch=6, batch = 8000 of 14253, loss=3.942, LR=0.0005
# Validation Loss = 0.016
# Epoch=6, batch = 9000 of 14253, loss=4.215, LR=0.0005
# Validation Loss = 2.666
# Epoch=6, batch = 10000 of 14253, loss=4.270, LR=0.0005
# Validation Loss = 0.402
# Epoch=6, batch = 11000 of 14253, loss=3.996, LR=0.0005
# Validation Loss = 3.184
# Epoch=6, batch = 12000 of 14253, loss=3.983, LR=0.0005
# Validation Loss = 2.666
# Epoch=6, batch = 13000 of 14253, loss=4.237, LR=0.0005
# Validation Loss = 1.826
# Epoch=6, batch = 14000 of 14253, loss=4.115, LR=0.0005
# Validation Loss = 3.261
# Epoch=7, batch = 0 of 14253, loss=4.317, LR=0.00034549150281252633
# Validation Loss = 1.714
# Epoch=7, batch = 1000 of 14253, loss=4.491, LR=0.00034549150281252633
# Validation Loss = 0.543
# Epoch=7, batch = 2000 of 14253, loss=4.299, LR=0.00034549150281252633
# Validation Loss = 2.223
# Epoch=7, batch = 3000 of 14253, loss=4.326, LR=0.00034549150281252633
# Validation Loss = 2.326
# Epoch=7, batch = 4000 of 14253, loss=3.959, LR=0.00034549150281252633
# Validation Loss = 1.477
# Epoch=7, batch = 5000 of 14253, loss=3.787, LR=0.00034549150281252633
# Validation Loss = 0.674
# Epoch=7, batch = 6000 of 14253, loss=4.359, LR=0.00034549150281252633
# Validation Loss = 2.254
# Epoch=7, batch = 7000 of 14253, loss=3.801, LR=0.00034549150281252633
# Validation Loss = 2.053
# Epoch=7, batch = 8000 of 14253, loss=3.663, LR=0.00034549150281252633
# Validation Loss = 2.714
# Epoch=7, batch = 9000 of 14253, loss=3.557, LR=0.00034549150281252633
# Validation Loss = 1.979
# Epoch=7, batch = 10000 of 14253, loss=3.459, LR=0.00034549150281252633
# Validation Loss = 3.375
# Epoch=7, batch = 11000 of 14253, loss=3.985, LR=0.00034549150281252633
# Validation Loss = 3.147
# Epoch=7, batch = 12000 of 14253, loss=4.217, LR=0.00034549150281252633
# Validation Loss = 4.067
# Epoch=7, batch = 13000 of 14253, loss=4.304, LR=0.00034549150281252633
# Validation Loss = 0.820
# Epoch=7, batch = 14000 of 14253, loss=4.048, LR=0.00034549150281252633
# Validation Loss = 2.426
# Epoch=8, batch = 0 of 14253, loss=3.649, LR=0.0002061073738537635
# Validation Loss = 1.666
# Epoch=8, batch = 1000 of 14253, loss=3.520, LR=0.0002061073738537635
# Validation Loss = 1.008
# Epoch=8, batch = 2000 of 14253, loss=4.415, LR=0.0002061073738537635
# Validation Loss = 0.958
# Epoch=8, batch = 3000 of 14253, loss=3.857, LR=0.0002061073738537635
# Validation Loss = 1.948
# Epoch=8, batch = 4000 of 14253, loss=3.601, LR=0.0002061073738537635
# Validation Loss = 2.005
# Epoch=8, batch = 5000 of 14253, loss=4.176, LR=0.0002061073738537635
# Validation Loss = 1.886
# Epoch=8, batch = 6000 of 14253, loss=4.666, LR=0.0002061073738537635
# Validation Loss = 0.824
# Epoch=8, batch = 7000 of 14253, loss=3.761, LR=0.0002061073738537635
# Validation Loss = 0.992
# Epoch=8, batch = 8000 of 14253, loss=3.855, LR=0.0002061073738537635
# Validation Loss = 2.210
# Epoch=8, batch = 9000 of 14253, loss=3.537, LR=0.0002061073738537635
# Validation Loss = 0.480
# Epoch=8, batch = 10000 of 14253, loss=4.026, LR=0.0002061073738537635
# Validation Loss = 2.796
# Epoch=8, batch = 11000 of 14253, loss=3.914, LR=0.0002061073738537635
# Validation Loss = 1.423
# Epoch=8, batch = 12000 of 14253, loss=3.717, LR=0.0002061073738537635
# Validation Loss = 2.589
# Epoch=8, batch = 13000 of 14253, loss=3.916, LR=0.0002061073738537635
# Validation Loss = 0.764
# Epoch=8, batch = 14000 of 14253, loss=3.746, LR=0.0002061073738537635
# Validation Loss = 1.227
# Epoch=9, batch = 0 of 14253, loss=3.736, LR=9.549150281252634e-05
# Validation Loss = 1.818
# Epoch=9, batch = 1000 of 14253, loss=3.828, LR=9.549150281252634e-05
# Validation Loss = 1.195
# Epoch=9, batch = 2000 of 14253, loss=4.076, LR=9.549150281252634e-05
# Validation Loss = 1.228
# Epoch=9, batch = 3000 of 14253, loss=3.555, LR=9.549150281252634e-05
# Validation Loss = 1.920
# Epoch=9, batch = 4000 of 14253, loss=3.518, LR=9.549150281252634e-05
# Validation Loss = 1.004
# Epoch=9, batch = 5000 of 14253, loss=3.350, LR=9.549150281252634e-05
# Validation Loss = 2.531
# Epoch=9, batch = 6000 of 14253, loss=3.563, LR=9.549150281252634e-05
# Validation Loss = 2.538
# Epoch=9, batch = 7000 of 14253, loss=3.849, LR=9.549150281252634e-05
# Validation Loss = 1.704
# Epoch=9, batch = 8000 of 14253, loss=3.881, LR=9.549150281252634e-05
# Validation Loss = 0.680
# Epoch=9, batch = 9000 of 14253, loss=3.122, LR=9.549150281252634e-05
# Validation Loss = 2.182
# Epoch=9, batch = 10000 of 14253, loss=3.696, LR=9.549150281252634e-05
# Validation Loss = 2.209
# Epoch=9, batch = 11000 of 14253, loss=3.834, LR=9.549150281252634e-05
# Validation Loss = 1.619
# Epoch=9, batch = 12000 of 14253, loss=3.889, LR=9.549150281252634e-05
# Validation Loss = 1.675
# Epoch=9, batch = 13000 of 14253, loss=3.943, LR=9.549150281252634e-05
# Validation Loss = 1.344
# Epoch=9, batch = 14000 of 14253, loss=3.650, LR=9.549150281252634e-05
# Validation Loss = 2.425
# Epoch=10, batch = 0 of 14253, loss=3.558, LR=2.4471741852423235e-05
# Validation Loss = 1.677
# Epoch=10, batch = 1000 of 14253, loss=3.629, LR=2.4471741852423235e-05
# Validation Loss = 2.399
# Epoch=10, batch = 2000 of 14253, loss=3.374, LR=2.4471741852423235e-05
# Validation Loss = 1.119
# Epoch=10, batch = 3000 of 14253, loss=3.607, LR=2.4471741852423235e-05
# Validation Loss = 1.073
# Epoch=10, batch = 4000 of 14253, loss=3.612, LR=2.4471741852423235e-05
# Validation Loss = 1.700
# Epoch=10, batch = 5000 of 14253, loss=3.438, LR=2.4471741852423235e-05
# Validation Loss = 1.654
# Epoch=10, batch = 6000 of 14253, loss=3.444, LR=2.4471741852423235e-05
# Validation Loss = 1.343
# Epoch=10, batch = 7000 of 14253, loss=3.655, LR=2.4471741852423235e-05
# Validation Loss = 1.047
# Epoch=10, batch = 8000 of 14253, loss=3.576, LR=2.4471741852423235e-05
# Validation Loss = 1.919
# Epoch=10, batch = 9000 of 14253, loss=3.542, LR=2.4471741852423235e-05
# Validation Loss = 1.439
# Epoch=10, batch = 10000 of 14253, loss=3.730, LR=2.4471741852423235e-05
# Validation Loss = 1.087
# Epoch=10, batch = 11000 of 14253, loss=3.639, LR=2.4471741852423235e-05
# Validation Loss = 1.719
# Epoch=10, batch = 12000 of 14253, loss=3.778, LR=2.4471741852423235e-05
# Validation Loss = 1.304
# Epoch=10, batch = 13000 of 14253, loss=3.608, LR=2.4471741852423235e-05
# Validation Loss = 2.149
# Epoch=10, batch = 14000 of 14253, loss=3.715, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 1.470
# Epoch=1, batch = 0 of 14253, loss=3.642, LR=0.001
# Validation Loss = 3.888
# Epoch=1, batch = 1000 of 14253, loss=4.612, LR=0.001
# Validation Loss = 2.229
# Epoch=1, batch = 2000 of 14253, loss=4.150, LR=0.001
# Validation Loss = 3.474
# Epoch=1, batch = 3000 of 14253, loss=4.649, LR=0.001
# Validation Loss = 3.992
# Epoch=1, batch = 4000 of 14253, loss=3.599, LR=0.001
# Validation Loss = 3.171
# Epoch=1, batch = 5000 of 14253, loss=3.881, LR=0.001
# Validation Loss = 5.690
# Epoch=1, batch = 6000 of 14253, loss=5.123, LR=0.001
# Validation Loss = 8.799
# Epoch=1, batch = 7000 of 14253, loss=5.333, LR=0.001
# Validation Loss = 4.606
# Epoch=1, batch = 8000 of 14253, loss=3.985, LR=0.001
# Validation Loss = 3.454
# Epoch=1, batch = 9000 of 14253, loss=4.019, LR=0.001
# Validation Loss = 2.513
# Epoch=1, batch = 10000 of 14253, loss=4.072, LR=0.001
# Validation Loss = 4.061
# Epoch=1, batch = 11000 of 14253, loss=4.886, LR=0.001
# Validation Loss = 2.317
# Epoch=1, batch = 12000 of 14253, loss=3.523, LR=0.001
# Validation Loss = 4.265
# Epoch=1, batch = 13000 of 14253, loss=3.691, LR=0.001
# Validation Loss = 1.208
# Epoch=1, batch = 14000 of 14253, loss=3.966, LR=0.001
# Validation Loss = 6.403
# Epoch=2, batch = 0 of 14253, loss=3.846, LR=0.0009938441702975688
# Validation Loss = 2.173
# Epoch=2, batch = 1000 of 14253, loss=3.539, LR=0.0009938441702975688
# Validation Loss = 4.111
# Epoch=2, batch = 2000 of 14253, loss=4.137, LR=0.0009938441702975688
# Validation Loss = 1.923
# Epoch=2, batch = 3000 of 14253, loss=4.626, LR=0.0009938441702975688
# Validation Loss = 2.872
# Epoch=2, batch = 4000 of 14253, loss=3.737, LR=0.0009938441702975688
# Validation Loss = 4.702
# Epoch=2, batch = 5000 of 14253, loss=4.734, LR=0.0009938441702975688
# Validation Loss = 1.989
# Epoch=2, batch = 6000 of 14253, loss=3.710, LR=0.0009938441702975688
# Validation Loss = 7.669
# Epoch=2, batch = 7000 of 14253, loss=4.120, LR=0.0009938441702975688
# Validation Loss = 2.473
# Epoch=2, batch = 8000 of 14253, loss=5.583, LR=0.0009938441702975688
# Validation Loss = 2.740
# Epoch=2, batch = 9000 of 14253, loss=4.909, LR=0.0009938441702975688
# Validation Loss = 5.517
# Epoch=2, batch = 10000 of 14253, loss=4.010, LR=0.0009938441702975688
# Validation Loss = 5.622
# Epoch=2, batch = 11000 of 14253, loss=4.034, LR=0.0009938441702975688
# Validation Loss = 5.955
# Epoch=2, batch = 12000 of 14253, loss=3.797, LR=0.0009938441702975688
# Validation Loss = 3.840
# Epoch=2, batch = 13000 of 14253, loss=3.806, LR=0.0009938441702975688
# Validation Loss = 3.142
# Epoch=2, batch = 14000 of 14253, loss=4.003, LR=0.0009938441702975688
# Validation Loss = 0.895
# Epoch=3, batch = 0 of 14253, loss=4.029, LR=0.0009755282581475768
# Validation Loss = 4.318
# Epoch=3, batch = 1000 of 14253, loss=3.780, LR=0.0009755282581475768
# Validation Loss = 5.160
# Epoch=3, batch = 2000 of 14253, loss=4.074, LR=0.0009755282581475768
# Validation Loss = 1.240
# Epoch=3, batch = 3000 of 14253, loss=4.395, LR=0.0009755282581475768
# Validation Loss = 1.365
# Epoch=3, batch = 4000 of 14253, loss=3.940, LR=0.0009755282581475768
# Validation Loss = 2.960
# Epoch=3, batch = 5000 of 14253, loss=3.818, LR=0.0009755282581475768
# Validation Loss = 3.344
# Epoch=3, batch = 6000 of 14253, loss=3.751, LR=0.0009755282581475768
# Validation Loss = 3.078
# Epoch=3, batch = 7000 of 14253, loss=3.965, LR=0.0009755282581475768
# Validation Loss = 2.499
# Epoch=3, batch = 8000 of 14253, loss=4.360, LR=0.0009755282581475768
# Validation Loss = 1.661
# Epoch=3, batch = 9000 of 14253, loss=4.296, LR=0.0009755282581475768
# Validation Loss = 5.974
# Epoch=3, batch = 10000 of 14253, loss=3.869, LR=0.0009755282581475768
# Validation Loss = 2.047
# Epoch=3, batch = 11000 of 14253, loss=3.870, LR=0.0009755282581475768
# Validation Loss = 0.778
# Epoch=3, batch = 12000 of 14253, loss=4.710, LR=0.0009755282581475768
# Validation Loss = 0.296
# Epoch=3, batch = 13000 of 14253, loss=5.195, LR=0.0009755282581475768
# Validation Loss = 5.153
# Epoch=3, batch = 14000 of 14253, loss=4.317, LR=0.0009755282581475768
# Validation Loss = 2.515
# Epoch=4, batch = 0 of 14253, loss=4.632, LR=0.0009455032620941839
# Validation Loss = 3.316
# Epoch=4, batch = 1000 of 14253, loss=4.514, LR=0.0009455032620941839
# Validation Loss = 5.600
# Epoch=4, batch = 2000 of 14253, loss=3.400, LR=0.0009455032620941839
# Validation Loss = 2.795
# Epoch=4, batch = 3000 of 14253, loss=3.956, LR=0.0009455032620941839
# Validation Loss = 5.520
# Epoch=4, batch = 4000 of 14253, loss=4.150, LR=0.0009455032620941839
# Validation Loss = 1.483
# Epoch=4, batch = 5000 of 14253, loss=3.480, LR=0.0009455032620941839
# Validation Loss = 4.193
# Epoch=4, batch = 6000 of 14253, loss=3.610, LR=0.0009455032620941839
# Validation Loss = 1.976
# Epoch=4, batch = 7000 of 14253, loss=3.559, LR=0.0009455032620941839
# Validation Loss = 1.175
# Epoch=4, batch = 8000 of 14253, loss=3.588, LR=0.0009455032620941839
# Validation Loss = 5.324
# Epoch=4, batch = 9000 of 14253, loss=4.069, LR=0.0009455032620941839
# Validation Loss = 2.099
# Epoch=4, batch = 10000 of 14253, loss=3.791, LR=0.0009455032620941839
# Validation Loss = 3.755
# Epoch=4, batch = 11000 of 14253, loss=4.074, LR=0.0009455032620941839
# Validation Loss = 1.066
# Epoch=4, batch = 12000 of 14253, loss=3.839, LR=0.0009455032620941839
# Validation Loss = 7.003
# Epoch=4, batch = 13000 of 14253, loss=4.769, LR=0.0009455032620941839
# Validation Loss = 3.953
# Epoch=4, batch = 14000 of 14253, loss=3.785, LR=0.0009455032620941839
# Validation Loss = 4.820
# Epoch=5, batch = 0 of 14253, loss=4.340, LR=0.0009045084971874737
# Validation Loss = 7.259
# Epoch=5, batch = 1000 of 14253, loss=5.183, LR=0.0009045084971874737
# Validation Loss = 7.494
# Epoch=5, batch = 2000 of 14253, loss=3.763, LR=0.0009045084971874737
# Validation Loss = 0.733
# Epoch=5, batch = 3000 of 14253, loss=3.895, LR=0.0009045084971874737
# Validation Loss = 5.454
# Epoch=5, batch = 4000 of 14253, loss=3.498, LR=0.0009045084971874737
# Validation Loss = 2.853
# Epoch=5, batch = 5000 of 14253, loss=3.670, LR=0.0009045084971874737
# Validation Loss = 6.450
# Epoch=5, batch = 6000 of 14253, loss=3.994, LR=0.0009045084971874737
# Validation Loss = 2.384
# Epoch=5, batch = 7000 of 14253, loss=4.151, LR=0.0009045084971874737
# Validation Loss = 0.789
# Epoch=5, batch = 8000 of 14253, loss=4.918, LR=0.0009045084971874737
# Validation Loss = 4.978
# Epoch=5, batch = 9000 of 14253, loss=3.602, LR=0.0009045084971874737
# Validation Loss = 0.768
# Epoch=5, batch = 10000 of 14253, loss=4.538, LR=0.0009045084971874737
# Validation Loss = 3.940
# Epoch=5, batch = 11000 of 14253, loss=3.832, LR=0.0009045084971874737
# Validation Loss = 5.144
# Epoch=5, batch = 12000 of 14253, loss=4.443, LR=0.0009045084971874737
# Validation Loss = 2.540
# Epoch=5, batch = 13000 of 14253, loss=3.726, LR=0.0009045084971874737
# Validation Loss = 0.971
# Epoch=5, batch = 14000 of 14253, loss=4.368, LR=0.0009045084971874737
# Validation Loss = 6.853
# Epoch=6, batch = 0 of 14253, loss=3.776, LR=0.0008535533905932737
# Validation Loss = 5.935
# Epoch=6, batch = 1000 of 14253, loss=4.586, LR=0.0008535533905932737
# Validation Loss = 4.322
# Epoch=6, batch = 2000 of 14253, loss=3.631, LR=0.0008535533905932737
# Validation Loss = 5.065
# Epoch=6, batch = 3000 of 14253, loss=3.893, LR=0.0008535533905932737
# Validation Loss = 8.909
# Epoch=6, batch = 4000 of 14253, loss=5.506, LR=0.0008535533905932737
# Validation Loss = 5.232
# Epoch=6, batch = 5000 of 14253, loss=3.880, LR=0.0008535533905932737
# Validation Loss = 2.651
# Epoch=6, batch = 6000 of 14253, loss=3.691, LR=0.0008535533905932737
# Validation Loss = 2.332
# Epoch=6, batch = 7000 of 14253, loss=4.049, LR=0.0008535533905932737
# Validation Loss = 0.746
# Epoch=6, batch = 8000 of 14253, loss=4.654, LR=0.0008535533905932737
# Validation Loss = 3.343
# Epoch=6, batch = 9000 of 14253, loss=4.748, LR=0.0008535533905932737
# Validation Loss = 4.980
# Epoch=6, batch = 10000 of 14253, loss=5.069, LR=0.0008535533905932737
# Validation Loss = 1.160
# Epoch=6, batch = 11000 of 14253, loss=3.899, LR=0.0008535533905932737
# Validation Loss = 6.326
# Epoch=6, batch = 12000 of 14253, loss=3.911, LR=0.0008535533905932737
# Validation Loss = 4.451
# Epoch=6, batch = 13000 of 14253, loss=3.509, LR=0.0008535533905932737
# Validation Loss = 2.211
# Epoch=6, batch = 14000 of 14253, loss=3.740, LR=0.0008535533905932737
# Validation Loss = 0.798
# Epoch=7, batch = 0 of 14253, loss=3.587, LR=0.0007938926261462366
# Validation Loss = 3.473
# Epoch=7, batch = 1000 of 14253, loss=3.944, LR=0.0007938926261462366
# Validation Loss = 4.241
# Epoch=7, batch = 2000 of 14253, loss=5.295, LR=0.0007938926261462366
# Validation Loss = 2.790
# Epoch=7, batch = 3000 of 14253, loss=3.968, LR=0.0007938926261462366
# Validation Loss = 5.123
# Epoch=7, batch = 4000 of 14253, loss=3.518, LR=0.0007938926261462366
# Validation Loss = 2.050
# Epoch=7, batch = 5000 of 14253, loss=3.837, LR=0.0007938926261462366
# Validation Loss = 5.380
# Epoch=7, batch = 6000 of 14253, loss=3.488, LR=0.0007938926261462366
# Validation Loss = 2.444
# Epoch=7, batch = 7000 of 14253, loss=3.831, LR=0.0007938926261462366
# Validation Loss = 2.136
# Epoch=7, batch = 8000 of 14253, loss=3.740, LR=0.0007938926261462366
# Validation Loss = 4.669
# Epoch=7, batch = 9000 of 14253, loss=4.432, LR=0.0007938926261462366
# Validation Loss = 3.594
# Epoch=7, batch = 10000 of 14253, loss=4.284, LR=0.0007938926261462366
# Validation Loss = 4.095
# Epoch=7, batch = 11000 of 14253, loss=3.821, LR=0.0007938926261462366
# Validation Loss = 6.572
# Epoch=7, batch = 12000 of 14253, loss=4.746, LR=0.0007938926261462366
# Validation Loss = 2.420
# Epoch=7, batch = 13000 of 14253, loss=4.422, LR=0.0007938926261462366
# Validation Loss = 3.516
# Epoch=7, batch = 14000 of 14253, loss=4.653, LR=0.0007938926261462366
# Validation Loss = 2.796
# Epoch=8, batch = 0 of 14253, loss=3.827, LR=0.0007269952498697733
# Validation Loss = 0.622
# Epoch=8, batch = 1000 of 14253, loss=3.676, LR=0.0007269952498697733
# Validation Loss = 0.965
# Epoch=8, batch = 2000 of 14253, loss=4.209, LR=0.0007269952498697733
# Validation Loss = 1.237
# Epoch=8, batch = 3000 of 14253, loss=4.687, LR=0.0007269952498697733
# Validation Loss = 4.028
# Epoch=8, batch = 4000 of 14253, loss=3.589, LR=0.0007269952498697733
# Validation Loss = 4.646
# Epoch=8, batch = 5000 of 14253, loss=3.713, LR=0.0007269952498697733
# Validation Loss = 0.293
# Epoch=8, batch = 6000 of 14253, loss=4.584, LR=0.0007269952498697733
# Validation Loss = 4.950
# Epoch=8, batch = 7000 of 14253, loss=4.104, LR=0.0007269952498697733
# Validation Loss = 0.932
# Epoch=8, batch = 8000 of 14253, loss=3.707, LR=0.0007269952498697733
# Validation Loss = 5.366
# Epoch=8, batch = 9000 of 14253, loss=4.343, LR=0.0007269952498697733
# Validation Loss = 4.158
# Epoch=8, batch = 10000 of 14253, loss=3.621, LR=0.0007269952498697733
# Validation Loss = 5.574
# Epoch=8, batch = 11000 of 14253, loss=4.185, LR=0.0007269952498697733
# Validation Loss = 3.716
# Epoch=8, batch = 12000 of 14253, loss=3.892, LR=0.0007269952498697733
# Validation Loss = 0.582
# Epoch=8, batch = 13000 of 14253, loss=4.092, LR=0.0007269952498697733
# Validation Loss = 4.187
# Epoch=8, batch = 14000 of 14253, loss=4.133, LR=0.0007269952498697733
# Validation Loss = 1.156
# Epoch=9, batch = 0 of 14253, loss=4.080, LR=0.0006545084971874737
# Validation Loss = 5.429
# Epoch=9, batch = 1000 of 14253, loss=3.605, LR=0.0006545084971874737
# Validation Loss = 1.381
# Epoch=9, batch = 2000 of 14253, loss=3.818, LR=0.0006545084971874737
# Validation Loss = 2.999
# Epoch=9, batch = 3000 of 14253, loss=4.274, LR=0.0006545084971874737
# Validation Loss = 3.801
# Epoch=9, batch = 4000 of 14253, loss=3.568, LR=0.0006545084971874737
# Validation Loss = 5.025
# Epoch=9, batch = 5000 of 14253, loss=4.041, LR=0.0006545084971874737
# Validation Loss = 4.315
# Epoch=9, batch = 6000 of 14253, loss=3.856, LR=0.0006545084971874737
# Validation Loss = 4.016
# Epoch=9, batch = 7000 of 14253, loss=4.239, LR=0.0006545084971874737
# Validation Loss = 0.637
# Epoch=9, batch = 8000 of 14253, loss=4.072, LR=0.0006545084971874737
# Validation Loss = 4.084
# Epoch=9, batch = 9000 of 14253, loss=4.069, LR=0.0006545084971874737
# Validation Loss = 2.897
# Epoch=9, batch = 10000 of 14253, loss=4.125, LR=0.0006545084971874737
# Validation Loss = 1.832
# Epoch=9, batch = 11000 of 14253, loss=3.470, LR=0.0006545084971874737
# Validation Loss = 5.863
# Epoch=9, batch = 12000 of 14253, loss=3.396, LR=0.0006545084971874737
# Validation Loss = 1.562
# Epoch=9, batch = 13000 of 14253, loss=4.168, LR=0.0006545084971874737
# Validation Loss = 3.178
# Epoch=9, batch = 14000 of 14253, loss=3.735, LR=0.0006545084971874737
# Validation Loss = 0.211
# Epoch=10, batch = 0 of 14253, loss=3.652, LR=0.0005782172325201155
# Validation Loss = 4.135
# Epoch=10, batch = 1000 of 14253, loss=3.551, LR=0.0005782172325201155
# Validation Loss = 1.956
# Epoch=10, batch = 2000 of 14253, loss=3.129, LR=0.0005782172325201155
# Validation Loss = 1.537
# Epoch=10, batch = 3000 of 14253, loss=3.433, LR=0.0005782172325201155
# Validation Loss = 6.019
# Epoch=10, batch = 4000 of 14253, loss=3.628, LR=0.0005782172325201155
# Validation Loss = 1.279
# Epoch=10, batch = 5000 of 14253, loss=3.684, LR=0.0005782172325201155
# Validation Loss = 0.307
# Epoch=10, batch = 6000 of 14253, loss=3.730, LR=0.0005782172325201155
# Validation Loss = 3.083
# Epoch=10, batch = 7000 of 14253, loss=3.130, LR=0.0005782172325201155
# Validation Loss = 6.832
# Epoch=10, batch = 8000 of 14253, loss=3.684, LR=0.0005782172325201155
# Validation Loss = 2.949
# Epoch=10, batch = 9000 of 14253, loss=3.671, LR=0.0005782172325201155
# Validation Loss = 2.773
# Epoch=10, batch = 10000 of 14253, loss=4.066, LR=0.0005782172325201155
# Validation Loss = 2.481
# Epoch=10, batch = 11000 of 14253, loss=4.308, LR=0.0005782172325201155
# Validation Loss = 2.721
# Epoch=10, batch = 12000 of 14253, loss=3.624, LR=0.0005782172325201155
# Validation Loss = 3.981
# Epoch=10, batch = 13000 of 14253, loss=3.550, LR=0.0005782172325201155
# Validation Loss = 4.160
# Epoch=10, batch = 14000 of 14253, loss=3.586, LR=0.0005782172325201155
# Validation Loss = 3.868
# Epoch=11, batch = 0 of 14253, loss=4.028, LR=0.0005
# Validation Loss = 1.475
# Epoch=11, batch = 1000 of 14253, loss=3.554, LR=0.0005
# Validation Loss = 2.777
# Epoch=11, batch = 2000 of 14253, loss=3.365, LR=0.0005
# Validation Loss = 2.578
# Epoch=11, batch = 3000 of 14253, loss=3.565, LR=0.0005
# Validation Loss = 3.421
# Epoch=11, batch = 4000 of 14253, loss=3.758, LR=0.0005
# Validation Loss = 1.575
# Epoch=11, batch = 5000 of 14253, loss=3.651, LR=0.0005
# Validation Loss = 3.138
# Epoch=11, batch = 6000 of 14253, loss=3.221, LR=0.0005
# Validation Loss = 2.162
# Epoch=11, batch = 7000 of 14253, loss=3.287, LR=0.0005
# Validation Loss = 1.790
# Epoch=11, batch = 8000 of 14253, loss=3.698, LR=0.0005
# Validation Loss = 3.689
# Epoch=11, batch = 9000 of 14253, loss=3.356, LR=0.0005
# Validation Loss = 2.685
# Epoch=11, batch = 10000 of 14253, loss=3.630, LR=0.0005
# Validation Loss = 1.880
# Epoch=11, batch = 11000 of 14253, loss=3.365, LR=0.0005
# Validation Loss = 5.625
# Epoch=11, batch = 12000 of 14253, loss=3.948, LR=0.0005
# Validation Loss = 1.348
# Epoch=11, batch = 13000 of 14253, loss=3.401, LR=0.0005
# Validation Loss = 4.048
# Epoch=11, batch = 14000 of 14253, loss=3.325, LR=0.0005
# Validation Loss = 2.813
# Epoch=12, batch = 0 of 14253, loss=3.230, LR=0.0004217827674798847
# Validation Loss = 6.738
# Epoch=12, batch = 1000 of 14253, loss=3.762, LR=0.0004217827674798847
# Validation Loss = 4.942
# Epoch=12, batch = 2000 of 14253, loss=4.060, LR=0.0004217827674798847
# Validation Loss = 2.154
# Epoch=12, batch = 3000 of 14253, loss=3.589, LR=0.0004217827674798847
# Validation Loss = 2.205
# Epoch=12, batch = 4000 of 14253, loss=4.102, LR=0.0004217827674798847
# Validation Loss = 0.598
# Epoch=12, batch = 5000 of 14253, loss=3.501, LR=0.0004217827674798847
# Validation Loss = 1.926
# Epoch=12, batch = 6000 of 14253, loss=3.888, LR=0.0004217827674798847
# Validation Loss = 2.736
# Epoch=12, batch = 7000 of 14253, loss=4.134, LR=0.0004217827674798847
# Validation Loss = 7.124
# Epoch=12, batch = 8000 of 14253, loss=3.744, LR=0.0004217827674798847
# Validation Loss = 4.065
# Epoch=12, batch = 9000 of 14253, loss=3.897, LR=0.0004217827674798847
# Validation Loss = 0.397
# Epoch=12, batch = 10000 of 14253, loss=3.487, LR=0.0004217827674798847
# Validation Loss = 1.827
# Epoch=12, batch = 11000 of 14253, loss=4.055, LR=0.0004217827674798847
# Validation Loss = 2.746
# Epoch=12, batch = 12000 of 14253, loss=3.841, LR=0.0004217827674798847
# Validation Loss = 2.243
# Epoch=12, batch = 13000 of 14253, loss=3.543, LR=0.0004217827674798847
# Validation Loss = 1.413
# Epoch=12, batch = 14000 of 14253, loss=3.835, LR=0.0004217827674798847
# Validation Loss = 2.390
# Epoch=13, batch = 0 of 14253, loss=3.529, LR=0.00034549150281252633
# Validation Loss = 2.627
# Epoch=13, batch = 1000 of 14253, loss=3.571, LR=0.00034549150281252633
# Validation Loss = 3.455
# Epoch=13, batch = 2000 of 14253, loss=3.766, LR=0.00034549150281252633
# Validation Loss = 2.457
# Epoch=13, batch = 3000 of 14253, loss=4.243, LR=0.00034549150281252633
# Validation Loss = 1.803
# Epoch=13, batch = 4000 of 14253, loss=3.987, LR=0.00034549150281252633
# Validation Loss = 1.514
# Epoch=13, batch = 5000 of 14253, loss=3.592, LR=0.00034549150281252633
# Validation Loss = 2.109
# Epoch=13, batch = 6000 of 14253, loss=3.244, LR=0.00034549150281252633
# Validation Loss = 0.761
# Epoch=13, batch = 7000 of 14253, loss=3.985, LR=0.00034549150281252633
# Validation Loss = 2.993
# Epoch=13, batch = 8000 of 14253, loss=3.644, LR=0.00034549150281252633
# Validation Loss = 2.951
# Epoch=13, batch = 9000 of 14253, loss=3.547, LR=0.00034549150281252633
# Validation Loss = 0.848
# Epoch=13, batch = 10000 of 14253, loss=3.456, LR=0.00034549150281252633
# Validation Loss = 1.663
# Epoch=13, batch = 11000 of 14253, loss=3.380, LR=0.00034549150281252633
# Validation Loss = 5.517
# Epoch=13, batch = 12000 of 14253, loss=3.676, LR=0.00034549150281252633
# Validation Loss = 1.155
# Epoch=13, batch = 13000 of 14253, loss=3.680, LR=0.00034549150281252633
# Validation Loss = 1.341
# Epoch=13, batch = 14000 of 14253, loss=3.334, LR=0.00034549150281252633
# Validation Loss = 2.253
# Epoch=14, batch = 0 of 14253, loss=3.870, LR=0.00027300475013022663
# Validation Loss = 4.354
# Epoch=14, batch = 1000 of 14253, loss=3.799, LR=0.00027300475013022663
# Validation Loss = 2.327
# Epoch=14, batch = 2000 of 14253, loss=3.584, LR=0.00027300475013022663
# Validation Loss = 1.789
# Epoch=14, batch = 3000 of 14253, loss=3.296, LR=0.00027300475013022663
# Validation Loss = 3.633
# Epoch=14, batch = 4000 of 14253, loss=3.661, LR=0.00027300475013022663
# Validation Loss = 2.850
# Epoch=14, batch = 5000 of 14253, loss=3.671, LR=0.00027300475013022663
# Validation Loss = 0.812
# Epoch=14, batch = 6000 of 14253, loss=3.720, LR=0.00027300475013022663
# Validation Loss = 5.549
# Epoch=14, batch = 7000 of 14253, loss=3.672, LR=0.00027300475013022663
# Validation Loss = 4.445
# Epoch=14, batch = 8000 of 14253, loss=3.524, LR=0.00027300475013022663
# Validation Loss = 4.038
# Epoch=14, batch = 9000 of 14253, loss=3.322, LR=0.00027300475013022663
# Validation Loss = 4.164
# Epoch=14, batch = 10000 of 14253, loss=3.765, LR=0.00027300475013022663
# Validation Loss = 0.922
# Epoch=14, batch = 11000 of 14253, loss=3.427, LR=0.00027300475013022663
# Validation Loss = 2.659
# Epoch=14, batch = 12000 of 14253, loss=3.940, LR=0.00027300475013022663
# Validation Loss = 1.583
# Epoch=14, batch = 13000 of 14253, loss=3.115, LR=0.00027300475013022663
# Validation Loss = 3.400
# Epoch=14, batch = 14000 of 14253, loss=3.403, LR=0.00027300475013022663
# Validation Loss = 4.205
# Epoch=15, batch = 0 of 14253, loss=3.579, LR=0.00020610737385376348
# Validation Loss = 4.358
# Epoch=15, batch = 1000 of 14253, loss=3.834, LR=0.00020610737385376348
# Validation Loss = 1.361
# Epoch=15, batch = 2000 of 14253, loss=3.505, LR=0.00020610737385376348
# Validation Loss = 5.419
# Epoch=15, batch = 3000 of 14253, loss=4.010, LR=0.00020610737385376348
# Validation Loss = 2.460
# Epoch=15, batch = 4000 of 14253, loss=3.697, LR=0.00020610737385376348
# Validation Loss = 4.904
# Epoch=15, batch = 5000 of 14253, loss=3.381, LR=0.00020610737385376348
# Validation Loss = 1.412
# Epoch=15, batch = 6000 of 14253, loss=3.627, LR=0.00020610737385376348
# Validation Loss = 2.086
# Epoch=15, batch = 7000 of 14253, loss=3.226, LR=0.00020610737385376348
# Validation Loss = 2.689
# Epoch=15, batch = 8000 of 14253, loss=3.812, LR=0.00020610737385376348
# Validation Loss = 3.207
# Epoch=15, batch = 9000 of 14253, loss=3.916, LR=0.00020610737385376348
# Validation Loss = 3.893
# Epoch=15, batch = 10000 of 14253, loss=3.724, LR=0.00020610737385376348
# Validation Loss = 4.059
# Epoch=15, batch = 11000 of 14253, loss=4.113, LR=0.00020610737385376348
# Validation Loss = 6.793
# Epoch=15, batch = 12000 of 14253, loss=3.492, LR=0.00020610737385376348
# Validation Loss = 3.051
# Epoch=15, batch = 13000 of 14253, loss=3.703, LR=0.00020610737385376348
# Validation Loss = 3.298
# Epoch=15, batch = 14000 of 14253, loss=3.299, LR=0.00020610737385376348
# Validation Loss = 2.716
# Epoch=16, batch = 0 of 14253, loss=3.732, LR=0.00014644660940672625
# Validation Loss = 3.129
# Epoch=16, batch = 1000 of 14253, loss=3.693, LR=0.00014644660940672625
# Validation Loss = 2.841
# Epoch=16, batch = 2000 of 14253, loss=3.573, LR=0.00014644660940672625
# Validation Loss = 1.603
# Epoch=16, batch = 3000 of 14253, loss=3.496, LR=0.00014644660940672625
# Validation Loss = 3.032
# Epoch=16, batch = 4000 of 14253, loss=3.285, LR=0.00014644660940672625
# Validation Loss = 3.202
# Epoch=16, batch = 5000 of 14253, loss=3.517, LR=0.00014644660940672625
# Validation Loss = 2.358
# Epoch=16, batch = 6000 of 14253, loss=3.580, LR=0.00014644660940672625
# Validation Loss = 2.141
# Epoch=16, batch = 7000 of 14253, loss=3.917, LR=0.00014644660940672625
# Validation Loss = 2.067
# Epoch=16, batch = 8000 of 14253, loss=3.533, LR=0.00014644660940672625
# Validation Loss = 2.288
# Epoch=16, batch = 9000 of 14253, loss=3.763, LR=0.00014644660940672625
# Validation Loss = 1.740
# Epoch=16, batch = 10000 of 14253, loss=3.421, LR=0.00014644660940672625
# Validation Loss = 4.474
# Epoch=16, batch = 11000 of 14253, loss=4.256, LR=0.00014644660940672625
# Validation Loss = 3.659
# Epoch=16, batch = 12000 of 14253, loss=3.372, LR=0.00014644660940672625
# Validation Loss = 2.934
# Epoch=16, batch = 13000 of 14253, loss=3.589, LR=0.00014644660940672625
# Validation Loss = 3.685
# Epoch=16, batch = 14000 of 14253, loss=3.529, LR=0.00014644660940672625
# Validation Loss = 2.432
# Epoch=17, batch = 0 of 14253, loss=3.156, LR=9.549150281252631e-05
# Validation Loss = 3.139
# Epoch=17, batch = 1000 of 14253, loss=3.369, LR=9.549150281252631e-05
# Validation Loss = 4.292
# Epoch=17, batch = 2000 of 14253, loss=3.349, LR=9.549150281252631e-05
# Validation Loss = 4.744
# Epoch=17, batch = 3000 of 14253, loss=3.388, LR=9.549150281252631e-05
# Validation Loss = 2.934
# Epoch=17, batch = 4000 of 14253, loss=3.238, LR=9.549150281252631e-05
# Validation Loss = 3.232
# Epoch=17, batch = 5000 of 14253, loss=2.989, LR=9.549150281252631e-05
# Validation Loss = 4.031
# Epoch=17, batch = 6000 of 14253, loss=3.746, LR=9.549150281252631e-05
# Validation Loss = 1.359
# Epoch=17, batch = 7000 of 14253, loss=3.772, LR=9.549150281252631e-05
# Validation Loss = 1.906
# Epoch=17, batch = 8000 of 14253, loss=3.664, LR=9.549150281252631e-05
# Validation Loss = 2.793
# Epoch=17, batch = 9000 of 14253, loss=4.190, LR=9.549150281252631e-05
# Validation Loss = 2.173
# Epoch=17, batch = 10000 of 14253, loss=3.314, LR=9.549150281252631e-05
# Validation Loss = 2.970
# Epoch=17, batch = 11000 of 14253, loss=4.458, LR=9.549150281252631e-05
# Validation Loss = 3.926
# Epoch=17, batch = 12000 of 14253, loss=3.289, LR=9.549150281252631e-05
# Validation Loss = 2.454
# Epoch=17, batch = 13000 of 14253, loss=3.453, LR=9.549150281252631e-05
# Validation Loss = 2.781
# Epoch=17, batch = 14000 of 14253, loss=3.579, LR=9.549150281252631e-05
# Validation Loss = 2.835
# Epoch=18, batch = 0 of 14253, loss=3.647, LR=5.4496737905816096e-05
# Validation Loss = 3.171
# Epoch=18, batch = 1000 of 14253, loss=3.077, LR=5.4496737905816096e-05
# Validation Loss = 2.267
# Epoch=18, batch = 2000 of 14253, loss=3.781, LR=5.4496737905816096e-05
# Validation Loss = 1.598
# Epoch=18, batch = 3000 of 14253, loss=3.207, LR=5.4496737905816096e-05
# Validation Loss = 2.650
# Epoch=18, batch = 4000 of 14253, loss=3.113, LR=5.4496737905816096e-05
# Validation Loss = 2.084
# Epoch=18, batch = 5000 of 14253, loss=3.628, LR=5.4496737905816096e-05
# Validation Loss = 2.760
# Epoch=18, batch = 6000 of 14253, loss=3.548, LR=5.4496737905816096e-05
# Validation Loss = 2.468
# Epoch=18, batch = 7000 of 14253, loss=3.566, LR=5.4496737905816096e-05
# Validation Loss = 3.745
# Epoch=18, batch = 8000 of 14253, loss=3.033, LR=5.4496737905816096e-05
# Validation Loss = 1.595
# Epoch=18, batch = 9000 of 14253, loss=3.389, LR=5.4496737905816096e-05
# Validation Loss = 2.457
# Epoch=18, batch = 10000 of 14253, loss=3.515, LR=5.4496737905816096e-05
# Validation Loss = 2.658
# Epoch=18, batch = 11000 of 14253, loss=3.451, LR=5.4496737905816096e-05
# Validation Loss = 3.509
# Epoch=18, batch = 12000 of 14253, loss=3.896, LR=5.4496737905816096e-05
# Validation Loss = 3.003
# Epoch=18, batch = 13000 of 14253, loss=3.375, LR=5.4496737905816096e-05
# Validation Loss = 3.266
# Epoch=18, batch = 14000 of 14253, loss=3.600, LR=5.4496737905816096e-05
# Validation Loss = 3.332
# Epoch=19, batch = 0 of 14253, loss=3.856, LR=2.447174185242323e-05
# Validation Loss = 2.539
# Epoch=19, batch = 1000 of 14253, loss=3.847, LR=2.447174185242323e-05
# Validation Loss = 2.709
# Epoch=19, batch = 2000 of 14253, loss=3.445, LR=2.447174185242323e-05
# Validation Loss = 2.743
# Epoch=19, batch = 3000 of 14253, loss=3.276, LR=2.447174185242323e-05
# Validation Loss = 2.388
# Epoch=19, batch = 4000 of 14253, loss=3.173, LR=2.447174185242323e-05
# Validation Loss = 2.504
# Epoch=19, batch = 5000 of 14253, loss=3.300, LR=2.447174185242323e-05
# Validation Loss = 2.254
# Epoch=19, batch = 6000 of 14253, loss=3.434, LR=2.447174185242323e-05
# Validation Loss = 2.578
# Epoch=19, batch = 7000 of 14253, loss=3.553, LR=2.447174185242323e-05
# Validation Loss = 2.672
# Epoch=19, batch = 8000 of 14253, loss=4.843, LR=2.447174185242323e-05
# Validation Loss = 2.486
# Epoch=19, batch = 9000 of 14253, loss=3.716, LR=2.447174185242323e-05
# Validation Loss = 2.928
# Epoch=19, batch = 10000 of 14253, loss=3.677, LR=2.447174185242323e-05
# Validation Loss = 2.182
# Epoch=19, batch = 11000 of 14253, loss=3.283, LR=2.447174185242323e-05
# Validation Loss = 2.491
# Epoch=19, batch = 12000 of 14253, loss=3.523, LR=2.447174185242323e-05
# Validation Loss = 2.845
# Epoch=19, batch = 13000 of 14253, loss=4.598, LR=2.447174185242323e-05
# Validation Loss = 2.344
# Epoch=19, batch = 14000 of 14253, loss=3.334, LR=2.447174185242323e-05
# Validation Loss = 2.597
# Epoch=20, batch = 0 of 14253, loss=3.471, LR=6.15582970243117e-06
# Validation Loss = 2.638
# Epoch=20, batch = 1000 of 14253, loss=3.569, LR=6.15582970243117e-06
# Validation Loss = 2.520
# Epoch=20, batch = 2000 of 14253, loss=3.350, LR=6.15582970243117e-06
# Validation Loss = 2.909
# Epoch=20, batch = 3000 of 14253, loss=3.307, LR=6.15582970243117e-06
# Validation Loss = 2.937
# Epoch=20, batch = 4000 of 14253, loss=3.530, LR=6.15582970243117e-06
# Validation Loss = 2.996
# Epoch=20, batch = 5000 of 14253, loss=3.543, LR=6.15582970243117e-06
# Validation Loss = 2.887
# Epoch=20, batch = 6000 of 14253, loss=3.843, LR=6.15582970243117e-06
# Validation Loss = 2.678
# Epoch=20, batch = 7000 of 14253, loss=4.133, LR=6.15582970243117e-06
# Validation Loss = 2.662
# Epoch=20, batch = 8000 of 14253, loss=3.575, LR=6.15582970243117e-06
# Validation Loss = 2.736
# Epoch=20, batch = 9000 of 14253, loss=3.355, LR=6.15582970243117e-06
# Validation Loss = 2.656
# Epoch=20, batch = 10000 of 14253, loss=3.808, LR=6.15582970243117e-06
# Validation Loss = 2.755
# Epoch=20, batch = 11000 of 14253, loss=2.975, LR=6.15582970243117e-06
# Validation Loss = 2.553
# Epoch=20, batch = 12000 of 14253, loss=3.679, LR=6.15582970243117e-06
# Validation Loss = 2.445
# ...
# Validation Loss = 21.988
# Epoch=1, batch = 7000 of 14253, loss=3.886, LR=0.001
# Validation Loss = 29.333
# Epoch=1, batch = 8000 of 14253, loss=3.644, LR=0.001
# Validation Loss = 25.931
# Epoch=1, batch = 9000 of 14253, loss=3.633, LR=0.001
# Validation Loss = 24.796
# Epoch=1, batch = 10000 of 14253, loss=4.333, LR=0.001
# Validation Loss = 21.430
# Epoch=1, batch = 11000 of 14253, loss=3.562, LR=0.001
# Validation Loss = 22.671
# Epoch=1, batch = 12000 of 14253, loss=3.459, LR=0.001
# Validation Loss = 33.959
# Epoch=1, batch = 13000 of 14253, loss=3.459, LR=0.001
# Validation Loss = 4.967
# Epoch=1, batch = 14000 of 14253, loss=5.913, LR=0.001
# Validation Loss = 22.773
# Epoch=2, batch = 0 of 14253, loss=4.024, LR=0.0009045084971874737
# Validation Loss = 19.589
# Epoch=2, batch = 1000 of 14253, loss=3.648, LR=0.0009045084971874737
# Validation Loss = 9.806
# Epoch=2, batch = 2000 of 14253, loss=3.660, LR=0.0009045084971874737
# Validation Loss = 4.705
# Epoch=2, batch = 3000 of 14253, loss=3.881, LR=0.0009045084971874737
# Validation Loss = 7.330
# Epoch=2, batch = 4000 of 14253, loss=4.094, LR=0.0009045084971874737
# Validation Loss = 0.297
# Epoch=2, batch = 5000 of 14253, loss=3.389, LR=0.0009045084971874737
# Validation Loss = 0.589
# Epoch=2, batch = 6000 of 14253, loss=3.575, LR=0.0009045084971874737
# Validation Loss = 3.600
# Epoch=2, batch = 7000 of 14253, loss=3.869, LR=0.0009045084971874737
# Validation Loss = 1.653
# Epoch=2, batch = 8000 of 14253, loss=3.364, LR=0.0009045084971874737
# Validation Loss = 5.317
# Epoch=2, batch = 9000 of 14253, loss=3.073, LR=0.0009045084971874737
# Validation Loss = 9.788
# Epoch=2, batch = 10000 of 14253, loss=9.965, LR=0.0009045084971874737
# Validation Loss = 4.596
# Epoch=2, batch = 11000 of 14253, loss=3.476, LR=0.0009045084971874737
# Validation Loss = 0.017
# Epoch=2, batch = 12000 of 14253, loss=3.323, LR=0.0009045084971874737
# Validation Loss = 0.515
# Epoch=2, batch = 13000 of 14253, loss=3.417, LR=0.0009045084971874737
# Validation Loss = 6.845
# Epoch=2, batch = 14000 of 14253, loss=2.627, LR=0.0009045084971874737
# Validation Loss = 1.403
# Epoch=3, batch = 0 of 14253, loss=2.726, LR=0.0006545084971874737
# Validation Loss = 3.190
# Epoch=3, batch = 1000 of 14253, loss=3.026, LR=0.0006545084971874737
# Validation Loss = 2.346
# Epoch=3, batch = 2000 of 14253, loss=3.106, LR=0.0006545084971874737
# Validation Loss = 5.647
# Epoch=3, batch = 3000 of 14253, loss=3.393, LR=0.0006545084971874737
# Validation Loss = 0.019
# Epoch=3, batch = 4000 of 14253, loss=2.947, LR=0.0006545084971874737
# Validation Loss = 7.965
# Epoch=3, batch = 5000 of 14253, loss=3.057, LR=0.0006545084971874737
# Validation Loss = 0.425
# Epoch=3, batch = 6000 of 14253, loss=2.764, LR=0.0006545084971874737
# Validation Loss = 3.562
# Epoch=3, batch = 7000 of 14253, loss=3.322, LR=0.0006545084971874737
# Validation Loss = 5.465
# Epoch=3, batch = 8000 of 14253, loss=2.634, LR=0.0006545084971874737
# Validation Loss = 0.765
# Epoch=3, batch = 9000 of 14253, loss=3.618, LR=0.0006545084971874737
# Validation Loss = 2.784
# Epoch=3, batch = 10000 of 14253, loss=2.888, LR=0.0006545084971874737
# Validation Loss = 3.035
# Epoch=3, batch = 11000 of 14253, loss=3.345, LR=0.0006545084971874737
# Validation Loss = 1.605
# Epoch=3, batch = 12000 of 14253, loss=2.866, LR=0.0006545084971874737
# Validation Loss = 0.071
# Epoch=3, batch = 13000 of 14253, loss=2.699, LR=0.0006545084971874737
# Validation Loss = 1.244
# Epoch=3, batch = 14000 of 14253, loss=3.087, LR=0.0006545084971874737
# Validation Loss = 0.044
# Epoch=4, batch = 0 of 14253, loss=2.753, LR=0.00034549150281252633
# Validation Loss = 0.169
# Epoch=4, batch = 1000 of 14253, loss=2.865, LR=0.00034549150281252633
# Validation Loss = 0.349
# Epoch=4, batch = 2000 of 14253, loss=3.037, LR=0.00034549150281252633
# Validation Loss = 0.689
# Epoch=4, batch = 3000 of 14253, loss=2.963, LR=0.00034549150281252633
# Validation Loss = 5.356
# Epoch=4, batch = 4000 of 14253, loss=2.387, LR=0.00034549150281252633
# Validation Loss = 4.808
# Epoch=4, batch = 5000 of 14253, loss=2.590, LR=0.00034549150281252633
# Validation Loss = 0.118
# Epoch=4, batch = 6000 of 14253, loss=2.675, LR=0.00034549150281252633
# Validation Loss = 0.158
# Epoch=4, batch = 7000 of 14253, loss=2.654, LR=0.00034549150281252633
# Validation Loss = 0.006
# Epoch=4, batch = 8000 of 14253, loss=2.691, LR=0.00034549150281252633
# Validation Loss = 0.171
# Epoch=4, batch = 9000 of 14253, loss=2.699, LR=0.00034549150281252633
# Validation Loss = 0.020
# Epoch=4, batch = 10000 of 14253, loss=2.601, LR=0.00034549150281252633
# Validation Loss = 0.334
# Epoch=4, batch = 11000 of 14253, loss=2.766, LR=0.00034549150281252633
# Validation Loss = 0.313
# Epoch=4, batch = 12000 of 14253, loss=3.248, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=4, batch = 13000 of 14253, loss=2.627, LR=0.00034549150281252633
# Validation Loss = 2.451
# Epoch=4, batch = 14000 of 14253, loss=2.654, LR=0.00034549150281252633
# Validation Loss = 0.625
# Epoch=5, batch = 0 of 14253, loss=2.842, LR=9.549150281252633e-05
# Validation Loss = 0.368
# Epoch=5, batch = 1000 of 14253, loss=2.660, LR=9.549150281252633e-05
# Validation Loss = 0.071
# Epoch=5, batch = 2000 of 14253, loss=2.427, LR=9.549150281252633e-05
# Validation Loss = 0.007
# Epoch=5, batch = 3000 of 14253, loss=2.909, LR=9.549150281252633e-05
# Validation Loss = 1.079
# Epoch=5, batch = 4000 of 14253, loss=2.697, LR=9.549150281252633e-05
# Validation Loss = 0.028
# Epoch=5, batch = 5000 of 14253, loss=2.905, LR=9.549150281252633e-05
# Validation Loss = 0.169
# Epoch=5, batch = 6000 of 14253, loss=2.695, LR=9.549150281252633e-05
# Validation Loss = 0.097
# Epoch=5, batch = 7000 of 14253, loss=3.266, LR=9.549150281252633e-05
# Validation Loss = 0.099
# Epoch=5, batch = 8000 of 14253, loss=2.913, LR=9.549150281252633e-05
# Validation Loss = 0.797
# Epoch=5, batch = 9000 of 14253, loss=2.481, LR=9.549150281252633e-05
# Validation Loss = 0.039
# Epoch=5, batch = 10000 of 14253, loss=2.057, LR=9.549150281252633e-05
# Validation Loss = 0.791
# Epoch=5, batch = 11000 of 14253, loss=2.384, LR=9.549150281252633e-05
# Validation Loss = 0.001
# Epoch=5, batch = 12000 of 14253, loss=2.758, LR=9.549150281252633e-05
# Validation Loss = 0.294
# Epoch=5, batch = 13000 of 14253, loss=2.653, LR=9.549150281252633e-05
# Validation Loss = 0.002
# Epoch=5, batch = 14000 of 14253, loss=2.419, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.138
# Epoch=1, batch = 0 of 14253, loss=2.437, LR=0.001
# Validation Loss = 21.696
# Epoch=1, batch = 1000 of 14253, loss=3.458, LR=0.001
# Validation Loss = 9.890
# Epoch=1, batch = 2000 of 14253, loss=3.504, LR=0.001
# Validation Loss = 0.398
# Epoch=1, batch = 3000 of 14253, loss=5.257, LR=0.001
# Validation Loss = 1.342
# Epoch=1, batch = 4000 of 14253, loss=4.496, LR=0.001
# Validation Loss = 0.111
# Epoch=1, batch = 5000 of 14253, loss=3.213, LR=0.001
# Validation Loss = 4.527
# Epoch=1, batch = 6000 of 14253, loss=2.543, LR=0.001
# Validation Loss = 8.984
# Epoch=1, batch = 7000 of 14253, loss=3.737, LR=0.001
# Validation Loss = 0.055
# Epoch=1, batch = 8000 of 14253, loss=2.893, LR=0.001
# Validation Loss = 2.724
# Epoch=1, batch = 9000 of 14253, loss=3.012, LR=0.001
# Validation Loss = 1.331
# Epoch=1, batch = 10000 of 14253, loss=2.975, LR=0.001
# Validation Loss = 18.844
# Epoch=1, batch = 11000 of 14253, loss=3.171, LR=0.001
# Validation Loss = 0.917
# Epoch=1, batch = 12000 of 14253, loss=3.068, LR=0.001
# Validation Loss = 6.175
# Epoch=1, batch = 13000 of 14253, loss=3.365, LR=0.001
# Validation Loss = 0.097
# Epoch=1, batch = 14000 of 14253, loss=3.725, LR=0.001
# Validation Loss = 4.462
# Epoch=2, batch = 0 of 14253, loss=3.508, LR=0.0009755282581475768
# Validation Loss = 0.159
# Epoch=2, batch = 1000 of 14253, loss=3.202, LR=0.0009755282581475768
# Validation Loss = 1.122
# Epoch=2, batch = 2000 of 14253, loss=2.634, LR=0.0009755282581475768
# Validation Loss = 0.000
# Epoch=2, batch = 3000 of 14253, loss=2.978, LR=0.0009755282581475768
# Validation Loss = 0.029
# Epoch=2, batch = 4000 of 14253, loss=2.922, LR=0.0009755282581475768
# Validation Loss = 4.930
# Epoch=2, batch = 5000 of 14253, loss=5.042, LR=0.0009755282581475768
# Validation Loss = 1.450
# Epoch=2, batch = 6000 of 14253, loss=2.669, LR=0.0009755282581475768
# Validation Loss = 0.954
# Epoch=2, batch = 7000 of 14253, loss=3.333, LR=0.0009755282581475768
# Validation Loss = 0.553
# Epoch=2, batch = 8000 of 14253, loss=2.941, LR=0.0009755282581475768
# Validation Loss = 0.655
# Epoch=2, batch = 9000 of 14253, loss=4.169, LR=0.0009755282581475768
# Validation Loss = 6.070
# Epoch=2, batch = 10000 of 14253, loss=3.555, LR=0.0009755282581475768
# Validation Loss = 0.568
# Epoch=2, batch = 11000 of 14253, loss=3.105, LR=0.0009755282581475768
# Validation Loss = 3.882
# Epoch=2, batch = 12000 of 14253, loss=2.748, LR=0.0009755282581475768
# Validation Loss = 0.976
# Epoch=2, batch = 13000 of 14253, loss=2.732, LR=0.0009755282581475768
# Validation Loss = 0.177
# Epoch=2, batch = 14000 of 14253, loss=2.707, LR=0.0009755282581475768
# Validation Loss = 1.527
# Epoch=3, batch = 0 of 14253, loss=2.597, LR=0.0009045084971874736
# Validation Loss = 0.353
# Epoch=3, batch = 1000 of 14253, loss=3.380, LR=0.0009045084971874736
# Validation Loss = 0.004
# Epoch=3, batch = 2000 of 14253, loss=2.696, LR=0.0009045084971874736
# Validation Loss = 4.643
# Epoch=3, batch = 3000 of 14253, loss=3.161, LR=0.0009045084971874736
# Validation Loss = 2.277
# Epoch=3, batch = 4000 of 14253, loss=2.459, LR=0.0009045084971874736
# Validation Loss = 7.799
# Epoch=3, batch = 5000 of 14253, loss=5.562, LR=0.0009045084971874736
# Validation Loss = 4.057
# Epoch=3, batch = 6000 of 14253, loss=4.761, LR=0.0009045084971874736
# Validation Loss = 2.589
# Epoch=3, batch = 7000 of 14253, loss=2.571, LR=0.0009045084971874736
# Validation Loss = 1.669
# Epoch=3, batch = 8000 of 14253, loss=3.847, LR=0.0009045084971874736
# Validation Loss = 0.073
# Epoch=3, batch = 9000 of 14253, loss=3.052, LR=0.0009045084971874736
# Validation Loss = 0.086
# Epoch=3, batch = 10000 of 14253, loss=2.713, LR=0.0009045084971874736
# Validation Loss = 0.689
# Epoch=3, batch = 11000 of 14253, loss=2.926, LR=0.0009045084971874736
# Validation Loss = 0.493
# Epoch=3, batch = 12000 of 14253, loss=2.863, LR=0.0009045084971874736
# Validation Loss = 0.003
# Epoch=3, batch = 13000 of 14253, loss=3.418, LR=0.0009045084971874736
# Validation Loss = 0.309
# Epoch=3, batch = 14000 of 14253, loss=4.019, LR=0.0009045084971874736
# Validation Loss = 6.177
# Epoch=4, batch = 0 of 14253, loss=2.603, LR=0.0007938926261462366
# Validation Loss = 0.658
# Epoch=4, batch = 1000 of 14253, loss=3.546, LR=0.0007938926261462366
# Validation Loss = 0.001
# Epoch=4, batch = 2000 of 14253, loss=3.046, LR=0.0007938926261462366
# Validation Loss = 0.077
# Epoch=4, batch = 3000 of 14253, loss=3.103, LR=0.0007938926261462366
# Validation Loss = 1.624
# Epoch=17, batch = 3000 of 14253, loss=2.231, LR=9.549150281252631e-05
# Validation Loss = 2.822
# Epoch=17, batch = 4000 of 14253, loss=2.206, LR=9.549150281252631e-05
# Validation Loss = 2.738
# Epoch=17, batch = 5000 of 14253, loss=2.169, LR=9.549150281252631e-05
# Validation Loss = 2.129
# Epoch=17, batch = 6000 of 14253, loss=2.315, LR=9.549150281252631e-05
# Validation Loss = 0.123
# Epoch=17, batch = 7000 of 14253, loss=2.127, LR=9.549150281252631e-05
# Validation Loss = 3.346
# Epoch=17, batch = 8000 of 14253, loss=2.238, LR=9.549150281252631e-05
# Validation Loss = 3.212
# Epoch=17, batch = 9000 of 14253, loss=2.506, LR=9.549150281252631e-05
# Validation Loss = 2.267
# Epoch=17, batch = 10000 of 14253, loss=2.188, LR=9.549150281252631e-05
# Validation Loss = 3.574
# Epoch=17, batch = 11000 of 14253, loss=2.350, LR=9.549150281252631e-05
# Validation Loss = 3.850
# Epoch=17, batch = 12000 of 14253, loss=2.237, LR=9.549150281252631e-05
# Validation Loss = 2.746
# Epoch=17, batch = 13000 of 14253, loss=1.982, LR=9.549150281252631e-05
# Validation Loss = 1.840
# Epoch=17, batch = 14000 of 14253, loss=2.403, LR=9.549150281252631e-05
# Validation Loss = 1.303
# Epoch=18, batch = 0 of 14253, loss=2.263, LR=5.4496737905816096e-05
# Validation Loss = 2.931
# Epoch=18, batch = 1000 of 14253, loss=2.293, LR=5.4496737905816096e-05
# Validation Loss = 0.812
# Epoch=18, batch = 2000 of 14253, loss=2.499, LR=5.4496737905816096e-05
# Validation Loss = 4.033
# Epoch=18, batch = 3000 of 14253, loss=2.360, LR=5.4496737905816096e-05
# Validation Loss = 3.445
# Epoch=18, batch = 4000 of 14253, loss=2.343, LR=5.4496737905816096e-05
# Validation Loss = 2.373
# Epoch=18, batch = 5000 of 14253, loss=2.288, LR=5.4496737905816096e-05
# Validation Loss = 3.689
# Epoch=18, batch = 6000 of 14253, loss=2.339, LR=5.4496737905816096e-05
# Validation Loss = 1.848
# Epoch=18, batch = 7000 of 14253, loss=2.011, LR=5.4496737905816096e-05
# Validation Loss = 3.669
# Epoch=18, batch = 8000 of 14253, loss=2.152, LR=5.4496737905816096e-05
# Validation Loss = 4.173
# Epoch=18, batch = 9000 of 14253, loss=2.077, LR=5.4496737905816096e-05
# Validation Loss = 2.443
# Epoch=18, batch = 10000 of 14253, loss=1.944, LR=5.4496737905816096e-05
# Validation Loss = 0.880
# Epoch=18, batch = 11000 of 14253, loss=2.021, LR=5.4496737905816096e-05
# Validation Loss = 1.465
# Epoch=18, batch = 12000 of 14253, loss=2.201, LR=5.4496737905816096e-05
# Validation Loss = 3.666
# Epoch=18, batch = 13000 of 14253, loss=2.072, LR=5.4496737905816096e-05
# Validation Loss = 2.950
# Epoch=18, batch = 14000 of 14253, loss=2.051, LR=5.4496737905816096e-05
# Validation Loss = 1.058
# Epoch=19, batch = 0 of 14253, loss=2.256, LR=2.447174185242323e-05
# Validation Loss = 1.108
# Epoch=19, batch = 1000 of 14253, loss=2.442, LR=2.447174185242323e-05
# Validation Loss = 2.354
# Epoch=19, batch = 2000 of 14253, loss=2.017, LR=2.447174185242323e-05
# Validation Loss = 1.401
# Epoch=19, batch = 3000 of 14253, loss=2.036, LR=2.447174185242323e-05
# Validation Loss = 0.844
# Epoch=19, batch = 4000 of 14253, loss=1.973, LR=2.447174185242323e-05
# Validation Loss = 0.333
# Epoch=19, batch = 5000 of 14253, loss=2.089, LR=2.447174185242323e-05
# Validation Loss = 2.720
# Epoch=19, batch = 6000 of 14253, loss=2.487, LR=2.447174185242323e-05
# Validation Loss = 2.206
# Epoch=19, batch = 7000 of 14253, loss=2.364, LR=2.447174185242323e-05
# Validation Loss = 3.423
# Epoch=19, batch = 8000 of 14253, loss=2.028, LR=2.447174185242323e-05
# Validation Loss = 1.950
# Epoch=19, batch = 9000 of 14253, loss=1.998, LR=2.447174185242323e-05
# Validation Loss = 2.304
# Epoch=19, batch = 10000 of 14253, loss=2.085, LR=2.447174185242323e-05
# Validation Loss = 2.508
# Epoch=19, batch = 11000 of 14253, loss=2.260, LR=2.447174185242323e-05
# Validation Loss = 2.280
# Epoch=19, batch = 12000 of 14253, loss=2.166, LR=2.447174185242323e-05
# Validation Loss = 1.304
# Epoch=19, batch = 13000 of 14253, loss=1.970, LR=2.447174185242323e-05
# Validation Loss = 3.384
# Epoch=19, batch = 14000 of 14253, loss=2.211, LR=2.447174185242323e-05
# Validation Loss = 2.245
# Epoch=20, batch = 0 of 14253, loss=2.230, LR=6.15582970243117e-06
# Validation Loss = 1.799
# Epoch=20, batch = 1000 of 14253, loss=2.295, LR=6.15582970243117e-06
# Validation Loss = 2.710
# Epoch=20, batch = 2000 of 14253, loss=2.054, LR=6.15582970243117e-06
# Validation Loss = 2.144
# Epoch=20, batch = 3000 of 14253, loss=1.979, LR=6.15582970243117e-06
# Validation Loss = 2.804
# Epoch=20, batch = 4000 of 14253, loss=2.181, LR=6.15582970243117e-06
# Validation Loss = 2.310
# Epoch=20, batch = 5000 of 14253, loss=2.140, LR=6.15582970243117e-06
# Validation Loss = 2.251
# Epoch=20, batch = 6000 of 14253, loss=2.271, LR=6.15582970243117e-06
# Validation Loss = 1.649
# Epoch=20, batch = 7000 of 14253, loss=2.142, LR=6.15582970243117e-06
# Validation Loss = 2.738
# Epoch=20, batch = 8000 of 14253, loss=2.126, LR=6.15582970243117e-06
# Validation Loss = 2.191
# Epoch=20, batch = 9000 of 14253, loss=2.138, LR=6.15582970243117e-06
# Validation Loss = 2.543
# Epoch=20, batch = 10000 of 14253, loss=2.131, LR=6.15582970243117e-06
# Validation Loss = 3.046
# Epoch=20, batch = 11000 of 14253, loss=2.001, LR=6.15582970243117e-06
# Validation Loss = 2.688
# Epoch=20, batch = 12000 of 14253, loss=2.314, LR=6.15582970243117e-06
# Validation Loss = 2.398
# Epoch=20, batch = 13000 of 14253, loss=2.249, LR=6.15582970243117e-06
# Validation Loss = 2.593
# Epoch=20, batch = 14000 of 14253, loss=2.238, LR=6.15582970243117e-06
# Finished training model for channel 183+-7V.
