# %% [markdown]
# # Channel Prediction Model for Quality Control
#
# This notebook contains the code and outlines the development of the
# GMI Channel Prediction Neural Network for QC purposes of GMI L1C
# data. The simple Feed-Forward Neural Networks (FFNNs) are trained on
# good quality brightness temperature observation vectors and are
# trained to predict one channel from all the others as predictors.
#
# The end product is a tree of FFNNs, discretized by surface (ocean or
# land), and by channel, since these are fully distinct problems.

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import glob
import torch
from torch import nn
import cartopy.crs as ccrs
from util_funcs.L1C import scantime2datetime
from util_funcs import data2xarray, array_funcs
import geography
from tqdm import tqdm

from dataset_class import dataset
from model_class import channel_predictor
import local_functions
import sensor_info


#General parameters:

satellite = sensor_info.satellite
sensor = sensor_info.sensor

nchans = sensor_info.nchannels - 2
batch_size = 1000
input_size = nchans - 1
hidden_size = 256
output_size = 1

# %%
'''
Function Definitions:
'''

chan_desc = sensor_info.channel_descriptions
chan_desc = chan_desc[2:]


def extract_channel(Tb_array, chan):

    '''
    Use in preparing training data.

    Assumes Tb array is [m x n] where m (rows) are samples
    and n (columns) is the number of channels.

    Passing in the channel description splits the data so
    that the specified channel is its own vector y and the
    rest are kept as predictors x.

    Inputs:
        Tb_array    |  ndarray of Tbs
        chan        |  string of channel name
    Outputs:
        x           |  matrix of predictors (other channels)
        y           |  vector of predictands (the missing channel)
        
    '''
    
    chan_desc = np.array(sensor_info.channel_descriptions)
    chan_desc = chan_desc[2:]


    chan_indx = np.where(chan == chan_desc)[0]

    if np.size(chan_indx) == 0:
        raise ValueError(f'Channel description must be in list {chan_desc}.')

    y = Tb_array[:,chan_indx]
    x = Tb_array[:,np.delete(np.arange(0,len(chan_desc)),chan_indx)]

    return x, y


def train_model(model, nepochs, dataloader, learning_rate=0.001, quiet=False, stage=None, validation_dataloader=None):

    nbatches = len(dataloader)
    
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=nepochs)
    device = None

    if stage:
        print(f'Training stage: {stage}')

    loss_arr    = np.zeros([nbatches,nepochs], dtype='f')
    valloss_arr = np.zeros([nbatches,nepochs], dtype='f')
    
    for epoch in range(nepochs):
        for i, (profs, obs) in enumerate(dataloader):
            if device:
                profs, obs = profs.to(device), obs.to(device)

            if validation_dataloader and i%1000==0:
                valprofs, valobs = next(enumerate(validation_dataloader))[1]
                val_pred = model(valprofs)
                valloss  = criterion(val_pred, valobs)
                print(f'Validation Loss = {valloss.item():.3f}')

            #Forward pass:
            obs_pred = model(profs)
            loss     = criterion(obs_pred, obs)


            #Backward pass:
            optimizer.zero_grad()
            loss.backward()

            #Update neurons:
            optimizer.step()

            loss_arr[i,epoch] = loss.item()
            valloss_arr[i,epoch] = valloss.item()
            
            if not quiet:
                if i%1000 == 0:
                    print(f'Epoch={epoch+1}, batch = {i} of {nbatches}, loss={loss.item():.3f}, LR={scheduler.get_last_lr()[0]}')
        
        scheduler.step()




    return loss_arr, valloss_arr

# %%
chan_desc
# Out:
# ['19V',
#  '19H',
#  '24V',
#  '37V',
#  '37H',
#  '89V',
#  '89H',
#  '166V',
#  '166H',
#  '183+-3V',
#  '183+-7V']

# %%
'''

GMI CHANNEL PREDICTION MODEL:
    1: Ocean

'''

sfc = [1]

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = np.isin(sfctype, sfc)
    sfcindcs = np.where(correct_sfc)[0]

    Tbs = f.Tbs.values[sfcindcs]

#---Don't shuffle data before splitting
#np.random.seed(40)
#Tbs = array_funcs.shuffle_data(Tbs, axis=0)

if Tbs.shape[0] > 5.0e+06:
    Tbs = Tbs[:5_000_000,:]

Tbs = Tbs[:,2:]

print(Tbs.shape)

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train = array_funcs.shuffle_data(Tbs_train, axis=0)
# Out:
# (5000000, 11)

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    # if channel == '10V' or channel == '10H':
    #     continue

    print(channel)
    
    x_train = Tbs_train
    y_train = extract_channel(Tbs_train, channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_ocean_no10.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_ocean_no10.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 19V
# Training stage: 1
# Validation Loss = 35131.027
# Epoch=1, batch = 0 of 4000, loss=34743.227, LR=0.001
# Validation Loss = 0.878
# Epoch=1, batch = 1000 of 4000, loss=0.775, LR=0.001
# Validation Loss = 1.266
# Epoch=1, batch = 2000 of 4000, loss=0.844, LR=0.001
# Validation Loss = 1.735
# Epoch=1, batch = 3000 of 4000, loss=1.288, LR=0.001
# Validation Loss = 0.097
# Epoch=2, batch = 0 of 4000, loss=0.619, LR=0.0009045084971874737
# Validation Loss = 3.384
# Epoch=2, batch = 1000 of 4000, loss=2.097, LR=0.0009045084971874737
# Validation Loss = 1.186
# Epoch=2, batch = 2000 of 4000, loss=1.003, LR=0.0009045084971874737
# Validation Loss = 0.199
# Epoch=2, batch = 3000 of 4000, loss=0.616, LR=0.0009045084971874737
# Validation Loss = 0.490
# Epoch=3, batch = 0 of 4000, loss=0.694, LR=0.0006545084971874737
# Validation Loss = 0.576
# Epoch=3, batch = 1000 of 4000, loss=0.729, LR=0.0006545084971874737
# Validation Loss = 0.644
# Epoch=3, batch = 2000 of 4000, loss=0.736, LR=0.0006545084971874737
# Validation Loss = 6.747
# Epoch=3, batch = 3000 of 4000, loss=5.588, LR=0.0006545084971874737
# Validation Loss = 0.020
# Epoch=4, batch = 0 of 4000, loss=0.636, LR=0.00034549150281252633
# Validation Loss = 0.084
# Epoch=4, batch = 1000 of 4000, loss=0.572, LR=0.00034549150281252633
# Validation Loss = 0.206
# Epoch=4, batch = 2000 of 4000, loss=0.581, LR=0.00034549150281252633
# Validation Loss = 0.140
# Epoch=4, batch = 3000 of 4000, loss=0.620, LR=0.00034549150281252633
# Validation Loss = 0.260
# Epoch=5, batch = 0 of 4000, loss=0.564, LR=9.549150281252633e-05
# Validation Loss = 0.085
# Epoch=5, batch = 1000 of 4000, loss=0.537, LR=9.549150281252633e-05
# Validation Loss = 0.039
# Epoch=5, batch = 2000 of 4000, loss=0.562, LR=9.549150281252633e-05
# Validation Loss = 0.162
# Epoch=5, batch = 3000 of 4000, loss=0.591, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.079
# Epoch=1, batch = 0 of 4000, loss=0.506, LR=0.001
# Validation Loss = 0.132
# Epoch=1, batch = 1000 of 4000, loss=0.496, LR=0.001
# Validation Loss = 0.467
# Epoch=1, batch = 2000 of 4000, loss=0.721, LR=0.001
# Validation Loss = 2.972
# Epoch=1, batch = 3000 of 4000, loss=4.483, LR=0.001
# Validation Loss = 0.153
# Epoch=2, batch = 0 of 4000, loss=0.573, LR=0.0009755282581475768
# Validation Loss = 0.009
# Epoch=2, batch = 1000 of 4000, loss=0.601, LR=0.0009755282581475768
# Validation Loss = 1.223
# Epoch=2, batch = 2000 of 4000, loss=1.314, LR=0.0009755282581475768
# Validation Loss = 0.012
# Epoch=2, batch = 3000 of 4000, loss=0.618, LR=0.0009755282581475768
# Validation Loss = 0.001
# Epoch=3, batch = 0 of 4000, loss=0.666, LR=0.0009045084971874736
# Validation Loss = 0.233
# Epoch=3, batch = 1000 of 4000, loss=0.972, LR=0.0009045084971874736
# Validation Loss = 0.017
# Epoch=3, batch = 2000 of 4000, loss=0.526, LR=0.0009045084971874736
# Validation Loss = 0.347
# Epoch=3, batch = 3000 of 4000, loss=1.231, LR=0.0009045084971874736
# Validation Loss = 0.644
# Epoch=4, batch = 0 of 4000, loss=1.793, LR=0.0007938926261462366
# Validation Loss = 0.069
# Epoch=4, batch = 1000 of 4000, loss=0.566, LR=0.0007938926261462366
# Validation Loss = 0.819
# Epoch=4, batch = 2000 of 4000, loss=0.945, LR=0.0007938926261462366
# Validation Loss = 0.024
# Epoch=4, batch = 3000 of 4000, loss=0.703, LR=0.0007938926261462366
# Validation Loss = 1.506
# Epoch=5, batch = 0 of 4000, loss=1.587, LR=0.0006545084971874737
# Validation Loss = 0.468
# Epoch=5, batch = 1000 of 4000, loss=0.734, LR=0.0006545084971874737
# Validation Loss = 1.365
# Epoch=5, batch = 2000 of 4000, loss=1.485, LR=0.0006545084971874737
# Validation Loss = 0.499
# Epoch=5, batch = 3000 of 4000, loss=0.695, LR=0.0006545084971874737
# Validation Loss = 0.567
# Epoch=6, batch = 0 of 4000, loss=0.847, LR=0.0005
# Validation Loss = 0.316
# Epoch=6, batch = 1000 of 4000, loss=0.620, LR=0.0005
# Validation Loss = 0.001
# Epoch=6, batch = 2000 of 4000, loss=0.550, LR=0.0005
# Validation Loss = 0.109
# Epoch=6, batch = 3000 of 4000, loss=0.548, LR=0.0005
# Validation Loss = 0.000
# Epoch=7, batch = 0 of 4000, loss=0.574, LR=0.00034549150281252633
# Validation Loss = 0.082
# Epoch=7, batch = 1000 of 4000, loss=0.499, LR=0.00034549150281252633
# Validation Loss = 0.379
# Epoch=7, batch = 2000 of 4000, loss=0.632, LR=0.00034549150281252633
# Validation Loss = 0.576
# Epoch=7, batch = 3000 of 4000, loss=0.746, LR=0.00034549150281252633
# Validation Loss = 0.019
# Epoch=8, batch = 0 of 4000, loss=0.518, LR=0.0002061073738537635
# Validation Loss = 0.117
# Epoch=8, batch = 1000 of 4000, loss=0.510, LR=0.0002061073738537635
# Validation Loss = 0.249
# Epoch=8, batch = 2000 of 4000, loss=0.583, LR=0.0002061073738537635
# Validation Loss = 0.014
# Epoch=8, batch = 3000 of 4000, loss=0.557, LR=0.0002061073738537635
# Validation Loss = 0.040
# Epoch=9, batch = 0 of 4000, loss=0.494, LR=9.549150281252634e-05
# Validation Loss = 0.039
# Epoch=9, batch = 1000 of 4000, loss=0.529, LR=9.549150281252634e-05
# Validation Loss = 0.006
# Epoch=9, batch = 2000 of 4000, loss=0.539, LR=9.549150281252634e-05
# Validation Loss = 0.000
# Epoch=9, batch = 3000 of 4000, loss=0.522, LR=9.549150281252634e-05
# Validation Loss = 0.015
# Epoch=10, batch = 0 of 4000, loss=0.541, LR=2.4471741852423235e-05
# Validation Loss = 0.053
# Epoch=10, batch = 1000 of 4000, loss=0.499, LR=2.4471741852423235e-05
# Validation Loss = 0.070
# Epoch=10, batch = 2000 of 4000, loss=0.489, LR=2.4471741852423235e-05
# Validation Loss = 0.039
# Epoch=10, batch = 3000 of 4000, loss=0.472, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.062
# Epoch=1, batch = 0 of 4000, loss=0.515, LR=0.001
# Validation Loss = 0.142
# Epoch=1, batch = 1000 of 4000, loss=0.558, LR=0.001
# Validation Loss = 0.254
# Epoch=1, batch = 2000 of 4000, loss=0.531, LR=0.001
# Validation Loss = 0.146
# Epoch=1, batch = 3000 of 4000, loss=0.937, LR=0.001
# Validation Loss = 0.004
# Epoch=2, batch = 0 of 4000, loss=0.656, LR=0.0009938441702975688
# Validation Loss = 1.867
# Epoch=2, batch = 1000 of 4000, loss=2.962, LR=0.0009938441702975688
# Validation Loss = 0.183
# Epoch=2, batch = 2000 of 4000, loss=0.601, LR=0.0009938441702975688
# Validation Loss = 0.063
# Epoch=2, batch = 3000 of 4000, loss=0.528, LR=0.0009938441702975688
# Validation Loss = 0.361
# Epoch=3, batch = 0 of 4000, loss=0.591, LR=0.0009755282581475768
# Validation Loss = 0.393
# Epoch=3, batch = 1000 of 4000, loss=0.734, LR=0.0009755282581475768
# Validation Loss = 0.037
# Epoch=3, batch = 2000 of 4000, loss=0.488, LR=0.0009755282581475768
# Validation Loss = 0.010
# Epoch=3, batch = 3000 of 4000, loss=0.610, LR=0.0009755282581475768
# Validation Loss = 1.259
# Epoch=4, batch = 0 of 4000, loss=2.282, LR=0.0009455032620941839
# Validation Loss = 0.844
# Epoch=4, batch = 1000 of 4000, loss=0.952, LR=0.0009455032620941839
# Validation Loss = 1.646
# Epoch=4, batch = 2000 of 4000, loss=1.662, LR=0.0009455032620941839
# Validation Loss = 0.567
# Epoch=4, batch = 3000 of 4000, loss=0.763, LR=0.0009455032620941839
# Validation Loss = 0.031
# Epoch=5, batch = 0 of 4000, loss=0.546, LR=0.0009045084971874737
# Validation Loss = 0.013
# Epoch=5, batch = 1000 of 4000, loss=0.687, LR=0.0009045084971874737
# Validation Loss = 0.464
# Epoch=5, batch = 2000 of 4000, loss=1.339, LR=0.0009045084971874737
# Validation Loss = 0.176
# Epoch=5, batch = 3000 of 4000, loss=0.976, LR=0.0009045084971874737
# Validation Loss = 0.000
# Epoch=6, batch = 0 of 4000, loss=0.529, LR=0.0008535533905932737
# Validation Loss = 0.001
# Epoch=6, batch = 1000 of 4000, loss=0.568, LR=0.0008535533905932737
# Validation Loss = 0.167
# Epoch=6, batch = 2000 of 4000, loss=0.563, LR=0.0008535533905932737
# Validation Loss = 0.151
# Epoch=6, batch = 3000 of 4000, loss=0.876, LR=0.0008535533905932737
# Validation Loss = 0.644
# Epoch=7, batch = 0 of 4000, loss=0.886, LR=0.0007938926261462366
# Validation Loss = 0.002
# Epoch=7, batch = 1000 of 4000, loss=0.522, LR=0.0007938926261462366
# Validation Loss = 0.084
# Epoch=7, batch = 2000 of 4000, loss=0.756, LR=0.0007938926261462366
# Validation Loss = 0.186
# Epoch=7, batch = 3000 of 4000, loss=0.550, LR=0.0007938926261462366
# Validation Loss = 0.969
# Epoch=8, batch = 0 of 4000, loss=1.021, LR=0.0007269952498697733
# Validation Loss = 0.044
# Epoch=8, batch = 1000 of 4000, loss=0.535, LR=0.0007269952498697733
# Validation Loss = 0.031
# Epoch=8, batch = 2000 of 4000, loss=0.471, LR=0.0007269952498697733
# Validation Loss = 0.000
# Epoch=8, batch = 3000 of 4000, loss=0.563, LR=0.0007269952498697733
# Validation Loss = 0.226
# Epoch=9, batch = 0 of 4000, loss=0.583, LR=0.0006545084971874737
# Validation Loss = 0.010
# Epoch=9, batch = 1000 of 4000, loss=0.614, LR=0.0006545084971874737
# Validation Loss = 0.261
# Epoch=9, batch = 2000 of 4000, loss=0.606, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=9, batch = 3000 of 4000, loss=0.580, LR=0.0006545084971874737
# Validation Loss = 0.004
# Epoch=10, batch = 0 of 4000, loss=0.543, LR=0.0005782172325201155
# Validation Loss = 0.069
# Epoch=10, batch = 1000 of 4000, loss=0.573, LR=0.0005782172325201155
# Validation Loss = 0.030
# Epoch=10, batch = 2000 of 4000, loss=0.463, LR=0.0005782172325201155
# Validation Loss = 0.001
# Epoch=10, batch = 3000 of 4000, loss=0.622, LR=0.0005782172325201155
# Validation Loss = 0.031
# Epoch=11, batch = 0 of 4000, loss=0.513, LR=0.0005
# Validation Loss = 0.226
# Epoch=11, batch = 1000 of 4000, loss=0.642, LR=0.0005
# Validation Loss = 0.112
# Epoch=11, batch = 2000 of 4000, loss=0.477, LR=0.0005
# Validation Loss = 0.000
# Epoch=11, batch = 3000 of 4000, loss=0.527, LR=0.0005
# Validation Loss = 0.003
# Epoch=12, batch = 0 of 4000, loss=0.612, LR=0.0004217827674798847
# Validation Loss = 0.029
# Epoch=12, batch = 1000 of 4000, loss=0.527, LR=0.0004217827674798847
# Validation Loss = 0.041
# Epoch=12, batch = 2000 of 4000, loss=0.530, LR=0.0004217827674798847
# Validation Loss = 0.004
# Epoch=12, batch = 3000 of 4000, loss=0.505, LR=0.0004217827674798847
# Validation Loss = 0.011
# Epoch=13, batch = 0 of 4000, loss=0.487, LR=0.00034549150281252633
# Validation Loss = 0.123
# Epoch=13, batch = 1000 of 4000, loss=0.588, LR=0.00034549150281252633
# Validation Loss = 0.318
# Epoch=13, batch = 2000 of 4000, loss=0.634, LR=0.00034549150281252633
# Validation Loss = 0.020
# Epoch=13, batch = 3000 of 4000, loss=0.516, LR=0.00034549150281252633
# Validation Loss = 0.137
# Epoch=14, batch = 0 of 4000, loss=0.526, LR=0.00027300475013022663
# Validation Loss = 0.069
# Epoch=14, batch = 1000 of 4000, loss=0.508, LR=0.00027300475013022663
# Validation Loss = 0.282
# Epoch=14, batch = 2000 of 4000, loss=0.638, LR=0.00027300475013022663
# Validation Loss = 0.156
# Epoch=14, batch = 3000 of 4000, loss=0.510, LR=0.00027300475013022663
# Validation Loss = 0.057
# Epoch=15, batch = 0 of 4000, loss=0.524, LR=0.00020610737385376348
# Validation Loss = 0.022
# Epoch=15, batch = 1000 of 4000, loss=0.500, LR=0.00020610737385376348
# Validation Loss = 0.056
# Epoch=15, batch = 2000 of 4000, loss=0.517, LR=0.00020610737385376348
# Validation Loss = 0.001
# Epoch=15, batch = 3000 of 4000, loss=0.563, LR=0.00020610737385376348
# Validation Loss = 0.043
# Epoch=16, batch = 0 of 4000, loss=0.481, LR=0.00014644660940672625
# Validation Loss = 0.022
# Epoch=16, batch = 1000 of 4000, loss=0.521, LR=0.00014644660940672625
# Validation Loss = 0.059
# Epoch=16, batch = 2000 of 4000, loss=0.502, LR=0.00014644660940672625
# Validation Loss = 0.018
# Epoch=16, batch = 3000 of 4000, loss=0.493, LR=0.00014644660940672625
# Validation Loss = 0.004
# Epoch=17, batch = 0 of 4000, loss=0.535, LR=9.549150281252631e-05
# Validation Loss = 0.044
# Epoch=17, batch = 1000 of 4000, loss=0.471, LR=9.549150281252631e-05
# Validation Loss = 0.051
# Epoch=17, batch = 2000 of 4000, loss=0.548, LR=9.549150281252631e-05
# Validation Loss = 0.000
# Epoch=17, batch = 3000 of 4000, loss=0.577, LR=9.549150281252631e-05
# Validation Loss = 0.067
# Epoch=18, batch = 0 of 4000, loss=0.508, LR=5.4496737905816096e-05
# Validation Loss = 0.036
# Epoch=18, batch = 1000 of 4000, loss=0.495, LR=5.4496737905816096e-05
# Validation Loss = 0.016
# Epoch=18, batch = 2000 of 4000, loss=0.521, LR=5.4496737905816096e-05
# Validation Loss = 0.045
# Epoch=18, batch = 3000 of 4000, loss=0.531, LR=5.4496737905816096e-05
# Validation Loss = 0.022
# Epoch=19, batch = 0 of 4000, loss=0.511, LR=2.447174185242323e-05
# Validation Loss = 0.008
# Epoch=19, batch = 1000 of 4000, loss=0.523, LR=2.447174185242323e-05
# Validation Loss = 0.009
# Epoch=19, batch = 2000 of 4000, loss=0.513, LR=2.447174185242323e-05
# Validation Loss = 0.004
# Epoch=19, batch = 3000 of 4000, loss=0.503, LR=2.447174185242323e-05
# Validation Loss = 0.030
# Epoch=20, batch = 0 of 4000, loss=0.520, LR=6.15582970243117e-06
# Validation Loss = 0.009
# Epoch=20, batch = 1000 of 4000, loss=0.489, LR=6.15582970243117e-06
# Validation Loss = 0.016
# Epoch=20, batch = 2000 of 4000, loss=0.514, LR=6.15582970243117e-06
# Validation Loss = 0.013
# Epoch=20, batch = 3000 of 4000, loss=0.508, LR=6.15582970243117e-06
# Finished training model for channel 19V.
# 19H
# Training stage: 1
# Validation Loss = 16290.271
# Epoch=1, batch = 0 of 4000, loss=15503.858, LR=0.001
# Validation Loss = 3.057
# Epoch=1, batch = 1000 of 4000, loss=3.365, LR=0.001
# Validation Loss = 3.053
# Epoch=1, batch = 2000 of 4000, loss=2.280, LR=0.001
# Validation Loss = 0.504
# Epoch=1, batch = 3000 of 4000, loss=1.133, LR=0.001
# Validation Loss = 1.179
# Epoch=2, batch = 0 of 4000, loss=1.141, LR=0.0009045084971874737
# Validation Loss = 0.610
# Epoch=2, batch = 1000 of 4000, loss=1.121, LR=0.0009045084971874737
# Validation Loss = 0.003
# Epoch=2, batch = 2000 of 4000, loss=1.408, LR=0.0009045084971874737
# Validation Loss = 0.855
# Epoch=2, batch = 3000 of 4000, loss=0.944, LR=0.0009045084971874737
# Validation Loss = 0.048
# Epoch=3, batch = 0 of 4000, loss=0.870, LR=0.0006545084971874737
# Validation Loss = 0.010
# Epoch=3, batch = 1000 of 4000, loss=1.133, LR=0.0006545084971874737
# Validation Loss = 0.650
# Epoch=3, batch = 2000 of 4000, loss=0.840, LR=0.0006545084971874737
# Validation Loss = 1.747
# Epoch=3, batch = 3000 of 4000, loss=1.149, LR=0.0006545084971874737
# Validation Loss = 0.016
# Epoch=4, batch = 0 of 4000, loss=1.273, LR=0.00034549150281252633
# Validation Loss = 0.523
# Epoch=4, batch = 1000 of 4000, loss=0.750, LR=0.00034549150281252633
# Validation Loss = 0.321
# Epoch=4, batch = 2000 of 4000, loss=0.811, LR=0.00034549150281252633
# Validation Loss = 0.858
# Epoch=4, batch = 3000 of 4000, loss=0.711, LR=0.00034549150281252633
# Validation Loss = 0.123
# Epoch=5, batch = 0 of 4000, loss=0.937, LR=9.549150281252633e-05
# Validation Loss = 0.398
# Epoch=5, batch = 1000 of 4000, loss=0.779, LR=9.549150281252633e-05
# Validation Loss = 0.384
# Epoch=5, batch = 2000 of 4000, loss=0.655, LR=9.549150281252633e-05
# Validation Loss = 0.605
# Epoch=5, batch = 3000 of 4000, loss=0.682, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.657
# Epoch=1, batch = 0 of 4000, loss=0.640, LR=0.001
# Validation Loss = 0.964
# Epoch=1, batch = 1000 of 4000, loss=0.875, LR=0.001
# Validation Loss = 0.010
# Epoch=1, batch = 2000 of 4000, loss=1.128, LR=0.001
# Validation Loss = 0.719
# Epoch=1, batch = 3000 of 4000, loss=0.799, LR=0.001
# Validation Loss = 6.744
# Epoch=2, batch = 0 of 4000, loss=3.770, LR=0.0009755282581475768
# Validation Loss = 2.093
# Epoch=2, batch = 1000 of 4000, loss=1.258, LR=0.0009755282581475768
# Validation Loss = 0.551
# Epoch=2, batch = 2000 of 4000, loss=0.738, LR=0.0009755282581475768
# Validation Loss = 0.459
# Epoch=2, batch = 3000 of 4000, loss=0.730, LR=0.0009755282581475768
# Validation Loss = 2.308
# Epoch=3, batch = 0 of 4000, loss=1.186, LR=0.0009045084971874736
# Validation Loss = 0.056
# Epoch=3, batch = 1000 of 4000, loss=0.776, LR=0.0009045084971874736
# Validation Loss = 0.906
# Epoch=3, batch = 2000 of 4000, loss=0.851, LR=0.0009045084971874736
# Validation Loss = 1.937
# Epoch=3, batch = 3000 of 4000, loss=1.210, LR=0.0009045084971874736
# Validation Loss = 0.749
# Epoch=4, batch = 0 of 4000, loss=0.841, LR=0.0007938926261462366
# Validation Loss = 0.174
# Epoch=4, batch = 1000 of 4000, loss=0.921, LR=0.0007938926261462366
# Validation Loss = 0.135
# Epoch=4, batch = 2000 of 4000, loss=0.702, LR=0.0007938926261462366
# Validation Loss = 0.595
# Epoch=4, batch = 3000 of 4000, loss=0.719, LR=0.0007938926261462366
# Validation Loss = 1.063
# Epoch=5, batch = 0 of 4000, loss=0.955, LR=0.0006545084971874737
# Validation Loss = 0.115
# Epoch=5, batch = 1000 of 4000, loss=0.791, LR=0.0006545084971874737
# Validation Loss = 0.294
# Epoch=5, batch = 2000 of 4000, loss=0.753, LR=0.0006545084971874737
# Validation Loss = 1.013
# Epoch=5, batch = 3000 of 4000, loss=0.793, LR=0.0006545084971874737
# Validation Loss = 1.542
# Epoch=6, batch = 0 of 4000, loss=1.115, LR=0.0005
# Validation Loss = 0.259
# Epoch=6, batch = 1000 of 4000, loss=0.623, LR=0.0005
# Validation Loss = 0.333
# Epoch=6, batch = 2000 of 4000, loss=0.679, LR=0.0005
# Validation Loss = 0.008
# Epoch=6, batch = 3000 of 4000, loss=1.293, LR=0.0005
# Validation Loss = 0.798
# Epoch=7, batch = 0 of 4000, loss=0.712, LR=0.00034549150281252633
# Validation Loss = 0.190
# Epoch=7, batch = 1000 of 4000, loss=0.681, LR=0.00034549150281252633
# Validation Loss = 0.553
# Epoch=7, batch = 2000 of 4000, loss=0.624, LR=0.00034549150281252633
# Validation Loss = 0.351
# Epoch=7, batch = 3000 of 4000, loss=0.622, LR=0.00034549150281252633
# Validation Loss = 0.232
# Epoch=8, batch = 0 of 4000, loss=0.614, LR=0.0002061073738537635
# Validation Loss = 0.372
# Epoch=8, batch = 1000 of 4000, loss=0.659, LR=0.0002061073738537635
# Validation Loss = 0.694
# Epoch=8, batch = 2000 of 4000, loss=0.724, LR=0.0002061073738537635
# Validation Loss = 0.894
# Epoch=8, batch = 3000 of 4000, loss=0.807, LR=0.0002061073738537635
# Validation Loss = 0.806
# Epoch=9, batch = 0 of 4000, loss=0.756, LR=9.549150281252634e-05
# Validation Loss = 0.305
# Epoch=9, batch = 1000 of 4000, loss=0.712, LR=9.549150281252634e-05
# Validation Loss = 0.266
# Epoch=9, batch = 2000 of 4000, loss=0.639, LR=9.549150281252634e-05
# Validation Loss = 0.393
# Epoch=9, batch = 3000 of 4000, loss=0.622, LR=9.549150281252634e-05
# Validation Loss = 0.524
# Epoch=10, batch = 0 of 4000, loss=0.630, LR=2.4471741852423235e-05
# Validation Loss = 0.379
# Epoch=10, batch = 1000 of 4000, loss=0.694, LR=2.4471741852423235e-05
# Validation Loss = 0.417
# Epoch=10, batch = 2000 of 4000, loss=0.633, LR=2.4471741852423235e-05
# Validation Loss = 0.323
# Epoch=10, batch = 3000 of 4000, loss=0.689, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.581
# Epoch=1, batch = 0 of 4000, loss=0.653, LR=0.001
# Validation Loss = 0.758
# Epoch=1, batch = 1000 of 4000, loss=0.766, LR=0.001
# Validation Loss = 1.907
# Epoch=1, batch = 2000 of 4000, loss=1.280, LR=0.001
# Validation Loss = 2.375
# Epoch=1, batch = 3000 of 4000, loss=1.116, LR=0.001
# Validation Loss = 0.120
# Epoch=2, batch = 0 of 4000, loss=1.069, LR=0.0009938441702975688
# Validation Loss = 0.111
# Epoch=2, batch = 1000 of 4000, loss=1.006, LR=0.0009938441702975688
# Validation Loss = 0.143
# Epoch=2, batch = 2000 of 4000, loss=1.091, LR=0.0009938441702975688
# Validation Loss = 0.012
# Epoch=2, batch = 3000 of 4000, loss=1.231, LR=0.0009938441702975688
# Validation Loss = 1.136
# Epoch=3, batch = 0 of 4000, loss=0.672, LR=0.0009755282581475768
# Validation Loss = 2.402
# Epoch=3, batch = 1000 of 4000, loss=0.951, LR=0.0009755282581475768
# Validation Loss = 0.640
# Epoch=3, batch = 2000 of 4000, loss=0.781, LR=0.0009755282581475768
# Validation Loss = 0.332
# Epoch=3, batch = 3000 of 4000, loss=0.730, LR=0.0009755282581475768
# Validation Loss = 0.098
# Epoch=4, batch = 0 of 4000, loss=1.017, LR=0.0009455032620941839
# Validation Loss = 0.000
# Epoch=4, batch = 1000 of 4000, loss=1.454, LR=0.0009455032620941839
# Validation Loss = 0.270
# Epoch=4, batch = 2000 of 4000, loss=0.853, LR=0.0009455032620941839
# Validation Loss = 1.344
# Epoch=4, batch = 3000 of 4000, loss=0.804, LR=0.0009455032620941839
# Validation Loss = 0.573
# Epoch=5, batch = 0 of 4000, loss=0.680, LR=0.0009045084971874737
# Validation Loss = 0.523
# Epoch=5, batch = 1000 of 4000, loss=0.722, LR=0.0009045084971874737
# Validation Loss = 2.549
# Epoch=5, batch = 2000 of 4000, loss=1.442, LR=0.0009045084971874737
# Validation Loss = 0.514
# Epoch=5, batch = 3000 of 4000, loss=0.680, LR=0.0009045084971874737
# Validation Loss = 0.065
# Epoch=6, batch = 0 of 4000, loss=1.360, LR=0.0008535533905932737
# Validation Loss = 1.209
# Epoch=6, batch = 1000 of 4000, loss=0.896, LR=0.0008535533905932737
# Validation Loss = 2.838
# Epoch=6, batch = 2000 of 4000, loss=1.209, LR=0.0008535533905932737
# Validation Loss = 0.032
# Epoch=6, batch = 3000 of 4000, loss=0.984, LR=0.0008535533905932737
# Validation Loss = 1.826
# Epoch=7, batch = 0 of 4000, loss=0.835, LR=0.0007938926261462366
# Validation Loss = 0.519
# Epoch=7, batch = 1000 of 4000, loss=0.708, LR=0.0007938926261462366
# Validation Loss = 0.539
# Epoch=7, batch = 2000 of 4000, loss=0.660, LR=0.0007938926261462366
# Validation Loss = 0.974
# Epoch=7, batch = 3000 of 4000, loss=0.663, LR=0.0007938926261462366
# Validation Loss = 1.120
# Epoch=8, batch = 0 of 4000, loss=0.712, LR=0.0007269952498697733
# Validation Loss = 0.605
# Epoch=8, batch = 1000 of 4000, loss=0.642, LR=0.0007269952498697733
# Validation Loss = 0.281
# Epoch=8, batch = 2000 of 4000, loss=0.774, LR=0.0007269952498697733
# Validation Loss = 1.905
# Epoch=8, batch = 3000 of 4000, loss=0.876, LR=0.0007269952498697733
# Validation Loss = 0.265
# Epoch=9, batch = 0 of 4000, loss=0.988, LR=0.0006545084971874737
# Validation Loss = 1.032
# Epoch=9, batch = 1000 of 4000, loss=0.638, LR=0.0006545084971874737
# Validation Loss = 0.158
# Epoch=9, batch = 2000 of 4000, loss=0.896, LR=0.0006545084971874737
# Validation Loss = 1.124
# Epoch=9, batch = 3000 of 4000, loss=0.709, LR=0.0006545084971874737
# Validation Loss = 1.790
# Epoch=10, batch = 0 of 4000, loss=0.954, LR=0.0005782172325201155
# Validation Loss = 0.221
# Epoch=10, batch = 1000 of 4000, loss=0.840, LR=0.0005782172325201155
# Validation Loss = 0.460
# Epoch=10, batch = 2000 of 4000, loss=0.664, LR=0.0005782172325201155
# Validation Loss = 0.372
# Epoch=10, batch = 3000 of 4000, loss=0.687, LR=0.0005782172325201155
# Validation Loss = 0.932
# Epoch=11, batch = 0 of 4000, loss=0.703, LR=0.0005
# Validation Loss = 0.389
# Epoch=11, batch = 1000 of 4000, loss=0.757, LR=0.0005
# Validation Loss = 0.283
# Epoch=11, batch = 2000 of 4000, loss=0.747, LR=0.0005
# Validation Loss = 1.439
# Epoch=11, batch = 3000 of 4000, loss=0.735, LR=0.0005
# Validation Loss = 0.462
# Epoch=12, batch = 0 of 4000, loss=0.688, LR=0.0004217827674798847
# Validation Loss = 1.281
# Epoch=12, batch = 1000 of 4000, loss=0.733, LR=0.0004217827674798847
# Validation Loss = 0.555
# Epoch=12, batch = 2000 of 4000, loss=0.770, LR=0.0004217827674798847
# Validation Loss = 0.891
# Epoch=12, batch = 3000 of 4000, loss=0.616, LR=0.0004217827674798847
# Validation Loss = 0.764
# Epoch=13, batch = 0 of 4000, loss=0.689, LR=0.00034549150281252633
# Validation Loss = 0.610
# Epoch=13, batch = 1000 of 4000, loss=0.757, LR=0.00034549150281252633
# Validation Loss = 0.620
# Epoch=13, batch = 2000 of 4000, loss=0.675, LR=0.00034549150281252633
# Validation Loss = 1.137
# Epoch=13, batch = 3000 of 4000, loss=0.663, LR=0.00034549150281252633
# Validation Loss = 0.750
# Epoch=14, batch = 0 of 4000, loss=0.645, LR=0.00027300475013022663
# Validation Loss = 0.891
# Epoch=14, batch = 1000 of 4000, loss=0.716, LR=0.00027300475013022663
# Validation Loss = 1.439
# Epoch=14, batch = 2000 of 4000, loss=0.740, LR=0.00027300475013022663
# Validation Loss = 0.957
# Epoch=14, batch = 3000 of 4000, loss=0.659, LR=0.00027300475013022663
# Validation Loss = 0.736
# Epoch=15, batch = 0 of 4000, loss=0.662, LR=0.00020610737385376348
# Validation Loss = 0.363
# Epoch=15, batch = 1000 of 4000, loss=0.760, LR=0.00020610737385376348
# Validation Loss = 0.902
# Epoch=15, batch = 2000 of 4000, loss=0.595, LR=0.00020610737385376348
# Validation Loss = 0.952
# Epoch=15, batch = 3000 of 4000, loss=0.682, LR=0.00020610737385376348
# Validation Loss = 0.876
# Epoch=16, batch = 0 of 4000, loss=0.577, LR=0.00014644660940672625
# Validation Loss = 0.802
# Epoch=16, batch = 1000 of 4000, loss=0.625, LR=0.00014644660940672625
# Validation Loss = 0.266
# Epoch=16, batch = 2000 of 4000, loss=0.777, LR=0.00014644660940672625
# Validation Loss = 0.464
# Epoch=16, batch = 3000 of 4000, loss=0.687, LR=0.00014644660940672625
# Validation Loss = 0.788
# Epoch=17, batch = 0 of 4000, loss=0.702, LR=9.549150281252631e-05
# Validation Loss = 0.915
# Epoch=17, batch = 1000 of 4000, loss=0.618, LR=9.549150281252631e-05
# Validation Loss = 0.773
# Epoch=17, batch = 2000 of 4000, loss=0.597, LR=9.549150281252631e-05
# Validation Loss = 0.491
# Epoch=17, batch = 3000 of 4000, loss=0.667, LR=9.549150281252631e-05
# Validation Loss = 0.659
# Epoch=18, batch = 0 of 4000, loss=0.592, LR=5.4496737905816096e-05
# Validation Loss = 0.669
# Epoch=18, batch = 1000 of 4000, loss=0.628, LR=5.4496737905816096e-05
# Validation Loss = 0.781
# Epoch=18, batch = 2000 of 4000, loss=0.654, LR=5.4496737905816096e-05
# Validation Loss = 0.547
# Epoch=18, batch = 3000 of 4000, loss=0.721, LR=5.4496737905816096e-05
# Validation Loss = 0.802
# Epoch=19, batch = 0 of 4000, loss=0.620, LR=2.447174185242323e-05
# Validation Loss = 0.612
# Epoch=19, batch = 1000 of 4000, loss=0.712, LR=2.447174185242323e-05
# Validation Loss = 0.717
# Epoch=19, batch = 2000 of 4000, loss=0.595, LR=2.447174185242323e-05
# Validation Loss = 0.577
# Epoch=19, batch = 3000 of 4000, loss=0.584, LR=2.447174185242323e-05
# Validation Loss = 0.819
# Epoch=20, batch = 0 of 4000, loss=0.691, LR=6.15582970243117e-06
# Validation Loss = 0.726
# Epoch=20, batch = 1000 of 4000, loss=0.596, LR=6.15582970243117e-06
# Validation Loss = 0.683
# Epoch=20, batch = 2000 of 4000, loss=0.641, LR=6.15582970243117e-06
# Validation Loss = 0.723
# Epoch=20, batch = 3000 of 4000, loss=0.650, LR=6.15582970243117e-06
# Finished training model for channel 19H.
# 24V
# Training stage: 1
# Validation Loss = 50579.980
# Epoch=1, batch = 0 of 4000, loss=47026.488, LR=0.001
# Validation Loss = 10.059
# Epoch=1, batch = 1000 of 4000, loss=3.544, LR=0.001
# Validation Loss = 7.459
# Epoch=1, batch = 2000 of 4000, loss=2.574, LR=0.001
# Validation Loss = 5.294
# Epoch=1, batch = 3000 of 4000, loss=2.484, LR=0.001
# Validation Loss = 4.662
# Epoch=2, batch = 0 of 4000, loss=2.055, LR=0.0009045084971874737
# Validation Loss = 30.334
# Epoch=2, batch = 1000 of 4000, loss=10.525, LR=0.0009045084971874737
# Validation Loss = 2.194
# Epoch=2, batch = 2000 of 4000, loss=2.419, LR=0.0009045084971874737
# Validation Loss = 11.765
# Epoch=2, batch = 3000 of 4000, loss=3.302, LR=0.0009045084971874737
# Validation Loss = 8.608
# Epoch=3, batch = 0 of 4000, loss=2.395, LR=0.0006545084971874737
# Validation Loss = 5.850
# Epoch=3, batch = 1000 of 4000, loss=1.909, LR=0.0006545084971874737
# Validation Loss = 2.245
# Epoch=3, batch = 2000 of 4000, loss=1.796, LR=0.0006545084971874737
# Validation Loss = 2.266
# Epoch=3, batch = 3000 of 4000, loss=1.925, LR=0.0006545084971874737
# Validation Loss = 3.205
# Epoch=4, batch = 0 of 4000, loss=1.820, LR=0.00034549150281252633
# Validation Loss = 3.854
# Epoch=4, batch = 1000 of 4000, loss=1.840, LR=0.00034549150281252633
# Validation Loss = 2.614
# Epoch=4, batch = 2000 of 4000, loss=1.781, LR=0.00034549150281252633
# Validation Loss = 5.743
# Epoch=4, batch = 3000 of 4000, loss=1.791, LR=0.00034549150281252633
# Validation Loss = 7.745
# Epoch=5, batch = 0 of 4000, loss=2.288, LR=9.549150281252633e-05
# Validation Loss = 3.074
# Epoch=5, batch = 1000 of 4000, loss=1.325, LR=9.549150281252633e-05
# Validation Loss = 3.582
# Epoch=5, batch = 2000 of 4000, loss=1.483, LR=9.549150281252633e-05
# Validation Loss = 2.539
# Epoch=5, batch = 3000 of 4000, loss=1.494, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 2.316
# Epoch=1, batch = 0 of 4000, loss=1.571, LR=0.001
# Validation Loss = 3.939
# Epoch=1, batch = 1000 of 4000, loss=1.827, LR=0.001
# Validation Loss = 1.863
# Epoch=1, batch = 2000 of 4000, loss=2.117, LR=0.001
# Validation Loss = 0.197
# Epoch=1, batch = 3000 of 4000, loss=3.969, LR=0.001
# Validation Loss = 3.615
# Epoch=2, batch = 0 of 4000, loss=1.606, LR=0.0009755282581475768
# Validation Loss = 17.237
# Epoch=2, batch = 1000 of 4000, loss=5.747, LR=0.0009755282581475768
# Validation Loss = 17.288
# Epoch=2, batch = 2000 of 4000, loss=6.331, LR=0.0009755282581475768
# Validation Loss = 3.084
# Epoch=2, batch = 3000 of 4000, loss=1.532, LR=0.0009755282581475768
# Validation Loss = 6.708
# Epoch=3, batch = 0 of 4000, loss=2.007, LR=0.0009045084971874736
# Validation Loss = 4.061
# Epoch=3, batch = 1000 of 4000, loss=1.402, LR=0.0009045084971874736
# Validation Loss = 7.016
# Epoch=3, batch = 2000 of 4000, loss=2.202, LR=0.0009045084971874736
# Validation Loss = 3.969
# Epoch=3, batch = 3000 of 4000, loss=1.384, LR=0.0009045084971874736
# Validation Loss = 0.001
# Epoch=4, batch = 0 of 4000, loss=5.034, LR=0.0007938926261462366
# Validation Loss = 1.406
# Epoch=4, batch = 1000 of 4000, loss=2.054, LR=0.0007938926261462366
# Validation Loss = 11.693
# Epoch=4, batch = 2000 of 4000, loss=3.363, LR=0.0007938926261462366
# Validation Loss = 3.078
# Epoch=4, batch = 3000 of 4000, loss=1.519, LR=0.0007938926261462366
# Validation Loss = 3.244
# Epoch=5, batch = 0 of 4000, loss=1.587, LR=0.0006545084971874737
# Validation Loss = 7.265
# Epoch=5, batch = 1000 of 4000, loss=2.338, LR=0.0006545084971874737
# Validation Loss = 1.087
# Epoch=5, batch = 2000 of 4000, loss=1.928, LR=0.0006545084971874737
# Validation Loss = 5.246
# Epoch=5, batch = 3000 of 4000, loss=1.570, LR=0.0006545084971874737
# Validation Loss = 1.002
# Epoch=6, batch = 0 of 4000, loss=2.124, LR=0.0005
# Validation Loss = 2.806
# Epoch=6, batch = 1000 of 4000, loss=1.488, LR=0.0005
# Validation Loss = 7.236
# Epoch=6, batch = 2000 of 4000, loss=2.507, LR=0.0005
# Validation Loss = 1.912
# Epoch=6, batch = 3000 of 4000, loss=1.612, LR=0.0005
# Validation Loss = 1.750
# Epoch=7, batch = 0 of 4000, loss=1.765, LR=0.00034549150281252633
# Validation Loss = 3.410
# Epoch=7, batch = 1000 of 4000, loss=1.347, LR=0.00034549150281252633
# Validation Loss = 2.128
# Epoch=7, batch = 2000 of 4000, loss=1.524, LR=0.00034549150281252633
# Validation Loss = 5.400
# Epoch=7, batch = 3000 of 4000, loss=1.748, LR=0.00034549150281252633
# Validation Loss = 3.446
# Epoch=8, batch = 0 of 4000, loss=1.550, LR=0.0002061073738537635
# Validation Loss = 2.417
# Epoch=8, batch = 1000 of 4000, loss=1.411, LR=0.0002061073738537635
# Validation Loss = 2.994
# Epoch=8, batch = 2000 of 4000, loss=1.374, LR=0.0002061073738537635
# Validation Loss = 2.684
# Epoch=8, batch = 3000 of 4000, loss=1.190, LR=0.0002061073738537635
# Validation Loss = 2.260
# Epoch=9, batch = 0 of 4000, loss=1.484, LR=9.549150281252634e-05
# Validation Loss = 3.266
# Epoch=9, batch = 1000 of 4000, loss=1.367, LR=9.549150281252634e-05
# Validation Loss = 4.221
# Epoch=9, batch = 2000 of 4000, loss=1.355, LR=9.549150281252634e-05
# Validation Loss = 4.038
# Epoch=9, batch = 3000 of 4000, loss=1.273, LR=9.549150281252634e-05
# Validation Loss = 3.233
# Epoch=10, batch = 0 of 4000, loss=1.314, LR=2.4471741852423235e-05
# Validation Loss = 2.611
# Epoch=10, batch = 1000 of 4000, loss=1.602, LR=2.4471741852423235e-05
# Validation Loss = 3.100
# Epoch=10, batch = 2000 of 4000, loss=1.175, LR=2.4471741852423235e-05
# Validation Loss = 3.459
# Epoch=10, batch = 3000 of 4000, loss=1.275, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 2.863
# Epoch=1, batch = 0 of 4000, loss=1.266, LR=0.001
# Validation Loss = 1.645
# Epoch=1, batch = 1000 of 4000, loss=1.575, LR=0.001
# Validation Loss = 1.913
# Epoch=1, batch = 2000 of 4000, loss=1.653, LR=0.001
# Validation Loss = 1.123
# Epoch=1, batch = 3000 of 4000, loss=1.715, LR=0.001
# Validation Loss = 6.503
# Epoch=2, batch = 0 of 4000, loss=1.956, LR=0.0009938441702975688
# Validation Loss = 0.707
# Epoch=2, batch = 1000 of 4000, loss=1.945, LR=0.0009938441702975688
# Validation Loss = 1.407
# Epoch=2, batch = 2000 of 4000, loss=1.515, LR=0.0009938441702975688
# Validation Loss = 5.682
# Epoch=2, batch = 3000 of 4000, loss=1.542, LR=0.0009938441702975688
# Validation Loss = 1.797
# Epoch=3, batch = 0 of 4000, loss=1.661, LR=0.0009755282581475768
# Validation Loss = 0.504
# Epoch=3, batch = 1000 of 4000, loss=2.484, LR=0.0009755282581475768
# Validation Loss = 1.441
# Epoch=3, batch = 2000 of 4000, loss=1.734, LR=0.0009755282581475768
# Validation Loss = 5.068
# Epoch=3, batch = 3000 of 4000, loss=1.760, LR=0.0009755282581475768
# Validation Loss = 4.277
# Epoch=4, batch = 0 of 4000, loss=1.322, LR=0.0009455032620941839
# Validation Loss = 2.686
# Epoch=4, batch = 1000 of 4000, loss=1.737, LR=0.0009455032620941839
# Validation Loss = 4.352
# Epoch=4, batch = 2000 of 4000, loss=1.481, LR=0.0009455032620941839
# Validation Loss = 10.450
# Epoch=4, batch = 3000 of 4000, loss=2.992, LR=0.0009455032620941839
# Validation Loss = 0.061
# Epoch=5, batch = 0 of 4000, loss=3.643, LR=0.0009045084971874737
# Validation Loss = 2.961
# Epoch=5, batch = 1000 of 4000, loss=1.442, LR=0.0009045084971874737
# Validation Loss = 4.284
# Epoch=5, batch = 2000 of 4000, loss=1.465, LR=0.0009045084971874737
# Validation Loss = 2.242
# Epoch=5, batch = 3000 of 4000, loss=1.501, LR=0.0009045084971874737
# Validation Loss = 6.324
# Epoch=6, batch = 0 of 4000, loss=2.500, LR=0.0008535533905932737
# Validation Loss = 1.031
# Epoch=6, batch = 1000 of 4000, loss=1.700, LR=0.0008535533905932737
# Validation Loss = 1.367
# Epoch=6, batch = 2000 of 4000, loss=1.694, LR=0.0008535533905932737
# Validation Loss = 5.042
# Epoch=6, batch = 3000 of 4000, loss=1.524, LR=0.0008535533905932737
# Validation Loss = 2.592
# Epoch=7, batch = 0 of 4000, loss=1.346, LR=0.0007938926261462366
# Validation Loss = 5.441
# Epoch=7, batch = 1000 of 4000, loss=1.568, LR=0.0007938926261462366
# Validation Loss = 2.477
# Epoch=7, batch = 2000 of 4000, loss=1.374, LR=0.0007938926261462366
# Validation Loss = 2.870
# Epoch=7, batch = 3000 of 4000, loss=1.471, LR=0.0007938926261462366
# Validation Loss = 4.324
# Epoch=8, batch = 0 of 4000, loss=1.160, LR=0.0007269952498697733
# Validation Loss = 2.860
# Epoch=8, batch = 1000 of 4000, loss=1.446, LR=0.0007269952498697733
# Validation Loss = 2.169
# Epoch=8, batch = 2000 of 4000, loss=1.396, LR=0.0007269952498697733
# Validation Loss = 2.449
# Epoch=8, batch = 3000 of 4000, loss=1.556, LR=0.0007269952498697733
# Validation Loss = 5.780
# Epoch=9, batch = 0 of 4000, loss=1.617, LR=0.0006545084971874737
# Validation Loss = 4.151
# Epoch=9, batch = 1000 of 4000, loss=1.524, LR=0.0006545084971874737
# Validation Loss = 2.936
# Epoch=9, batch = 2000 of 4000, loss=1.238, LR=0.0006545084971874737
# Validation Loss = 2.383
# Epoch=9, batch = 3000 of 4000, loss=1.333, LR=0.0006545084971874737
# Validation Loss = 2.438
# Epoch=10, batch = 0 of 4000, loss=1.229, LR=0.0005782172325201155
# Validation Loss = 3.665
# Epoch=10, batch = 1000 of 4000, loss=1.414, LR=0.0005782172325201155
# Validation Loss = 3.500
# Epoch=10, batch = 2000 of 4000, loss=1.252, LR=0.0005782172325201155
# Validation Loss = 3.505
# Epoch=10, batch = 3000 of 4000, loss=1.326, LR=0.0005782172325201155
# Validation Loss = 5.612
# Epoch=11, batch = 0 of 4000, loss=1.546, LR=0.0005
# Validation Loss = 3.486
# Epoch=11, batch = 1000 of 4000, loss=1.222, LR=0.0005
# Validation Loss = 4.012
# Epoch=11, batch = 2000 of 4000, loss=1.497, LR=0.0005
# Validation Loss = 6.884
# Epoch=11, batch = 3000 of 4000, loss=2.014, LR=0.0005
# Validation Loss = 4.717
# Epoch=12, batch = 0 of 4000, loss=1.192, LR=0.0004217827674798847
# Validation Loss = 2.707
# Epoch=12, batch = 1000 of 4000, loss=1.308, LR=0.0004217827674798847
# Validation Loss = 6.009
# Epoch=12, batch = 2000 of 4000, loss=1.980, LR=0.0004217827674798847
# Validation Loss = 3.116
# Epoch=12, batch = 3000 of 4000, loss=1.361, LR=0.0004217827674798847
# Validation Loss = 1.815
# Epoch=13, batch = 0 of 4000, loss=1.364, LR=0.00034549150281252633
# Validation Loss = 4.581
# Epoch=13, batch = 1000 of 4000, loss=1.259, LR=0.00034549150281252633
# Validation Loss = 4.857
# Epoch=13, batch = 2000 of 4000, loss=1.671, LR=0.00034549150281252633
# Validation Loss = 1.833
# Epoch=13, batch = 3000 of 4000, loss=1.688, LR=0.00034549150281252633
# Validation Loss = 2.723
# Epoch=14, batch = 0 of 4000, loss=1.298, LR=0.00027300475013022663
# Validation Loss = 2.527
# Epoch=14, batch = 1000 of 4000, loss=1.430, LR=0.00027300475013022663
# Validation Loss = 1.590
# Epoch=14, batch = 2000 of 4000, loss=1.719, LR=0.00027300475013022663
# Validation Loss = 4.219
# Epoch=14, batch = 3000 of 4000, loss=1.292, LR=0.00027300475013022663
# Validation Loss = 4.574
# Epoch=15, batch = 0 of 4000, loss=1.241, LR=0.00020610737385376348
# Validation Loss = 4.032
# Epoch=15, batch = 1000 of 4000, loss=1.245, LR=0.00020610737385376348
# Validation Loss = 4.765
# Epoch=15, batch = 2000 of 4000, loss=1.393, LR=0.00020610737385376348
# Validation Loss = 2.691
# Epoch=15, batch = 3000 of 4000, loss=1.175, LR=0.00020610737385376348
# Validation Loss = 2.410
# Epoch=16, batch = 0 of 4000, loss=1.470, LR=0.00014644660940672625
# Validation Loss = 3.972
# Epoch=16, batch = 1000 of 4000, loss=1.305, LR=0.00014644660940672625
# Validation Loss = 3.858
# Epoch=16, batch = 2000 of 4000, loss=1.321, LR=0.00014644660940672625
# Validation Loss = 2.649
# Epoch=16, batch = 3000 of 4000, loss=1.489, LR=0.00014644660940672625
# Validation Loss = 3.259
# Epoch=17, batch = 0 of 4000, loss=1.446, LR=9.549150281252631e-05
# Validation Loss = 3.382
# Epoch=17, batch = 1000 of 4000, loss=1.356, LR=9.549150281252631e-05
# Validation Loss = 4.192
# Epoch=17, batch = 2000 of 4000, loss=1.349, LR=9.549150281252631e-05
# Validation Loss = 3.318
# Epoch=17, batch = 3000 of 4000, loss=1.183, LR=9.549150281252631e-05
# Validation Loss = 3.271
# Epoch=18, batch = 0 of 4000, loss=1.143, LR=5.4496737905816096e-05
# Validation Loss = 2.664
# Epoch=18, batch = 1000 of 4000, loss=1.345, LR=5.4496737905816096e-05
# Validation Loss = 5.454
# Epoch=18, batch = 2000 of 4000, loss=1.655, LR=5.4496737905816096e-05
# Validation Loss = 3.015
# Epoch=18, batch = 3000 of 4000, loss=1.252, LR=5.4496737905816096e-05
# Validation Loss = 4.393
# Epoch=19, batch = 0 of 4000, loss=1.086, LR=2.447174185242323e-05
# Validation Loss = 3.260
# Epoch=19, batch = 1000 of 4000, loss=1.255, LR=2.447174185242323e-05
# Validation Loss = 3.691
# Epoch=19, batch = 2000 of 4000, loss=1.380, LR=2.447174185242323e-05
# Validation Loss = 3.469
# Epoch=19, batch = 3000 of 4000, loss=1.336, LR=2.447174185242323e-05
# Validation Loss = 3.541
# Epoch=20, batch = 0 of 4000, loss=1.331, LR=6.15582970243117e-06
# Validation Loss = 3.704
# Epoch=20, batch = 1000 of 4000, loss=1.168, LR=6.15582970243117e-06
# Validation Loss = 3.765
# Epoch=20, batch = 2000 of 4000, loss=1.189, LR=6.15582970243117e-06
# Validation Loss = 3.800
# Epoch=20, batch = 3000 of 4000, loss=1.341, LR=6.15582970243117e-06
# Finished training model for channel 24V.
# 37V
# Training stage: 1
# Validation Loss = 42737.945
# Epoch=1, batch = 0 of 4000, loss=43062.293, LR=0.001
# Validation Loss = 1.457
# Epoch=1, batch = 1000 of 4000, loss=1.270, LR=0.001
# Validation Loss = 0.092
# Epoch=1, batch = 2000 of 4000, loss=0.974, LR=0.001
# Validation Loss = 0.018
# Epoch=1, batch = 3000 of 4000, loss=1.031, LR=0.001
# Validation Loss = 6.548
# Epoch=2, batch = 0 of 4000, loss=3.491, LR=0.0009045084971874737
# Validation Loss = 0.110
# Epoch=2, batch = 1000 of 4000, loss=1.421, LR=0.0009045084971874737
# Validation Loss = 0.217
# Epoch=2, batch = 2000 of 4000, loss=0.630, LR=0.0009045084971874737
# Validation Loss = 0.219
# Epoch=2, batch = 3000 of 4000, loss=0.584, LR=0.0009045084971874737
# Validation Loss = 0.489
# Epoch=3, batch = 0 of 4000, loss=0.565, LR=0.0006545084971874737
# Validation Loss = 0.002
# Epoch=3, batch = 1000 of 4000, loss=0.716, LR=0.0006545084971874737
# Validation Loss = 0.354
# Epoch=3, batch = 2000 of 4000, loss=0.513, LR=0.0006545084971874737
# Validation Loss = 0.007
# Epoch=3, batch = 3000 of 4000, loss=0.535, LR=0.0006545084971874737
# Validation Loss = 0.401
# Epoch=4, batch = 0 of 4000, loss=1.630, LR=0.00034549150281252633
# Validation Loss = 0.628
# Epoch=4, batch = 1000 of 4000, loss=0.738, LR=0.00034549150281252633
# Validation Loss = 0.000
# Epoch=4, batch = 2000 of 4000, loss=0.574, LR=0.00034549150281252633
# Validation Loss = 0.001
# Epoch=4, batch = 3000 of 4000, loss=0.535, LR=0.00034549150281252633
# Validation Loss = 0.118
# Epoch=5, batch = 0 of 4000, loss=0.505, LR=9.549150281252633e-05
# Validation Loss = 0.129
# Epoch=5, batch = 1000 of 4000, loss=0.732, LR=9.549150281252633e-05
# Validation Loss = 0.195
# Epoch=5, batch = 2000 of 4000, loss=0.450, LR=9.549150281252633e-05
# Validation Loss = 0.054
# Epoch=5, batch = 3000 of 4000, loss=0.471, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.134
# Epoch=1, batch = 0 of 4000, loss=0.461, LR=0.001
# Validation Loss = 0.000
# Epoch=1, batch = 1000 of 4000, loss=0.558, LR=0.001
# Validation Loss = 0.167
# Epoch=1, batch = 2000 of 4000, loss=0.946, LR=0.001
# Validation Loss = 0.113
# Epoch=1, batch = 3000 of 4000, loss=0.841, LR=0.001
# Validation Loss = 0.307
# Epoch=2, batch = 0 of 4000, loss=1.166, LR=0.0009755282581475768
# Validation Loss = 0.172
# Epoch=2, batch = 1000 of 4000, loss=0.474, LR=0.0009755282581475768
# Validation Loss = 0.594
# Epoch=2, batch = 2000 of 4000, loss=0.658, LR=0.0009755282581475768
# Validation Loss = 1.560
# Epoch=2, batch = 3000 of 4000, loss=1.447, LR=0.0009755282581475768
# Validation Loss = 0.114
# Epoch=3, batch = 0 of 4000, loss=0.446, LR=0.0009045084971874736
# Validation Loss = 0.204
# Epoch=3, batch = 1000 of 4000, loss=0.974, LR=0.0009045084971874736
# Validation Loss = 0.301
# Epoch=3, batch = 2000 of 4000, loss=1.052, LR=0.0009045084971874736
# Validation Loss = 0.935
# Epoch=3, batch = 3000 of 4000, loss=2.012, LR=0.0009045084971874736
# Validation Loss = 0.536
# Epoch=4, batch = 0 of 4000, loss=1.190, LR=0.0007938926261462366
# Validation Loss = 0.426
# Epoch=4, batch = 1000 of 4000, loss=0.657, LR=0.0007938926261462366
# Validation Loss = 0.497
# Epoch=4, batch = 2000 of 4000, loss=0.769, LR=0.0007938926261462366
# Validation Loss = 0.005
# Epoch=4, batch = 3000 of 4000, loss=0.463, LR=0.0007938926261462366
# Validation Loss = 0.549
# Epoch=5, batch = 0 of 4000, loss=0.762, LR=0.0006545084971874737
# Validation Loss = 0.301
# Epoch=5, batch = 1000 of 4000, loss=0.584, LR=0.0006545084971874737
# Validation Loss = 0.092
# Epoch=5, batch = 2000 of 4000, loss=0.660, LR=0.0006545084971874737
# Validation Loss = 0.948
# Epoch=5, batch = 3000 of 4000, loss=1.775, LR=0.0006545084971874737
# Validation Loss = 0.082
# Epoch=6, batch = 0 of 4000, loss=0.687, LR=0.0005
# Validation Loss = 0.851
# Epoch=6, batch = 1000 of 4000, loss=0.980, LR=0.0005
# Validation Loss = 0.748
# Epoch=6, batch = 2000 of 4000, loss=1.460, LR=0.0005
# Validation Loss = 0.043
# Epoch=6, batch = 3000 of 4000, loss=0.503, LR=0.0005
# Validation Loss = 0.297
# Epoch=7, batch = 0 of 4000, loss=0.627, LR=0.00034549150281252633
# Validation Loss = 0.020
# Epoch=7, batch = 1000 of 4000, loss=0.505, LR=0.00034549150281252633
# Validation Loss = 0.313
# Epoch=7, batch = 2000 of 4000, loss=0.601, LR=0.00034549150281252633
# Validation Loss = 0.018
# Epoch=7, batch = 3000 of 4000, loss=0.451, LR=0.00034549150281252633
# Validation Loss = 0.261
# Epoch=8, batch = 0 of 4000, loss=0.893, LR=0.0002061073738537635
# Validation Loss = 0.015
# Epoch=8, batch = 1000 of 4000, loss=0.555, LR=0.0002061073738537635
# Validation Loss = 0.001
# Epoch=8, batch = 2000 of 4000, loss=0.424, LR=0.0002061073738537635
# Validation Loss = 0.043
# Epoch=8, batch = 3000 of 4000, loss=0.452, LR=0.0002061073738537635
# Validation Loss = 0.028
# Epoch=9, batch = 0 of 4000, loss=0.523, LR=9.549150281252634e-05
# Validation Loss = 0.070
# Epoch=9, batch = 1000 of 4000, loss=0.454, LR=9.549150281252634e-05
# Validation Loss = 0.076
# Epoch=9, batch = 2000 of 4000, loss=0.404, LR=9.549150281252634e-05
# Validation Loss = 0.010
# Epoch=9, batch = 3000 of 4000, loss=0.396, LR=9.549150281252634e-05
# Validation Loss = 0.030
# Epoch=10, batch = 0 of 4000, loss=0.419, LR=2.4471741852423235e-05
# Validation Loss = 0.038
# Epoch=10, batch = 1000 of 4000, loss=0.438, LR=2.4471741852423235e-05
# Validation Loss = 0.006
# Epoch=10, batch = 2000 of 4000, loss=0.471, LR=2.4471741852423235e-05
# Validation Loss = 0.009
# Epoch=10, batch = 3000 of 4000, loss=0.470, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.042
# Epoch=1, batch = 0 of 4000, loss=0.482, LR=0.001
# Validation Loss = 0.055
# Epoch=1, batch = 1000 of 4000, loss=0.481, LR=0.001
# Validation Loss = 0.009
# Epoch=1, batch = 2000 of 4000, loss=0.441, LR=0.001
# Validation Loss = 0.039
# Epoch=1, batch = 3000 of 4000, loss=0.458, LR=0.001
# Validation Loss = 0.000
# Epoch=2, batch = 0 of 4000, loss=0.518, LR=0.0009938441702975688
# Validation Loss = 0.007
# Epoch=2, batch = 1000 of 4000, loss=0.467, LR=0.0009938441702975688
# Validation Loss = 0.263
# Epoch=2, batch = 2000 of 4000, loss=0.612, LR=0.0009938441702975688
# Validation Loss = 0.141
# Epoch=2, batch = 3000 of 4000, loss=0.476, LR=0.0009938441702975688
# Validation Loss = 0.619
# Epoch=3, batch = 0 of 4000, loss=1.219, LR=0.0009755282581475768
# Validation Loss = 1.782
# Epoch=3, batch = 1000 of 4000, loss=2.472, LR=0.0009755282581475768
# Validation Loss = 0.537
# Epoch=3, batch = 2000 of 4000, loss=1.138, LR=0.0009755282581475768
# Validation Loss = 0.010
# Epoch=3, batch = 3000 of 4000, loss=0.429, LR=0.0009755282581475768
# Validation Loss = 0.935
# Epoch=4, batch = 0 of 4000, loss=1.661, LR=0.0009455032620941839
# Validation Loss = 0.063
# Epoch=4, batch = 1000 of 4000, loss=0.589, LR=0.0009455032620941839
# Validation Loss = 0.660
# Epoch=4, batch = 2000 of 4000, loss=0.862, LR=0.0009455032620941839
# Validation Loss = 0.003
# Epoch=4, batch = 3000 of 4000, loss=0.515, LR=0.0009455032620941839
# Validation Loss = 0.685
# Epoch=5, batch = 0 of 4000, loss=1.259, LR=0.0009045084971874737
# Validation Loss = 0.293
# Epoch=5, batch = 1000 of 4000, loss=0.666, LR=0.0009045084971874737
# Validation Loss = 1.263
# Epoch=5, batch = 2000 of 4000, loss=1.353, LR=0.0009045084971874737
# Validation Loss = 0.102
# Epoch=5, batch = 3000 of 4000, loss=0.650, LR=0.0009045084971874737
# Validation Loss = 0.037
# Epoch=6, batch = 0 of 4000, loss=0.572, LR=0.0008535533905932737
# Validation Loss = 0.004
# Epoch=6, batch = 1000 of 4000, loss=0.454, LR=0.0008535533905932737
# Validation Loss = 0.238
# Epoch=6, batch = 2000 of 4000, loss=0.568, LR=0.0008535533905932737
# Validation Loss = 0.641
# Epoch=6, batch = 3000 of 4000, loss=0.875, LR=0.0008535533905932737
# Validation Loss = 0.163
# Epoch=7, batch = 0 of 4000, loss=0.698, LR=0.0007938926261462366
# Validation Loss = 0.000
# Epoch=7, batch = 1000 of 4000, loss=0.500, LR=0.0007938926261462366
# Validation Loss = 0.115
# Epoch=7, batch = 2000 of 4000, loss=0.468, LR=0.0007938926261462366
# Validation Loss = 0.467
# Epoch=7, batch = 3000 of 4000, loss=0.698, LR=0.0007938926261462366
# Validation Loss = 0.811
# Epoch=8, batch = 0 of 4000, loss=1.027, LR=0.0007269952498697733
# Validation Loss = 0.177
# Epoch=8, batch = 1000 of 4000, loss=0.754, LR=0.0007269952498697733
# Validation Loss = 0.426
# Epoch=8, batch = 2000 of 4000, loss=0.674, LR=0.0007269952498697733
# Validation Loss = 0.035
# Epoch=8, batch = 3000 of 4000, loss=0.436, LR=0.0007269952498697733
# Validation Loss = 0.087
# Epoch=9, batch = 0 of 4000, loss=0.501, LR=0.0006545084971874737
# Validation Loss = 1.001
# Epoch=9, batch = 1000 of 4000, loss=1.167, LR=0.0006545084971874737
# Validation Loss = 0.148
# Epoch=9, batch = 2000 of 4000, loss=0.482, LR=0.0006545084971874737
# Validation Loss = 0.476
# Epoch=9, batch = 3000 of 4000, loss=0.656, LR=0.0006545084971874737
# Validation Loss = 0.105
# Epoch=10, batch = 0 of 4000, loss=0.421, LR=0.0005782172325201155
# Validation Loss = 0.117
# Epoch=10, batch = 1000 of 4000, loss=0.613, LR=0.0005782172325201155
# Validation Loss = 0.424
# Epoch=10, batch = 2000 of 4000, loss=0.704, LR=0.0005782172325201155
# Validation Loss = 0.003
# Epoch=10, batch = 3000 of 4000, loss=0.426, LR=0.0005782172325201155
# Validation Loss = 0.073
# Epoch=11, batch = 0 of 4000, loss=0.464, LR=0.0005
# Validation Loss = 0.006
# Epoch=11, batch = 1000 of 4000, loss=0.475, LR=0.0005
# Validation Loss = 0.185
# Epoch=11, batch = 2000 of 4000, loss=0.550, LR=0.0005
# Validation Loss = 0.600
# Epoch=11, batch = 3000 of 4000, loss=0.893, LR=0.0005
# Validation Loss = 0.000
# Epoch=12, batch = 0 of 4000, loss=0.414, LR=0.0004217827674798847
# Validation Loss = 0.068
# Epoch=12, batch = 1000 of 4000, loss=0.441, LR=0.0004217827674798847
# Validation Loss = 0.026
# Epoch=12, batch = 2000 of 4000, loss=0.412, LR=0.0004217827674798847
# Validation Loss = 0.083
# Epoch=12, batch = 3000 of 4000, loss=0.433, LR=0.0004217827674798847
# Validation Loss = 0.003
# Epoch=13, batch = 0 of 4000, loss=0.404, LR=0.00034549150281252633
# Validation Loss = 0.054
# Epoch=13, batch = 1000 of 4000, loss=0.602, LR=0.00034549150281252633
# Validation Loss = 0.006
# Epoch=13, batch = 2000 of 4000, loss=0.420, LR=0.00034549150281252633
# Validation Loss = 0.155
# Epoch=13, batch = 3000 of 4000, loss=0.514, LR=0.00034549150281252633
# Validation Loss = 0.030
# ...
# Validation Loss = 0.512
# Epoch=12, batch = 1000 of 4000, loss=3.480, LR=0.0004217827674798847
# Validation Loss = 0.063
# Epoch=12, batch = 2000 of 4000, loss=3.370, LR=0.0004217827674798847
# Validation Loss = 1.014
# Epoch=12, batch = 3000 of 4000, loss=3.876, LR=0.0004217827674798847
# Validation Loss = 0.015
# Epoch=13, batch = 0 of 4000, loss=3.563, LR=0.00034549150281252633
# Validation Loss = 0.991
# Epoch=13, batch = 1000 of 4000, loss=4.135, LR=0.00034549150281252633
# Validation Loss = 0.023
# Epoch=13, batch = 2000 of 4000, loss=3.403, LR=0.00034549150281252633
# Validation Loss = 1.317
# Epoch=13, batch = 3000 of 4000, loss=3.939, LR=0.00034549150281252633
# Validation Loss = 0.048
# Epoch=14, batch = 0 of 4000, loss=3.857, LR=0.00027300475013022663
# Validation Loss = 0.136
# Epoch=14, batch = 1000 of 4000, loss=3.778, LR=0.00027300475013022663
# Validation Loss = 0.336
# Epoch=14, batch = 2000 of 4000, loss=3.679, LR=0.00027300475013022663
# Validation Loss = 0.044
# Epoch=14, batch = 3000 of 4000, loss=3.714, LR=0.00027300475013022663
# Validation Loss = 0.111
# Epoch=15, batch = 0 of 4000, loss=3.219, LR=0.00020610737385376348
# Validation Loss = 0.725
# Epoch=15, batch = 1000 of 4000, loss=3.616, LR=0.00020610737385376348
# Validation Loss = 0.571
# Epoch=15, batch = 2000 of 4000, loss=3.292, LR=0.00020610737385376348
# Validation Loss = 0.246
# Epoch=15, batch = 3000 of 4000, loss=3.297, LR=0.00020610737385376348
# Validation Loss = 0.575
# Epoch=16, batch = 0 of 4000, loss=3.386, LR=0.00014644660940672625
# Validation Loss = 0.292
# Epoch=16, batch = 1000 of 4000, loss=3.170, LR=0.00014644660940672625
# Validation Loss = 0.094
# Epoch=16, batch = 2000 of 4000, loss=3.443, LR=0.00014644660940672625
# Validation Loss = 0.594
# Epoch=16, batch = 3000 of 4000, loss=3.685, LR=0.00014644660940672625
# Validation Loss = 0.345
# Epoch=17, batch = 0 of 4000, loss=3.400, LR=9.549150281252631e-05
# Validation Loss = 0.483
# Epoch=17, batch = 1000 of 4000, loss=3.466, LR=9.549150281252631e-05
# Validation Loss = 0.136
# Epoch=17, batch = 2000 of 4000, loss=3.305, LR=9.549150281252631e-05
# Validation Loss = 0.770
# Epoch=17, batch = 3000 of 4000, loss=3.768, LR=9.549150281252631e-05
# Validation Loss = 0.445
# Epoch=18, batch = 0 of 4000, loss=3.582, LR=5.4496737905816096e-05
# Validation Loss = 0.194
# Epoch=18, batch = 1000 of 4000, loss=3.460, LR=5.4496737905816096e-05
# Validation Loss = 0.062
# Epoch=18, batch = 2000 of 4000, loss=3.449, LR=5.4496737905816096e-05
# Validation Loss = 0.680
# Epoch=18, batch = 3000 of 4000, loss=3.676, LR=5.4496737905816096e-05
# Validation Loss = 0.012
# Epoch=19, batch = 0 of 4000, loss=3.286, LR=2.447174185242323e-05
# Validation Loss = 0.253
# Epoch=19, batch = 1000 of 4000, loss=3.467, LR=2.447174185242323e-05
# Validation Loss = 0.216
# Epoch=19, batch = 2000 of 4000, loss=3.444, LR=2.447174185242323e-05
# Validation Loss = 0.329
# Epoch=19, batch = 3000 of 4000, loss=3.320, LR=2.447174185242323e-05
# Validation Loss = 0.163
# Epoch=20, batch = 0 of 4000, loss=3.154, LR=6.15582970243117e-06
# Validation Loss = 0.156
# Epoch=20, batch = 1000 of 4000, loss=3.115, LR=6.15582970243117e-06
# Validation Loss = 0.191
# Epoch=20, batch = 2000 of 4000, loss=3.067, LR=6.15582970243117e-06
# Validation Loss = 0.125
# Epoch=20, batch = 3000 of 4000, loss=3.521, LR=6.15582970243117e-06
# Finished training model for channel 183+-3V.
# 183+-7V
# Training stage: 1
# Validation Loss = 69785.633
# Epoch=1, batch = 0 of 4000, loss=70444.734, LR=0.001
# Validation Loss = 1.233
# Epoch=1, batch = 1000 of 4000, loss=1.685, LR=0.001
# Validation Loss = 1.633
# Epoch=1, batch = 2000 of 4000, loss=1.523, LR=0.001
# Validation Loss = 0.648
# Epoch=1, batch = 3000 of 4000, loss=1.246, LR=0.001
# Validation Loss = 1.960
# Epoch=2, batch = 0 of 4000, loss=6.110, LR=0.0009045084971874737
# Validation Loss = 6.633
# Epoch=2, batch = 1000 of 4000, loss=11.312, LR=0.0009045084971874737
# Validation Loss = 5.588
# Epoch=2, batch = 2000 of 4000, loss=10.875, LR=0.0009045084971874737
# Validation Loss = 0.197
# Epoch=2, batch = 3000 of 4000, loss=1.143, LR=0.0009045084971874737
# Validation Loss = 0.526
# Epoch=3, batch = 0 of 4000, loss=1.311, LR=0.0006545084971874737
# Validation Loss = 0.000
# Epoch=3, batch = 1000 of 4000, loss=1.307, LR=0.0006545084971874737
# Validation Loss = 0.738
# Epoch=3, batch = 2000 of 4000, loss=1.374, LR=0.0006545084971874737
# Validation Loss = 0.011
# Epoch=3, batch = 3000 of 4000, loss=1.172, LR=0.0006545084971874737
# Validation Loss = 0.747
# Epoch=4, batch = 0 of 4000, loss=3.053, LR=0.00034549150281252633
# Validation Loss = 0.384
# Epoch=4, batch = 1000 of 4000, loss=0.999, LR=0.00034549150281252633
# Validation Loss = 0.431
# Epoch=4, batch = 2000 of 4000, loss=1.168, LR=0.00034549150281252633
# Validation Loss = 1.578
# Epoch=4, batch = 3000 of 4000, loss=3.466, LR=0.00034549150281252633
# Validation Loss = 0.476
# Epoch=5, batch = 0 of 4000, loss=1.175, LR=9.549150281252633e-05
# Validation Loss = 0.065
# Epoch=5, batch = 1000 of 4000, loss=0.918, LR=9.549150281252633e-05
# Validation Loss = 0.222
# Epoch=5, batch = 2000 of 4000, loss=1.181, LR=9.549150281252633e-05
# Validation Loss = 0.005
# Epoch=5, batch = 3000 of 4000, loss=0.982, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.032
# Epoch=1, batch = 0 of 4000, loss=1.047, LR=0.001
# Validation Loss = 0.151
# Epoch=1, batch = 1000 of 4000, loss=1.144, LR=0.001
# Validation Loss = 0.757
# Epoch=1, batch = 2000 of 4000, loss=1.198, LR=0.001
# Validation Loss = 0.230
# Epoch=1, batch = 3000 of 4000, loss=2.026, LR=0.001
# Validation Loss = 0.019
# Epoch=2, batch = 0 of 4000, loss=1.438, LR=0.0009755282581475768
# Validation Loss = 0.991
# Epoch=2, batch = 1000 of 4000, loss=1.409, LR=0.0009755282581475768
# Validation Loss = 1.227
# Epoch=2, batch = 2000 of 4000, loss=1.643, LR=0.0009755282581475768
# Validation Loss = 3.706
# Epoch=2, batch = 3000 of 4000, loss=3.059, LR=0.0009755282581475768
# Validation Loss = 0.457
# Epoch=3, batch = 0 of 4000, loss=1.105, LR=0.0009045084971874736
# Validation Loss = 1.483
# Epoch=3, batch = 1000 of 4000, loss=1.821, LR=0.0009045084971874736
# Validation Loss = 0.183
# Epoch=3, batch = 2000 of 4000, loss=1.738, LR=0.0009045084971874736
# Validation Loss = 0.214
# Epoch=3, batch = 3000 of 4000, loss=1.665, LR=0.0009045084971874736
# Validation Loss = 0.476
# Epoch=4, batch = 0 of 4000, loss=1.178, LR=0.0007938926261462366
# Validation Loss = 1.270
# Epoch=4, batch = 1000 of 4000, loss=2.013, LR=0.0007938926261462366
# Validation Loss = 0.280
# Epoch=4, batch = 2000 of 4000, loss=1.056, LR=0.0007938926261462366
# Validation Loss = 0.039
# Epoch=4, batch = 3000 of 4000, loss=1.294, LR=0.0007938926261462366
# Validation Loss = 0.571
# Epoch=5, batch = 0 of 4000, loss=1.978, LR=0.0006545084971874737
# Validation Loss = 0.226
# Epoch=5, batch = 1000 of 4000, loss=1.016, LR=0.0006545084971874737
# Validation Loss = 0.651
# Epoch=5, batch = 2000 of 4000, loss=1.556, LR=0.0006545084971874737
# Validation Loss = 0.001
# Epoch=5, batch = 3000 of 4000, loss=1.113, LR=0.0006545084971874737
# Validation Loss = 0.095
# Epoch=6, batch = 0 of 4000, loss=1.208, LR=0.0005
# Validation Loss = 0.051
# Epoch=6, batch = 1000 of 4000, loss=1.093, LR=0.0005
# Validation Loss = 0.386
# Epoch=6, batch = 2000 of 4000, loss=1.248, LR=0.0005
# Validation Loss = 0.089
# Epoch=6, batch = 3000 of 4000, loss=0.887, LR=0.0005
# Validation Loss = 0.550
# Epoch=7, batch = 0 of 4000, loss=1.304, LR=0.00034549150281252633
# Validation Loss = 0.116
# Epoch=7, batch = 1000 of 4000, loss=1.397, LR=0.00034549150281252633
# Validation Loss = 0.056
# Epoch=7, batch = 2000 of 4000, loss=0.966, LR=0.00034549150281252633
# Validation Loss = 0.008
# Epoch=7, batch = 3000 of 4000, loss=0.977, LR=0.00034549150281252633
# Validation Loss = 0.015
# Epoch=8, batch = 0 of 4000, loss=0.979, LR=0.0002061073738537635
# Validation Loss = 0.019
# Epoch=8, batch = 1000 of 4000, loss=1.005, LR=0.0002061073738537635
# Validation Loss = 0.100
# Epoch=8, batch = 2000 of 4000, loss=0.904, LR=0.0002061073738537635
# Validation Loss = 0.228
# Epoch=8, batch = 3000 of 4000, loss=1.126, LR=0.0002061073738537635
# Validation Loss = 0.032
# Epoch=9, batch = 0 of 4000, loss=0.914, LR=9.549150281252634e-05
# Validation Loss = 0.007
# Epoch=9, batch = 1000 of 4000, loss=0.941, LR=9.549150281252634e-05
# Validation Loss = 0.043
# Epoch=9, batch = 2000 of 4000, loss=0.980, LR=9.549150281252634e-05
# Validation Loss = 0.133
# Epoch=9, batch = 3000 of 4000, loss=0.887, LR=9.549150281252634e-05
# Validation Loss = 0.001
# Epoch=10, batch = 0 of 4000, loss=0.972, LR=2.4471741852423235e-05
# Validation Loss = 0.005
# Epoch=10, batch = 1000 of 4000, loss=0.850, LR=2.4471741852423235e-05
# Validation Loss = 0.023
# Epoch=10, batch = 2000 of 4000, loss=0.943, LR=2.4471741852423235e-05
# Validation Loss = 0.006
# Epoch=10, batch = 3000 of 4000, loss=0.948, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 0.006
# Epoch=1, batch = 0 of 4000, loss=1.036, LR=0.001
# Validation Loss = 0.014
# Epoch=1, batch = 1000 of 4000, loss=0.997, LR=0.001
# Validation Loss = 0.009
# Epoch=1, batch = 2000 of 4000, loss=0.994, LR=0.001
# Validation Loss = 0.389
# Epoch=1, batch = 3000 of 4000, loss=1.303, LR=0.001
# Validation Loss = 2.022
# Epoch=2, batch = 0 of 4000, loss=3.742, LR=0.0009938441702975688
# Validation Loss = 0.010
# Epoch=2, batch = 1000 of 4000, loss=1.055, LR=0.0009938441702975688
# Validation Loss = 2.436
# Epoch=2, batch = 2000 of 4000, loss=3.191, LR=0.0009938441702975688
# Validation Loss = 0.001
# Epoch=2, batch = 3000 of 4000, loss=0.997, LR=0.0009938441702975688
# Validation Loss = 0.061
# Epoch=3, batch = 0 of 4000, loss=0.992, LR=0.0009755282581475768
# Validation Loss = 1.297
# Epoch=3, batch = 1000 of 4000, loss=2.108, LR=0.0009755282581475768
# Validation Loss = 0.851
# Epoch=3, batch = 2000 of 4000, loss=2.374, LR=0.0009755282581475768
# Validation Loss = 0.195
# Epoch=3, batch = 3000 of 4000, loss=1.073, LR=0.0009755282581475768
# Validation Loss = 0.621
# Epoch=4, batch = 0 of 4000, loss=1.374, LR=0.0009455032620941839
# Validation Loss = 0.261
# Epoch=4, batch = 1000 of 4000, loss=1.145, LR=0.0009455032620941839
# Validation Loss = 0.673
# Epoch=4, batch = 2000 of 4000, loss=1.467, LR=0.0009455032620941839
# Validation Loss = 0.589
# Epoch=4, batch = 3000 of 4000, loss=1.413, LR=0.0009455032620941839
# Validation Loss = 0.919
# Epoch=5, batch = 0 of 4000, loss=2.073, LR=0.0009045084971874737
# Validation Loss = 0.023
# Epoch=5, batch = 1000 of 4000, loss=1.054, LR=0.0009045084971874737
# Validation Loss = 0.986
# Epoch=5, batch = 2000 of 4000, loss=2.345, LR=0.0009045084971874737
# Validation Loss = 0.011
# Epoch=5, batch = 3000 of 4000, loss=0.958, LR=0.0009045084971874737
# Validation Loss = 0.459
# Epoch=6, batch = 0 of 4000, loss=1.264, LR=0.0008535533905932737
# Validation Loss = 0.134
# Epoch=6, batch = 1000 of 4000, loss=1.126, LR=0.0008535533905932737
# Validation Loss = 1.064
# Epoch=6, batch = 2000 of 4000, loss=1.678, LR=0.0008535533905932737
# Validation Loss = 0.518
# Epoch=6, batch = 3000 of 4000, loss=1.719, LR=0.0008535533905932737
# Validation Loss = 0.071
# Epoch=7, batch = 0 of 4000, loss=1.058, LR=0.0007938926261462366
# Validation Loss = 0.162
# Epoch=7, batch = 1000 of 4000, loss=1.299, LR=0.0007938926261462366
# Validation Loss = 0.085
# Epoch=7, batch = 2000 of 4000, loss=0.992, LR=0.0007938926261462366
# Validation Loss = 0.511
# Epoch=7, batch = 3000 of 4000, loss=1.254, LR=0.0007938926261462366
# Validation Loss = 0.983
# Epoch=8, batch = 0 of 4000, loss=1.549, LR=0.0007269952498697733
# Validation Loss = 0.461
# Epoch=8, batch = 1000 of 4000, loss=1.158, LR=0.0007269952498697733
# Validation Loss = 0.054
# Epoch=8, batch = 2000 of 4000, loss=1.317, LR=0.0007269952498697733
# Validation Loss = 0.137
# Epoch=8, batch = 3000 of 4000, loss=1.323, LR=0.0007269952498697733
# Validation Loss = 0.074
# Epoch=9, batch = 0 of 4000, loss=1.208, LR=0.0006545084971874737
# Validation Loss = 0.096
# Epoch=9, batch = 1000 of 4000, loss=1.037, LR=0.0006545084971874737
# Validation Loss = 0.003
# Epoch=9, batch = 2000 of 4000, loss=1.000, LR=0.0006545084971874737
# Validation Loss = 0.106
# Epoch=9, batch = 3000 of 4000, loss=0.856, LR=0.0006545084971874737
# Validation Loss = 0.007
# Epoch=10, batch = 0 of 4000, loss=1.104, LR=0.0005782172325201155
# Validation Loss = 0.001
# Epoch=10, batch = 1000 of 4000, loss=0.917, LR=0.0005782172325201155
# Validation Loss = 0.006
# Epoch=10, batch = 2000 of 4000, loss=0.945, LR=0.0005782172325201155
# Validation Loss = 0.528
# Epoch=10, batch = 3000 of 4000, loss=1.259, LR=0.0005782172325201155
# Validation Loss = 0.219
# Epoch=11, batch = 0 of 4000, loss=0.995, LR=0.0005
# Validation Loss = 0.306
# Epoch=11, batch = 1000 of 4000, loss=1.071, LR=0.0005
# Validation Loss = 0.233
# Epoch=11, batch = 2000 of 4000, loss=1.029, LR=0.0005
# Validation Loss = 0.040
# Epoch=11, batch = 3000 of 4000, loss=1.033, LR=0.0005
# Validation Loss = 0.338
# Epoch=12, batch = 0 of 4000, loss=1.055, LR=0.0004217827674798847
# Validation Loss = 0.178
# Epoch=12, batch = 1000 of 4000, loss=1.037, LR=0.0004217827674798847
# Validation Loss = 0.000
# Epoch=12, batch = 2000 of 4000, loss=1.018, LR=0.0004217827674798847
# Validation Loss = 0.150
# Epoch=12, batch = 3000 of 4000, loss=1.095, LR=0.0004217827674798847
# Validation Loss = 0.230
# Epoch=13, batch = 0 of 4000, loss=1.032, LR=0.00034549150281252633
# Validation Loss = 0.007
# Epoch=13, batch = 1000 of 4000, loss=0.973, LR=0.00034549150281252633
# Validation Loss = 0.002
# Epoch=13, batch = 2000 of 4000, loss=0.949, LR=0.00034549150281252633
# Validation Loss = 0.074
# Epoch=13, batch = 3000 of 4000, loss=0.951, LR=0.00034549150281252633
# Validation Loss = 0.137
# Epoch=14, batch = 0 of 4000, loss=0.944, LR=0.00027300475013022663
# Validation Loss = 0.147
# Epoch=14, batch = 1000 of 4000, loss=0.955, LR=0.00027300475013022663
# Validation Loss = 0.161
# Epoch=14, batch = 2000 of 4000, loss=0.967, LR=0.00027300475013022663
# Validation Loss = 0.010
# Epoch=14, batch = 3000 of 4000, loss=0.935, LR=0.00027300475013022663
# Validation Loss = 0.240
# Epoch=15, batch = 0 of 4000, loss=1.033, LR=0.00020610737385376348
# Validation Loss = 0.019
# Epoch=15, batch = 1000 of 4000, loss=0.926, LR=0.00020610737385376348
# Validation Loss = 0.002
# Epoch=15, batch = 2000 of 4000, loss=0.920, LR=0.00020610737385376348
# Validation Loss = 0.005
# Epoch=15, batch = 3000 of 4000, loss=0.962, LR=0.00020610737385376348
# Validation Loss = 0.143
# Epoch=16, batch = 0 of 4000, loss=0.891, LR=0.00014644660940672625
# Validation Loss = 0.001
# Epoch=16, batch = 1000 of 4000, loss=0.960, LR=0.00014644660940672625
# Validation Loss = 0.001
# Epoch=16, batch = 2000 of 4000, loss=0.992, LR=0.00014644660940672625
# Validation Loss = 0.017
# Epoch=16, batch = 3000 of 4000, loss=0.948, LR=0.00014644660940672625
# Validation Loss = 0.075
# Epoch=17, batch = 0 of 4000, loss=0.990, LR=9.549150281252631e-05
# Validation Loss = 0.081
# Epoch=17, batch = 1000 of 4000, loss=0.906, LR=9.549150281252631e-05
# Validation Loss = 0.048
# Epoch=17, batch = 2000 of 4000, loss=0.831, LR=9.549150281252631e-05
# Validation Loss = 0.000
# Epoch=17, batch = 3000 of 4000, loss=0.985, LR=9.549150281252631e-05
# Validation Loss = 0.123
# Epoch=18, batch = 0 of 4000, loss=0.911, LR=5.4496737905816096e-05
# Validation Loss = 0.003
# Epoch=18, batch = 1000 of 4000, loss=0.940, LR=5.4496737905816096e-05
# Validation Loss = 0.020
# Epoch=18, batch = 2000 of 4000, loss=0.900, LR=5.4496737905816096e-05
# Validation Loss = 0.000
# Epoch=18, batch = 3000 of 4000, loss=0.922, LR=5.4496737905816096e-05
# Validation Loss = 0.013
# Epoch=19, batch = 0 of 4000, loss=0.864, LR=2.447174185242323e-05
# Validation Loss = 0.005
# Epoch=19, batch = 1000 of 4000, loss=0.958, LR=2.447174185242323e-05
# Validation Loss = 0.013
# Epoch=19, batch = 2000 of 4000, loss=0.896, LR=2.447174185242323e-05
# Validation Loss = 0.081
# Epoch=19, batch = 3000 of 4000, loss=0.953, LR=2.447174185242323e-05
# Validation Loss = 0.015
# Epoch=20, batch = 0 of 4000, loss=0.876, LR=6.15582970243117e-06
# Validation Loss = 0.004
# Epoch=20, batch = 1000 of 4000, loss=0.887, LR=6.15582970243117e-06
# Validation Loss = 0.021
# Epoch=20, batch = 2000 of 4000, loss=0.926, LR=6.15582970243117e-06
# Validation Loss = 0.004
# Epoch=20, batch = 3000 of 4000, loss=0.876, LR=6.15582970243117e-06
# Finished training model for channel 183+-7V.

# %%
#General parameters:
input_size = nchans - 1 + 1 #Remaining channels + surface type

# %%
'''

GMI CHANNEL PREDICTION MODEL:
    2: Non-Ocean Surfaces

'''

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = sfctype > 1

    Tbs = f.Tbs.values[correct_sfc,:]
    sfctype = sfctype[correct_sfc]

Tbs = Tbs[:,2:]

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = local_functions.split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

sfctype_train = sfctype[train_indcs].astype(np.float32)
sfctype_test  = sfctype[test_indcs].astype(np.float32)
sfctype_val   = sfctype[val_indcs].astype(np.float32)

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train, shuffled_indcs = array_funcs.shuffle_data(Tbs_train, axis=0, return_indcs=True)
sfctype_train = sfctype_train[shuffled_indcs]

# %%
sfctype_train, sfctype_test, sfctype_val
# Out:
# (array([ 8.,  5.,  2., ...,  5.,  9., 17.],
#        shape=(14253019,), dtype=float32),
#  array([10., 10., 10., ..., 18., 18., 18.], shape=(1781627,), dtype=float32),
#  array([18., 18., 18., ...,  2.,  2.,  2.], shape=(1781628,), dtype=float32))

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    print(channel)

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)

    x_train = np.concatenate((x_train, sfctype_train[:,None]), axis=1)
    x_test  = np.concatenate((x_test,  sfctype_test[:,None]), axis=1)
    x_val   = np.concatenate((x_val,   sfctype_val[:,None]), axis=1)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_nonocean_no10.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_nonocean_no10.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# 19V
# Training stage: 1
# Validation Loss = 61833.207
# Epoch=1, batch = 0 of 14253, loss=74896.578, LR=0.001
# Validation Loss = 0.471
# Epoch=1, batch = 1000 of 14253, loss=4.282, LR=0.001
# Validation Loss = 7.252
# Epoch=1, batch = 2000 of 14253, loss=2.867, LR=0.001
# Validation Loss = 7.336
# Epoch=1, batch = 3000 of 14253, loss=3.084, LR=0.001
# Validation Loss = 0.396
# Epoch=1, batch = 4000 of 14253, loss=5.438, LR=0.001
# Validation Loss = 11.649
# Epoch=1, batch = 5000 of 14253, loss=4.114, LR=0.001
# Validation Loss = 4.715
# Epoch=1, batch = 6000 of 14253, loss=2.157, LR=0.001
# Validation Loss = 14.386
# Epoch=1, batch = 7000 of 14253, loss=4.640, LR=0.001
# Validation Loss = 0.001
# Epoch=1, batch = 8000 of 14253, loss=8.124, LR=0.001
# Validation Loss = 3.753
# Epoch=1, batch = 9000 of 14253, loss=2.219, LR=0.001
# Validation Loss = 10.396
# Epoch=1, batch = 10000 of 14253, loss=2.641, LR=0.001
# Validation Loss = 7.003
# Epoch=1, batch = 11000 of 14253, loss=1.768, LR=0.001
# Validation Loss = 0.369
# Epoch=1, batch = 12000 of 14253, loss=4.321, LR=0.001
# Validation Loss = 6.117
# Epoch=1, batch = 13000 of 14253, loss=1.873, LR=0.001
# Validation Loss = 11.653
# Epoch=1, batch = 14000 of 14253, loss=2.253, LR=0.001
# Validation Loss = 6.883
# Epoch=2, batch = 0 of 14253, loss=1.815, LR=0.0009045084971874737
# Validation Loss = 3.551
# Epoch=2, batch = 1000 of 14253, loss=1.769, LR=0.0009045084971874737
# Validation Loss = 8.484
# Epoch=2, batch = 2000 of 14253, loss=1.951, LR=0.0009045084971874737
# Validation Loss = 2.113
# Epoch=2, batch = 3000 of 14253, loss=2.629, LR=0.0009045084971874737
# Validation Loss = 8.451
# Epoch=2, batch = 4000 of 14253, loss=1.680, LR=0.0009045084971874737
# Validation Loss = 18.379
# Epoch=2, batch = 5000 of 14253, loss=3.071, LR=0.0009045084971874737
# Validation Loss = 5.441
# Epoch=2, batch = 6000 of 14253, loss=1.453, LR=0.0009045084971874737
# Validation Loss = 1.909
# Epoch=2, batch = 7000 of 14253, loss=2.195, LR=0.0009045084971874737
# Validation Loss = 3.702
# Epoch=2, batch = 8000 of 14253, loss=1.299, LR=0.0009045084971874737
# Validation Loss = 2.818
# Epoch=2, batch = 9000 of 14253, loss=1.658, LR=0.0009045084971874737
# Validation Loss = 5.873
# Epoch=2, batch = 10000 of 14253, loss=2.028, LR=0.0009045084971874737
# Validation Loss = 1.981
# Epoch=2, batch = 11000 of 14253, loss=2.722, LR=0.0009045084971874737
# Validation Loss = 6.214
# Epoch=2, batch = 12000 of 14253, loss=1.793, LR=0.0009045084971874737
# Validation Loss = 2.329
# Epoch=2, batch = 13000 of 14253, loss=1.625, LR=0.0009045084971874737
# Validation Loss = 3.796
# Epoch=2, batch = 14000 of 14253, loss=1.902, LR=0.0009045084971874737
# Validation Loss = 8.609
# Epoch=3, batch = 0 of 14253, loss=1.759, LR=0.0006545084971874737
# Validation Loss = 4.018
# Epoch=3, batch = 1000 of 14253, loss=1.510, LR=0.0006545084971874737
# Validation Loss = 4.640
# Epoch=3, batch = 2000 of 14253, loss=1.617, LR=0.0006545084971874737
# Validation Loss = 0.206
# Epoch=3, batch = 3000 of 14253, loss=3.454, LR=0.0006545084971874737
# Validation Loss = 3.070
# Epoch=3, batch = 4000 of 14253, loss=1.359, LR=0.0006545084971874737
# Validation Loss = 4.809
# Epoch=3, batch = 5000 of 14253, loss=1.424, LR=0.0006545084971874737
# Validation Loss = 5.759
# Epoch=3, batch = 6000 of 14253, loss=1.617, LR=0.0006545084971874737
# Validation Loss = 3.113
# Epoch=3, batch = 7000 of 14253, loss=1.218, LR=0.0006545084971874737
# Validation Loss = 2.927
# Epoch=3, batch = 8000 of 14253, loss=1.315, LR=0.0006545084971874737
# Validation Loss = 0.820
# Epoch=3, batch = 9000 of 14253, loss=2.252, LR=0.0006545084971874737
# Validation Loss = 5.574
# Epoch=3, batch = 10000 of 14253, loss=1.404, LR=0.0006545084971874737
# Validation Loss = 3.903
# Epoch=3, batch = 11000 of 14253, loss=1.568, LR=0.0006545084971874737
# Validation Loss = 2.475
# Epoch=3, batch = 12000 of 14253, loss=1.653, LR=0.0006545084971874737
# Validation Loss = 2.472
# Epoch=3, batch = 13000 of 14253, loss=1.232, LR=0.0006545084971874737
# Validation Loss = 1.757
# Epoch=3, batch = 14000 of 14253, loss=1.271, LR=0.0006545084971874737
# Validation Loss = 4.417
# Epoch=4, batch = 0 of 14253, loss=1.529, LR=0.00034549150281252633
# Validation Loss = 2.694
# Epoch=4, batch = 1000 of 14253, loss=1.469, LR=0.00034549150281252633
# Validation Loss = 2.190
# Epoch=4, batch = 2000 of 14253, loss=1.285, LR=0.00034549150281252633
# Validation Loss = 2.573
# Epoch=4, batch = 3000 of 14253, loss=1.280, LR=0.00034549150281252633
# Validation Loss = 3.275
# Epoch=4, batch = 4000 of 14253, loss=1.381, LR=0.00034549150281252633
# Validation Loss = 5.652
# Epoch=4, batch = 5000 of 14253, loss=1.475, LR=0.00034549150281252633
# Validation Loss = 4.663
# Epoch=4, batch = 6000 of 14253, loss=1.734, LR=0.00034549150281252633
# Validation Loss = 2.543
# Epoch=4, batch = 7000 of 14253, loss=1.391, LR=0.00034549150281252633
# Validation Loss = 2.477
# Epoch=4, batch = 8000 of 14253, loss=1.245, LR=0.00034549150281252633
# Validation Loss = 2.107
# Epoch=4, batch = 9000 of 14253, loss=1.561, LR=0.00034549150281252633
# Validation Loss = 2.625
# Epoch=4, batch = 10000 of 14253, loss=1.434, LR=0.00034549150281252633
# Validation Loss = 4.037
# Epoch=4, batch = 11000 of 14253, loss=1.290, LR=0.00034549150281252633
# Validation Loss = 3.505
# Epoch=4, batch = 12000 of 14253, loss=1.120, LR=0.00034549150281252633
# Validation Loss = 4.182
# Epoch=4, batch = 13000 of 14253, loss=1.405, LR=0.00034549150281252633
# Validation Loss = 3.803
# Epoch=4, batch = 14000 of 14253, loss=1.192, LR=0.00034549150281252633
# Validation Loss = 2.007
# Epoch=5, batch = 0 of 14253, loss=1.349, LR=9.549150281252633e-05
# Validation Loss = 3.430
# Epoch=5, batch = 1000 of 14253, loss=1.306, LR=9.549150281252633e-05
# Validation Loss = 2.621
# Epoch=5, batch = 2000 of 14253, loss=1.335, LR=9.549150281252633e-05
# Validation Loss = 2.638
# Epoch=5, batch = 3000 of 14253, loss=1.219, LR=9.549150281252633e-05
# Validation Loss = 2.444
# Epoch=5, batch = 4000 of 14253, loss=1.110, LR=9.549150281252633e-05
# Validation Loss = 3.217
# Epoch=5, batch = 5000 of 14253, loss=1.181, LR=9.549150281252633e-05
# Validation Loss = 3.084
# Epoch=5, batch = 6000 of 14253, loss=1.154, LR=9.549150281252633e-05
# Validation Loss = 3.315
# Epoch=5, batch = 7000 of 14253, loss=1.249, LR=9.549150281252633e-05
# Validation Loss = 3.370
# Epoch=5, batch = 8000 of 14253, loss=1.210, LR=9.549150281252633e-05
# Validation Loss = 3.411
# Epoch=5, batch = 9000 of 14253, loss=1.130, LR=9.549150281252633e-05
# Validation Loss = 2.951
# Epoch=5, batch = 10000 of 14253, loss=1.374, LR=9.549150281252633e-05
# Validation Loss = 3.760
# Epoch=5, batch = 11000 of 14253, loss=1.060, LR=9.549150281252633e-05
# Validation Loss = 2.304
# Epoch=5, batch = 12000 of 14253, loss=1.339, LR=9.549150281252633e-05
# Validation Loss = 5.090
# Epoch=5, batch = 13000 of 14253, loss=1.614, LR=9.549150281252633e-05
# Validation Loss = 2.527
# Epoch=5, batch = 14000 of 14253, loss=1.211, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 2.531
# Epoch=1, batch = 0 of 14253, loss=1.164, LR=0.001
# Validation Loss = 5.065
# Epoch=1, batch = 1000 of 14253, loss=1.927, LR=0.001
# Validation Loss = 1.701
# Epoch=1, batch = 2000 of 14253, loss=1.704, LR=0.001
# Validation Loss = 0.303
# Epoch=1, batch = 3000 of 14253, loss=4.581, LR=0.001
# Validation Loss = 9.716
# Epoch=1, batch = 4000 of 14253, loss=4.300, LR=0.001
# Validation Loss = 0.344
# Epoch=1, batch = 5000 of 14253, loss=2.362, LR=0.001
# Validation Loss = 5.326
# Epoch=1, batch = 6000 of 14253, loss=2.295, LR=0.001
# Validation Loss = 2.629
# Epoch=1, batch = 7000 of 14253, loss=1.436, LR=0.001
# Validation Loss = 10.496
# Epoch=1, batch = 8000 of 14253, loss=2.052, LR=0.001
# Validation Loss = 4.640
# Epoch=1, batch = 9000 of 14253, loss=1.371, LR=0.001
# Validation Loss = 2.055
# Epoch=1, batch = 10000 of 14253, loss=1.612, LR=0.001
# Validation Loss = 1.615
# Epoch=1, batch = 11000 of 14253, loss=1.777, LR=0.001
# Validation Loss = 0.517
# Epoch=1, batch = 12000 of 14253, loss=2.729, LR=0.001
# Validation Loss = 0.962
# Epoch=1, batch = 13000 of 14253, loss=1.598, LR=0.001
# Validation Loss = 5.337
# Epoch=1, batch = 14000 of 14253, loss=1.490, LR=0.001
# Validation Loss = 0.871
# Epoch=2, batch = 0 of 14253, loss=2.045, LR=0.0009755282581475768
# Validation Loss = 5.702
# Epoch=2, batch = 1000 of 14253, loss=1.836, LR=0.0009755282581475768
# Validation Loss = 5.327
# Epoch=2, batch = 2000 of 14253, loss=1.758, LR=0.0009755282581475768
# Validation Loss = 1.233
# Epoch=2, batch = 3000 of 14253, loss=1.699, LR=0.0009755282581475768
# Validation Loss = 1.642
# Epoch=2, batch = 4000 of 14253, loss=1.758, LR=0.0009755282581475768
# Validation Loss = 2.933
# Epoch=2, batch = 5000 of 14253, loss=1.265, LR=0.0009755282581475768
# Validation Loss = 1.981
# Epoch=2, batch = 6000 of 14253, loss=1.818, LR=0.0009755282581475768
# Validation Loss = 1.186
# Epoch=2, batch = 7000 of 14253, loss=1.585, LR=0.0009755282581475768
# Validation Loss = 2.781
# Epoch=2, batch = 8000 of 14253, loss=1.228, LR=0.0009755282581475768
# Validation Loss = 2.406
# Epoch=2, batch = 9000 of 14253, loss=1.495, LR=0.0009755282581475768
# Validation Loss = 4.144
# Epoch=2, batch = 10000 of 14253, loss=1.401, LR=0.0009755282581475768
# Validation Loss = 0.076
# Epoch=2, batch = 11000 of 14253, loss=3.524, LR=0.0009755282581475768
# Validation Loss = 4.437
# Epoch=2, batch = 12000 of 14253, loss=1.205, LR=0.0009755282581475768
# Validation Loss = 1.840
# Epoch=2, batch = 13000 of 14253, loss=1.273, LR=0.0009755282581475768
# Validation Loss = 0.844
# Epoch=2, batch = 14000 of 14253, loss=1.977, LR=0.0009755282581475768
# Validation Loss = 5.313
# Epoch=3, batch = 0 of 14253, loss=1.655, LR=0.0009045084971874736
# Validation Loss = 3.590
# Epoch=3, batch = 1000 of 14253, loss=1.382, LR=0.0009045084971874736
# Validation Loss = 5.692
# Epoch=3, batch = 2000 of 14253, loss=2.174, LR=0.0009045084971874736
# Validation Loss = 2.953
# Epoch=3, batch = 3000 of 14253, loss=1.358, LR=0.0009045084971874736
# Validation Loss = 1.512
# Epoch=3, batch = 4000 of 14253, loss=1.439, LR=0.0009045084971874736
# Validation Loss = 4.432
# Epoch=3, batch = 5000 of 14253, loss=1.229, LR=0.0009045084971874736
# Validation Loss = 4.344
# Epoch=3, batch = 6000 of 14253, loss=1.818, LR=0.0009045084971874736
# Validation Loss = 0.649
# Epoch=3, batch = 7000 of 14253, loss=2.076, LR=0.0009045084971874736
# Validation Loss = 4.410
# Epoch=3, batch = 8000 of 14253, loss=1.405, LR=0.0009045084971874736
# Validation Loss = 2.555
# Epoch=3, batch = 9000 of 14253, loss=1.222, LR=0.0009045084971874736
# Validation Loss = 1.841
# Epoch=3, batch = 10000 of 14253, loss=1.317, LR=0.0009045084971874736
# Validation Loss = 3.835
# Epoch=3, batch = 11000 of 14253, loss=1.307, LR=0.0009045084971874736
# Validation Loss = 0.306
# Epoch=3, batch = 12000 of 14253, loss=2.479, LR=0.0009045084971874736
# Validation Loss = 4.279
# Epoch=3, batch = 13000 of 14253, loss=1.877, LR=0.0009045084971874736
# Validation Loss = 1.555
# Epoch=3, batch = 14000 of 14253, loss=1.305, LR=0.0009045084971874736
# Validation Loss = 4.431
# Epoch=4, batch = 0 of 14253, loss=1.173, LR=0.0007938926261462366
# Validation Loss = 2.526
# Epoch=4, batch = 1000 of 14253, loss=1.172, LR=0.0007938926261462366
# Validation Loss = 2.292
# Epoch=4, batch = 2000 of 14253, loss=1.253, LR=0.0007938926261462366
# Validation Loss = 2.494
# Epoch=4, batch = 3000 of 14253, loss=1.186, LR=0.0007938926261462366
# Validation Loss = 4.143
# Epoch=4, batch = 4000 of 14253, loss=1.640, LR=0.0007938926261462366
# Validation Loss = 1.197
# Epoch=4, batch = 5000 of 14253, loss=1.806, LR=0.0007938926261462366
# Validation Loss = 3.675
# Epoch=4, batch = 6000 of 14253, loss=1.295, LR=0.0007938926261462366
# Validation Loss = 6.538
# Epoch=4, batch = 7000 of 14253, loss=2.118, LR=0.0007938926261462366
# Validation Loss = 4.126
# Epoch=4, batch = 8000 of 14253, loss=1.689, LR=0.0007938926261462366
# Validation Loss = 4.115
# Epoch=4, batch = 9000 of 14253, loss=1.350, LR=0.0007938926261462366
# Validation Loss = 0.867
# Epoch=4, batch = 10000 of 14253, loss=1.771, LR=0.0007938926261462366
# Validation Loss = 4.360
# Epoch=4, batch = 11000 of 14253, loss=1.452, LR=0.0007938926261462366
# Validation Loss = 4.665
# Epoch=4, batch = 12000 of 14253, loss=1.579, LR=0.0007938926261462366
# Validation Loss = 0.957
# Epoch=4, batch = 13000 of 14253, loss=1.281, LR=0.0007938926261462366
# Validation Loss = 2.222
# Epoch=4, batch = 14000 of 14253, loss=1.077, LR=0.0007938926261462366
# Validation Loss = 0.425
# Epoch=5, batch = 0 of 14253, loss=1.840, LR=0.0006545084971874737
# Validation Loss = 1.665
# Epoch=5, batch = 1000 of 14253, loss=1.128, LR=0.0006545084971874737
# Validation Loss = 0.438
# Epoch=5, batch = 2000 of 14253, loss=1.434, LR=0.0006545084971874737
# Validation Loss = 4.798
# Epoch=5, batch = 3000 of 14253, loss=1.518, LR=0.0006545084971874737
# Validation Loss = 5.681
# Epoch=5, batch = 4000 of 14253, loss=2.877, LR=0.0006545084971874737
# Validation Loss = 4.763
# Epoch=5, batch = 5000 of 14253, loss=1.449, LR=0.0006545084971874737
# Validation Loss = 2.796
# Epoch=5, batch = 6000 of 14253, loss=1.170, LR=0.0006545084971874737
# Validation Loss = 1.545
# Epoch=5, batch = 7000 of 14253, loss=1.069, LR=0.0006545084971874737
# Validation Loss = 0.905
# Epoch=5, batch = 8000 of 14253, loss=1.422, LR=0.0006545084971874737
# Validation Loss = 0.633
# Epoch=5, batch = 9000 of 14253, loss=1.422, LR=0.0006545084971874737
# Validation Loss = 1.125
# Epoch=5, batch = 10000 of 14253, loss=1.108, LR=0.0006545084971874737
# Validation Loss = 1.688
# Epoch=5, batch = 11000 of 14253, loss=1.145, LR=0.0006545084971874737
# Validation Loss = 1.118
# Epoch=5, batch = 12000 of 14253, loss=1.521, LR=0.0006545084971874737
# Validation Loss = 0.602
# Epoch=5, batch = 13000 of 14253, loss=1.432, LR=0.0006545084971874737
# Validation Loss = 1.496
# Epoch=5, batch = 14000 of 14253, loss=1.177, LR=0.0006545084971874737
# Validation Loss = 2.386
# Epoch=6, batch = 0 of 14253, loss=1.179, LR=0.0005
# Validation Loss = 1.176
# Epoch=6, batch = 1000 of 14253, loss=1.149, LR=0.0005
# Validation Loss = 1.467
# Epoch=6, batch = 2000 of 14253, loss=1.161, LR=0.0005
# Validation Loss = 1.652
# Epoch=6, batch = 3000 of 14253, loss=1.256, LR=0.0005
# Validation Loss = 1.046
# Epoch=6, batch = 4000 of 14253, loss=1.128, LR=0.0005
# Validation Loss = 1.319
# Epoch=6, batch = 5000 of 14253, loss=1.285, LR=0.0005
# Validation Loss = 1.505
# Epoch=6, batch = 6000 of 14253, loss=1.182, LR=0.0005
# Validation Loss = 1.886
# Epoch=6, batch = 7000 of 14253, loss=1.245, LR=0.0005
# Validation Loss = 1.346
# Epoch=6, batch = 8000 of 14253, loss=1.235, LR=0.0005
# Validation Loss = 0.581
# Epoch=6, batch = 9000 of 14253, loss=1.416, LR=0.0005
# Validation Loss = 2.151
# Epoch=6, batch = 10000 of 14253, loss=1.240, LR=0.0005
# Validation Loss = 1.841
# Epoch=6, batch = 11000 of 14253, loss=1.139, LR=0.0005
# Validation Loss = 1.054
# Epoch=6, batch = 12000 of 14253, loss=1.572, LR=0.0005
# Validation Loss = 0.992
# Epoch=6, batch = 13000 of 14253, loss=1.308, LR=0.0005
# Validation Loss = 4.183
# Epoch=6, batch = 14000 of 14253, loss=1.842, LR=0.0005
# Validation Loss = 2.000
# Epoch=7, batch = 0 of 14253, loss=1.153, LR=0.00034549150281252633
# Validation Loss = 4.077
# Epoch=7, batch = 1000 of 14253, loss=1.199, LR=0.00034549150281252633
# Validation Loss = 1.672
# Epoch=7, batch = 2000 of 14253, loss=1.136, LR=0.00034549150281252633
# Validation Loss = 2.554
# Epoch=7, batch = 3000 of 14253, loss=1.196, LR=0.00034549150281252633
# Validation Loss = 2.763
# Epoch=7, batch = 4000 of 14253, loss=1.047, LR=0.00034549150281252633
# Validation Loss = 2.228
# Epoch=7, batch = 5000 of 14253, loss=1.118, LR=0.00034549150281252633
# Validation Loss = 1.786
# Epoch=7, batch = 6000 of 14253, loss=1.329, LR=0.00034549150281252633
# Validation Loss = 2.092
# Epoch=7, batch = 7000 of 14253, loss=1.246, LR=0.00034549150281252633
# Validation Loss = 2.561
# Epoch=7, batch = 8000 of 14253, loss=1.139, LR=0.00034549150281252633
# Validation Loss = 2.378
# Epoch=7, batch = 9000 of 14253, loss=1.229, LR=0.00034549150281252633
# Validation Loss = 1.218
# Epoch=7, batch = 10000 of 14253, loss=1.112, LR=0.00034549150281252633
# Validation Loss = 1.357
# Epoch=7, batch = 11000 of 14253, loss=1.272, LR=0.00034549150281252633
# Validation Loss = 1.749
# Epoch=7, batch = 12000 of 14253, loss=1.084, LR=0.00034549150281252633
# Validation Loss = 1.821
# Epoch=7, batch = 13000 of 14253, loss=1.136, LR=0.00034549150281252633
# Validation Loss = 2.640
# Epoch=7, batch = 14000 of 14253, loss=1.308, LR=0.00034549150281252633
# Validation Loss = 2.410
# Epoch=8, batch = 0 of 14253, loss=1.190, LR=0.0002061073738537635
# Validation Loss = 1.880
# Epoch=8, batch = 1000 of 14253, loss=1.101, LR=0.0002061073738537635
# Validation Loss = 1.045
# Epoch=8, batch = 2000 of 14253, loss=1.317, LR=0.0002061073738537635
# Validation Loss = 2.418
# Epoch=8, batch = 3000 of 14253, loss=1.313, LR=0.0002061073738537635
# Validation Loss = 1.989
# Epoch=8, batch = 4000 of 14253, loss=1.299, LR=0.0002061073738537635
# Validation Loss = 1.553
# Epoch=8, batch = 5000 of 14253, loss=1.103, LR=0.0002061073738537635
# Validation Loss = 1.329
# Epoch=8, batch = 6000 of 14253, loss=1.055, LR=0.0002061073738537635
# Validation Loss = 1.837
# Epoch=8, batch = 7000 of 14253, loss=1.148, LR=0.0002061073738537635
# Validation Loss = 1.740
# Epoch=8, batch = 8000 of 14253, loss=1.275, LR=0.0002061073738537635
# Validation Loss = 1.435
# Epoch=8, batch = 9000 of 14253, loss=1.188, LR=0.0002061073738537635
# Validation Loss = 2.608
# Epoch=8, batch = 10000 of 14253, loss=1.259, LR=0.0002061073738537635
# Validation Loss = 1.153
# Epoch=8, batch = 11000 of 14253, loss=1.320, LR=0.0002061073738537635
# Validation Loss = 1.783
# Epoch=8, batch = 12000 of 14253, loss=1.198, LR=0.0002061073738537635
# Validation Loss = 2.363
# Epoch=8, batch = 13000 of 14253, loss=1.169, LR=0.0002061073738537635
# Validation Loss = 2.293
# Epoch=8, batch = 14000 of 14253, loss=1.211, LR=0.0002061073738537635
# Validation Loss = 1.667
# Epoch=9, batch = 0 of 14253, loss=1.095, LR=9.549150281252634e-05
# Validation Loss = 1.834
# Epoch=9, batch = 1000 of 14253, loss=1.147, LR=9.549150281252634e-05
# Validation Loss = 2.305
# Epoch=9, batch = 2000 of 14253, loss=1.148, LR=9.549150281252634e-05
# Validation Loss = 3.346
# Epoch=9, batch = 3000 of 14253, loss=1.242, LR=9.549150281252634e-05
# Validation Loss = 2.118
# Epoch=9, batch = 4000 of 14253, loss=1.151, LR=9.549150281252634e-05
# Validation Loss = 2.197
# Epoch=9, batch = 5000 of 14253, loss=1.165, LR=9.549150281252634e-05
# Validation Loss = 2.198
# Epoch=9, batch = 6000 of 14253, loss=1.039, LR=9.549150281252634e-05
# Validation Loss = 1.477
# Epoch=9, batch = 7000 of 14253, loss=1.211, LR=9.549150281252634e-05
# Validation Loss = 2.216
# Epoch=9, batch = 8000 of 14253, loss=1.061, LR=9.549150281252634e-05
# Validation Loss = 1.612
# Epoch=9, batch = 9000 of 14253, loss=1.094, LR=9.549150281252634e-05
# Validation Loss = 1.960
# Epoch=9, batch = 10000 of 14253, loss=1.156, LR=9.549150281252634e-05
# Validation Loss = 3.126
# Epoch=9, batch = 11000 of 14253, loss=1.211, LR=9.549150281252634e-05
# Validation Loss = 2.116
# Epoch=9, batch = 12000 of 14253, loss=1.184, LR=9.549150281252634e-05
# Validation Loss = 2.085
# Epoch=9, batch = 13000 of 14253, loss=1.050, LR=9.549150281252634e-05
# Validation Loss = 1.649
# Epoch=9, batch = 14000 of 14253, loss=1.058, LR=9.549150281252634e-05
# Validation Loss = 1.777
# Epoch=10, batch = 0 of 14253, loss=1.053, LR=2.4471741852423235e-05
# Validation Loss = 2.396
# Epoch=10, batch = 1000 of 14253, loss=1.239, LR=2.4471741852423235e-05
# Validation Loss = 2.296
# Epoch=10, batch = 2000 of 14253, loss=1.222, LR=2.4471741852423235e-05
# Validation Loss = 2.202
# Epoch=10, batch = 3000 of 14253, loss=1.146, LR=2.4471741852423235e-05
# Validation Loss = 1.949
# Epoch=10, batch = 4000 of 14253, loss=1.065, LR=2.4471741852423235e-05
# Validation Loss = 2.097
# Epoch=10, batch = 5000 of 14253, loss=1.154, LR=2.4471741852423235e-05
# Validation Loss = 2.063
# Epoch=10, batch = 6000 of 14253, loss=1.162, LR=2.4471741852423235e-05
# Validation Loss = 2.319
# Epoch=10, batch = 7000 of 14253, loss=1.279, LR=2.4471741852423235e-05
# Validation Loss = 2.288
# Epoch=10, batch = 8000 of 14253, loss=1.216, LR=2.4471741852423235e-05
# Validation Loss = 2.355
# Epoch=10, batch = 9000 of 14253, loss=1.088, LR=2.4471741852423235e-05
# Validation Loss = 2.059
# Epoch=10, batch = 10000 of 14253, loss=1.195, LR=2.4471741852423235e-05
# Validation Loss = 2.057
# Epoch=10, batch = 11000 of 14253, loss=1.129, LR=2.4471741852423235e-05
# Validation Loss = 2.095
# Epoch=10, batch = 12000 of 14253, loss=1.105, LR=2.4471741852423235e-05
# Validation Loss = 1.961
# Epoch=10, batch = 13000 of 14253, loss=1.176, LR=2.4471741852423235e-05
# Validation Loss = 1.788
# Epoch=10, batch = 14000 of 14253, loss=1.213, LR=2.4471741852423235e-05
# Training stage: 3
# Validation Loss = 2.702
# Epoch=1, batch = 0 of 14253, loss=1.141, LR=0.001
# Validation Loss = 2.364
# Epoch=1, batch = 1000 of 14253, loss=1.301, LR=0.001
# Validation Loss = 1.430
# Epoch=1, batch = 2000 of 14253, loss=1.429, LR=0.001
# Validation Loss = 2.133
# Epoch=1, batch = 3000 of 14253, loss=1.452, LR=0.001
# Validation Loss = 0.956
# Epoch=1, batch = 4000 of 14253, loss=1.653, LR=0.001
# Validation Loss = 7.216
# Epoch=1, batch = 5000 of 14253, loss=1.894, LR=0.001
# Validation Loss = 4.967
# Epoch=1, batch = 6000 of 14253, loss=1.463, LR=0.001
# Validation Loss = 0.709
# Epoch=1, batch = 7000 of 14253, loss=1.305, LR=0.001
# Validation Loss = 0.810
# Epoch=1, batch = 8000 of 14253, loss=1.436, LR=0.001
# Validation Loss = 6.659
# Epoch=1, batch = 9000 of 14253, loss=2.370, LR=0.001
# Validation Loss = 0.467
# Epoch=1, batch = 10000 of 14253, loss=1.528, LR=0.001
# Validation Loss = 4.736
# Epoch=1, batch = 11000 of 14253, loss=1.275, LR=0.001
# Validation Loss = 1.065
# Epoch=1, batch = 12000 of 14253, loss=1.400, LR=0.001
# Validation Loss = 0.070
# Epoch=1, batch = 13000 of 14253, loss=2.758, LR=0.001
# Validation Loss = 3.280
# Epoch=1, batch = 14000 of 14253, loss=1.242, LR=0.001
# Validation Loss = 3.376
# Epoch=2, batch = 0 of 14253, loss=1.271, LR=0.0009938441702975688
# Validation Loss = 7.596
# Epoch=2, batch = 1000 of 14253, loss=3.828, LR=0.0009938441702975688
# Validation Loss = 2.100
# Epoch=2, batch = 2000 of 14253, loss=1.468, LR=0.0009938441702975688
# Validation Loss = 2.255
# Epoch=2, batch = 3000 of 14253, loss=1.151, LR=0.0009938441702975688
# Validation Loss = 1.897
# Epoch=2, batch = 4000 of 14253, loss=1.182, LR=0.0009938441702975688
# Validation Loss = 1.289
# Epoch=2, batch = 5000 of 14253, loss=1.456, LR=0.0009938441702975688
# Validation Loss = 1.982
# Epoch=2, batch = 6000 of 14253, loss=1.356, LR=0.0009938441702975688
# Validation Loss = 1.222
# Epoch=2, batch = 7000 of 14253, loss=1.361, LR=0.0009938441702975688
# Validation Loss = 3.232
# Epoch=2, batch = 8000 of 14253, loss=1.191, LR=0.0009938441702975688
# Validation Loss = 5.387
# Epoch=2, batch = 9000 of 14253, loss=1.174, LR=0.0009938441702975688
# Validation Loss = 6.220
# Epoch=2, batch = 10000 of 14253, loss=1.656, LR=0.0009938441702975688
# Validation Loss = 7.991
# Epoch=2, batch = 11000 of 14253, loss=1.368, LR=0.0009938441702975688
# Validation Loss = 0.989
# Epoch=2, batch = 12000 of 14253, loss=1.343, LR=0.0009938441702975688
# Validation Loss = 1.812
# Epoch=2, batch = 13000 of 14253, loss=1.354, LR=0.0009938441702975688
# Validation Loss = 2.010
# Epoch=2, batch = 14000 of 14253, loss=1.380, LR=0.0009938441702975688
# Validation Loss = 0.353
# Epoch=3, batch = 0 of 14253, loss=1.567, LR=0.0009755282581475768
# Validation Loss = 2.396
# Epoch=3, batch = 1000 of 14253, loss=1.140, LR=0.0009755282581475768
# Validation Loss = 1.325
# Epoch=3, batch = 2000 of 14253, loss=1.956, LR=0.0009755282581475768
# Validation Loss = 0.483
# Epoch=3, batch = 3000 of 14253, loss=1.192, LR=0.0009755282581475768
# Validation Loss = 3.275
# Epoch=3, batch = 4000 of 14253, loss=1.646, LR=0.0009755282581475768
# Validation Loss = 4.742
# Epoch=3, batch = 5000 of 14253, loss=1.107, LR=0.0009755282581475768
# Validation Loss = 1.749
# Epoch=3, batch = 6000 of 14253, loss=1.350, LR=0.0009755282581475768
# Validation Loss = 2.323
# Epoch=3, batch = 7000 of 14253, loss=1.320, LR=0.0009755282581475768
# Validation Loss = 4.069
# Epoch=3, batch = 8000 of 14253, loss=1.211, LR=0.0009755282581475768
# Validation Loss = 4.206
# Epoch=3, batch = 9000 of 14253, loss=1.149, LR=0.0009755282581475768
# Validation Loss = 1.374
# Epoch=3, batch = 10000 of 14253, loss=1.294, LR=0.0009755282581475768
# Validation Loss = 5.431
# Epoch=3, batch = 11000 of 14253, loss=1.603, LR=0.0009755282581475768
# Validation Loss = 4.704
# Epoch=3, batch = 12000 of 14253, loss=1.235, LR=0.0009755282581475768
# Validation Loss = 0.974
# Epoch=3, batch = 13000 of 14253, loss=1.575, LR=0.0009755282581475768
# Validation Loss = 2.556
# Epoch=3, batch = 14000 of 14253, loss=1.127, LR=0.0009755282581475768
# Validation Loss = 0.699
# Epoch=4, batch = 0 of 14253, loss=1.815, LR=0.0009455032620941839
# Validation Loss = 2.663
# Epoch=4, batch = 1000 of 14253, loss=1.220, LR=0.0009455032620941839
# Validation Loss = 1.783
# Epoch=4, batch = 2000 of 14253, loss=1.058, LR=0.0009455032620941839
# Validation Loss = 0.203
# Epoch=4, batch = 3000 of 14253, loss=1.665, LR=0.0009455032620941839
# Validation Loss = 2.270
# Epoch=4, batch = 4000 of 14253, loss=1.224, LR=0.0009455032620941839
# Validation Loss = 2.946
# Epoch=4, batch = 5000 of 14253, loss=1.128, LR=0.0009455032620941839
# Validation Loss = 1.676
# Epoch=4, batch = 6000 of 14253, loss=1.425, LR=0.0009455032620941839
# Validation Loss = 1.885
# Epoch=4, batch = 7000 of 14253, loss=1.106, LR=0.0009455032620941839
# Validation Loss = 2.989
# Epoch=4, batch = 8000 of 14253, loss=1.156, LR=0.0009455032620941839
# Validation Loss = 0.350
# Epoch=4, batch = 9000 of 14253, loss=1.437, LR=0.0009455032620941839
# Validation Loss = 1.951
# Epoch=4, batch = 10000 of 14253, loss=1.238, LR=0.0009455032620941839
# Validation Loss = 3.056
# Epoch=4, batch = 11000 of 14253, loss=1.218, LR=0.0009455032620941839
# Validation Loss = 3.651
# Epoch=4, batch = 12000 of 14253, loss=1.275, LR=0.0009455032620941839
# Validation Loss = 5.710
# Epoch=4, batch = 13000 of 14253, loss=1.409, LR=0.0009455032620941839
# Validation Loss = 4.152
# Epoch=4, batch = 14000 of 14253, loss=1.110, LR=0.0009455032620941839
# Validation Loss = 7.905
# Epoch=5, batch = 0 of 14253, loss=2.489, LR=0.0009045084971874737
# Validation Loss = 1.259
# Epoch=5, batch = 1000 of 14253, loss=1.235, LR=0.0009045084971874737
# Validation Loss = 4.702
# Epoch=5, batch = 2000 of 14253, loss=1.103, LR=0.0009045084971874737
# Validation Loss = 2.046
# Epoch=5, batch = 3000 of 14253, loss=1.449, LR=0.0009045084971874737
# Validation Loss = 8.904
# Epoch=5, batch = 4000 of 14253, loss=2.578, LR=0.0009045084971874737
# Validation Loss = 3.326
# Epoch=5, batch = 5000 of 14253, loss=1.234, LR=0.0009045084971874737
# Validation Loss = 3.721
# Epoch=5, batch = 6000 of 14253, loss=1.231, LR=0.0009045084971874737
# Validation Loss = 1.305
# Epoch=5, batch = 7000 of 14253, loss=1.500, LR=0.0009045084971874737
# Validation Loss = 2.299
# Epoch=5, batch = 8000 of 14253, loss=1.006, LR=0.0009045084971874737
# Validation Loss = 4.183
# Epoch=5, batch = 9000 of 14253, loss=1.410, LR=0.0009045084971874737
# Validation Loss = 2.992
# Epoch=5, batch = 10000 of 14253, loss=1.228, LR=0.0009045084971874737
# Validation Loss = 7.228
# Epoch=5, batch = 11000 of 14253, loss=1.556, LR=0.0009045084971874737
# Validation Loss = 2.368
# Epoch=5, batch = 12000 of 14253, loss=1.186, LR=0.0009045084971874737
# Validation Loss = 3.009
# Epoch=5, batch = 13000 of 14253, loss=1.239, LR=0.0009045084971874737
# Validation Loss = 5.761
# Epoch=5, batch = 14000 of 14253, loss=1.397, LR=0.0009045084971874737
# Validation Loss = 6.331
# Epoch=6, batch = 0 of 14253, loss=1.354, LR=0.0008535533905932737
# Validation Loss = 5.366
# Epoch=6, batch = 1000 of 14253, loss=1.360, LR=0.0008535533905932737
# Validation Loss = 2.669
# Epoch=6, batch = 2000 of 14253, loss=1.137, LR=0.0008535533905932737
# Validation Loss = 4.236
# Epoch=6, batch = 3000 of 14253, loss=1.159, LR=0.0008535533905932737
# Validation Loss = 2.079
# Epoch=6, batch = 4000 of 14253, loss=1.157, LR=0.0008535533905932737
# Validation Loss = 3.791
# Epoch=6, batch = 5000 of 14253, loss=1.239, LR=0.0008535533905932737
# Validation Loss = 4.606
# Epoch=6, batch = 6000 of 14253, loss=1.531, LR=0.0008535533905932737
# Validation Loss = 0.616
# Epoch=6, batch = 7000 of 14253, loss=1.412, LR=0.0008535533905932737
# Validation Loss = 0.255
# Epoch=6, batch = 8000 of 14253, loss=2.176, LR=0.0008535533905932737
# Validation Loss = 3.645
# Epoch=6, batch = 9000 of 14253, loss=1.229, LR=0.0008535533905932737
# Validation Loss = 2.132
# Epoch=6, batch = 10000 of 14253, loss=1.172, LR=0.0008535533905932737
# Validation Loss = 4.565
# Epoch=6, batch = 11000 of 14253, loss=1.275, LR=0.0008535533905932737
# Validation Loss = 2.463
# Epoch=6, batch = 12000 of 14253, loss=1.090, LR=0.0008535533905932737
# Validation Loss = 2.758
# Epoch=6, batch = 13000 of 14253, loss=1.252, LR=0.0008535533905932737
# Validation Loss = 3.587
# Epoch=6, batch = 14000 of 14253, loss=1.193, LR=0.0008535533905932737
# Validation Loss = 7.508
# Epoch=7, batch = 0 of 14253, loss=1.664, LR=0.0007938926261462366
# Validation Loss = 1.323
# Epoch=7, batch = 1000 of 14253, loss=1.499, LR=0.0007938926261462366
# Validation Loss = 2.289
# Epoch=7, batch = 2000 of 14253, loss=1.195, LR=0.0007938926261462366
# Validation Loss = 1.401
# Epoch=7, batch = 3000 of 14253, loss=1.189, LR=0.0007938926261462366
# Validation Loss = 2.023
# Epoch=7, batch = 4000 of 14253, loss=1.097, LR=0.0007938926261462366
# Validation Loss = 4.343
# Epoch=7, batch = 5000 of 14253, loss=1.261, LR=0.0007938926261462366
# Validation Loss = 3.152
# Epoch=7, batch = 6000 of 14253, loss=1.056, LR=0.0007938926261462366
# Validation Loss = 5.499
# Epoch=7, batch = 7000 of 14253, loss=1.184, LR=0.0007938926261462366
# Validation Loss = 3.119
# Epoch=7, batch = 8000 of 14253, loss=1.237, LR=0.0007938926261462366
# Validation Loss = 1.621
# Epoch=7, batch = 9000 of 14253, loss=1.035, LR=0.0007938926261462366
# Validation Loss = 3.828
# Epoch=7, batch = 10000 of 14253, loss=1.117, LR=0.0007938926261462366
# Validation Loss = 4.965
# Epoch=7, batch = 11000 of 14253, loss=1.535, LR=0.0007938926261462366
# Validation Loss = 1.324
# Epoch=7, batch = 12000 of 14253, loss=1.066, LR=0.0007938926261462366
# Validation Loss = 0.412
# Epoch=7, batch = 13000 of 14253, loss=2.252, LR=0.0007938926261462366
# Validation Loss = 2.111
# Epoch=7, batch = 14000 of 14253, loss=1.116, LR=0.0007938926261462366
# Validation Loss = 1.066
# Epoch=8, batch = 0 of 14253, loss=1.199, LR=0.0007269952498697733
# Validation Loss = 4.838
# Epoch=8, batch = 1000 of 14253, loss=1.147, LR=0.0007269952498697733
# Validation Loss = 3.735
# Epoch=8, batch = 2000 of 14253, loss=1.059, LR=0.0007269952498697733
# Validation Loss = 4.128
# Epoch=8, batch = 3000 of 14253, loss=1.525, LR=0.0007269952498697733
# Validation Loss = 1.226
# Epoch=8, batch = 4000 of 14253, loss=1.290, LR=0.0007269952498697733
# Validation Loss = 3.253
# Epoch=8, batch = 5000 of 14253, loss=1.074, LR=0.0007269952498697733
# Validation Loss = 1.951
# Epoch=8, batch = 6000 of 14253, loss=1.046, LR=0.0007269952498697733
# Validation Loss = 1.385
# Epoch=8, batch = 7000 of 14253, loss=1.166, LR=0.0007269952498697733
# Validation Loss = 3.871
# Epoch=8, batch = 8000 of 14253, loss=1.175, LR=0.0007269952498697733
# Validation Loss = 2.757
# Epoch=8, batch = 9000 of 14253, loss=1.280, LR=0.0007269952498697733
# Validation Loss = 2.832
# Epoch=8, batch = 10000 of 14253, loss=1.136, LR=0.0007269952498697733
# Validation Loss = 0.019
# Epoch=8, batch = 11000 of 14253, loss=1.776, LR=0.0007269952498697733
# Validation Loss = 3.135
# Epoch=8, batch = 12000 of 14253, loss=1.146, LR=0.0007269952498697733
# Validation Loss = 4.029
# Epoch=8, batch = 13000 of 14253, loss=1.282, LR=0.0007269952498697733
# Validation Loss = 2.170
# Epoch=8, batch = 14000 of 14253, loss=1.380, LR=0.0007269952498697733
# Validation Loss = 0.925
# Epoch=9, batch = 0 of 14253, loss=1.169, LR=0.0006545084971874737
# Validation Loss = 3.110
# Epoch=9, batch = 1000 of 14253, loss=1.147, LR=0.0006545084971874737
# Validation Loss = 0.703
# Epoch=9, batch = 2000 of 14253, loss=1.341, LR=0.0006545084971874737
# Validation Loss = 3.170
# Epoch=9, batch = 3000 of 14253, loss=1.159, LR=0.0006545084971874737
# Validation Loss = 1.625
# Epoch=9, batch = 4000 of 14253, loss=1.763, LR=0.0006545084971874737
# Validation Loss = 0.923
# Epoch=9, batch = 5000 of 14253, loss=1.457, LR=0.0006545084971874737
# Validation Loss = 3.875
# Epoch=9, batch = 6000 of 14253, loss=1.240, LR=0.0006545084971874737
# Validation Loss = 0.906
# Epoch=9, batch = 7000 of 14253, loss=1.478, LR=0.0006545084971874737
# Validation Loss = 2.798
# Epoch=9, batch = 8000 of 14253, loss=1.234, LR=0.0006545084971874737
# Validation Loss = 2.562
# Epoch=9, batch = 9000 of 14253, loss=1.253, LR=0.0006545084971874737
# Validation Loss = 2.286
# Epoch=9, batch = 10000 of 14253, loss=1.226, LR=0.0006545084971874737
# Validation Loss = 2.188
# Epoch=9, batch = 11000 of 14253, loss=1.430, LR=0.0006545084971874737
# Validation Loss = 2.125
# Epoch=9, batch = 12000 of 14253, loss=1.103, LR=0.0006545084971874737
# Validation Loss = 4.431
# Epoch=9, batch = 13000 of 14253, loss=1.187, LR=0.0006545084971874737
# Validation Loss = 3.923
# Epoch=9, batch = 14000 of 14253, loss=1.192, LR=0.0006545084971874737
# Validation Loss = 3.663
# Epoch=10, batch = 0 of 14253, loss=1.121, LR=0.0005782172325201155
# Validation Loss = 2.444
# Epoch=10, batch = 1000 of 14253, loss=1.096, LR=0.0005782172325201155
# Validation Loss = 3.019
# Epoch=10, batch = 2000 of 14253, loss=1.194, LR=0.0005782172325201155
# Validation Loss = 3.397
# Epoch=10, batch = 3000 of 14253, loss=1.177, LR=0.0005782172325201155
# Validation Loss = 4.665
# Epoch=10, batch = 4000 of 14253, loss=1.526, LR=0.0005782172325201155
# Validation Loss = 1.529
# Epoch=10, batch = 5000 of 14253, loss=1.054, LR=0.0005782172325201155
# Validation Loss = 1.151
# Epoch=10, batch = 6000 of 14253, loss=1.189, LR=0.0005782172325201155
# Validation Loss = 0.526
# Epoch=10, batch = 7000 of 14253, loss=1.668, LR=0.0005782172325201155
# Validation Loss = 4.370
# Epoch=10, batch = 8000 of 14253, loss=1.326, LR=0.0005782172325201155
# Validation Loss = 2.198
# Epoch=10, batch = 9000 of 14253, loss=1.181, LR=0.0005782172325201155
# Validation Loss = 5.079
# Epoch=10, batch = 10000 of 14253, loss=1.350, LR=0.0005782172325201155
# Validation Loss = 0.611
# Epoch=10, batch = 11000 of 14253, loss=1.268, LR=0.0005782172325201155
# Validation Loss = 0.781
# Epoch=10, batch = 12000 of 14253, loss=1.106, LR=0.0005782172325201155
# Validation Loss = 0.158
# Epoch=10, batch = 13000 of 14253, loss=1.986, LR=0.0005782172325201155
# Validation Loss = 0.014
# Epoch=10, batch = 14000 of 14253, loss=1.944, LR=0.0005782172325201155
# Validation Loss = 2.726
# Epoch=11, batch = 0 of 14253, loss=1.199, LR=0.0005
# Validation Loss = 2.564
# Epoch=11, batch = 1000 of 14253, loss=1.373, LR=0.0005
# Validation Loss = 1.985
# Epoch=11, batch = 2000 of 14253, loss=1.127, LR=0.0005
# Validation Loss = 2.109
# Epoch=11, batch = 3000 of 14253, loss=1.190, LR=0.0005
# Validation Loss = 1.929
# Epoch=11, batch = 4000 of 14253, loss=0.912, LR=0.0005
# Validation Loss = 2.028
# Epoch=11, batch = 5000 of 14253, loss=1.266, LR=0.0005
# Validation Loss = 1.672
# Epoch=11, batch = 6000 of 14253, loss=1.081, LR=0.0005
# Validation Loss = 1.844
# Epoch=11, batch = 7000 of 14253, loss=1.014, LR=0.0005
# Validation Loss = 2.581
# Epoch=11, batch = 8000 of 14253, loss=1.593, LR=0.0005
# Validation Loss = 0.919
# Epoch=11, batch = 9000 of 14253, loss=1.127, LR=0.0005
# Validation Loss = 2.966
# Epoch=11, batch = 10000 of 14253, loss=1.190, LR=0.0005
# Validation Loss = 0.933
# Epoch=11, batch = 11000 of 14253, loss=1.039, LR=0.0005
# Validation Loss = 2.172
# Epoch=11, batch = 12000 of 14253, loss=1.021, LR=0.0005
# Validation Loss = 1.188
# Epoch=11, batch = 13000 of 14253, loss=1.218, LR=0.0005
# Validation Loss = 0.999
# Epoch=11, batch = 14000 of 14253, loss=1.063, LR=0.0005
# Validation Loss = 1.895
# Epoch=12, batch = 0 of 14253, loss=1.081, LR=0.0004217827674798847
# Validation Loss = 1.635
# Epoch=12, batch = 1000 of 14253, loss=1.200, LR=0.0004217827674798847
# Validation Loss = 0.881
# Epoch=12, batch = 2000 of 14253, loss=1.237, LR=0.0004217827674798847
# Validation Loss = 0.806
# Epoch=12, batch = 3000 of 14253, loss=1.176, LR=0.0004217827674798847
# Validation Loss = 3.759
# Epoch=12, batch = 4000 of 14253, loss=1.046, LR=0.0004217827674798847
# Validation Loss = 2.019
# Epoch=12, batch = 5000 of 14253, loss=1.110, LR=0.0004217827674798847
# Validation Loss = 5.039
# Epoch=12, batch = 6000 of 14253, loss=1.256, LR=0.0004217827674798847
# Validation Loss = 1.018
# Epoch=12, batch = 7000 of 14253, loss=1.259, LR=0.0004217827674798847
# Validation Loss = 1.496
# Epoch=12, batch = 8000 of 14253, loss=1.012, LR=0.0004217827674798847
# Validation Loss = 0.550
# Epoch=12, batch = 9000 of 14253, loss=1.204, LR=0.0004217827674798847
# Validation Loss = 2.933
# Epoch=12, batch = 10000 of 14253, loss=1.162, LR=0.0004217827674798847
# Validation Loss = 1.705
# Epoch=12, batch = 11000 of 14253, loss=1.095, LR=0.0004217827674798847
# Validation Loss = 1.886
# Epoch=12, batch = 12000 of 14253, loss=1.271, LR=0.0004217827674798847
# Validation Loss = 1.800
# Epoch=12, batch = 13000 of 14253, loss=1.087, LR=0.0004217827674798847
# Validation Loss = 1.721
# Epoch=12, batch = 14000 of 14253, loss=1.125, LR=0.0004217827674798847
# Validation Loss = 1.108
# Epoch=13, batch = 0 of 14253, loss=1.050, LR=0.00034549150281252633
# Validation Loss = 1.547
# Epoch=13, batch = 1000 of 14253, loss=0.981, LR=0.00034549150281252633
# Validation Loss = 1.442
# Epoch=13, batch = 2000 of 14253, loss=1.048, LR=0.00034549150281252633
# Validation Loss = 2.340
# Epoch=13, batch = 3000 of 14253, loss=1.194, LR=0.00034549150281252633
# Validation Loss = 1.507
# Epoch=13, batch = 4000 of 14253, loss=1.074, LR=0.00034549150281252633
# Validation Loss = 2.332
# Epoch=13, batch = 5000 of 14253, loss=1.113, LR=0.00034549150281252633
# Validation Loss = 1.635
# Epoch=13, batch = 6000 of 14253, loss=1.221, LR=0.00034549150281252633
# Validation Loss = 1.856
# Epoch=13, batch = 7000 of 14253, loss=1.089, LR=0.00034549150281252633
# Validation Loss = 1.436
# Epoch=13, batch = 8000 of 14253, loss=1.148, LR=0.00034549150281252633
# Validation Loss = 2.440
# Epoch=13, batch = 9000 of 14253, loss=1.177, LR=0.00034549150281252633
# Validation Loss = 2.483
# Epoch=13, batch = 10000 of 14253, loss=1.214, LR=0.00034549150281252633
# Validation Loss = 0.385
# Epoch=13, batch = 11000 of 14253, loss=1.412, LR=0.00034549150281252633
# Validation Loss = 1.350
# Epoch=13, batch = 12000 of 14253, loss=1.223, LR=0.00034549150281252633
# Validation Loss = 1.675
# Epoch=13, batch = 13000 of 14253, loss=1.184, LR=0.00034549150281252633
# Validation Loss = 2.882
# Epoch=13, batch = 14000 of 14253, loss=1.186, LR=0.00034549150281252633
# Validation Loss = 3.260
# Epoch=14, batch = 0 of 14253, loss=1.340, LR=0.00027300475013022663
# Validation Loss = 2.686
# Epoch=14, batch = 1000 of 14253, loss=1.039, LR=0.00027300475013022663
# Validation Loss = 1.181
# Epoch=14, batch = 2000 of 14253, loss=1.148, LR=0.00027300475013022663
# Validation Loss = 3.454
# Epoch=14, batch = 3000 of 14253, loss=1.330, LR=0.00027300475013022663
# Validation Loss = 1.375
# Epoch=14, batch = 4000 of 14253, loss=1.220, LR=0.00027300475013022663
# Validation Loss = 0.224
# Epoch=14, batch = 5000 of 14253, loss=1.202, LR=0.00027300475013022663
# Validation Loss = 1.501
# Epoch=14, batch = 6000 of 14253, loss=1.143, LR=0.00027300475013022663
# Validation Loss = 1.244
# Epoch=14, batch = 7000 of 14253, loss=1.015, LR=0.00027300475013022663
# Validation Loss = 1.623
# Epoch=14, batch = 8000 of 14253, loss=1.059, LR=0.00027300475013022663
# Validation Loss = 0.528
# Epoch=14, batch = 9000 of 14253, loss=1.276, LR=0.00027300475013022663
# Validation Loss = 1.285
# Epoch=14, batch = 10000 of 14253, loss=1.174, LR=0.00027300475013022663
# Validation Loss = 3.209
# Epoch=14, batch = 11000 of 14253, loss=1.161, LR=0.00027300475013022663
# Validation Loss = 1.891
# Epoch=14, batch = 12000 of 14253, loss=1.250, LR=0.00027300475013022663
# Validation Loss = 1.646
# Epoch=14, batch = 13000 of 14253, loss=1.029, LR=0.00027300475013022663
# Validation Loss = 2.014
# Epoch=14, batch = 14000 of 14253, loss=1.581, LR=0.00027300475013022663
# Validation Loss = 1.380
# Epoch=15, batch = 0 of 14253, loss=1.159, LR=0.00020610737385376348
# Validation Loss = 2.852
# Epoch=15, batch = 1000 of 14253, loss=1.011, LR=0.00020610737385376348
# Validation Loss = 2.250
# Epoch=15, batch = 2000 of 14253, loss=1.217, LR=0.00020610737385376348
# Validation Loss = 1.579
# Epoch=15, batch = 3000 of 14253, loss=1.015, LR=0.00020610737385376348
# Validation Loss = 2.934
# Epoch=15, batch = 4000 of 14253, loss=1.121, LR=0.00020610737385376348
# Validation Loss = 1.453
# Epoch=15, batch = 5000 of 14253, loss=1.148, LR=0.00020610737385376348
# Validation Loss = 3.563
# Epoch=15, batch = 6000 of 14253, loss=1.160, LR=0.00020610737385376348
# Validation Loss = 1.505
# Epoch=15, batch = 7000 of 14253, loss=1.088, LR=0.00020610737385376348
# Validation Loss = 2.958
# Epoch=15, batch = 8000 of 14253, loss=1.037, LR=0.00020610737385376348
# Validation Loss = 2.593
# Epoch=15, batch = 9000 of 14253, loss=1.111, LR=0.00020610737385376348
# Validation Loss = 2.448
# Epoch=15, batch = 10000 of 14253, loss=1.026, LR=0.00020610737385376348
# Validation Loss = 2.039
# Epoch=15, batch = 11000 of 14253, loss=0.977, LR=0.00020610737385376348
# Validation Loss = 1.960
# Epoch=15, batch = 12000 of 14253, loss=1.081, LR=0.00020610737385376348
# Validation Loss = 1.768
# Epoch=15, batch = 13000 of 14253, loss=2.737, LR=0.00020610737385376348
# Validation Loss = 1.899
# Epoch=15, batch = 14000 of 14253, loss=1.111, LR=0.00020610737385376348
# Validation Loss = 2.069
# Epoch=16, batch = 0 of 14253, loss=0.995, LR=0.00014644660940672625
# Validation Loss = 2.720
# Epoch=16, batch = 1000 of 14253, loss=1.035, LR=0.00014644660940672625
# Validation Loss = 2.608
# Epoch=16, batch = 2000 of 14253, loss=1.291, LR=0.00014644660940672625
# Validation Loss = 1.763
# Epoch=16, batch = 3000 of 14253, loss=1.088, LR=0.00014644660940672625
# Validation Loss = 1.620
# Epoch=16, batch = 4000 of 14253, loss=1.243, LR=0.00014644660940672625
# Validation Loss = 1.878
# Epoch=16, batch = 5000 of 14253, loss=2.142, LR=0.00014644660940672625
# Validation Loss = 1.598
# Epoch=16, batch = 6000 of 14253, loss=1.081, LR=0.00014644660940672625
# Validation Loss = 1.696
# Epoch=16, batch = 7000 of 14253, loss=1.042, LR=0.00014644660940672625
# Validation Loss = 2.014
# Epoch=16, batch = 8000 of 14253, loss=1.176, LR=0.00014644660940672625
# Validation Loss = 2.086
# Epoch=16, batch = 9000 of 14253, loss=1.421, LR=0.00014644660940672625
# Validation Loss = 2.445
# Epoch=16, batch = 10000 of 14253, loss=1.007, LR=0.00014644660940672625
# Validation Loss = 1.611
# Epoch=16, batch = 11000 of 14253, loss=1.040, LR=0.00014644660940672625
# Validation Loss = 1.279
# Epoch=16, batch = 12000 of 14253, loss=1.076, LR=0.00014644660940672625
# Validation Loss = 2.479
# Epoch=16, batch = 13000 of 14253, loss=1.100, LR=0.00014644660940672625
# Validation Loss = 2.822
# Epoch=16, batch = 14000 of 14253, loss=1.089, LR=0.00014644660940672625
# Validation Loss = 3.244
# Epoch=17, batch = 0 of 14253, loss=1.110, LR=9.549150281252631e-05
# Validation Loss = 2.080
# Epoch=17, batch = 1000 of 14253, loss=1.024, LR=9.549150281252631e-05
# Validation Loss = 1.486
# Epoch=17, batch = 2000 of 14253, loss=1.042, LR=9.549150281252631e-05
# Validation Loss = 2.637
# Epoch=17, batch = 3000 of 14253, loss=1.068, LR=9.549150281252631e-05
# Validation Loss = 1.504
# Epoch=17, batch = 4000 of 14253, loss=0.897, LR=9.549150281252631e-05
# Validation Loss = 1.963
# Epoch=17, batch = 5000 of 14253, loss=1.064, LR=9.549150281252631e-05
# Validation Loss = 2.667
# Epoch=17, batch = 6000 of 14253, loss=1.069, LR=9.549150281252631e-05
# Validation Loss = 1.828
# Epoch=17, batch = 7000 of 14253, loss=0.977, LR=9.549150281252631e-05
# Validation Loss = 1.419
# Epoch=17, batch = 8000 of 14253, loss=0.923, LR=9.549150281252631e-05
# Validation Loss = 2.282
# Epoch=17, batch = 9000 of 14253, loss=1.167, LR=9.549150281252631e-05
# Validation Loss = 2.977
# Epoch=17, batch = 10000 of 14253, loss=1.158, LR=9.549150281252631e-05
# Validation Loss = 1.856
# Epoch=17, batch = 11000 of 14253, loss=0.951, LR=9.549150281252631e-05
# Validation Loss = 1.512
# Epoch=17, batch = 12000 of 14253, loss=1.098, LR=9.549150281252631e-05
# Validation Loss = 2.806
# Epoch=17, batch = 13000 of 14253, loss=1.193, LR=9.549150281252631e-05
# Validation Loss = 2.457
# Epoch=17, batch = 14000 of 14253, loss=1.138, LR=9.549150281252631e-05
# Validation Loss = 1.837
# Epoch=18, batch = 0 of 14253, loss=1.060, LR=5.4496737905816096e-05
# Validation Loss = 2.177
# Epoch=18, batch = 1000 of 14253, loss=1.181, LR=5.4496737905816096e-05
# Validation Loss = 1.691
# Epoch=18, batch = 2000 of 14253, loss=1.053, LR=5.4496737905816096e-05
# Validation Loss = 2.760
# Epoch=18, batch = 3000 of 14253, loss=1.009, LR=5.4496737905816096e-05
# Validation Loss = 2.258
# Epoch=18, batch = 4000 of 14253, loss=1.052, LR=5.4496737905816096e-05
# Validation Loss = 1.998
# Epoch=18, batch = 5000 of 14253, loss=1.046, LR=5.4496737905816096e-05
# Validation Loss = 1.723
# Epoch=18, batch = 6000 of 14253, loss=1.029, LR=5.4496737905816096e-05
# Validation Loss = 2.947
# Epoch=18, batch = 7000 of 14253, loss=1.025, LR=5.4496737905816096e-05
# Validation Loss = 2.518
# Epoch=18, batch = 8000 of 14253, loss=1.170, LR=5.4496737905816096e-05
# Validation Loss = 2.473
# Epoch=18, batch = 9000 of 14253, loss=1.134, LR=5.4496737905816096e-05
# Validation Loss = 2.486
# Epoch=18, batch = 10000 of 14253, loss=0.937, LR=5.4496737905816096e-05
# Validation Loss = 1.810
# Epoch=18, batch = 11000 of 14253, loss=1.001, LR=5.4496737905816096e-05
# Validation Loss = 1.908
# Epoch=18, batch = 12000 of 14253, loss=1.010, LR=5.4496737905816096e-05
# Validation Loss = 1.742
# Epoch=18, batch = 13000 of 14253, loss=1.063, LR=5.4496737905816096e-05
# Validation Loss = 1.839
# Epoch=18, batch = 14000 of 14253, loss=1.022, LR=5.4496737905816096e-05
# Validation Loss = 2.396
# Epoch=19, batch = 0 of 14253, loss=1.102, LR=2.447174185242323e-05
# Validation Loss = 1.861
# Epoch=19, batch = 1000 of 14253, loss=1.121, LR=2.447174185242323e-05
# Validation Loss = 1.988
# Epoch=19, batch = 2000 of 14253, loss=1.032, LR=2.447174185242323e-05
# Validation Loss = 2.019
# Epoch=19, batch = 3000 of 14253, loss=1.229, LR=2.447174185242323e-05
# Validation Loss = 2.129
# Epoch=19, batch = 4000 of 14253, loss=1.001, LR=2.447174185242323e-05
# Validation Loss = 1.752
# Epoch=19, batch = 5000 of 14253, loss=1.055, LR=2.447174185242323e-05
# Validation Loss = 2.631
# Epoch=19, batch = 6000 of 14253, loss=0.930, LR=2.447174185242323e-05
# Validation Loss = 2.312
# Epoch=19, batch = 7000 of 14253, loss=1.031, LR=2.447174185242323e-05
# Validation Loss = 1.953
# Epoch=19, batch = 8000 of 14253, loss=1.042, LR=2.447174185242323e-05
# Validation Loss = 1.794
# Epoch=19, batch = 9000 of 14253, loss=1.078, LR=2.447174185242323e-05
# Validation Loss = 1.943
# Epoch=19, batch = 10000 of 14253, loss=1.093, LR=2.447174185242323e-05
# Validation Loss = 2.328
# Epoch=19, batch = 11000 of 14253, loss=0.904, LR=2.447174185242323e-05
# Validation Loss = 2.349
# Epoch=19, batch = 12000 of 14253, loss=1.016, LR=2.447174185242323e-05
# Validation Loss = 2.208
# Epoch=19, batch = 13000 of 14253, loss=1.265, LR=2.447174185242323e-05
# Validation Loss = 1.958
# Epoch=19, batch = 14000 of 14253, loss=1.075, LR=2.447174185242323e-05
# Validation Loss = 2.198
# Epoch=20, batch = 0 of 14253, loss=0.981, LR=6.15582970243117e-06
# Validation Loss = 1.886
# Epoch=20, batch = 1000 of 14253, loss=1.168, LR=6.15582970243117e-06
# Validation Loss = 2.280
# Epoch=20, batch = 2000 of 14253, loss=0.982, LR=6.15582970243117e-06
# Validation Loss = 1.995
# Epoch=20, batch = 3000 of 14253, loss=1.019, LR=6.15582970243117e-06
# Validation Loss = 2.065
# Epoch=20, batch = 4000 of 14253, loss=1.087, LR=6.15582970243117e-06
# Validation Loss = 1.845
# Epoch=20, batch = 5000 of 14253, loss=1.006, LR=6.15582970243117e-06
# Validation Loss = 2.054
# Epoch=20, batch = 6000 of 14253, loss=0.937, LR=6.15582970243117e-06
# Validation Loss = 2.072
# Epoch=20, batch = 7000 of 14253, loss=0.975, LR=6.15582970243117e-06
# Validation Loss = 2.007
# Epoch=20, batch = 8000 of 14253, loss=1.050, LR=6.15582970243117e-06
# Validation Loss = 2.253
# Epoch=20, batch = 9000 of 14253, loss=1.109, LR=6.15582970243117e-06
# Validation Loss = 2.130
# Epoch=20, batch = 10000 of 14253, loss=0.992, LR=6.15582970243117e-06
# Validation Loss = 2.016
# Epoch=20, batch = 11000 of 14253, loss=1.008, LR=6.15582970243117e-06
# Validation Loss = 2.136
# Epoch=20, batch = 12000 of 14253, loss=1.059, LR=6.15582970243117e-06
# Validation Loss = 2.216
# Epoch=20, batch = 13000 of 14253, loss=1.046, LR=6.15582970243117e-06
# ...
# Validation Loss = 0.505
# Epoch=19, batch = 4000 of 14253, loss=4.411, LR=2.447174185242323e-05
# Validation Loss = 1.287
# Epoch=19, batch = 5000 of 14253, loss=3.790, LR=2.447174185242323e-05
# Validation Loss = 0.901
# Epoch=19, batch = 6000 of 14253, loss=4.146, LR=2.447174185242323e-05
# Validation Loss = 0.721
# Epoch=19, batch = 7000 of 14253, loss=4.187, LR=2.447174185242323e-05
# Validation Loss = 0.468
# Epoch=19, batch = 8000 of 14253, loss=4.293, LR=2.447174185242323e-05
# Validation Loss = 1.678
# Epoch=19, batch = 9000 of 14253, loss=3.729, LR=2.447174185242323e-05
# Validation Loss = 1.469
# Epoch=19, batch = 10000 of 14253, loss=3.943, LR=2.447174185242323e-05
# Validation Loss = 1.649
# Epoch=19, batch = 11000 of 14253, loss=3.990, LR=2.447174185242323e-05
# Validation Loss = 0.987
# Epoch=19, batch = 12000 of 14253, loss=3.929, LR=2.447174185242323e-05
# Validation Loss = 0.151
# Epoch=19, batch = 13000 of 14253, loss=4.153, LR=2.447174185242323e-05
# Validation Loss = 0.442
# Epoch=19, batch = 14000 of 14253, loss=4.272, LR=2.447174185242323e-05
# Validation Loss = 0.853
# Epoch=20, batch = 0 of 14253, loss=4.223, LR=6.15582970243117e-06
# Validation Loss = 1.048
# Epoch=20, batch = 1000 of 14253, loss=3.902, LR=6.15582970243117e-06
# Validation Loss = 0.915
# Epoch=20, batch = 2000 of 14253, loss=4.476, LR=6.15582970243117e-06
# Validation Loss = 1.221
# Epoch=20, batch = 3000 of 14253, loss=3.762, LR=6.15582970243117e-06
# Validation Loss = 0.964
# Epoch=20, batch = 4000 of 14253, loss=4.092, LR=6.15582970243117e-06
# Validation Loss = 1.021
# Epoch=20, batch = 5000 of 14253, loss=4.058, LR=6.15582970243117e-06
# Validation Loss = 0.806
# Epoch=20, batch = 6000 of 14253, loss=3.971, LR=6.15582970243117e-06
# Validation Loss = 1.131
# Epoch=20, batch = 7000 of 14253, loss=4.095, LR=6.15582970243117e-06
# Validation Loss = 1.449
# Epoch=20, batch = 8000 of 14253, loss=4.165, LR=6.15582970243117e-06
# Validation Loss = 1.015
# Epoch=20, batch = 9000 of 14253, loss=3.925, LR=6.15582970243117e-06
# Validation Loss = 0.946
# Epoch=20, batch = 10000 of 14253, loss=4.102, LR=6.15582970243117e-06
# Validation Loss = 1.047
# Epoch=20, batch = 11000 of 14253, loss=4.061, LR=6.15582970243117e-06
# Validation Loss = 0.698
# Epoch=20, batch = 12000 of 14253, loss=3.990, LR=6.15582970243117e-06
# Validation Loss = 0.786
# Epoch=20, batch = 13000 of 14253, loss=3.981, LR=6.15582970243117e-06
# Validation Loss = 1.072
# Epoch=20, batch = 14000 of 14253, loss=4.340, LR=6.15582970243117e-06
# Finished training model for channel 183+-3V.
# 183+-7V
# Training stage: 1
# Validation Loss = 55968.105
# Epoch=1, batch = 0 of 14253, loss=76893.453, LR=0.001
# Validation Loss = 8.304
# Epoch=1, batch = 1000 of 14253, loss=4.384, LR=0.001
# Validation Loss = 4.136
# Epoch=1, batch = 2000 of 14253, loss=4.359, LR=0.001
# Validation Loss = 8.923
# Epoch=1, batch = 3000 of 14253, loss=3.612, LR=0.001
# Validation Loss = 5.439
# Epoch=1, batch = 4000 of 14253, loss=4.519, LR=0.001
# Validation Loss = 34.726
# Epoch=1, batch = 5000 of 14253, loss=8.640, LR=0.001
# Validation Loss = 30.865
# Epoch=1, batch = 6000 of 14253, loss=8.537, LR=0.001
# Validation Loss = 4.279
# Epoch=1, batch = 7000 of 14253, loss=6.064, LR=0.001
# Validation Loss = 12.261
# Epoch=1, batch = 8000 of 14253, loss=4.728, LR=0.001
# Validation Loss = 15.352
# Epoch=1, batch = 9000 of 14253, loss=4.148, LR=0.001
# Validation Loss = 33.768
# Epoch=1, batch = 10000 of 14253, loss=3.968, LR=0.001
# Validation Loss = 27.410
# Epoch=1, batch = 11000 of 14253, loss=4.010, LR=0.001
# Validation Loss = 1.323
# Epoch=1, batch = 12000 of 14253, loss=16.714, LR=0.001
# Validation Loss = 25.531
# Epoch=1, batch = 13000 of 14253, loss=4.094, LR=0.001
# Validation Loss = 19.881
# Epoch=1, batch = 14000 of 14253, loss=3.620, LR=0.001
# Validation Loss = 21.187
# Epoch=2, batch = 0 of 14253, loss=3.146, LR=0.0009045084971874737
# Validation Loss = 15.348
# Epoch=2, batch = 1000 of 14253, loss=4.292, LR=0.0009045084971874737
# Validation Loss = 20.194
# Epoch=2, batch = 2000 of 14253, loss=3.269, LR=0.0009045084971874737
# Validation Loss = 7.525
# Epoch=2, batch = 3000 of 14253, loss=3.236, LR=0.0009045084971874737
# Validation Loss = 7.937
# Epoch=2, batch = 4000 of 14253, loss=3.747, LR=0.0009045084971874737
# Validation Loss = 0.295
# Epoch=2, batch = 5000 of 14253, loss=3.967, LR=0.0009045084971874737
# Validation Loss = 6.060
# Epoch=2, batch = 6000 of 14253, loss=3.305, LR=0.0009045084971874737
# Validation Loss = 11.245
# Epoch=2, batch = 7000 of 14253, loss=3.381, LR=0.0009045084971874737
# Validation Loss = 5.568
# Epoch=2, batch = 8000 of 14253, loss=4.470, LR=0.0009045084971874737
# Validation Loss = 2.112
# Epoch=2, batch = 9000 of 14253, loss=3.221, LR=0.0009045084971874737
# Validation Loss = 4.639
# Epoch=2, batch = 10000 of 14253, loss=3.904, LR=0.0009045084971874737
# Validation Loss = 1.629
# Epoch=2, batch = 11000 of 14253, loss=3.975, LR=0.0009045084971874737
# Validation Loss = 4.739
# Epoch=2, batch = 12000 of 14253, loss=3.881, LR=0.0009045084971874737
# Validation Loss = 1.733
# Epoch=2, batch = 13000 of 14253, loss=3.902, LR=0.0009045084971874737
# Validation Loss = 2.386
# Epoch=2, batch = 14000 of 14253, loss=3.201, LR=0.0009045084971874737
# Validation Loss = 4.434
# Epoch=3, batch = 0 of 14253, loss=3.128, LR=0.0006545084971874737
# Validation Loss = 0.363
# Epoch=3, batch = 1000 of 14253, loss=4.025, LR=0.0006545084971874737
# Validation Loss = 9.497
# Epoch=3, batch = 2000 of 14253, loss=3.241, LR=0.0006545084971874737
# Validation Loss = 3.802
# Epoch=3, batch = 3000 of 14253, loss=3.329, LR=0.0006545084971874737
# Validation Loss = 1.865
# Epoch=3, batch = 4000 of 14253, loss=2.546, LR=0.0006545084971874737
# Validation Loss = 5.657
# Epoch=3, batch = 5000 of 14253, loss=2.721, LR=0.0006545084971874737
# Validation Loss = 0.738
# Epoch=3, batch = 6000 of 14253, loss=3.007, LR=0.0006545084971874737
# Validation Loss = 11.550
# Epoch=3, batch = 7000 of 14253, loss=2.569, LR=0.0006545084971874737
# Validation Loss = 2.036
# Epoch=3, batch = 8000 of 14253, loss=3.517, LR=0.0006545084971874737
# Validation Loss = 1.816
# Epoch=3, batch = 9000 of 14253, loss=3.373, LR=0.0006545084971874737
# Validation Loss = 9.225
# Epoch=3, batch = 10000 of 14253, loss=4.266, LR=0.0006545084971874737
# Validation Loss = 0.173
# Epoch=3, batch = 11000 of 14253, loss=3.752, LR=0.0006545084971874737
# Validation Loss = 4.906
# Epoch=3, batch = 12000 of 14253, loss=2.458, LR=0.0006545084971874737
# Validation Loss = 8.763
# Epoch=3, batch = 13000 of 14253, loss=3.080, LR=0.0006545084971874737
# Validation Loss = 0.165
# Epoch=3, batch = 14000 of 14253, loss=2.798, LR=0.0006545084971874737
# Validation Loss = 0.382
# Epoch=4, batch = 0 of 14253, loss=3.179, LR=0.00034549150281252633
# Validation Loss = 1.911
# Epoch=4, batch = 1000 of 14253, loss=3.113, LR=0.00034549150281252633
# Validation Loss = 4.595
# Epoch=4, batch = 2000 of 14253, loss=2.728, LR=0.00034549150281252633
# Validation Loss = 2.930
# Epoch=4, batch = 3000 of 14253, loss=2.847, LR=0.00034549150281252633
# Validation Loss = 3.450
# Epoch=4, batch = 4000 of 14253, loss=3.786, LR=0.00034549150281252633
# Validation Loss = 3.453
# Epoch=4, batch = 5000 of 14253, loss=3.121, LR=0.00034549150281252633
# Validation Loss = 4.506
# Epoch=4, batch = 6000 of 14253, loss=2.762, LR=0.00034549150281252633
# Validation Loss = 3.005
# Epoch=4, batch = 7000 of 14253, loss=2.586, LR=0.00034549150281252633
# Validation Loss = 0.004
# Epoch=4, batch = 8000 of 14253, loss=3.455, LR=0.00034549150281252633
# Validation Loss = 0.598
# Epoch=4, batch = 9000 of 14253, loss=2.795, LR=0.00034549150281252633
# Validation Loss = 0.446
# Epoch=4, batch = 10000 of 14253, loss=2.707, LR=0.00034549150281252633
# Validation Loss = 0.888
# Epoch=4, batch = 11000 of 14253, loss=2.581, LR=0.00034549150281252633
# Validation Loss = 1.597
# Epoch=4, batch = 12000 of 14253, loss=2.687, LR=0.00034549150281252633
# Validation Loss = 1.476
# Epoch=4, batch = 13000 of 14253, loss=2.584, LR=0.00034549150281252633
# Validation Loss = 0.859
# Epoch=4, batch = 14000 of 14253, loss=2.917, LR=0.00034549150281252633
# Validation Loss = 3.574
# Epoch=5, batch = 0 of 14253, loss=2.553, LR=9.549150281252633e-05
# Validation Loss = 0.922
# Epoch=5, batch = 1000 of 14253, loss=2.621, LR=9.549150281252633e-05
# Validation Loss = 1.549
# Epoch=5, batch = 2000 of 14253, loss=2.148, LR=9.549150281252633e-05
# Validation Loss = 2.614
# Epoch=5, batch = 3000 of 14253, loss=2.669, LR=9.549150281252633e-05
# Validation Loss = 4.028
# Epoch=5, batch = 4000 of 14253, loss=2.815, LR=9.549150281252633e-05
# Validation Loss = 2.244
# Epoch=5, batch = 5000 of 14253, loss=2.572, LR=9.549150281252633e-05
# Validation Loss = 2.893
# Epoch=5, batch = 6000 of 14253, loss=2.727, LR=9.549150281252633e-05
# Validation Loss = 1.648
# Epoch=5, batch = 7000 of 14253, loss=2.682, LR=9.549150281252633e-05
# Validation Loss = 3.651
# Epoch=5, batch = 8000 of 14253, loss=2.895, LR=9.549150281252633e-05
# Validation Loss = 2.788
# Epoch=5, batch = 9000 of 14253, loss=2.782, LR=9.549150281252633e-05
# Validation Loss = 1.734
# Epoch=5, batch = 10000 of 14253, loss=2.718, LR=9.549150281252633e-05
# Validation Loss = 3.789
# Epoch=5, batch = 11000 of 14253, loss=2.699, LR=9.549150281252633e-05
# Validation Loss = 2.604
# Epoch=5, batch = 12000 of 14253, loss=2.884, LR=9.549150281252633e-05
# Validation Loss = 2.917
# Epoch=5, batch = 13000 of 14253, loss=2.632, LR=9.549150281252633e-05
# Validation Loss = 0.396
# Epoch=5, batch = 14000 of 14253, loss=2.474, LR=9.549150281252633e-05
# Training stage: 2
# Validation Loss = 1.765
# Epoch=1, batch = 0 of 14253, loss=2.643, LR=0.001
# Validation Loss = 2.295
# Epoch=1, batch = 1000 of 14253, loss=2.650, LR=0.001
# Validation Loss = 0.409
# Epoch=1, batch = 2000 of 14253, loss=5.390, LR=0.001
# Validation Loss = 1.023
# Epoch=1, batch = 3000 of 14253, loss=3.069, LR=0.001
# Validation Loss = 3.638
# Epoch=1, batch = 4000 of 14253, loss=2.868, LR=0.001
# Validation Loss = 1.036
# Epoch=1, batch = 5000 of 14253, loss=2.896, LR=0.001
# Validation Loss = 2.839
# Epoch=1, batch = 6000 of 14253, loss=3.052, LR=0.001
# Validation Loss = 0.138
# Epoch=1, batch = 7000 of 14253, loss=3.000, LR=0.001
# Validation Loss = 11.441
# Epoch=1, batch = 8000 of 14253, loss=3.182, LR=0.001
# Validation Loss = 0.007
# Epoch=1, batch = 9000 of 14253, loss=3.927, LR=0.001
# Validation Loss = 0.245
# Epoch=1, batch = 10000 of 14253, loss=3.053, LR=0.001
# Validation Loss = 0.128
# Epoch=1, batch = 11000 of 14253, loss=3.553, LR=0.001
# Validation Loss = 6.276
# Epoch=1, batch = 12000 of 14253, loss=2.729, LR=0.001
# Validation Loss = 8.179
# Epoch=1, batch = 13000 of 14253, loss=3.599, LR=0.001
# Validation Loss = 1.176
# Epoch=1, batch = 14000 of 14253, loss=6.259, LR=0.001
# Validation Loss = 7.535
# Epoch=2, batch = 0 of 14253, loss=6.470, LR=0.0009755282581475768
# Validation Loss = 3.590
# Epoch=2, batch = 1000 of 14253, loss=2.970, LR=0.0009755282581475768
# Validation Loss = 3.038
# Epoch=2, batch = 2000 of 14253, loss=2.799, LR=0.0009755282581475768
# Validation Loss = 7.110
# Epoch=2, batch = 3000 of 14253, loss=3.963, LR=0.0009755282581475768
# Validation Loss = 2.049
# Epoch=2, batch = 4000 of 14253, loss=3.616, LR=0.0009755282581475768
# Validation Loss = 0.017
# Epoch=2, batch = 5000 of 14253, loss=3.230, LR=0.0009755282581475768
# Validation Loss = 1.709
# Epoch=2, batch = 6000 of 14253, loss=2.776, LR=0.0009755282581475768
# Validation Loss = 3.375
# Epoch=2, batch = 7000 of 14253, loss=4.024, LR=0.0009755282581475768
# Validation Loss = 2.324
# Epoch=2, batch = 8000 of 14253, loss=3.263, LR=0.0009755282581475768
# Validation Loss = 2.651
# Epoch=2, batch = 9000 of 14253, loss=2.922, LR=0.0009755282581475768
# Validation Loss = 3.019
# Epoch=2, batch = 10000 of 14253, loss=3.451, LR=0.0009755282581475768
# Validation Loss = 0.820
# Epoch=2, batch = 11000 of 14253, loss=3.723, LR=0.0009755282581475768
# Validation Loss = 11.516
# Epoch=2, batch = 12000 of 14253, loss=3.912, LR=0.0009755282581475768
# Validation Loss = 6.280
# Epoch=2, batch = 13000 of 14253, loss=3.425, LR=0.0009755282581475768
# Validation Loss = 0.725
# Epoch=2, batch = 14000 of 14253, loss=3.140, LR=0.0009755282581475768
# Validation Loss = 0.000
# Epoch=3, batch = 0 of 14253, loss=3.968, LR=0.0009045084971874736
# Validation Loss = 0.587
# Epoch=3, batch = 1000 of 14253, loss=3.379, LR=0.0009045084971874736
# Validation Loss = 0.103
# Epoch=3, batch = 2000 of 14253, loss=2.643, LR=0.0009045084971874736
# Validation Loss = 0.939
# Epoch=3, batch = 3000 of 14253, loss=2.753, LR=0.0009045084971874736
# Validation Loss = 8.592
# Epoch=3, batch = 4000 of 14253, loss=3.570, LR=0.0009045084971874736
# Validation Loss = 16.215
# Epoch=3, batch = 5000 of 14253, loss=2.686, LR=0.0009045084971874736
# Validation Loss = 2.669
# Epoch=3, batch = 6000 of 14253, loss=2.552, LR=0.0009045084971874736
# Validation Loss = 2.405
# Epoch=3, batch = 7000 of 14253, loss=2.882, LR=0.0009045084971874736
# Validation Loss = 2.702
# Epoch=3, batch = 8000 of 14253, loss=2.986, LR=0.0009045084971874736
# Validation Loss = 1.951
# Epoch=3, batch = 9000 of 14253, loss=3.566, LR=0.0009045084971874736
# Validation Loss = 3.868
# Epoch=3, batch = 10000 of 14253, loss=2.498, LR=0.0009045084971874736
# Validation Loss = 5.029
# Epoch=3, batch = 11000 of 14253, loss=3.080, LR=0.0009045084971874736
# Validation Loss = 2.742
# Epoch=3, batch = 12000 of 14253, loss=2.400, LR=0.0009045084971874736
# Validation Loss = 10.812
# Epoch=3, batch = 13000 of 14253, loss=3.227, LR=0.0009045084971874736
# Validation Loss = 0.000
# Epoch=3, batch = 14000 of 14253, loss=3.416, LR=0.0009045084971874736
# Validation Loss = 2.685
# Epoch=4, batch = 0 of 14253, loss=2.926, LR=0.0007938926261462366
# Validation Loss = 0.026
# Epoch=4, batch = 1000 of 14253, loss=3.249, LR=0.0007938926261462366
# Validation Loss = 8.733
# Epoch=4, batch = 2000 of 14253, loss=2.794, LR=0.0007938926261462366
# Validation Loss = 7.628
# Epoch=4, batch = 3000 of 14253, loss=2.634, LR=0.0007938926261462366
# Validation Loss = 8.299
# Epoch=4, batch = 4000 of 14253, loss=3.207, LR=0.0007938926261462366
# Validation Loss = 23.712
# Epoch=4, batch = 5000 of 14253, loss=2.929, LR=0.0007938926261462366
# Validation Loss = 0.193
# Epoch=4, batch = 6000 of 14253, loss=3.033, LR=0.0007938926261462366
# Validation Loss = 0.010
# Epoch=4, batch = 7000 of 14253, loss=4.040, LR=0.0007938926261462366
# Validation Loss = 2.192
# Epoch=4, batch = 8000 of 14253, loss=3.730, LR=0.0007938926261462366
# Validation Loss = 13.525
# Epoch=4, batch = 9000 of 14253, loss=3.315, LR=0.0007938926261462366
# Validation Loss = 4.236
# Epoch=4, batch = 10000 of 14253, loss=2.929, LR=0.0007938926261462366
# Validation Loss = 0.159
# Epoch=4, batch = 11000 of 14253, loss=2.964, LR=0.0007938926261462366
# Validation Loss = 0.094
# Epoch=4, batch = 12000 of 14253, loss=2.795, LR=0.0007938926261462366
# Validation Loss = 1.800
# Epoch=4, batch = 13000 of 14253, loss=3.050, LR=0.0007938926261462366
# Validation Loss = 4.850
# Epoch=4, batch = 14000 of 14253, loss=2.574, LR=0.0007938926261462366
# Validation Loss = 5.375
# Epoch=5, batch = 0 of 14253, loss=2.794, LR=0.0006545084971874737
# Validation Loss = 0.424
# Epoch=5, batch = 1000 of 14253, loss=2.517, LR=0.0006545084971874737
# Validation Loss = 0.275
# Epoch=5, batch = 2000 of 14253, loss=3.103, LR=0.0006545084971874737
# Validation Loss = 0.307
# Epoch=5, batch = 3000 of 14253, loss=3.019, LR=0.0006545084971874737
# Validation Loss = 2.176
# Epoch=5, batch = 4000 of 14253, loss=2.754, LR=0.0006545084971874737
# Validation Loss = 0.672
# Epoch=5, batch = 5000 of 14253, loss=2.259, LR=0.0006545084971874737
# Validation Loss = 0.870
# Epoch=5, batch = 6000 of 14253, loss=3.170, LR=0.0006545084971874737
# Validation Loss = 0.947
# Epoch=5, batch = 7000 of 14253, loss=2.415, LR=0.0006545084971874737
# Validation Loss = 2.737
# Epoch=5, batch = 8000 of 14253, loss=3.391, LR=0.0006545084971874737
# Validation Loss = 4.051
# Epoch=5, batch = 9000 of 14253, loss=3.028, LR=0.0006545084971874737
# Validation Loss = 0.691
# Epoch=5, batch = 10000 of 14253, loss=2.865, LR=0.0006545084971874737
# Validation Loss = 2.067
# Epoch=5, batch = 11000 of 14253, loss=2.784, LR=0.0006545084971874737
# Validation Loss = 2.654
# Epoch=5, batch = 12000 of 14253, loss=2.550, LR=0.0006545084971874737
# Validation Loss = 1.261
# Epoch=5, batch = 13000 of 14253, loss=2.428, LR=0.0006545084971874737
