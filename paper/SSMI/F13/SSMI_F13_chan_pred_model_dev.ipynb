# %% [markdown]
# # Channel Prediction Model for Quality Control
#
# This notebook contains the code and outlines the development of the
# SSMI Channel Prediction Neural Network for QC purposes of SSMI L1C
# data. The simple Feed-Forward Neural Networks (FFNNs) are trained on
# good quality SSMIS brightness temperature observation vectors and are
# trained to predict one channel from all the others as predictors.
#
# The end product is a tree of FFNNs, discretized by surface (ocean or
# land), and by channel, since these are fully distinct problems.

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import glob
import torch
from torch import nn
import cartopy.crs as ccrs
from util_funcs.L1C import scantime2datetime
from util_funcs import data2xarray, array_funcs
import geography
from tqdm import tqdm

from dataset_class import dataset
from model_class import channel_predictor


#General parameters:

satellite = 'F13'
sensor = 'SSMI'

nchans = 9
batch_size = 1000
input_size = nchans - 1
hidden_size = 256
output_size = 1

# %%
'''
Function Definitions:
'''


# Tb array will be set up as follows:
#     Tbs =  [m x n], where m is the number of samples and n is the
#            number of channels (features)
#     1-2:   19.35 V and H
#     3:     22.235 V
#     4-5:   37.0 V and H
#     6-9:   85.5 V and H #Double-sampled 85

chan_desc = np.array(['19V', '19H', '22V', '37V', '37H', '85Va', '85Ha', '85Vb', '85Hb'])


def extract_channel(Tb_array, chan):

    '''
    Use in preparing training data.

    Assumes Tb array is [m x n] where m (rows) are samples
    and n (columns) is the number of channels.

    Passing in the channel description splits the data so
    that the specified channel is its own vector y and the
    rest are kept as predictors x.

    Inputs:
        Tb_array    |  ndarray of Tbs
        chan        |  string of channel name
    Outputs:
        x           |  matrix of predictors (other channels)
        y           |  vector of predictands (the missing channel)
        
    '''
    
    chan_desc = np.array(['19V', '19H', '22V', '37V', '37H', '85Va', '85Ha', '85Vb', '85Hb'])


    chan_indx = np.where(chan == chan_desc)[0]

    if np.size(chan_indx) == 0:
        raise ValueError(f'Channel description must be in list {chan_desc}.')

    y = Tb_array[:,chan_indx]
    x = Tb_array[:,np.delete(np.arange(0,len(chan_desc)),chan_indx)]

    return x, y



def split_data_indcs(x, train=80, test=10, val=10, device=None, randomize=False):

    '''
    Creates train/test/validation split for training data. Default is 80%/10%/10%.

    Inputs:
        x       |   Array of predictors. Expects shape (nsamples, nfeatures).
        y       |   Array of predictands. Expects shape (nsamples, nfeatures).
        train   |   Percentage of data to be used for training.
        test    |   Percentage of data to be used for testing.
        val     |   Percentage of data to be used for validation.
                        -Train + test + val must equal 100.
        device (optional)    |  Either 'cuda' or 'cpu'. 
        randomize (optional) |  Whether to shuffle the data before creating
                                    the splits. This functionality is currently
                                    not supported but is intended to be 
                                    implemented in the future.
    '''

    if train + test + val != 100:
        raise ValueError(f'train + test + val must equal 100%.')

    # if x.shape[0] != y.shape[0]:
    #     raise ValueError(f'Dimensions of x {x.shape} and y {y.shape} not compatible.')

    nsamples = x.shape[0]

    ntrain = int(nsamples * (train / 100.))
    ntest  = int(nsamples * (test / 100.))
    nval   = nsamples - ntrain - ntest

    indcs = np.arange(0,nsamples)

    train_indcs = indcs[0:ntrain]
    test_indcs  = indcs[ntrain:ntrain+ntest]
    val_indcs   = indcs[ntrain+ntest:]

    return train_indcs, test_indcs, val_indcs


def train_model(model, nepochs, dataloader, learning_rate=0.001, quiet=False, stage=None, validation_dataloader=None):

    nbatches = len(dataloader)
    
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=nepochs)
    device = None

    if stage:
        print(f'Training stage: {stage}')

    loss_arr    = np.zeros([nbatches,nepochs], dtype='f')
    valloss_arr = np.zeros([nbatches,nepochs], dtype='f')
    
    for epoch in range(nepochs):
        for i, (profs, obs) in enumerate(dataloader):
            if device:
                profs, obs = profs.to(device), obs.to(device)

            if validation_dataloader and i%100==0:
                valprofs, valobs = next(enumerate(validation_dataloader))[1]
                val_pred = model(valprofs)
                valloss  = criterion(val_pred, valobs)
                print(f'Validation Loss = {valloss.item():.3f}')

            #Forward pass:
            obs_pred = model(profs)
            loss     = criterion(obs_pred, obs)


            #Backward pass:
            optimizer.zero_grad()
            loss.backward()

            #Update neurons:
            optimizer.step()

            loss_arr[i,epoch] = loss.item()
            valloss_arr[i,epoch] = valloss.item()
            
            if not quiet:
                if i%100 == 0:
                    print(f'Epoch = {epoch+1}, batch = {i} of {nbatches}, loss = {loss.item():.3f}, LR = {scheduler.get_last_lr()[0]}')
        
        scheduler.step()




    return loss_arr, valloss_arr

# %%
'''

SSMI CHANNEL PREDICTION MODEL:
    1: Ocean

'''

sfc = [1]

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = np.isin(sfctype, sfc)
    sfcindcs = np.where(correct_sfc)[0]

    Tbs = f.Tbs.values[sfcindcs]

#---Don't shuffle data before splitting
#np.random.seed(40)
#Tbs = array_funcs.shuffle_data(Tbs, axis=0)

if Tbs.shape[0] > 5.0e+06:
    Tbs = Tbs[:5_000_000,:]


print(Tbs.shape)

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train = array_funcs.shuffle_data(Tbs_train, axis=0)
# Out:
# (5000000, 9)

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_ocean.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_ocean.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# Training stage: 1
# Validation Loss = 42322.785
# Epoch = 1, batch = 0 of 4000, loss = 40583.426, LR = 0.001
# Validation Loss = 70.244
# Epoch = 1, batch = 100 of 4000, loss = 10.686, LR = 0.001
# Validation Loss = 18.441
# Epoch = 1, batch = 200 of 4000, loss = 3.315, LR = 0.001
# Validation Loss = 3.954
# Epoch = 1, batch = 300 of 4000, loss = 2.044, LR = 0.001
# Validation Loss = 1.986
# Epoch = 1, batch = 400 of 4000, loss = 1.561, LR = 0.001
# Validation Loss = 2.176
# Epoch = 1, batch = 500 of 4000, loss = 1.539, LR = 0.001
# Validation Loss = 0.375
# Epoch = 1, batch = 600 of 4000, loss = 1.601, LR = 0.001
# Validation Loss = 1.672
# Epoch = 1, batch = 700 of 4000, loss = 1.298, LR = 0.001
# Validation Loss = 0.965
# Epoch = 1, batch = 800 of 4000, loss = 1.197, LR = 0.001
# Validation Loss = 0.979
# Epoch = 1, batch = 900 of 4000, loss = 1.464, LR = 0.001
# Validation Loss = 1.407
# Epoch = 1, batch = 1000 of 4000, loss = 1.236, LR = 0.001
# Validation Loss = 1.203
# Epoch = 1, batch = 1100 of 4000, loss = 1.137, LR = 0.001
# Validation Loss = 0.276
# Epoch = 1, batch = 1200 of 4000, loss = 1.177, LR = 0.001
# Validation Loss = 0.819
# Epoch = 1, batch = 1300 of 4000, loss = 1.264, LR = 0.001
# Validation Loss = 0.813
# Epoch = 1, batch = 1400 of 4000, loss = 1.040, LR = 0.001
# Validation Loss = 0.556
# Epoch = 1, batch = 1500 of 4000, loss = 1.062, LR = 0.001
# Validation Loss = 0.293
# Epoch = 1, batch = 1600 of 4000, loss = 1.154, LR = 0.001
# Validation Loss = 0.373
# Epoch = 1, batch = 1700 of 4000, loss = 0.968, LR = 0.001
# Validation Loss = 0.714
# Epoch = 1, batch = 1800 of 4000, loss = 0.975, LR = 0.001
# Validation Loss = 0.906
# Epoch = 1, batch = 1900 of 4000, loss = 1.035, LR = 0.001
# Validation Loss = 0.380
# Epoch = 1, batch = 2000 of 4000, loss = 1.066, LR = 0.001
# Validation Loss = 0.192
# Epoch = 1, batch = 2100 of 4000, loss = 1.141, LR = 0.001
# Validation Loss = 0.226
# Epoch = 1, batch = 2200 of 4000, loss = 0.901, LR = 0.001
# Validation Loss = 0.297
# Epoch = 1, batch = 2300 of 4000, loss = 0.876, LR = 0.001
# Validation Loss = 0.252
# Epoch = 1, batch = 2400 of 4000, loss = 0.846, LR = 0.001
# Validation Loss = 0.198
# Epoch = 1, batch = 2500 of 4000, loss = 0.896, LR = 0.001
# Validation Loss = 0.017
# Epoch = 1, batch = 2600 of 4000, loss = 0.983, LR = 0.001
# Validation Loss = 0.468
# Epoch = 1, batch = 2700 of 4000, loss = 0.906, LR = 0.001
# Validation Loss = 0.514
# Epoch = 1, batch = 2800 of 4000, loss = 1.104, LR = 0.001
# Validation Loss = 0.328
# Epoch = 1, batch = 2900 of 4000, loss = 0.964, LR = 0.001
# Validation Loss = 0.014
# Epoch = 1, batch = 3000 of 4000, loss = 0.832, LR = 0.001
# Validation Loss = 0.208
# Epoch = 1, batch = 3100 of 4000, loss = 0.903, LR = 0.001
# Validation Loss = 0.014
# Epoch = 1, batch = 3200 of 4000, loss = 0.733, LR = 0.001
# Validation Loss = 0.104
# Epoch = 1, batch = 3300 of 4000, loss = 0.818, LR = 0.001
# Validation Loss = 0.017
# Epoch = 1, batch = 3400 of 4000, loss = 0.779, LR = 0.001
# Validation Loss = 1.340
# Epoch = 1, batch = 3500 of 4000, loss = 1.892, LR = 0.001
# Validation Loss = 0.675
# Epoch = 1, batch = 3600 of 4000, loss = 1.489, LR = 0.001
# Validation Loss = 0.553
# Epoch = 1, batch = 3700 of 4000, loss = 1.053, LR = 0.001
# Validation Loss = 0.185
# Epoch = 1, batch = 3800 of 4000, loss = 0.860, LR = 0.001
# Validation Loss = 0.393
# Epoch = 1, batch = 3900 of 4000, loss = 0.997, LR = 0.001
# Validation Loss = 3.138
# Epoch = 2, batch = 0 of 4000, loss = 3.380, LR = 0.0009045084971874737
# Validation Loss = 0.015
# Epoch = 2, batch = 100 of 4000, loss = 0.793, LR = 0.0009045084971874737
# Validation Loss = 0.345
# Epoch = 2, batch = 200 of 4000, loss = 1.054, LR = 0.0009045084971874737
# Validation Loss = 3.384
# Epoch = 2, batch = 300 of 4000, loss = 4.023, LR = 0.0009045084971874737
# Validation Loss = 0.254
# Epoch = 2, batch = 400 of 4000, loss = 0.891, LR = 0.0009045084971874737
# Validation Loss = 0.005
# Epoch = 2, batch = 500 of 4000, loss = 0.780, LR = 0.0009045084971874737
# Validation Loss = 2.673
# Epoch = 2, batch = 600 of 4000, loss = 3.318, LR = 0.0009045084971874737
# Validation Loss = 0.536
# Epoch = 2, batch = 700 of 4000, loss = 1.097, LR = 0.0009045084971874737
# Validation Loss = 0.911
# Epoch = 2, batch = 800 of 4000, loss = 1.540, LR = 0.0009045084971874737
# Validation Loss = 0.738
# Epoch = 2, batch = 900 of 4000, loss = 1.246, LR = 0.0009045084971874737
# Validation Loss = 2.105
# Epoch = 2, batch = 1000 of 4000, loss = 2.379, LR = 0.0009045084971874737
# Validation Loss = 0.105
# Epoch = 2, batch = 1100 of 4000, loss = 0.771, LR = 0.0009045084971874737
# Validation Loss = 1.575
# Epoch = 2, batch = 1200 of 4000, loss = 2.160, LR = 0.0009045084971874737
# Validation Loss = 0.261
# Epoch = 2, batch = 1300 of 4000, loss = 0.972, LR = 0.0009045084971874737
# Validation Loss = 0.604
# Epoch = 2, batch = 1400 of 4000, loss = 1.079, LR = 0.0009045084971874737
# Validation Loss = 0.425
# Epoch = 2, batch = 1500 of 4000, loss = 1.243, LR = 0.0009045084971874737
# Validation Loss = 0.457
# Epoch = 2, batch = 1600 of 4000, loss = 1.219, LR = 0.0009045084971874737
# Validation Loss = 0.089
# Epoch = 2, batch = 1700 of 4000, loss = 0.783, LR = 0.0009045084971874737
# Validation Loss = 0.040
# Epoch = 2, batch = 1800 of 4000, loss = 0.681, LR = 0.0009045084971874737
# Validation Loss = 0.088
# Epoch = 2, batch = 1900 of 4000, loss = 0.777, LR = 0.0009045084971874737
# Validation Loss = 0.062
# Epoch = 2, batch = 2000 of 4000, loss = 0.764, LR = 0.0009045084971874737
# Validation Loss = 6.047
# Epoch = 2, batch = 2100 of 4000, loss = 6.542, LR = 0.0009045084971874737
# Validation Loss = 1.164
# Epoch = 2, batch = 2200 of 4000, loss = 1.450, LR = 0.0009045084971874737
# Validation Loss = 5.317
# Epoch = 2, batch = 2300 of 4000, loss = 4.751, LR = 0.0009045084971874737
# Validation Loss = 0.773
# Epoch = 2, batch = 2400 of 4000, loss = 1.505, LR = 0.0009045084971874737
# Validation Loss = 1.027
# Epoch = 2, batch = 2500 of 4000, loss = 1.470, LR = 0.0009045084971874737
# Validation Loss = 1.077
# Epoch = 2, batch = 2600 of 4000, loss = 1.656, LR = 0.0009045084971874737
# Validation Loss = 0.362
# Epoch = 2, batch = 2700 of 4000, loss = 0.797, LR = 0.0009045084971874737
# Validation Loss = 0.001
# Epoch = 2, batch = 2800 of 4000, loss = 0.690, LR = 0.0009045084971874737
# Validation Loss = 0.094
# Epoch = 2, batch = 2900 of 4000, loss = 0.802, LR = 0.0009045084971874737
# Validation Loss = 0.562
# Epoch = 2, batch = 3000 of 4000, loss = 1.238, LR = 0.0009045084971874737
# Validation Loss = 0.006
# Epoch = 2, batch = 3100 of 4000, loss = 0.659, LR = 0.0009045084971874737
# Validation Loss = 0.032
# Epoch = 2, batch = 3200 of 4000, loss = 0.641, LR = 0.0009045084971874737
# Validation Loss = 0.010
# Epoch = 2, batch = 3300 of 4000, loss = 0.757, LR = 0.0009045084971874737
# Validation Loss = 0.005
# Epoch = 2, batch = 3400 of 4000, loss = 0.724, LR = 0.0009045084971874737
# Validation Loss = 0.540
# Epoch = 2, batch = 3500 of 4000, loss = 0.900, LR = 0.0009045084971874737
# Validation Loss = 0.022
# Epoch = 2, batch = 3600 of 4000, loss = 0.821, LR = 0.0009045084971874737
# Validation Loss = 0.178
# Epoch = 2, batch = 3700 of 4000, loss = 1.026, LR = 0.0009045084971874737
# Validation Loss = 0.005
# Epoch = 2, batch = 3800 of 4000, loss = 0.728, LR = 0.0009045084971874737
# Validation Loss = 0.164
# Epoch = 2, batch = 3900 of 4000, loss = 0.725, LR = 0.0009045084971874737
# Validation Loss = 0.016
# Epoch = 3, batch = 0 of 4000, loss = 0.780, LR = 0.0006545084971874737
# Validation Loss = 0.205
# Epoch = 3, batch = 100 of 4000, loss = 0.631, LR = 0.0006545084971874737
# Validation Loss = 0.083
# Epoch = 3, batch = 200 of 4000, loss = 0.674, LR = 0.0006545084971874737
# Validation Loss = 0.098
# Epoch = 3, batch = 300 of 4000, loss = 0.609, LR = 0.0006545084971874737
# Validation Loss = 0.000
# Epoch = 3, batch = 400 of 4000, loss = 0.621, LR = 0.0006545084971874737
# Validation Loss = 2.030
# Epoch = 3, batch = 500 of 4000, loss = 1.686, LR = 0.0006545084971874737
# Validation Loss = 0.188
# Epoch = 3, batch = 600 of 4000, loss = 0.993, LR = 0.0006545084971874737
# Validation Loss = 0.031
# Epoch = 3, batch = 700 of 4000, loss = 0.583, LR = 0.0006545084971874737
# Validation Loss = 1.116
# Epoch = 3, batch = 800 of 4000, loss = 1.065, LR = 0.0006545084971874737
# Validation Loss = 0.368
# Epoch = 3, batch = 900 of 4000, loss = 0.801, LR = 0.0006545084971874737
# Validation Loss = 0.441
# Epoch = 3, batch = 1000 of 4000, loss = 1.270, LR = 0.0006545084971874737
# Validation Loss = 0.034
# Epoch = 3, batch = 1100 of 4000, loss = 0.598, LR = 0.0006545084971874737
# Validation Loss = 0.022
# Epoch = 3, batch = 1200 of 4000, loss = 0.632, LR = 0.0006545084971874737
# Validation Loss = 0.046
# Epoch = 3, batch = 1300 of 4000, loss = 0.657, LR = 0.0006545084971874737
# Validation Loss = 0.560
# Epoch = 3, batch = 1400 of 4000, loss = 0.908, LR = 0.0006545084971874737
# Validation Loss = 2.775
# Epoch = 3, batch = 1500 of 4000, loss = 2.447, LR = 0.0006545084971874737
# Validation Loss = 0.029
# Epoch = 3, batch = 1600 of 4000, loss = 0.686, LR = 0.0006545084971874737
# Validation Loss = 0.476
# Epoch = 3, batch = 1700 of 4000, loss = 0.867, LR = 0.0006545084971874737
# Validation Loss = 1.676
# Epoch = 3, batch = 1800 of 4000, loss = 1.452, LR = 0.0006545084971874737
# Validation Loss = 0.438
# Epoch = 3, batch = 1900 of 4000, loss = 1.376, LR = 0.0006545084971874737
# Validation Loss = 0.710
# Epoch = 3, batch = 2000 of 4000, loss = 0.896, LR = 0.0006545084971874737
# Validation Loss = 0.013
# Epoch = 3, batch = 2100 of 4000, loss = 0.679, LR = 0.0006545084971874737
# Validation Loss = 2.104
# Epoch = 3, batch = 2200 of 4000, loss = 1.830, LR = 0.0006545084971874737
# Validation Loss = 0.985
# Epoch = 3, batch = 2300 of 4000, loss = 0.951, LR = 0.0006545084971874737
# Validation Loss = 0.205
# Epoch = 3, batch = 2400 of 4000, loss = 0.712, LR = 0.0006545084971874737
# Validation Loss = 0.700
# Epoch = 3, batch = 2500 of 4000, loss = 1.031, LR = 0.0006545084971874737
# Validation Loss = 0.040
# Epoch = 3, batch = 2600 of 4000, loss = 0.959, LR = 0.0006545084971874737
# Validation Loss = 4.020
# Epoch = 3, batch = 2700 of 4000, loss = 4.251, LR = 0.0006545084971874737
# Validation Loss = 0.107
# Epoch = 3, batch = 2800 of 4000, loss = 0.819, LR = 0.0006545084971874737
# Validation Loss = 0.020
# Epoch = 3, batch = 2900 of 4000, loss = 0.633, LR = 0.0006545084971874737
# Validation Loss = 0.110
# Epoch = 3, batch = 3000 of 4000, loss = 0.647, LR = 0.0006545084971874737
# Validation Loss = 0.435
# Epoch = 3, batch = 3100 of 4000, loss = 0.831, LR = 0.0006545084971874737
# Validation Loss = 0.782
# Epoch = 3, batch = 3200 of 4000, loss = 0.973, LR = 0.0006545084971874737
# Validation Loss = 0.000
# Epoch = 3, batch = 3300 of 4000, loss = 0.620, LR = 0.0006545084971874737
# Validation Loss = 0.021
# Epoch = 3, batch = 3400 of 4000, loss = 0.598, LR = 0.0006545084971874737
# Validation Loss = 0.043
# Epoch = 3, batch = 3500 of 4000, loss = 0.667, LR = 0.0006545084971874737
# Validation Loss = 0.614
# Epoch = 3, batch = 3600 of 4000, loss = 0.808, LR = 0.0006545084971874737
# Validation Loss = 0.209
# Epoch = 3, batch = 3700 of 4000, loss = 0.671, LR = 0.0006545084971874737
# Validation Loss = 0.000
# Epoch = 3, batch = 3800 of 4000, loss = 0.680, LR = 0.0006545084971874737
# Validation Loss = 0.585
# Epoch = 3, batch = 3900 of 4000, loss = 0.908, LR = 0.0006545084971874737
# Validation Loss = 0.058
# Epoch = 4, batch = 0 of 4000, loss = 0.612, LR = 0.00034549150281252633
# Validation Loss = 0.069
# Epoch = 4, batch = 100 of 4000, loss = 0.569, LR = 0.00034549150281252633
# Validation Loss = 0.009
# Epoch = 4, batch = 200 of 4000, loss = 0.670, LR = 0.00034549150281252633
# Validation Loss = 0.274
# Epoch = 4, batch = 300 of 4000, loss = 0.594, LR = 0.00034549150281252633
# Validation Loss = 0.031
# Epoch = 4, batch = 400 of 4000, loss = 0.620, LR = 0.00034549150281252633
# Validation Loss = 0.053
# Epoch = 4, batch = 500 of 4000, loss = 0.577, LR = 0.00034549150281252633
# Validation Loss = 0.050
# Epoch = 4, batch = 600 of 4000, loss = 0.641, LR = 0.00034549150281252633
# Validation Loss = 0.051
# Epoch = 4, batch = 700 of 4000, loss = 0.595, LR = 0.00034549150281252633
# Validation Loss = 0.162
# Epoch = 4, batch = 800 of 4000, loss = 0.577, LR = 0.00034549150281252633
# Validation Loss = 0.031
# Epoch = 4, batch = 900 of 4000, loss = 0.647, LR = 0.00034549150281252633
# Validation Loss = 0.005
# Epoch = 4, batch = 1000 of 4000, loss = 0.675, LR = 0.00034549150281252633
# Validation Loss = 0.034
# Epoch = 4, batch = 1100 of 4000, loss = 0.652, LR = 0.00034549150281252633
# Validation Loss = 0.335
# Epoch = 4, batch = 1200 of 4000, loss = 0.718, LR = 0.00034549150281252633
# Validation Loss = 0.020
# Epoch = 4, batch = 1300 of 4000, loss = 0.580, LR = 0.00034549150281252633
# Validation Loss = 0.268
# Epoch = 4, batch = 1400 of 4000, loss = 0.608, LR = 0.00034549150281252633
# Validation Loss = 0.610
# Epoch = 4, batch = 1500 of 4000, loss = 1.385, LR = 0.00034549150281252633
# Validation Loss = 0.016
# Epoch = 4, batch = 1600 of 4000, loss = 0.660, LR = 0.00034549150281252633
# Validation Loss = 0.090
# Epoch = 4, batch = 1700 of 4000, loss = 0.620, LR = 0.00034549150281252633
# Validation Loss = 0.102
# Epoch = 4, batch = 1800 of 4000, loss = 0.645, LR = 0.00034549150281252633
# Validation Loss = 0.148
# Epoch = 4, batch = 1900 of 4000, loss = 0.640, LR = 0.00034549150281252633
# Validation Loss = 0.467
# Epoch = 4, batch = 2000 of 4000, loss = 0.764, LR = 0.00034549150281252633
# Validation Loss = 0.116
# Epoch = 4, batch = 2100 of 4000, loss = 0.796, LR = 0.00034549150281252633
# Validation Loss = 0.025
# Epoch = 4, batch = 2200 of 4000, loss = 0.622, LR = 0.00034549150281252633
# Validation Loss = 0.213
# Epoch = 4, batch = 2300 of 4000, loss = 0.603, LR = 0.00034549150281252633
# Validation Loss = 1.572
# Epoch = 4, batch = 2400 of 4000, loss = 1.326, LR = 0.00034549150281252633
# Validation Loss = 0.717
# Epoch = 4, batch = 2500 of 4000, loss = 0.865, LR = 0.00034549150281252633
# Validation Loss = 0.003
# Epoch = 4, batch = 2600 of 4000, loss = 0.738, LR = 0.00034549150281252633
# Validation Loss = 0.070
# Epoch = 4, batch = 2700 of 4000, loss = 0.585, LR = 0.00034549150281252633
# Validation Loss = 0.129
# Epoch = 4, batch = 2800 of 4000, loss = 0.828, LR = 0.00034549150281252633
# Validation Loss = 0.029
# Epoch = 4, batch = 2900 of 4000, loss = 0.574, LR = 0.00034549150281252633
# Validation Loss = 1.384
# Epoch = 4, batch = 3000 of 4000, loss = 1.157, LR = 0.00034549150281252633
# Validation Loss = 0.014
# Epoch = 4, batch = 3100 of 4000, loss = 0.560, LR = 0.00034549150281252633
# Validation Loss = 0.032
# Epoch = 4, batch = 3200 of 4000, loss = 0.737, LR = 0.00034549150281252633
# Validation Loss = 0.002
# Epoch = 4, batch = 3300 of 4000, loss = 0.592, LR = 0.00034549150281252633
# Validation Loss = 0.025
# Epoch = 4, batch = 3400 of 4000, loss = 0.709, LR = 0.00034549150281252633
# Validation Loss = 0.351
# Epoch = 4, batch = 3500 of 4000, loss = 0.840, LR = 0.00034549150281252633
# Validation Loss = 0.017
# Epoch = 4, batch = 3600 of 4000, loss = 0.587, LR = 0.00034549150281252633
# Validation Loss = 0.005
# Epoch = 4, batch = 3700 of 4000, loss = 0.653, LR = 0.00034549150281252633
# Validation Loss = 0.111
# Epoch = 4, batch = 3800 of 4000, loss = 0.609, LR = 0.00034549150281252633
# Validation Loss = 0.751
# Epoch = 4, batch = 3900 of 4000, loss = 0.938, LR = 0.00034549150281252633
# Validation Loss = 0.935
# Epoch = 5, batch = 0 of 4000, loss = 1.445, LR = 9.549150281252633e-05
# Validation Loss = 0.078
# Epoch = 5, batch = 100 of 4000, loss = 0.634, LR = 9.549150281252633e-05
# Validation Loss = 0.054
# Epoch = 5, batch = 200 of 4000, loss = 0.637, LR = 9.549150281252633e-05
# Validation Loss = 0.116
# Epoch = 5, batch = 300 of 4000, loss = 0.568, LR = 9.549150281252633e-05
# Validation Loss = 0.033
# Epoch = 5, batch = 400 of 4000, loss = 0.561, LR = 9.549150281252633e-05
# Validation Loss = 0.013
# Epoch = 5, batch = 500 of 4000, loss = 0.585, LR = 9.549150281252633e-05
# Validation Loss = 0.028
# Epoch = 5, batch = 600 of 4000, loss = 0.602, LR = 9.549150281252633e-05
# Validation Loss = 0.026
# Epoch = 5, batch = 700 of 4000, loss = 0.559, LR = 9.549150281252633e-05
# Validation Loss = 0.055
# Epoch = 5, batch = 800 of 4000, loss = 0.664, LR = 9.549150281252633e-05
# Validation Loss = 0.121
# Epoch = 5, batch = 900 of 4000, loss = 0.562, LR = 9.549150281252633e-05
# Validation Loss = 0.025
# Epoch = 5, batch = 1000 of 4000, loss = 0.540, LR = 9.549150281252633e-05
# Validation Loss = 0.175
# Epoch = 5, batch = 1100 of 4000, loss = 0.812, LR = 9.549150281252633e-05
# Validation Loss = 0.121
# Epoch = 5, batch = 1200 of 4000, loss = 0.597, LR = 9.549150281252633e-05
# Validation Loss = 0.105
# Epoch = 5, batch = 1300 of 4000, loss = 0.630, LR = 9.549150281252633e-05
# Validation Loss = 0.055
# Epoch = 5, batch = 1400 of 4000, loss = 0.534, LR = 9.549150281252633e-05
# Validation Loss = 0.119
# Epoch = 5, batch = 1500 of 4000, loss = 0.558, LR = 9.549150281252633e-05
# Validation Loss = 0.144
# Epoch = 5, batch = 1600 of 4000, loss = 0.598, LR = 9.549150281252633e-05
# Validation Loss = 0.157
# Epoch = 5, batch = 1700 of 4000, loss = 0.630, LR = 9.549150281252633e-05
# Validation Loss = 0.082
# Epoch = 5, batch = 1800 of 4000, loss = 0.582, LR = 9.549150281252633e-05
# Validation Loss = 0.114
# Epoch = 5, batch = 1900 of 4000, loss = 0.605, LR = 9.549150281252633e-05
# Validation Loss = 0.081
# Epoch = 5, batch = 2000 of 4000, loss = 0.614, LR = 9.549150281252633e-05
# Validation Loss = 0.031
# Epoch = 5, batch = 2100 of 4000, loss = 0.574, LR = 9.549150281252633e-05
# Validation Loss = 0.116
# Epoch = 5, batch = 2200 of 4000, loss = 0.595, LR = 9.549150281252633e-05
# Validation Loss = 0.038
# Epoch = 5, batch = 2300 of 4000, loss = 0.570, LR = 9.549150281252633e-05
# Validation Loss = 0.277
# Epoch = 5, batch = 2400 of 4000, loss = 0.638, LR = 9.549150281252633e-05
# Validation Loss = 0.101
# Epoch = 5, batch = 2500 of 4000, loss = 0.551, LR = 9.549150281252633e-05
# Validation Loss = 0.052
# Epoch = 5, batch = 2600 of 4000, loss = 0.645, LR = 9.549150281252633e-05
# Validation Loss = 0.174
# Epoch = 5, batch = 2700 of 4000, loss = 0.607, LR = 9.549150281252633e-05
# Validation Loss = 0.159
# Epoch = 5, batch = 2800 of 4000, loss = 0.573, LR = 9.549150281252633e-05
# Validation Loss = 0.022
# Epoch = 5, batch = 2900 of 4000, loss = 0.603, LR = 9.549150281252633e-05
# Validation Loss = 0.133
# Epoch = 5, batch = 3000 of 4000, loss = 0.534, LR = 9.549150281252633e-05
# Validation Loss = 0.072
# Epoch = 5, batch = 3100 of 4000, loss = 0.610, LR = 9.549150281252633e-05
# Validation Loss = 0.014
# Epoch = 5, batch = 3200 of 4000, loss = 0.642, LR = 9.549150281252633e-05
# Validation Loss = 0.025
# Epoch = 5, batch = 3300 of 4000, loss = 0.576, LR = 9.549150281252633e-05
# Validation Loss = 0.448
# Epoch = 5, batch = 3400 of 4000, loss = 0.636, LR = 9.549150281252633e-05
# Validation Loss = 0.354
# Epoch = 5, batch = 3500 of 4000, loss = 0.629, LR = 9.549150281252633e-05
# Validation Loss = 0.002
# Epoch = 5, batch = 3600 of 4000, loss = 0.612, LR = 9.549150281252633e-05
# Validation Loss = 0.021
# Epoch = 5, batch = 3700 of 4000, loss = 0.635, LR = 9.549150281252633e-05
# Validation Loss = 0.022
# Epoch = 5, batch = 3800 of 4000, loss = 0.624, LR = 9.549150281252633e-05
# Validation Loss = 0.031
# Epoch = 5, batch = 3900 of 4000, loss = 0.569, LR = 9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.120
# Epoch = 1, batch = 0 of 4000, loss = 0.667, LR = 0.001
# Validation Loss = 0.004
# Epoch = 1, batch = 100 of 4000, loss = 0.865, LR = 0.001
# Validation Loss = 0.060
# Epoch = 1, batch = 200 of 4000, loss = 0.685, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 300 of 4000, loss = 0.673, LR = 0.001
# Validation Loss = 0.035
# Epoch = 1, batch = 400 of 4000, loss = 0.664, LR = 0.001
# Validation Loss = 0.081
# Epoch = 1, batch = 500 of 4000, loss = 0.560, LR = 0.001
# Validation Loss = 0.065
# Epoch = 1, batch = 600 of 4000, loss = 0.609, LR = 0.001
# Validation Loss = 0.037
# Epoch = 1, batch = 700 of 4000, loss = 0.672, LR = 0.001
# Validation Loss = 0.004
# Epoch = 1, batch = 800 of 4000, loss = 0.605, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 900 of 4000, loss = 0.654, LR = 0.001
# Validation Loss = 0.025
# Epoch = 1, batch = 1000 of 4000, loss = 0.662, LR = 0.001
# Validation Loss = 0.004
# Epoch = 1, batch = 1100 of 4000, loss = 0.631, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 1200 of 4000, loss = 0.795, LR = 0.001
# Validation Loss = 0.008
# Epoch = 1, batch = 1300 of 4000, loss = 0.627, LR = 0.001
# Validation Loss = 0.016
# Epoch = 1, batch = 1400 of 4000, loss = 0.662, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 1500 of 4000, loss = 0.549, LR = 0.001
# Validation Loss = 0.054
# Epoch = 1, batch = 1600 of 4000, loss = 0.695, LR = 0.001
# Validation Loss = 0.074
# Epoch = 1, batch = 1700 of 4000, loss = 0.588, LR = 0.001
# Validation Loss = 0.098
# Epoch = 1, batch = 1800 of 4000, loss = 0.687, LR = 0.001
# Validation Loss = 0.012
# Epoch = 1, batch = 1900 of 4000, loss = 0.582, LR = 0.001
# Validation Loss = 0.264
# Epoch = 1, batch = 2000 of 4000, loss = 0.740, LR = 0.001
# Validation Loss = 0.978
# Epoch = 1, batch = 2100 of 4000, loss = 1.718, LR = 0.001
# Validation Loss = 0.003
# Epoch = 1, batch = 2200 of 4000, loss = 0.622, LR = 0.001
# Validation Loss = 0.024
# Epoch = 1, batch = 2300 of 4000, loss = 0.571, LR = 0.001
# Validation Loss = 0.640
# Epoch = 1, batch = 2400 of 4000, loss = 1.284, LR = 0.001
# Validation Loss = 0.029
# Epoch = 1, batch = 2500 of 4000, loss = 0.760, LR = 0.001
# Validation Loss = 0.025
# Epoch = 1, batch = 2600 of 4000, loss = 0.622, LR = 0.001
# Validation Loss = 0.671
# Epoch = 1, batch = 2700 of 4000, loss = 1.171, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 2800 of 4000, loss = 0.586, LR = 0.001
# Validation Loss = 0.403
# Epoch = 1, batch = 2900 of 4000, loss = 0.957, LR = 0.001
# Validation Loss = 0.137
# Epoch = 1, batch = 3000 of 4000, loss = 0.719, LR = 0.001
# Validation Loss = 0.175
# Epoch = 1, batch = 3100 of 4000, loss = 0.743, LR = 0.001
# Validation Loss = 1.709
# Epoch = 1, batch = 3200 of 4000, loss = 2.421, LR = 0.001
# Validation Loss = 0.169
# Epoch = 1, batch = 3300 of 4000, loss = 0.742, LR = 0.001
# Validation Loss = 0.680
# Epoch = 1, batch = 3400 of 4000, loss = 1.172, LR = 0.001
# Validation Loss = 0.037
# Epoch = 1, batch = 3500 of 4000, loss = 0.704, LR = 0.001
# Validation Loss = 0.359
# Epoch = 1, batch = 3600 of 4000, loss = 0.830, LR = 0.001
# Validation Loss = 1.019
# Epoch = 1, batch = 3700 of 4000, loss = 1.459, LR = 0.001
# Validation Loss = 1.378
# Epoch = 1, batch = 3800 of 4000, loss = 2.037, LR = 0.001
# Validation Loss = 0.273
# Epoch = 1, batch = 3900 of 4000, loss = 0.782, LR = 0.001
# Validation Loss = 4.045
# Epoch = 2, batch = 0 of 4000, loss = 4.140, LR = 0.0009755282581475768
# Validation Loss = 2.194
# Epoch = 2, batch = 100 of 4000, loss = 2.626, LR = 0.0009755282581475768
# Validation Loss = 0.248
# Epoch = 2, batch = 200 of 4000, loss = 0.997, LR = 0.0009755282581475768
# Validation Loss = 0.127
# Epoch = 2, batch = 300 of 4000, loss = 0.779, LR = 0.0009755282581475768
# Validation Loss = 0.007
# Epoch = 2, batch = 400 of 4000, loss = 0.566, LR = 0.0009755282581475768
# Validation Loss = 2.245
# Epoch = 2, batch = 500 of 4000, loss = 2.556, LR = 0.0009755282581475768
# Validation Loss = 0.006
# Epoch = 2, batch = 600 of 4000, loss = 0.571, LR = 0.0009755282581475768
# Validation Loss = 0.421
# Epoch = 2, batch = 700 of 4000, loss = 0.937, LR = 0.0009755282581475768
# Validation Loss = 0.023
# Epoch = 2, batch = 800 of 4000, loss = 0.649, LR = 0.0009755282581475768
# Validation Loss = 0.102
# Epoch = 2, batch = 900 of 4000, loss = 0.797, LR = 0.0009755282581475768
# Validation Loss = 1.127
# Epoch = 2, batch = 1000 of 4000, loss = 1.583, LR = 0.0009755282581475768
# Validation Loss = 1.229
# Epoch = 2, batch = 1100 of 4000, loss = 1.414, LR = 0.0009755282581475768
# Validation Loss = 0.411
# Epoch = 2, batch = 1200 of 4000, loss = 0.929, LR = 0.0009755282581475768
# Validation Loss = 0.856
# Epoch = 2, batch = 1300 of 4000, loss = 1.250, LR = 0.0009755282581475768
# Validation Loss = 0.149
# Epoch = 2, batch = 1400 of 4000, loss = 0.767, LR = 0.0009755282581475768
# Validation Loss = 3.168
# Epoch = 2, batch = 1500 of 4000, loss = 3.137, LR = 0.0009755282581475768
# Validation Loss = 0.002
# Epoch = 2, batch = 1600 of 4000, loss = 0.648, LR = 0.0009755282581475768
# Validation Loss = 1.637
# Epoch = 2, batch = 1700 of 4000, loss = 2.171, LR = 0.0009755282581475768
# Validation Loss = 0.011
# Epoch = 2, batch = 1800 of 4000, loss = 0.661, LR = 0.0009755282581475768
# Validation Loss = 0.345
# Epoch = 2, batch = 1900 of 4000, loss = 0.947, LR = 0.0009755282581475768
# Validation Loss = 0.216
# Epoch = 2, batch = 2000 of 4000, loss = 0.787, LR = 0.0009755282581475768
# Validation Loss = 0.002
# Epoch = 2, batch = 2100 of 4000, loss = 0.629, LR = 0.0009755282581475768
# Validation Loss = 0.216
# Epoch = 2, batch = 2200 of 4000, loss = 0.999, LR = 0.0009755282581475768
# Validation Loss = 0.370
# Epoch = 2, batch = 2300 of 4000, loss = 1.016, LR = 0.0009755282581475768
# Validation Loss = 0.525
# Epoch = 2, batch = 2400 of 4000, loss = 1.056, LR = 0.0009755282581475768
# Validation Loss = 0.277
# Epoch = 2, batch = 2500 of 4000, loss = 0.846, LR = 0.0009755282581475768
# Validation Loss = 0.068
# Epoch = 2, batch = 2600 of 4000, loss = 0.705, LR = 0.0009755282581475768
# Validation Loss = 0.140
# Epoch = 2, batch = 2700 of 4000, loss = 0.728, LR = 0.0009755282581475768
# Validation Loss = 0.012
# Epoch = 2, batch = 2800 of 4000, loss = 0.544, LR = 0.0009755282581475768
# Validation Loss = 2.597
# Epoch = 2, batch = 2900 of 4000, loss = 2.613, LR = 0.0009755282581475768
# Validation Loss = 2.216
# Epoch = 2, batch = 3000 of 4000, loss = 2.649, LR = 0.0009755282581475768
# Validation Loss = 0.368
# Epoch = 2, batch = 3100 of 4000, loss = 0.844, LR = 0.0009755282581475768
# Validation Loss = 0.031
# Epoch = 2, batch = 3200 of 4000, loss = 0.585, LR = 0.0009755282581475768
# Validation Loss = 1.478
# Epoch = 2, batch = 3300 of 4000, loss = 2.019, LR = 0.0009755282581475768
# Validation Loss = 0.082
# Epoch = 2, batch = 3400 of 4000, loss = 0.690, LR = 0.0009755282581475768
# Validation Loss = 1.232
# Epoch = 2, batch = 3500 of 4000, loss = 1.523, LR = 0.0009755282581475768
# Validation Loss = 0.765
# Epoch = 2, batch = 3600 of 4000, loss = 1.210, LR = 0.0009755282581475768
# Validation Loss = 0.001
# Epoch = 2, batch = 3700 of 4000, loss = 0.582, LR = 0.0009755282581475768
# Validation Loss = 4.624
# Epoch = 2, batch = 3800 of 4000, loss = 4.784, LR = 0.0009755282581475768
# Validation Loss = 0.431
# Epoch = 2, batch = 3900 of 4000, loss = 1.022, LR = 0.0009755282581475768
# Validation Loss = 0.025
# Epoch = 3, batch = 0 of 4000, loss = 0.610, LR = 0.0009045084971874736
# Validation Loss = 0.224
# Epoch = 3, batch = 100 of 4000, loss = 0.666, LR = 0.0009045084971874736
# Validation Loss = 0.014
# Epoch = 3, batch = 200 of 4000, loss = 0.610, LR = 0.0009045084971874736
# Validation Loss = 1.313
# Epoch = 3, batch = 300 of 4000, loss = 1.703, LR = 0.0009045084971874736
# Validation Loss = 0.202
# Epoch = 3, batch = 400 of 4000, loss = 0.765, LR = 0.0009045084971874736
# Validation Loss = 0.054
# Epoch = 3, batch = 500 of 4000, loss = 0.576, LR = 0.0009045084971874736
# Validation Loss = 0.401
# Epoch = 3, batch = 600 of 4000, loss = 0.882, LR = 0.0009045084971874736
# Validation Loss = 0.393
# Epoch = 3, batch = 700 of 4000, loss = 0.763, LR = 0.0009045084971874736
# Validation Loss = 0.008
# Epoch = 3, batch = 800 of 4000, loss = 0.598, LR = 0.0009045084971874736
# Validation Loss = 2.940
# Epoch = 3, batch = 900 of 4000, loss = 2.877, LR = 0.0009045084971874736
# Validation Loss = 0.000
# Epoch = 3, batch = 1000 of 4000, loss = 0.546, LR = 0.0009045084971874736
# Validation Loss = 0.523
# Epoch = 3, batch = 1100 of 4000, loss = 1.069, LR = 0.0009045084971874736
# Validation Loss = 1.859
# Epoch = 3, batch = 1200 of 4000, loss = 2.001, LR = 0.0009045084971874736
# Validation Loss = 0.004
# Epoch = 3, batch = 1300 of 4000, loss = 0.575, LR = 0.0009045084971874736
# Validation Loss = 0.175
# Epoch = 3, batch = 1400 of 4000, loss = 0.669, LR = 0.0009045084971874736
# Validation Loss = 2.904
# Epoch = 3, batch = 1500 of 4000, loss = 3.001, LR = 0.0009045084971874736
# Validation Loss = 0.112
# Epoch = 3, batch = 1600 of 4000, loss = 0.662, LR = 0.0009045084971874736
# Validation Loss = 0.461
# Epoch = 3, batch = 1700 of 4000, loss = 0.966, LR = 0.0009045084971874736
# Validation Loss = 0.472
# Epoch = 3, batch = 1800 of 4000, loss = 0.937, LR = 0.0009045084971874736
# Validation Loss = 0.115
# Epoch = 3, batch = 1900 of 4000, loss = 0.624, LR = 0.0009045084971874736
# Validation Loss = 0.540
# Epoch = 3, batch = 2000 of 4000, loss = 0.994, LR = 0.0009045084971874736
# Validation Loss = 0.515
# Epoch = 3, batch = 2100 of 4000, loss = 1.150, LR = 0.0009045084971874736
# Validation Loss = 1.040
# Epoch = 3, batch = 2200 of 4000, loss = 1.375, LR = 0.0009045084971874736
# Validation Loss = 0.150
# Epoch = 3, batch = 2300 of 4000, loss = 0.739, LR = 0.0009045084971874736
# Validation Loss = 0.003
# Epoch = 3, batch = 2400 of 4000, loss = 0.614, LR = 0.0009045084971874736
# Validation Loss = 0.352
# Epoch = 3, batch = 2500 of 4000, loss = 0.672, LR = 0.0009045084971874736
# Validation Loss = 0.114
# Epoch = 3, batch = 2600 of 4000, loss = 0.659, LR = 0.0009045084971874736
# Validation Loss = 0.426
# Epoch = 3, batch = 2700 of 4000, loss = 0.909, LR = 0.0009045084971874736
# Validation Loss = 0.031
# Epoch = 3, batch = 2800 of 4000, loss = 0.585, LR = 0.0009045084971874736
# Validation Loss = 0.247
# Epoch = 3, batch = 2900 of 4000, loss = 0.734, LR = 0.0009045084971874736
# Validation Loss = 0.185
# Epoch = 3, batch = 3000 of 4000, loss = 0.734, LR = 0.0009045084971874736
# Validation Loss = 0.065
# Epoch = 3, batch = 3100 of 4000, loss = 0.587, LR = 0.0009045084971874736
# Validation Loss = 0.483
# Epoch = 3, batch = 3200 of 4000, loss = 0.967, LR = 0.0009045084971874736
# Validation Loss = 0.339
# Epoch = 3, batch = 3300 of 4000, loss = 0.649, LR = 0.0009045084971874736
# Validation Loss = 0.519
# Epoch = 3, batch = 3400 of 4000, loss = 1.106, LR = 0.0009045084971874736
# Validation Loss = 0.062
# Epoch = 3, batch = 3500 of 4000, loss = 0.586, LR = 0.0009045084971874736
# Validation Loss = 0.171
# Epoch = 3, batch = 3600 of 4000, loss = 0.702, LR = 0.0009045084971874736
# Validation Loss = 1.101
# Epoch = 3, batch = 3700 of 4000, loss = 1.929, LR = 0.0009045084971874736
# Validation Loss = 0.845
# Epoch = 3, batch = 3800 of 4000, loss = 1.123, LR = 0.0009045084971874736
# Validation Loss = 0.716
# Epoch = 3, batch = 3900 of 4000, loss = 1.064, LR = 0.0009045084971874736
# Validation Loss = 0.002
# Epoch = 4, batch = 0 of 4000, loss = 0.595, LR = 0.0007938926261462366
# Validation Loss = 0.151
# Epoch = 4, batch = 100 of 4000, loss = 0.678, LR = 0.0007938926261462366
# Validation Loss = 0.529
# Epoch = 4, batch = 200 of 4000, loss = 0.793, LR = 0.0007938926261462366
# Validation Loss = 0.168
# Epoch = 4, batch = 300 of 4000, loss = 0.851, LR = 0.0007938926261462366
# Validation Loss = 0.041
# Epoch = 4, batch = 400 of 4000, loss = 0.663, LR = 0.0007938926261462366
# Validation Loss = 0.695
# Epoch = 4, batch = 500 of 4000, loss = 1.368, LR = 0.0007938926261462366
# Validation Loss = 0.731
# Epoch = 4, batch = 600 of 4000, loss = 1.061, LR = 0.0007938926261462366
# Validation Loss = 0.465
# Epoch = 4, batch = 700 of 4000, loss = 0.909, LR = 0.0007938926261462366
# Validation Loss = 0.101
# Epoch = 4, batch = 800 of 4000, loss = 0.871, LR = 0.0007938926261462366
# Validation Loss = 0.020
# Epoch = 4, batch = 900 of 4000, loss = 0.573, LR = 0.0007938926261462366
# Validation Loss = 0.185
# Epoch = 4, batch = 1000 of 4000, loss = 0.772, LR = 0.0007938926261462366
# Validation Loss = 0.879
# Epoch = 4, batch = 1100 of 4000, loss = 1.327, LR = 0.0007938926261462366
# Validation Loss = 0.375
# Epoch = 4, batch = 1200 of 4000, loss = 0.977, LR = 0.0007938926261462366
# Validation Loss = 0.267
# Epoch = 4, batch = 1300 of 4000, loss = 0.754, LR = 0.0007938926261462366
# Validation Loss = 0.002
# Epoch = 4, batch = 1400 of 4000, loss = 0.636, LR = 0.0007938926261462366
# Validation Loss = 0.006
# Epoch = 4, batch = 1500 of 4000, loss = 0.576, LR = 0.0007938926261462366
# Validation Loss = 0.098
# Epoch = 4, batch = 1600 of 4000, loss = 0.558, LR = 0.0007938926261462366
# Validation Loss = 0.004
# Epoch = 4, batch = 1700 of 4000, loss = 0.584, LR = 0.0007938926261462366
# Validation Loss = 0.272
# Epoch = 4, batch = 1800 of 4000, loss = 0.647, LR = 0.0007938926261462366
# Validation Loss = 0.214
# Epoch = 4, batch = 1900 of 4000, loss = 0.638, LR = 0.0007938926261462366
# Validation Loss = 0.246
# Epoch = 4, batch = 2000 of 4000, loss = 0.748, LR = 0.0007938926261462366
# Validation Loss = 0.051
# Epoch = 4, batch = 2100 of 4000, loss = 0.599, LR = 0.0007938926261462366
# Validation Loss = 0.314
# Epoch = 4, batch = 2200 of 4000, loss = 0.980, LR = 0.0007938926261462366
# Validation Loss = 1.080
# Epoch = 4, batch = 2300 of 4000, loss = 1.491, LR = 0.0007938926261462366
# Validation Loss = 0.123
# Epoch = 4, batch = 2400 of 4000, loss = 0.950, LR = 0.0007938926261462366
# Validation Loss = 0.294
# Epoch = 4, batch = 2500 of 4000, loss = 0.594, LR = 0.0007938926261462366
# Validation Loss = 0.036
# Epoch = 4, batch = 2600 of 4000, loss = 0.537, LR = 0.0007938926261462366
# Validation Loss = 0.322
# Epoch = 4, batch = 2700 of 4000, loss = 0.709, LR = 0.0007938926261462366
# Validation Loss = 0.354
# Epoch = 4, batch = 2800 of 4000, loss = 0.728, LR = 0.0007938926261462366
# Validation Loss = 0.083
# Epoch = 4, batch = 2900 of 4000, loss = 0.722, LR = 0.0007938926261462366
# Validation Loss = 0.430
# Epoch = 4, batch = 3000 of 4000, loss = 1.026, LR = 0.0007938926261462366
# Validation Loss = 0.328
# Epoch = 4, batch = 3100 of 4000, loss = 0.789, LR = 0.0007938926261462366
# Validation Loss = 0.330
# Epoch = 4, batch = 3200 of 4000, loss = 0.924, LR = 0.0007938926261462366
# Validation Loss = 0.130
# Epoch = 4, batch = 3300 of 4000, loss = 0.622, LR = 0.0007938926261462366
# Validation Loss = 0.104
# Epoch = 4, batch = 3400 of 4000, loss = 0.667, LR = 0.0007938926261462366
# Validation Loss = 0.015
# Epoch = 4, batch = 3500 of 4000, loss = 0.567, LR = 0.0007938926261462366
# Validation Loss = 0.125
# Epoch = 4, batch = 3600 of 4000, loss = 0.735, LR = 0.0007938926261462366
# Validation Loss = 1.250
# Epoch = 4, batch = 3700 of 4000, loss = 1.945, LR = 0.0007938926261462366
# Validation Loss = 1.515
# Epoch = 4, batch = 3800 of 4000, loss = 2.397, LR = 0.0007938926261462366
# Validation Loss = 0.949
# Epoch = 4, batch = 3900 of 4000, loss = 1.182, LR = 0.0007938926261462366
# Validation Loss = 0.301
# Epoch = 5, batch = 0 of 4000, loss = 0.683, LR = 0.0006545084971874737
# Validation Loss = 0.092
# Epoch = 5, batch = 100 of 4000, loss = 0.586, LR = 0.0006545084971874737
# Validation Loss = 0.080
# Epoch = 5, batch = 200 of 4000, loss = 0.608, LR = 0.0006545084971874737
# Validation Loss = 0.017
# Epoch = 5, batch = 300 of 4000, loss = 1.326, LR = 0.0006545084971874737
# Validation Loss = 0.017
# Epoch = 5, batch = 400 of 4000, loss = 0.699, LR = 0.0006545084971874737
# Validation Loss = 0.314
# Epoch = 5, batch = 500 of 4000, loss = 1.064, LR = 0.0006545084971874737
# Validation Loss = 0.253
# Epoch = 5, batch = 600 of 4000, loss = 0.688, LR = 0.0006545084971874737
# Validation Loss = 0.000
# Epoch = 5, batch = 700 of 4000, loss = 0.598, LR = 0.0006545084971874737
# Validation Loss = 0.576
# Epoch = 5, batch = 800 of 4000, loss = 0.813, LR = 0.0006545084971874737
# Validation Loss = 0.000
# Epoch = 5, batch = 900 of 4000, loss = 0.842, LR = 0.0006545084971874737
# Validation Loss = 0.051
# Epoch = 5, batch = 1000 of 4000, loss = 0.697, LR = 0.0006545084971874737
# Validation Loss = 0.286
# Epoch = 5, batch = 1100 of 4000, loss = 1.148, LR = 0.0006545084971874737
# Validation Loss = 0.448
# Epoch = 5, batch = 1200 of 4000, loss = 0.805, LR = 0.0006545084971874737
# Validation Loss = 1.138
# Epoch = 5, batch = 1300 of 4000, loss = 1.315, LR = 0.0006545084971874737
# Validation Loss = 0.084
# Epoch = 5, batch = 1400 of 4000, loss = 0.604, LR = 0.0006545084971874737
# Validation Loss = 0.309
# Epoch = 5, batch = 1500 of 4000, loss = 0.804, LR = 0.0006545084971874737
# Validation Loss = 0.237
# Epoch = 5, batch = 1600 of 4000, loss = 0.793, LR = 0.0006545084971874737
# Validation Loss = 0.039
# Epoch = 5, batch = 1700 of 4000, loss = 0.607, LR = 0.0006545084971874737
# Validation Loss = 0.078
# Epoch = 5, batch = 1800 of 4000, loss = 0.760, LR = 0.0006545084971874737
# Validation Loss = 0.175
# Epoch = 5, batch = 1900 of 4000, loss = 0.714, LR = 0.0006545084971874737
# Validation Loss = 0.052
# Epoch = 5, batch = 2000 of 4000, loss = 0.655, LR = 0.0006545084971874737
# Validation Loss = 0.313
# Epoch = 5, batch = 2100 of 4000, loss = 0.715, LR = 0.0006545084971874737
# Validation Loss = 0.321
# Epoch = 5, batch = 2200 of 4000, loss = 0.638, LR = 0.0006545084971874737
# Validation Loss = 0.320
# Epoch = 5, batch = 2300 of 4000, loss = 0.673, LR = 0.0006545084971874737
# Validation Loss = 0.005
# Epoch = 5, batch = 2400 of 4000, loss = 0.641, LR = 0.0006545084971874737
# Validation Loss = 0.002
# Epoch = 5, batch = 2500 of 4000, loss = 0.608, LR = 0.0006545084971874737
# Validation Loss = 0.841
# Epoch = 5, batch = 2600 of 4000, loss = 1.729, LR = 0.0006545084971874737
# Validation Loss = 0.004
# Epoch = 5, batch = 2700 of 4000, loss = 0.559, LR = 0.0006545084971874737
# Validation Loss = 0.074
# Epoch = 5, batch = 2800 of 4000, loss = 0.699, LR = 0.0006545084971874737
# Validation Loss = 0.120
# Epoch = 5, batch = 2900 of 4000, loss = 0.632, LR = 0.0006545084971874737
# Validation Loss = 0.204
# Epoch = 5, batch = 3000 of 4000, loss = 0.676, LR = 0.0006545084971874737
# Validation Loss = 0.990
# Epoch = 5, batch = 3100 of 4000, loss = 1.491, LR = 0.0006545084971874737
# Validation Loss = 0.001
# Epoch = 5, batch = 3200 of 4000, loss = 0.593, LR = 0.0006545084971874737
# Validation Loss = 0.382
# Epoch = 5, batch = 3300 of 4000, loss = 0.932, LR = 0.0006545084971874737
# Validation Loss = 1.122
# Epoch = 5, batch = 3400 of 4000, loss = 1.180, LR = 0.0006545084971874737
# Validation Loss = 0.557
# Epoch = 5, batch = 3500 of 4000, loss = 0.893, LR = 0.0006545084971874737
# Validation Loss = 0.005
# Epoch = 5, batch = 3600 of 4000, loss = 0.695, LR = 0.0006545084971874737
# Validation Loss = 0.555
# Epoch = 5, batch = 3700 of 4000, loss = 1.078, LR = 0.0006545084971874737
# Validation Loss = 0.774
# Epoch = 5, batch = 3800 of 4000, loss = 1.090, LR = 0.0006545084971874737
# Validation Loss = 0.033
# Epoch = 5, batch = 3900 of 4000, loss = 0.670, LR = 0.0006545084971874737
# Validation Loss = 0.258
# Epoch = 6, batch = 0 of 4000, loss = 1.517, LR = 0.0005
# Validation Loss = 0.148
# Epoch = 6, batch = 100 of 4000, loss = 0.606, LR = 0.0005
# Validation Loss = 0.005
# Epoch = 6, batch = 200 of 4000, loss = 0.639, LR = 0.0005
# Validation Loss = 0.071
# Epoch = 6, batch = 300 of 4000, loss = 0.652, LR = 0.0005
# Validation Loss = 0.477
# Epoch = 6, batch = 400 of 4000, loss = 0.765, LR = 0.0005
# Validation Loss = 0.004
# Epoch = 6, batch = 500 of 4000, loss = 0.573, LR = 0.0005
# Validation Loss = 0.001
# Epoch = 6, batch = 600 of 4000, loss = 0.659, LR = 0.0005
# Validation Loss = 0.057
# Epoch = 6, batch = 700 of 4000, loss = 0.549, LR = 0.0005
# Validation Loss = 0.231
# Epoch = 6, batch = 800 of 4000, loss = 0.971, LR = 0.0005
# Validation Loss = 0.027
# Epoch = 6, batch = 900 of 4000, loss = 0.714, LR = 0.0005
# Validation Loss = 0.048
# Epoch = 6, batch = 1000 of 4000, loss = 0.543, LR = 0.0005
# Validation Loss = 0.131
# Epoch = 6, batch = 1100 of 4000, loss = 0.584, LR = 0.0005
# Validation Loss = 0.004
# Epoch = 6, batch = 1200 of 4000, loss = 0.489, LR = 0.0005
# Validation Loss = 0.039
# Epoch = 6, batch = 1300 of 4000, loss = 0.530, LR = 0.0005
# Validation Loss = 0.005
# Epoch = 6, batch = 1400 of 4000, loss = 0.567, LR = 0.0005
# Validation Loss = 0.265
# Epoch = 6, batch = 1500 of 4000, loss = 0.742, LR = 0.0005
# Validation Loss = 0.370
# Epoch = 6, batch = 1600 of 4000, loss = 0.797, LR = 0.0005
# Validation Loss = 0.516
# Epoch = 6, batch = 1700 of 4000, loss = 0.608, LR = 0.0005
# Validation Loss = 0.352
# Epoch = 6, batch = 1800 of 4000, loss = 1.107, LR = 0.0005
# Validation Loss = 0.000
# Epoch = 6, batch = 1900 of 4000, loss = 0.574, LR = 0.0005
# Validation Loss = 0.006
# Epoch = 6, batch = 2000 of 4000, loss = 0.617, LR = 0.0005
# Validation Loss = 0.005
# Epoch = 6, batch = 2100 of 4000, loss = 0.674, LR = 0.0005
# Validation Loss = 0.158
# Epoch = 6, batch = 2200 of 4000, loss = 0.610, LR = 0.0005
# Validation Loss = 0.025
# Epoch = 6, batch = 2300 of 4000, loss = 0.692, LR = 0.0005
# Validation Loss = 0.325
# Epoch = 6, batch = 2400 of 4000, loss = 0.594, LR = 0.0005
# Validation Loss = 0.003
# Epoch = 6, batch = 2500 of 4000, loss = 0.711, LR = 0.0005
# Validation Loss = 0.314
# Epoch = 6, batch = 2600 of 4000, loss = 0.615, LR = 0.0005
# Validation Loss = 0.180
# Epoch = 6, batch = 2700 of 4000, loss = 0.795, LR = 0.0005
# Validation Loss = 0.436
# Epoch = 6, batch = 2800 of 4000, loss = 0.719, LR = 0.0005
# Validation Loss = 0.065
# Epoch = 6, batch = 2900 of 4000, loss = 0.544, LR = 0.0005
# Validation Loss = 0.098
# Epoch = 6, batch = 3000 of 4000, loss = 0.648, LR = 0.0005
# Validation Loss = 0.004
# Epoch = 6, batch = 3100 of 4000, loss = 0.577, LR = 0.0005
# Validation Loss = 0.034
# Epoch = 6, batch = 3200 of 4000, loss = 0.540, LR = 0.0005
# Validation Loss = 0.255
# Epoch = 6, batch = 3300 of 4000, loss = 0.637, LR = 0.0005
# Validation Loss = 1.060
# Epoch = 6, batch = 3400 of 4000, loss = 1.041, LR = 0.0005
# Validation Loss = 0.310
# Epoch = 6, batch = 3500 of 4000, loss = 0.656, LR = 0.0005
# Validation Loss = 0.238
# Epoch = 6, batch = 3600 of 4000, loss = 0.610, LR = 0.0005
# Validation Loss = 0.364
# Epoch = 6, batch = 3700 of 4000, loss = 0.763, LR = 0.0005
# Validation Loss = 0.078
# Epoch = 6, batch = 3800 of 4000, loss = 0.638, LR = 0.0005
# Validation Loss = 0.002
# Epoch = 6, batch = 3900 of 4000, loss = 0.707, LR = 0.0005
# Validation Loss = 0.759
# Epoch = 7, batch = 0 of 4000, loss = 0.905, LR = 0.00034549150281252633
# Validation Loss = 0.047
# Epoch = 7, batch = 100 of 4000, loss = 0.607, LR = 0.00034549150281252633
# Validation Loss = 0.169
# Epoch = 7, batch = 200 of 4000, loss = 0.522, LR = 0.00034549150281252633
# Validation Loss = 0.040
# Epoch = 7, batch = 300 of 4000, loss = 0.652, LR = 0.00034549150281252633
# Validation Loss = 0.534
# Epoch = 7, batch = 400 of 4000, loss = 0.679, LR = 0.00034549150281252633
# Validation Loss = 0.038
# Epoch = 7, batch = 500 of 4000, loss = 0.583, LR = 0.00034549150281252633
# Validation Loss = 0.059
# Epoch = 7, batch = 600 of 4000, loss = 0.552, LR = 0.00034549150281252633
# Validation Loss = 0.159
# Epoch = 7, batch = 700 of 4000, loss = 0.564, LR = 0.00034549150281252633
# Validation Loss = 0.011
# Epoch = 7, batch = 800 of 4000, loss = 0.601, LR = 0.00034549150281252633
# Validation Loss = 0.509
# Epoch = 7, batch = 900 of 4000, loss = 0.687, LR = 0.00034549150281252633
# Validation Loss = 0.053
# Epoch = 7, batch = 1000 of 4000, loss = 0.577, LR = 0.00034549150281252633
# Validation Loss = 0.452
# Epoch = 7, batch = 1100 of 4000, loss = 0.661, LR = 0.00034549150281252633
# Validation Loss = 0.509
# Epoch = 7, batch = 1200 of 4000, loss = 0.731, LR = 0.00034549150281252633
# Validation Loss = 0.293
# Epoch = 7, batch = 1300 of 4000, loss = 0.570, LR = 0.00034549150281252633
# Validation Loss = 0.725
# Epoch = 7, batch = 1400 of 4000, loss = 0.686, LR = 0.00034549150281252633
# Validation Loss = 0.123
# Epoch = 7, batch = 1500 of 4000, loss = 0.598, LR = 0.00034549150281252633
# Validation Loss = 0.095
# Epoch = 7, batch = 1600 of 4000, loss = 0.583, LR = 0.00034549150281252633
# Validation Loss = 0.003
# Epoch = 7, batch = 1700 of 4000, loss = 0.676, LR = 0.00034549150281252633
# Validation Loss = 0.038
# Epoch = 7, batch = 1800 of 4000, loss = 0.585, LR = 0.00034549150281252633
# Validation Loss = 0.141
# Epoch = 7, batch = 1900 of 4000, loss = 0.577, LR = 0.00034549150281252633
# Validation Loss = 0.162
# Epoch = 7, batch = 2000 of 4000, loss = 0.566, LR = 0.00034549150281252633
# Validation Loss = 0.043
# Epoch = 7, batch = 2100 of 4000, loss = 0.606, LR = 0.00034549150281252633
# Validation Loss = 0.068
# Epoch = 7, batch = 2200 of 4000, loss = 0.573, LR = 0.00034549150281252633
# Validation Loss = 0.005
# Epoch = 7, batch = 2300 of 4000, loss = 0.615, LR = 0.00034549150281252633
# Validation Loss = 0.001
# Epoch = 7, batch = 2400 of 4000, loss = 0.644, LR = 0.00034549150281252633
# Validation Loss = 0.011
# Epoch = 7, batch = 2500 of 4000, loss = 0.666, LR = 0.00034549150281252633
# Validation Loss = 0.016
# Epoch = 7, batch = 2600 of 4000, loss = 0.707, LR = 0.00034549150281252633
# Validation Loss = 0.418
# Epoch = 7, batch = 2700 of 4000, loss = 0.545, LR = 0.00034549150281252633
# Validation Loss = 0.009
# Epoch = 7, batch = 2800 of 4000, loss = 0.558, LR = 0.00034549150281252633
# Validation Loss = 0.028
# Epoch = 7, batch = 2900 of 4000, loss = 0.578, LR = 0.00034549150281252633
# Validation Loss = 0.055
# Epoch = 7, batch = 3000 of 4000, loss = 0.559, LR = 0.00034549150281252633
# Validation Loss = 0.000
# Epoch = 7, batch = 3100 of 4000, loss = 0.648, LR = 0.00034549150281252633
# Validation Loss = 0.012
# Epoch = 7, batch = 3200 of 4000, loss = 0.827, LR = 0.00034549150281252633
# Validation Loss = 0.009
# Epoch = 7, batch = 3300 of 4000, loss = 0.707, LR = 0.00034549150281252633
# Validation Loss = 0.343
# Epoch = 7, batch = 3400 of 4000, loss = 0.624, LR = 0.00034549150281252633
# Validation Loss = 0.088
# Epoch = 7, batch = 3500 of 4000, loss = 0.583, LR = 0.00034549150281252633
# Validation Loss = 0.060
# Epoch = 7, batch = 3600 of 4000, loss = 0.549, LR = 0.00034549150281252633
# Validation Loss = 0.414
# Epoch = 7, batch = 3700 of 4000, loss = 0.600, LR = 0.00034549150281252633
# Validation Loss = 0.092
# Epoch = 7, batch = 3800 of 4000, loss = 0.601, LR = 0.00034549150281252633
# Validation Loss = 0.159
# Epoch = 7, batch = 3900 of 4000, loss = 0.601, LR = 0.00034549150281252633
# Validation Loss = 0.001
# Epoch = 8, batch = 0 of 4000, loss = 0.552, LR = 0.0002061073738537635
# Validation Loss = 0.143
# Epoch = 8, batch = 100 of 4000, loss = 0.616, LR = 0.0002061073738537635
# Validation Loss = 0.243
# Epoch = 8, batch = 200 of 4000, loss = 0.577, LR = 0.0002061073738537635
# Validation Loss = 0.023
# Epoch = 8, batch = 300 of 4000, loss = 0.592, LR = 0.0002061073738537635
# Validation Loss = 0.291
# Epoch = 8, batch = 400 of 4000, loss = 0.572, LR = 0.0002061073738537635
# Validation Loss = 0.103
# Epoch = 8, batch = 500 of 4000, loss = 0.546, LR = 0.0002061073738537635
# Validation Loss = 0.204
# Epoch = 8, batch = 600 of 4000, loss = 0.580, LR = 0.0002061073738537635
# Validation Loss = 0.034
# Epoch = 8, batch = 700 of 4000, loss = 0.585, LR = 0.0002061073738537635
# Validation Loss = 0.186
# Epoch = 8, batch = 800 of 4000, loss = 0.597, LR = 0.0002061073738537635
# Validation Loss = 0.181
# Epoch = 8, batch = 900 of 4000, loss = 0.607, LR = 0.0002061073738537635
# Validation Loss = 0.104
# Epoch = 8, batch = 1000 of 4000, loss = 0.563, LR = 0.0002061073738537635
# Validation Loss = 0.015
# Epoch = 8, batch = 1100 of 4000, loss = 0.592, LR = 0.0002061073738537635
# Validation Loss = 0.000
# Epoch = 8, batch = 1200 of 4000, loss = 0.601, LR = 0.0002061073738537635
# Validation Loss = 0.255
# Epoch = 8, batch = 1300 of 4000, loss = 0.590, LR = 0.0002061073738537635
# Validation Loss = 0.039
# Epoch = 8, batch = 1400 of 4000, loss = 0.591, LR = 0.0002061073738537635
# Validation Loss = 0.024
# Epoch = 8, batch = 1500 of 4000, loss = 0.608, LR = 0.0002061073738537635
# Validation Loss = 0.320
# Epoch = 8, batch = 1600 of 4000, loss = 0.663, LR = 0.0002061073738537635
# Validation Loss = 0.254
# Epoch = 8, batch = 1700 of 4000, loss = 0.564, LR = 0.0002061073738537635
# Validation Loss = 0.411
# Epoch = 8, batch = 1800 of 4000, loss = 0.593, LR = 0.0002061073738537635
# Validation Loss = 0.184
# Epoch = 8, batch = 1900 of 4000, loss = 0.807, LR = 0.0002061073738537635
# Validation Loss = 0.221
# Epoch = 8, batch = 2000 of 4000, loss = 0.578, LR = 0.0002061073738537635
# Validation Loss = 0.163
# Epoch = 8, batch = 2100 of 4000, loss = 0.573, LR = 0.0002061073738537635
# Validation Loss = 0.192
# Epoch = 8, batch = 2200 of 4000, loss = 0.572, LR = 0.0002061073738537635
# Validation Loss = 0.002
# Epoch = 8, batch = 2300 of 4000, loss = 0.559, LR = 0.0002061073738537635
# Validation Loss = 0.124
# Epoch = 8, batch = 2400 of 4000, loss = 0.588, LR = 0.0002061073738537635
# Validation Loss = 0.033
# Epoch = 8, batch = 2500 of 4000, loss = 0.534, LR = 0.0002061073738537635
# Validation Loss = 0.039
# Epoch = 8, batch = 2600 of 4000, loss = 0.597, LR = 0.0002061073738537635
# Validation Loss = 0.282
# Epoch = 8, batch = 2700 of 4000, loss = 0.600, LR = 0.0002061073738537635
# Validation Loss = 0.067
# Epoch = 8, batch = 2800 of 4000, loss = 0.512, LR = 0.0002061073738537635
# Validation Loss = 0.385
# ...
# Epoch = 12, batch = 0 of 4000, loss = 1.356, LR = 0.0004217827674798847
# Validation Loss = 0.494
# Epoch = 12, batch = 100 of 4000, loss = 1.072, LR = 0.0004217827674798847
# Validation Loss = 0.431
# Epoch = 12, batch = 200 of 4000, loss = 1.095, LR = 0.0004217827674798847
# Validation Loss = 1.525
# Epoch = 12, batch = 300 of 4000, loss = 1.088, LR = 0.0004217827674798847
# Validation Loss = 0.148
# Epoch = 12, batch = 400 of 4000, loss = 1.290, LR = 0.0004217827674798847
# Validation Loss = 0.407
# Epoch = 12, batch = 500 of 4000, loss = 0.922, LR = 0.0004217827674798847
# Validation Loss = 1.562
# Epoch = 12, batch = 600 of 4000, loss = 0.982, LR = 0.0004217827674798847
# Validation Loss = 2.165
# Epoch = 12, batch = 700 of 4000, loss = 1.080, LR = 0.0004217827674798847
# Validation Loss = 1.237
# Epoch = 12, batch = 800 of 4000, loss = 0.919, LR = 0.0004217827674798847
# Validation Loss = 1.823
# Epoch = 12, batch = 900 of 4000, loss = 1.193, LR = 0.0004217827674798847
# Validation Loss = 0.763
# Epoch = 12, batch = 1000 of 4000, loss = 0.993, LR = 0.0004217827674798847
# Validation Loss = 1.427
# Epoch = 12, batch = 1100 of 4000, loss = 1.054, LR = 0.0004217827674798847
# Validation Loss = 0.370
# Epoch = 12, batch = 1200 of 4000, loss = 1.087, LR = 0.0004217827674798847
# Validation Loss = 2.081
# Epoch = 12, batch = 1300 of 4000, loss = 1.089, LR = 0.0004217827674798847
# Validation Loss = 0.250
# Epoch = 12, batch = 1400 of 4000, loss = 1.210, LR = 0.0004217827674798847
# Validation Loss = 1.231
# Epoch = 12, batch = 1500 of 4000, loss = 1.031, LR = 0.0004217827674798847
# Validation Loss = 1.237
# Epoch = 12, batch = 1600 of 4000, loss = 0.862, LR = 0.0004217827674798847
# Validation Loss = 0.432
# Epoch = 12, batch = 1700 of 4000, loss = 1.176, LR = 0.0004217827674798847
# Validation Loss = 0.798
# Epoch = 12, batch = 1800 of 4000, loss = 0.879, LR = 0.0004217827674798847
# Validation Loss = 0.717
# Epoch = 12, batch = 1900 of 4000, loss = 0.988, LR = 0.0004217827674798847
# Validation Loss = 1.399
# Epoch = 12, batch = 2000 of 4000, loss = 0.905, LR = 0.0004217827674798847
# Validation Loss = 0.304
# Epoch = 12, batch = 2100 of 4000, loss = 1.161, LR = 0.0004217827674798847
# Validation Loss = 1.320
# Epoch = 12, batch = 2200 of 4000, loss = 0.909, LR = 0.0004217827674798847
# Validation Loss = 1.612
# Epoch = 12, batch = 2300 of 4000, loss = 0.930, LR = 0.0004217827674798847
# Validation Loss = 0.835
# Epoch = 12, batch = 2400 of 4000, loss = 0.935, LR = 0.0004217827674798847
# Validation Loss = 0.969
# Epoch = 12, batch = 2500 of 4000, loss = 0.985, LR = 0.0004217827674798847
# Validation Loss = 0.739
# Epoch = 12, batch = 2600 of 4000, loss = 1.104, LR = 0.0004217827674798847
# Validation Loss = 1.270
# Epoch = 12, batch = 2700 of 4000, loss = 1.123, LR = 0.0004217827674798847
# Validation Loss = 1.234
# Epoch = 12, batch = 2800 of 4000, loss = 0.910, LR = 0.0004217827674798847
# Validation Loss = 5.382
# Epoch = 12, batch = 2900 of 4000, loss = 2.291, LR = 0.0004217827674798847
# Validation Loss = 1.406
# Epoch = 12, batch = 3000 of 4000, loss = 1.051, LR = 0.0004217827674798847
# Validation Loss = 0.602
# Epoch = 12, batch = 3100 of 4000, loss = 1.136, LR = 0.0004217827674798847
# Validation Loss = 1.552
# Epoch = 12, batch = 3200 of 4000, loss = 1.008, LR = 0.0004217827674798847
# Validation Loss = 0.404
# Epoch = 12, batch = 3300 of 4000, loss = 1.103, LR = 0.0004217827674798847
# Validation Loss = 2.156
# Epoch = 12, batch = 3400 of 4000, loss = 1.225, LR = 0.0004217827674798847
# Validation Loss = 3.399
# Epoch = 12, batch = 3500 of 4000, loss = 1.679, LR = 0.0004217827674798847
# Validation Loss = 0.904
# Epoch = 12, batch = 3600 of 4000, loss = 0.965, LR = 0.0004217827674798847
# Validation Loss = 0.219
# Epoch = 12, batch = 3700 of 4000, loss = 0.998, LR = 0.0004217827674798847
# Validation Loss = 1.125
# Epoch = 12, batch = 3800 of 4000, loss = 0.899, LR = 0.0004217827674798847
# Validation Loss = 2.300
# Epoch = 12, batch = 3900 of 4000, loss = 1.113, LR = 0.0004217827674798847
# Validation Loss = 1.920
# Epoch = 13, batch = 0 of 4000, loss = 1.014, LR = 0.00034549150281252633
# Validation Loss = 1.164
# Epoch = 13, batch = 100 of 4000, loss = 0.910, LR = 0.00034549150281252633
# Validation Loss = 1.105
# Epoch = 13, batch = 200 of 4000, loss = 0.991, LR = 0.00034549150281252633
# Validation Loss = 0.867
# Epoch = 13, batch = 300 of 4000, loss = 0.946, LR = 0.00034549150281252633
# Validation Loss = 1.711
# Epoch = 13, batch = 400 of 4000, loss = 1.075, LR = 0.00034549150281252633
# Validation Loss = 0.645
# Epoch = 13, batch = 500 of 4000, loss = 1.001, LR = 0.00034549150281252633
# Validation Loss = 2.297
# Epoch = 13, batch = 600 of 4000, loss = 1.341, LR = 0.00034549150281252633
# Validation Loss = 0.849
# Epoch = 13, batch = 700 of 4000, loss = 0.928, LR = 0.00034549150281252633
# Validation Loss = 1.311
# Epoch = 13, batch = 800 of 4000, loss = 1.080, LR = 0.00034549150281252633
# Validation Loss = 1.770
# Epoch = 13, batch = 900 of 4000, loss = 1.314, LR = 0.00034549150281252633
# Validation Loss = 2.317
# Epoch = 13, batch = 1000 of 4000, loss = 1.112, LR = 0.00034549150281252633
# Validation Loss = 0.662
# Epoch = 13, batch = 1100 of 4000, loss = 0.900, LR = 0.00034549150281252633
# Validation Loss = 0.811
# Epoch = 13, batch = 1200 of 4000, loss = 0.964, LR = 0.00034549150281252633
# Validation Loss = 1.274
# Epoch = 13, batch = 1300 of 4000, loss = 0.892, LR = 0.00034549150281252633
# Validation Loss = 1.407
# Epoch = 13, batch = 1400 of 4000, loss = 0.987, LR = 0.00034549150281252633
# Validation Loss = 1.725
# Epoch = 13, batch = 1500 of 4000, loss = 1.008, LR = 0.00034549150281252633
# Validation Loss = 0.069
# Epoch = 13, batch = 1600 of 4000, loss = 1.572, LR = 0.00034549150281252633
# Validation Loss = 0.962
# Epoch = 13, batch = 1700 of 4000, loss = 0.855, LR = 0.00034549150281252633
# Validation Loss = 0.873
# Epoch = 13, batch = 1800 of 4000, loss = 1.050, LR = 0.00034549150281252633
# Validation Loss = 0.996
# Epoch = 13, batch = 1900 of 4000, loss = 0.923, LR = 0.00034549150281252633
# Validation Loss = 1.893
# Epoch = 13, batch = 2000 of 4000, loss = 1.284, LR = 0.00034549150281252633
# Validation Loss = 1.034
# Epoch = 13, batch = 2100 of 4000, loss = 1.159, LR = 0.00034549150281252633
# Validation Loss = 1.696
# Epoch = 13, batch = 2200 of 4000, loss = 1.016, LR = 0.00034549150281252633
# Validation Loss = 2.910
# Epoch = 13, batch = 2300 of 4000, loss = 1.439, LR = 0.00034549150281252633
# Validation Loss = 0.576
# Epoch = 13, batch = 2400 of 4000, loss = 0.997, LR = 0.00034549150281252633
# Validation Loss = 0.514
# Epoch = 13, batch = 2500 of 4000, loss = 1.077, LR = 0.00034549150281252633
# Validation Loss = 1.125
# Epoch = 13, batch = 2600 of 4000, loss = 0.890, LR = 0.00034549150281252633
# Validation Loss = 0.631
# Epoch = 13, batch = 2700 of 4000, loss = 1.007, LR = 0.00034549150281252633
# Validation Loss = 1.913
# Epoch = 13, batch = 2800 of 4000, loss = 0.838, LR = 0.00034549150281252633
# Validation Loss = 0.645
# Epoch = 13, batch = 2900 of 4000, loss = 1.087, LR = 0.00034549150281252633
# Validation Loss = 1.018
# Epoch = 13, batch = 3000 of 4000, loss = 0.895, LR = 0.00034549150281252633
# Validation Loss = 0.469
# Epoch = 13, batch = 3100 of 4000, loss = 1.023, LR = 0.00034549150281252633
# Validation Loss = 2.537
# Epoch = 13, batch = 3200 of 4000, loss = 1.262, LR = 0.00034549150281252633
# Validation Loss = 0.319
# Epoch = 13, batch = 3300 of 4000, loss = 1.139, LR = 0.00034549150281252633
# Validation Loss = 0.883
# Epoch = 13, batch = 3400 of 4000, loss = 0.823, LR = 0.00034549150281252633
# Validation Loss = 0.891
# Epoch = 13, batch = 3500 of 4000, loss = 0.946, LR = 0.00034549150281252633
# Validation Loss = 0.498
# Epoch = 13, batch = 3600 of 4000, loss = 1.091, LR = 0.00034549150281252633
# Validation Loss = 1.115
# Epoch = 13, batch = 3700 of 4000, loss = 1.171, LR = 0.00034549150281252633
# Validation Loss = 1.767
# Epoch = 13, batch = 3800 of 4000, loss = 1.118, LR = 0.00034549150281252633
# Validation Loss = 0.938
# Epoch = 13, batch = 3900 of 4000, loss = 0.984, LR = 0.00034549150281252633
# Validation Loss = 2.224
# Epoch = 14, batch = 0 of 4000, loss = 1.183, LR = 0.00027300475013022663
# Validation Loss = 1.140
# Epoch = 14, batch = 100 of 4000, loss = 0.923, LR = 0.00027300475013022663
# Validation Loss = 1.090
# Epoch = 14, batch = 200 of 4000, loss = 1.013, LR = 0.00027300475013022663
# Validation Loss = 1.278
# Epoch = 14, batch = 300 of 4000, loss = 0.921, LR = 0.00027300475013022663
# Validation Loss = 1.045
# Epoch = 14, batch = 400 of 4000, loss = 0.944, LR = 0.00027300475013022663
# Validation Loss = 1.027
# Epoch = 14, batch = 500 of 4000, loss = 0.969, LR = 0.00027300475013022663
# Validation Loss = 0.861
# Epoch = 14, batch = 600 of 4000, loss = 0.937, LR = 0.00027300475013022663
# Validation Loss = 0.931
# Epoch = 14, batch = 700 of 4000, loss = 1.090, LR = 0.00027300475013022663
# Validation Loss = 0.644
# Epoch = 14, batch = 800 of 4000, loss = 0.927, LR = 0.00027300475013022663
# Validation Loss = 1.411
# Epoch = 14, batch = 900 of 4000, loss = 0.901, LR = 0.00027300475013022663
# Validation Loss = 2.082
# Epoch = 14, batch = 1000 of 4000, loss = 0.990, LR = 0.00027300475013022663
# Validation Loss = 0.923
# Epoch = 14, batch = 1100 of 4000, loss = 1.017, LR = 0.00027300475013022663
# Validation Loss = 1.600
# Epoch = 14, batch = 1200 of 4000, loss = 0.907, LR = 0.00027300475013022663
# Validation Loss = 1.245
# Epoch = 14, batch = 1300 of 4000, loss = 0.880, LR = 0.00027300475013022663
# Validation Loss = 0.600
# Epoch = 14, batch = 1400 of 4000, loss = 0.911, LR = 0.00027300475013022663
# Validation Loss = 0.538
# Epoch = 14, batch = 1500 of 4000, loss = 1.047, LR = 0.00027300475013022663
# Validation Loss = 0.930
# Epoch = 14, batch = 1600 of 4000, loss = 0.881, LR = 0.00027300475013022663
# Validation Loss = 1.258
# Epoch = 14, batch = 1700 of 4000, loss = 1.066, LR = 0.00027300475013022663
# Validation Loss = 1.471
# Epoch = 14, batch = 1800 of 4000, loss = 0.957, LR = 0.00027300475013022663
# Validation Loss = 0.805
# Epoch = 14, batch = 1900 of 4000, loss = 1.056, LR = 0.00027300475013022663
# Validation Loss = 1.657
# Epoch = 14, batch = 2000 of 4000, loss = 1.107, LR = 0.00027300475013022663
# Validation Loss = 1.848
# Epoch = 14, batch = 2100 of 4000, loss = 1.012, LR = 0.00027300475013022663
# Validation Loss = 0.820
# Epoch = 14, batch = 2200 of 4000, loss = 0.963, LR = 0.00027300475013022663
# Validation Loss = 0.914
# Epoch = 14, batch = 2300 of 4000, loss = 0.891, LR = 0.00027300475013022663
# Validation Loss = 1.196
# Epoch = 14, batch = 2400 of 4000, loss = 1.024, LR = 0.00027300475013022663
# Validation Loss = 1.679
# Epoch = 14, batch = 2500 of 4000, loss = 1.021, LR = 0.00027300475013022663
# Validation Loss = 0.317
# Epoch = 14, batch = 2600 of 4000, loss = 1.344, LR = 0.00027300475013022663
# Validation Loss = 1.106
# Epoch = 14, batch = 2700 of 4000, loss = 0.894, LR = 0.00027300475013022663
# Validation Loss = 1.119
# Epoch = 14, batch = 2800 of 4000, loss = 0.935, LR = 0.00027300475013022663
# Validation Loss = 2.917
# Epoch = 14, batch = 2900 of 4000, loss = 1.228, LR = 0.00027300475013022663
# Validation Loss = 0.897
# Epoch = 14, batch = 3000 of 4000, loss = 1.013, LR = 0.00027300475013022663
# Validation Loss = 2.062
# Epoch = 14, batch = 3100 of 4000, loss = 1.245, LR = 0.00027300475013022663
# Validation Loss = 1.819
# Epoch = 14, batch = 3200 of 4000, loss = 1.029, LR = 0.00027300475013022663
# Validation Loss = 0.234
# Epoch = 14, batch = 3300 of 4000, loss = 1.386, LR = 0.00027300475013022663
# Validation Loss = 1.342
# Epoch = 14, batch = 3400 of 4000, loss = 0.873, LR = 0.00027300475013022663
# Validation Loss = 1.495
# Epoch = 14, batch = 3500 of 4000, loss = 0.997, LR = 0.00027300475013022663
# Validation Loss = 1.660
# Epoch = 14, batch = 3600 of 4000, loss = 1.032, LR = 0.00027300475013022663
# Validation Loss = 1.073
# Epoch = 14, batch = 3700 of 4000, loss = 1.002, LR = 0.00027300475013022663
# Validation Loss = 1.582
# Epoch = 14, batch = 3800 of 4000, loss = 0.879, LR = 0.00027300475013022663
# Validation Loss = 1.375
# Epoch = 14, batch = 3900 of 4000, loss = 0.882, LR = 0.00027300475013022663
# Validation Loss = 1.656
# Epoch = 15, batch = 0 of 4000, loss = 1.030, LR = 0.00020610737385376348
# Validation Loss = 0.843
# Epoch = 15, batch = 100 of 4000, loss = 0.922, LR = 0.00020610737385376348
# Validation Loss = 1.326
# Epoch = 15, batch = 200 of 4000, loss = 0.799, LR = 0.00020610737385376348
# Validation Loss = 1.789
# Epoch = 15, batch = 300 of 4000, loss = 0.937, LR = 0.00020610737385376348
# Validation Loss = 0.518
# Epoch = 15, batch = 400 of 4000, loss = 0.942, LR = 0.00020610737385376348
# Validation Loss = 0.916
# Epoch = 15, batch = 500 of 4000, loss = 0.946, LR = 0.00020610737385376348
# Validation Loss = 1.186
# Epoch = 15, batch = 600 of 4000, loss = 0.924, LR = 0.00020610737385376348
# Validation Loss = 1.220
# Epoch = 15, batch = 700 of 4000, loss = 0.989, LR = 0.00020610737385376348
# Validation Loss = 0.674
# Epoch = 15, batch = 800 of 4000, loss = 0.951, LR = 0.00020610737385376348
# Validation Loss = 1.015
# Epoch = 15, batch = 900 of 4000, loss = 0.820, LR = 0.00020610737385376348
# Validation Loss = 0.814
# Epoch = 15, batch = 1000 of 4000, loss = 0.942, LR = 0.00020610737385376348
# Validation Loss = 1.757
# Epoch = 15, batch = 1100 of 4000, loss = 0.950, LR = 0.00020610737385376348
# Validation Loss = 1.166
# Epoch = 15, batch = 1200 of 4000, loss = 0.934, LR = 0.00020610737385376348
# Validation Loss = 0.972
# Epoch = 15, batch = 1300 of 4000, loss = 0.880, LR = 0.00020610737385376348
# Validation Loss = 1.687
# Epoch = 15, batch = 1400 of 4000, loss = 1.049, LR = 0.00020610737385376348
# Validation Loss = 0.947
# Epoch = 15, batch = 1500 of 4000, loss = 0.913, LR = 0.00020610737385376348
# Validation Loss = 1.751
# Epoch = 15, batch = 1600 of 4000, loss = 0.964, LR = 0.00020610737385376348
# Validation Loss = 1.054
# Epoch = 15, batch = 1700 of 4000, loss = 0.861, LR = 0.00020610737385376348
# Validation Loss = 1.432
# Epoch = 15, batch = 1800 of 4000, loss = 0.942, LR = 0.00020610737385376348
# Validation Loss = 0.453
# Epoch = 15, batch = 1900 of 4000, loss = 1.199, LR = 0.00020610737385376348
# Validation Loss = 0.756
# Epoch = 15, batch = 2000 of 4000, loss = 1.014, LR = 0.00020610737385376348
# Validation Loss = 0.694
# Epoch = 15, batch = 2100 of 4000, loss = 1.032, LR = 0.00020610737385376348
# Validation Loss = 0.830
# Epoch = 15, batch = 2200 of 4000, loss = 1.025, LR = 0.00020610737385376348
# Validation Loss = 1.841
# Epoch = 15, batch = 2300 of 4000, loss = 1.044, LR = 0.00020610737385376348
# Validation Loss = 0.934
# Epoch = 15, batch = 2400 of 4000, loss = 1.031, LR = 0.00020610737385376348
# Validation Loss = 0.765
# Epoch = 15, batch = 2500 of 4000, loss = 1.172, LR = 0.00020610737385376348
# Validation Loss = 1.044
# Epoch = 15, batch = 2600 of 4000, loss = 0.951, LR = 0.00020610737385376348
# Validation Loss = 1.069
# Epoch = 15, batch = 2700 of 4000, loss = 0.957, LR = 0.00020610737385376348
# Validation Loss = 1.104
# Epoch = 15, batch = 2800 of 4000, loss = 1.037, LR = 0.00020610737385376348
# Validation Loss = 1.579
# Epoch = 15, batch = 2900 of 4000, loss = 0.885, LR = 0.00020610737385376348
# Validation Loss = 1.620
# Epoch = 15, batch = 3000 of 4000, loss = 1.050, LR = 0.00020610737385376348
# Validation Loss = 1.693
# Epoch = 15, batch = 3100 of 4000, loss = 0.964, LR = 0.00020610737385376348
# Validation Loss = 1.334
# Epoch = 15, batch = 3200 of 4000, loss = 0.892, LR = 0.00020610737385376348
# Validation Loss = 1.258
# Epoch = 15, batch = 3300 of 4000, loss = 0.947, LR = 0.00020610737385376348
# Validation Loss = 1.068
# Epoch = 15, batch = 3400 of 4000, loss = 0.928, LR = 0.00020610737385376348
# Validation Loss = 0.530
# Epoch = 15, batch = 3500 of 4000, loss = 0.961, LR = 0.00020610737385376348
# Validation Loss = 1.120
# Epoch = 15, batch = 3600 of 4000, loss = 0.915, LR = 0.00020610737385376348
# Validation Loss = 1.634
# Epoch = 15, batch = 3700 of 4000, loss = 0.991, LR = 0.00020610737385376348
# Validation Loss = 1.418
# Epoch = 15, batch = 3800 of 4000, loss = 1.016, LR = 0.00020610737385376348
# Validation Loss = 0.980
# Epoch = 15, batch = 3900 of 4000, loss = 0.971, LR = 0.00020610737385376348
# Validation Loss = 1.078
# Epoch = 16, batch = 0 of 4000, loss = 0.993, LR = 0.00014644660940672625

# %%
#General parameters:
nchans = 9
batch_size = 1000
input_size = nchans - 1 + 1 #Remaining channels + surface type
hidden_size = 256
output_size = 1

# %%
'''

SSMI CHANNEL PREDICTION MODEL:
    2: Non-Ocean Surfaces

'''

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = sfctype > 1

    Tbs = f.Tbs.values[correct_sfc,:]
    sfctype = sfctype[correct_sfc]

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

sfctype_train = sfctype[train_indcs].astype(np.float32)
sfctype_test  = sfctype[test_indcs].astype(np.float32)
sfctype_val   = sfctype[val_indcs].astype(np.float32)

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train, shuffled_indcs = array_funcs.shuffle_data(Tbs_train, axis=0, return_indcs=True)
sfctype_train = sfctype_train[shuffled_indcs]

# %%
sfctype_train, sfctype_test, sfctype_val
# Out:
# (array([ 2.,  5., 13., ...,  2., 11., 15.], shape=(7748290,), dtype=float32),
#  array([ 8.,  8.,  8., ..., 11., 11., 11.], shape=(968536,), dtype=float32),
#  array([11., 11., 11., ..., 11., 11., 11.], shape=(968537,), dtype=float32))

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)

    x_train = np.concatenate((x_train, sfctype_train[:,None]), axis=1)
    x_test  = np.concatenate((x_test,  sfctype_test[:,None]), axis=1)
    x_val   = np.concatenate((x_val,   sfctype_val[:,None]), axis=1)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_nonocean.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_nonocean.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# Training stage: 1
# Validation Loss = 52840.531
# Epoch = 1, batch = 0 of 7748, loss = 66195.156, LR = 0.001
# Validation Loss = 32.030
# Epoch = 1, batch = 100 of 7748, loss = 58.996, LR = 0.001
# Validation Loss = 11.092
# Epoch = 1, batch = 200 of 7748, loss = 19.572, LR = 0.001
# Validation Loss = 0.913
# Epoch = 1, batch = 300 of 7748, loss = 12.254, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 400 of 7748, loss = 10.749, LR = 0.001
# Validation Loss = 0.001
# Epoch = 1, batch = 500 of 7748, loss = 9.786, LR = 0.001
# Validation Loss = 0.304
# Epoch = 1, batch = 600 of 7748, loss = 7.696, LR = 0.001
# Validation Loss = 0.778
# Epoch = 1, batch = 700 of 7748, loss = 6.814, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 800 of 7748, loss = 7.085, LR = 0.001
# Validation Loss = 1.040
# Epoch = 1, batch = 900 of 7748, loss = 6.616, LR = 0.001
# Validation Loss = 0.028
# Epoch = 1, batch = 1000 of 7748, loss = 5.839, LR = 0.001
# Validation Loss = 0.016
# Epoch = 1, batch = 1100 of 7748, loss = 5.947, LR = 0.001
# Validation Loss = 0.264
# Epoch = 1, batch = 1200 of 7748, loss = 5.343, LR = 0.001
# Validation Loss = 0.736
# Epoch = 1, batch = 1300 of 7748, loss = 5.272, LR = 0.001
# Validation Loss = 0.387
# Epoch = 1, batch = 1400 of 7748, loss = 4.970, LR = 0.001
# Validation Loss = 0.002
# Epoch = 1, batch = 1500 of 7748, loss = 4.708, LR = 0.001
# Validation Loss = 1.458
# Epoch = 1, batch = 1600 of 7748, loss = 4.866, LR = 0.001
# Validation Loss = 0.589
# Epoch = 1, batch = 1700 of 7748, loss = 5.180, LR = 0.001
# Validation Loss = 2.698
# Epoch = 1, batch = 1800 of 7748, loss = 5.136, LR = 0.001
# Validation Loss = 4.360
# Epoch = 1, batch = 1900 of 7748, loss = 5.237, LR = 0.001
# Validation Loss = 2.076
# Epoch = 1, batch = 2000 of 7748, loss = 4.662, LR = 0.001
# Validation Loss = 3.005
# Epoch = 1, batch = 2100 of 7748, loss = 4.745, LR = 0.001
# Validation Loss = 1.724
# Epoch = 1, batch = 2200 of 7748, loss = 3.833, LR = 0.001
# Validation Loss = 4.143
# Epoch = 1, batch = 2300 of 7748, loss = 4.229, LR = 0.001
# Validation Loss = 2.238
# Epoch = 1, batch = 2400 of 7748, loss = 3.093, LR = 0.001
# Validation Loss = 6.191
# Epoch = 1, batch = 2500 of 7748, loss = 5.072, LR = 0.001
# Validation Loss = 0.361
# Epoch = 1, batch = 2600 of 7748, loss = 4.109, LR = 0.001
# Validation Loss = 4.944
# Epoch = 1, batch = 2700 of 7748, loss = 4.771, LR = 0.001
# Validation Loss = 2.243
# Epoch = 1, batch = 2800 of 7748, loss = 4.056, LR = 0.001
# Validation Loss = 1.198
# Epoch = 1, batch = 2900 of 7748, loss = 4.232, LR = 0.001
# Validation Loss = 0.245
# Epoch = 1, batch = 3000 of 7748, loss = 4.791, LR = 0.001
# Validation Loss = 3.844
# Epoch = 1, batch = 3100 of 7748, loss = 4.147, LR = 0.001
# Validation Loss = 1.010
# Epoch = 1, batch = 3200 of 7748, loss = 4.073, LR = 0.001
# Validation Loss = 3.278
# Epoch = 1, batch = 3300 of 7748, loss = 3.747, LR = 0.001
# Validation Loss = 0.203
# Epoch = 1, batch = 3400 of 7748, loss = 5.026, LR = 0.001
# Validation Loss = 1.116
# Epoch = 1, batch = 3500 of 7748, loss = 3.989, LR = 0.001
# Validation Loss = 9.287
# Epoch = 1, batch = 3600 of 7748, loss = 6.063, LR = 0.001
# Validation Loss = 1.159
# Epoch = 1, batch = 3700 of 7748, loss = 3.971, LR = 0.001
# Validation Loss = 4.631
# Epoch = 1, batch = 3800 of 7748, loss = 3.655, LR = 0.001
# Validation Loss = 4.014
# Epoch = 1, batch = 3900 of 7748, loss = 3.600, LR = 0.001
# Validation Loss = 4.240
# Epoch = 1, batch = 4000 of 7748, loss = 4.001, LR = 0.001
# Validation Loss = 12.290
# Epoch = 1, batch = 4100 of 7748, loss = 7.466, LR = 0.001
# Validation Loss = 0.435
# Epoch = 1, batch = 4200 of 7748, loss = 4.139, LR = 0.001
# Validation Loss = 7.028
# Epoch = 1, batch = 4300 of 7748, loss = 4.233, LR = 0.001
# Validation Loss = 9.230
# Epoch = 1, batch = 4400 of 7748, loss = 6.185, LR = 0.001
# Validation Loss = 0.128
# Epoch = 1, batch = 4500 of 7748, loss = 4.957, LR = 0.001
# Validation Loss = 1.896
# Epoch = 1, batch = 4600 of 7748, loss = 3.113, LR = 0.001
# Validation Loss = 0.387
# Epoch = 1, batch = 4700 of 7748, loss = 4.694, LR = 0.001
# Validation Loss = 1.456
# Epoch = 1, batch = 4800 of 7748, loss = 3.318, LR = 0.001
# Validation Loss = 1.613
# Epoch = 1, batch = 4900 of 7748, loss = 14.977, LR = 0.001
# Validation Loss = 0.958
# Epoch = 1, batch = 5000 of 7748, loss = 3.518, LR = 0.001
# Validation Loss = 0.006
# Epoch = 1, batch = 5100 of 7748, loss = 6.222, LR = 0.001
# Validation Loss = 4.304
# Epoch = 1, batch = 5200 of 7748, loss = 3.095, LR = 0.001
# Validation Loss = 5.994
# Epoch = 1, batch = 5300 of 7748, loss = 4.216, LR = 0.001
# Validation Loss = 0.003
# Epoch = 1, batch = 5400 of 7748, loss = 5.901, LR = 0.001
# Validation Loss = 14.558
# Epoch = 1, batch = 5500 of 7748, loss = 8.370, LR = 0.001
# Validation Loss = 5.922
# Epoch = 1, batch = 5600 of 7748, loss = 4.233, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 5700 of 7748, loss = 6.941, LR = 0.001
# Validation Loss = 0.120
# Epoch = 1, batch = 5800 of 7748, loss = 6.067, LR = 0.001
# Validation Loss = 6.698
# Epoch = 1, batch = 5900 of 7748, loss = 4.101, LR = 0.001
# Validation Loss = 0.299
# Epoch = 1, batch = 6000 of 7748, loss = 9.922, LR = 0.001
# Validation Loss = 3.742
# Epoch = 1, batch = 6100 of 7748, loss = 3.469, LR = 0.001
# Validation Loss = 3.812
# Epoch = 1, batch = 6200 of 7748, loss = 3.022, LR = 0.001
# Validation Loss = 8.726
# Epoch = 1, batch = 6300 of 7748, loss = 4.516, LR = 0.001
# Validation Loss = 1.353
# Epoch = 1, batch = 6400 of 7748, loss = 3.261, LR = 0.001
# Validation Loss = 3.221
# Epoch = 1, batch = 6500 of 7748, loss = 3.193, LR = 0.001
# Validation Loss = 2.506
# Epoch = 1, batch = 6600 of 7748, loss = 3.007, LR = 0.001
# Validation Loss = 6.286
# Epoch = 1, batch = 6700 of 7748, loss = 3.653, LR = 0.001
# Validation Loss = 6.377
# Epoch = 1, batch = 6800 of 7748, loss = 4.490, LR = 0.001
# Validation Loss = 5.593
# Epoch = 1, batch = 6900 of 7748, loss = 3.494, LR = 0.001
# Validation Loss = 4.966
# Epoch = 1, batch = 7000 of 7748, loss = 3.365, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 7100 of 7748, loss = 6.905, LR = 0.001
# Validation Loss = 3.256
# Epoch = 1, batch = 7200 of 7748, loss = 2.678, LR = 0.001
# Validation Loss = 0.008
# Epoch = 1, batch = 7300 of 7748, loss = 7.657, LR = 0.001
# Validation Loss = 0.098
# Epoch = 1, batch = 7400 of 7748, loss = 5.916, LR = 0.001
# Validation Loss = 3.447
# Epoch = 1, batch = 7500 of 7748, loss = 3.156, LR = 0.001
# Validation Loss = 13.676
# Epoch = 1, batch = 7600 of 7748, loss = 7.112, LR = 0.001
# Validation Loss = 7.371
# Epoch = 1, batch = 7700 of 7748, loss = 3.646, LR = 0.001
# Validation Loss = 8.964
# Epoch = 2, batch = 0 of 7748, loss = 4.272, LR = 0.0009045084971874737
# Validation Loss = 0.160
# Epoch = 2, batch = 100 of 7748, loss = 5.239, LR = 0.0009045084971874737
# Validation Loss = 0.629
# Epoch = 2, batch = 200 of 7748, loss = 4.133, LR = 0.0009045084971874737
# Validation Loss = 2.989
# Epoch = 2, batch = 300 of 7748, loss = 3.154, LR = 0.0009045084971874737
# Validation Loss = 16.659
# Epoch = 2, batch = 400 of 7748, loss = 8.771, LR = 0.0009045084971874737
# Validation Loss = 0.195
# Epoch = 2, batch = 500 of 7748, loss = 4.754, LR = 0.0009045084971874737
# Validation Loss = 5.532
# Epoch = 2, batch = 600 of 7748, loss = 2.880, LR = 0.0009045084971874737
# Validation Loss = 0.928
# Epoch = 2, batch = 700 of 7748, loss = 3.885, LR = 0.0009045084971874737
# Validation Loss = 1.161
# Epoch = 2, batch = 800 of 7748, loss = 3.609, LR = 0.0009045084971874737
# Validation Loss = 3.161
# Epoch = 2, batch = 900 of 7748, loss = 3.524, LR = 0.0009045084971874737
# Validation Loss = 0.115
# Epoch = 2, batch = 1000 of 7748, loss = 6.501, LR = 0.0009045084971874737
# Validation Loss = 3.230
# Epoch = 2, batch = 1100 of 7748, loss = 2.532, LR = 0.0009045084971874737
# Validation Loss = 9.343
# Epoch = 2, batch = 1200 of 7748, loss = 4.691, LR = 0.0009045084971874737
# Validation Loss = 4.030
# Epoch = 2, batch = 1300 of 7748, loss = 3.373, LR = 0.0009045084971874737
# Validation Loss = 11.738
# Epoch = 2, batch = 1400 of 7748, loss = 5.183, LR = 0.0009045084971874737
# Validation Loss = 0.662
# Epoch = 2, batch = 1500 of 7748, loss = 4.962, LR = 0.0009045084971874737
# Validation Loss = 4.050
# Epoch = 2, batch = 1600 of 7748, loss = 3.096, LR = 0.0009045084971874737
# Validation Loss = 4.174
# Epoch = 2, batch = 1700 of 7748, loss = 2.542, LR = 0.0009045084971874737
# Validation Loss = 5.443
# Epoch = 2, batch = 1800 of 7748, loss = 2.943, LR = 0.0009045084971874737
# Validation Loss = 6.825
# Epoch = 2, batch = 1900 of 7748, loss = 3.545, LR = 0.0009045084971874737
# Validation Loss = 5.958
# Epoch = 2, batch = 2000 of 7748, loss = 3.006, LR = 0.0009045084971874737
# Validation Loss = 2.225
# Epoch = 2, batch = 2100 of 7748, loss = 3.504, LR = 0.0009045084971874737
# Validation Loss = 3.163
# Epoch = 2, batch = 2200 of 7748, loss = 2.803, LR = 0.0009045084971874737
# Validation Loss = 1.449
# Epoch = 2, batch = 2300 of 7748, loss = 4.106, LR = 0.0009045084971874737
# Validation Loss = 0.599
# Epoch = 2, batch = 2400 of 7748, loss = 5.501, LR = 0.0009045084971874737
# Validation Loss = 5.465
# Epoch = 2, batch = 2500 of 7748, loss = 2.414, LR = 0.0009045084971874737
# Validation Loss = 8.619
# Epoch = 2, batch = 2600 of 7748, loss = 3.153, LR = 0.0009045084971874737
# Validation Loss = 0.675
# Epoch = 2, batch = 2700 of 7748, loss = 5.009, LR = 0.0009045084971874737
# Validation Loss = 1.805
# Epoch = 2, batch = 2800 of 7748, loss = 3.977, LR = 0.0009045084971874737
# Validation Loss = 3.377
# Epoch = 2, batch = 2900 of 7748, loss = 2.943, LR = 0.0009045084971874737
# Validation Loss = 1.281
# Epoch = 2, batch = 3000 of 7748, loss = 4.425, LR = 0.0009045084971874737
# Validation Loss = 16.690
# Epoch = 2, batch = 3100 of 7748, loss = 7.979, LR = 0.0009045084971874737
# Validation Loss = 3.487
# Epoch = 2, batch = 3200 of 7748, loss = 2.780, LR = 0.0009045084971874737
# Validation Loss = 13.636
# Epoch = 2, batch = 3300 of 7748, loss = 5.522, LR = 0.0009045084971874737
# Validation Loss = 1.832
# Epoch = 2, batch = 3400 of 7748, loss = 3.741, LR = 0.0009045084971874737
# Validation Loss = 2.481
# Epoch = 2, batch = 3500 of 7748, loss = 3.455, LR = 0.0009045084971874737
# Validation Loss = 4.245
# Epoch = 2, batch = 3600 of 7748, loss = 2.758, LR = 0.0009045084971874737
# Validation Loss = 10.233
# Epoch = 2, batch = 3700 of 7748, loss = 4.103, LR = 0.0009045084971874737
# Validation Loss = 2.324
# Epoch = 2, batch = 3800 of 7748, loss = 3.392, LR = 0.0009045084971874737
# Validation Loss = 12.396
# Epoch = 2, batch = 3900 of 7748, loss = 4.450, LR = 0.0009045084971874737
# Validation Loss = 8.231
# Epoch = 2, batch = 4000 of 7748, loss = 3.029, LR = 0.0009045084971874737
# Validation Loss = 3.046
# Epoch = 2, batch = 4100 of 7748, loss = 2.909, LR = 0.0009045084971874737
# Validation Loss = 4.353
# Epoch = 2, batch = 4200 of 7748, loss = 2.398, LR = 0.0009045084971874737
# Validation Loss = 7.917
# Epoch = 2, batch = 4300 of 7748, loss = 3.189, LR = 0.0009045084971874737
# Validation Loss = 7.374
# Epoch = 2, batch = 4400 of 7748, loss = 2.829, LR = 0.0009045084971874737
# Validation Loss = 5.548
# Epoch = 2, batch = 4500 of 7748, loss = 2.430, LR = 0.0009045084971874737
# Validation Loss = 6.086
# Epoch = 2, batch = 4600 of 7748, loss = 2.524, LR = 0.0009045084971874737
# Validation Loss = 10.799
# Epoch = 2, batch = 4700 of 7748, loss = 3.773, LR = 0.0009045084971874737
# Validation Loss = 5.257
# Epoch = 2, batch = 4800 of 7748, loss = 2.715, LR = 0.0009045084971874737
# Validation Loss = 8.390
# Epoch = 2, batch = 4900 of 7748, loss = 2.719, LR = 0.0009045084971874737
# Validation Loss = 1.313
# Epoch = 2, batch = 5000 of 7748, loss = 3.979, LR = 0.0009045084971874737
# Validation Loss = 7.070
# Epoch = 2, batch = 5100 of 7748, loss = 3.063, LR = 0.0009045084971874737
# Validation Loss = 1.506
# Epoch = 2, batch = 5200 of 7748, loss = 3.529, LR = 0.0009045084971874737
# Validation Loss = 17.177
# Epoch = 2, batch = 5300 of 7748, loss = 7.318, LR = 0.0009045084971874737
# Validation Loss = 3.931
# Epoch = 2, batch = 5400 of 7748, loss = 2.752, LR = 0.0009045084971874737
# Validation Loss = 2.677
# Epoch = 2, batch = 5500 of 7748, loss = 3.578, LR = 0.0009045084971874737
# Validation Loss = 1.680
# Epoch = 2, batch = 5600 of 7748, loss = 2.935, LR = 0.0009045084971874737
# Validation Loss = 7.993
# Epoch = 2, batch = 5700 of 7748, loss = 2.859, LR = 0.0009045084971874737
# Validation Loss = 2.648
# Epoch = 2, batch = 5800 of 7748, loss = 3.204, LR = 0.0009045084971874737
# Validation Loss = 7.677
# Epoch = 2, batch = 5900 of 7748, loss = 3.633, LR = 0.0009045084971874737
# Validation Loss = 6.781
# Epoch = 2, batch = 6000 of 7748, loss = 3.316, LR = 0.0009045084971874737
# Validation Loss = 11.900
# Epoch = 2, batch = 6100 of 7748, loss = 4.197, LR = 0.0009045084971874737
# Validation Loss = 2.334
# Epoch = 2, batch = 6200 of 7748, loss = 4.055, LR = 0.0009045084971874737
# Validation Loss = 0.957
# Epoch = 2, batch = 6300 of 7748, loss = 4.539, LR = 0.0009045084971874737
# Validation Loss = 11.995
# Epoch = 2, batch = 6400 of 7748, loss = 3.616, LR = 0.0009045084971874737
# Validation Loss = 8.639
# Epoch = 2, batch = 6500 of 7748, loss = 3.094, LR = 0.0009045084971874737
# Validation Loss = 10.603
# Epoch = 2, batch = 6600 of 7748, loss = 3.954, LR = 0.0009045084971874737
# Validation Loss = 4.738
# Epoch = 2, batch = 6700 of 7748, loss = 2.645, LR = 0.0009045084971874737
# Validation Loss = 2.390
# Epoch = 2, batch = 6800 of 7748, loss = 2.822, LR = 0.0009045084971874737
# Validation Loss = 15.821
# Epoch = 2, batch = 6900 of 7748, loss = 6.906, LR = 0.0009045084971874737
# Validation Loss = 0.136
# Epoch = 2, batch = 7000 of 7748, loss = 6.803, LR = 0.0009045084971874737
# Validation Loss = 0.839
# Epoch = 2, batch = 7100 of 7748, loss = 5.088, LR = 0.0009045084971874737
# Validation Loss = 17.139
# Epoch = 2, batch = 7200 of 7748, loss = 7.677, LR = 0.0009045084971874737
# Validation Loss = 0.720
# Epoch = 2, batch = 7300 of 7748, loss = 4.791, LR = 0.0009045084971874737
# Validation Loss = 4.978
# Epoch = 2, batch = 7400 of 7748, loss = 2.842, LR = 0.0009045084971874737
# Validation Loss = 5.053
# Epoch = 2, batch = 7500 of 7748, loss = 2.302, LR = 0.0009045084971874737
# Validation Loss = 18.437
# Epoch = 2, batch = 7600 of 7748, loss = 7.700, LR = 0.0009045084971874737
# Validation Loss = 11.269
# Epoch = 2, batch = 7700 of 7748, loss = 3.930, LR = 0.0009045084971874737
# Validation Loss = 2.631
# Epoch = 3, batch = 0 of 7748, loss = 3.105, LR = 0.0006545084971874737
# Validation Loss = 6.258
# Epoch = 3, batch = 100 of 7748, loss = 3.111, LR = 0.0006545084971874737
# Validation Loss = 5.513
# Epoch = 3, batch = 200 of 7748, loss = 3.228, LR = 0.0006545084971874737
# Validation Loss = 7.003
# Epoch = 3, batch = 300 of 7748, loss = 2.480, LR = 0.0006545084971874737
# Validation Loss = 5.828
# Epoch = 3, batch = 400 of 7748, loss = 2.621, LR = 0.0006545084971874737
# Validation Loss = 6.154
# Epoch = 3, batch = 500 of 7748, loss = 2.824, LR = 0.0006545084971874737
# Validation Loss = 3.590
# Epoch = 3, batch = 600 of 7748, loss = 2.719, LR = 0.0006545084971874737
# Validation Loss = 3.748
# Epoch = 3, batch = 700 of 7748, loss = 2.492, LR = 0.0006545084971874737
# Validation Loss = 6.897
# Epoch = 3, batch = 800 of 7748, loss = 2.853, LR = 0.0006545084971874737
# Validation Loss = 1.273
# Epoch = 3, batch = 900 of 7748, loss = 4.349, LR = 0.0006545084971874737
# Validation Loss = 5.135
# Epoch = 3, batch = 1000 of 7748, loss = 2.510, LR = 0.0006545084971874737
# Validation Loss = 2.032
# Epoch = 3, batch = 1100 of 7748, loss = 2.868, LR = 0.0006545084971874737
# Validation Loss = 4.403
# Epoch = 3, batch = 1200 of 7748, loss = 2.235, LR = 0.0006545084971874737
# Validation Loss = 9.054
# Epoch = 3, batch = 1300 of 7748, loss = 3.356, LR = 0.0006545084971874737
# Validation Loss = 6.592
# Epoch = 3, batch = 1400 of 7748, loss = 2.909, LR = 0.0006545084971874737
# Validation Loss = 10.934
# Epoch = 3, batch = 1500 of 7748, loss = 3.045, LR = 0.0006545084971874737
# Validation Loss = 10.530
# Epoch = 3, batch = 1600 of 7748, loss = 3.746, LR = 0.0006545084971874737
# Validation Loss = 4.057
# Epoch = 3, batch = 1700 of 7748, loss = 2.595, LR = 0.0006545084971874737
# Validation Loss = 2.800
# Epoch = 3, batch = 1800 of 7748, loss = 3.107, LR = 0.0006545084971874737
# Validation Loss = 6.377
# Epoch = 3, batch = 1900 of 7748, loss = 2.804, LR = 0.0006545084971874737
# Validation Loss = 7.451
# Epoch = 3, batch = 2000 of 7748, loss = 3.289, LR = 0.0006545084971874737
# Validation Loss = 5.919
# Epoch = 3, batch = 2100 of 7748, loss = 2.871, LR = 0.0006545084971874737
# Validation Loss = 3.815
# Epoch = 3, batch = 2200 of 7748, loss = 2.506, LR = 0.0006545084971874737
# Validation Loss = 9.362
# Epoch = 3, batch = 2300 of 7748, loss = 3.628, LR = 0.0006545084971874737
# Validation Loss = 4.525
# Epoch = 3, batch = 2400 of 7748, loss = 2.714, LR = 0.0006545084971874737
# Validation Loss = 4.443
# Epoch = 3, batch = 2500 of 7748, loss = 2.848, LR = 0.0006545084971874737
# Validation Loss = 2.231
# Epoch = 3, batch = 2600 of 7748, loss = 3.034, LR = 0.0006545084971874737
# Validation Loss = 3.102
# Epoch = 3, batch = 2700 of 7748, loss = 2.763, LR = 0.0006545084971874737
# Validation Loss = 3.833
# Epoch = 3, batch = 2800 of 7748, loss = 2.286, LR = 0.0006545084971874737
# Validation Loss = 8.436
# Epoch = 3, batch = 2900 of 7748, loss = 2.988, LR = 0.0006545084971874737
# Validation Loss = 6.042
# Epoch = 3, batch = 3000 of 7748, loss = 2.472, LR = 0.0006545084971874737
# Validation Loss = 6.344
# Epoch = 3, batch = 3100 of 7748, loss = 2.526, LR = 0.0006545084971874737
# Validation Loss = 4.261
# Epoch = 3, batch = 3200 of 7748, loss = 2.390, LR = 0.0006545084971874737
# Validation Loss = 2.868
# Epoch = 3, batch = 3300 of 7748, loss = 2.968, LR = 0.0006545084971874737
# Validation Loss = 8.182
# Epoch = 3, batch = 3400 of 7748, loss = 3.213, LR = 0.0006545084971874737
# Validation Loss = 3.449
# Epoch = 3, batch = 3500 of 7748, loss = 2.491, LR = 0.0006545084971874737
# Validation Loss = 0.371
# Epoch = 3, batch = 3600 of 7748, loss = 5.215, LR = 0.0006545084971874737
# Validation Loss = 4.620
# Epoch = 3, batch = 3700 of 7748, loss = 1.987, LR = 0.0006545084971874737
# Validation Loss = 3.462
# Epoch = 3, batch = 3800 of 7748, loss = 2.462, LR = 0.0006545084971874737
# Validation Loss = 7.874
# Epoch = 3, batch = 3900 of 7748, loss = 3.258, LR = 0.0006545084971874737
# Validation Loss = 3.561
# Epoch = 3, batch = 4000 of 7748, loss = 2.356, LR = 0.0006545084971874737
# Validation Loss = 6.259
# Epoch = 3, batch = 4100 of 7748, loss = 2.607, LR = 0.0006545084971874737
# Validation Loss = 5.327
# Epoch = 3, batch = 4200 of 7748, loss = 2.791, LR = 0.0006545084971874737
# Validation Loss = 3.049
# Epoch = 3, batch = 4300 of 7748, loss = 2.192, LR = 0.0006545084971874737
# Validation Loss = 11.462
# Epoch = 3, batch = 4400 of 7748, loss = 2.791, LR = 0.0006545084971874737
# Validation Loss = 3.643
# Epoch = 3, batch = 4500 of 7748, loss = 2.365, LR = 0.0006545084971874737
# Validation Loss = 10.594
# Epoch = 3, batch = 4600 of 7748, loss = 3.480, LR = 0.0006545084971874737
# Validation Loss = 8.955
# Epoch = 3, batch = 4700 of 7748, loss = 2.305, LR = 0.0006545084971874737
# Validation Loss = 3.994
# Epoch = 3, batch = 4800 of 7748, loss = 2.235, LR = 0.0006545084971874737
# Validation Loss = 3.002
# Epoch = 3, batch = 4900 of 7748, loss = 2.609, LR = 0.0006545084971874737
# Validation Loss = 1.262
# Epoch = 3, batch = 5000 of 7748, loss = 3.154, LR = 0.0006545084971874737
# Validation Loss = 8.630
# Epoch = 3, batch = 5100 of 7748, loss = 2.912, LR = 0.0006545084971874737
# Validation Loss = 1.804
# Epoch = 3, batch = 5200 of 7748, loss = 2.970, LR = 0.0006545084971874737
# Validation Loss = 6.177
# Epoch = 3, batch = 5300 of 7748, loss = 2.228, LR = 0.0006545084971874737
# Validation Loss = 1.398
# Epoch = 3, batch = 5400 of 7748, loss = 3.559, LR = 0.0006545084971874737
# Validation Loss = 3.038
# Epoch = 3, batch = 5500 of 7748, loss = 2.475, LR = 0.0006545084971874737
# Validation Loss = 3.581
# Epoch = 3, batch = 5600 of 7748, loss = 2.587, LR = 0.0006545084971874737
# Validation Loss = 3.014
# Epoch = 3, batch = 5700 of 7748, loss = 3.174, LR = 0.0006545084971874737
# Validation Loss = 5.226
# Epoch = 3, batch = 5800 of 7748, loss = 2.199, LR = 0.0006545084971874737
# Validation Loss = 1.300
# Epoch = 3, batch = 5900 of 7748, loss = 3.486, LR = 0.0006545084971874737
# Validation Loss = 7.306
# Epoch = 3, batch = 6000 of 7748, loss = 2.642, LR = 0.0006545084971874737
# Validation Loss = 9.342
# Epoch = 3, batch = 6100 of 7748, loss = 3.677, LR = 0.0006545084971874737
# Validation Loss = 9.978
# Epoch = 3, batch = 6200 of 7748, loss = 2.792, LR = 0.0006545084971874737
# Validation Loss = 8.969
# Epoch = 3, batch = 6300 of 7748, loss = 2.583, LR = 0.0006545084971874737
# Validation Loss = 6.748
# Epoch = 3, batch = 6400 of 7748, loss = 2.269, LR = 0.0006545084971874737
# Validation Loss = 1.657
# Epoch = 3, batch = 6500 of 7748, loss = 3.041, LR = 0.0006545084971874737
# Validation Loss = 4.214
# Epoch = 3, batch = 6600 of 7748, loss = 2.008, LR = 0.0006545084971874737
# Validation Loss = 5.399
# Epoch = 3, batch = 6700 of 7748, loss = 2.289, LR = 0.0006545084971874737
# Validation Loss = 1.892
# Epoch = 3, batch = 6800 of 7748, loss = 3.011, LR = 0.0006545084971874737
# Validation Loss = 3.361
# Epoch = 3, batch = 6900 of 7748, loss = 2.503, LR = 0.0006545084971874737
# Validation Loss = 6.182
# Epoch = 3, batch = 7000 of 7748, loss = 2.564, LR = 0.0006545084971874737
# Validation Loss = 3.735
# Epoch = 3, batch = 7100 of 7748, loss = 1.866, LR = 0.0006545084971874737
# Validation Loss = 1.818
# Epoch = 3, batch = 7200 of 7748, loss = 2.479, LR = 0.0006545084971874737
# Validation Loss = 14.414
# Epoch = 3, batch = 7300 of 7748, loss = 4.643, LR = 0.0006545084971874737
# Validation Loss = 5.079
# Epoch = 3, batch = 7400 of 7748, loss = 2.677, LR = 0.0006545084971874737
# Validation Loss = 5.980
# Epoch = 3, batch = 7500 of 7748, loss = 2.039, LR = 0.0006545084971874737
# Validation Loss = 3.273
# Epoch = 3, batch = 7600 of 7748, loss = 2.302, LR = 0.0006545084971874737
# Validation Loss = 3.054
# Epoch = 3, batch = 7700 of 7748, loss = 2.664, LR = 0.0006545084971874737
# Validation Loss = 1.723
# Epoch = 4, batch = 0 of 7748, loss = 2.841, LR = 0.00034549150281252633
# Validation Loss = 4.164
# Epoch = 4, batch = 100 of 7748, loss = 1.804, LR = 0.00034549150281252633
# Validation Loss = 4.372
# Epoch = 4, batch = 200 of 7748, loss = 2.280, LR = 0.00034549150281252633
# Validation Loss = 5.297
# Epoch = 4, batch = 300 of 7748, loss = 1.937, LR = 0.00034549150281252633
# Validation Loss = 3.635
# Epoch = 4, batch = 400 of 7748, loss = 2.320, LR = 0.00034549150281252633
# Validation Loss = 4.189
# Epoch = 4, batch = 500 of 7748, loss = 2.369, LR = 0.00034549150281252633
# Validation Loss = 6.545
# Epoch = 4, batch = 600 of 7748, loss = 2.166, LR = 0.00034549150281252633
# Validation Loss = 3.814
# Epoch = 4, batch = 700 of 7748, loss = 2.063, LR = 0.00034549150281252633
# Validation Loss = 3.967
# Epoch = 4, batch = 800 of 7748, loss = 2.072, LR = 0.00034549150281252633
# Validation Loss = 5.560
# Epoch = 4, batch = 900 of 7748, loss = 2.170, LR = 0.00034549150281252633
# Validation Loss = 1.578
# Epoch = 4, batch = 1000 of 7748, loss = 2.585, LR = 0.00034549150281252633
# Validation Loss = 2.007
# Epoch = 4, batch = 1100 of 7748, loss = 2.339, LR = 0.00034549150281252633
# Validation Loss = 6.554
# Epoch = 4, batch = 1200 of 7748, loss = 2.333, LR = 0.00034549150281252633
# Validation Loss = 4.863
# Epoch = 4, batch = 1300 of 7748, loss = 2.403, LR = 0.00034549150281252633
# Validation Loss = 3.466
# Epoch = 4, batch = 1400 of 7748, loss = 1.977, LR = 0.00034549150281252633
# Validation Loss = 2.321
# Epoch = 4, batch = 1500 of 7748, loss = 2.118, LR = 0.00034549150281252633
# Validation Loss = 3.722
# Epoch = 4, batch = 1600 of 7748, loss = 1.915, LR = 0.00034549150281252633
# Validation Loss = 3.699
# Epoch = 4, batch = 1700 of 7748, loss = 2.065, LR = 0.00034549150281252633
# Validation Loss = 5.855
# Epoch = 4, batch = 1800 of 7748, loss = 2.340, LR = 0.00034549150281252633
# Validation Loss = 5.233
# Epoch = 4, batch = 1900 of 7748, loss = 2.035, LR = 0.00034549150281252633
# Validation Loss = 6.691
# Epoch = 4, batch = 2000 of 7748, loss = 2.580, LR = 0.00034549150281252633
# Validation Loss = 4.831
# Epoch = 4, batch = 2100 of 7748, loss = 2.198, LR = 0.00034549150281252633
# Validation Loss = 6.355
# Epoch = 4, batch = 2200 of 7748, loss = 2.448, LR = 0.00034549150281252633
# Validation Loss = 7.161
# Epoch = 4, batch = 2300 of 7748, loss = 2.404, LR = 0.00034549150281252633
# Validation Loss = 5.375
# Epoch = 4, batch = 2400 of 7748, loss = 1.831, LR = 0.00034549150281252633
# Validation Loss = 1.931
# Epoch = 4, batch = 2500 of 7748, loss = 2.479, LR = 0.00034549150281252633
# Validation Loss = 4.246
# Epoch = 4, batch = 2600 of 7748, loss = 1.993, LR = 0.00034549150281252633
# Validation Loss = 4.271
# Epoch = 4, batch = 2700 of 7748, loss = 2.094, LR = 0.00034549150281252633
# Validation Loss = 5.364
# Epoch = 4, batch = 2800 of 7748, loss = 1.973, LR = 0.00034549150281252633
# Validation Loss = 2.769
# Epoch = 4, batch = 2900 of 7748, loss = 1.757, LR = 0.00034549150281252633
# Validation Loss = 5.466
# Epoch = 4, batch = 3000 of 7748, loss = 2.006, LR = 0.00034549150281252633
# Validation Loss = 7.269
# Epoch = 4, batch = 3100 of 7748, loss = 2.889, LR = 0.00034549150281252633
# Validation Loss = 1.130
# Epoch = 4, batch = 3200 of 7748, loss = 2.427, LR = 0.00034549150281252633
# Validation Loss = 5.280
# Epoch = 4, batch = 3300 of 7748, loss = 2.511, LR = 0.00034549150281252633
# Validation Loss = 3.238
# Epoch = 4, batch = 3400 of 7748, loss = 2.176, LR = 0.00034549150281252633
# Validation Loss = 3.354
# Epoch = 4, batch = 3500 of 7748, loss = 2.230, LR = 0.00034549150281252633
# Validation Loss = 6.594
# Epoch = 4, batch = 3600 of 7748, loss = 1.954, LR = 0.00034549150281252633
# Validation Loss = 2.591
# Epoch = 4, batch = 3700 of 7748, loss = 2.138, LR = 0.00034549150281252633
# Validation Loss = 5.013
# Epoch = 4, batch = 3800 of 7748, loss = 1.960, LR = 0.00034549150281252633
# Validation Loss = 3.898
# Epoch = 4, batch = 3900 of 7748, loss = 2.227, LR = 0.00034549150281252633
# Validation Loss = 6.439
# Epoch = 4, batch = 4000 of 7748, loss = 2.054, LR = 0.00034549150281252633
# Validation Loss = 3.153
# Epoch = 4, batch = 4100 of 7748, loss = 1.721, LR = 0.00034549150281252633
# Validation Loss = 4.547
# Epoch = 4, batch = 4200 of 7748, loss = 2.041, LR = 0.00034549150281252633
# Validation Loss = 1.816
# Epoch = 4, batch = 4300 of 7748, loss = 2.133, LR = 0.00034549150281252633
# Validation Loss = 2.674
# Epoch = 4, batch = 4400 of 7748, loss = 1.624, LR = 0.00034549150281252633
# Validation Loss = 4.513
# Epoch = 4, batch = 4500 of 7748, loss = 1.994, LR = 0.00034549150281252633
# Validation Loss = 3.852
# Epoch = 4, batch = 4600 of 7748, loss = 2.376, LR = 0.00034549150281252633
# Validation Loss = 5.517
# Epoch = 4, batch = 4700 of 7748, loss = 1.869, LR = 0.00034549150281252633
# Validation Loss = 4.973
# Epoch = 4, batch = 4800 of 7748, loss = 2.083, LR = 0.00034549150281252633
# Validation Loss = 4.122
# Epoch = 4, batch = 4900 of 7748, loss = 1.990, LR = 0.00034549150281252633
# Validation Loss = 2.225
# Epoch = 4, batch = 5000 of 7748, loss = 2.146, LR = 0.00034549150281252633
# Validation Loss = 4.819
# Epoch = 4, batch = 5100 of 7748, loss = 1.997, LR = 0.00034549150281252633
# Validation Loss = 7.960
# Epoch = 4, batch = 5200 of 7748, loss = 2.133, LR = 0.00034549150281252633
# Validation Loss = 8.029
# Epoch = 4, batch = 5300 of 7748, loss = 2.029, LR = 0.00034549150281252633
# Validation Loss = 8.284
# Epoch = 4, batch = 5400 of 7748, loss = 2.702, LR = 0.00034549150281252633
# Validation Loss = 1.229
# Epoch = 4, batch = 5500 of 7748, loss = 2.806, LR = 0.00034549150281252633
# Validation Loss = 3.508
# Epoch = 4, batch = 5600 of 7748, loss = 2.056, LR = 0.00034549150281252633
# Validation Loss = 4.107
# Epoch = 4, batch = 5700 of 7748, loss = 2.234, LR = 0.00034549150281252633
# Validation Loss = 4.432
# Epoch = 4, batch = 5800 of 7748, loss = 2.062, LR = 0.00034549150281252633
# Validation Loss = 5.703
# Epoch = 4, batch = 5900 of 7748, loss = 2.241, LR = 0.00034549150281252633
# Validation Loss = 5.066
# Epoch = 4, batch = 6000 of 7748, loss = 1.863, LR = 0.00034549150281252633
# Validation Loss = 7.552
# Epoch = 4, batch = 6100 of 7748, loss = 1.992, LR = 0.00034549150281252633
# Validation Loss = 8.640
# Epoch = 4, batch = 6200 of 7748, loss = 2.696, LR = 0.00034549150281252633
# Validation Loss = 9.522
# Epoch = 4, batch = 6300 of 7748, loss = 2.634, LR = 0.00034549150281252633
# Validation Loss = 6.086
# Epoch = 4, batch = 6400 of 7748, loss = 2.144, LR = 0.00034549150281252633
# Validation Loss = 7.969
# Epoch = 4, batch = 6500 of 7748, loss = 2.334, LR = 0.00034549150281252633
# Validation Loss = 3.389
# Epoch = 4, batch = 6600 of 7748, loss = 2.139, LR = 0.00034549150281252633
# Validation Loss = 3.289
# Epoch = 4, batch = 6700 of 7748, loss = 1.691, LR = 0.00034549150281252633
# Validation Loss = 3.081
# Epoch = 4, batch = 6800 of 7748, loss = 1.951, LR = 0.00034549150281252633
# Validation Loss = 2.947
# Epoch = 4, batch = 6900 of 7748, loss = 2.056, LR = 0.00034549150281252633
# Validation Loss = 3.836
# Epoch = 4, batch = 7000 of 7748, loss = 1.959, LR = 0.00034549150281252633
# Validation Loss = 8.468
# Epoch = 4, batch = 7100 of 7748, loss = 2.158, LR = 0.00034549150281252633
# Validation Loss = 6.736
# Epoch = 4, batch = 7200 of 7748, loss = 2.403, LR = 0.00034549150281252633
# Validation Loss = 4.833
# Epoch = 4, batch = 7300 of 7748, loss = 1.803, LR = 0.00034549150281252633
# Validation Loss = 4.263
# Epoch = 4, batch = 7400 of 7748, loss = 2.154, LR = 0.00034549150281252633
# Validation Loss = 0.666
# Epoch = 4, batch = 7500 of 7748, loss = 3.432, LR = 0.00034549150281252633
# Validation Loss = 3.595
# Epoch = 4, batch = 7600 of 7748, loss = 1.851, LR = 0.00034549150281252633
# Validation Loss = 4.211
# Epoch = 4, batch = 7700 of 7748, loss = 2.231, LR = 0.00034549150281252633
# Validation Loss = 3.717
# Epoch = 5, batch = 0 of 7748, loss = 2.022, LR = 9.549150281252633e-05
# Validation Loss = 4.728
# Epoch = 5, batch = 100 of 7748, loss = 2.021, LR = 9.549150281252633e-05
# Validation Loss = 3.924
# Epoch = 5, batch = 200 of 7748, loss = 1.775, LR = 9.549150281252633e-05
# Validation Loss = 4.144
# Epoch = 5, batch = 300 of 7748, loss = 2.057, LR = 9.549150281252633e-05
# Validation Loss = 4.288
# Epoch = 5, batch = 400 of 7748, loss = 1.975, LR = 9.549150281252633e-05
# Validation Loss = 3.806
# Epoch = 5, batch = 500 of 7748, loss = 1.655, LR = 9.549150281252633e-05
# Validation Loss = 4.735
# Epoch = 5, batch = 600 of 7748, loss = 2.081, LR = 9.549150281252633e-05
# Validation Loss = 3.891
# Epoch = 5, batch = 700 of 7748, loss = 1.983, LR = 9.549150281252633e-05
# Validation Loss = 4.285
# Epoch = 5, batch = 800 of 7748, loss = 1.733, LR = 9.549150281252633e-05
# Validation Loss = 3.880
# Epoch = 5, batch = 900 of 7748, loss = 1.984, LR = 9.549150281252633e-05
# Validation Loss = 4.330
# Epoch = 5, batch = 1000 of 7748, loss = 2.001, LR = 9.549150281252633e-05
# Validation Loss = 4.733
# Epoch = 5, batch = 1100 of 7748, loss = 2.192, LR = 9.549150281252633e-05
# Validation Loss = 4.703
# Epoch = 5, batch = 1200 of 7748, loss = 1.878, LR = 9.549150281252633e-05
# Validation Loss = 5.352
# Epoch = 5, batch = 1300 of 7748, loss = 2.023, LR = 9.549150281252633e-05
# Validation Loss = 5.239
# Epoch = 5, batch = 1400 of 7748, loss = 2.050, LR = 9.549150281252633e-05
# Validation Loss = 4.247
# Epoch = 5, batch = 1500 of 7748, loss = 1.669, LR = 9.549150281252633e-05
# Validation Loss = 4.096
# Epoch = 5, batch = 1600 of 7748, loss = 2.030, LR = 9.549150281252633e-05
# Validation Loss = 4.880
# Epoch = 5, batch = 1700 of 7748, loss = 1.713, LR = 9.549150281252633e-05
# Validation Loss = 5.389
# Epoch = 5, batch = 1800 of 7748, loss = 1.718, LR = 9.549150281252633e-05
# Validation Loss = 3.434
# Epoch = 5, batch = 1900 of 7748, loss = 1.845, LR = 9.549150281252633e-05
# Validation Loss = 5.219
# Epoch = 5, batch = 2000 of 7748, loss = 2.024, LR = 9.549150281252633e-05
# Validation Loss = 3.892
# Epoch = 5, batch = 2100 of 7748, loss = 1.743, LR = 9.549150281252633e-05
# Validation Loss = 5.193
# Epoch = 5, batch = 2200 of 7748, loss = 1.977, LR = 9.549150281252633e-05
# Validation Loss = 5.042
# Epoch = 5, batch = 2300 of 7748, loss = 1.987, LR = 9.549150281252633e-05
# Validation Loss = 3.743
# Epoch = 5, batch = 2400 of 7748, loss = 1.816, LR = 9.549150281252633e-05
# Validation Loss = 5.636
# Epoch = 5, batch = 2500 of 7748, loss = 1.714, LR = 9.549150281252633e-05
# Validation Loss = 8.634
# Epoch = 5, batch = 2600 of 7748, loss = 2.151, LR = 9.549150281252633e-05
# Validation Loss = 5.293
# Epoch = 5, batch = 2700 of 7748, loss = 1.874, LR = 9.549150281252633e-05
# Validation Loss = 5.344
# Epoch = 5, batch = 2800 of 7748, loss = 1.892, LR = 9.549150281252633e-05
# Validation Loss = 6.597
# Epoch = 5, batch = 2900 of 7748, loss = 1.909, LR = 9.549150281252633e-05
# Validation Loss = 3.731
# Epoch = 5, batch = 3000 of 7748, loss = 2.065, LR = 9.549150281252633e-05
# Validation Loss = 4.572
# Epoch = 5, batch = 3100 of 7748, loss = 1.803, LR = 9.549150281252633e-05
# Validation Loss = 5.270
# Epoch = 5, batch = 3200 of 7748, loss = 2.080, LR = 9.549150281252633e-05
# Validation Loss = 6.216
# Epoch = 5, batch = 3300 of 7748, loss = 1.658, LR = 9.549150281252633e-05
# Validation Loss = 5.462
# Epoch = 5, batch = 3400 of 7748, loss = 1.963, LR = 9.549150281252633e-05
# Validation Loss = 5.920
# Epoch = 5, batch = 3500 of 7748, loss = 1.688, LR = 9.549150281252633e-05
# Validation Loss = 4.897
# Epoch = 5, batch = 3600 of 7748, loss = 1.969, LR = 9.549150281252633e-05
# Validation Loss = 6.394
# Epoch = 5, batch = 3700 of 7748, loss = 1.658, LR = 9.549150281252633e-05
# Validation Loss = 5.164
# Epoch = 5, batch = 3800 of 7748, loss = 1.753, LR = 9.549150281252633e-05
# Validation Loss = 4.501
# Epoch = 5, batch = 3900 of 7748, loss = 1.778, LR = 9.549150281252633e-05
# Validation Loss = 4.543
# Epoch = 5, batch = 4000 of 7748, loss = 1.642, LR = 9.549150281252633e-05
# Validation Loss = 5.649
# Epoch = 5, batch = 4100 of 7748, loss = 2.149, LR = 9.549150281252633e-05
# Validation Loss = 5.820
# Epoch = 5, batch = 4200 of 7748, loss = 1.938, LR = 9.549150281252633e-05
# Validation Loss = 5.513
# Epoch = 5, batch = 4300 of 7748, loss = 1.786, LR = 9.549150281252633e-05
# Validation Loss = 4.783
# Epoch = 5, batch = 4400 of 7748, loss = 1.819, LR = 9.549150281252633e-05
# Validation Loss = 4.770
# Epoch = 5, batch = 4500 of 7748, loss = 1.830, LR = 9.549150281252633e-05
# Validation Loss = 4.775
# Epoch = 5, batch = 4600 of 7748, loss = 1.873, LR = 9.549150281252633e-05
# Validation Loss = 4.942
# Epoch = 5, batch = 4700 of 7748, loss = 1.878, LR = 9.549150281252633e-05
# Validation Loss = 4.019
# Epoch = 5, batch = 4800 of 7748, loss = 1.999, LR = 9.549150281252633e-05
# Validation Loss = 5.036
# Epoch = 5, batch = 4900 of 7748, loss = 1.885, LR = 9.549150281252633e-05
# Validation Loss = 4.013
# Epoch = 5, batch = 5000 of 7748, loss = 1.858, LR = 9.549150281252633e-05
# Validation Loss = 2.747
# Epoch = 5, batch = 5100 of 7748, loss = 1.965, LR = 9.549150281252633e-05
# Validation Loss = 6.224
# Epoch = 5, batch = 5200 of 7748, loss = 1.892, LR = 9.549150281252633e-05
# Validation Loss = 5.913
# Epoch = 5, batch = 5300 of 7748, loss = 2.093, LR = 9.549150281252633e-05
# Validation Loss = 4.107
# Epoch = 5, batch = 5400 of 7748, loss = 1.961, LR = 9.549150281252633e-05
# Validation Loss = 5.412
# Epoch = 5, batch = 5500 of 7748, loss = 1.866, LR = 9.549150281252633e-05
# Validation Loss = 5.455
# Epoch = 5, batch = 5600 of 7748, loss = 1.765, LR = 9.549150281252633e-05
# Validation Loss = 4.017
# Epoch = 5, batch = 5700 of 7748, loss = 1.829, LR = 9.549150281252633e-05
# Validation Loss = 4.491
# Epoch = 5, batch = 5800 of 7748, loss = 1.830, LR = 9.549150281252633e-05
# Validation Loss = 6.779
# Epoch = 5, batch = 5900 of 7748, loss = 1.959, LR = 9.549150281252633e-05
# Validation Loss = 5.200
# Epoch = 5, batch = 6000 of 7748, loss = 1.737, LR = 9.549150281252633e-05
# Validation Loss = 5.284
# Epoch = 5, batch = 6100 of 7748, loss = 1.778, LR = 9.549150281252633e-05
# Validation Loss = 3.959
# Epoch = 5, batch = 6200 of 7748, loss = 1.719, LR = 9.549150281252633e-05
# Validation Loss = 5.892
# Epoch = 5, batch = 6300 of 7748, loss = 1.695, LR = 9.549150281252633e-05
# Validation Loss = 4.929
# Epoch = 5, batch = 6400 of 7748, loss = 1.819, LR = 9.549150281252633e-05
# Validation Loss = 4.171
# Epoch = 5, batch = 6500 of 7748, loss = 1.982, LR = 9.549150281252633e-05
# Validation Loss = 1.917
# Epoch = 5, batch = 6600 of 7748, loss = 1.792, LR = 9.549150281252633e-05
# Validation Loss = 5.267
# Epoch = 5, batch = 6700 of 7748, loss = 1.643, LR = 9.549150281252633e-05
# Validation Loss = 6.507
# Epoch = 5, batch = 6800 of 7748, loss = 1.810, LR = 9.549150281252633e-05
# Validation Loss = 6.231
# Epoch = 5, batch = 6900 of 7748, loss = 1.935, LR = 9.549150281252633e-05
# Validation Loss = 3.438
# Epoch = 5, batch = 7000 of 7748, loss = 1.814, LR = 9.549150281252633e-05
# Validation Loss = 4.995
# Epoch = 5, batch = 7100 of 7748, loss = 1.744, LR = 9.549150281252633e-05
# Validation Loss = 4.558
# Epoch = 5, batch = 7200 of 7748, loss = 1.768, LR = 9.549150281252633e-05
# Validation Loss = 7.220
# Epoch = 5, batch = 7300 of 7748, loss = 1.871, LR = 9.549150281252633e-05
# Validation Loss = 6.359
# Epoch = 5, batch = 7400 of 7748, loss = 1.945, LR = 9.549150281252633e-05
# Validation Loss = 6.191
# Epoch = 5, batch = 7500 of 7748, loss = 2.141, LR = 9.549150281252633e-05
# Validation Loss = 6.539
# Epoch = 5, batch = 7600 of 7748, loss = 1.742, LR = 9.549150281252633e-05
# Validation Loss = 3.758
# Epoch = 5, batch = 7700 of 7748, loss = 1.778, LR = 9.549150281252633e-05
# Training stage: 2
# Validation Loss = 6.582
# Epoch = 1, batch = 0 of 7748, loss = 1.843, LR = 0.001
# Validation Loss = 5.150
# Epoch = 1, batch = 100 of 7748, loss = 4.156, LR = 0.001
# Validation Loss = 7.685
# Epoch = 1, batch = 200 of 7748, loss = 2.738, LR = 0.001
# Validation Loss = 5.715
# Epoch = 1, batch = 300 of 7748, loss = 2.940, LR = 0.001
# Validation Loss = 4.763
# Epoch = 1, batch = 400 of 7748, loss = 2.860, LR = 0.001
# Validation Loss = 4.212
# Epoch = 1, batch = 500 of 7748, loss = 2.493, LR = 0.001
# Validation Loss = 4.815
# Epoch = 1, batch = 600 of 7748, loss = 2.244, LR = 0.001
# Validation Loss = 6.220
# Epoch = 1, batch = 700 of 7748, loss = 2.426, LR = 0.001
# Validation Loss = 5.399
# Epoch = 1, batch = 800 of 7748, loss = 2.252, LR = 0.001
# Validation Loss = 7.943
# Epoch = 1, batch = 900 of 7748, loss = 2.366, LR = 0.001
# Validation Loss = 7.670
# Epoch = 1, batch = 1000 of 7748, loss = 3.268, LR = 0.001
# Validation Loss = 3.495
# Epoch = 1, batch = 1100 of 7748, loss = 2.637, LR = 0.001
# Validation Loss = 5.018
# Epoch = 1, batch = 1200 of 7748, loss = 2.205, LR = 0.001
# Validation Loss = 5.632
# Epoch = 1, batch = 1300 of 7748, loss = 2.524, LR = 0.001
# Validation Loss = 7.402
# Epoch = 1, batch = 1400 of 7748, loss = 2.748, LR = 0.001
# Validation Loss = 4.761
# Epoch = 1, batch = 1500 of 7748, loss = 2.558, LR = 0.001
# Validation Loss = 5.572
# Epoch = 1, batch = 1600 of 7748, loss = 2.339, LR = 0.001
# Validation Loss = 0.948
# Epoch = 1, batch = 1700 of 7748, loss = 3.785, LR = 0.001
# Validation Loss = 5.646
# Epoch = 1, batch = 1800 of 7748, loss = 2.517, LR = 0.001
# Validation Loss = 4.257
# Epoch = 1, batch = 1900 of 7748, loss = 2.292, LR = 0.001
# Validation Loss = 1.599
# Epoch = 1, batch = 2000 of 7748, loss = 2.356, LR = 0.001
# Validation Loss = 5.037
# Epoch = 1, batch = 2100 of 7748, loss = 2.272, LR = 0.001
# Validation Loss = 10.963
# Epoch = 1, batch = 2200 of 7748, loss = 4.197, LR = 0.001
# Validation Loss = 4.447
# Epoch = 1, batch = 2300 of 7748, loss = 2.006, LR = 0.001
# Validation Loss = 3.278
# Epoch = 1, batch = 2400 of 7748, loss = 2.436, LR = 0.001
# Validation Loss = 6.547
# Epoch = 1, batch = 2500 of 7748, loss = 2.155, LR = 0.001
# Validation Loss = 3.039
# Epoch = 1, batch = 2600 of 7748, loss = 2.324, LR = 0.001
# Validation Loss = 2.545
# Epoch = 1, batch = 2700 of 7748, loss = 2.606, LR = 0.001
# Validation Loss = 0.604
# Epoch = 1, batch = 2800 of 7748, loss = 6.098, LR = 0.001
# Validation Loss = 9.395
# Epoch = 1, batch = 2900 of 7748, loss = 7.973, LR = 0.001
# Validation Loss = 5.105
# Epoch = 1, batch = 3000 of 7748, loss = 2.176, LR = 0.001
# Validation Loss = 1.025
# Epoch = 1, batch = 3100 of 7748, loss = 5.112, LR = 0.001
# Validation Loss = 22.445
# Epoch = 1, batch = 3200 of 7748, loss = 9.726, LR = 0.001
# Validation Loss = 12.181
# Epoch = 1, batch = 3300 of 7748, loss = 3.629, LR = 0.001
# Validation Loss = 8.023
# Epoch = 1, batch = 3400 of 7748, loss = 2.520, LR = 0.001
# Validation Loss = 1.981
# Epoch = 1, batch = 3500 of 7748, loss = 2.710, LR = 0.001
# Validation Loss = 6.390
# Epoch = 1, batch = 3600 of 7748, loss = 2.115, LR = 0.001
# Validation Loss = 15.450
# Epoch = 1, batch = 3700 of 7748, loss = 5.010, LR = 0.001
# Validation Loss = 9.812
# Epoch = 1, batch = 3800 of 7748, loss = 3.040, LR = 0.001
# Validation Loss = 10.996
# Epoch = 1, batch = 3900 of 7748, loss = 3.001, LR = 0.001
# Validation Loss = 2.399
# Epoch = 1, batch = 4000 of 7748, loss = 2.706, LR = 0.001
# Validation Loss = 9.683
# Epoch = 1, batch = 4100 of 7748, loss = 2.841, LR = 0.001
# Validation Loss = 5.638
# Epoch = 1, batch = 4200 of 7748, loss = 2.037, LR = 0.001
# Validation Loss = 2.008
# Epoch = 1, batch = 4300 of 7748, loss = 2.980, LR = 0.001
# Validation Loss = 8.814
# Epoch = 1, batch = 4400 of 7748, loss = 2.882, LR = 0.001
# Validation Loss = 1.411
# Epoch = 1, batch = 4500 of 7748, loss = 4.096, LR = 0.001
# Validation Loss = 8.669
# Epoch = 1, batch = 4600 of 7748, loss = 1.932, LR = 0.001
# Validation Loss = 5.033
# Epoch = 1, batch = 4700 of 7748, loss = 2.104, LR = 0.001
# Validation Loss = 5.672
# Epoch = 1, batch = 4800 of 7748, loss = 2.203, LR = 0.001
# Validation Loss = 10.857
# Epoch = 1, batch = 4900 of 7748, loss = 2.580, LR = 0.001
# Validation Loss = 2.638
# Epoch = 1, batch = 5000 of 7748, loss = 3.395, LR = 0.001
# Validation Loss = 13.990
# Epoch = 1, batch = 5100 of 7748, loss = 3.422, LR = 0.001
# Validation Loss = 0.847
# Epoch = 1, batch = 5200 of 7748, loss = 4.380, LR = 0.001
# Validation Loss = 2.498
# Epoch = 1, batch = 5300 of 7748, loss = 3.677, LR = 0.001
# Validation Loss = 1.912
# Epoch = 1, batch = 5400 of 7748, loss = 3.537, LR = 0.001
# Validation Loss = 5.894
# Epoch = 1, batch = 5500 of 7748, loss = 2.555, LR = 0.001
# Validation Loss = 6.747
# Epoch = 1, batch = 5600 of 7748, loss = 2.300, LR = 0.001
# Validation Loss = 6.824
# Epoch = 1, batch = 5700 of 7748, loss = 2.256, LR = 0.001
# Validation Loss = 8.351
# Epoch = 1, batch = 5800 of 7748, loss = 2.081, LR = 0.001
# Validation Loss = 3.804
# Epoch = 1, batch = 5900 of 7748, loss = 2.270, LR = 0.001
# Validation Loss = 8.350
# Epoch = 1, batch = 6000 of 7748, loss = 2.077, LR = 0.001
# Validation Loss = 10.608
# Epoch = 1, batch = 6100 of 7748, loss = 2.723, LR = 0.001
# Validation Loss = 7.838
# Epoch = 1, batch = 6200 of 7748, loss = 2.320, LR = 0.001
# Validation Loss = 2.919
# Epoch = 1, batch = 6300 of 7748, loss = 3.074, LR = 0.001
# Validation Loss = 5.361
# Epoch = 1, batch = 6400 of 7748, loss = 2.040, LR = 0.001
# Validation Loss = 0.544
# Epoch = 1, batch = 6500 of 7748, loss = 5.039, LR = 0.001
# Validation Loss = 7.141
# Epoch = 1, batch = 6600 of 7748, loss = 2.211, LR = 0.001
# Validation Loss = 5.535
# Epoch = 1, batch = 6700 of 7748, loss = 2.006, LR = 0.001
# Validation Loss = 13.924
# Epoch = 1, batch = 6800 of 7748, loss = 3.297, LR = 0.001
# Validation Loss = 3.182
# Epoch = 1, batch = 6900 of 7748, loss = 2.091, LR = 0.001
# Validation Loss = 13.285
# Epoch = 1, batch = 7000 of 7748, loss = 2.789, LR = 0.001
# Validation Loss = 10.521
# Epoch = 1, batch = 7100 of 7748, loss = 2.330, LR = 0.001
# Validation Loss = 5.324
# Epoch = 1, batch = 7200 of 7748, loss = 2.118, LR = 0.001
# Validation Loss = 4.062
# Epoch = 1, batch = 7300 of 7748, loss = 2.130, LR = 0.001
# Validation Loss = 8.038
# Epoch = 1, batch = 7400 of 7748, loss = 2.029, LR = 0.001
# Validation Loss = 10.285
# Epoch = 1, batch = 7500 of 7748, loss = 3.859, LR = 0.001
# Validation Loss = 12.926
# Epoch = 1, batch = 7600 of 7748, loss = 2.485, LR = 0.001
# Validation Loss = 15.744
# Epoch = 1, batch = 7700 of 7748, loss = 3.877, LR = 0.001
# Validation Loss = 3.855
# Epoch = 2, batch = 0 of 7748, loss = 2.090, LR = 0.0009755282581475768
# Validation Loss = 13.360
# Epoch = 2, batch = 100 of 7748, loss = 3.283, LR = 0.0009755282581475768
# Validation Loss = 8.853
# Epoch = 2, batch = 200 of 7748, loss = 1.744, LR = 0.0009755282581475768
# Validation Loss = 13.963
# Epoch = 2, batch = 300 of 7748, loss = 2.639, LR = 0.0009755282581475768
# Validation Loss = 4.221
# Epoch = 2, batch = 400 of 7748, loss = 1.922, LR = 0.0009755282581475768
# Validation Loss = 5.486
# Epoch = 2, batch = 500 of 7748, loss = 2.056, LR = 0.0009755282581475768
# Validation Loss = 3.606
# Epoch = 2, batch = 600 of 7748, loss = 3.102, LR = 0.0009755282581475768
# Validation Loss = 5.035
# Epoch = 2, batch = 700 of 7748, loss = 2.078, LR = 0.0009755282581475768
# Validation Loss = 4.742
# Epoch = 2, batch = 800 of 7748, loss = 2.397, LR = 0.0009755282581475768
# Validation Loss = 12.417
# Epoch = 2, batch = 900 of 7748, loss = 2.451, LR = 0.0009755282581475768
# Validation Loss = 5.230
# Epoch = 2, batch = 1000 of 7748, loss = 2.039, LR = 0.0009755282581475768
# Validation Loss = 8.470
# Epoch = 2, batch = 1100 of 7748, loss = 1.945, LR = 0.0009755282581475768
# Validation Loss = 4.374
# Epoch = 2, batch = 1200 of 7748, loss = 2.460, LR = 0.0009755282581475768
# Validation Loss = 11.375
# Epoch = 2, batch = 1300 of 7748, loss = 2.367, LR = 0.0009755282581475768
# Validation Loss = 7.119
# Epoch = 2, batch = 1400 of 7748, loss = 2.052, LR = 0.0009755282581475768
# Validation Loss = 5.179
# Epoch = 2, batch = 1500 of 7748, loss = 1.918, LR = 0.0009755282581475768
# Validation Loss = 5.189
# Epoch = 2, batch = 1600 of 7748, loss = 2.066, LR = 0.0009755282581475768
# Validation Loss = 11.331
# Epoch = 2, batch = 1700 of 7748, loss = 4.405, LR = 0.0009755282581475768
# Validation Loss = 18.708
# Epoch = 2, batch = 1800 of 7748, loss = 5.607, LR = 0.0009755282581475768
# Validation Loss = 5.515
# Epoch = 2, batch = 1900 of 7748, loss = 1.908, LR = 0.0009755282581475768
# Validation Loss = 12.750
# Epoch = 2, batch = 2000 of 7748, loss = 3.062, LR = 0.0009755282581475768
# Validation Loss = 11.723
# Epoch = 2, batch = 2100 of 7748, loss = 2.581, LR = 0.0009755282581475768
# Validation Loss = 3.501
# Epoch = 2, batch = 2200 of 7748, loss = 1.655, LR = 0.0009755282581475768
# Validation Loss = 13.343
# Epoch = 2, batch = 2300 of 7748, loss = 3.488, LR = 0.0009755282581475768
# Validation Loss = 13.564
# Epoch = 2, batch = 2400 of 7748, loss = 3.539, LR = 0.0009755282581475768
# Validation Loss = 11.869
# Epoch = 2, batch = 2500 of 7748, loss = 2.768, LR = 0.0009755282581475768
# Validation Loss = 5.233
# Epoch = 2, batch = 2600 of 7748, loss = 1.917, LR = 0.0009755282581475768
# Validation Loss = 7.244
# Epoch = 2, batch = 2700 of 7748, loss = 2.188, LR = 0.0009755282581475768
# Validation Loss = 1.349
# Epoch = 2, batch = 2800 of 7748, loss = 4.172, LR = 0.0009755282581475768
# Validation Loss = 7.808
# Epoch = 2, batch = 2900 of 7748, loss = 2.699, LR = 0.0009755282581475768
# Validation Loss = 4.762
# Epoch = 2, batch = 3000 of 7748, loss = 1.913, LR = 0.0009755282581475768
# Validation Loss = 0.207
# Epoch = 2, batch = 3100 of 7748, loss = 5.216, LR = 0.0009755282581475768
# Validation Loss = 9.367
# Epoch = 2, batch = 3200 of 7748, loss = 2.403, LR = 0.0009755282581475768
# Validation Loss = 2.966
# Epoch = 2, batch = 3300 of 7748, loss = 3.025, LR = 0.0009755282581475768
# Validation Loss = 4.292
# Epoch = 2, batch = 3400 of 7748, loss = 1.930, LR = 0.0009755282581475768
# Validation Loss = 9.728
# Epoch = 2, batch = 3500 of 7748, loss = 2.216, LR = 0.0009755282581475768
# Validation Loss = 9.858
# Epoch = 2, batch = 3600 of 7748, loss = 2.990, LR = 0.0009755282581475768
# Validation Loss = 11.270
# Epoch = 2, batch = 3700 of 7748, loss = 3.117, LR = 0.0009755282581475768
# Validation Loss = 7.182
# Epoch = 2, batch = 3800 of 7748, loss = 2.253, LR = 0.0009755282581475768
# Validation Loss = 4.882
# Epoch = 2, batch = 3900 of 7748, loss = 1.809, LR = 0.0009755282581475768
# Validation Loss = 3.749
# Epoch = 2, batch = 4000 of 7748, loss = 2.007, LR = 0.0009755282581475768
# Validation Loss = 5.983
# Epoch = 2, batch = 4100 of 7748, loss = 1.801, LR = 0.0009755282581475768
# Validation Loss = 4.559
# Epoch = 2, batch = 4200 of 7748, loss = 2.088, LR = 0.0009755282581475768
# Validation Loss = 9.399
# Epoch = 2, batch = 4300 of 7748, loss = 2.582, LR = 0.0009755282581475768
# Validation Loss = 9.159
# Epoch = 2, batch = 4400 of 7748, loss = 2.342, LR = 0.0009755282581475768
# Validation Loss = 9.448
# Epoch = 2, batch = 4500 of 7748, loss = 1.979, LR = 0.0009755282581475768
# Validation Loss = 2.249
# ...
# Epoch = 8, batch = 6200 of 7748, loss = 7.189, LR = 0.0002061073738537635
# Validation Loss = 14.332
# Epoch = 8, batch = 6300 of 7748, loss = 6.977, LR = 0.0002061073738537635
# Validation Loss = 8.987
# Epoch = 8, batch = 6400 of 7748, loss = 6.060, LR = 0.0002061073738537635
# Validation Loss = 7.453
# Epoch = 8, batch = 6500 of 7748, loss = 6.475, LR = 0.0002061073738537635
# Validation Loss = 15.956
# Epoch = 8, batch = 6600 of 7748, loss = 6.431, LR = 0.0002061073738537635
# Validation Loss = 13.909
# Epoch = 8, batch = 6700 of 7748, loss = 6.057, LR = 0.0002061073738537635
# Validation Loss = 10.535
# Epoch = 8, batch = 6800 of 7748, loss = 5.863, LR = 0.0002061073738537635
# Validation Loss = 18.630
# Epoch = 8, batch = 6900 of 7748, loss = 6.696, LR = 0.0002061073738537635
# Validation Loss = 12.170
# Epoch = 8, batch = 7000 of 7748, loss = 6.889, LR = 0.0002061073738537635
# Validation Loss = 10.132
# Epoch = 8, batch = 7100 of 7748, loss = 6.015, LR = 0.0002061073738537635
# Validation Loss = 13.789
# Epoch = 8, batch = 7200 of 7748, loss = 6.975, LR = 0.0002061073738537635
# Validation Loss = 9.670
# Epoch = 8, batch = 7300 of 7748, loss = 6.747, LR = 0.0002061073738537635
# Validation Loss = 9.800
# Epoch = 8, batch = 7400 of 7748, loss = 5.535, LR = 0.0002061073738537635
# Validation Loss = 9.115
# Epoch = 8, batch = 7500 of 7748, loss = 6.340, LR = 0.0002061073738537635
# Validation Loss = 7.316
# Epoch = 8, batch = 7600 of 7748, loss = 5.703, LR = 0.0002061073738537635
# Validation Loss = 9.667
# Epoch = 8, batch = 7700 of 7748, loss = 23.238, LR = 0.0002061073738537635
# Validation Loss = 6.927
# Epoch = 9, batch = 0 of 7748, loss = 6.098, LR = 9.549150281252634e-05
# Validation Loss = 9.047
# Epoch = 9, batch = 100 of 7748, loss = 6.191, LR = 9.549150281252634e-05
# Validation Loss = 8.457
# Epoch = 9, batch = 200 of 7748, loss = 6.930, LR = 9.549150281252634e-05
# Validation Loss = 11.036
# Epoch = 9, batch = 300 of 7748, loss = 5.960, LR = 9.549150281252634e-05
# Validation Loss = 11.238
# Epoch = 9, batch = 400 of 7748, loss = 7.691, LR = 9.549150281252634e-05
# Validation Loss = 9.316
# Epoch = 9, batch = 500 of 7748, loss = 6.202, LR = 9.549150281252634e-05
# Validation Loss = 9.577
# Epoch = 9, batch = 600 of 7748, loss = 6.133, LR = 9.549150281252634e-05
# Validation Loss = 10.336
# Epoch = 9, batch = 700 of 7748, loss = 6.785, LR = 9.549150281252634e-05
# Validation Loss = 6.150
# Epoch = 9, batch = 800 of 7748, loss = 6.163, LR = 9.549150281252634e-05
# Validation Loss = 10.538
# Epoch = 9, batch = 900 of 7748, loss = 5.966, LR = 9.549150281252634e-05
# Validation Loss = 10.587
# Epoch = 9, batch = 1000 of 7748, loss = 6.944, LR = 9.549150281252634e-05
# Validation Loss = 7.561
# Epoch = 9, batch = 1100 of 7748, loss = 6.275, LR = 9.549150281252634e-05
# Validation Loss = 7.715
# Epoch = 9, batch = 1200 of 7748, loss = 6.971, LR = 9.549150281252634e-05
# Validation Loss = 9.745
# Epoch = 9, batch = 1300 of 7748, loss = 7.226, LR = 9.549150281252634e-05
# Validation Loss = 10.555
# Epoch = 9, batch = 1400 of 7748, loss = 6.112, LR = 9.549150281252634e-05
# Validation Loss = 9.471
# Epoch = 9, batch = 1500 of 7748, loss = 6.842, LR = 9.549150281252634e-05
# Validation Loss = 10.272
# Epoch = 9, batch = 1600 of 7748, loss = 6.327, LR = 9.549150281252634e-05
# Validation Loss = 7.000
# Epoch = 9, batch = 1700 of 7748, loss = 6.256, LR = 9.549150281252634e-05
# Validation Loss = 7.762
# Epoch = 9, batch = 1800 of 7748, loss = 6.808, LR = 9.549150281252634e-05
# Validation Loss = 12.296
# Epoch = 9, batch = 1900 of 7748, loss = 7.018, LR = 9.549150281252634e-05
# Validation Loss = 10.925
# Epoch = 9, batch = 2000 of 7748, loss = 6.628, LR = 9.549150281252634e-05
# Validation Loss = 11.625
# Epoch = 9, batch = 2100 of 7748, loss = 6.395, LR = 9.549150281252634e-05
# Validation Loss = 8.650
# Epoch = 9, batch = 2200 of 7748, loss = 6.341, LR = 9.549150281252634e-05
# Validation Loss = 13.606
# Epoch = 9, batch = 2300 of 7748, loss = 6.356, LR = 9.549150281252634e-05
# Validation Loss = 10.881
# Epoch = 9, batch = 2400 of 7748, loss = 6.348, LR = 9.549150281252634e-05
# Validation Loss = 10.921
# Epoch = 9, batch = 2500 of 7748, loss = 6.590, LR = 9.549150281252634e-05
# Validation Loss = 11.816
# Epoch = 9, batch = 2600 of 7748, loss = 7.081, LR = 9.549150281252634e-05
# Validation Loss = 13.022
# Epoch = 9, batch = 2700 of 7748, loss = 6.973, LR = 9.549150281252634e-05
# Validation Loss = 13.396
# Epoch = 9, batch = 2800 of 7748, loss = 6.535, LR = 9.549150281252634e-05
# Validation Loss = 14.656
# Epoch = 9, batch = 2900 of 7748, loss = 7.020, LR = 9.549150281252634e-05
# Validation Loss = 8.666
# Epoch = 9, batch = 3000 of 7748, loss = 6.105, LR = 9.549150281252634e-05
# Validation Loss = 12.911
# Epoch = 9, batch = 3100 of 7748, loss = 6.475, LR = 9.549150281252634e-05
# Validation Loss = 10.365
# Epoch = 9, batch = 3200 of 7748, loss = 5.864, LR = 9.549150281252634e-05
# Validation Loss = 11.211
# Epoch = 9, batch = 3300 of 7748, loss = 6.807, LR = 9.549150281252634e-05
# Validation Loss = 18.181
# Epoch = 9, batch = 3400 of 7748, loss = 7.272, LR = 9.549150281252634e-05
# Validation Loss = 13.058
# Epoch = 9, batch = 3500 of 7748, loss = 7.095, LR = 9.549150281252634e-05
# Validation Loss = 11.801
# Epoch = 9, batch = 3600 of 7748, loss = 6.302, LR = 9.549150281252634e-05
# Validation Loss = 11.216
# Epoch = 9, batch = 3700 of 7748, loss = 6.637, LR = 9.549150281252634e-05
# Validation Loss = 8.384
# Epoch = 9, batch = 3800 of 7748, loss = 7.341, LR = 9.549150281252634e-05
# Validation Loss = 11.081
# Epoch = 9, batch = 3900 of 7748, loss = 6.480, LR = 9.549150281252634e-05
# Validation Loss = 10.770
# Epoch = 9, batch = 4000 of 7748, loss = 6.429, LR = 9.549150281252634e-05
# Validation Loss = 13.872
# Epoch = 9, batch = 4100 of 7748, loss = 6.902, LR = 9.549150281252634e-05
# Validation Loss = 11.652
# Epoch = 9, batch = 4200 of 7748, loss = 6.068, LR = 9.549150281252634e-05
# Validation Loss = 9.296
# Epoch = 9, batch = 4300 of 7748, loss = 6.702, LR = 9.549150281252634e-05
# Validation Loss = 12.457
# Epoch = 9, batch = 4400 of 7748, loss = 6.073, LR = 9.549150281252634e-05
# Validation Loss = 10.938
# Epoch = 9, batch = 4500 of 7748, loss = 6.316, LR = 9.549150281252634e-05
# Validation Loss = 9.960
# Epoch = 9, batch = 4600 of 7748, loss = 6.102, LR = 9.549150281252634e-05
# Validation Loss = 10.431
# Epoch = 9, batch = 4700 of 7748, loss = 5.765, LR = 9.549150281252634e-05
# Validation Loss = 11.590
# Epoch = 9, batch = 4800 of 7748, loss = 5.968, LR = 9.549150281252634e-05
# Validation Loss = 12.983
# Epoch = 9, batch = 4900 of 7748, loss = 6.690, LR = 9.549150281252634e-05
# Validation Loss = 9.558
# Epoch = 9, batch = 5000 of 7748, loss = 6.339, LR = 9.549150281252634e-05
# Validation Loss = 12.393
# Epoch = 9, batch = 5100 of 7748, loss = 6.826, LR = 9.549150281252634e-05
# Validation Loss = 9.570
# Epoch = 9, batch = 5200 of 7748, loss = 5.944, LR = 9.549150281252634e-05
# Validation Loss = 12.637
# Epoch = 9, batch = 5300 of 7748, loss = 6.398, LR = 9.549150281252634e-05
# Validation Loss = 13.491
# Epoch = 9, batch = 5400 of 7748, loss = 6.931, LR = 9.549150281252634e-05
# Validation Loss = 17.008
# Epoch = 9, batch = 5500 of 7748, loss = 7.657, LR = 9.549150281252634e-05
# Validation Loss = 16.891
# Epoch = 9, batch = 5600 of 7748, loss = 6.311, LR = 9.549150281252634e-05
# Validation Loss = 10.484
# Epoch = 9, batch = 5700 of 7748, loss = 6.789, LR = 9.549150281252634e-05
# Validation Loss = 9.787
# Epoch = 9, batch = 5800 of 7748, loss = 6.076, LR = 9.549150281252634e-05
# Validation Loss = 14.610
# Epoch = 9, batch = 5900 of 7748, loss = 6.592, LR = 9.549150281252634e-05
# Validation Loss = 10.313
# Epoch = 9, batch = 6000 of 7748, loss = 6.595, LR = 9.549150281252634e-05
# Validation Loss = 11.536
# Epoch = 9, batch = 6100 of 7748, loss = 6.606, LR = 9.549150281252634e-05
# Validation Loss = 11.237
# Epoch = 9, batch = 6200 of 7748, loss = 5.941, LR = 9.549150281252634e-05
# Validation Loss = 11.466
# Epoch = 9, batch = 6300 of 7748, loss = 6.207, LR = 9.549150281252634e-05
# Validation Loss = 6.658
# Epoch = 9, batch = 6400 of 7748, loss = 5.857, LR = 9.549150281252634e-05
# Validation Loss = 11.886
# Epoch = 9, batch = 6500 of 7748, loss = 6.381, LR = 9.549150281252634e-05
# Validation Loss = 9.552
# Epoch = 9, batch = 6600 of 7748, loss = 7.307, LR = 9.549150281252634e-05
# Validation Loss = 12.097
# Epoch = 9, batch = 6700 of 7748, loss = 6.493, LR = 9.549150281252634e-05
# Validation Loss = 11.695
# Epoch = 9, batch = 6800 of 7748, loss = 6.975, LR = 9.549150281252634e-05
# Validation Loss = 11.396
# Epoch = 9, batch = 6900 of 7748, loss = 6.311, LR = 9.549150281252634e-05
# Validation Loss = 9.927
# Epoch = 9, batch = 7000 of 7748, loss = 6.091, LR = 9.549150281252634e-05
# Validation Loss = 8.342
# Epoch = 9, batch = 7100 of 7748, loss = 5.901, LR = 9.549150281252634e-05
# Validation Loss = 14.642
# Epoch = 9, batch = 7200 of 7748, loss = 6.648, LR = 9.549150281252634e-05
# Validation Loss = 11.357
# Epoch = 9, batch = 7300 of 7748, loss = 5.715, LR = 9.549150281252634e-05
# Validation Loss = 13.659
# Epoch = 9, batch = 7400 of 7748, loss = 5.679, LR = 9.549150281252634e-05
# Validation Loss = 9.601
# Epoch = 9, batch = 7500 of 7748, loss = 6.539, LR = 9.549150281252634e-05
# Validation Loss = 10.736
# Epoch = 9, batch = 7600 of 7748, loss = 6.657, LR = 9.549150281252634e-05
# Validation Loss = 13.727
# Epoch = 9, batch = 7700 of 7748, loss = 6.198, LR = 9.549150281252634e-05
# Validation Loss = 11.125
# Epoch = 10, batch = 0 of 7748, loss = 5.738, LR = 2.4471741852423235e-05
# Validation Loss = 11.054
# Epoch = 10, batch = 100 of 7748, loss = 6.085, LR = 2.4471741852423235e-05
# Validation Loss = 11.617
# Epoch = 10, batch = 200 of 7748, loss = 5.793, LR = 2.4471741852423235e-05
# Validation Loss = 10.278
# Epoch = 10, batch = 300 of 7748, loss = 6.246, LR = 2.4471741852423235e-05
# Validation Loss = 10.837
# Epoch = 10, batch = 400 of 7748, loss = 5.776, LR = 2.4471741852423235e-05
# Validation Loss = 10.482
# Epoch = 10, batch = 500 of 7748, loss = 7.172, LR = 2.4471741852423235e-05
# Validation Loss = 9.872
# Epoch = 10, batch = 600 of 7748, loss = 5.911, LR = 2.4471741852423235e-05
# Validation Loss = 12.150
# Epoch = 10, batch = 700 of 7748, loss = 7.354, LR = 2.4471741852423235e-05
# Validation Loss = 10.522
# Epoch = 10, batch = 800 of 7748, loss = 6.141, LR = 2.4471741852423235e-05
# Validation Loss = 11.581
# Epoch = 10, batch = 900 of 7748, loss = 5.896, LR = 2.4471741852423235e-05
# Validation Loss = 10.378
# Epoch = 10, batch = 1000 of 7748, loss = 6.271, LR = 2.4471741852423235e-05
# Validation Loss = 13.793
# Epoch = 10, batch = 1100 of 7748, loss = 5.809, LR = 2.4471741852423235e-05
# Validation Loss = 8.918
# Epoch = 10, batch = 1200 of 7748, loss = 6.203, LR = 2.4471741852423235e-05
# Validation Loss = 10.140
# Epoch = 10, batch = 1300 of 7748, loss = 6.807, LR = 2.4471741852423235e-05
# Validation Loss = 11.542
# Epoch = 10, batch = 1400 of 7748, loss = 6.988, LR = 2.4471741852423235e-05
# Validation Loss = 10.838
# Epoch = 10, batch = 1500 of 7748, loss = 6.249, LR = 2.4471741852423235e-05
# Validation Loss = 13.775
# Epoch = 10, batch = 1600 of 7748, loss = 6.720, LR = 2.4471741852423235e-05
# Validation Loss = 10.648
# Epoch = 10, batch = 1700 of 7748, loss = 6.687, LR = 2.4471741852423235e-05
# Validation Loss = 11.164
# Epoch = 10, batch = 1800 of 7748, loss = 5.677, LR = 2.4471741852423235e-05
# Validation Loss = 12.662
# Epoch = 10, batch = 1900 of 7748, loss = 6.640, LR = 2.4471741852423235e-05
# Validation Loss = 11.644
# Epoch = 10, batch = 2000 of 7748, loss = 6.937, LR = 2.4471741852423235e-05
# Validation Loss = 10.102
# Epoch = 10, batch = 2100 of 7748, loss = 5.723, LR = 2.4471741852423235e-05
# Validation Loss = 11.909
# Epoch = 10, batch = 2200 of 7748, loss = 6.076, LR = 2.4471741852423235e-05
# Validation Loss = 9.931
# Epoch = 10, batch = 2300 of 7748, loss = 6.451, LR = 2.4471741852423235e-05
# Validation Loss = 11.818
# Epoch = 10, batch = 2400 of 7748, loss = 5.929, LR = 2.4471741852423235e-05
# Validation Loss = 11.075
# Epoch = 10, batch = 2500 of 7748, loss = 6.434, LR = 2.4471741852423235e-05
# Validation Loss = 12.401
# Epoch = 10, batch = 2600 of 7748, loss = 7.084, LR = 2.4471741852423235e-05
# Validation Loss = 14.139
# Epoch = 10, batch = 2700 of 7748, loss = 7.026, LR = 2.4471741852423235e-05
# Validation Loss = 13.138
# Epoch = 10, batch = 2800 of 7748, loss = 6.328, LR = 2.4471741852423235e-05
# Validation Loss = 11.109
# Epoch = 10, batch = 2900 of 7748, loss = 6.257, LR = 2.4471741852423235e-05
# Validation Loss = 14.267
# Epoch = 10, batch = 3000 of 7748, loss = 6.792, LR = 2.4471741852423235e-05
# Validation Loss = 9.718
# Epoch = 10, batch = 3100 of 7748, loss = 6.202, LR = 2.4471741852423235e-05
# Validation Loss = 11.087
# Epoch = 10, batch = 3200 of 7748, loss = 5.747, LR = 2.4471741852423235e-05
# Validation Loss = 10.083
# Epoch = 10, batch = 3300 of 7748, loss = 5.879, LR = 2.4471741852423235e-05
# Validation Loss = 11.643
# Epoch = 10, batch = 3400 of 7748, loss = 6.389, LR = 2.4471741852423235e-05
# Validation Loss = 11.786
# Epoch = 10, batch = 3500 of 7748, loss = 5.893, LR = 2.4471741852423235e-05
# Validation Loss = 11.410
# Epoch = 10, batch = 3600 of 7748, loss = 6.321, LR = 2.4471741852423235e-05
# Validation Loss = 10.328
# Epoch = 10, batch = 3700 of 7748, loss = 7.140, LR = 2.4471741852423235e-05
# Validation Loss = 12.107
# Epoch = 10, batch = 3800 of 7748, loss = 6.166, LR = 2.4471741852423235e-05
# Validation Loss = 10.107
# Epoch = 10, batch = 3900 of 7748, loss = 6.275, LR = 2.4471741852423235e-05
# Validation Loss = 12.785
# Epoch = 10, batch = 4000 of 7748, loss = 7.144, LR = 2.4471741852423235e-05
# Validation Loss = 12.786
# Epoch = 10, batch = 4100 of 7748, loss = 5.787, LR = 2.4471741852423235e-05
# Validation Loss = 9.761
# Epoch = 10, batch = 4200 of 7748, loss = 6.223, LR = 2.4471741852423235e-05
# Validation Loss = 11.259
# Epoch = 10, batch = 4300 of 7748, loss = 6.257, LR = 2.4471741852423235e-05
# Validation Loss = 11.500
# Epoch = 10, batch = 4400 of 7748, loss = 7.062, LR = 2.4471741852423235e-05
# Validation Loss = 11.030
# Epoch = 10, batch = 4500 of 7748, loss = 6.394, LR = 2.4471741852423235e-05
# Validation Loss = 11.700
# Epoch = 10, batch = 4600 of 7748, loss = 6.481, LR = 2.4471741852423235e-05
# Validation Loss = 12.078
# Epoch = 10, batch = 4700 of 7748, loss = 6.951, LR = 2.4471741852423235e-05
# Validation Loss = 11.931
# Epoch = 10, batch = 4800 of 7748, loss = 6.485, LR = 2.4471741852423235e-05
# Validation Loss = 11.120
# Epoch = 10, batch = 4900 of 7748, loss = 5.989, LR = 2.4471741852423235e-05
# Validation Loss = 8.932
# Epoch = 10, batch = 5000 of 7748, loss = 6.287, LR = 2.4471741852423235e-05
# Validation Loss = 12.405
# Epoch = 10, batch = 5100 of 7748, loss = 6.215, LR = 2.4471741852423235e-05
# Validation Loss = 12.312
# Epoch = 10, batch = 5200 of 7748, loss = 5.559, LR = 2.4471741852423235e-05
# Validation Loss = 12.381
# Epoch = 10, batch = 5300 of 7748, loss = 6.059, LR = 2.4471741852423235e-05
# Validation Loss = 9.471
# Epoch = 10, batch = 5400 of 7748, loss = 6.678, LR = 2.4471741852423235e-05
# Validation Loss = 11.937
# Epoch = 10, batch = 5500 of 7748, loss = 6.114, LR = 2.4471741852423235e-05
# Validation Loss = 10.344
# Epoch = 10, batch = 5600 of 7748, loss = 5.716, LR = 2.4471741852423235e-05
# Validation Loss = 12.836
# Epoch = 10, batch = 5700 of 7748, loss = 6.019, LR = 2.4471741852423235e-05
# Validation Loss = 11.968
# Epoch = 10, batch = 5800 of 7748, loss = 6.002, LR = 2.4471741852423235e-05
# Validation Loss = 11.648
# Epoch = 10, batch = 5900 of 7748, loss = 5.876, LR = 2.4471741852423235e-05
# Validation Loss = 12.327
# Epoch = 10, batch = 6000 of 7748, loss = 6.299, LR = 2.4471741852423235e-05
# Validation Loss = 11.969
# Epoch = 10, batch = 6100 of 7748, loss = 6.267, LR = 2.4471741852423235e-05
# Validation Loss = 10.753
# Epoch = 10, batch = 6200 of 7748, loss = 6.644, LR = 2.4471741852423235e-05
# Validation Loss = 10.051
# Epoch = 10, batch = 6300 of 7748, loss = 5.680, LR = 2.4471741852423235e-05
# Validation Loss = 11.427
# Epoch = 10, batch = 6400 of 7748, loss = 5.523, LR = 2.4471741852423235e-05
# Validation Loss = 10.293
# Epoch = 10, batch = 6500 of 7748, loss = 6.198, LR = 2.4471741852423235e-05
# Validation Loss = 11.984
# Epoch = 10, batch = 6600 of 7748, loss = 6.008, LR = 2.4471741852423235e-05
