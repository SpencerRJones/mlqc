# %% [markdown]
# # Channel Prediction Model for Quality Control
#
# This notebook contains the code and outlines the development of the
# SSMI Channel Prediction Neural Network for QC purposes of SSMI L1C
# data. The simple Feed-Forward Neural Networks (FFNNs) are trained on
# good quality SSMIS brightness temperature observation vectors and are
# trained to predict one channel from all the others as predictors.
#
# The end product is a tree of FFNNs, discretized by surface (ocean or
# land), and by channel, since these are fully distinct problems.

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import glob
import torch
from torch import nn
import cartopy.crs as ccrs
from util_funcs.L1C import scantime2datetime
from util_funcs import data2xarray, array_funcs
import geography
from tqdm import tqdm

from dataset_class import dataset
from model_class import channel_predictor


#General parameters:

satellite = 'F13'
sensor = 'SSMI'

nchans = 5
batch_size = 1000
input_size = nchans - 1
hidden_size = 256
output_size = 1

# %%
'''
Function Definitions:
'''


# Tb array will be set up as follows:
#     Tbs =  [m x n], where m is the number of samples and n is the
#            number of channels (features)
#     1-2:   19.35 V and H
#     3:     22.235 V
#     4-5:   37.0 V and H
#     6-9:   85.5 V and H #Double-sampled 85

chan_desc = np.array(['19V', '19H', '22V', '37V', '37H'])


def extract_channel(Tb_array, chan):

    '''
    Use in preparing training data.

    Assumes Tb array is [m x n] where m (rows) are samples
    and n (columns) is the number of channels.

    Passing in the channel description splits the data so
    that the specified channel is its own vector y and the
    rest are kept as predictors x.

    Inputs:
        Tb_array    |  ndarray of Tbs
        chan        |  string of channel name
    Outputs:
        x           |  matrix of predictors (other channels)
        y           |  vector of predictands (the missing channel)
        
    '''
    
    chan_desc = np.array(['19V', '19H', '22V', '37V', '37H'])


    chan_indx = np.where(chan == chan_desc)[0]

    if np.size(chan_indx) == 0:
        raise ValueError(f'Channel description must be in list {chan_desc}.')

    y = Tb_array[:,chan_indx]
    x = Tb_array[:,np.delete(np.arange(0,len(chan_desc)),chan_indx)]

    return x, y



def split_data_indcs(x, train=80, test=10, val=10, device=None, randomize=False):

    '''
    Creates train/test/validation split for training data. Default is 80%/10%/10%.

    Inputs:
        x       |   Array of predictors. Expects shape (nsamples, nfeatures).
        y       |   Array of predictands. Expects shape (nsamples, nfeatures).
        train   |   Percentage of data to be used for training.
        test    |   Percentage of data to be used for testing.
        val     |   Percentage of data to be used for validation.
                        -Train + test + val must equal 100.
        device (optional)    |  Either 'cuda' or 'cpu'. 
        randomize (optional) |  Whether to shuffle the data before creating
                                    the splits. This functionality is currently
                                    not supported but is intended to be 
                                    implemented in the future.
    '''

    if train + test + val != 100:
        raise ValueError(f'train + test + val must equal 100%.')

    # if x.shape[0] != y.shape[0]:
    #     raise ValueError(f'Dimensions of x {x.shape} and y {y.shape} not compatible.')

    nsamples = x.shape[0]

    ntrain = int(nsamples * (train / 100.))
    ntest  = int(nsamples * (test / 100.))
    nval   = nsamples - ntrain - ntest

    indcs = np.arange(0,nsamples)

    train_indcs = indcs[0:ntrain]
    test_indcs  = indcs[ntrain:ntrain+ntest]
    val_indcs   = indcs[ntrain+ntest:]

    return train_indcs, test_indcs, val_indcs


def train_model(model, nepochs, dataloader, learning_rate=0.001, quiet=False, stage=None, validation_dataloader=None):

    nbatches = len(dataloader)
    
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=nepochs)
    device = None

    if stage:
        print(f'Training stage: {stage}')

    loss_arr    = np.zeros([nbatches,nepochs], dtype='f')
    valloss_arr = np.zeros([nbatches,nepochs], dtype='f')
    
    for epoch in range(nepochs):
        for i, (profs, obs) in enumerate(dataloader):
            if device:
                profs, obs = profs.to(device), obs.to(device)

            if validation_dataloader and i%100==0:
                valprofs, valobs = next(enumerate(validation_dataloader))[1]
                val_pred = model(valprofs)
                valloss  = criterion(val_pred, valobs)
                print(f'Validation Loss = {valloss.item():.3f}')

            #Forward pass:
            obs_pred = model(profs)
            loss     = criterion(obs_pred, obs)


            #Backward pass:
            optimizer.zero_grad()
            loss.backward()

            #Update neurons:
            optimizer.step()

            loss_arr[i,epoch] = loss.item()
            valloss_arr[i,epoch] = valloss.item()
            
            if not quiet:
                if i%100 == 0:
                    print(f'Epoch = {epoch+1}, batch = {i} of {nbatches}, loss = {loss.item():.3f}, LR = {scheduler.get_last_lr()[0]}')
        
        scheduler.step()




    return loss_arr, valloss_arr

# %%
'''

SSMI CHANNEL PREDICTION MODEL:
    1: Ocean

'''

sfc = [1]

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = np.isin(sfctype, sfc)
    sfcindcs = np.where(correct_sfc)[0]

    Tbs = f.Tbs.values[sfcindcs]

#---Don't shuffle data before splitting
#np.random.seed(40)
#Tbs = array_funcs.shuffle_data(Tbs, axis=0)

#Get rid of 89s:
Tbs = Tbs[:,:-4]

if Tbs.shape[0] > 5.0e+06:
    Tbs = Tbs[:5_000_000,:]


print(Tbs.shape)

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train = array_funcs.shuffle_data(Tbs_train, axis=0)
# Out:
# (5000000, 5)

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_ocean.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_ocean.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# Training stage: 1
# Validation Loss = 39554.375
# Epoch = 1, batch = 0 of 4000, loss = 38317.957, LR = 0.001
# Validation Loss = 54.737
# Epoch = 1, batch = 100 of 4000, loss = 14.577, LR = 0.001
# Validation Loss = 10.782
# Epoch = 1, batch = 200 of 4000, loss = 2.653, LR = 0.001
# Validation Loss = 3.881
# Epoch = 1, batch = 300 of 4000, loss = 2.297, LR = 0.001
# Validation Loss = 2.424
# Epoch = 1, batch = 400 of 4000, loss = 2.015, LR = 0.001
# Validation Loss = 2.438
# Epoch = 1, batch = 500 of 4000, loss = 1.870, LR = 0.001
# Validation Loss = 2.352
# Epoch = 1, batch = 600 of 4000, loss = 1.927, LR = 0.001
# Validation Loss = 1.801
# Epoch = 1, batch = 700 of 4000, loss = 1.795, LR = 0.001
# Validation Loss = 1.758
# Epoch = 1, batch = 800 of 4000, loss = 1.593, LR = 0.001
# Validation Loss = 1.091
# Epoch = 1, batch = 900 of 4000, loss = 1.824, LR = 0.001
# Validation Loss = 2.027
# Epoch = 1, batch = 1000 of 4000, loss = 1.460, LR = 0.001
# Validation Loss = 1.658
# Epoch = 1, batch = 1100 of 4000, loss = 1.461, LR = 0.001
# Validation Loss = 1.447
# Epoch = 1, batch = 1200 of 4000, loss = 1.252, LR = 0.001
# Validation Loss = 0.880
# Epoch = 1, batch = 1300 of 4000, loss = 1.184, LR = 0.001
# Validation Loss = 0.708
# Epoch = 1, batch = 1400 of 4000, loss = 1.194, LR = 0.001
# Validation Loss = 0.497
# Epoch = 1, batch = 1500 of 4000, loss = 1.167, LR = 0.001
# Validation Loss = 0.335
# Epoch = 1, batch = 1600 of 4000, loss = 1.139, LR = 0.001
# Validation Loss = 0.595
# Epoch = 1, batch = 1700 of 4000, loss = 0.953, LR = 0.001
# Validation Loss = 1.911
# Epoch = 1, batch = 1800 of 4000, loss = 4.024, LR = 0.001
# Validation Loss = 0.302
# Epoch = 1, batch = 1900 of 4000, loss = 0.868, LR = 0.001
# Validation Loss = 0.167
# Epoch = 1, batch = 2000 of 4000, loss = 0.901, LR = 0.001
# Validation Loss = 0.359
# Epoch = 1, batch = 2100 of 4000, loss = 0.946, LR = 0.001
# Validation Loss = 0.249
# Epoch = 1, batch = 2200 of 4000, loss = 0.901, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 2300 of 4000, loss = 0.930, LR = 0.001
# Validation Loss = 0.016
# Epoch = 1, batch = 2400 of 4000, loss = 0.947, LR = 0.001
# Validation Loss = 0.048
# Epoch = 1, batch = 2500 of 4000, loss = 0.800, LR = 0.001
# Validation Loss = 0.259
# Epoch = 1, batch = 2600 of 4000, loss = 0.972, LR = 0.001
# Validation Loss = 0.024
# Epoch = 1, batch = 2700 of 4000, loss = 0.820, LR = 0.001
# Validation Loss = 0.009
# Epoch = 1, batch = 2800 of 4000, loss = 0.768, LR = 0.001
# Validation Loss = 0.127
# Epoch = 1, batch = 2900 of 4000, loss = 0.850, LR = 0.001
# Validation Loss = 0.104
# Epoch = 1, batch = 3000 of 4000, loss = 0.879, LR = 0.001
# Validation Loss = 0.035
# Epoch = 1, batch = 3100 of 4000, loss = 0.713, LR = 0.001
# Validation Loss = 0.004
# Epoch = 1, batch = 3200 of 4000, loss = 0.776, LR = 0.001
# Validation Loss = 0.071
# Epoch = 1, batch = 3300 of 4000, loss = 0.902, LR = 0.001
# Validation Loss = 0.060
# Epoch = 1, batch = 3400 of 4000, loss = 0.896, LR = 0.001
# Validation Loss = 0.674
# Epoch = 1, batch = 3500 of 4000, loss = 1.356, LR = 0.001
# Validation Loss = 0.613
# Epoch = 1, batch = 3600 of 4000, loss = 1.360, LR = 0.001
# Validation Loss = 0.400
# Epoch = 1, batch = 3700 of 4000, loss = 1.206, LR = 0.001
# Validation Loss = 1.130
# Epoch = 1, batch = 3800 of 4000, loss = 1.630, LR = 0.001
# Validation Loss = 0.008
# Epoch = 1, batch = 3900 of 4000, loss = 0.889, LR = 0.001
# Validation Loss = 0.812
# Epoch = 2, batch = 0 of 4000, loss = 1.439, LR = 0.0009045084971874737
# Validation Loss = 0.391
# Epoch = 2, batch = 100 of 4000, loss = 0.964, LR = 0.0009045084971874737
# Validation Loss = 0.691
# Epoch = 2, batch = 200 of 4000, loss = 1.625, LR = 0.0009045084971874737
# Validation Loss = 0.002
# Epoch = 2, batch = 300 of 4000, loss = 0.713, LR = 0.0009045084971874737
# Validation Loss = 0.223
# Epoch = 2, batch = 400 of 4000, loss = 1.160, LR = 0.0009045084971874737
# Validation Loss = 0.086
# Epoch = 2, batch = 500 of 4000, loss = 0.765, LR = 0.0009045084971874737
# Validation Loss = 0.227
# Epoch = 2, batch = 600 of 4000, loss = 0.935, LR = 0.0009045084971874737
# Validation Loss = 0.105
# Epoch = 2, batch = 700 of 4000, loss = 0.781, LR = 0.0009045084971874737
# Validation Loss = 0.024
# Epoch = 2, batch = 800 of 4000, loss = 0.821, LR = 0.0009045084971874737
# Validation Loss = 0.056
# Epoch = 2, batch = 900 of 4000, loss = 0.863, LR = 0.0009045084971874737
# Validation Loss = 0.092
# Epoch = 2, batch = 1000 of 4000, loss = 0.774, LR = 0.0009045084971874737
# Validation Loss = 0.607
# Epoch = 2, batch = 1100 of 4000, loss = 1.375, LR = 0.0009045084971874737
# Validation Loss = 7.738
# Epoch = 2, batch = 1200 of 4000, loss = 7.243, LR = 0.0009045084971874737
# Validation Loss = 0.560
# Epoch = 2, batch = 1300 of 4000, loss = 1.152, LR = 0.0009045084971874737
# Validation Loss = 4.185
# Epoch = 2, batch = 1400 of 4000, loss = 4.372, LR = 0.0009045084971874737
# Validation Loss = 0.253
# Epoch = 2, batch = 1500 of 4000, loss = 1.069, LR = 0.0009045084971874737
# Validation Loss = 0.732
# Epoch = 2, batch = 1600 of 4000, loss = 1.581, LR = 0.0009045084971874737
# Validation Loss = 0.712
# Epoch = 2, batch = 1700 of 4000, loss = 1.378, LR = 0.0009045084971874737
# Validation Loss = 0.140
# Epoch = 2, batch = 1800 of 4000, loss = 0.959, LR = 0.0009045084971874737
# Validation Loss = 0.003
# Epoch = 2, batch = 1900 of 4000, loss = 0.713, LR = 0.0009045084971874737
# Validation Loss = 0.034
# Epoch = 2, batch = 2000 of 4000, loss = 0.734, LR = 0.0009045084971874737
# Validation Loss = 1.241
# Epoch = 2, batch = 2100 of 4000, loss = 1.651, LR = 0.0009045084971874737
# Validation Loss = 0.468
# Epoch = 2, batch = 2200 of 4000, loss = 1.333, LR = 0.0009045084971874737
# Validation Loss = 1.233
# Epoch = 2, batch = 2300 of 4000, loss = 1.709, LR = 0.0009045084971874737
# Validation Loss = 2.143
# Epoch = 2, batch = 2400 of 4000, loss = 2.404, LR = 0.0009045084971874737
# Validation Loss = 1.328
# Epoch = 2, batch = 2500 of 4000, loss = 1.829, LR = 0.0009045084971874737
# Validation Loss = 0.558
# Epoch = 2, batch = 2600 of 4000, loss = 1.184, LR = 0.0009045084971874737
# Validation Loss = 1.669
# Epoch = 2, batch = 2700 of 4000, loss = 2.180, LR = 0.0009045084971874737
# Validation Loss = 0.466
# Epoch = 2, batch = 2800 of 4000, loss = 1.111, LR = 0.0009045084971874737
# Validation Loss = 1.907
# Epoch = 2, batch = 2900 of 4000, loss = 2.711, LR = 0.0009045084971874737
# Validation Loss = 0.492
# Epoch = 2, batch = 3000 of 4000, loss = 1.324, LR = 0.0009045084971874737
# Validation Loss = 0.314
# Epoch = 2, batch = 3100 of 4000, loss = 1.253, LR = 0.0009045084971874737
# Validation Loss = 0.062
# Epoch = 2, batch = 3200 of 4000, loss = 0.822, LR = 0.0009045084971874737
# Validation Loss = 0.173
# Epoch = 2, batch = 3300 of 4000, loss = 0.922, LR = 0.0009045084971874737
# Validation Loss = 2.133
# Epoch = 2, batch = 3400 of 4000, loss = 2.384, LR = 0.0009045084971874737
# Validation Loss = 0.780
# Epoch = 2, batch = 3500 of 4000, loss = 1.373, LR = 0.0009045084971874737
# Validation Loss = 0.135
# Epoch = 2, batch = 3600 of 4000, loss = 0.870, LR = 0.0009045084971874737
# Validation Loss = 0.130
# Epoch = 2, batch = 3700 of 4000, loss = 0.919, LR = 0.0009045084971874737
# Validation Loss = 0.652
# Epoch = 2, batch = 3800 of 4000, loss = 1.443, LR = 0.0009045084971874737
# Validation Loss = 1.672
# Epoch = 2, batch = 3900 of 4000, loss = 2.157, LR = 0.0009045084971874737
# Validation Loss = 0.979
# Epoch = 3, batch = 0 of 4000, loss = 1.280, LR = 0.0006545084971874737
# Validation Loss = 0.089
# Epoch = 3, batch = 100 of 4000, loss = 0.907, LR = 0.0006545084971874737
# Validation Loss = 0.006
# Epoch = 3, batch = 200 of 4000, loss = 0.806, LR = 0.0006545084971874737
# Validation Loss = 0.166
# Epoch = 3, batch = 300 of 4000, loss = 0.779, LR = 0.0006545084971874737
# Validation Loss = 0.000
# Epoch = 3, batch = 400 of 4000, loss = 0.840, LR = 0.0006545084971874737
# Validation Loss = 0.050
# Epoch = 3, batch = 500 of 4000, loss = 0.753, LR = 0.0006545084971874737
# Validation Loss = 0.085
# Epoch = 3, batch = 600 of 4000, loss = 0.818, LR = 0.0006545084971874737
# Validation Loss = 0.170
# Epoch = 3, batch = 700 of 4000, loss = 1.148, LR = 0.0006545084971874737
# Validation Loss = 0.078
# Epoch = 3, batch = 800 of 4000, loss = 0.804, LR = 0.0006545084971874737
# Validation Loss = 0.411
# Epoch = 3, batch = 900 of 4000, loss = 0.963, LR = 0.0006545084971874737
# Validation Loss = 0.010
# Epoch = 3, batch = 1000 of 4000, loss = 0.876, LR = 0.0006545084971874737
# Validation Loss = 0.641
# Epoch = 3, batch = 1100 of 4000, loss = 0.965, LR = 0.0006545084971874737
# Validation Loss = 0.021
# Epoch = 3, batch = 1200 of 4000, loss = 0.818, LR = 0.0006545084971874737
# Validation Loss = 0.039
# Epoch = 3, batch = 1300 of 4000, loss = 0.760, LR = 0.0006545084971874737
# Validation Loss = 0.001
# Epoch = 3, batch = 1400 of 4000, loss = 0.823, LR = 0.0006545084971874737
# Validation Loss = 0.166
# Epoch = 3, batch = 1500 of 4000, loss = 0.776, LR = 0.0006545084971874737
# Validation Loss = 0.216
# Epoch = 3, batch = 1600 of 4000, loss = 0.763, LR = 0.0006545084971874737
# Validation Loss = 0.857
# Epoch = 3, batch = 1700 of 4000, loss = 1.251, LR = 0.0006545084971874737
# Validation Loss = 0.037
# Epoch = 3, batch = 1800 of 4000, loss = 0.850, LR = 0.0006545084971874737
# Validation Loss = 0.029
# Epoch = 3, batch = 1900 of 4000, loss = 0.829, LR = 0.0006545084971874737
# Validation Loss = 0.006
# Epoch = 3, batch = 2000 of 4000, loss = 0.743, LR = 0.0006545084971874737
# Validation Loss = 0.116
# Epoch = 3, batch = 2100 of 4000, loss = 0.947, LR = 0.0006545084971874737
# Validation Loss = 0.003
# Epoch = 3, batch = 2200 of 4000, loss = 0.805, LR = 0.0006545084971874737
# Validation Loss = 0.557
# Epoch = 3, batch = 2300 of 4000, loss = 1.105, LR = 0.0006545084971874737
# Validation Loss = 0.563
# Epoch = 3, batch = 2400 of 4000, loss = 1.595, LR = 0.0006545084971874737
# Validation Loss = 0.336
# Epoch = 3, batch = 2500 of 4000, loss = 0.878, LR = 0.0006545084971874737
# Validation Loss = 0.330
# Epoch = 3, batch = 2600 of 4000, loss = 1.381, LR = 0.0006545084971874737
# Validation Loss = 0.270
# Epoch = 3, batch = 2700 of 4000, loss = 1.336, LR = 0.0006545084971874737
# Validation Loss = 0.001
# Epoch = 3, batch = 2800 of 4000, loss = 0.788, LR = 0.0006545084971874737
# Validation Loss = 0.065
# Epoch = 3, batch = 2900 of 4000, loss = 0.955, LR = 0.0006545084971874737
# Validation Loss = 0.000
# Epoch = 3, batch = 3000 of 4000, loss = 0.684, LR = 0.0006545084971874737
# Validation Loss = 0.276
# Epoch = 3, batch = 3100 of 4000, loss = 1.169, LR = 0.0006545084971874737
# Validation Loss = 0.046
# Epoch = 3, batch = 3200 of 4000, loss = 0.801, LR = 0.0006545084971874737
# Validation Loss = 0.203
# Epoch = 3, batch = 3300 of 4000, loss = 0.786, LR = 0.0006545084971874737
# Validation Loss = 0.017
# Epoch = 3, batch = 3400 of 4000, loss = 0.865, LR = 0.0006545084971874737
# Validation Loss = 0.288
# Epoch = 3, batch = 3500 of 4000, loss = 1.247, LR = 0.0006545084971874737
# Validation Loss = 0.093
# Epoch = 3, batch = 3600 of 4000, loss = 0.752, LR = 0.0006545084971874737
# Validation Loss = 1.084
# Epoch = 3, batch = 3700 of 4000, loss = 1.280, LR = 0.0006545084971874737
# Validation Loss = 0.416
# Epoch = 3, batch = 3800 of 4000, loss = 0.956, LR = 0.0006545084971874737
# Validation Loss = 0.030
# Epoch = 3, batch = 3900 of 4000, loss = 0.715, LR = 0.0006545084971874737
# Validation Loss = 0.574
# Epoch = 4, batch = 0 of 4000, loss = 0.961, LR = 0.00034549150281252633
# Validation Loss = 0.006
# Epoch = 4, batch = 100 of 4000, loss = 0.804, LR = 0.00034549150281252633
# Validation Loss = 0.200
# Epoch = 4, batch = 200 of 4000, loss = 0.774, LR = 0.00034549150281252633
# Validation Loss = 0.069
# Epoch = 4, batch = 300 of 4000, loss = 0.797, LR = 0.00034549150281252633
# Validation Loss = 0.315
# Epoch = 4, batch = 400 of 4000, loss = 0.794, LR = 0.00034549150281252633
# Validation Loss = 0.103
# Epoch = 4, batch = 500 of 4000, loss = 0.723, LR = 0.00034549150281252633
# Validation Loss = 0.057
# Epoch = 4, batch = 600 of 4000, loss = 0.714, LR = 0.00034549150281252633
# Validation Loss = 0.060
# Epoch = 4, batch = 700 of 4000, loss = 0.727, LR = 0.00034549150281252633
# Validation Loss = 0.080
# Epoch = 4, batch = 800 of 4000, loss = 0.717, LR = 0.00034549150281252633
# Validation Loss = 0.085
# Epoch = 4, batch = 900 of 4000, loss = 0.655, LR = 0.00034549150281252633
# Validation Loss = 0.002
# Epoch = 4, batch = 1000 of 4000, loss = 0.866, LR = 0.00034549150281252633
# Validation Loss = 0.061
# Epoch = 4, batch = 1100 of 4000, loss = 0.723, LR = 0.00034549150281252633
# Validation Loss = 0.223
# Epoch = 4, batch = 1200 of 4000, loss = 0.742, LR = 0.00034549150281252633
# Validation Loss = 0.083
# Epoch = 4, batch = 1300 of 4000, loss = 1.077, LR = 0.00034549150281252633
# Validation Loss = 0.403
# Epoch = 4, batch = 1400 of 4000, loss = 0.870, LR = 0.00034549150281252633
# Validation Loss = 0.132
# Epoch = 4, batch = 1500 of 4000, loss = 0.734, LR = 0.00034549150281252633
# Validation Loss = 0.458
# Epoch = 4, batch = 1600 of 4000, loss = 0.827, LR = 0.00034549150281252633
# Validation Loss = 0.166
# Epoch = 4, batch = 1700 of 4000, loss = 0.690, LR = 0.00034549150281252633
# Validation Loss = 0.594
# Epoch = 4, batch = 1800 of 4000, loss = 0.911, LR = 0.00034549150281252633
# Validation Loss = 0.068
# Epoch = 4, batch = 1900 of 4000, loss = 0.849, LR = 0.00034549150281252633
# Validation Loss = 0.031
# Epoch = 4, batch = 2000 of 4000, loss = 0.727, LR = 0.00034549150281252633
# Validation Loss = 0.434
# Epoch = 4, batch = 2100 of 4000, loss = 0.805, LR = 0.00034549150281252633
# Validation Loss = 0.014
# Epoch = 4, batch = 2200 of 4000, loss = 0.786, LR = 0.00034549150281252633
# Validation Loss = 0.343
# Epoch = 4, batch = 2300 of 4000, loss = 0.824, LR = 0.00034549150281252633
# Validation Loss = 0.015
# Epoch = 4, batch = 2400 of 4000, loss = 0.764, LR = 0.00034549150281252633
# Validation Loss = 0.005
# Epoch = 4, batch = 2500 of 4000, loss = 0.847, LR = 0.00034549150281252633
# Validation Loss = 0.634
# Epoch = 4, batch = 2600 of 4000, loss = 0.911, LR = 0.00034549150281252633
# Validation Loss = 0.461
# Epoch = 4, batch = 2700 of 4000, loss = 0.841, LR = 0.00034549150281252633
# Validation Loss = 0.026
# Epoch = 4, batch = 2800 of 4000, loss = 0.970, LR = 0.00034549150281252633
# Validation Loss = 0.002
# Epoch = 4, batch = 2900 of 4000, loss = 0.944, LR = 0.00034549150281252633
# Validation Loss = 0.014
# Epoch = 4, batch = 3000 of 4000, loss = 0.873, LR = 0.00034549150281252633
# Validation Loss = 0.304
# Epoch = 4, batch = 3100 of 4000, loss = 0.822, LR = 0.00034549150281252633
# Validation Loss = 0.003
# Epoch = 4, batch = 3200 of 4000, loss = 0.815, LR = 0.00034549150281252633
# Validation Loss = 0.005
# Epoch = 4, batch = 3300 of 4000, loss = 0.819, LR = 0.00034549150281252633
# Validation Loss = 0.027
# Epoch = 4, batch = 3400 of 4000, loss = 1.036, LR = 0.00034549150281252633
# Validation Loss = 0.039
# Epoch = 4, batch = 3500 of 4000, loss = 0.815, LR = 0.00034549150281252633
# Validation Loss = 0.192
# Epoch = 4, batch = 3600 of 4000, loss = 1.415, LR = 0.00034549150281252633
# Validation Loss = 0.210
# Epoch = 4, batch = 3700 of 4000, loss = 0.773, LR = 0.00034549150281252633
# Validation Loss = 0.076
# Epoch = 4, batch = 3800 of 4000, loss = 0.769, LR = 0.00034549150281252633
# Validation Loss = 0.390
# Epoch = 4, batch = 3900 of 4000, loss = 0.813, LR = 0.00034549150281252633
# Validation Loss = 0.326
# Epoch = 5, batch = 0 of 4000, loss = 1.494, LR = 9.549150281252633e-05
# Validation Loss = 0.103
# Epoch = 5, batch = 100 of 4000, loss = 0.700, LR = 9.549150281252633e-05
# Validation Loss = 0.134
# Epoch = 5, batch = 200 of 4000, loss = 0.734, LR = 9.549150281252633e-05
# Validation Loss = 0.274
# Epoch = 5, batch = 300 of 4000, loss = 0.703, LR = 9.549150281252633e-05
# Validation Loss = 0.110
# Epoch = 5, batch = 400 of 4000, loss = 0.783, LR = 9.549150281252633e-05
# Validation Loss = 0.161
# Epoch = 5, batch = 500 of 4000, loss = 0.789, LR = 9.549150281252633e-05
# Validation Loss = 0.158
# Epoch = 5, batch = 600 of 4000, loss = 0.742, LR = 9.549150281252633e-05
# Validation Loss = 0.221
# Epoch = 5, batch = 700 of 4000, loss = 0.797, LR = 9.549150281252633e-05
# Validation Loss = 0.113
# Epoch = 5, batch = 800 of 4000, loss = 0.694, LR = 9.549150281252633e-05
# Validation Loss = 0.070
# Epoch = 5, batch = 900 of 4000, loss = 0.765, LR = 9.549150281252633e-05
# Validation Loss = 0.098
# Epoch = 5, batch = 1000 of 4000, loss = 0.765, LR = 9.549150281252633e-05
# Validation Loss = 0.111
# Epoch = 5, batch = 1100 of 4000, loss = 0.742, LR = 9.549150281252633e-05
# Validation Loss = 0.105
# Epoch = 5, batch = 1200 of 4000, loss = 0.718, LR = 9.549150281252633e-05
# Validation Loss = 0.214
# Epoch = 5, batch = 1300 of 4000, loss = 0.735, LR = 9.549150281252633e-05
# Validation Loss = 0.175
# Epoch = 5, batch = 1400 of 4000, loss = 0.722, LR = 9.549150281252633e-05
# Validation Loss = 0.044
# Epoch = 5, batch = 1500 of 4000, loss = 0.803, LR = 9.549150281252633e-05
# Validation Loss = 0.146
# Epoch = 5, batch = 1600 of 4000, loss = 0.779, LR = 9.549150281252633e-05
# Validation Loss = 0.144
# Epoch = 5, batch = 1700 of 4000, loss = 0.705, LR = 9.549150281252633e-05
# Validation Loss = 0.160
# Epoch = 5, batch = 1800 of 4000, loss = 0.716, LR = 9.549150281252633e-05
# Validation Loss = 0.108
# Epoch = 5, batch = 1900 of 4000, loss = 0.772, LR = 9.549150281252633e-05
# Validation Loss = 0.082
# Epoch = 5, batch = 2000 of 4000, loss = 0.706, LR = 9.549150281252633e-05
# Validation Loss = 0.115
# Epoch = 5, batch = 2100 of 4000, loss = 0.731, LR = 9.549150281252633e-05
# Validation Loss = 0.129
# Epoch = 5, batch = 2200 of 4000, loss = 0.712, LR = 9.549150281252633e-05
# Validation Loss = 0.207
# Epoch = 5, batch = 2300 of 4000, loss = 0.729, LR = 9.549150281252633e-05
# Validation Loss = 0.195
# Epoch = 5, batch = 2400 of 4000, loss = 0.666, LR = 9.549150281252633e-05
# Validation Loss = 0.257
# Epoch = 5, batch = 2500 of 4000, loss = 0.808, LR = 9.549150281252633e-05
# Validation Loss = 0.158
# Epoch = 5, batch = 2600 of 4000, loss = 0.697, LR = 9.549150281252633e-05
# Validation Loss = 0.029
# Epoch = 5, batch = 2700 of 4000, loss = 0.761, LR = 9.549150281252633e-05
# Validation Loss = 0.114
# Epoch = 5, batch = 2800 of 4000, loss = 0.698, LR = 9.549150281252633e-05
# Validation Loss = 0.123
# Epoch = 5, batch = 2900 of 4000, loss = 0.627, LR = 9.549150281252633e-05
# Validation Loss = 0.147
# Epoch = 5, batch = 3000 of 4000, loss = 0.671, LR = 9.549150281252633e-05
# Validation Loss = 0.286
# Epoch = 5, batch = 3100 of 4000, loss = 0.724, LR = 9.549150281252633e-05
# Validation Loss = 0.157
# Epoch = 5, batch = 3200 of 4000, loss = 0.823, LR = 9.549150281252633e-05
# Validation Loss = 0.131
# Epoch = 5, batch = 3300 of 4000, loss = 0.740, LR = 9.549150281252633e-05
# Validation Loss = 0.145
# Epoch = 5, batch = 3400 of 4000, loss = 0.721, LR = 9.549150281252633e-05
# Validation Loss = 0.151
# Epoch = 5, batch = 3500 of 4000, loss = 0.734, LR = 9.549150281252633e-05
# Validation Loss = 0.055
# Epoch = 5, batch = 3600 of 4000, loss = 0.750, LR = 9.549150281252633e-05
# Validation Loss = 0.099
# Epoch = 5, batch = 3700 of 4000, loss = 0.709, LR = 9.549150281252633e-05
# Validation Loss = 0.348
# Epoch = 5, batch = 3800 of 4000, loss = 0.748, LR = 9.549150281252633e-05
# Validation Loss = 0.197
# Epoch = 5, batch = 3900 of 4000, loss = 0.700, LR = 9.549150281252633e-05
# Training stage: 2
# Validation Loss = 0.179
# Epoch = 1, batch = 0 of 4000, loss = 0.728, LR = 0.001
# Validation Loss = 0.010
# Epoch = 1, batch = 100 of 4000, loss = 0.782, LR = 0.001
# Validation Loss = 0.014
# Epoch = 1, batch = 200 of 4000, loss = 0.764, LR = 0.001
# Validation Loss = 0.006
# Epoch = 1, batch = 300 of 4000, loss = 0.776, LR = 0.001
# Validation Loss = 0.006
# Epoch = 1, batch = 400 of 4000, loss = 0.741, LR = 0.001
# Validation Loss = 0.044
# Epoch = 1, batch = 500 of 4000, loss = 0.797, LR = 0.001
# Validation Loss = 0.007
# Epoch = 1, batch = 600 of 4000, loss = 0.727, LR = 0.001
# Validation Loss = 0.022
# Epoch = 1, batch = 700 of 4000, loss = 0.705, LR = 0.001
# Validation Loss = 0.048
# Epoch = 1, batch = 800 of 4000, loss = 0.744, LR = 0.001
# Validation Loss = 0.017
# Epoch = 1, batch = 900 of 4000, loss = 0.700, LR = 0.001
# Validation Loss = 0.040
# Epoch = 1, batch = 1000 of 4000, loss = 0.729, LR = 0.001
# Validation Loss = 0.001
# Epoch = 1, batch = 1100 of 4000, loss = 0.767, LR = 0.001
# Validation Loss = 0.022
# Epoch = 1, batch = 1200 of 4000, loss = 0.745, LR = 0.001
# Validation Loss = 0.017
# Epoch = 1, batch = 1300 of 4000, loss = 0.663, LR = 0.001
# Validation Loss = 0.001
# Epoch = 1, batch = 1400 of 4000, loss = 0.833, LR = 0.001
# Validation Loss = 0.142
# Epoch = 1, batch = 1500 of 4000, loss = 0.705, LR = 0.001
# Validation Loss = 0.003
# Epoch = 1, batch = 1600 of 4000, loss = 0.829, LR = 0.001
# Validation Loss = 0.241
# Epoch = 1, batch = 1700 of 4000, loss = 0.778, LR = 0.001
# Validation Loss = 0.143
# Epoch = 1, batch = 1800 of 4000, loss = 0.698, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 1900 of 4000, loss = 0.867, LR = 0.001
# Validation Loss = 0.069
# Epoch = 1, batch = 2000 of 4000, loss = 0.672, LR = 0.001
# Validation Loss = 0.017
# Epoch = 1, batch = 2100 of 4000, loss = 0.893, LR = 0.001
# Validation Loss = 0.188
# Epoch = 1, batch = 2200 of 4000, loss = 0.744, LR = 0.001
# Validation Loss = 0.935
# Epoch = 1, batch = 2300 of 4000, loss = 1.981, LR = 0.001
# Validation Loss = 0.318
# Epoch = 1, batch = 2400 of 4000, loss = 0.808, LR = 0.001
# Validation Loss = 0.790
# Epoch = 1, batch = 2500 of 4000, loss = 1.896, LR = 0.001
# Validation Loss = 0.169
# Epoch = 1, batch = 2600 of 4000, loss = 0.755, LR = 0.001
# Validation Loss = 1.616
# Epoch = 1, batch = 2700 of 4000, loss = 1.715, LR = 0.001
# Validation Loss = 1.619
# Epoch = 1, batch = 2800 of 4000, loss = 3.062, LR = 0.001
# Validation Loss = 0.377
# Epoch = 1, batch = 2900 of 4000, loss = 1.392, LR = 0.001
# Validation Loss = 0.001
# Epoch = 1, batch = 3000 of 4000, loss = 0.776, LR = 0.001
# Validation Loss = 0.034
# Epoch = 1, batch = 3100 of 4000, loss = 0.896, LR = 0.001
# Validation Loss = 1.637
# Epoch = 1, batch = 3200 of 4000, loss = 2.750, LR = 0.001
# Validation Loss = 0.224
# Epoch = 1, batch = 3300 of 4000, loss = 0.718, LR = 0.001
# Validation Loss = 1.107
# Epoch = 1, batch = 3400 of 4000, loss = 2.395, LR = 0.001
# Validation Loss = 0.401
# Epoch = 1, batch = 3500 of 4000, loss = 0.863, LR = 0.001
# Validation Loss = 0.114
# Epoch = 1, batch = 3600 of 4000, loss = 1.035, LR = 0.001
# Validation Loss = 1.518
# Epoch = 1, batch = 3700 of 4000, loss = 2.670, LR = 0.001
# Validation Loss = 0.186
# Epoch = 1, batch = 3800 of 4000, loss = 0.792, LR = 0.001
# Validation Loss = 0.794
# Epoch = 1, batch = 3900 of 4000, loss = 1.186, LR = 0.001
# Validation Loss = 0.000
# Epoch = 2, batch = 0 of 4000, loss = 0.785, LR = 0.0009755282581475768
# Validation Loss = 0.050
# Epoch = 2, batch = 100 of 4000, loss = 0.900, LR = 0.0009755282581475768
# Validation Loss = 0.031
# Epoch = 2, batch = 200 of 4000, loss = 0.652, LR = 0.0009755282581475768
# Validation Loss = 2.924
# Epoch = 2, batch = 300 of 4000, loss = 2.592, LR = 0.0009755282581475768
# Validation Loss = 0.442
# Epoch = 2, batch = 400 of 4000, loss = 0.859, LR = 0.0009755282581475768
# Validation Loss = 0.059
# Epoch = 2, batch = 500 of 4000, loss = 0.737, LR = 0.0009755282581475768
# Validation Loss = 0.447
# Epoch = 2, batch = 600 of 4000, loss = 0.959, LR = 0.0009755282581475768
# Validation Loss = 0.006
# Epoch = 2, batch = 700 of 4000, loss = 0.716, LR = 0.0009755282581475768
# Validation Loss = 0.776
# Epoch = 2, batch = 800 of 4000, loss = 1.985, LR = 0.0009755282581475768
# Validation Loss = 1.919
# Epoch = 2, batch = 900 of 4000, loss = 3.346, LR = 0.0009755282581475768
# Validation Loss = 0.481
# Epoch = 2, batch = 1000 of 4000, loss = 1.001, LR = 0.0009755282581475768
# Validation Loss = 1.050
# Epoch = 2, batch = 1100 of 4000, loss = 2.217, LR = 0.0009755282581475768
# Validation Loss = 0.074
# Epoch = 2, batch = 1200 of 4000, loss = 0.668, LR = 0.0009755282581475768
# Validation Loss = 1.770
# Epoch = 2, batch = 1300 of 4000, loss = 1.821, LR = 0.0009755282581475768
# Validation Loss = 1.252
# Epoch = 2, batch = 1400 of 4000, loss = 1.426, LR = 0.0009755282581475768
# Validation Loss = 1.899
# Epoch = 2, batch = 1500 of 4000, loss = 1.801, LR = 0.0009755282581475768
# Validation Loss = 4.220
# Epoch = 2, batch = 1600 of 4000, loss = 3.861, LR = 0.0009755282581475768
# Validation Loss = 0.353
# Epoch = 2, batch = 1700 of 4000, loss = 1.355, LR = 0.0009755282581475768
# Validation Loss = 1.134
# Epoch = 2, batch = 1800 of 4000, loss = 1.314, LR = 0.0009755282581475768
# Validation Loss = 0.011
# Epoch = 2, batch = 1900 of 4000, loss = 0.768, LR = 0.0009755282581475768
# Validation Loss = 0.408
# Epoch = 2, batch = 2000 of 4000, loss = 0.822, LR = 0.0009755282581475768
# Validation Loss = 0.273
# Epoch = 2, batch = 2100 of 4000, loss = 0.799, LR = 0.0009755282581475768
# Validation Loss = 0.143
# Epoch = 2, batch = 2200 of 4000, loss = 0.702, LR = 0.0009755282581475768
# Validation Loss = 0.334
# Epoch = 2, batch = 2300 of 4000, loss = 1.428, LR = 0.0009755282581475768
# Validation Loss = 0.337
# Epoch = 2, batch = 2400 of 4000, loss = 0.765, LR = 0.0009755282581475768
# Validation Loss = 0.052
# Epoch = 2, batch = 2500 of 4000, loss = 0.713, LR = 0.0009755282581475768
# Validation Loss = 0.273
# Epoch = 2, batch = 2600 of 4000, loss = 0.773, LR = 0.0009755282581475768
# Validation Loss = 1.431
# Epoch = 2, batch = 2700 of 4000, loss = 2.763, LR = 0.0009755282581475768
# Validation Loss = 0.193
# Epoch = 2, batch = 2800 of 4000, loss = 0.810, LR = 0.0009755282581475768
# Validation Loss = 0.244
# Epoch = 2, batch = 2900 of 4000, loss = 0.783, LR = 0.0009755282581475768
# Validation Loss = 0.228
# Epoch = 2, batch = 3000 of 4000, loss = 0.762, LR = 0.0009755282581475768
# Validation Loss = 1.646
# Epoch = 2, batch = 3100 of 4000, loss = 1.631, LR = 0.0009755282581475768
# Validation Loss = 0.000
# Epoch = 2, batch = 3200 of 4000, loss = 0.931, LR = 0.0009755282581475768
# Validation Loss = 0.758
# Epoch = 2, batch = 3300 of 4000, loss = 2.003, LR = 0.0009755282581475768
# Validation Loss = 0.094
# Epoch = 2, batch = 3400 of 4000, loss = 1.070, LR = 0.0009755282581475768
# Validation Loss = 0.034
# Epoch = 2, batch = 3500 of 4000, loss = 0.752, LR = 0.0009755282581475768
# Validation Loss = 0.397
# Epoch = 2, batch = 3600 of 4000, loss = 0.859, LR = 0.0009755282581475768
# Validation Loss = 0.040
# Epoch = 2, batch = 3700 of 4000, loss = 0.873, LR = 0.0009755282581475768
# Validation Loss = 0.025
# Epoch = 2, batch = 3800 of 4000, loss = 0.765, LR = 0.0009755282581475768
# Validation Loss = 0.081
# Epoch = 2, batch = 3900 of 4000, loss = 1.103, LR = 0.0009755282581475768
# Validation Loss = 0.171
# Epoch = 3, batch = 0 of 4000, loss = 1.233, LR = 0.0009045084971874736
# Validation Loss = 0.822
# Epoch = 3, batch = 100 of 4000, loss = 0.968, LR = 0.0009045084971874736
# Validation Loss = 0.153
# Epoch = 3, batch = 200 of 4000, loss = 1.212, LR = 0.0009045084971874736
# Validation Loss = 0.151
# Epoch = 3, batch = 300 of 4000, loss = 0.679, LR = 0.0009045084971874736
# Validation Loss = 0.810
# Epoch = 3, batch = 400 of 4000, loss = 1.050, LR = 0.0009045084971874736
# Validation Loss = 2.241
# Epoch = 3, batch = 500 of 4000, loss = 3.754, LR = 0.0009045084971874736
# Validation Loss = 1.332
# Epoch = 3, batch = 600 of 4000, loss = 1.300, LR = 0.0009045084971874736
# Validation Loss = 0.948
# Epoch = 3, batch = 700 of 4000, loss = 1.051, LR = 0.0009045084971874736
# Validation Loss = 4.343
# Epoch = 3, batch = 800 of 4000, loss = 3.425, LR = 0.0009045084971874736
# Validation Loss = 0.097
# Epoch = 3, batch = 900 of 4000, loss = 0.693, LR = 0.0009045084971874736
# Validation Loss = 0.239
# Epoch = 3, batch = 1000 of 4000, loss = 1.344, LR = 0.0009045084971874736
# Validation Loss = 0.028
# Epoch = 3, batch = 1100 of 4000, loss = 0.782, LR = 0.0009045084971874736
# Validation Loss = 0.106
# Epoch = 3, batch = 1200 of 4000, loss = 0.713, LR = 0.0009045084971874736
# Validation Loss = 0.111
# Epoch = 3, batch = 1300 of 4000, loss = 0.713, LR = 0.0009045084971874736
# Validation Loss = 0.002
# Epoch = 3, batch = 1400 of 4000, loss = 0.873, LR = 0.0009045084971874736
# Validation Loss = 0.028
# Epoch = 3, batch = 1500 of 4000, loss = 0.854, LR = 0.0009045084971874736
# Validation Loss = 0.029
# Epoch = 3, batch = 1600 of 4000, loss = 0.938, LR = 0.0009045084971874736
# Validation Loss = 0.941
# Epoch = 3, batch = 1700 of 4000, loss = 1.057, LR = 0.0009045084971874736
# Validation Loss = 0.096
# Epoch = 3, batch = 1800 of 4000, loss = 0.765, LR = 0.0009045084971874736
# Validation Loss = 0.028
# Epoch = 3, batch = 1900 of 4000, loss = 0.986, LR = 0.0009045084971874736
# Validation Loss = 0.416
# Epoch = 3, batch = 2000 of 4000, loss = 0.712, LR = 0.0009045084971874736
# Validation Loss = 0.018
# Epoch = 3, batch = 2100 of 4000, loss = 0.793, LR = 0.0009045084971874736
# Validation Loss = 0.545
# Epoch = 3, batch = 2200 of 4000, loss = 0.734, LR = 0.0009045084971874736
# Validation Loss = 0.004
# Epoch = 3, batch = 2300 of 4000, loss = 0.839, LR = 0.0009045084971874736
# Validation Loss = 0.031
# Epoch = 3, batch = 2400 of 4000, loss = 0.751, LR = 0.0009045084971874736
# Validation Loss = 0.217
# Epoch = 3, batch = 2500 of 4000, loss = 0.748, LR = 0.0009045084971874736
# Validation Loss = 0.400
# Epoch = 3, batch = 2600 of 4000, loss = 1.602, LR = 0.0009045084971874736
# Validation Loss = 0.009
# Epoch = 3, batch = 2700 of 4000, loss = 0.802, LR = 0.0009045084971874736
# Validation Loss = 1.202
# Epoch = 3, batch = 2800 of 4000, loss = 1.162, LR = 0.0009045084971874736
# Validation Loss = 0.015
# Epoch = 3, batch = 2900 of 4000, loss = 0.730, LR = 0.0009045084971874736
# Validation Loss = 0.507
# Epoch = 3, batch = 3000 of 4000, loss = 0.812, LR = 0.0009045084971874736
# Validation Loss = 0.054
# Epoch = 3, batch = 3100 of 4000, loss = 1.053, LR = 0.0009045084971874736
# Validation Loss = 1.273
# Epoch = 3, batch = 3200 of 4000, loss = 1.259, LR = 0.0009045084971874736
# Validation Loss = 2.453
# Epoch = 3, batch = 3300 of 4000, loss = 1.946, LR = 0.0009045084971874736
# Validation Loss = 1.507
# Epoch = 3, batch = 3400 of 4000, loss = 1.425, LR = 0.0009045084971874736
# Validation Loss = 0.755
# Epoch = 3, batch = 3500 of 4000, loss = 0.894, LR = 0.0009045084971874736
# Validation Loss = 0.001
# Epoch = 3, batch = 3600 of 4000, loss = 0.899, LR = 0.0009045084971874736
# Validation Loss = 2.942
# Epoch = 3, batch = 3700 of 4000, loss = 2.530, LR = 0.0009045084971874736
# Validation Loss = 0.019
# Epoch = 3, batch = 3800 of 4000, loss = 0.761, LR = 0.0009045084971874736
# Validation Loss = 0.154
# Epoch = 3, batch = 3900 of 4000, loss = 0.648, LR = 0.0009045084971874736
# Validation Loss = 0.061
# Epoch = 4, batch = 0 of 4000, loss = 0.781, LR = 0.0007938926261462366
# Validation Loss = 0.483
# Epoch = 4, batch = 100 of 4000, loss = 0.816, LR = 0.0007938926261462366
# Validation Loss = 0.005
# Epoch = 4, batch = 200 of 4000, loss = 0.990, LR = 0.0007938926261462366
# Validation Loss = 1.607
# Epoch = 4, batch = 300 of 4000, loss = 1.366, LR = 0.0007938926261462366
# Validation Loss = 1.110
# Epoch = 4, batch = 400 of 4000, loss = 1.113, LR = 0.0007938926261462366
# Validation Loss = 0.028
# Epoch = 4, batch = 500 of 4000, loss = 0.995, LR = 0.0007938926261462366
# Validation Loss = 0.512
# Epoch = 4, batch = 600 of 4000, loss = 0.826, LR = 0.0007938926261462366
# Validation Loss = 1.729
# Epoch = 4, batch = 700 of 4000, loss = 1.357, LR = 0.0007938926261462366
# Validation Loss = 0.479
# Epoch = 4, batch = 800 of 4000, loss = 0.766, LR = 0.0007938926261462366
# Validation Loss = 0.022
# Epoch = 4, batch = 900 of 4000, loss = 1.055, LR = 0.0007938926261462366
# Validation Loss = 0.249
# Epoch = 4, batch = 1000 of 4000, loss = 0.757, LR = 0.0007938926261462366
# Validation Loss = 0.781
# Epoch = 4, batch = 1100 of 4000, loss = 0.885, LR = 0.0007938926261462366
# Validation Loss = 0.358
# Epoch = 4, batch = 1200 of 4000, loss = 0.743, LR = 0.0007938926261462366
# Validation Loss = 0.041
# Epoch = 4, batch = 1300 of 4000, loss = 1.063, LR = 0.0007938926261462366
# Validation Loss = 0.007
# Epoch = 4, batch = 1400 of 4000, loss = 0.930, LR = 0.0007938926261462366
# Validation Loss = 1.709
# Epoch = 4, batch = 1500 of 4000, loss = 1.569, LR = 0.0007938926261462366
# Validation Loss = 0.241
# Epoch = 4, batch = 1600 of 4000, loss = 0.770, LR = 0.0007938926261462366
# Validation Loss = 0.019
# Epoch = 4, batch = 1700 of 4000, loss = 0.989, LR = 0.0007938926261462366
# Validation Loss = 0.031
# Epoch = 4, batch = 1800 of 4000, loss = 0.741, LR = 0.0007938926261462366
# Validation Loss = 0.003
# Epoch = 4, batch = 1900 of 4000, loss = 0.931, LR = 0.0007938926261462366
# Validation Loss = 0.593
# Epoch = 4, batch = 2000 of 4000, loss = 0.830, LR = 0.0007938926261462366
# Validation Loss = 0.004
# Epoch = 4, batch = 2100 of 4000, loss = 0.786, LR = 0.0007938926261462366
# Validation Loss = 0.799
# Epoch = 4, batch = 2200 of 4000, loss = 0.919, LR = 0.0007938926261462366
# Validation Loss = 2.769
# Epoch = 4, batch = 2300 of 4000, loss = 2.064, LR = 0.0007938926261462366
# Validation Loss = 0.001
# Epoch = 4, batch = 2400 of 4000, loss = 0.861, LR = 0.0007938926261462366
# Validation Loss = 0.000
# Epoch = 4, batch = 2500 of 4000, loss = 0.841, LR = 0.0007938926261462366
# Validation Loss = 0.000
# Epoch = 4, batch = 2600 of 4000, loss = 1.012, LR = 0.0007938926261462366
# Validation Loss = 0.182
# Epoch = 4, batch = 2700 of 4000, loss = 0.689, LR = 0.0007938926261462366
# Validation Loss = 0.627
# Epoch = 4, batch = 2800 of 4000, loss = 0.801, LR = 0.0007938926261462366
# Validation Loss = 1.315
# Epoch = 4, batch = 2900 of 4000, loss = 1.346, LR = 0.0007938926261462366
# Validation Loss = 0.750
# Epoch = 4, batch = 3000 of 4000, loss = 0.870, LR = 0.0007938926261462366
# Validation Loss = 0.440
# Epoch = 4, batch = 3100 of 4000, loss = 0.767, LR = 0.0007938926261462366
# Validation Loss = 0.165
# Epoch = 4, batch = 3200 of 4000, loss = 0.693, LR = 0.0007938926261462366
# Validation Loss = 1.420
# Epoch = 4, batch = 3300 of 4000, loss = 1.240, LR = 0.0007938926261462366
# Validation Loss = 1.306
# Epoch = 4, batch = 3400 of 4000, loss = 1.251, LR = 0.0007938926261462366
# Validation Loss = 0.576
# Epoch = 4, batch = 3500 of 4000, loss = 0.827, LR = 0.0007938926261462366
# Validation Loss = 0.533
# Epoch = 4, batch = 3600 of 4000, loss = 0.833, LR = 0.0007938926261462366
# Validation Loss = 0.289
# Epoch = 4, batch = 3700 of 4000, loss = 0.769, LR = 0.0007938926261462366
# Validation Loss = 1.214
# Epoch = 4, batch = 3800 of 4000, loss = 1.142, LR = 0.0007938926261462366
# Validation Loss = 0.012
# Epoch = 4, batch = 3900 of 4000, loss = 0.798, LR = 0.0007938926261462366
# Validation Loss = 0.138
# Epoch = 5, batch = 0 of 4000, loss = 0.754, LR = 0.0006545084971874737
# Validation Loss = 0.200
# Epoch = 5, batch = 100 of 4000, loss = 0.667, LR = 0.0006545084971874737
# Validation Loss = 0.183
# Epoch = 5, batch = 200 of 4000, loss = 0.747, LR = 0.0006545084971874737
# Validation Loss = 0.006
# Epoch = 5, batch = 300 of 4000, loss = 0.786, LR = 0.0006545084971874737
# Validation Loss = 0.036
# Epoch = 5, batch = 400 of 4000, loss = 1.046, LR = 0.0006545084971874737
# Validation Loss = 0.361
# Epoch = 5, batch = 500 of 4000, loss = 0.800, LR = 0.0006545084971874737
# Validation Loss = 0.184
# Epoch = 5, batch = 600 of 4000, loss = 0.735, LR = 0.0006545084971874737
# Validation Loss = 0.027
# Epoch = 5, batch = 700 of 4000, loss = 0.780, LR = 0.0006545084971874737
# Validation Loss = 0.190
# Epoch = 5, batch = 800 of 4000, loss = 0.706, LR = 0.0006545084971874737
# Validation Loss = 0.101
# Epoch = 5, batch = 900 of 4000, loss = 0.687, LR = 0.0006545084971874737
# Validation Loss = 0.018
# Epoch = 5, batch = 1000 of 4000, loss = 0.691, LR = 0.0006545084971874737
# Validation Loss = 0.567
# Epoch = 5, batch = 1100 of 4000, loss = 0.827, LR = 0.0006545084971874737
# Validation Loss = 0.223
# Epoch = 5, batch = 1200 of 4000, loss = 0.696, LR = 0.0006545084971874737
# Validation Loss = 0.539
# Epoch = 5, batch = 1300 of 4000, loss = 0.813, LR = 0.0006545084971874737
# Validation Loss = 0.628
# Epoch = 5, batch = 1400 of 4000, loss = 0.789, LR = 0.0006545084971874737
# Validation Loss = 0.398
# Epoch = 5, batch = 1500 of 4000, loss = 0.773, LR = 0.0006545084971874737
# Validation Loss = 0.010
# Epoch = 5, batch = 1600 of 4000, loss = 1.001, LR = 0.0006545084971874737
# Validation Loss = 0.851
# Epoch = 5, batch = 1700 of 4000, loss = 0.994, LR = 0.0006545084971874737
# Validation Loss = 0.488
# Epoch = 5, batch = 1800 of 4000, loss = 0.777, LR = 0.0006545084971874737
# Validation Loss = 0.575
# Epoch = 5, batch = 1900 of 4000, loss = 0.857, LR = 0.0006545084971874737
# Validation Loss = 0.006
# Epoch = 5, batch = 2000 of 4000, loss = 0.964, LR = 0.0006545084971874737
# Validation Loss = 0.945
# Epoch = 5, batch = 2100 of 4000, loss = 1.002, LR = 0.0006545084971874737
# Validation Loss = 0.125
# Epoch = 5, batch = 2200 of 4000, loss = 1.333, LR = 0.0006545084971874737
# Validation Loss = 0.079
# Epoch = 5, batch = 2300 of 4000, loss = 0.714, LR = 0.0006545084971874737
# Validation Loss = 0.008
# Epoch = 5, batch = 2400 of 4000, loss = 0.825, LR = 0.0006545084971874737
# Validation Loss = 0.001
# Epoch = 5, batch = 2500 of 4000, loss = 0.846, LR = 0.0006545084971874737
# Validation Loss = 0.231
# Epoch = 5, batch = 2600 of 4000, loss = 0.693, LR = 0.0006545084971874737
# Validation Loss = 1.956
# Epoch = 5, batch = 2700 of 4000, loss = 1.641, LR = 0.0006545084971874737
# Validation Loss = 0.070
# Epoch = 5, batch = 2800 of 4000, loss = 0.705, LR = 0.0006545084971874737
# Validation Loss = 0.075
# Epoch = 5, batch = 2900 of 4000, loss = 0.779, LR = 0.0006545084971874737
# Validation Loss = 0.089
# Epoch = 5, batch = 3000 of 4000, loss = 1.157, LR = 0.0006545084971874737
# Validation Loss = 0.000
# Epoch = 5, batch = 3100 of 4000, loss = 0.866, LR = 0.0006545084971874737
# Validation Loss = 2.063
# Epoch = 5, batch = 3200 of 4000, loss = 1.638, LR = 0.0006545084971874737
# Validation Loss = 0.382
# Epoch = 5, batch = 3300 of 4000, loss = 0.745, LR = 0.0006545084971874737
# Validation Loss = 0.381
# Epoch = 5, batch = 3400 of 4000, loss = 0.666, LR = 0.0006545084971874737
# Validation Loss = 0.009
# Epoch = 5, batch = 3500 of 4000, loss = 0.781, LR = 0.0006545084971874737
# Validation Loss = 0.149
# Epoch = 5, batch = 3600 of 4000, loss = 0.728, LR = 0.0006545084971874737
# Validation Loss = 0.009
# Epoch = 5, batch = 3700 of 4000, loss = 0.802, LR = 0.0006545084971874737
# Validation Loss = 1.419
# Epoch = 5, batch = 3800 of 4000, loss = 1.268, LR = 0.0006545084971874737
# Validation Loss = 0.175
# Epoch = 5, batch = 3900 of 4000, loss = 0.652, LR = 0.0006545084971874737
# Validation Loss = 0.005
# Epoch = 6, batch = 0 of 4000, loss = 0.878, LR = 0.0005
# Validation Loss = 0.088
# Epoch = 6, batch = 100 of 4000, loss = 0.753, LR = 0.0005
# Validation Loss = 0.047
# Epoch = 6, batch = 200 of 4000, loss = 0.769, LR = 0.0005
# Validation Loss = 0.001
# Epoch = 6, batch = 300 of 4000, loss = 0.870, LR = 0.0005
# Validation Loss = 0.006
# Epoch = 6, batch = 400 of 4000, loss = 0.845, LR = 0.0005
# Validation Loss = 0.280
# Epoch = 6, batch = 500 of 4000, loss = 0.754, LR = 0.0005
# Validation Loss = 0.030
# Epoch = 6, batch = 600 of 4000, loss = 0.799, LR = 0.0005
# Validation Loss = 0.143
# Epoch = 6, batch = 700 of 4000, loss = 0.752, LR = 0.0005
# Validation Loss = 1.544
# Epoch = 6, batch = 800 of 4000, loss = 1.297, LR = 0.0005
# Validation Loss = 1.270
# Epoch = 6, batch = 900 of 4000, loss = 1.190, LR = 0.0005
# Validation Loss = 0.166
# Epoch = 6, batch = 1000 of 4000, loss = 0.751, LR = 0.0005
# Validation Loss = 0.009
# Epoch = 6, batch = 1100 of 4000, loss = 0.829, LR = 0.0005
# Validation Loss = 0.036
# Epoch = 6, batch = 1200 of 4000, loss = 0.712, LR = 0.0005
# Validation Loss = 0.006
# Epoch = 6, batch = 1300 of 4000, loss = 0.946, LR = 0.0005
# Validation Loss = 0.353
# Epoch = 6, batch = 1400 of 4000, loss = 0.688, LR = 0.0005
# Validation Loss = 0.046
# Epoch = 6, batch = 1500 of 4000, loss = 0.793, LR = 0.0005
# Validation Loss = 0.594
# Epoch = 6, batch = 1600 of 4000, loss = 0.832, LR = 0.0005
# Validation Loss = 0.116
# Epoch = 6, batch = 1700 of 4000, loss = 0.707, LR = 0.0005
# Validation Loss = 0.000
# Epoch = 6, batch = 1800 of 4000, loss = 0.869, LR = 0.0005
# Validation Loss = 0.032
# Epoch = 6, batch = 1900 of 4000, loss = 1.037, LR = 0.0005
# Validation Loss = 0.215
# Epoch = 6, batch = 2000 of 4000, loss = 0.766, LR = 0.0005
# Validation Loss = 0.133
# Epoch = 6, batch = 2100 of 4000, loss = 0.734, LR = 0.0005
# Validation Loss = 1.162
# Epoch = 6, batch = 2200 of 4000, loss = 1.050, LR = 0.0005
# Validation Loss = 0.009
# Epoch = 6, batch = 2300 of 4000, loss = 1.014, LR = 0.0005
# Validation Loss = 0.189
# Epoch = 6, batch = 2400 of 4000, loss = 0.692, LR = 0.0005
# Validation Loss = 0.587
# Epoch = 6, batch = 2500 of 4000, loss = 0.883, LR = 0.0005
# Validation Loss = 0.005
# Epoch = 6, batch = 2600 of 4000, loss = 0.840, LR = 0.0005
# Validation Loss = 0.554
# Epoch = 6, batch = 2700 of 4000, loss = 0.868, LR = 0.0005
# Validation Loss = 0.010
# Epoch = 6, batch = 2800 of 4000, loss = 0.972, LR = 0.0005
# Validation Loss = 0.615
# Epoch = 6, batch = 2900 of 4000, loss = 0.778, LR = 0.0005
# Validation Loss = 0.377
# Epoch = 6, batch = 3000 of 4000, loss = 0.678, LR = 0.0005
# Validation Loss = 0.002
# Epoch = 6, batch = 3100 of 4000, loss = 0.911, LR = 0.0005
# Validation Loss = 0.362
# Epoch = 6, batch = 3200 of 4000, loss = 0.756, LR = 0.0005
# Validation Loss = 0.469
# Epoch = 6, batch = 3300 of 4000, loss = 0.845, LR = 0.0005
# Validation Loss = 0.305
# Epoch = 6, batch = 3400 of 4000, loss = 0.767, LR = 0.0005
# Validation Loss = 0.001
# Epoch = 6, batch = 3500 of 4000, loss = 0.852, LR = 0.0005
# Validation Loss = 0.212
# Epoch = 6, batch = 3600 of 4000, loss = 0.727, LR = 0.0005
# Validation Loss = 0.706
# Epoch = 6, batch = 3700 of 4000, loss = 1.043, LR = 0.0005
# Validation Loss = 0.401
# Epoch = 6, batch = 3800 of 4000, loss = 0.787, LR = 0.0005
# Validation Loss = 0.001
# Epoch = 6, batch = 3900 of 4000, loss = 0.861, LR = 0.0005
# Validation Loss = 0.458
# Epoch = 7, batch = 0 of 4000, loss = 0.750, LR = 0.00034549150281252633
# Validation Loss = 0.010
# Epoch = 7, batch = 100 of 4000, loss = 0.708, LR = 0.00034549150281252633
# Validation Loss = 0.159
# Epoch = 7, batch = 200 of 4000, loss = 0.697, LR = 0.00034549150281252633
# Validation Loss = 0.006
# Epoch = 7, batch = 300 of 4000, loss = 0.827, LR = 0.00034549150281252633
# Validation Loss = 0.058
# Epoch = 7, batch = 400 of 4000, loss = 0.746, LR = 0.00034549150281252633
# Validation Loss = 0.365
# Epoch = 7, batch = 500 of 4000, loss = 0.754, LR = 0.00034549150281252633
# Validation Loss = 0.090
# Epoch = 7, batch = 600 of 4000, loss = 0.730, LR = 0.00034549150281252633
# Validation Loss = 0.167
# Epoch = 7, batch = 700 of 4000, loss = 0.676, LR = 0.00034549150281252633
# Validation Loss = 0.183
# Epoch = 7, batch = 800 of 4000, loss = 0.743, LR = 0.00034549150281252633
# Validation Loss = 0.147
# Epoch = 7, batch = 900 of 4000, loss = 0.745, LR = 0.00034549150281252633
# Validation Loss = 0.107
# Epoch = 7, batch = 1000 of 4000, loss = 0.713, LR = 0.00034549150281252633
# Validation Loss = 0.178
# Epoch = 7, batch = 1100 of 4000, loss = 0.717, LR = 0.00034549150281252633
# Validation Loss = 0.468
# Epoch = 7, batch = 1200 of 4000, loss = 0.794, LR = 0.00034549150281252633
# Validation Loss = 0.240
# Epoch = 7, batch = 1300 of 4000, loss = 0.693, LR = 0.00034549150281252633
# Validation Loss = 0.000
# Epoch = 7, batch = 1400 of 4000, loss = 0.852, LR = 0.00034549150281252633
# Validation Loss = 0.722
# Epoch = 7, batch = 1500 of 4000, loss = 0.876, LR = 0.00034549150281252633
# Validation Loss = 0.133
# Epoch = 7, batch = 1600 of 4000, loss = 0.681, LR = 0.00034549150281252633
# Validation Loss = 0.251
# Epoch = 7, batch = 1700 of 4000, loss = 0.702, LR = 0.00034549150281252633
# Validation Loss = 0.338
# Epoch = 7, batch = 1800 of 4000, loss = 0.767, LR = 0.00034549150281252633
# Validation Loss = 0.426
# Epoch = 7, batch = 1900 of 4000, loss = 0.800, LR = 0.00034549150281252633
# Validation Loss = 0.311
# Epoch = 7, batch = 2000 of 4000, loss = 0.722, LR = 0.00034549150281252633
# Validation Loss = 0.399
# Epoch = 7, batch = 2100 of 4000, loss = 0.728, LR = 0.00034549150281252633
# Validation Loss = 0.754
# Epoch = 7, batch = 2200 of 4000, loss = 0.992, LR = 0.00034549150281252633
# Validation Loss = 0.196
# Epoch = 7, batch = 2300 of 4000, loss = 0.639, LR = 0.00034549150281252633
# Validation Loss = 0.083
# Epoch = 7, batch = 2400 of 4000, loss = 0.696, LR = 0.00034549150281252633
# Validation Loss = 0.274
# Epoch = 7, batch = 2500 of 4000, loss = 0.706, LR = 0.00034549150281252633
# Validation Loss = 0.010
# Epoch = 7, batch = 2600 of 4000, loss = 0.769, LR = 0.00034549150281252633
# Validation Loss = 0.482
# Epoch = 7, batch = 2700 of 4000, loss = 0.744, LR = 0.00034549150281252633
# Validation Loss = 0.197
# Epoch = 7, batch = 2800 of 4000, loss = 0.739, LR = 0.00034549150281252633
# Validation Loss = 0.102
# Epoch = 7, batch = 2900 of 4000, loss = 0.785, LR = 0.00034549150281252633
# Validation Loss = 0.251
# Epoch = 7, batch = 3000 of 4000, loss = 0.718, LR = 0.00034549150281252633
# Validation Loss = 0.010
# Epoch = 7, batch = 3100 of 4000, loss = 0.937, LR = 0.00034549150281252633
# Validation Loss = 0.005
# Epoch = 7, batch = 3200 of 4000, loss = 0.980, LR = 0.00034549150281252633
# Validation Loss = 0.203
# Epoch = 7, batch = 3300 of 4000, loss = 0.736, LR = 0.00034549150281252633
# Validation Loss = 0.086
# Epoch = 7, batch = 3400 of 4000, loss = 0.788, LR = 0.00034549150281252633
# Validation Loss = 0.243
# Epoch = 7, batch = 3500 of 4000, loss = 0.695, LR = 0.00034549150281252633
# Validation Loss = 0.506
# Epoch = 7, batch = 3600 of 4000, loss = 0.764, LR = 0.00034549150281252633
# Validation Loss = 0.459
# Epoch = 7, batch = 3700 of 4000, loss = 0.755, LR = 0.00034549150281252633
# Validation Loss = 0.001
# Epoch = 7, batch = 3800 of 4000, loss = 0.922, LR = 0.00034549150281252633
# Validation Loss = 0.001
# Epoch = 7, batch = 3900 of 4000, loss = 0.847, LR = 0.00034549150281252633
# Validation Loss = 0.240
# Epoch = 8, batch = 0 of 4000, loss = 0.771, LR = 0.0002061073738537635
# Validation Loss = 0.300
# Epoch = 8, batch = 100 of 4000, loss = 0.684, LR = 0.0002061073738537635
# Validation Loss = 0.260
# Epoch = 8, batch = 200 of 4000, loss = 0.711, LR = 0.0002061073738537635
# Validation Loss = 0.234
# Epoch = 8, batch = 300 of 4000, loss = 0.738, LR = 0.0002061073738537635
# Validation Loss = 0.283
# Epoch = 8, batch = 400 of 4000, loss = 0.730, LR = 0.0002061073738537635
# Validation Loss = 0.341
# Epoch = 8, batch = 500 of 4000, loss = 0.721, LR = 0.0002061073738537635
# Validation Loss = 0.097
# Epoch = 8, batch = 600 of 4000, loss = 0.660, LR = 0.0002061073738537635
# Validation Loss = 0.526
# Epoch = 8, batch = 700 of 4000, loss = 0.819, LR = 0.0002061073738537635
# Validation Loss = 0.154
# Epoch = 8, batch = 800 of 4000, loss = 0.690, LR = 0.0002061073738537635
# Validation Loss = 0.118
# Epoch = 8, batch = 900 of 4000, loss = 0.707, LR = 0.0002061073738537635
# Validation Loss = 0.396
# Epoch = 8, batch = 1000 of 4000, loss = 0.749, LR = 0.0002061073738537635
# Validation Loss = 0.114
# Epoch = 8, batch = 1100 of 4000, loss = 0.747, LR = 0.0002061073738537635
# Validation Loss = 0.287
# Epoch = 8, batch = 1200 of 4000, loss = 0.703, LR = 0.0002061073738537635
# Validation Loss = 0.239
# Epoch = 8, batch = 1300 of 4000, loss = 0.792, LR = 0.0002061073738537635
# Validation Loss = 0.032
# Epoch = 8, batch = 1400 of 4000, loss = 0.779, LR = 0.0002061073738537635
# Validation Loss = 0.036
# Epoch = 8, batch = 1500 of 4000, loss = 0.780, LR = 0.0002061073738537635
# Validation Loss = 0.281
# Epoch = 8, batch = 1600 of 4000, loss = 0.644, LR = 0.0002061073738537635
# Validation Loss = 0.159
# Epoch = 8, batch = 1700 of 4000, loss = 0.767, LR = 0.0002061073738537635
# Validation Loss = 0.123
# Epoch = 8, batch = 1800 of 4000, loss = 0.749, LR = 0.0002061073738537635
# Validation Loss = 0.154
# Epoch = 8, batch = 1900 of 4000, loss = 0.688, LR = 0.0002061073738537635
# Validation Loss = 0.224
# Epoch = 8, batch = 2000 of 4000, loss = 0.692, LR = 0.0002061073738537635
# Validation Loss = 0.269
# Epoch = 8, batch = 2100 of 4000, loss = 0.711, LR = 0.0002061073738537635
# Validation Loss = 0.086
# Epoch = 8, batch = 2200 of 4000, loss = 0.697, LR = 0.0002061073738537635
# Validation Loss = 0.179
# Epoch = 8, batch = 2300 of 4000, loss = 0.679, LR = 0.0002061073738537635
# Validation Loss = 0.218
# Epoch = 8, batch = 2400 of 4000, loss = 0.681, LR = 0.0002061073738537635
# Validation Loss = 0.232
# Epoch = 8, batch = 2500 of 4000, loss = 0.721, LR = 0.0002061073738537635
# Validation Loss = 0.274
# Epoch = 8, batch = 2600 of 4000, loss = 0.658, LR = 0.0002061073738537635
# Validation Loss = 0.299
# Epoch = 8, batch = 2700 of 4000, loss = 0.698, LR = 0.0002061073738537635
# Validation Loss = 0.058
# Epoch = 8, batch = 2800 of 4000, loss = 0.792, LR = 0.0002061073738537635
# Validation Loss = 0.230
# ...
# Validation Loss = 0.061
# Epoch = 5, batch = 3200 of 4000, loss = 1.163, LR = 0.0006545084971874737
# Validation Loss = 0.014
# Epoch = 5, batch = 3300 of 4000, loss = 0.786, LR = 0.0006545084971874737
# Validation Loss = 0.593
# Epoch = 5, batch = 3400 of 4000, loss = 0.946, LR = 0.0006545084971874737
# Validation Loss = 0.590
# Epoch = 5, batch = 3500 of 4000, loss = 1.924, LR = 0.0006545084971874737
# Validation Loss = 0.573
# Epoch = 5, batch = 3600 of 4000, loss = 0.916, LR = 0.0006545084971874737
# Validation Loss = 0.853
# Epoch = 5, batch = 3700 of 4000, loss = 1.014, LR = 0.0006545084971874737
# Validation Loss = 0.476
# Epoch = 5, batch = 3800 of 4000, loss = 0.901, LR = 0.0006545084971874737
# Validation Loss = 0.479
# Epoch = 5, batch = 3900 of 4000, loss = 0.843, LR = 0.0006545084971874737
# Validation Loss = 0.001
# Epoch = 6, batch = 0 of 4000, loss = 1.019, LR = 0.0005
# Validation Loss = 0.250
# Epoch = 6, batch = 100 of 4000, loss = 0.758, LR = 0.0005
# Validation Loss = 0.109
# Epoch = 6, batch = 200 of 4000, loss = 0.910, LR = 0.0005
# Validation Loss = 0.172
# Epoch = 6, batch = 300 of 4000, loss = 0.784, LR = 0.0005
# Validation Loss = 0.110
# Epoch = 6, batch = 400 of 4000, loss = 0.822, LR = 0.0005
# Validation Loss = 0.133
# Epoch = 6, batch = 500 of 4000, loss = 0.826, LR = 0.0005
# Validation Loss = 0.700
# Epoch = 6, batch = 600 of 4000, loss = 0.874, LR = 0.0005
# Validation Loss = 0.325
# Epoch = 6, batch = 700 of 4000, loss = 0.911, LR = 0.0005
# Validation Loss = 0.137
# Epoch = 6, batch = 800 of 4000, loss = 0.886, LR = 0.0005
# Validation Loss = 0.013
# Epoch = 6, batch = 900 of 4000, loss = 1.095, LR = 0.0005
# Validation Loss = 1.092
# Epoch = 6, batch = 1000 of 4000, loss = 1.227, LR = 0.0005
# Validation Loss = 0.040
# Epoch = 6, batch = 1100 of 4000, loss = 1.151, LR = 0.0005
# Validation Loss = 0.967
# Epoch = 6, batch = 1200 of 4000, loss = 0.992, LR = 0.0005
# Validation Loss = 0.085
# Epoch = 6, batch = 1300 of 4000, loss = 0.891, LR = 0.0005
# Validation Loss = 0.081
# Epoch = 6, batch = 1400 of 4000, loss = 0.843, LR = 0.0005
# Validation Loss = 0.171
# Epoch = 6, batch = 1500 of 4000, loss = 0.793, LR = 0.0005
# Validation Loss = 1.101
# Epoch = 6, batch = 1600 of 4000, loss = 1.168, LR = 0.0005
# Validation Loss = 0.091
# Epoch = 6, batch = 1700 of 4000, loss = 1.022, LR = 0.0005
# Validation Loss = 0.172
# Epoch = 6, batch = 1800 of 4000, loss = 0.782, LR = 0.0005
# Validation Loss = 0.005
# Epoch = 6, batch = 1900 of 4000, loss = 0.913, LR = 0.0005
# Validation Loss = 0.004
# Epoch = 6, batch = 2000 of 4000, loss = 1.009, LR = 0.0005
# Validation Loss = 0.168
# Epoch = 6, batch = 2100 of 4000, loss = 1.414, LR = 0.0005
# Validation Loss = 0.221
# Epoch = 6, batch = 2200 of 4000, loss = 0.773, LR = 0.0005
# Validation Loss = 0.169
# Epoch = 6, batch = 2300 of 4000, loss = 0.787, LR = 0.0005
# Validation Loss = 0.009
# Epoch = 6, batch = 2400 of 4000, loss = 0.846, LR = 0.0005
# Validation Loss = 0.104
# Epoch = 6, batch = 2500 of 4000, loss = 0.779, LR = 0.0005
# Validation Loss = 0.158
# Epoch = 6, batch = 2600 of 4000, loss = 0.858, LR = 0.0005
# Validation Loss = 0.127
# Epoch = 6, batch = 2700 of 4000, loss = 0.844, LR = 0.0005
# Validation Loss = 0.159
# Epoch = 6, batch = 2800 of 4000, loss = 0.769, LR = 0.0005
# Validation Loss = 0.228
# Epoch = 6, batch = 2900 of 4000, loss = 0.716, LR = 0.0005
# Validation Loss = 0.005
# Epoch = 6, batch = 3000 of 4000, loss = 0.918, LR = 0.0005
# Validation Loss = 0.140
# Epoch = 6, batch = 3100 of 4000, loss = 0.808, LR = 0.0005
# Validation Loss = 0.007
# Epoch = 6, batch = 3200 of 4000, loss = 0.970, LR = 0.0005
# Validation Loss = 0.327
# Epoch = 6, batch = 3300 of 4000, loss = 0.822, LR = 0.0005
# Validation Loss = 1.133
# Epoch = 6, batch = 3400 of 4000, loss = 1.164, LR = 0.0005
# Validation Loss = 0.121
# Epoch = 6, batch = 3500 of 4000, loss = 1.266, LR = 0.0005
# Validation Loss = 0.236
# Epoch = 6, batch = 3600 of 4000, loss = 0.821, LR = 0.0005
# Validation Loss = 0.192
# Epoch = 6, batch = 3700 of 4000, loss = 0.751, LR = 0.0005
# Validation Loss = 1.861
# Epoch = 6, batch = 3800 of 4000, loss = 1.609, LR = 0.0005
# Validation Loss = 0.064
# Epoch = 6, batch = 3900 of 4000, loss = 0.865, LR = 0.0005
# Validation Loss = 0.406
# Epoch = 7, batch = 0 of 4000, loss = 0.867, LR = 0.00034549150281252633
# Validation Loss = 0.371
# Epoch = 7, batch = 100 of 4000, loss = 0.850, LR = 0.00034549150281252633
# Validation Loss = 0.098
# Epoch = 7, batch = 200 of 4000, loss = 0.786, LR = 0.00034549150281252633
# Validation Loss = 0.061
# Epoch = 7, batch = 300 of 4000, loss = 0.875, LR = 0.00034549150281252633
# Validation Loss = 0.418
# Epoch = 7, batch = 400 of 4000, loss = 1.029, LR = 0.00034549150281252633
# Validation Loss = 0.000
# Epoch = 7, batch = 500 of 4000, loss = 0.915, LR = 0.00034549150281252633
# Validation Loss = 0.000
# Epoch = 7, batch = 600 of 4000, loss = 0.939, LR = 0.00034549150281252633
# Validation Loss = 0.168
# Epoch = 7, batch = 700 of 4000, loss = 0.814, LR = 0.00034549150281252633
# Validation Loss = 0.005
# Epoch = 7, batch = 800 of 4000, loss = 0.983, LR = 0.00034549150281252633
# Validation Loss = 0.013
# Epoch = 7, batch = 900 of 4000, loss = 0.830, LR = 0.00034549150281252633
# Validation Loss = 0.102
# Epoch = 7, batch = 1000 of 4000, loss = 0.863, LR = 0.00034549150281252633
# Validation Loss = 0.118
# Epoch = 7, batch = 1100 of 4000, loss = 0.878, LR = 0.00034549150281252633
# Validation Loss = 0.302
# Epoch = 7, batch = 1200 of 4000, loss = 0.840, LR = 0.00034549150281252633
# Validation Loss = 0.241
# Epoch = 7, batch = 1300 of 4000, loss = 0.953, LR = 0.00034549150281252633
# Validation Loss = 0.002
# Epoch = 7, batch = 1400 of 4000, loss = 1.003, LR = 0.00034549150281252633
# Validation Loss = 0.349
# Epoch = 7, batch = 1500 of 4000, loss = 0.773, LR = 0.00034549150281252633
# Validation Loss = 0.143
# Epoch = 7, batch = 1600 of 4000, loss = 0.828, LR = 0.00034549150281252633
# Validation Loss = 0.087
# Epoch = 7, batch = 1700 of 4000, loss = 0.856, LR = 0.00034549150281252633
# Validation Loss = 0.512
# Epoch = 7, batch = 1800 of 4000, loss = 0.912, LR = 0.00034549150281252633
# Validation Loss = 0.720
# Epoch = 7, batch = 1900 of 4000, loss = 1.030, LR = 0.00034549150281252633
# Validation Loss = 0.575
# Epoch = 7, batch = 2000 of 4000, loss = 0.990, LR = 0.00034549150281252633
# Validation Loss = 0.052
# Epoch = 7, batch = 2100 of 4000, loss = 0.828, LR = 0.00034549150281252633
# Validation Loss = 0.135
# Epoch = 7, batch = 2200 of 4000, loss = 0.898, LR = 0.00034549150281252633
# Validation Loss = 0.017
# Epoch = 7, batch = 2300 of 4000, loss = 0.980, LR = 0.00034549150281252633
# Validation Loss = 0.003
# Epoch = 7, batch = 2400 of 4000, loss = 0.946, LR = 0.00034549150281252633
# Validation Loss = 0.348
# Epoch = 7, batch = 2500 of 4000, loss = 0.830, LR = 0.00034549150281252633
# Validation Loss = 0.147
# Epoch = 7, batch = 2600 of 4000, loss = 0.808, LR = 0.00034549150281252633
# Validation Loss = 0.030
# Epoch = 7, batch = 2700 of 4000, loss = 0.814, LR = 0.00034549150281252633
# Validation Loss = 0.056
# Epoch = 7, batch = 2800 of 4000, loss = 0.794, LR = 0.00034549150281252633
# Validation Loss = 1.261
# Epoch = 7, batch = 2900 of 4000, loss = 1.266, LR = 0.00034549150281252633
# Validation Loss = 0.214
# Epoch = 7, batch = 3000 of 4000, loss = 0.796, LR = 0.00034549150281252633
# Validation Loss = 0.039
# Epoch = 7, batch = 3100 of 4000, loss = 0.867, LR = 0.00034549150281252633
# Validation Loss = 0.195
# Epoch = 7, batch = 3200 of 4000, loss = 0.814, LR = 0.00034549150281252633
# Validation Loss = 0.134
# Epoch = 7, batch = 3300 of 4000, loss = 0.809, LR = 0.00034549150281252633
# Validation Loss = 0.029
# Epoch = 7, batch = 3400 of 4000, loss = 0.779, LR = 0.00034549150281252633
# Validation Loss = 0.022
# Epoch = 7, batch = 3500 of 4000, loss = 0.915, LR = 0.00034549150281252633
# Validation Loss = 0.022
# Epoch = 7, batch = 3600 of 4000, loss = 1.110, LR = 0.00034549150281252633
# Validation Loss = 0.158
# Epoch = 7, batch = 3700 of 4000, loss = 0.777, LR = 0.00034549150281252633
# Validation Loss = 0.164
# Epoch = 7, batch = 3800 of 4000, loss = 0.775, LR = 0.00034549150281252633
# Validation Loss = 0.043
# Epoch = 7, batch = 3900 of 4000, loss = 0.811, LR = 0.00034549150281252633
# Validation Loss = 0.143
# Epoch = 8, batch = 0 of 4000, loss = 0.884, LR = 0.0002061073738537635
# Validation Loss = 0.077
# Epoch = 8, batch = 100 of 4000, loss = 0.818, LR = 0.0002061073738537635
# Validation Loss = 0.003
# Epoch = 8, batch = 200 of 4000, loss = 0.829, LR = 0.0002061073738537635
# Validation Loss = 0.084
# Epoch = 8, batch = 300 of 4000, loss = 0.819, LR = 0.0002061073738537635
# Validation Loss = 0.216
# Epoch = 8, batch = 400 of 4000, loss = 0.761, LR = 0.0002061073738537635
# Validation Loss = 0.163
# Epoch = 8, batch = 500 of 4000, loss = 0.880, LR = 0.0002061073738537635
# Validation Loss = 0.115
# Epoch = 8, batch = 600 of 4000, loss = 0.819, LR = 0.0002061073738537635
# Validation Loss = 0.057
# Epoch = 8, batch = 700 of 4000, loss = 0.826, LR = 0.0002061073738537635
# Validation Loss = 0.184
# Epoch = 8, batch = 800 of 4000, loss = 0.782, LR = 0.0002061073738537635
# Validation Loss = 0.087
# Epoch = 8, batch = 900 of 4000, loss = 0.851, LR = 0.0002061073738537635
# Validation Loss = 0.315
# Epoch = 8, batch = 1000 of 4000, loss = 0.824, LR = 0.0002061073738537635
# Validation Loss = 0.155
# Epoch = 8, batch = 1100 of 4000, loss = 0.845, LR = 0.0002061073738537635
# Validation Loss = 0.087
# Epoch = 8, batch = 1200 of 4000, loss = 0.865, LR = 0.0002061073738537635
# Validation Loss = 0.307
# Epoch = 8, batch = 1300 of 4000, loss = 0.884, LR = 0.0002061073738537635
# Validation Loss = 0.186
# Epoch = 8, batch = 1400 of 4000, loss = 0.883, LR = 0.0002061073738537635
# Validation Loss = 0.108
# Epoch = 8, batch = 1500 of 4000, loss = 0.782, LR = 0.0002061073738537635
# Validation Loss = 0.367
# Epoch = 8, batch = 1600 of 4000, loss = 0.838, LR = 0.0002061073738537635
# Validation Loss = 0.042
# Epoch = 8, batch = 1700 of 4000, loss = 1.158, LR = 0.0002061073738537635
# Validation Loss = 0.070
# Epoch = 8, batch = 1800 of 4000, loss = 0.843, LR = 0.0002061073738537635
# Validation Loss = 0.016
# Epoch = 8, batch = 1900 of 4000, loss = 1.057, LR = 0.0002061073738537635
# Validation Loss = 0.309
# Epoch = 8, batch = 2000 of 4000, loss = 0.842, LR = 0.0002061073738537635
# Validation Loss = 0.137
# Epoch = 8, batch = 2100 of 4000, loss = 0.809, LR = 0.0002061073738537635
# Validation Loss = 0.198
# Epoch = 8, batch = 2200 of 4000, loss = 0.838, LR = 0.0002061073738537635
# Validation Loss = 0.403
# Epoch = 8, batch = 2300 of 4000, loss = 0.758, LR = 0.0002061073738537635
# Validation Loss = 0.091
# Epoch = 8, batch = 2400 of 4000, loss = 0.841, LR = 0.0002061073738537635
# Validation Loss = 0.180
# Epoch = 8, batch = 2500 of 4000, loss = 0.846, LR = 0.0002061073738537635
# Validation Loss = 0.001
# Epoch = 8, batch = 2600 of 4000, loss = 0.928, LR = 0.0002061073738537635
# Validation Loss = 0.217
# Epoch = 8, batch = 2700 of 4000, loss = 0.765, LR = 0.0002061073738537635
# Validation Loss = 1.563
# Epoch = 8, batch = 2800 of 4000, loss = 1.475, LR = 0.0002061073738537635
# Validation Loss = 0.197
# Epoch = 8, batch = 2900 of 4000, loss = 0.810, LR = 0.0002061073738537635
# Validation Loss = 0.147
# Epoch = 8, batch = 3000 of 4000, loss = 0.831, LR = 0.0002061073738537635
# Validation Loss = 0.309
# Epoch = 8, batch = 3100 of 4000, loss = 0.909, LR = 0.0002061073738537635
# Validation Loss = 0.247
# Epoch = 8, batch = 3200 of 4000, loss = 0.793, LR = 0.0002061073738537635
# Validation Loss = 0.216
# Epoch = 8, batch = 3300 of 4000, loss = 0.819, LR = 0.0002061073738537635
# Validation Loss = 0.206
# Epoch = 8, batch = 3400 of 4000, loss = 0.843, LR = 0.0002061073738537635
# Validation Loss = 0.207
# Epoch = 8, batch = 3500 of 4000, loss = 0.886, LR = 0.0002061073738537635
# Validation Loss = 0.191
# Epoch = 8, batch = 3600 of 4000, loss = 0.783, LR = 0.0002061073738537635
# Validation Loss = 0.196
# Epoch = 8, batch = 3700 of 4000, loss = 0.898, LR = 0.0002061073738537635
# Validation Loss = 0.009
# Epoch = 8, batch = 3800 of 4000, loss = 0.962, LR = 0.0002061073738537635
# Validation Loss = 0.125
# Epoch = 8, batch = 3900 of 4000, loss = 0.896, LR = 0.0002061073738537635
# Validation Loss = 0.264
# Epoch = 9, batch = 0 of 4000, loss = 0.792, LR = 9.549150281252634e-05
# Validation Loss = 0.052
# Epoch = 9, batch = 100 of 4000, loss = 0.856, LR = 9.549150281252634e-05
# Validation Loss = 0.182
# Epoch = 9, batch = 200 of 4000, loss = 0.716, LR = 9.549150281252634e-05
# Validation Loss = 0.084
# Epoch = 9, batch = 300 of 4000, loss = 0.865, LR = 9.549150281252634e-05
# Validation Loss = 0.069
# Epoch = 9, batch = 400 of 4000, loss = 0.794, LR = 9.549150281252634e-05
# Validation Loss = 0.097
# Epoch = 9, batch = 500 of 4000, loss = 0.761, LR = 9.549150281252634e-05
# Validation Loss = 0.153
# Epoch = 9, batch = 600 of 4000, loss = 0.802, LR = 9.549150281252634e-05
# Validation Loss = 0.060
# Epoch = 9, batch = 700 of 4000, loss = 0.777, LR = 9.549150281252634e-05
# Validation Loss = 0.189
# Epoch = 9, batch = 800 of 4000, loss = 0.846, LR = 9.549150281252634e-05
# Validation Loss = 0.178
# Epoch = 9, batch = 900 of 4000, loss = 0.777, LR = 9.549150281252634e-05
# Validation Loss = 0.140
# Epoch = 9, batch = 1000 of 4000, loss = 0.828, LR = 9.549150281252634e-05
# Validation Loss = 0.116
# Epoch = 9, batch = 1100 of 4000, loss = 0.885, LR = 9.549150281252634e-05
# Validation Loss = 0.147
# Epoch = 9, batch = 1200 of 4000, loss = 0.800, LR = 9.549150281252634e-05
# Validation Loss = 0.201
# Epoch = 9, batch = 1300 of 4000, loss = 0.769, LR = 9.549150281252634e-05
# Validation Loss = 0.222
# Epoch = 9, batch = 1400 of 4000, loss = 0.802, LR = 9.549150281252634e-05
# Validation Loss = 0.041
# Epoch = 9, batch = 1500 of 4000, loss = 0.894, LR = 9.549150281252634e-05
# Validation Loss = 0.086
# Epoch = 9, batch = 1600 of 4000, loss = 0.748, LR = 9.549150281252634e-05
# Validation Loss = 0.034
# Epoch = 9, batch = 1700 of 4000, loss = 0.881, LR = 9.549150281252634e-05
# Validation Loss = 0.094
# Epoch = 9, batch = 1800 of 4000, loss = 0.821, LR = 9.549150281252634e-05
# Validation Loss = 0.243
# Epoch = 9, batch = 1900 of 4000, loss = 0.793, LR = 9.549150281252634e-05
# Validation Loss = 0.226
# Epoch = 9, batch = 2000 of 4000, loss = 0.732, LR = 9.549150281252634e-05
# Validation Loss = 0.226
# Epoch = 9, batch = 2100 of 4000, loss = 0.754, LR = 9.549150281252634e-05
# Validation Loss = 0.254
# Epoch = 9, batch = 2200 of 4000, loss = 0.837, LR = 9.549150281252634e-05
# Validation Loss = 0.118
# Epoch = 9, batch = 2300 of 4000, loss = 0.849, LR = 9.549150281252634e-05
# Validation Loss = 0.323
# Epoch = 9, batch = 2400 of 4000, loss = 0.849, LR = 9.549150281252634e-05
# Validation Loss = 0.279
# Epoch = 9, batch = 2500 of 4000, loss = 0.828, LR = 9.549150281252634e-05
# Validation Loss = 0.096
# Epoch = 9, batch = 2600 of 4000, loss = 0.823, LR = 9.549150281252634e-05
# Validation Loss = 0.187
# Epoch = 9, batch = 2700 of 4000, loss = 0.780, LR = 9.549150281252634e-05
# Validation Loss = 0.159
# Epoch = 9, batch = 2800 of 4000, loss = 0.795, LR = 9.549150281252634e-05
# Validation Loss = 0.105
# Epoch = 9, batch = 2900 of 4000, loss = 0.801, LR = 9.549150281252634e-05
# Validation Loss = 0.229
# Epoch = 9, batch = 3000 of 4000, loss = 0.853, LR = 9.549150281252634e-05
# Validation Loss = 0.047
# Epoch = 9, batch = 3100 of 4000, loss = 0.855, LR = 9.549150281252634e-05
# Validation Loss = 0.389
# Epoch = 9, batch = 3200 of 4000, loss = 0.816, LR = 9.549150281252634e-05
# Validation Loss = 0.099
# Epoch = 9, batch = 3300 of 4000, loss = 0.846, LR = 9.549150281252634e-05
# Validation Loss = 0.143
# Epoch = 9, batch = 3400 of 4000, loss = 0.792, LR = 9.549150281252634e-05
# Validation Loss = 0.347
# Epoch = 9, batch = 3600 of 4000, loss = 0.868, LR = 9.549150281252634e-05
# Validation Loss = 0.193
# Epoch = 9, batch = 3700 of 4000, loss = 0.838, LR = 9.549150281252634e-05
# Validation Loss = 0.133
# Epoch = 9, batch = 3800 of 4000, loss = 0.789, LR = 9.549150281252634e-05
# Validation Loss = 0.210
# Epoch = 9, batch = 3900 of 4000, loss = 0.870, LR = 9.549150281252634e-05
# Validation Loss = 0.251
# Epoch = 10, batch = 0 of 4000, loss = 0.789, LR = 2.4471741852423235e-05
# Validation Loss = 0.186
# Epoch = 10, batch = 100 of 4000, loss = 0.790, LR = 2.4471741852423235e-05

# %%
#General parameters:
nchans = 5
batch_size = 1000
input_size = nchans - 1 + 1 #Remaining channels + surface type
hidden_size = 256
output_size = 1

# %%
'''

SSMI CHANNEL PREDICTION MODEL:
    2: Non-Ocean Surfaces

'''

with xr.open_dataset(f'training_data/{satellite}_training_data.nc') as f:
    
    sfctype = f.sfctype.values

    correct_sfc = sfctype > 1

    Tbs = f.Tbs.values[correct_sfc,:]
    sfctype = sfctype[correct_sfc]


#Get rid of 89s:
Tbs = Tbs[:,:-4]

#---Split data into train/test/val:
train_indcs, test_indcs, val_indcs = split_data_indcs(Tbs)

Tbs_train = Tbs[train_indcs]
Tbs_test  = Tbs[test_indcs]
Tbs_val   = Tbs[val_indcs]

sfctype_train = sfctype[train_indcs].astype(np.float32)
sfctype_test  = sfctype[test_indcs].astype(np.float32)
sfctype_val   = sfctype[val_indcs].astype(np.float32)

#---Shuffle before converting to tensors:
np.random.seed(40)
Tbs_train, shuffled_indcs = array_funcs.shuffle_data(Tbs_train, axis=0, return_indcs=True)
sfctype_train = sfctype_train[shuffled_indcs]

# %%
sfctype_train, sfctype_test, sfctype_val
# Out:
# (array([ 2.,  5., 13., ...,  2., 11., 15.], shape=(7748290,), dtype=float32),
#  array([ 8.,  8.,  8., ..., 11., 11., 11.], shape=(968536,), dtype=float32),
#  array([11., 11., 11., ..., 11., 11., 11.], shape=(968537,), dtype=float32))

# %%
'''
Predict channels: Train all models
'''

torch.set_num_threads(10)

for ichan, channel in enumerate(chan_desc):

    #---Extract channel, x = predictors, y = channel to predict
    x_train, y_train = extract_channel(Tbs_train, channel)
    x_test,  y_test  = extract_channel(Tbs_test, channel)
    x_val,   y_val   = extract_channel(Tbs_val, channel)

    x_train = np.concatenate((x_train, sfctype_train[:,None]), axis=1)
    x_test  = np.concatenate((x_test,  sfctype_test[:,None]), axis=1)
    x_val   = np.concatenate((x_val,   sfctype_val[:,None]), axis=1)
    
    x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
    x_test,  y_test  = torch.tensor(x_test), torch.tensor(y_test)
    x_val,   y_val   = torch.tensor(x_val), torch.tensor(y_val)


    #---Set up dataloaders:
    train_loader = torch.utils.data.DataLoader(dataset=dataset(x_train,y_train), 
                                               batch_size=batch_size, 
                                               shuffle=True, drop_last=True)
    test_loader = torch.utils.data.DataLoader(dataset=dataset(x_test,y_test), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)
    val_loader = torch.utils.data.DataLoader(dataset=dataset(x_val,y_val), 
                                               batch_size=None, 
                                               shuffle=False, drop_last=False)

    #---Create model:
    model = channel_predictor(input_size, hidden_size, output_size)

    #---Train_model:
    nbatches = len(train_loader)
    nepochs_stage1 = 5
    nepochs_stage2 = 10
    nepochs_stage3 = 20

    loss_stage1, valloss_stage1 = train_model(model, nepochs=5, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=1, validation_dataloader=val_loader)
    loss_stage2, valloss_stage2 = train_model(model, nepochs=10, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=2, validation_dataloader=val_loader)
    loss_stage3, valloss_stage3 = train_model(model, nepochs=20, dataloader=train_loader, 
                                          learning_rate=0.001, quiet=False, stage=3, validation_dataloader=val_loader)

    torch.save(model.state_dict(), f'models/{sensor}_{satellite}_channel_predictor_{channel}_nonocean.pt')

    loss_data = data2xarray(data_vars = (loss_stage1, loss_stage2, loss_stage3, 
                                     valloss_stage1, valloss_stage2, valloss_stage3),
                        var_names = ('LossStage1','LossStage2','LossStage3',
                                     'ValidationLossStage1', 'ValidationLossStage2', 'ValidationLossStage3'),
                        dims = (nbatches,nepochs_stage1,nepochs_stage2, nepochs_stage3),
                        dim_names = ('training_batches', 'epochs_stage1', 'epochs_stage2', 'epochs_stage3'))

    loss_data.to_netcdf(f'diagnostics/loss_data_{channel}_nonocean.nc', engine='netcdf4')

    print(f'Finished training model for channel {channel}.')
# Out:
# Training stage: 1
# Validation Loss = 41041.945
# Epoch = 1, batch = 0 of 7748, loss = 51357.312, LR = 0.001
# Validation Loss = 6.805
# Epoch = 1, batch = 100 of 7748, loss = 38.479, LR = 0.001
# Validation Loss = 4.460
# Epoch = 1, batch = 200 of 7748, loss = 17.008, LR = 0.001
# Validation Loss = 5.430
# Epoch = 1, batch = 300 of 7748, loss = 18.186, LR = 0.001
# Validation Loss = 6.189
# Epoch = 1, batch = 400 of 7748, loss = 15.277, LR = 0.001
# Validation Loss = 4.049
# Epoch = 1, batch = 500 of 7748, loss = 16.288, LR = 0.001
# Validation Loss = 0.076
# Epoch = 1, batch = 600 of 7748, loss = 11.692, LR = 0.001
# Validation Loss = 0.002
# Epoch = 1, batch = 700 of 7748, loss = 11.210, LR = 0.001
# Validation Loss = 0.009
# Epoch = 1, batch = 800 of 7748, loss = 8.332, LR = 0.001
# Validation Loss = 0.064
# Epoch = 1, batch = 900 of 7748, loss = 9.273, LR = 0.001
# Validation Loss = 0.084
# Epoch = 1, batch = 1000 of 7748, loss = 8.091, LR = 0.001
# Validation Loss = 0.023
# Epoch = 1, batch = 1100 of 7748, loss = 7.288, LR = 0.001
# Validation Loss = 0.003
# Epoch = 1, batch = 1200 of 7748, loss = 7.097, LR = 0.001
# Validation Loss = 0.023
# Epoch = 1, batch = 1300 of 7748, loss = 7.409, LR = 0.001
# Validation Loss = 0.170
# Epoch = 1, batch = 1400 of 7748, loss = 6.624, LR = 0.001
# Validation Loss = 0.021
# Epoch = 1, batch = 1500 of 7748, loss = 7.482, LR = 0.001
# Validation Loss = 0.014
# Epoch = 1, batch = 1600 of 7748, loss = 6.661, LR = 0.001
# Validation Loss = 0.135
# Epoch = 1, batch = 1700 of 7748, loss = 7.569, LR = 0.001
# Validation Loss = 0.411
# Epoch = 1, batch = 1800 of 7748, loss = 6.542, LR = 0.001
# Validation Loss = 0.050
# Epoch = 1, batch = 1900 of 7748, loss = 7.209, LR = 0.001
# Validation Loss = 0.002
# Epoch = 1, batch = 2000 of 7748, loss = 5.735, LR = 0.001
# Validation Loss = 0.224
# Epoch = 1, batch = 2100 of 7748, loss = 7.323, LR = 0.001
# Validation Loss = 0.043
# Epoch = 1, batch = 2200 of 7748, loss = 7.192, LR = 0.001
# Validation Loss = 0.099
# Epoch = 1, batch = 2300 of 7748, loss = 6.520, LR = 0.001
# Validation Loss = 0.060
# Epoch = 1, batch = 2400 of 7748, loss = 7.243, LR = 0.001
# Validation Loss = 1.365
# Epoch = 1, batch = 2500 of 7748, loss = 8.255, LR = 0.001
# Validation Loss = 0.105
# Epoch = 1, batch = 2600 of 7748, loss = 6.360, LR = 0.001
# Validation Loss = 0.523
# Epoch = 1, batch = 2700 of 7748, loss = 6.736, LR = 0.001
# Validation Loss = 0.091
# Epoch = 1, batch = 2800 of 7748, loss = 5.834, LR = 0.001
# Validation Loss = 0.326
# Epoch = 1, batch = 2900 of 7748, loss = 7.659, LR = 0.001
# Validation Loss = 0.102
# Epoch = 1, batch = 3000 of 7748, loss = 6.147, LR = 0.001
# Validation Loss = 0.158
# Epoch = 1, batch = 3100 of 7748, loss = 6.658, LR = 0.001
# Validation Loss = 0.747
# Epoch = 1, batch = 3200 of 7748, loss = 7.016, LR = 0.001
# Validation Loss = 0.566
# Epoch = 1, batch = 3300 of 7748, loss = 5.444, LR = 0.001
# Validation Loss = 1.133
# Epoch = 1, batch = 3400 of 7748, loss = 8.547, LR = 0.001
# Validation Loss = 2.596
# Epoch = 1, batch = 3500 of 7748, loss = 10.716, LR = 0.001
# Validation Loss = 1.860
# Epoch = 1, batch = 3600 of 7748, loss = 6.118, LR = 0.001
# Validation Loss = 0.086
# Epoch = 1, batch = 3700 of 7748, loss = 6.869, LR = 0.001
# Validation Loss = 3.354
# Epoch = 1, batch = 3800 of 7748, loss = 9.552, LR = 0.001
# Validation Loss = 1.907
# Epoch = 1, batch = 3900 of 7748, loss = 8.679, LR = 0.001
# Validation Loss = 1.373
# Epoch = 1, batch = 4000 of 7748, loss = 7.192, LR = 0.001
# Validation Loss = 1.217
# Epoch = 1, batch = 4100 of 7748, loss = 8.919, LR = 0.001
# Validation Loss = 2.039
# Epoch = 1, batch = 4200 of 7748, loss = 6.410, LR = 0.001
# Validation Loss = 1.034
# Epoch = 1, batch = 4300 of 7748, loss = 8.299, LR = 0.001
# Validation Loss = 4.138
# Epoch = 1, batch = 4400 of 7748, loss = 10.071, LR = 0.001
# Validation Loss = 13.348
# Epoch = 1, batch = 4500 of 7748, loss = 19.899, LR = 0.001
# Validation Loss = 1.093
# Epoch = 1, batch = 4600 of 7748, loss = 6.475, LR = 0.001
# Validation Loss = 1.744
# Epoch = 1, batch = 4700 of 7748, loss = 8.090, LR = 0.001
# Validation Loss = 1.909
# Epoch = 1, batch = 4800 of 7748, loss = 7.086, LR = 0.001
# Validation Loss = 3.957
# Epoch = 1, batch = 4900 of 7748, loss = 13.586, LR = 0.001
# Validation Loss = 8.168
# Epoch = 1, batch = 5000 of 7748, loss = 12.343, LR = 0.001
# Validation Loss = 0.618
# Epoch = 1, batch = 5100 of 7748, loss = 6.342, LR = 0.001
# Validation Loss = 0.323
# Epoch = 1, batch = 5200 of 7748, loss = 7.492, LR = 0.001
# Validation Loss = 2.943
# Epoch = 1, batch = 5300 of 7748, loss = 13.243, LR = 0.001
# Validation Loss = 0.498
# Epoch = 1, batch = 5400 of 7748, loss = 8.731, LR = 0.001
# Validation Loss = 0.282
# Epoch = 1, batch = 5500 of 7748, loss = 6.905, LR = 0.001
# Validation Loss = 1.208
# Epoch = 1, batch = 5600 of 7748, loss = 5.936, LR = 0.001
# Validation Loss = 6.336
# Epoch = 1, batch = 5700 of 7748, loss = 10.222, LR = 0.001
# Validation Loss = 0.002
# Epoch = 1, batch = 5800 of 7748, loss = 7.013, LR = 0.001
# Validation Loss = 12.757
# Epoch = 1, batch = 5900 of 7748, loss = 16.708, LR = 0.001
# Validation Loss = 0.748
# Epoch = 1, batch = 6000 of 7748, loss = 6.658, LR = 0.001
# Validation Loss = 1.293
# Epoch = 1, batch = 6100 of 7748, loss = 5.666, LR = 0.001
# Validation Loss = 6.855
# Epoch = 1, batch = 6200 of 7748, loss = 11.826, LR = 0.001
# Validation Loss = 2.143
# Epoch = 1, batch = 6300 of 7748, loss = 7.468, LR = 0.001
# Validation Loss = 0.467
# Epoch = 1, batch = 6400 of 7748, loss = 7.719, LR = 0.001
# Validation Loss = 3.331
# Epoch = 1, batch = 6500 of 7748, loss = 7.289, LR = 0.001
# Validation Loss = 0.522
# Epoch = 1, batch = 6600 of 7748, loss = 6.956, LR = 0.001
# Validation Loss = 2.803
# Epoch = 1, batch = 6700 of 7748, loss = 6.914, LR = 0.001
# Validation Loss = 0.763
# Epoch = 1, batch = 6800 of 7748, loss = 6.403, LR = 0.001
# Validation Loss = 0.583
# Epoch = 1, batch = 6900 of 7748, loss = 5.001, LR = 0.001
# Validation Loss = 1.918
# Epoch = 1, batch = 7000 of 7748, loss = 5.655, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 7100 of 7748, loss = 5.885, LR = 0.001
# Validation Loss = 0.218
# Epoch = 1, batch = 7200 of 7748, loss = 7.726, LR = 0.001
# Validation Loss = 0.960
# Epoch = 1, batch = 7300 of 7748, loss = 6.270, LR = 0.001
# Validation Loss = 0.075
# Epoch = 1, batch = 7400 of 7748, loss = 6.314, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 7500 of 7748, loss = 5.886, LR = 0.001
# Validation Loss = 0.159
# Epoch = 1, batch = 7600 of 7748, loss = 5.422, LR = 0.001
# Validation Loss = 1.301
# Epoch = 1, batch = 7700 of 7748, loss = 6.197, LR = 0.001
# Validation Loss = 8.621
# Epoch = 2, batch = 0 of 7748, loss = 10.623, LR = 0.0009045084971874737
# Validation Loss = 0.759
# Epoch = 2, batch = 100 of 7748, loss = 5.204, LR = 0.0009045084971874737
# Validation Loss = 0.193
# Epoch = 2, batch = 200 of 7748, loss = 6.353, LR = 0.0009045084971874737
# Validation Loss = 0.100
# Epoch = 2, batch = 300 of 7748, loss = 6.450, LR = 0.0009045084971874737
# Validation Loss = 0.350
# Epoch = 2, batch = 400 of 7748, loss = 5.583, LR = 0.0009045084971874737
# Validation Loss = 0.010
# Epoch = 2, batch = 500 of 7748, loss = 6.956, LR = 0.0009045084971874737
# Validation Loss = 1.071
# Epoch = 2, batch = 600 of 7748, loss = 5.872, LR = 0.0009045084971874737
# Validation Loss = 0.002
# Epoch = 2, batch = 700 of 7748, loss = 5.823, LR = 0.0009045084971874737
# Validation Loss = 0.167
# Epoch = 2, batch = 800 of 7748, loss = 5.974, LR = 0.0009045084971874737
# Validation Loss = 0.811
# Epoch = 2, batch = 900 of 7748, loss = 5.490, LR = 0.0009045084971874737
# Validation Loss = 0.020
# Epoch = 2, batch = 1000 of 7748, loss = 5.505, LR = 0.0009045084971874737
# Validation Loss = 1.320
# Epoch = 2, batch = 1100 of 7748, loss = 9.443, LR = 0.0009045084971874737
# Validation Loss = 1.043
# Epoch = 2, batch = 1200 of 7748, loss = 8.704, LR = 0.0009045084971874737
# Validation Loss = 1.328
# Epoch = 2, batch = 1300 of 7748, loss = 4.882, LR = 0.0009045084971874737
# Validation Loss = 0.194
# Epoch = 2, batch = 1400 of 7748, loss = 5.536, LR = 0.0009045084971874737
# Validation Loss = 0.007
# Epoch = 2, batch = 1500 of 7748, loss = 5.168, LR = 0.0009045084971874737
# Validation Loss = 0.001
# Epoch = 2, batch = 1600 of 7748, loss = 4.963, LR = 0.0009045084971874737
# Validation Loss = 0.771
# Epoch = 2, batch = 1700 of 7748, loss = 6.167, LR = 0.0009045084971874737
# Validation Loss = 0.052
# Epoch = 2, batch = 1800 of 7748, loss = 6.515, LR = 0.0009045084971874737
# Validation Loss = 0.883
# Epoch = 2, batch = 1900 of 7748, loss = 4.994, LR = 0.0009045084971874737
# Validation Loss = 15.074
# Epoch = 2, batch = 2000 of 7748, loss = 15.547, LR = 0.0009045084971874737
# Validation Loss = 0.005
# Epoch = 2, batch = 2100 of 7748, loss = 5.935, LR = 0.0009045084971874737
# Validation Loss = 0.000
# Epoch = 2, batch = 2200 of 7748, loss = 5.798, LR = 0.0009045084971874737
# Validation Loss = 0.207
# Epoch = 2, batch = 2300 of 7748, loss = 5.044, LR = 0.0009045084971874737
# Validation Loss = 0.405
# Epoch = 2, batch = 2400 of 7748, loss = 4.550, LR = 0.0009045084971874737
# Validation Loss = 0.000
# Epoch = 2, batch = 2500 of 7748, loss = 5.064, LR = 0.0009045084971874737
# Validation Loss = 1.406
# Epoch = 2, batch = 2600 of 7748, loss = 4.894, LR = 0.0009045084971874737
# Validation Loss = 1.635
# Epoch = 2, batch = 2700 of 7748, loss = 5.770, LR = 0.0009045084971874737
# Validation Loss = 3.640
# Epoch = 2, batch = 2800 of 7748, loss = 5.996, LR = 0.0009045084971874737
# Validation Loss = 2.189
# Epoch = 2, batch = 2900 of 7748, loss = 4.672, LR = 0.0009045084971874737
# Validation Loss = 3.677
# Epoch = 2, batch = 3000 of 7748, loss = 5.319, LR = 0.0009045084971874737
# Validation Loss = 3.027
# Epoch = 2, batch = 3100 of 7748, loss = 5.893, LR = 0.0009045084971874737
# Validation Loss = 2.112
# Epoch = 2, batch = 3200 of 7748, loss = 5.011, LR = 0.0009045084971874737
# Validation Loss = 1.375
# Epoch = 2, batch = 3300 of 7748, loss = 4.389, LR = 0.0009045084971874737
# Validation Loss = 2.691
# Epoch = 2, batch = 3400 of 7748, loss = 5.282, LR = 0.0009045084971874737
# Validation Loss = 0.161
# Epoch = 2, batch = 3500 of 7748, loss = 4.773, LR = 0.0009045084971874737
# Validation Loss = 8.527
# Epoch = 2, batch = 3600 of 7748, loss = 9.590, LR = 0.0009045084971874737
# Validation Loss = 0.003
# Epoch = 2, batch = 3700 of 7748, loss = 4.927, LR = 0.0009045084971874737
# Validation Loss = 0.313
# Epoch = 2, batch = 3800 of 7748, loss = 4.857, LR = 0.0009045084971874737
# Validation Loss = 0.014
# Epoch = 2, batch = 3900 of 7748, loss = 4.479, LR = 0.0009045084971874737
# Validation Loss = 0.515
# Epoch = 2, batch = 4000 of 7748, loss = 7.413, LR = 0.0009045084971874737
# Validation Loss = 0.447
# Epoch = 2, batch = 4100 of 7748, loss = 7.444, LR = 0.0009045084971874737
# Validation Loss = 0.936
# Epoch = 2, batch = 4200 of 7748, loss = 4.802, LR = 0.0009045084971874737
# Validation Loss = 0.360
# Epoch = 2, batch = 4300 of 7748, loss = 7.854, LR = 0.0009045084971874737
# Validation Loss = 1.595
# Epoch = 2, batch = 4400 of 7748, loss = 4.457, LR = 0.0009045084971874737
# Validation Loss = 1.260
# Epoch = 2, batch = 4500 of 7748, loss = 4.610, LR = 0.0009045084971874737
# Validation Loss = 2.085
# Epoch = 2, batch = 4600 of 7748, loss = 4.712, LR = 0.0009045084971874737
# Validation Loss = 0.156
# Epoch = 2, batch = 4700 of 7748, loss = 7.645, LR = 0.0009045084971874737
# Validation Loss = 3.064
# Epoch = 2, batch = 4800 of 7748, loss = 3.791, LR = 0.0009045084971874737
# Validation Loss = 0.210
# Epoch = 2, batch = 4900 of 7748, loss = 5.187, LR = 0.0009045084971874737
# Validation Loss = 0.107
# Epoch = 2, batch = 5000 of 7748, loss = 4.796, LR = 0.0009045084971874737
# Validation Loss = 0.253
# Epoch = 2, batch = 5100 of 7748, loss = 4.321, LR = 0.0009045084971874737
# Validation Loss = 0.285
# Epoch = 2, batch = 5200 of 7748, loss = 4.884, LR = 0.0009045084971874737
# Validation Loss = 3.983
# Epoch = 2, batch = 5300 of 7748, loss = 4.317, LR = 0.0009045084971874737
# Validation Loss = 7.739
# Epoch = 2, batch = 5400 of 7748, loss = 5.410, LR = 0.0009045084971874737
# Validation Loss = 8.321
# Epoch = 2, batch = 5500 of 7748, loss = 6.759, LR = 0.0009045084971874737
# Validation Loss = 0.127
# Epoch = 2, batch = 5600 of 7748, loss = 5.122, LR = 0.0009045084971874737
# Validation Loss = 3.548
# Epoch = 2, batch = 5700 of 7748, loss = 3.746, LR = 0.0009045084971874737
# Validation Loss = 2.720
# Epoch = 2, batch = 5800 of 7748, loss = 4.445, LR = 0.0009045084971874737
# Validation Loss = 0.115
# Epoch = 2, batch = 5900 of 7748, loss = 6.860, LR = 0.0009045084971874737
# Validation Loss = 0.208
# Epoch = 2, batch = 6000 of 7748, loss = 4.618, LR = 0.0009045084971874737
# Validation Loss = 0.995
# Epoch = 2, batch = 6100 of 7748, loss = 4.699, LR = 0.0009045084971874737
# Validation Loss = 3.250
# Epoch = 2, batch = 6200 of 7748, loss = 4.467, LR = 0.0009045084971874737
# Validation Loss = 2.194
# Epoch = 2, batch = 6300 of 7748, loss = 3.807, LR = 0.0009045084971874737
# Validation Loss = 0.409
# Epoch = 2, batch = 6400 of 7748, loss = 3.990, LR = 0.0009045084971874737
# Validation Loss = 0.058
# Epoch = 2, batch = 6500 of 7748, loss = 4.504, LR = 0.0009045084971874737
# Validation Loss = 6.455
# Epoch = 2, batch = 6600 of 7748, loss = 3.257, LR = 0.0009045084971874737
# Validation Loss = 4.004
# Epoch = 2, batch = 6700 of 7748, loss = 4.660, LR = 0.0009045084971874737
# Validation Loss = 1.357
# Epoch = 2, batch = 6800 of 7748, loss = 4.084, LR = 0.0009045084971874737
# Validation Loss = 1.555
# Epoch = 2, batch = 6900 of 7748, loss = 4.095, LR = 0.0009045084971874737
# Validation Loss = 3.497
# Epoch = 2, batch = 7000 of 7748, loss = 3.936, LR = 0.0009045084971874737
# Validation Loss = 0.791
# Epoch = 2, batch = 7100 of 7748, loss = 3.738, LR = 0.0009045084971874737
# Validation Loss = 3.251
# Epoch = 2, batch = 7200 of 7748, loss = 4.289, LR = 0.0009045084971874737
# Validation Loss = 13.065
# Epoch = 2, batch = 7300 of 7748, loss = 6.129, LR = 0.0009045084971874737
# Validation Loss = 4.055
# Epoch = 2, batch = 7400 of 7748, loss = 3.427, LR = 0.0009045084971874737
# Validation Loss = 0.232
# Epoch = 2, batch = 7500 of 7748, loss = 4.856, LR = 0.0009045084971874737
# Validation Loss = 7.623
# Epoch = 2, batch = 7600 of 7748, loss = 3.813, LR = 0.0009045084971874737
# Validation Loss = 0.577
# Epoch = 2, batch = 7700 of 7748, loss = 3.591, LR = 0.0009045084971874737
# Validation Loss = 2.106
# Epoch = 3, batch = 0 of 7748, loss = 3.574, LR = 0.0006545084971874737
# Validation Loss = 6.075
# Epoch = 3, batch = 100 of 7748, loss = 4.084, LR = 0.0006545084971874737
# Validation Loss = 0.182
# Epoch = 3, batch = 200 of 7748, loss = 4.329, LR = 0.0006545084971874737
# Validation Loss = 2.121
# Epoch = 3, batch = 300 of 7748, loss = 3.699, LR = 0.0006545084971874737
# Validation Loss = 4.250
# Epoch = 3, batch = 400 of 7748, loss = 3.608, LR = 0.0006545084971874737
# Validation Loss = 4.767
# Epoch = 3, batch = 500 of 7748, loss = 3.751, LR = 0.0006545084971874737
# Validation Loss = 2.466
# Epoch = 3, batch = 600 of 7748, loss = 2.759, LR = 0.0006545084971874737
# Validation Loss = 3.420
# Epoch = 3, batch = 700 of 7748, loss = 3.888, LR = 0.0006545084971874737
# Validation Loss = 0.790
# Epoch = 3, batch = 800 of 7748, loss = 4.046, LR = 0.0006545084971874737
# Validation Loss = 3.412
# Epoch = 3, batch = 900 of 7748, loss = 3.182, LR = 0.0006545084971874737
# Validation Loss = 6.410
# Epoch = 3, batch = 1000 of 7748, loss = 3.869, LR = 0.0006545084971874737
# Validation Loss = 3.742
# Epoch = 3, batch = 1100 of 7748, loss = 3.831, LR = 0.0006545084971874737
# Validation Loss = 3.818
# Epoch = 3, batch = 1200 of 7748, loss = 3.590, LR = 0.0006545084971874737
# Validation Loss = 3.263
# Epoch = 3, batch = 1300 of 7748, loss = 3.496, LR = 0.0006545084971874737
# Validation Loss = 3.976
# Epoch = 3, batch = 1400 of 7748, loss = 3.989, LR = 0.0006545084971874737
# Validation Loss = 0.746
# Epoch = 3, batch = 1500 of 7748, loss = 3.963, LR = 0.0006545084971874737
# Validation Loss = 1.726
# Epoch = 3, batch = 1600 of 7748, loss = 3.741, LR = 0.0006545084971874737
# Validation Loss = 1.019
# Epoch = 3, batch = 1700 of 7748, loss = 3.944, LR = 0.0006545084971874737
# Validation Loss = 1.791
# Epoch = 3, batch = 1800 of 7748, loss = 3.753, LR = 0.0006545084971874737
# Validation Loss = 0.961
# Epoch = 3, batch = 1900 of 7748, loss = 3.608, LR = 0.0006545084971874737
# Validation Loss = 0.321
# Epoch = 3, batch = 2000 of 7748, loss = 3.919, LR = 0.0006545084971874737
# Validation Loss = 3.136
# Epoch = 3, batch = 2100 of 7748, loss = 2.943, LR = 0.0006545084971874737
# Validation Loss = 9.600
# Epoch = 3, batch = 2200 of 7748, loss = 5.178, LR = 0.0006545084971874737
# Validation Loss = 1.509
# Epoch = 3, batch = 2300 of 7748, loss = 3.916, LR = 0.0006545084971874737
# Validation Loss = 8.737
# Epoch = 3, batch = 2400 of 7748, loss = 3.869, LR = 0.0006545084971874737
# Validation Loss = 1.537
# Epoch = 3, batch = 2500 of 7748, loss = 3.400, LR = 0.0006545084971874737
# Validation Loss = 7.722
# Epoch = 3, batch = 2600 of 7748, loss = 3.383, LR = 0.0006545084971874737
# Validation Loss = 6.543
# Epoch = 3, batch = 2700 of 7748, loss = 3.847, LR = 0.0006545084971874737
# Validation Loss = 2.176
# Epoch = 3, batch = 2800 of 7748, loss = 3.121, LR = 0.0006545084971874737
# Validation Loss = 11.653
# Epoch = 3, batch = 2900 of 7748, loss = 6.165, LR = 0.0006545084971874737
# Validation Loss = 13.842
# Epoch = 3, batch = 3000 of 7748, loss = 4.845, LR = 0.0006545084971874737
# Validation Loss = 8.252
# Epoch = 3, batch = 3100 of 7748, loss = 4.509, LR = 0.0006545084971874737
# Validation Loss = 4.464
# Epoch = 3, batch = 3200 of 7748, loss = 3.762, LR = 0.0006545084971874737
# Validation Loss = 5.256
# Epoch = 3, batch = 3300 of 7748, loss = 3.518, LR = 0.0006545084971874737
# Validation Loss = 2.640
# Epoch = 3, batch = 3400 of 7748, loss = 3.558, LR = 0.0006545084971874737
# Validation Loss = 4.924
# Epoch = 3, batch = 3500 of 7748, loss = 3.012, LR = 0.0006545084971874737
# Validation Loss = 0.495
# Epoch = 3, batch = 3600 of 7748, loss = 3.430, LR = 0.0006545084971874737
# Validation Loss = 5.106
# Epoch = 3, batch = 3700 of 7748, loss = 3.493, LR = 0.0006545084971874737
# Validation Loss = 6.243
# Epoch = 3, batch = 3800 of 7748, loss = 3.321, LR = 0.0006545084971874737
# Validation Loss = 1.946
# Epoch = 3, batch = 3900 of 7748, loss = 3.345, LR = 0.0006545084971874737
# Validation Loss = 1.656
# Epoch = 3, batch = 4000 of 7748, loss = 3.367, LR = 0.0006545084971874737
# Validation Loss = 2.445
# Epoch = 3, batch = 4100 of 7748, loss = 2.638, LR = 0.0006545084971874737
# Validation Loss = 4.612
# Epoch = 3, batch = 4200 of 7748, loss = 2.970, LR = 0.0006545084971874737
# Validation Loss = 14.251
# Epoch = 3, batch = 4300 of 7748, loss = 5.602, LR = 0.0006545084971874737
# Validation Loss = 2.439
# Epoch = 3, batch = 4400 of 7748, loss = 2.828, LR = 0.0006545084971874737
# Validation Loss = 10.615
# Epoch = 3, batch = 4500 of 7748, loss = 3.849, LR = 0.0006545084971874737
# Validation Loss = 2.828
# Epoch = 3, batch = 4600 of 7748, loss = 3.409, LR = 0.0006545084971874737
# Validation Loss = 3.931
# Epoch = 3, batch = 4700 of 7748, loss = 3.265, LR = 0.0006545084971874737
# Validation Loss = 7.517
# Epoch = 3, batch = 4800 of 7748, loss = 3.184, LR = 0.0006545084971874737
# Validation Loss = 3.581
# Epoch = 3, batch = 4900 of 7748, loss = 3.003, LR = 0.0006545084971874737
# Validation Loss = 3.596
# Epoch = 3, batch = 5000 of 7748, loss = 3.098, LR = 0.0006545084971874737
# Validation Loss = 2.918
# Epoch = 3, batch = 5100 of 7748, loss = 3.337, LR = 0.0006545084971874737
# Validation Loss = 3.803
# Epoch = 3, batch = 5200 of 7748, loss = 3.056, LR = 0.0006545084971874737
# Validation Loss = 4.134
# Epoch = 3, batch = 5300 of 7748, loss = 3.205, LR = 0.0006545084971874737
# Validation Loss = 4.907
# Epoch = 3, batch = 5400 of 7748, loss = 2.747, LR = 0.0006545084971874737
# Validation Loss = 6.590
# Epoch = 3, batch = 5500 of 7748, loss = 3.051, LR = 0.0006545084971874737
# Validation Loss = 4.929
# Epoch = 3, batch = 5600 of 7748, loss = 2.896, LR = 0.0006545084971874737
# Validation Loss = 5.203
# Epoch = 3, batch = 5700 of 7748, loss = 2.991, LR = 0.0006545084971874737
# Validation Loss = 0.995
# Epoch = 3, batch = 5800 of 7748, loss = 3.442, LR = 0.0006545084971874737
# Validation Loss = 1.492
# Epoch = 3, batch = 5900 of 7748, loss = 3.326, LR = 0.0006545084971874737
# Validation Loss = 2.072
# Epoch = 3, batch = 6000 of 7748, loss = 3.897, LR = 0.0006545084971874737
# Validation Loss = 3.422
# Epoch = 3, batch = 6100 of 7748, loss = 3.063, LR = 0.0006545084971874737
# Validation Loss = 0.438
# Epoch = 3, batch = 6200 of 7748, loss = 4.766, LR = 0.0006545084971874737
# Validation Loss = 1.187
# Epoch = 3, batch = 6300 of 7748, loss = 2.926, LR = 0.0006545084971874737
# Validation Loss = 5.061
# Epoch = 3, batch = 6400 of 7748, loss = 2.866, LR = 0.0006545084971874737
# Validation Loss = 4.276
# Epoch = 3, batch = 6500 of 7748, loss = 2.890, LR = 0.0006545084971874737
# Validation Loss = 0.088
# Epoch = 3, batch = 6600 of 7748, loss = 4.591, LR = 0.0006545084971874737
# Validation Loss = 4.893
# Epoch = 3, batch = 6700 of 7748, loss = 3.043, LR = 0.0006545084971874737
# Validation Loss = 1.661
# Epoch = 3, batch = 6800 of 7748, loss = 2.906, LR = 0.0006545084971874737
# Validation Loss = 0.142
# Epoch = 3, batch = 6900 of 7748, loss = 4.820, LR = 0.0006545084971874737
# Validation Loss = 3.869
# Epoch = 3, batch = 7000 of 7748, loss = 3.079, LR = 0.0006545084971874737
# Validation Loss = 7.375
# Epoch = 3, batch = 7100 of 7748, loss = 3.098, LR = 0.0006545084971874737
# Validation Loss = 6.660
# Epoch = 3, batch = 7200 of 7748, loss = 2.785, LR = 0.0006545084971874737
# Validation Loss = 1.882
# Epoch = 3, batch = 7300 of 7748, loss = 2.838, LR = 0.0006545084971874737
# Validation Loss = 9.143
# Epoch = 3, batch = 7400 of 7748, loss = 3.228, LR = 0.0006545084971874737
# Validation Loss = 0.273
# Epoch = 3, batch = 7500 of 7748, loss = 3.495, LR = 0.0006545084971874737
# Validation Loss = 3.757
# Epoch = 3, batch = 7600 of 7748, loss = 3.384, LR = 0.0006545084971874737
# Validation Loss = 1.878
# Epoch = 3, batch = 7700 of 7748, loss = 3.543, LR = 0.0006545084971874737
# Validation Loss = 2.837
# Epoch = 4, batch = 0 of 7748, loss = 2.961, LR = 0.00034549150281252633
# Validation Loss = 4.329
# Epoch = 4, batch = 100 of 7748, loss = 2.710, LR = 0.00034549150281252633
# Validation Loss = 3.239
# Epoch = 4, batch = 200 of 7748, loss = 2.795, LR = 0.00034549150281252633
# Validation Loss = 3.944
# Epoch = 4, batch = 300 of 7748, loss = 2.728, LR = 0.00034549150281252633
# Validation Loss = 4.161
# Epoch = 4, batch = 400 of 7748, loss = 2.744, LR = 0.00034549150281252633
# Validation Loss = 6.820
# Epoch = 4, batch = 500 of 7748, loss = 2.644, LR = 0.00034549150281252633
# Validation Loss = 1.660
# Epoch = 4, batch = 600 of 7748, loss = 2.928, LR = 0.00034549150281252633
# Validation Loss = 6.788
# Epoch = 4, batch = 700 of 7748, loss = 2.491, LR = 0.00034549150281252633
# Validation Loss = 2.841
# Epoch = 4, batch = 800 of 7748, loss = 3.389, LR = 0.00034549150281252633
# Validation Loss = 2.510
# Epoch = 4, batch = 900 of 7748, loss = 2.636, LR = 0.00034549150281252633
# Validation Loss = 4.158
# Epoch = 4, batch = 1000 of 7748, loss = 2.723, LR = 0.00034549150281252633
# Validation Loss = 1.690
# Epoch = 4, batch = 1100 of 7748, loss = 2.574, LR = 0.00034549150281252633
# Validation Loss = 5.357
# Epoch = 4, batch = 1200 of 7748, loss = 2.713, LR = 0.00034549150281252633
# Validation Loss = 5.152
# Epoch = 4, batch = 1300 of 7748, loss = 3.004, LR = 0.00034549150281252633
# Validation Loss = 2.567
# Epoch = 4, batch = 1400 of 7748, loss = 2.830, LR = 0.00034549150281252633
# Validation Loss = 2.724
# Epoch = 4, batch = 1500 of 7748, loss = 2.973, LR = 0.00034549150281252633
# Validation Loss = 1.648
# Epoch = 4, batch = 1600 of 7748, loss = 3.807, LR = 0.00034549150281252633
# Validation Loss = 0.780
# Epoch = 4, batch = 1700 of 7748, loss = 2.974, LR = 0.00034549150281252633
# Validation Loss = 5.257
# Epoch = 4, batch = 1800 of 7748, loss = 2.367, LR = 0.00034549150281252633
# Validation Loss = 3.677
# Epoch = 4, batch = 1900 of 7748, loss = 2.685, LR = 0.00034549150281252633
# Validation Loss = 5.469
# Epoch = 4, batch = 2000 of 7748, loss = 2.269, LR = 0.00034549150281252633
# Validation Loss = 7.274
# Epoch = 4, batch = 2100 of 7748, loss = 2.657, LR = 0.00034549150281252633
# Validation Loss = 0.893
# Epoch = 4, batch = 2200 of 7748, loss = 3.443, LR = 0.00034549150281252633
# Validation Loss = 2.571
# Epoch = 4, batch = 2300 of 7748, loss = 2.597, LR = 0.00034549150281252633
# Validation Loss = 7.166
# Epoch = 4, batch = 2400 of 7748, loss = 3.062, LR = 0.00034549150281252633
# Validation Loss = 1.815
# Epoch = 4, batch = 2500 of 7748, loss = 3.799, LR = 0.00034549150281252633
# Validation Loss = 3.676
# Epoch = 4, batch = 2600 of 7748, loss = 2.729, LR = 0.00034549150281252633
# Validation Loss = 7.005
# Epoch = 4, batch = 2700 of 7748, loss = 2.541, LR = 0.00034549150281252633
# Validation Loss = 2.174
# Epoch = 4, batch = 2800 of 7748, loss = 2.614, LR = 0.00034549150281252633
# Validation Loss = 4.267
# Epoch = 4, batch = 2900 of 7748, loss = 2.769, LR = 0.00034549150281252633
# Validation Loss = 7.032
# Epoch = 4, batch = 3000 of 7748, loss = 2.536, LR = 0.00034549150281252633
# Validation Loss = 3.184
# Epoch = 4, batch = 3100 of 7748, loss = 2.628, LR = 0.00034549150281252633
# Validation Loss = 2.167
# Epoch = 4, batch = 3200 of 7748, loss = 2.384, LR = 0.00034549150281252633
# Validation Loss = 3.245
# Epoch = 4, batch = 3300 of 7748, loss = 2.430, LR = 0.00034549150281252633
# Validation Loss = 3.774
# Epoch = 4, batch = 3400 of 7748, loss = 2.523, LR = 0.00034549150281252633
# Validation Loss = 2.823
# Epoch = 4, batch = 3500 of 7748, loss = 2.504, LR = 0.00034549150281252633
# Validation Loss = 7.409
# Epoch = 4, batch = 3600 of 7748, loss = 2.264, LR = 0.00034549150281252633
# Validation Loss = 6.547
# Epoch = 4, batch = 3700 of 7748, loss = 2.534, LR = 0.00034549150281252633
# Validation Loss = 6.310
# Epoch = 4, batch = 3800 of 7748, loss = 3.284, LR = 0.00034549150281252633
# Validation Loss = 1.328
# Epoch = 4, batch = 3900 of 7748, loss = 2.927, LR = 0.00034549150281252633
# Validation Loss = 3.728
# Epoch = 4, batch = 4000 of 7748, loss = 2.263, LR = 0.00034549150281252633
# Validation Loss = 2.314
# Epoch = 4, batch = 4100 of 7748, loss = 2.587, LR = 0.00034549150281252633
# Validation Loss = 4.789
# Epoch = 4, batch = 4200 of 7748, loss = 2.483, LR = 0.00034549150281252633
# Validation Loss = 2.001
# Epoch = 4, batch = 4300 of 7748, loss = 2.683, LR = 0.00034549150281252633
# Validation Loss = 7.242
# Epoch = 4, batch = 4400 of 7748, loss = 2.318, LR = 0.00034549150281252633
# Validation Loss = 2.997
# Epoch = 4, batch = 4500 of 7748, loss = 2.254, LR = 0.00034549150281252633
# Validation Loss = 1.986
# Epoch = 4, batch = 4600 of 7748, loss = 2.228, LR = 0.00034549150281252633
# Validation Loss = 6.694
# Epoch = 4, batch = 4700 of 7748, loss = 3.197, LR = 0.00034549150281252633
# Validation Loss = 3.824
# Epoch = 4, batch = 4800 of 7748, loss = 2.640, LR = 0.00034549150281252633
# Validation Loss = 1.186
# Epoch = 4, batch = 4900 of 7748, loss = 2.737, LR = 0.00034549150281252633
# Validation Loss = 2.029
# Epoch = 4, batch = 5000 of 7748, loss = 2.332, LR = 0.00034549150281252633
# Validation Loss = 5.823
# Epoch = 4, batch = 5100 of 7748, loss = 2.375, LR = 0.00034549150281252633
# Validation Loss = 1.892
# Epoch = 4, batch = 5200 of 7748, loss = 2.832, LR = 0.00034549150281252633
# Validation Loss = 3.833
# Epoch = 4, batch = 5300 of 7748, loss = 2.494, LR = 0.00034549150281252633
# Validation Loss = 7.396
# Epoch = 4, batch = 5400 of 7748, loss = 2.769, LR = 0.00034549150281252633
# Validation Loss = 2.509
# Epoch = 4, batch = 5500 of 7748, loss = 2.824, LR = 0.00034549150281252633
# Validation Loss = 2.018
# Epoch = 4, batch = 5600 of 7748, loss = 2.319, LR = 0.00034549150281252633
# Validation Loss = 2.335
# Epoch = 4, batch = 5700 of 7748, loss = 2.202, LR = 0.00034549150281252633
# Validation Loss = 1.945
# Epoch = 4, batch = 5800 of 7748, loss = 2.454, LR = 0.00034549150281252633
# Validation Loss = 1.611
# Epoch = 4, batch = 5900 of 7748, loss = 2.531, LR = 0.00034549150281252633
# Validation Loss = 0.981
# Epoch = 4, batch = 6000 of 7748, loss = 3.313, LR = 0.00034549150281252633
# Validation Loss = 6.876
# Epoch = 4, batch = 6100 of 7748, loss = 2.572, LR = 0.00034549150281252633
# Validation Loss = 5.343
# Epoch = 4, batch = 6200 of 7748, loss = 2.270, LR = 0.00034549150281252633
# Validation Loss = 7.362
# Epoch = 4, batch = 6300 of 7748, loss = 2.553, LR = 0.00034549150281252633
# Validation Loss = 2.027
# Epoch = 4, batch = 6400 of 7748, loss = 2.871, LR = 0.00034549150281252633
# Validation Loss = 3.866
# Epoch = 4, batch = 6500 of 7748, loss = 2.721, LR = 0.00034549150281252633
# Validation Loss = 4.072
# Epoch = 4, batch = 6600 of 7748, loss = 2.511, LR = 0.00034549150281252633
# Validation Loss = 1.175
# Epoch = 4, batch = 6700 of 7748, loss = 3.385, LR = 0.00034549150281252633
# Validation Loss = 0.897
# Epoch = 4, batch = 6800 of 7748, loss = 3.417, LR = 0.00034549150281252633
# Validation Loss = 5.185
# Epoch = 4, batch = 6900 of 7748, loss = 2.538, LR = 0.00034549150281252633
# Validation Loss = 6.149
# Epoch = 4, batch = 7000 of 7748, loss = 2.669, LR = 0.00034549150281252633
# Validation Loss = 4.626
# Epoch = 4, batch = 7100 of 7748, loss = 2.720, LR = 0.00034549150281252633
# Validation Loss = 6.320
# Epoch = 4, batch = 7200 of 7748, loss = 2.717, LR = 0.00034549150281252633
# Validation Loss = 4.062
# Epoch = 4, batch = 7300 of 7748, loss = 2.625, LR = 0.00034549150281252633
# Validation Loss = 6.049
# Epoch = 4, batch = 7400 of 7748, loss = 2.273, LR = 0.00034549150281252633
# Validation Loss = 3.972
# Epoch = 4, batch = 7500 of 7748, loss = 2.577, LR = 0.00034549150281252633
# Validation Loss = 7.303
# Epoch = 4, batch = 7600 of 7748, loss = 2.392, LR = 0.00034549150281252633
# Validation Loss = 4.199
# Epoch = 4, batch = 7700 of 7748, loss = 2.088, LR = 0.00034549150281252633
# Validation Loss = 4.166
# Epoch = 5, batch = 0 of 7748, loss = 2.419, LR = 9.549150281252633e-05
# Validation Loss = 4.436
# Epoch = 5, batch = 100 of 7748, loss = 2.271, LR = 9.549150281252633e-05
# Validation Loss = 5.471
# Epoch = 5, batch = 200 of 7748, loss = 2.243, LR = 9.549150281252633e-05
# Validation Loss = 4.038
# Epoch = 5, batch = 300 of 7748, loss = 2.546, LR = 9.549150281252633e-05
# Validation Loss = 5.853
# Epoch = 5, batch = 400 of 7748, loss = 2.282, LR = 9.549150281252633e-05
# Validation Loss = 4.402
# Epoch = 5, batch = 500 of 7748, loss = 2.062, LR = 9.549150281252633e-05
# Validation Loss = 3.859
# Epoch = 5, batch = 600 of 7748, loss = 2.155, LR = 9.549150281252633e-05
# Validation Loss = 2.430
# Epoch = 5, batch = 700 of 7748, loss = 2.248, LR = 9.549150281252633e-05
# Validation Loss = 3.529
# Epoch = 5, batch = 800 of 7748, loss = 2.493, LR = 9.549150281252633e-05
# Validation Loss = 3.494
# Epoch = 5, batch = 900 of 7748, loss = 2.185, LR = 9.549150281252633e-05
# Validation Loss = 5.400
# Epoch = 5, batch = 1000 of 7748, loss = 2.448, LR = 9.549150281252633e-05
# Validation Loss = 4.370
# Epoch = 5, batch = 1100 of 7748, loss = 2.146, LR = 9.549150281252633e-05
# Validation Loss = 4.544
# Epoch = 5, batch = 1200 of 7748, loss = 2.434, LR = 9.549150281252633e-05
# Validation Loss = 3.999
# Epoch = 5, batch = 1300 of 7748, loss = 2.115, LR = 9.549150281252633e-05
# Validation Loss = 5.257
# Epoch = 5, batch = 1400 of 7748, loss = 2.392, LR = 9.549150281252633e-05
# Validation Loss = 4.033
# Epoch = 5, batch = 1500 of 7748, loss = 2.296, LR = 9.549150281252633e-05
# Validation Loss = 1.707
# Epoch = 5, batch = 1600 of 7748, loss = 2.473, LR = 9.549150281252633e-05
# Validation Loss = 4.798
# Epoch = 5, batch = 1700 of 7748, loss = 2.330, LR = 9.549150281252633e-05
# Validation Loss = 4.837
# Epoch = 5, batch = 1800 of 7748, loss = 2.113, LR = 9.549150281252633e-05
# Validation Loss = 4.325
# Epoch = 5, batch = 1900 of 7748, loss = 2.443, LR = 9.549150281252633e-05
# Validation Loss = 4.579
# Epoch = 5, batch = 2000 of 7748, loss = 2.565, LR = 9.549150281252633e-05
# Validation Loss = 3.582
# Epoch = 5, batch = 2100 of 7748, loss = 2.656, LR = 9.549150281252633e-05
# Validation Loss = 6.405
# Epoch = 5, batch = 2200 of 7748, loss = 2.473, LR = 9.549150281252633e-05
# Validation Loss = 4.306
# Epoch = 5, batch = 2300 of 7748, loss = 2.152, LR = 9.549150281252633e-05
# Validation Loss = 4.200
# Epoch = 5, batch = 2400 of 7748, loss = 2.069, LR = 9.549150281252633e-05
# Validation Loss = 4.622
# Epoch = 5, batch = 2500 of 7748, loss = 2.289, LR = 9.549150281252633e-05
# Validation Loss = 5.627
# Epoch = 5, batch = 2600 of 7748, loss = 2.433, LR = 9.549150281252633e-05
# Validation Loss = 4.823
# Epoch = 5, batch = 2700 of 7748, loss = 2.077, LR = 9.549150281252633e-05
# Validation Loss = 3.457
# Epoch = 5, batch = 2800 of 7748, loss = 2.739, LR = 9.549150281252633e-05
# Validation Loss = 5.132
# Epoch = 5, batch = 2900 of 7748, loss = 2.547, LR = 9.549150281252633e-05
# Validation Loss = 6.579
# Epoch = 5, batch = 3000 of 7748, loss = 2.237, LR = 9.549150281252633e-05
# Validation Loss = 3.917
# Epoch = 5, batch = 3100 of 7748, loss = 2.359, LR = 9.549150281252633e-05
# Validation Loss = 4.687
# Epoch = 5, batch = 3200 of 7748, loss = 1.998, LR = 9.549150281252633e-05
# Validation Loss = 5.796
# Epoch = 5, batch = 3300 of 7748, loss = 2.562, LR = 9.549150281252633e-05
# Validation Loss = 4.259
# Epoch = 5, batch = 3400 of 7748, loss = 2.163, LR = 9.549150281252633e-05
# Validation Loss = 5.607
# Epoch = 5, batch = 3500 of 7748, loss = 2.247, LR = 9.549150281252633e-05
# Validation Loss = 3.485
# Epoch = 5, batch = 3600 of 7748, loss = 2.268, LR = 9.549150281252633e-05
# Validation Loss = 6.160
# Epoch = 5, batch = 3700 of 7748, loss = 2.379, LR = 9.549150281252633e-05
# Validation Loss = 6.805
# Epoch = 5, batch = 3800 of 7748, loss = 2.352, LR = 9.549150281252633e-05
# Validation Loss = 3.784
# Epoch = 5, batch = 3900 of 7748, loss = 2.167, LR = 9.549150281252633e-05
# Validation Loss = 2.011
# Epoch = 5, batch = 4000 of 7748, loss = 2.784, LR = 9.549150281252633e-05
# Validation Loss = 4.624
# Epoch = 5, batch = 4100 of 7748, loss = 2.612, LR = 9.549150281252633e-05
# Validation Loss = 3.650
# Epoch = 5, batch = 4200 of 7748, loss = 2.481, LR = 9.549150281252633e-05
# Validation Loss = 4.026
# Epoch = 5, batch = 4300 of 7748, loss = 2.234, LR = 9.549150281252633e-05
# Validation Loss = 6.400
# Epoch = 5, batch = 4400 of 7748, loss = 2.210, LR = 9.549150281252633e-05
# Validation Loss = 7.279
# Epoch = 5, batch = 4500 of 7748, loss = 2.605, LR = 9.549150281252633e-05
# Validation Loss = 3.154
# Epoch = 5, batch = 4600 of 7748, loss = 2.053, LR = 9.549150281252633e-05
# Validation Loss = 4.839
# Epoch = 5, batch = 4700 of 7748, loss = 2.116, LR = 9.549150281252633e-05
# Validation Loss = 6.773
# Epoch = 5, batch = 4800 of 7748, loss = 2.428, LR = 9.549150281252633e-05
# Validation Loss = 4.710
# Epoch = 5, batch = 4900 of 7748, loss = 2.162, LR = 9.549150281252633e-05
# Validation Loss = 6.481
# Epoch = 5, batch = 5000 of 7748, loss = 2.538, LR = 9.549150281252633e-05
# Validation Loss = 3.889
# Epoch = 5, batch = 5100 of 7748, loss = 2.049, LR = 9.549150281252633e-05
# Validation Loss = 3.715
# Epoch = 5, batch = 5200 of 7748, loss = 2.658, LR = 9.549150281252633e-05
# Validation Loss = 3.362
# Epoch = 5, batch = 5300 of 7748, loss = 2.389, LR = 9.549150281252633e-05
# Validation Loss = 3.657
# Epoch = 5, batch = 5400 of 7748, loss = 2.148, LR = 9.549150281252633e-05
# Validation Loss = 5.309
# Epoch = 5, batch = 5500 of 7748, loss = 2.488, LR = 9.549150281252633e-05
# Validation Loss = 4.933
# Epoch = 5, batch = 5600 of 7748, loss = 2.194, LR = 9.549150281252633e-05
# Validation Loss = 4.676
# Epoch = 5, batch = 5700 of 7748, loss = 2.355, LR = 9.549150281252633e-05
# Validation Loss = 3.125
# Epoch = 5, batch = 5800 of 7748, loss = 2.286, LR = 9.549150281252633e-05
# Validation Loss = 4.272
# Epoch = 5, batch = 5900 of 7748, loss = 1.920, LR = 9.549150281252633e-05
# Validation Loss = 4.950
# Epoch = 5, batch = 6000 of 7748, loss = 2.504, LR = 9.549150281252633e-05
# Validation Loss = 3.643
# Epoch = 5, batch = 6100 of 7748, loss = 2.582, LR = 9.549150281252633e-05
# Validation Loss = 7.376
# Epoch = 5, batch = 6200 of 7748, loss = 2.485, LR = 9.549150281252633e-05
# Validation Loss = 5.146
# Epoch = 5, batch = 6300 of 7748, loss = 2.479, LR = 9.549150281252633e-05
# Validation Loss = 4.656
# Epoch = 5, batch = 6400 of 7748, loss = 2.242, LR = 9.549150281252633e-05
# Validation Loss = 5.158
# Epoch = 5, batch = 6500 of 7748, loss = 1.939, LR = 9.549150281252633e-05
# Validation Loss = 5.637
# Epoch = 5, batch = 6600 of 7748, loss = 2.491, LR = 9.549150281252633e-05
# Validation Loss = 3.288
# Epoch = 5, batch = 6700 of 7748, loss = 2.175, LR = 9.549150281252633e-05
# Validation Loss = 5.461
# Epoch = 5, batch = 6800 of 7748, loss = 2.267, LR = 9.549150281252633e-05
# Validation Loss = 5.133
# Epoch = 5, batch = 6900 of 7748, loss = 2.201, LR = 9.549150281252633e-05
# Validation Loss = 3.747
# Epoch = 5, batch = 7000 of 7748, loss = 2.079, LR = 9.549150281252633e-05
# Validation Loss = 4.892
# Epoch = 5, batch = 7100 of 7748, loss = 2.105, LR = 9.549150281252633e-05
# Validation Loss = 4.400
# Epoch = 5, batch = 7200 of 7748, loss = 2.383, LR = 9.549150281252633e-05
# Validation Loss = 3.411
# Epoch = 5, batch = 7300 of 7748, loss = 2.778, LR = 9.549150281252633e-05
# Validation Loss = 5.383
# Epoch = 5, batch = 7400 of 7748, loss = 2.298, LR = 9.549150281252633e-05
# Validation Loss = 3.043
# Epoch = 5, batch = 7500 of 7748, loss = 2.356, LR = 9.549150281252633e-05
# Validation Loss = 5.080
# Epoch = 5, batch = 7600 of 7748, loss = 2.034, LR = 9.549150281252633e-05
# Validation Loss = 3.710
# Epoch = 5, batch = 7700 of 7748, loss = 2.300, LR = 9.549150281252633e-05
# Training stage: 2
# Validation Loss = 5.310
# Epoch = 1, batch = 0 of 7748, loss = 2.531, LR = 0.001
# Validation Loss = 1.199
# Epoch = 1, batch = 100 of 7748, loss = 6.164, LR = 0.001
# Validation Loss = 1.687
# Epoch = 1, batch = 200 of 7748, loss = 5.355, LR = 0.001
# Validation Loss = 1.809
# Epoch = 1, batch = 300 of 7748, loss = 4.166, LR = 0.001
# Validation Loss = 1.560
# Epoch = 1, batch = 400 of 7748, loss = 4.456, LR = 0.001
# Validation Loss = 1.610
# Epoch = 1, batch = 500 of 7748, loss = 4.700, LR = 0.001
# Validation Loss = 1.620
# Epoch = 1, batch = 600 of 7748, loss = 4.452, LR = 0.001
# Validation Loss = 3.149
# Epoch = 1, batch = 700 of 7748, loss = 4.420, LR = 0.001
# Validation Loss = 3.105
# Epoch = 1, batch = 800 of 7748, loss = 4.241, LR = 0.001
# Validation Loss = 1.305
# Epoch = 1, batch = 900 of 7748, loss = 5.187, LR = 0.001
# Validation Loss = 0.301
# Epoch = 1, batch = 1000 of 7748, loss = 4.389, LR = 0.001
# Validation Loss = 2.344
# Epoch = 1, batch = 1100 of 7748, loss = 4.527, LR = 0.001
# Validation Loss = 1.075
# Epoch = 1, batch = 1200 of 7748, loss = 3.025, LR = 0.001
# Validation Loss = 2.595
# Epoch = 1, batch = 1300 of 7748, loss = 3.599, LR = 0.001
# Validation Loss = 2.116
# Epoch = 1, batch = 1400 of 7748, loss = 3.494, LR = 0.001
# Validation Loss = 0.229
# Epoch = 1, batch = 1500 of 7748, loss = 4.277, LR = 0.001
# Validation Loss = 0.321
# Epoch = 1, batch = 1600 of 7748, loss = 3.626, LR = 0.001
# Validation Loss = 0.310
# Epoch = 1, batch = 1700 of 7748, loss = 7.764, LR = 0.001
# Validation Loss = 4.262
# Epoch = 1, batch = 1800 of 7748, loss = 3.947, LR = 0.001
# Validation Loss = 2.337
# Epoch = 1, batch = 1900 of 7748, loss = 5.514, LR = 0.001
# Validation Loss = 5.401
# Epoch = 1, batch = 2000 of 7748, loss = 4.077, LR = 0.001
# Validation Loss = 2.510
# Epoch = 1, batch = 2100 of 7748, loss = 3.239, LR = 0.001
# Validation Loss = 1.971
# Epoch = 1, batch = 2200 of 7748, loss = 3.169, LR = 0.001
# Validation Loss = 9.291
# Epoch = 1, batch = 2300 of 7748, loss = 6.722, LR = 0.001
# Validation Loss = 0.245
# Epoch = 1, batch = 2400 of 7748, loss = 4.374, LR = 0.001
# Validation Loss = 1.234
# Epoch = 1, batch = 2500 of 7748, loss = 3.115, LR = 0.001
# Validation Loss = 3.793
# Epoch = 1, batch = 2600 of 7748, loss = 3.357, LR = 0.001
# Validation Loss = 6.315
# Epoch = 1, batch = 2700 of 7748, loss = 4.430, LR = 0.001
# Validation Loss = 1.710
# Epoch = 1, batch = 2800 of 7748, loss = 2.863, LR = 0.001
# Validation Loss = 5.853
# Epoch = 1, batch = 2900 of 7748, loss = 4.856, LR = 0.001
# Validation Loss = 1.867
# Epoch = 1, batch = 3000 of 7748, loss = 11.432, LR = 0.001
# Validation Loss = 5.899
# Epoch = 1, batch = 3100 of 7748, loss = 3.268, LR = 0.001
# Validation Loss = 5.431
# Epoch = 1, batch = 3200 of 7748, loss = 3.589, LR = 0.001
# Validation Loss = 1.162
# Epoch = 1, batch = 3300 of 7748, loss = 3.188, LR = 0.001
# Validation Loss = 5.081
# Epoch = 1, batch = 3400 of 7748, loss = 4.547, LR = 0.001
# Validation Loss = 2.541
# Epoch = 1, batch = 3500 of 7748, loss = 2.712, LR = 0.001
# Validation Loss = 0.028
# Epoch = 1, batch = 3600 of 7748, loss = 4.547, LR = 0.001
# Validation Loss = 6.310
# Epoch = 1, batch = 3700 of 7748, loss = 4.567, LR = 0.001
# Validation Loss = 1.981
# Epoch = 1, batch = 3800 of 7748, loss = 3.533, LR = 0.001
# Validation Loss = 0.571
# Epoch = 1, batch = 3900 of 7748, loss = 3.790, LR = 0.001
# Validation Loss = 0.140
# Epoch = 1, batch = 4000 of 7748, loss = 4.156, LR = 0.001
# Validation Loss = 0.646
# Epoch = 1, batch = 4100 of 7748, loss = 3.394, LR = 0.001
# Validation Loss = 2.217
# Epoch = 1, batch = 4200 of 7748, loss = 2.788, LR = 0.001
# Validation Loss = 1.748
# Epoch = 1, batch = 4300 of 7748, loss = 3.792, LR = 0.001
# Validation Loss = 0.927
# Epoch = 1, batch = 4400 of 7748, loss = 3.201, LR = 0.001
# Validation Loss = 0.620
# Epoch = 1, batch = 4500 of 7748, loss = 3.538, LR = 0.001
# Validation Loss = 0.352
# Epoch = 1, batch = 4600 of 7748, loss = 3.512, LR = 0.001
# Validation Loss = 5.107
# Epoch = 1, batch = 4700 of 7748, loss = 3.388, LR = 0.001
# Validation Loss = 4.571
# Epoch = 1, batch = 4800 of 7748, loss = 3.001, LR = 0.001
# Validation Loss = 2.101
# Epoch = 1, batch = 4900 of 7748, loss = 3.019, LR = 0.001
# Validation Loss = 3.545
# Epoch = 1, batch = 5000 of 7748, loss = 2.882, LR = 0.001
# Validation Loss = 0.167
# Epoch = 1, batch = 5100 of 7748, loss = 4.361, LR = 0.001
# Validation Loss = 3.792
# Epoch = 1, batch = 5200 of 7748, loss = 3.382, LR = 0.001
# Validation Loss = 0.006
# Epoch = 1, batch = 5300 of 7748, loss = 4.066, LR = 0.001
# Validation Loss = 2.321
# Epoch = 1, batch = 5400 of 7748, loss = 2.974, LR = 0.001
# Validation Loss = 3.426
# Epoch = 1, batch = 5500 of 7748, loss = 2.937, LR = 0.001
# Validation Loss = 3.954
# Epoch = 1, batch = 5600 of 7748, loss = 2.878, LR = 0.001
# Validation Loss = 0.004
# Epoch = 1, batch = 5700 of 7748, loss = 7.200, LR = 0.001
# Validation Loss = 4.800
# Epoch = 1, batch = 5800 of 7748, loss = 3.134, LR = 0.001
# Validation Loss = 0.983
# Epoch = 1, batch = 5900 of 7748, loss = 2.625, LR = 0.001
# Validation Loss = 2.655
# Epoch = 1, batch = 6000 of 7748, loss = 2.840, LR = 0.001
# Validation Loss = 0.000
# Epoch = 1, batch = 6100 of 7748, loss = 5.403, LR = 0.001
# Validation Loss = 3.576
# Epoch = 1, batch = 6200 of 7748, loss = 2.802, LR = 0.001
# Validation Loss = 0.334
# Epoch = 1, batch = 6300 of 7748, loss = 5.854, LR = 0.001
# Validation Loss = 0.544
# Epoch = 1, batch = 6400 of 7748, loss = 3.820, LR = 0.001
# Validation Loss = 5.844
# Epoch = 1, batch = 6500 of 7748, loss = 3.392, LR = 0.001
# Validation Loss = 0.105
# Epoch = 1, batch = 6600 of 7748, loss = 3.545, LR = 0.001
# Validation Loss = 12.543
# Epoch = 1, batch = 6700 of 7748, loss = 7.664, LR = 0.001
# Validation Loss = 2.250
# Epoch = 1, batch = 6800 of 7748, loss = 3.334, LR = 0.001
# Validation Loss = 6.855
# Epoch = 1, batch = 6900 of 7748, loss = 3.418, LR = 0.001
# Validation Loss = 6.247
# Epoch = 1, batch = 7000 of 7748, loss = 3.678, LR = 0.001
# Validation Loss = 1.463
# Epoch = 1, batch = 7100 of 7748, loss = 2.935, LR = 0.001
# Validation Loss = 2.983
# Epoch = 1, batch = 7200 of 7748, loss = 2.515, LR = 0.001
# Validation Loss = 1.741
# Epoch = 1, batch = 7300 of 7748, loss = 2.443, LR = 0.001
# Validation Loss = 0.254
# Epoch = 1, batch = 7400 of 7748, loss = 3.596, LR = 0.001
# Validation Loss = 1.401
# Epoch = 1, batch = 7500 of 7748, loss = 2.846, LR = 0.001
# Validation Loss = 1.146
# Epoch = 1, batch = 7600 of 7748, loss = 3.569, LR = 0.001
# Validation Loss = 3.844
# Epoch = 1, batch = 7700 of 7748, loss = 2.603, LR = 0.001
# Validation Loss = 6.737
# Epoch = 2, batch = 0 of 7748, loss = 2.950, LR = 0.0009755282581475768
# Validation Loss = 5.021
# Epoch = 2, batch = 100 of 7748, loss = 3.513, LR = 0.0009755282581475768
# Validation Loss = 2.311
# Epoch = 2, batch = 200 of 7748, loss = 2.958, LR = 0.0009755282581475768
# Validation Loss = 4.636
# Epoch = 2, batch = 300 of 7748, loss = 2.926, LR = 0.0009755282581475768
# Validation Loss = 2.163
# Epoch = 2, batch = 400 of 7748, loss = 2.694, LR = 0.0009755282581475768
# Validation Loss = 6.177
# Epoch = 2, batch = 500 of 7748, loss = 2.590, LR = 0.0009755282581475768
# Validation Loss = 3.011
# Epoch = 2, batch = 600 of 7748, loss = 2.598, LR = 0.0009755282581475768
# Validation Loss = 2.487
# Epoch = 2, batch = 700 of 7748, loss = 2.284, LR = 0.0009755282581475768
# Validation Loss = 9.893
# Epoch = 2, batch = 800 of 7748, loss = 4.033, LR = 0.0009755282581475768
# Validation Loss = 6.680
# Epoch = 2, batch = 900 of 7748, loss = 3.440, LR = 0.0009755282581475768
# Validation Loss = 7.786
# Epoch = 2, batch = 1000 of 7748, loss = 3.651, LR = 0.0009755282581475768
# Validation Loss = 2.445
# Epoch = 2, batch = 1100 of 7748, loss = 2.610, LR = 0.0009755282581475768
# Validation Loss = 0.541
# Epoch = 2, batch = 1200 of 7748, loss = 4.195, LR = 0.0009755282581475768
# Validation Loss = 4.013
# Epoch = 2, batch = 1300 of 7748, loss = 2.887, LR = 0.0009755282581475768
# Validation Loss = 5.763
# Epoch = 2, batch = 1400 of 7748, loss = 2.457, LR = 0.0009755282581475768
# Validation Loss = 2.048
# Epoch = 2, batch = 1500 of 7748, loss = 2.342, LR = 0.0009755282581475768
# Validation Loss = 5.405
# Epoch = 2, batch = 1600 of 7748, loss = 3.192, LR = 0.0009755282581475768
# Validation Loss = 5.648
# Epoch = 2, batch = 1700 of 7748, loss = 2.892, LR = 0.0009755282581475768
# Validation Loss = 2.426
# Epoch = 2, batch = 1800 of 7748, loss = 2.436, LR = 0.0009755282581475768
# Validation Loss = 9.864
# Epoch = 2, batch = 1900 of 7748, loss = 4.417, LR = 0.0009755282581475768
# Validation Loss = 1.254
# Epoch = 2, batch = 2000 of 7748, loss = 2.437, LR = 0.0009755282581475768
# Validation Loss = 2.478
# Epoch = 2, batch = 2100 of 7748, loss = 2.509, LR = 0.0009755282581475768
# Validation Loss = 16.702
# Epoch = 2, batch = 2200 of 7748, loss = 4.805, LR = 0.0009755282581475768
# Validation Loss = 1.554
# Epoch = 2, batch = 2300 of 7748, loss = 3.315, LR = 0.0009755282581475768
# Validation Loss = 1.066
# Epoch = 2, batch = 2400 of 7748, loss = 2.943, LR = 0.0009755282581475768
# Validation Loss = 1.385
# Epoch = 2, batch = 2500 of 7748, loss = 2.739, LR = 0.0009755282581475768
# Validation Loss = 5.835
# Epoch = 2, batch = 2600 of 7748, loss = 3.198, LR = 0.0009755282581475768
# Validation Loss = 2.245
# Epoch = 2, batch = 2700 of 7748, loss = 2.376, LR = 0.0009755282581475768
# Validation Loss = 11.527
# Epoch = 2, batch = 2800 of 7748, loss = 4.062, LR = 0.0009755282581475768
# Validation Loss = 0.322
# Epoch = 2, batch = 2900 of 7748, loss = 5.197, LR = 0.0009755282581475768
# Validation Loss = 2.533
# Epoch = 2, batch = 3000 of 7748, loss = 2.733, LR = 0.0009755282581475768
# Validation Loss = 1.418
# Epoch = 2, batch = 3100 of 7748, loss = 2.749, LR = 0.0009755282581475768
# Validation Loss = 1.964
# Epoch = 2, batch = 3200 of 7748, loss = 2.635, LR = 0.0009755282581475768
# Validation Loss = 2.696
# Epoch = 2, batch = 3300 of 7748, loss = 2.687, LR = 0.0009755282581475768
# Validation Loss = 4.354
# Epoch = 2, batch = 3400 of 7748, loss = 2.179, LR = 0.0009755282581475768
# Validation Loss = 1.499
# Epoch = 2, batch = 3500 of 7748, loss = 3.443, LR = 0.0009755282581475768
# Validation Loss = 1.499
# Epoch = 2, batch = 3600 of 7748, loss = 3.525, LR = 0.0009755282581475768
# Validation Loss = 2.886
# Epoch = 2, batch = 3700 of 7748, loss = 2.737, LR = 0.0009755282581475768
# Validation Loss = 2.039
# Epoch = 2, batch = 3800 of 7748, loss = 2.565, LR = 0.0009755282581475768
# Validation Loss = 3.769
# Epoch = 2, batch = 3900 of 7748, loss = 2.347, LR = 0.0009755282581475768
# Validation Loss = 4.348
# Epoch = 2, batch = 4000 of 7748, loss = 2.658, LR = 0.0009755282581475768
# Validation Loss = 4.507
# Epoch = 2, batch = 4100 of 7748, loss = 2.366, LR = 0.0009755282581475768
# Validation Loss = 13.217
# Epoch = 2, batch = 4200 of 7748, loss = 3.270, LR = 0.0009755282581475768
# Validation Loss = 3.950
# Epoch = 2, batch = 4300 of 7748, loss = 2.301, LR = 0.0009755282581475768
# Validation Loss = 3.423
# Epoch = 2, batch = 4400 of 7748, loss = 2.826, LR = 0.0009755282581475768
# Validation Loss = 5.256
# Epoch = 2, batch = 4500 of 7748, loss = 2.510, LR = 0.0009755282581475768
# Validation Loss = 4.417
# Epoch = 2, batch = 4600 of 7748, loss = 2.410, LR = 0.0009755282581475768
# Validation Loss = 0.295
# Epoch = 2, batch = 4700 of 7748, loss = 5.928, LR = 0.0009755282581475768
# Validation Loss = 2.501
# Epoch = 2, batch = 4800 of 7748, loss = 2.233, LR = 0.0009755282581475768
# Validation Loss = 4.906
# Epoch = 2, batch = 4900 of 7748, loss = 2.249, LR = 0.0009755282581475768
# Validation Loss = 6.280
# Epoch = 2, batch = 5000 of 7748, loss = 2.582, LR = 0.0009755282581475768
# Validation Loss = 1.599
# Epoch = 2, batch = 5100 of 7748, loss = 2.420, LR = 0.0009755282581475768
# Validation Loss = 14.195
# Epoch = 2, batch = 5200 of 7748, loss = 5.102, LR = 0.0009755282581475768
# Validation Loss = 2.430
# Epoch = 2, batch = 5300 of 7748, loss = 2.664, LR = 0.0009755282581475768
# Validation Loss = 8.565
# Epoch = 2, batch = 5400 of 7748, loss = 2.755, LR = 0.0009755282581475768
# Validation Loss = 3.367
# Epoch = 2, batch = 5500 of 7748, loss = 2.954, LR = 0.0009755282581475768
# Validation Loss = 4.104
# Epoch = 2, batch = 5600 of 7748, loss = 2.457, LR = 0.0009755282581475768
# Validation Loss = 2.342
# Epoch = 2, batch = 5700 of 7748, loss = 3.038, LR = 0.0009755282581475768
# Validation Loss = 3.083
# Epoch = 2, batch = 5800 of 7748, loss = 2.364, LR = 0.0009755282581475768
# Validation Loss = 6.080
# Epoch = 2, batch = 5900 of 7748, loss = 2.416, LR = 0.0009755282581475768
# Validation Loss = 0.489
# Epoch = 2, batch = 6000 of 7748, loss = 3.711, LR = 0.0009755282581475768
# Validation Loss = 2.907
# Epoch = 2, batch = 6100 of 7748, loss = 2.229, LR = 0.0009755282581475768
# Validation Loss = 1.783
# Epoch = 2, batch = 6200 of 7748, loss = 2.382, LR = 0.0009755282581475768
# Validation Loss = 5.545
# Epoch = 2, batch = 6300 of 7748, loss = 2.498, LR = 0.0009755282581475768
# Validation Loss = 1.411
# Epoch = 2, batch = 6400 of 7748, loss = 2.813, LR = 0.0009755282581475768
# Validation Loss = 10.841
# Epoch = 2, batch = 6500 of 7748, loss = 2.599, LR = 0.0009755282581475768
# Validation Loss = 5.862
# Epoch = 2, batch = 6600 of 7748, loss = 2.213, LR = 0.0009755282581475768
# Validation Loss = 4.558
# Epoch = 2, batch = 6700 of 7748, loss = 2.450, LR = 0.0009755282581475768
# Validation Loss = 8.282
# Epoch = 2, batch = 6800 of 7748, loss = 2.989, LR = 0.0009755282581475768
# Validation Loss = 1.941
# Epoch = 2, batch = 6900 of 7748, loss = 2.866, LR = 0.0009755282581475768
# Validation Loss = 3.011
# Epoch = 2, batch = 7000 of 7748, loss = 2.559, LR = 0.0009755282581475768
# Validation Loss = 9.479
# Epoch = 2, batch = 7100 of 7748, loss = 3.242, LR = 0.0009755282581475768
# Validation Loss = 11.725
# Epoch = 2, batch = 7200 of 7748, loss = 3.170, LR = 0.0009755282581475768
# Validation Loss = 7.089
# Epoch = 2, batch = 7300 of 7748, loss = 2.258, LR = 0.0009755282581475768
# Validation Loss = 8.551
# Epoch = 2, batch = 7400 of 7748, loss = 3.491, LR = 0.0009755282581475768
# Validation Loss = 6.211
# Epoch = 2, batch = 7500 of 7748, loss = 3.266, LR = 0.0009755282581475768
# Validation Loss = 11.074
# Epoch = 2, batch = 7600 of 7748, loss = 3.317, LR = 0.0009755282581475768
# Validation Loss = 3.911
# Epoch = 2, batch = 7700 of 7748, loss = 2.069, LR = 0.0009755282581475768
# Validation Loss = 4.239
# Epoch = 3, batch = 0 of 7748, loss = 2.756, LR = 0.0009045084971874736
# Validation Loss = 4.096
# Epoch = 3, batch = 100 of 7748, loss = 2.522, LR = 0.0009045084971874736
# Validation Loss = 8.888
# Epoch = 3, batch = 200 of 7748, loss = 2.760, LR = 0.0009045084971874736
# Validation Loss = 6.995
# Epoch = 3, batch = 300 of 7748, loss = 2.389, LR = 0.0009045084971874736
# Validation Loss = 4.494
# Epoch = 3, batch = 400 of 7748, loss = 2.105, LR = 0.0009045084971874736
# Validation Loss = 6.447
# Epoch = 3, batch = 500 of 7748, loss = 2.284, LR = 0.0009045084971874736
# Validation Loss = 5.309
# Epoch = 3, batch = 600 of 7748, loss = 2.205, LR = 0.0009045084971874736
# Validation Loss = 6.679
# Epoch = 3, batch = 700 of 7748, loss = 2.292, LR = 0.0009045084971874736
# Validation Loss = 5.115
# Epoch = 3, batch = 800 of 7748, loss = 2.429, LR = 0.0009045084971874736
# Validation Loss = 12.539
# Epoch = 3, batch = 900 of 7748, loss = 3.441, LR = 0.0009045084971874736
# Validation Loss = 6.007
# Epoch = 3, batch = 1000 of 7748, loss = 2.577, LR = 0.0009045084971874736
# Validation Loss = 10.433
# Epoch = 3, batch = 1100 of 7748, loss = 3.589, LR = 0.0009045084971874736
# Validation Loss = 9.626
# Epoch = 3, batch = 1200 of 7748, loss = 2.366, LR = 0.0009045084971874736
# Validation Loss = 9.698
# Epoch = 3, batch = 1300 of 7748, loss = 2.472, LR = 0.0009045084971874736
# Validation Loss = 7.539
# Epoch = 3, batch = 1400 of 7748, loss = 2.409, LR = 0.0009045084971874736
# Validation Loss = 5.304
# Epoch = 3, batch = 1500 of 7748, loss = 3.224, LR = 0.0009045084971874736
# Validation Loss = 6.048
# Epoch = 3, batch = 1600 of 7748, loss = 2.245, LR = 0.0009045084971874736
# Validation Loss = 8.923
# Epoch = 3, batch = 1700 of 7748, loss = 2.386, LR = 0.0009045084971874736
# Validation Loss = 6.831
# Epoch = 3, batch = 1800 of 7748, loss = 2.719, LR = 0.0009045084971874736
# Validation Loss = 3.227
# Epoch = 3, batch = 1900 of 7748, loss = 4.672, LR = 0.0009045084971874736
# Validation Loss = 8.516
# Epoch = 3, batch = 2000 of 7748, loss = 2.485, LR = 0.0009045084971874736
# Validation Loss = 3.100
# Epoch = 3, batch = 2100 of 7748, loss = 2.416, LR = 0.0009045084971874736
# Validation Loss = 1.709
# Epoch = 3, batch = 2200 of 7748, loss = 3.006, LR = 0.0009045084971874736
# Validation Loss = 5.554
# Epoch = 3, batch = 2300 of 7748, loss = 2.425, LR = 0.0009045084971874736
# Validation Loss = 5.137
# Epoch = 3, batch = 2400 of 7748, loss = 2.345, LR = 0.0009045084971874736
# Validation Loss = 2.915
# Epoch = 3, batch = 2500 of 7748, loss = 2.379, LR = 0.0009045084971874736
# Validation Loss = 10.370
# Epoch = 3, batch = 2600 of 7748, loss = 3.050, LR = 0.0009045084971874736
# Validation Loss = 2.132
# Epoch = 3, batch = 2700 of 7748, loss = 2.880, LR = 0.0009045084971874736
# Validation Loss = 5.949
# Epoch = 3, batch = 2800 of 7748, loss = 2.063, LR = 0.0009045084971874736
# Validation Loss = 8.457
# Epoch = 3, batch = 2900 of 7748, loss = 2.452, LR = 0.0009045084971874736
# Validation Loss = 7.185
# Epoch = 3, batch = 3000 of 7748, loss = 2.287, LR = 0.0009045084971874736
# Validation Loss = 6.136
# Epoch = 3, batch = 3100 of 7748, loss = 2.020, LR = 0.0009045084971874736
# Validation Loss = 2.598
# Epoch = 3, batch = 3200 of 7748, loss = 3.091, LR = 0.0009045084971874736
# Validation Loss = 4.372
# Epoch = 3, batch = 3300 of 7748, loss = 2.047, LR = 0.0009045084971874736
# Validation Loss = 11.590
# Epoch = 3, batch = 3400 of 7748, loss = 3.187, LR = 0.0009045084971874736
# Validation Loss = 5.922
# Epoch = 3, batch = 3500 of 7748, loss = 2.498, LR = 0.0009045084971874736
# Validation Loss = 7.631
# Epoch = 3, batch = 3600 of 7748, loss = 2.357, LR = 0.0009045084971874736
# Validation Loss = 3.917
# Epoch = 3, batch = 3700 of 7748, loss = 3.469, LR = 0.0009045084971874736
# Validation Loss = 5.545
# Epoch = 3, batch = 3800 of 7748, loss = 2.486, LR = 0.0009045084971874736
# Validation Loss = 13.396
# Epoch = 3, batch = 3900 of 7748, loss = 4.234, LR = 0.0009045084971874736
# Validation Loss = 4.065
# Epoch = 3, batch = 4000 of 7748, loss = 2.347, LR = 0.0009045084971874736
# Validation Loss = 12.458
# Epoch = 3, batch = 4100 of 7748, loss = 2.496, LR = 0.0009045084971874736
# Validation Loss = 18.909
# Epoch = 3, batch = 4200 of 7748, loss = 3.098, LR = 0.0009045084971874736
# Validation Loss = 9.608
# Epoch = 3, batch = 4300 of 7748, loss = 2.956, LR = 0.0009045084971874736
# Validation Loss = 6.864
# Epoch = 3, batch = 4400 of 7748, loss = 2.558, LR = 0.0009045084971874736
