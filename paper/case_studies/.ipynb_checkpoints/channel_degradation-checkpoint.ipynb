# %%
'''
Case study for paper: Channel degradation of SSMI 
'''


import numpy as np
import pickle
from contextlib import contextmanager
import os
import matplotlib.pyplot as plt
import glob

@contextmanager
def cd(newdir):
    prevdir = os.getcwd()
    os.chdir(newdir)
    try:
        yield
    finally:
        os.chdir(prevdir)


ssmi_path = '../SSMI/F13'
with cd(ssmi_path):
    import sensor_info

chan_desc = sensor_info.channel_descriptions

# %%
flist = glob.glob(f'/qdata1/pbrown/transfer/spencer/SSMI_files/F08_*_qc.pkl'); flist.sort()

for i,ifile in enumerate(flist):
    if len(ifile.split('/')[-1].split('_')[1]) > 4: continue
    with open(ifile, 'rb') as f:
        data = pickle.load(f)
    if i == 0:
        datetimes = data['datetimes']
        counts    = data['counts_array']
    else:
        datetimes = np.concatenate((datetimes, data['datetimes']))
        counts    = np.concatenate((counts, data['counts_array']), axis=0)

# %%
import datetime
end = np.where(datetimes > datetime.datetime(1989,7,1,0,0,0))[0][0]

# %%
datetimes = datetimes[:end]
counts    = counts[:end,:]

# %%
#Apply running mean to make plots nicer
import stats
for ichan in range(nchans):
    counts[:,ichan] = stats.running_mean(counts[:,ichan], window_size=9, method='center')
# Out:
# array([468.        , 437.55555556, 458.55555556, ...,   0.        ,
#          0.        ,   0.        ], shape=(9120,))

# %%
plt.figure(figsize=[8,6])
for ichan in range(nchans):
    plt.plot(datetimes,counts[:,ichan])

# %%
file = '/qdata1/pbrown/transfer/spencer/SSMI_files/F08_198902_qc.pkl'

with open(file, "rb") as f:
    data = pickle.load(f)

ndates, nchans = data['counts_array'].shape

# %%
plt.figure(figsize=[8,6])
for ichan in range(nchans):
    plt.plot(data['datetimes'],data['counts_array'][:,ichan])
